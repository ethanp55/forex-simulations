# %%
import talib
import numpy as np
import pandas as pd
import random
from collections import deque

# %%
file_path = '/Users/mymac/Google_Drive/Forex_Robot/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
df = pd.read_csv(file_path + 'Oanda_Gbp_Usd_M5_2020-2021.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2020-07-30 07:00:00   1.29543   1.29607  1.29540    1.29572   1.29562
# 1 2020-07-30 07:05:00   1.29569   1.29591  1.29505    1.29542   1.29588
# 2 2020-07-30 07:10:00   1.29541   1.29590  1.29514    1.29559   1.29557
# 3 2020-07-30 07:15:00   1.29561   1.29567  1.29510    1.29515   1.29577
# 4 2020-07-30 07:20:00   1.29514   1.29643  1.29501    1.29642   1.29529
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 0   1.29623  1.29560    1.29589   1.29552   1.29615  1.29550    1.29580
# 1   1.29608  1.29522    1.29560   1.29578   1.29600  1.29514    1.29551
# 2   1.29606  1.29535    1.29575   1.29549   1.29598  1.29524    1.29567
# 3   1.29584  1.29530    1.29533   1.29569   1.29576  1.29520    1.29524
# 4   1.29660  1.29518    1.29660   1.29522   1.29652  1.29510    1.29651
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 74259 2021-07-30 06:35:00   1.39401   1.39451  1.39401    1.39430   1.39417
# 74260 2021-07-30 06:40:00   1.39433   1.39452  1.39415    1.39422   1.39449
# 74261 2021-07-30 06:45:00   1.39420   1.39455  1.39400    1.39451   1.39436
# 74262 2021-07-30 06:50:00   1.39454   1.39481  1.39447    1.39470   1.39469
# 74263 2021-07-30 06:55:00   1.39469   1.39503  1.39462    1.39503   1.39486
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 74259   1.39467  1.39417    1.39447   1.39409   1.39459  1.39409    1.39438
# 74260   1.39466  1.39433    1.39440   1.39441   1.39459  1.39424    1.39431
# 74261   1.39472  1.39418    1.39466   1.39428   1.39464  1.39409    1.39458
# 74262   1.39499  1.39462    1.39490   1.39462   1.39490  1.39454    1.39480
# 74263   1.39518  1.39477    1.39518   1.39478   1.39510  1.39470    1.39510

# %%
df['macd'], df['macdsignal'], df['macdhist'] = talib.MACD(df['Mid_Close'])
df['ema200'] = talib.EMA(df['Mid_Close'], timeperiod=200)
df['ema175'] = talib.EMA(df['Mid_Close'], timeperiod=175)
df['ema150'] = talib.EMA(df['Mid_Close'], timeperiod=150)
df['ema125'] = talib.EMA(df['Mid_Close'], timeperiod=125)
df['ema100'] = talib.EMA(df['Mid_Close'], timeperiod=100)
df['ema75'] = talib.EMA(df['Mid_Close'], timeperiod=75)
df['ema20'] = talib.EMA(df['Mid_Close'], timeperiod=20)
df['ema10'] = talib.EMA(df['Mid_Close'], timeperiod=10)
df['ema5'] = talib.EMA(df['Mid_Close'], timeperiod=5)
df['adx'] = talib.ADX(df['Mid_High'], df['Mid_Low'], df['Mid_Close'], timeperiod=14)
df['rsi'] = talib.RSI(df['Mid_Close'], timeperiod=20)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
value_per_pip = 1.0
# max_pips_to_risk = 0.0020
amounts_per_day = [-0.00008, -0.0001, -0.00012]

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee


def run_simulation(risk_reward_ratio, spread_cutoff, use_tl, min_pips_to_risk, max_pips_to_risk, adx_cutoff):
    max_pips_to_risk /= 10000
    min_pips_to_risk /= 10000
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    n_units = 50000
    trade = None

    i = 12

    while i < len(df):
        curr_date = df.loc[df.index[i], 'Date']
        ema200 = df.loc[df.index[i - 1], 'ema200']
        ema175 = df.loc[df.index[i - 1], 'ema175']
        ema150 = df.loc[df.index[i - 1], 'ema150']
        ema125 = df.loc[df.index[i - 1], 'ema125']
        ema100 = df.loc[df.index[i - 1], 'ema100']
        ema75 = df.loc[df.index[i - 1], 'ema75']
        ema10_1, ema5_1 = df.loc[df.index[i - 1], ['ema10', 'ema5']]
        ema10_2, ema5_2 = df.loc[df.index[i - 2], ['ema10', 'ema5']]
        adx = max(df.loc[df.index[i - 6:i], 'adx'])
        rsi = df.loc[df.index[i - 1], 'rsi']
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        enough_volatility = spread <= spread_cutoff
        curr_ml2 = df.loc[df.index[i - 2], 'Mid_Low']
        curr_ml1 = df.loc[df.index[i - 1], 'Mid_Low']
        curr_mh2 = df.loc[df.index[i - 2], 'Mid_High']
        curr_mh1 = df.loc[df.index[i - 1], 'Mid_High']
        curr_bar_length = abs(curr_mh1 - curr_ml1)
        macd2, macdsignal2 = df.loc[df.index[i - 2], ['macd', 'macdsignal']]
        macd1, macdsignal1 = df.loc[df.index[i - 1], ['macd', 'macdsignal']]
        macd_vals = [0, macd2, macdsignal1]
        trending = adx >= adx_cutoff
        curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
          df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                              'Ask_Low', 'Ask_Close']]

        if trade is None:
          if macd2 < macdsignal2 and macd1 > macdsignal1 and ema5_1 > ema10_1 and ema5_2 > ema10_2 and max(macd_vals) == 0 and enough_volatility and trending:
              all_buys = True

              if all_buys:
                open_price = float(curr_ask_open)
                pullback = None
                pullback = min(df.loc[df.index[i - 12:i], 'Mid_Low'])

                if open_price - pullback < min_pips_to_risk:
                  pullback = open_price - min_pips_to_risk

                elif open_price - pullback > max_pips_to_risk:
                  pullback = open_price - max_pips_to_risk

                if pullback is not None:
                    stop_loss = round(pullback, 5)
                    # stop_loss = round(pullback - pullback_cushion, 3)

                    if stop_loss < open_price:
                        curr_pips_to_risk = open_price - stop_loss

                        if curr_pips_to_risk <= max_pips_to_risk:
                            stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 5)
                            # stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 3)

                            trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                              'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                              'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

                            n_buys += 1

                            pips_risked.append(curr_pips_to_risk)

          elif macd2 > macdsignal2 and macd1 < macdsignal1 and ema5_1 < ema10_1 and ema5_2 < ema10_2 and min(macd_vals) == 0 and enough_volatility and trending:
              all_sells = True

              if all_sells:
                open_price = float(curr_bid_open)
                pullback = None
                pullback = max(df.loc[df.index[i - 15:i], 'Mid_High'])

                if pullback - open_price < min_pips_to_risk:
                  pullback = open_price + min_pips_to_risk

                elif pullback - open_price > max_pips_to_risk:
                  pullback = open_price + max_pips_to_risk

                if pullback is not None:
                    stop_loss = round(pullback, 5)
                    # stop_loss = round(pullback + pullback_cushion, 3)

                    if stop_loss > open_price:
                        curr_pips_to_risk = stop_loss - open_price

                        if curr_pips_to_risk <= max_pips_to_risk:
                            stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 5)
                            # stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 3)

                            trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                                    'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                    'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

                            n_sells += 1

                            pips_risked.append(curr_pips_to_risk)

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
          trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
          reward += trade_amount
          day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

          n_wins += 1 if trade_amount > 0 else 0
          n_losses += 1 if trade_amount < 0 else 0
          curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
          curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

          if curr_win_streak > win_streak:
            win_streak = curr_win_streak

          if curr_loss_streak > loss_streak:
            loss_streak = curr_loss_streak

          trade = None

        if use_tl:
          # if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high - trade['pips_risked'] > trade['stop_loss']:
          #     trade['stop_loss'] = curr_bid_high - trade['pips_risked']
          if trade is not None and trade['original_units'] == trade['n_units'] and trade['trade_type'] == 'buy' and curr_bid_high - trade['open_price'] >= trade['pips_risked']:
              trade['stop_loss'] = trade['open_price']
              reward += trade['pips_risked'] * (trade['n_units'] / 2) * value_per_pip
              day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'] / 2)
              trade['n_units'] = trade['n_units'] / 2
              

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
          trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
          reward += trade_amount
          day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

          n_wins += 1 if trade_amount > 0 else 0
          n_losses += 1 if trade_amount < 0 else 0
          curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
          curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

          if curr_win_streak > win_streak:
            win_streak = curr_win_streak

          if curr_loss_streak > loss_streak:
            loss_streak = curr_loss_streak

          trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
          trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
          reward += trade_amount
          day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

          n_wins += 1 if trade_amount > 0 else 0
          n_losses += 1 if trade_amount < 0 else 0
          curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
          curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

          if curr_win_streak > win_streak:
            win_streak = curr_win_streak

          if curr_loss_streak > loss_streak:
            loss_streak = curr_loss_streak

          trade = None

        if use_tl:
          # if trade is not None and trade['trade_type'] == 'sell' and trade['pips_risked'] + curr_ask_low < trade['stop_loss']:
          #   trade['stop_loss'] = trade['pips_risked'] + curr_ask_low
          if trade is not None and trade['original_units'] == trade['n_units'] and trade['trade_type'] == 'sell' and trade['open_price'] - curr_ask_low >= trade['pips_risked']:
              trade['stop_loss'] = trade['open_price']
              reward += trade['pips_risked'] * (trade['n_units'] / 2) * value_per_pip
              day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'] / 2)
              trade['n_units'] = trade['n_units'] / 2

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
          trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
          reward += trade_amount
          day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

          n_wins += 1 if trade_amount > 0 else 0
          n_losses += 1 if trade_amount < 0 else 0
          curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
          curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

          if curr_win_streak > win_streak:
            win_streak = curr_win_streak

          if curr_loss_streak > loss_streak:
            loss_streak = curr_loss_streak

          trade = None

        i += 1

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
risk_reward_ratio_vals = [1, 1.5, 2]
# risk_reward_ratio_vals = [2]
spread_cutoffs = [1.5, 2, 2.5]
# spread_cutoffs = [2]
use_tl_vals = [True, False]
min_pips_to_risk_vals = [5, 10]
max_pips_to_risk_vals = [15, 20]
adx_cutoff_vals = [5, 10, 15, 20]
n_possibilities = len(risk_reward_ratio_vals) * len(spread_cutoffs) * len(use_tl_vals) * len(min_pips_to_risk_vals) * len(max_pips_to_risk_vals) * len(adx_cutoff_vals)
all_combos = []

for risk_reward_ratio in risk_reward_ratio_vals:
  for spread_val in spread_cutoffs:
    for use_tl in use_tl_vals:
      for min_pips in min_pips_to_risk_vals:
        for max_pips in max_pips_to_risk_vals:
          for adx_cutoff in adx_cutoff_vals:
            all_combos.append((risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff))

# percentage_to_try = 0.5
percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)
print('Num runs: '+ str(len(combos_to_try)) + '\n')

best_risk_reward = None
best_spread_cutoff = None
best_use_tl_val = None
best_min_pips_val = None
best_max_pips_val = None
best_adx_val = None
top_n_results = 20
best_rewards = []
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff in combos_to_try:
  reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked = run_simulation(risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff)
  runs_finished += 1

  print(reward)
  print('Num buys: ' + str(n_sells))
  print('Num sells: ' + str(n_buys))
  print('Num trades: ' + str(n_buys + n_sells))
  print('Num wins: ' + str(n_wins))
  print('Num losses: ' + str(n_losses))
  print('Win streak: ' + str(win_streak))
  print('Loss streak: ' + str(loss_streak))
  print('Avg pips risked: ' + str(sum(pips_risked) / len(pips_risked)))
  print('Remaining runs: ' + str(n_runs - runs_finished))

  min_item = min(best_rewards, key=lambda entry: entry['reward']) if len(best_rewards) >= top_n_results else None
  if min_item is None or reward > min_item['reward']:
    if min_item is not None:
      best_rewards.remove(min_item)
    best_rewards.append({'reward': int(reward), 'ratio': risk_reward_ratio, 'spread': spread_val, 'use_tl': use_tl, 'min_pips': min_pips, 'max_pips': max_pips, 'adx_cutoff': adx_cutoff})


  if reward > best_reward:
    best_reward = reward
    best_risk_reward = risk_reward_ratio
    best_spread_cutoff = spread_val
    best_use_tl_val = use_tl
    best_min_pips_val = min_pips
    best_max_pips_val = max_pips
    best_adx_val = adx_cutoff

  print('Best reward so far: ' + str(best_reward))
  print()
# Out:
# Num runs: 288
#
# -3278.4999999997976
# Num buys: 86
# Num sells: 109
# Num trades: 195
# Num wins: 65
# Num losses: 130
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010948205128204853
# Remaining runs: 287
# Best reward so far: -3278.4999999997976
#
# -2563.4999999998095
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 42
# Num losses: 108
# Win streak: 3
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 286
# Best reward so far: -2563.4999999998095
#
# -3968.4999999999586
# Num buys: 91
# Num sells: 120
# Num trades: 211
# Num wins: 70
# Num losses: 141
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011753080568720387
# Remaining runs: 285
# Best reward so far: -2563.4999999998095
#
# -4112.999999999951
# Num buys: 88
# Num sells: 119
# Num trades: 207
# Num wins: 71
# Num losses: 136
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0012601932367149763
# Remaining runs: 284
# Best reward so far: -2563.4999999998095
#
# -3126.2499999998067
# Num buys: 88
# Num sells: 110
# Num trades: 198
# Num wins: 47
# Num losses: 131
# Win streak: 5
# Loss streak: 23
# Avg pips risked: 0.0010914646464646174
# Remaining runs: 283
# Best reward so far: -2563.4999999998095
#
# -4102.500000000002
# Num buys: 91
# Num sells: 118
# Num trades: 209
# Num wins: 55
# Num losses: 154
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011731100478468907
# Remaining runs: 282
# Best reward so far: -2563.4999999998095
#
# -3123.249999999841
# Num buys: 82
# Num sells: 106
# Num trades: 188
# Num wins: 48
# Num losses: 122
# Win streak: 5
# Loss streak: 15
# Avg pips risked: 0.0011888829787233789
# Remaining runs: 281
# Best reward so far: -2563.4999999998095
#
# -3340.999999999816
# Num buys: 82
# Num sells: 107
# Num trades: 189
# Num wins: 66
# Num losses: 123
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011893121693121434
# Remaining runs: 280
# Best reward so far: -2563.4999999998095
#
# -672.4999999997957
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 26
# Num losses: 65
# Win streak: 4
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 279
# Best reward so far: -672.4999999997957
#
# -4194.000000000047
# Num buys: 86
# Num sells: 114
# Num trades: 200
# Num wins: 54
# Num losses: 146
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.0012604000000000037
# Remaining runs: 278
# Best reward so far: -672.4999999997957
#
# -2595.249999999819
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 31
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 277
# Best reward so far: -672.4999999997957
#
# -2872.999999999745
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 48
# Num losses: 106
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 276
# Best reward so far: -672.4999999997957
#
# -4013.999999999943
# Num buys: 92
# Num sells: 122
# Num trades: 214
# Num wins: 71
# Num losses: 143
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011725233644859804
# Remaining runs: 275
# Best reward so far: -672.4999999997957
#
# -580.4999999998278
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 32
# Num losses: 59
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 274
# Best reward so far: -580.4999999998278
#
# -1082.4999999999313
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 35
# Num losses: 59
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 273
# Best reward so far: -580.4999999998278
#
# -2354.99999999974
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 42
# Num losses: 112
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 272
# Best reward so far: -580.4999999998278
#
# -3972.499999999976
# Num buys: 91
# Num sells: 120
# Num trades: 211
# Num wins: 70
# Num losses: 141
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011753080568720387
# Remaining runs: 271
# Best reward so far: -580.4999999998278
#
# -578.4999999998278
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 32
# Num losses: 59
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 270
# Best reward so far: -578.4999999998278
#
# -2871.2499999998317
# Num buys: 82
# Num sells: 106
# Num trades: 188
# Num wins: 41
# Num losses: 122
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011888829787233789
# Remaining runs: 269
# Best reward so far: -578.4999999998278
#
# -2755.9999999997603
# Num buys: 84
# Num sells: 107
# Num trades: 191
# Num wins: 48
# Num losses: 143
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.001186492146596831
# Remaining runs: 268
# Best reward so far: -578.4999999998278
#
# -3005.4999999997617
# Num buys: 88
# Num sells: 109
# Num trades: 197
# Num wins: 54
# Num losses: 143
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0010903045685278898
# Remaining runs: 267
# Best reward so far: -578.4999999998278
#
# -4376.500000000027
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 54
# Num losses: 149
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.001258669950738918
# Remaining runs: 266
# Best reward so far: -578.4999999998278
#
# -3228.499999999804
# Num buys: 84
# Num sells: 107
# Num trades: 191
# Num wins: 54
# Num losses: 137
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.001186492146596831
# Remaining runs: 265
# Best reward so far: -578.4999999998278
#
# -3192.999999999827
# Num buys: 84
# Num sells: 108
# Num trades: 192
# Num wins: 48
# Num losses: 124
# Win streak: 5
# Loss streak: 15
# Avg pips risked: 0.0011871874999999723
# Remaining runs: 264
# Best reward so far: -578.4999999998278
#
# -3520.999999999954
# Num buys: 74
# Num sells: 91
# Num trades: 165
# Num wins: 42
# Num losses: 123
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0012166060606060573
# Remaining runs: 263
# Best reward so far: -578.4999999998278
#
# -2589.4999999997217
# Num buys: 88
# Num sells: 109
# Num trades: 197
# Num wins: 48
# Num losses: 149
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0010903045685278898
# Remaining runs: 262
# Best reward so far: -578.4999999998278
#
# -3227.499999999804
# Num buys: 84
# Num sells: 107
# Num trades: 191
# Num wins: 54
# Num losses: 137
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.001186492146596831
# Remaining runs: 261
# Best reward so far: -578.4999999998278
#
# -3470.9999999999927
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 38
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 260
# Best reward so far: -578.4999999998278
#
# -3942.000000000019
# Num buys: 90
# Num sells: 116
# Num trades: 206
# Num wins: 55
# Num losses: 151
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011759708737864103
# Remaining runs: 259
# Best reward so far: -578.4999999998278
#
# -3099.249999999982
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 34
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 258
# Best reward so far: -578.4999999998278
#
# -4110.999999999951
# Num buys: 88
# Num sells: 119
# Num trades: 207
# Num wins: 71
# Num losses: 136
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0012601932367149763
# Remaining runs: 257
# Best reward so far: -578.4999999998278
#
# -616.4999999997598
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 25
# Num losses: 66
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.001176813186813132
# Remaining runs: 256
# Best reward so far: -578.4999999998278
#
# -3344.9999999997826
# Num buys: 82
# Num sells: 107
# Num trades: 189
# Num wins: 66
# Num losses: 123
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011893121693121434
# Remaining runs: 255
# Best reward so far: -578.4999999998278
#
# -3859.499999999995
# Num buys: 92
# Num sells: 121
# Num trades: 213
# Num wins: 50
# Num losses: 142
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.00117206572769953
# Remaining runs: 254
# Best reward so far: -578.4999999998278
#
# -3222.0000000000027
# Num buys: 90
# Num sells: 116
# Num trades: 206
# Num wins: 50
# Num losses: 156
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011759708737864103
# Remaining runs: 253
# Best reward so far: -578.4999999998278
#
# -3271.999999999783
# Num buys: 88
# Num sells: 111
# Num trades: 199
# Num wins: 67
# Num losses: 132
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010923618090451967
# Remaining runs: 252
# Best reward so far: -578.4999999998278
#
# -2936.499999999818
# Num buys: 84
# Num sells: 108
# Num trades: 192
# Num wins: 41
# Num losses: 124
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011871874999999723
# Remaining runs: 251
# Best reward so far: -578.4999999998278
#
# -2517.499999999787
# Num buys: 82
# Num sells: 105
# Num trades: 187
# Num wins: 48
# Num losses: 139
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0011881818181817927
# Remaining runs: 250
# Best reward so far: -578.4999999998278
#
# -3857.5000000000196
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 50
# Num losses: 133
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.001261871921182269
# Remaining runs: 249
# Best reward so far: -578.4999999998278
#
# -2800.999999999787
# Num buys: 86
# Num sells: 107
# Num trades: 193
# Num wins: 54
# Num losses: 139
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0010927461139896102
# Remaining runs: 248
# Best reward so far: -578.4999999998278
#
# -4194.000000000047
# Num buys: 86
# Num sells: 114
# Num trades: 200
# Num wins: 54
# Num losses: 146
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.0012604000000000037
# Remaining runs: 247
# Best reward so far: -578.4999999998278
#
# -3529.499999999914
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 52
# Num losses: 116
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 246
# Best reward so far: -578.4999999998278
#
# -3953.750000000006
# Num buys: 88
# Num sells: 118
# Num trades: 206
# Num wins: 50
# Num losses: 135
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.0012601456310679623
# Remaining runs: 245
# Best reward so far: -578.4999999998278
#
# -3187.999999999827
# Num buys: 84
# Num sells: 108
# Num trades: 192
# Num wins: 48
# Num losses: 124
# Win streak: 5
# Loss streak: 15
# Avg pips risked: 0.0011871874999999723
# Remaining runs: 244
# Best reward so far: -578.4999999998278
#
# -3851.5000000000196
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 50
# Num losses: 133
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.001261871921182269
# Remaining runs: 243
# Best reward so far: -578.4999999998278
#
# -1003.9999999998053
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 34
# Num losses: 57
# Win streak: 5
# Loss streak: 7
# Avg pips risked: 0.001176813186813132
# Remaining runs: 242
# Best reward so far: -578.4999999998278
#
# -3783.5000000000055
# Num buys: 72
# Num sells: 89
# Num trades: 161
# Num wins: 41
# Num losses: 120
# Win streak: 2
# Loss streak: 14
# Avg pips risked: 0.0012898136645962716
# Remaining runs: 241
# Best reward so far: -578.4999999998278
#
# -3421.500000000001
# Num buys: 91
# Num sells: 119
# Num trades: 210
# Num wins: 44
# Num losses: 140
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.0011748571428571442
# Remaining runs: 240
# Best reward so far: -578.4999999998278
#
# -933.9999999999388
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 38
# Num losses: 55
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 239
# Best reward so far: -578.4999999998278
#
# -4044.499999999968
# Num buys: 87
# Num sells: 117
# Num trades: 204
# Num wins: 70
# Num losses: 134
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0012619117647058847
# Remaining runs: 238
# Best reward so far: -578.4999999998278
#
# -2584.499999999776
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 30
# Num losses: 106
# Win streak: 4
# Loss streak: 19
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 237
# Best reward so far: -578.4999999998278
#
# -2726.499999999784
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 36
# Num losses: 106
# Win streak: 4
# Loss streak: 19
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 236
# Best reward so far: -578.4999999998278
#
# -2761.249999999835
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 37
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 235
# Best reward so far: -578.4999999998278
#
# -3120.249999999841
# Num buys: 82
# Num sells: 106
# Num trades: 188
# Num wins: 48
# Num losses: 122
# Win streak: 5
# Loss streak: 15
# Avg pips risked: 0.0011888829787233789
# Remaining runs: 234
# Best reward so far: -578.4999999998278
#
# -3966.4999999999586
# Num buys: 91
# Num sells: 120
# Num trades: 211
# Num wins: 70
# Num losses: 141
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011753080568720387
# Remaining runs: 233
# Best reward so far: -578.4999999998278
#
# -3937.000000000019
# Num buys: 90
# Num sells: 116
# Num trades: 206
# Num wins: 55
# Num losses: 151
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011759708737864103
# Remaining runs: 232
# Best reward so far: -578.4999999998278
#
# -2907.4999999998095
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 50
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 231
# Best reward so far: -578.4999999998278
#
# -2028.9999999997103
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 37
# Num losses: 117
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 230
# Best reward so far: -578.4999999998278
#
# -2869.249999999809
# Num buys: 86
# Num sells: 108
# Num trades: 194
# Num wins: 40
# Num losses: 129
# Win streak: 5
# Loss streak: 26
# Avg pips risked: 0.0010939175257731687
# Remaining runs: 229
# Best reward so far: -578.4999999998278
#
# -2870.249999999809
# Num buys: 86
# Num sells: 108
# Num trades: 194
# Num wins: 40
# Num losses: 129
# Win streak: 5
# Loss streak: 26
# Avg pips risked: 0.0010939175257731687
# Remaining runs: 228
# Best reward so far: -578.4999999998278
#
# -2586.999999999776
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 30
# Num losses: 106
# Win streak: 4
# Loss streak: 19
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 227
# Best reward so far: -578.4999999998278
#
# -3567.499999999959
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 53
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 226
# Best reward so far: -578.4999999998278
#
# -754.749999999978
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 22
# Num losses: 55
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 225
# Best reward so far: -578.4999999998278
#
# -4040.9999999999845
# Num buys: 87
# Num sells: 117
# Num trades: 204
# Num wins: 70
# Num losses: 134
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0012619117647058847
# Remaining runs: 224
# Best reward so far: -578.4999999998278
#
# -936.4999999998414
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 37
# Num losses: 54
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 223
# Best reward so far: -578.4999999998278
#
# -1097.4999999999725
# Num buys: 43
# Num sells: 48
# Num trades: 91
# Num wins: 24
# Num losses: 67
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.0013059340659340617
# Remaining runs: 222
# Best reward so far: -578.4999999998278
#
# -1079.999999999909
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 35
# Num losses: 59
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 221
# Best reward so far: -578.4999999998278
#
# -2875.999999999745
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 48
# Num losses: 106
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 220
# Best reward so far: -578.4999999998278
#
# -3096.749999999982
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 34
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 219
# Best reward so far: -578.4999999998278
#
# -2904.9999999997717
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 50
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 218
# Best reward so far: -578.4999999998278
#
# -3566.999999999959
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 53
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 217
# Best reward so far: -578.4999999998278
#
# -577.4999999998278
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 32
# Num losses: 59
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 216
# Best reward so far: -577.4999999998278
#
# -3268.499999999783
# Num buys: 88
# Num sells: 111
# Num trades: 199
# Num wins: 67
# Num losses: 132
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010923618090451967
# Remaining runs: 215
# Best reward so far: -577.4999999998278
#
# -3215.0000000000027
# Num buys: 90
# Num sells: 116
# Num trades: 206
# Num wins: 50
# Num losses: 156
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011759708737864103
# Remaining runs: 214
# Best reward so far: -577.4999999998278
#
# -3382.4999999999854
# Num buys: 91
# Num sells: 118
# Num trades: 209
# Num wins: 50
# Num losses: 159
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011731100478468907
# Remaining runs: 213
# Best reward so far: -577.4999999998278
#
# -1078.999999999909
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 35
# Num losses: 59
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 212
# Best reward so far: -577.4999999998278
#
# -808.7499999998502
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 21
# Num losses: 54
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 211
# Best reward so far: -577.4999999998278
#
# -3336.9999999997826
# Num buys: 82
# Num sells: 107
# Num trades: 189
# Num wins: 66
# Num losses: 123
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011893121693121434
# Remaining runs: 210
# Best reward so far: -577.4999999998278
#
# -4012.999999999943
# Num buys: 92
# Num sells: 122
# Num trades: 214
# Num wins: 71
# Num losses: 143
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011725233644859804
# Remaining runs: 209
# Best reward so far: -577.4999999998278
#
# -3544.2499999999955
# Num buys: 88
# Num sells: 118
# Num trades: 206
# Num wins: 44
# Num losses: 135
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.0012601456310679623
# Remaining runs: 208
# Best reward so far: -577.4999999998278
#
# -2992.9999999998295
# Num buys: 82
# Num sells: 105
# Num trades: 187
# Num wins: 54
# Num losses: 133
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0011881818181817927
# Remaining runs: 207
# Best reward so far: -577.4999999998278
#
# -1003.4999999997709
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 34
# Num losses: 57
# Win streak: 5
# Loss streak: 7
# Avg pips risked: 0.001176813186813132
# Remaining runs: 206
# Best reward so far: -577.4999999998278
#
# -4108.49999999997
# Num buys: 88
# Num sells: 119
# Num trades: 207
# Num wins: 71
# Num losses: 136
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0012601932367149763
# Remaining runs: 205
# Best reward so far: -577.4999999998278
#
# -2226.499999999764
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 37
# Num losses: 113
# Win streak: 2
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 204
# Best reward so far: -577.4999999998278
#
# -2869.249999999809
# Num buys: 86
# Num sells: 108
# Num trades: 194
# Num wins: 40
# Num losses: 129
# Win streak: 5
# Loss streak: 26
# Avg pips risked: 0.0010939175257731687
# Remaining runs: 203
# Best reward so far: -577.4999999998278
#
# -2582.499999999776
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 30
# Num losses: 106
# Win streak: 4
# Loss streak: 19
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 202
# Best reward so far: -577.4999999998278
#
# -1353.9999999999811
# Num buys: 43
# Num sells: 48
# Num trades: 91
# Num wins: 28
# Num losses: 63
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.0013059340659340617
# Remaining runs: 201
# Best reward so far: -577.4999999998278
#
# -3521.999999999954
# Num buys: 74
# Num sells: 91
# Num trades: 165
# Num wins: 42
# Num losses: 123
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0012166060606060573
# Remaining runs: 200
# Best reward so far: -577.4999999998278
#
# -2732.999999999784
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 36
# Num losses: 106
# Win streak: 4
# Loss streak: 19
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 199
# Best reward so far: -577.4999999998278
#
# -3522.999999999934
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 52
# Num losses: 116
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 198
# Best reward so far: -577.4999999998278
#
# -2691.4999999999513
# Num buys: 74
# Num sells: 91
# Num trades: 165
# Num wins: 39
# Num losses: 126
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0012166060606060573
# Remaining runs: 197
# Best reward so far: -577.4999999998278
#
# -619.4999999997598
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 25
# Num losses: 66
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.001176813186813132
# Remaining runs: 196
# Best reward so far: -577.4999999998278
#
# -3423.249999999954
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 38
# Num losses: 116
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 195
# Best reward so far: -577.4999999998278
#
# -3529.499999999934
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 52
# Num losses: 116
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 194
# Best reward so far: -577.4999999998278
#
# -3362.9999999997976
# Num buys: 84
# Num sells: 109
# Num trades: 193
# Num wins: 68
# Num losses: 125
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011876165803108528
# Remaining runs: 193
# Best reward so far: -577.4999999998278
#
# -2911.4999999998095
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 50
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 192
# Best reward so far: -577.4999999998278
#
# -2914.999999999799
# Num buys: 88
# Num sells: 110
# Num trades: 198
# Num wins: 40
# Num losses: 131
# Win streak: 5
# Loss streak: 26
# Avg pips risked: 0.0010914646464646174
# Remaining runs: 191
# Best reward so far: -577.4999999998278
#
# -1157.9999999999536
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 23
# Num losses: 59
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 190
# Best reward so far: -577.4999999998278
#
# -3101.249999999982
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 34
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 189
# Best reward so far: -577.4999999998278
#
# -3356.4999999997976
# Num buys: 84
# Num sells: 109
# Num trades: 193
# Num wins: 68
# Num losses: 125
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011876165803108528
# Remaining runs: 188
# Best reward so far: -577.4999999998278
#
# -3335.999999999816
# Num buys: 82
# Num sells: 107
# Num trades: 189
# Num wins: 66
# Num losses: 123
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011893121693121434
# Remaining runs: 187
# Best reward so far: -577.4999999998278
#
# -3945.000000000019
# Num buys: 90
# Num sells: 116
# Num trades: 206
# Num wins: 55
# Num losses: 151
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011759708737864103
# Remaining runs: 186
# Best reward so far: -577.4999999998278
#
# -3279.9999999997976
# Num buys: 86
# Num sells: 109
# Num trades: 195
# Num wins: 65
# Num losses: 130
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010948205128204853
# Remaining runs: 185
# Best reward so far: -577.4999999998278
#
# -1082.9999999999313
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 35
# Num losses: 59
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 184
# Best reward so far: -577.4999999998278
#
# -3188.499999999827
# Num buys: 84
# Num sells: 108
# Num trades: 192
# Num wins: 48
# Num losses: 124
# Win streak: 5
# Loss streak: 15
# Avg pips risked: 0.0011871874999999723
# Remaining runs: 183
# Best reward so far: -577.4999999998278
#
# -614.4999999997598
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 25
# Num losses: 66
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.001176813186813132
# Remaining runs: 182
# Best reward so far: -577.4999999998278
#
# -2794.999999999787
# Num buys: 86
# Num sells: 107
# Num trades: 193
# Num wins: 54
# Num losses: 139
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0010927461139896102
# Remaining runs: 181
# Best reward so far: -577.4999999998278
#
# -932.9999999999388
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 38
# Num losses: 55
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 180
# Best reward so far: -577.4999999998278
#
# -1003.9999999998053
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 34
# Num losses: 57
# Win streak: 5
# Loss streak: 7
# Avg pips risked: 0.001176813186813132
# Remaining runs: 179
# Best reward so far: -577.4999999998278
#
# -2877.999999999774
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 48
# Num losses: 106
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 178
# Best reward so far: -577.4999999998278
#
# -2352.99999999974
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 42
# Num losses: 112
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 177
# Best reward so far: -577.4999999998278
#
# -3792.250000000006
# Num buys: 91
# Num sells: 119
# Num trades: 210
# Num wins: 50
# Num losses: 140
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.0011748571428571442
# Remaining runs: 176
# Best reward so far: -577.4999999998278
#
# -2034.9999999997103
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 37
# Num losses: 117
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 175
# Best reward so far: -577.4999999998278
#
# -938.4999999998073
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 37
# Num losses: 54
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 174
# Best reward so far: -577.4999999998278
#
# -2959.9999999999836
# Num buys: 72
# Num sells: 89
# Num trades: 161
# Num wins: 38
# Num losses: 123
# Win streak: 2
# Loss streak: 14
# Avg pips risked: 0.0012898136645962716
# Remaining runs: 173
# Best reward so far: -577.4999999998278
#
# -2911.9999999997717
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 50
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 172
# Best reward so far: -577.4999999998278
#
# -957.4999999999845
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 26
# Num losses: 55
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 171
# Best reward so far: -577.4999999998278
#
# -940.9999999998414
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 37
# Num losses: 54
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 170
# Best reward so far: -577.4999999998278
#
# -2865.2499999998317
# Num buys: 82
# Num sells: 106
# Num trades: 188
# Num wins: 41
# Num losses: 122
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011888829787233789
# Remaining runs: 169
# Best reward so far: -577.4999999998278
#
# -935.4999999999616
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 38
# Num losses: 55
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 168
# Best reward so far: -577.4999999998278
#
# -3498.24999999999
# Num buys: 92
# Num sells: 121
# Num trades: 213
# Num wins: 44
# Num losses: 142
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.00117206572769953
# Remaining runs: 167
# Best reward so far: -577.4999999998278
#
# -3273.4999999997676
# Num buys: 86
# Num sells: 109
# Num trades: 195
# Num wins: 65
# Num losses: 130
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010948205128204853
# Remaining runs: 166
# Best reward so far: -577.4999999998278
#
# -3569.999999999959
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 53
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 165
# Best reward so far: -577.4999999998278
#
# -3854.499999999995
# Num buys: 92
# Num sells: 121
# Num trades: 213
# Num wins: 50
# Num losses: 142
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.00117206572769953
# Remaining runs: 164
# Best reward so far: -577.4999999998278
#
# -3231.499999999804
# Num buys: 84
# Num sells: 107
# Num trades: 191
# Num wins: 54
# Num losses: 137
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.001186492146596831
# Remaining runs: 163
# Best reward so far: -577.4999999998278
#
# -2693.4999999999513
# Num buys: 74
# Num sells: 91
# Num trades: 165
# Num wins: 39
# Num losses: 126
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0012166060606060573
# Remaining runs: 162
# Best reward so far: -577.4999999998278
#
# -1373.9999999999482
# Num buys: 43
# Num sells: 49
# Num trades: 92
# Num wins: 27
# Num losses: 65
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.001242717391304341
# Remaining runs: 161
# Best reward so far: -577.4999999998278
#
# -2749.9999999997603
# Num buys: 84
# Num sells: 107
# Num trades: 191
# Num wins: 48
# Num losses: 143
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.001186492146596831
# Remaining runs: 160
# Best reward so far: -577.4999999998278
#
# -807.7499999998502
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 21
# Num losses: 54
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 159
# Best reward so far: -577.4999999998278
#
# -1156.9999999999536
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 23
# Num losses: 59
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 158
# Best reward so far: -577.4999999998278
#
# -4019.499999999963
# Num buys: 92
# Num sells: 122
# Num trades: 214
# Num wins: 71
# Num losses: 143
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011725233644859804
# Remaining runs: 157
# Best reward so far: -577.4999999998278
#
# -2755.9999999997603
# Num buys: 84
# Num sells: 107
# Num trades: 191
# Num wins: 48
# Num losses: 143
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.001186492146596831
# Remaining runs: 156
# Best reward so far: -577.4999999998278
#
# -4014.499999999963
# Num buys: 92
# Num sells: 122
# Num trades: 214
# Num wins: 71
# Num losses: 143
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011725233644859804
# Remaining runs: 155
# Best reward so far: -577.4999999998278
#
# -622.9999999997884
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 30
# Num losses: 61
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.001176813186813132
# Remaining runs: 154
# Best reward so far: -577.4999999998278
#
# -3372.4999999999854
# Num buys: 91
# Num sells: 118
# Num trades: 209
# Num wins: 50
# Num losses: 159
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011731100478468907
# Remaining runs: 153
# Best reward so far: -577.4999999998278
#
# -2876.499999999774
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 48
# Num losses: 106
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 152
# Best reward so far: -577.4999999998278
#
# -623.9999999997884
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 30
# Num losses: 61
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.001176813186813132
# Remaining runs: 151
# Best reward so far: -577.4999999998278
#
# -3124.2499999998067
# Num buys: 88
# Num sells: 110
# Num trades: 198
# Num wins: 47
# Num losses: 131
# Win streak: 5
# Loss streak: 23
# Avg pips risked: 0.0010914646464646174
# Remaining runs: 150
# Best reward so far: -577.4999999998278
#
# -1093.4999999999725
# Num buys: 43
# Num sells: 48
# Num trades: 91
# Num wins: 24
# Num losses: 67
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.0013059340659340617
# Remaining runs: 149
# Best reward so far: -577.4999999998278
#
# -1155.4999999999536
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 23
# Num losses: 59
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 148
# Best reward so far: -577.4999999998278
#
# -2223.499999999764
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 37
# Num losses: 113
# Win streak: 2
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 147
# Best reward so far: -577.4999999998278
#
# -1079.999999999909
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 35
# Num losses: 59
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 146
# Best reward so far: -577.4999999998278
#
# -3791.250000000006
# Num buys: 91
# Num sells: 119
# Num trades: 210
# Num wins: 50
# Num losses: 140
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.0011748571428571442
# Remaining runs: 145
# Best reward so far: -577.4999999998278
#
# -1354.9999999999811
# Num buys: 43
# Num sells: 48
# Num trades: 91
# Num wins: 28
# Num losses: 63
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.0013059340659340617
# Remaining runs: 144
# Best reward so far: -577.4999999998278
#
# -3077.4999999998176
# Num buys: 86
# Num sells: 108
# Num trades: 194
# Num wins: 47
# Num losses: 129
# Win streak: 5
# Loss streak: 23
# Avg pips risked: 0.0010939175257731687
# Remaining runs: 143
# Best reward so far: -577.4999999998278
#
# -2874.499999999774
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 48
# Num losses: 106
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 142
# Best reward so far: -577.4999999998278
#
# -3859.499999999995
# Num buys: 92
# Num sells: 121
# Num trades: 213
# Num wins: 50
# Num losses: 142
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.00117206572769953
# Remaining runs: 141
# Best reward so far: -577.4999999998278
#
# -3351.499999999759
# Num buys: 84
# Num sells: 109
# Num trades: 193
# Num wins: 68
# Num losses: 125
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011876165803108528
# Remaining runs: 140
# Best reward so far: -577.4999999998278
#
# -3274.999999999783
# Num buys: 88
# Num sells: 111
# Num trades: 199
# Num wins: 67
# Num losses: 132
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010923618090451967
# Remaining runs: 139
# Best reward so far: -577.4999999998278
#
# -3270.9999999997485
# Num buys: 88
# Num sells: 111
# Num trades: 199
# Num wins: 67
# Num losses: 132
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010923618090451967
# Remaining runs: 138
# Best reward so far: -577.4999999998278
#
# -2997.4999999997617
# Num buys: 88
# Num sells: 109
# Num trades: 197
# Num wins: 54
# Num losses: 143
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0010903045685278898
# Remaining runs: 137
# Best reward so far: -577.4999999998278
#
# -3279.4999999997976
# Num buys: 86
# Num sells: 109
# Num trades: 195
# Num wins: 65
# Num losses: 130
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010948205128204853
# Remaining runs: 136
# Best reward so far: -577.4999999998278
#
# -2911.999999999799
# Num buys: 88
# Num sells: 110
# Num trades: 198
# Num wins: 40
# Num losses: 131
# Win streak: 5
# Loss streak: 26
# Avg pips risked: 0.0010914646464646174
# Remaining runs: 135
# Best reward so far: -577.4999999998278
#
# -2904.9999999997717
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 50
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 134
# Best reward so far: -577.4999999998278
#
# -3061.4999999999523
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 34
# Num losses: 116
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 133
# Best reward so far: -577.4999999998278
#
# -807.7499999998502
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 21
# Num losses: 54
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 132
# Best reward so far: -577.4999999998278
#
# -3449.000000000009
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 44
# Num losses: 133
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.001261871921182269
# Remaining runs: 131
# Best reward so far: -577.4999999998278
#
# -992.9999999999454
# Num buys: 43
# Num sells: 49
# Num trades: 92
# Num wins: 24
# Num losses: 68
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.001242717391304341
# Remaining runs: 130
# Best reward so far: -577.4999999998278
#
# -939.4999999998073
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 37
# Num losses: 54
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 129
# Best reward so far: -577.4999999998278
#
# -3547.2499999999955
# Num buys: 88
# Num sells: 118
# Num trades: 206
# Num wins: 44
# Num losses: 135
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.0012601456310679623
# Remaining runs: 128
# Best reward so far: -577.4999999998278
#
# -2588.749999999819
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 31
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 127
# Best reward so far: -577.4999999998278
#
# -3568.9999999999336
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 53
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 126
# Best reward so far: -577.4999999998278
#
# -2861.7499999998317
# Num buys: 82
# Num sells: 106
# Num trades: 188
# Num wins: 41
# Num losses: 122
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011888829787233789
# Remaining runs: 125
# Best reward so far: -577.4999999998278
#
# -854.7499999998608
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 27
# Num losses: 54
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 124
# Best reward so far: -577.4999999998278
#
# -859.2499999998608
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 27
# Num losses: 54
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 123
# Best reward so far: -577.4999999998278
#
# -3276.4999999997676
# Num buys: 86
# Num sells: 109
# Num trades: 195
# Num wins: 65
# Num losses: 130
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010948205128204853
# Remaining runs: 122
# Best reward so far: -577.4999999998278
#
# -751.749999999978
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 22
# Num losses: 55
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 121
# Best reward so far: -577.4999999998278
#
# -3524.499999999914
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 52
# Num losses: 116
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 120
# Best reward so far: -577.4999999998278
#
# -986.9999999999454
# Num buys: 43
# Num sells: 49
# Num trades: 92
# Num wins: 24
# Num losses: 68
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.001242717391304341
# Remaining runs: 119
# Best reward so far: -577.4999999998278
#
# -3558.2499999999955
# Num buys: 88
# Num sells: 118
# Num trades: 206
# Num wins: 44
# Num losses: 135
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.0012601456310679623
# Remaining runs: 118
# Best reward so far: -577.4999999998278
#
# -975.249999999823
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 24
# Num losses: 57
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001176813186813132
# Remaining runs: 117
# Best reward so far: -577.4999999998278
#
# -3854.0000000000196
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 50
# Num losses: 133
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.001261871921182269
# Remaining runs: 116
# Best reward so far: -577.4999999998278
#
# -3419.749999999954
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 38
# Num losses: 116
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 115
# Best reward so far: -577.4999999998278
#
# -928.9999999999388
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 38
# Num losses: 55
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 114
# Best reward so far: -577.4999999998278
#
# -2569.4999999998095
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 42
# Num losses: 108
# Win streak: 3
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 113
# Best reward so far: -577.4999999998278
#
# -2906.9999999998095
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 50
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 112
# Best reward so far: -577.4999999998278
#
# -3498.24999999999
# Num buys: 92
# Num sells: 121
# Num trades: 213
# Num wins: 44
# Num losses: 142
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.00117206572769953
# Remaining runs: 111
# Best reward so far: -577.4999999998278
#
# -3121.249999999841
# Num buys: 82
# Num sells: 106
# Num trades: 188
# Num wins: 48
# Num losses: 122
# Win streak: 5
# Loss streak: 15
# Avg pips risked: 0.0011888829787233789
# Remaining runs: 110
# Best reward so far: -577.4999999998278
#
# -930.9999999999616
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 38
# Num losses: 55
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 109
# Best reward so far: -577.4999999998278
#
# -2936.999999999818
# Num buys: 84
# Num sells: 108
# Num trades: 192
# Num wins: 41
# Num losses: 124
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011871874999999723
# Remaining runs: 108
# Best reward so far: -577.4999999998278
#
# -3079.4999999998176
# Num buys: 86
# Num sells: 108
# Num trades: 194
# Num wins: 47
# Num losses: 129
# Win streak: 5
# Loss streak: 23
# Avg pips risked: 0.0010939175257731687
# Remaining runs: 107
# Best reward so far: -577.4999999998278
#
# -3562.9999999999336
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 53
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 106
# Best reward so far: -577.4999999998278
#
# -3567.9999999999336
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 53
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 105
# Best reward so far: -577.4999999998278
#
# -975.749999999823
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 24
# Num losses: 57
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001176813186813132
# Remaining runs: 104
# Best reward so far: -577.4999999998278
#
# -1083.4999999999313
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 35
# Num losses: 59
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 103
# Best reward so far: -577.4999999998278
#
# -3275.4999999997676
# Num buys: 86
# Num sells: 109
# Num trades: 195
# Num wins: 65
# Num losses: 130
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010948205128204853
# Remaining runs: 102
# Best reward so far: -577.4999999998278
#
# -4116.999999999951
# Num buys: 88
# Num sells: 119
# Num trades: 207
# Num wins: 71
# Num losses: 136
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0012601932367149763
# Remaining runs: 101
# Best reward so far: -577.4999999998278
#
# -3607.0000000000064
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 49
# Num losses: 154
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.001258669950738918
# Remaining runs: 100
# Best reward so far: -577.4999999998278
#
# -4377.500000000027
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 54
# Num losses: 149
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.001258669950738918
# Remaining runs: 99
# Best reward so far: -577.4999999998278
#
# -1354.9999999999811
# Num buys: 43
# Num sells: 48
# Num trades: 91
# Num wins: 28
# Num losses: 63
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.0013059340659340617
# Remaining runs: 98
# Best reward so far: -577.4999999998278
#
# -3971.999999999976
# Num buys: 91
# Num sells: 120
# Num trades: 211
# Num wins: 70
# Num losses: 141
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011753080568720387
# Remaining runs: 97
# Best reward so far: -577.4999999998278
#
# -4204.000000000047
# Num buys: 86
# Num sells: 114
# Num trades: 200
# Num wins: 54
# Num losses: 146
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.0012604000000000037
# Remaining runs: 96
# Best reward so far: -577.4999999998278
#
# -4094.500000000002
# Num buys: 91
# Num sells: 118
# Num trades: 209
# Num wins: 55
# Num losses: 154
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011731100478468907
# Remaining runs: 95
# Best reward so far: -577.4999999998278
#
# -4044.9999999999845
# Num buys: 87
# Num sells: 117
# Num trades: 204
# Num wins: 70
# Num losses: 134
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0012619117647058847
# Remaining runs: 94
# Best reward so far: -577.4999999998278
#
# -3427.000000000001
# Num buys: 91
# Num sells: 119
# Num trades: 210
# Num wins: 44
# Num losses: 140
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.0011748571428571442
# Remaining runs: 93
# Best reward so far: -577.4999999998278
#
# -620.9999999997884
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 30
# Num losses: 61
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.001176813186813132
# Remaining runs: 92
# Best reward so far: -577.4999999998278
#
# -3340.499999999816
# Num buys: 82
# Num sells: 107
# Num trades: 189
# Num wins: 66
# Num losses: 123
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011893121693121434
# Remaining runs: 91
# Best reward so far: -577.4999999998278
#
# -2951.9999999999836
# Num buys: 72
# Num sells: 89
# Num trades: 161
# Num wins: 38
# Num losses: 123
# Win streak: 2
# Loss streak: 14
# Avg pips risked: 0.0012898136645962716
# Remaining runs: 90
# Best reward so far: -577.4999999998278
#
# -1373.9999999999482
# Num buys: 43
# Num sells: 49
# Num trades: 92
# Num wins: 27
# Num losses: 65
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.001242717391304341
# Remaining runs: 89
# Best reward so far: -577.4999999998278
#
# -2954.9999999999836
# Num buys: 72
# Num sells: 89
# Num trades: 161
# Num wins: 38
# Num losses: 123
# Win streak: 2
# Loss streak: 14
# Avg pips risked: 0.0012898136645962716
# Remaining runs: 88
# Best reward so far: -577.4999999998278
#
# -945.4999999999502
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 20
# Num losses: 59
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 87
# Best reward so far: -577.4999999998278
#
# -3058.4999999999523
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 34
# Num losses: 116
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 86
# Best reward so far: -577.4999999998278
#
# -915.4999999998164
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 19
# Num losses: 57
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001176813186813132
# Remaining runs: 85
# Best reward so far: -577.4999999998278
#
# -676.4999999997957
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 26
# Num losses: 65
# Win streak: 4
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 84
# Best reward so far: -577.4999999998278
#
# -859.2499999998608
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 27
# Num losses: 54
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012473626373625862
# Remaining runs: 83
# Best reward so far: -577.4999999998278
#
# -2589.4999999997217
# Num buys: 88
# Num sells: 109
# Num trades: 197
# Num wins: 48
# Num losses: 149
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0010903045685278898
# Remaining runs: 82
# Best reward so far: -577.4999999998278
#
# -3472.9999999999927
# Num buys: 73
# Num sells: 90
# Num trades: 163
# Num wins: 38
# Num losses: 110
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012909202453987706
# Remaining runs: 81
# Best reward so far: -577.4999999998278
#
# -3781.5000000000055
# Num buys: 72
# Num sells: 89
# Num trades: 161
# Num wins: 41
# Num losses: 120
# Win streak: 2
# Loss streak: 14
# Avg pips risked: 0.0012898136645962716
# Remaining runs: 80
# Best reward so far: -577.4999999998278
#
# -2931.499999999818
# Num buys: 84
# Num sells: 108
# Num trades: 192
# Num wins: 41
# Num losses: 124
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011871874999999723
# Remaining runs: 79
# Best reward so far: -577.4999999998278
#
# -2992.9999999998295
# Num buys: 82
# Num sells: 105
# Num trades: 187
# Num wins: 54
# Num losses: 133
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0011881818181817927
# Remaining runs: 78
# Best reward so far: -577.4999999998278
#
# -3521.499999999934
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 52
# Num losses: 116
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 77
# Best reward so far: -577.4999999998278
#
# -2516.499999999787
# Num buys: 82
# Num sells: 105
# Num trades: 187
# Num wins: 48
# Num losses: 139
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0011881818181817927
# Remaining runs: 76
# Best reward so far: -577.4999999998278
#
# -3520.999999999954
# Num buys: 74
# Num sells: 91
# Num trades: 165
# Num wins: 42
# Num losses: 123
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0012166060606060573
# Remaining runs: 75
# Best reward so far: -577.4999999998278
#
# -2378.9999999997453
# Num buys: 86
# Num sells: 107
# Num trades: 193
# Num wins: 48
# Num losses: 145
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0010927461139896102
# Remaining runs: 74
# Best reward so far: -577.4999999998278
#
# -2517.499999999787
# Num buys: 82
# Num sells: 105
# Num trades: 187
# Num wins: 48
# Num losses: 139
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0011881818181817927
# Remaining runs: 73
# Best reward so far: -577.4999999998278
#
# -3356.499999999759
# Num buys: 84
# Num sells: 109
# Num trades: 193
# Num wins: 68
# Num losses: 125
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011876165803108528
# Remaining runs: 72
# Best reward so far: -577.4999999998278
#
# -2024.9999999997103
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 37
# Num losses: 117
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 71
# Best reward so far: -577.4999999998278
#
# -4014.999999999943
# Num buys: 92
# Num sells: 122
# Num trades: 214
# Num wins: 71
# Num losses: 143
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011725233644859804
# Remaining runs: 70
# Best reward so far: -577.4999999998278
#
# -3459.000000000009
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 44
# Num losses: 133
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.001261871921182269
# Remaining runs: 69
# Best reward so far: -577.4999999998278
#
# -4369.500000000027
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 54
# Num losses: 149
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.001258669950738918
# Remaining runs: 68
# Best reward so far: -577.4999999998278
#
# -3426.5000000000264
# Num buys: 86
# Num sells: 114
# Num trades: 200
# Num wins: 49
# Num losses: 151
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.0012604000000000037
# Remaining runs: 67
# Best reward so far: -577.4999999998278
#
# -3218.0000000000027
# Num buys: 90
# Num sells: 116
# Num trades: 206
# Num wins: 50
# Num losses: 156
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011759708737864103
# Remaining runs: 66
# Best reward so far: -577.4999999998278
#
# -3336.9999999997826
# Num buys: 82
# Num sells: 107
# Num trades: 189
# Num wins: 66
# Num losses: 123
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0011893121693121434
# Remaining runs: 65
# Best reward so far: -577.4999999998278
#
# -946.4999999999502
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 20
# Num losses: 59
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 64
# Best reward so far: -577.4999999998278
#
# -913.4999999998164
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 19
# Num losses: 57
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001176813186813132
# Remaining runs: 63
# Best reward so far: -577.4999999998278
#
# -932.4999999999616
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 38
# Num losses: 55
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 62
# Best reward so far: -577.4999999998278
#
# -3064.4999999999523
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 34
# Num losses: 116
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 61
# Best reward so far: -577.4999999998278
#
# -2992.9999999998295
# Num buys: 82
# Num sells: 105
# Num trades: 187
# Num wins: 54
# Num losses: 133
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0011881818181817927
# Remaining runs: 60
# Best reward so far: -577.4999999998278
#
# -2588.749999999819
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 31
# Num losses: 100
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 59
# Best reward so far: -577.4999999998278
#
# -1089.4999999999725
# Num buys: 43
# Num sells: 48
# Num trades: 91
# Num wins: 24
# Num losses: 67
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.0013059340659340617
# Remaining runs: 58
# Best reward so far: -577.4999999998278
#
# -2225.499999999764
# Num buys: 70
# Num sells: 80
# Num trades: 150
# Num wins: 37
# Num losses: 113
# Win streak: 2
# Loss streak: 13
# Avg pips risked: 0.0012078666666666305
# Remaining runs: 57
# Best reward so far: -577.4999999998278
#
# -3268.9999999997485
# Num buys: 88
# Num sells: 111
# Num trades: 199
# Num wins: 67
# Num losses: 132
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0010923618090451967
# Remaining runs: 56
# Best reward so far: -577.4999999998278
#
# -2907.999999999799
# Num buys: 88
# Num sells: 110
# Num trades: 198
# Num wins: 40
# Num losses: 131
# Win streak: 5
# Loss streak: 26
# Avg pips risked: 0.0010914646464646174
# Remaining runs: 55
# Best reward so far: -577.4999999998278
#
# -3971.999999999976
# Num buys: 91
# Num sells: 120
# Num trades: 211
# Num wins: 70
# Num losses: 141
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0011753080568720387
# Remaining runs: 54
# Best reward so far: -577.4999999998278
#
# -4038.499999999968
# Num buys: 87
# Num sells: 117
# Num trades: 204
# Num wins: 70
# Num losses: 134
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0012619117647058847
# Remaining runs: 53
# Best reward so far: -577.4999999998278
#
# -2731.499999999784
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 36
# Num losses: 106
# Win streak: 4
# Loss streak: 19
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 52
# Best reward so far: -577.4999999998278
#
# -3613.0000000000064
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 49
# Num losses: 154
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.001258669950738918
# Remaining runs: 51
# Best reward so far: -577.4999999998278
#
# -3372.4999999999854
# Num buys: 91
# Num sells: 118
# Num trades: 209
# Num wins: 50
# Num losses: 159
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011731100478468907
# Remaining runs: 50
# Best reward so far: -577.4999999998278
#
# -3611.0000000000064
# Num buys: 87
# Num sells: 116
# Num trades: 203
# Num wins: 49
# Num losses: 154
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.001258669950738918
# Remaining runs: 49
# Best reward so far: -577.4999999998278
#
# -3797.750000000006
# Num buys: 91
# Num sells: 119
# Num trades: 210
# Num wins: 50
# Num losses: 140
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.0011748571428571442
# Remaining runs: 48
# Best reward so far: -577.4999999998278
#
# -3434.5000000000264
# Num buys: 86
# Num sells: 114
# Num trades: 200
# Num wins: 49
# Num losses: 151
# Win streak: 3
# Loss streak: 17
# Avg pips risked: 0.0012604000000000037
# Remaining runs: 47
# Best reward so far: -577.4999999998278
#
# -4097.500000000002
# Num buys: 91
# Num sells: 118
# Num trades: 209
# Num wins: 55
# Num losses: 154
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0011731100478468907
# Remaining runs: 46
# Best reward so far: -577.4999999998278
#
# -969.249999999823
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 24
# Num losses: 57
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001176813186813132
# Remaining runs: 45
# Best reward so far: -577.4999999998278
#
# -955.9999999999845
# Num buys: 43
# Num sells: 50
# Num trades: 93
# Num wins: 26
# Num losses: 55
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0013075268817204246
# Remaining runs: 44
# Best reward so far: -577.4999999998278
#
# -2873.999999999745
# Num buys: 72
# Num sells: 82
# Num trades: 154
# Num wins: 48
# Num losses: 106
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0011220779220778836
# Remaining runs: 43
# Best reward so far: -577.4999999998278
#
# -3420.749999999954
# Num buys: 75
# Num sells: 93
# Num trades: 168
# Num wins: 38
# Num losses: 116
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012136309523809478
# Remaining runs: 42
# Best reward so far: -577.4999999998278
#
# -946.9999999999502
# Num buys: 43
# Num sells: 51
# Num trades: 94
# Num wins: 20
# Num losses: 59
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0012431914893616947
# Remaining runs: 41
# Best reward so far: -577.4999999998278
#
# -912.9999999998164
# Num buys: 44
# Num sells: 47
# Num trades: 91
# Num wins: 19
# Num losses: 57
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001176813186813132
# Remaining runs: 40
# Best reward so far: -577.4999999998278
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/y1/r6lw81g960n148db75yhq7140000gn/T/ipykernel_19175/3706201740.py in <module>
#      39
#      40 for risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff in combos_to_try:
# ---> 41   reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked = run_simulation(risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff)
#      42   runs_finished += 1
#      43
#
# /var/folders/y1/r6lw81g960n148db75yhq7140000gn/T/ipykernel_19175/3840701099.py in run_simulation(risk_reward_ratio, spread_cutoff, use_tl, min_pips_to_risk, max_pips_to_risk, adx_cutoff)
#      55         curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
#      56           df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
# ---> 57                               'Ask_Low', 'Ask_Close']]
#      58
#      59         if trade is None:
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     829                     return section
#     830                 # This is an elided recursive call to iloc/loc
# --> 831                 return getattr(section, self.name)[new_key]
#     832
#     833         raise IndexingError("not applicable")
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
# -> 1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1056         )
#    1057
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4889             new_data = new_data.copy()
#    4890
# -> 4891         return self._constructor(new_data).__finalize__(self)
#    4892
#    4893     def filter(
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/generic.py in __finalize__(self, other, method, **kwargs)
#    5437             for name in set(self._metadata) & set(other._metadata):
#    5438                 assert isinstance(name, str)
# -> 5439                 object.__setattr__(self, name, getattr(other, name, None))
#    5440
#    5441         if method == "concat":
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/series.py in name(self, value)
#     538     @name.setter
#     539     def name(self, value: Label) -> None:
# --> 540         validate_all_hashable(value, error_name=f"{type(self).__name__}.name")
#     541         object.__setattr__(self, "_name", value)
#     542
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/dtypes/common.py in validate_all_hashable(error_name, *args)
#    1760     None
#    1761     """
# -> 1762     if not all(is_hashable(arg) for arg in args):
#    1763         if error_name:
#    1764             raise TypeError(f"{error_name} must be a hashable type")
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/dtypes/common.py in <genexpr>(.0)
#    1760     None
#    1761     """
# -> 1762     if not all(is_hashable(arg) for arg in args):
#    1763         if error_name:
#    1764             raise TypeError(f"{error_name} must be a hashable type")
#
# KeyboardInterrupt:

# %%
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best TL val: ' + str(best_use_tl_val))
print('Best min pips to risk: ' + str(best_min_pips_val))
print('Best max pips to risk: ' + str(best_max_pips_val))
print('Best adx val: ' + str(best_adx_val))
print('-----------------------')
print('Top results:')
for entry in best_rewards:
    print(entry)

# 2018-2019:
# {'reward': 1539, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 1554, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 575, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': -94, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 553, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 526, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 153, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1345, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 585, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': -99, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 25, 'spread': 2}
# {'reward': 150, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': -94, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 3}
# {'reward': 1355, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': -96, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 25, 'spread': 3}
# {'reward': 115, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 3}
# {'reward': 102, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 2}
# {'reward': -100, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': -125, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 2}
# {'reward': -92, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 2}
# {'reward': -139, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 3}

# 2019-2020:
# {'reward': 494, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 2}
# {'reward': 1306, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1316, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1088, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1345, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 892, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 801, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 562, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 495, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 3}
# {'reward': 895, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': -34, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1077, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1323, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': -17, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 741, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 3}
# {'reward': 549, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 742, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 2}
# {'reward': 797, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 350, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 348, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}

# {'reward': 1788, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1795, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 803, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 1211, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1335, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 889, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 1329, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 889, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 728, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 787, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 1042, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 1431, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 728, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1320, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 1425, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 1057, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 1089, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1341, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1222, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1093, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}


# 2020-2021:
# {'reward': 2381, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 15, 'spread': 3}
# {'reward': 2239, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 2513, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 2666, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 10}
# {'reward': 2254, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 10}
# {'reward': 2516, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 10}
# {'reward': 2256, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 2277, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 2254, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 2366, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 15, 'spread': 2}
# {'reward': 2531, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 2552, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 2285, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 2667, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 2}
# {'reward': 2238, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 10}
# {'reward': 2280, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 10, 'adx': 20, 'spread': 10}
# {'reward': 2552, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 10}
# {'reward': 2369, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 15, 'spread': 10}
# {'reward': 2673, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 3}
# {'reward': 2523, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}

# {'reward': 549, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 1254, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 717, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 2}
# {'reward': 734, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 25, 'spread': 2}
# {'reward': 560, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 517, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 528, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 503, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 729, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 732, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 25, 'spread': 3}
# {'reward': 642, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 710, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 3}
# {'reward': 495, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 655, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 779, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1259, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 725, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 772, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 674, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 664, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: -4025.4999999998936
# Best risk/reward ratio: 2
# Best bar length: 10
# Best spread: 3
# Best TL val: False
# Best pips to risk: 20
# Best strict pips val: True
# -----------------------
# Top results:
# {'reward': -4554, 'ratio': 1.5, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': False}
# {'reward': -4463, 'ratio': 1.5, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4320, 'ratio': 1.5, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4322, 'ratio': 1.5, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4184, 'ratio': 2, 'bar_length': 10, 'spread': 2, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4214, 'ratio': 2, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4193, 'ratio': 2, 'bar_length': 10, 'spread': 3, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4025, 'ratio': 2, 'bar_length': 10, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4540, 'ratio': 2, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': False}
# {'reward': -4729, 'ratio': 1.5, 'bar_length': 10, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -5095, 'ratio': 2, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': False}
# {'reward': -4102, 'ratio': 2, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4025, 'ratio': 2, 'bar_length': 10, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4534, 'ratio': 1.5, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': False}
# {'reward': -4536, 'ratio': 2, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': False}
# {'reward': -4102, 'ratio': 2, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -5075, 'ratio': 2, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': False}
# {'reward': -4222, 'ratio': 2, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4448, 'ratio': 1.5, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4726, 'ratio': 1.5, 'bar_length': 10, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}

# %%
print(df['macd'].min())
print(df['macd'].max())
print(df['macd'].mean())
# Out:
# -0.003969309682979816
# 0.0035649639441031056
# 8.15201580071511e-06

# %%
print(df['macdsignal'].min())
print(df['macdsignal'].max())
print(df['macdsignal'].mean())
# Out:
# -0.0036593454070104913
# 0.003094390540288942
# 8.13115151206653e-06

# %%
foo1 = set([1, 2, 3])
foo2 = set([4, 5, 6])
foo3 = set([7, 8, 9])
foos = [foo1, foo2, foo3]

import itertools

list(itertools.product(*foos))
# Out:
# [(1, 4, 8),
#  (1, 4, 9),
#  (1, 4, 7),
#  (1, 5, 8),
#  (1, 5, 9),
#  (1, 5, 7),
#  (1, 6, 8),
#  (1, 6, 9),
#  (1, 6, 7),
#  (2, 4, 8),
#  (2, 4, 9),
#  (2, 4, 7),
#  (2, 5, 8),
#  (2, 5, 9),
#  (2, 5, 7),
#  (2, 6, 8),
#  (2, 6, 9),
#  (2, 6, 7),
#  (3, 4, 8),
#  (3, 4, 9),
#  (3, 4, 7),
#  (3, 5, 8),
#  (3, 5, 9),
#  (3, 5, 7),
#  (3, 6, 8),
#  (3, 6, 9),
#  (3, 6, 7)]
