# %%
import numpy as np
import pandas as pd
import random

# %%
file_path = '../../bar_movement/data/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
df = pd.read_csv(file_path + 'Oanda_Eur_Usd_M5_2021-2022.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2021-04-01 06:00:00   1.17170   1.17172  1.17141    1.17141   1.17184
# 1 2021-04-01 06:05:00   1.17140   1.17182  1.17119    1.17154   1.17153
# 2 2021-04-01 06:10:00   1.17153   1.17162  1.17140    1.17161   1.17166
# 3 2021-04-01 06:15:00   1.17160   1.17187  1.17153    1.17185   1.17173
# 4 2021-04-01 06:20:00   1.17184   1.17253  1.17171    1.17232   1.17196
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0   1.17187  1.17154    1.17154   1.17177   1.17180  1.17148    1.17148
# 1   1.17194  1.17133    1.17167   1.17146   1.17188  1.17126    1.17160
# 2   1.17175  1.17151    1.17174   1.17160   1.17168  1.17146    1.17168
# 3   1.17200  1.17165    1.17197   1.17166   1.17194  1.17160    1.17191
# 4   1.17266  1.17185    1.17244   1.17190   1.17259  1.17178    1.17238
#
#    Volume
# 0     348
# 1     451
# 2     324
# 3     275
# 4     646
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 74778 2022-04-01 05:35:00   1.10690   1.10694  1.10668    1.10676   1.10707
# 74779 2022-04-01 05:40:00   1.10675   1.10727  1.10672    1.10720   1.10691
# 74780 2022-04-01 05:45:00   1.10721   1.10722  1.10698    1.10704   1.10737
# 74781 2022-04-01 05:50:00   1.10703   1.10729  1.10700    1.10726   1.10721
# 74782 2022-04-01 05:55:00   1.10727   1.10737  1.10667    1.10673   1.10742
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 74778   1.10710  1.10683    1.10691   1.10698   1.10702  1.10676    1.10684
# 74779   1.10744  1.10689    1.10737   1.10683   1.10735  1.10680    1.10728
# 74780   1.10738  1.10715    1.10721   1.10729   1.10730  1.10707    1.10712
# 74781   1.10744  1.10717    1.10743   1.10712   1.10736  1.10708    1.10734
# 74782   1.10754  1.10683    1.10690   1.10734   1.10745  1.10675    1.10682
#
#        Volume
# 74778     291
# 74779     400
# 74780     183
# 74781     227
# 74782     439

# %%
def psar(barsdata, iaf=0.02, maxaf=0.2):
    length = len(barsdata)
    high = list(barsdata['Mid_High'])
    low = list(barsdata['Mid_Low'])
    close = list(barsdata['Mid_Close'])
    psar = close[0:len(close)]
    bull = True
    af = iaf
    hp = high[0]
    lp = low[0]
    for i in range(2, length):
        if bull:
            psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
        else:
            psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
        reverse = False
        if bull:
            if low[i] < psar[i]:
                bull = False
                reverse = True
                psar[i] = hp
                lp = low[i]
                af = iaf
        else:
            if high[i] > psar[i]:
                bull = True
                reverse = True
                psar[i] = lp
                hp = high[i]
                af = iaf
        if not reverse:
            if bull:
                if high[i] > hp:
                    hp = high[i]
                    af = min(af + iaf, maxaf)
                if low[i - 1] < psar[i]:
                    psar[i] = low[i - 1]
                if low[i - 2] < psar[i]:
                    psar[i] = low[i - 2]
            else:
                if low[i] < lp:
                    lp = low[i]
                    af = min(af + iaf, maxaf)
                if high[i - 1] > psar[i]:
                    psar[i] = high[i - 1]
                if high[i - 2] > psar[i]:
                    psar[i] = high[i - 2]
    return psar


def atr(barsdata, lookback=14):
    high_low = barsdata['Mid_High'] - barsdata['Mid_Low']
    high_close = np.abs(barsdata['Mid_High'] - barsdata['Mid_Close'].shift())
    low_close = np.abs(barsdata['Mid_Low'] - barsdata['Mid_Close'].shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = np.max(ranges, axis=1)

    return true_range.rolling(lookback).sum() / lookback


def rsi(barsdata, periods=14):
    close_delta = barsdata['Mid_Close'].diff()

    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)
    ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))

    return rsi

  
def adx(high, low, close, lookback=14):
    plus_dm = high.diff()
    minus_dm = low.diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0
    
    tr1 = pd.DataFrame(high - low)
    tr2 = pd.DataFrame(abs(high - close.shift(1)))
    tr3 = pd.DataFrame(abs(low - close.shift(1)))
    frames = [tr1, tr2, tr3]
    tr = pd.concat(frames, axis = 1, join = 'inner').max(axis = 1)
    atr = tr.rolling(lookback).mean()
    
    plus_di = 100 * (plus_dm.ewm(alpha = 1/lookback).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha = 1/lookback).mean() / atr))
    dx = (abs(plus_di - minus_di) / abs(plus_di + minus_di)) * 100
    adx = ((dx.shift(1) * (lookback - 1)) + dx) / lookback
    adx_smooth = adx.ewm(alpha = 1/lookback).mean()

    return adx_smooth


def stoch(high, low, close, lookback=14):
    high_lookback = high.rolling(lookback).max()
    low_lookback = low.rolling(lookback).min()
    slow_k = (close - low_lookback) * 100 / (high_lookback - low_lookback)
    slow_d = slow_k.rolling(3).mean()

    return slow_k, slow_d

def stoch_rsi(data, k_window=3, d_window=3, window=14):
    min_val = data.rolling(window=window, center=False).min()
    max_val = data.rolling(window=window, center=False).max()

    stoch = ((data - min_val) / (max_val - min_val)) * 100

    slow_k = stoch.rolling(window=k_window, center=False).mean()

    slow_d = slow_k.rolling(window=d_window, center=False).mean()

    return slow_k, slow_d

def n_macd(macd, macdsignal, lookback=50):
    n_macd = 2 * (((macd - macd.rolling(lookback).min()) / (macd.rolling(lookback).max() - macd.rolling(lookback).min()))) - 1
    n_macdsignal = 2 * (((macdsignal - macdsignal.rolling(lookback).min()) / (macdsignal.rolling(lookback).max() - macdsignal.rolling(lookback).min()))) - 1

    return n_macd, n_macdsignal

def chop(df, lookback=14):
    atr1 = atr(df, lookback=1)
    high, low = df['Mid_High'], df['Mid_Low']

    chop = np.log10(atr1.rolling(lookback).sum() / (high.rolling(lookback).max() - low.rolling(lookback).min())) / np.log10(lookback)

    return chop

def vo(volume, short_lookback=5, long_lookback=10):
    short_ema =  pd.Series.ewm(volume, span=short_lookback).mean()
    long_ema = pd.Series.ewm(volume, span=long_lookback).mean()

    volume_oscillator = (short_ema - long_ema) / long_ema

    return volume_oscillator

def bar_lengths(bar_lens, window=36):
    return bar_lens.rolling(window=window).mean(), bar_lens.rolling(window=window).std()

def sar_lengths(opens, sars, window=36):
    diffs = abs(opens - sars.shift(1))

    return diffs.rolling(window=window).mean(), diffs.rolling(window=window).std()

def range_high_lows(df, i, n_histograms=6):
    green, red = False, False
    curr_color, curr_streak = None, 0
    high, low = -np.inf, np.inf

    while i >= 0:
        hist = df.loc[df.index[i], 'macdhist']
        curr_high, curr_low = df.loc[df.index[i], ['Mid_High', 'Mid_Low']]
        new_color = 'green' if hist > 0 else 'red'

        if curr_color != new_color:
            curr_color = new_color
            curr_streak = 0

            if green and red:
                break

        curr_streak += 1

        if curr_streak >= n_histograms:
            high = max(high, curr_high)
            low = min(low, curr_low)

            if curr_color == 'red':
                red = True

            else:
                green = True

        i -= 1

    return high, low if (high > -np.inf and low < np.inf) else np.nan, np.nan

# def range_high_lows(df, i):
#     green, red = False, False
#     curr_color, curr_streak = None, 0
#     high, low = -np.inf, np.inf

#     while i >= 0:
#         hist = df.loc[df.index[i], 'macdhist']
#         curr_high, curr_low = df.loc[df.index[i], ['Mid_High', 'Mid_Low']]
#         new_color = 'green' if hist > 0 else 'red'

#         if curr_color != new_color:
#             curr_color = new_color
#             curr_streak = 0

#             if green and red:
#                 break

#         curr_streak += 1

#         if curr_streak >= 3:
#             if curr_color == 'red':
#                 low = min(low, curr_low)
#                 red = True

#             else:
#                 high = max(high, curr_high)
#                 green = True

#         i -= 1

#     return high, low if (high > -np.inf and low < np.inf) else np.nan, np.nan

# %%
# Add technical indicators (for additional features)
df['atr'] = atr(df)
df['adx'] = adx(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

print(df)
# Out:
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0     2021-04-01 07:10:00   1.17239   1.17334  1.17239    1.17316   1.17252
# 1     2021-04-01 07:15:00   1.17315   1.17321  1.17274    1.17297   1.17329
# 2     2021-04-01 07:20:00   1.17298   1.17362  1.17263    1.17362   1.17311
# 3     2021-04-01 07:25:00   1.17364   1.17420  1.17352    1.17414   1.17377
# 4     2021-04-01 07:30:00   1.17412   1.17425  1.17381    1.17394   1.17425
# ...                   ...       ...       ...      ...        ...       ...
# 74764 2022-04-01 05:35:00   1.10690   1.10694  1.10668    1.10676   1.10707
# 74765 2022-04-01 05:40:00   1.10675   1.10727  1.10672    1.10720   1.10691
# 74766 2022-04-01 05:45:00   1.10721   1.10722  1.10698    1.10704   1.10737
# 74767 2022-04-01 05:50:00   1.10703   1.10729  1.10700    1.10726   1.10721
# 74768 2022-04-01 05:55:00   1.10727   1.10737  1.10667    1.10673   1.10742
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0       1.17348  1.17252    1.17330   1.17246   1.17341  1.17246    1.17323
# 1       1.17334  1.17287    1.17310   1.17322   1.17328  1.17281    1.17304
# 2       1.17375  1.17276    1.17375   1.17304   1.17368  1.17270    1.17368
# 3       1.17433  1.17366    1.17427   1.17370   1.17426  1.17359    1.17420
# 4       1.17438  1.17391    1.17405   1.17418   1.17432  1.17386    1.17400
# ...         ...      ...        ...       ...       ...      ...        ...
# 74764   1.10710  1.10683    1.10691   1.10698   1.10702  1.10676    1.10684
# 74765   1.10744  1.10689    1.10737   1.10683   1.10735  1.10680    1.10728
# 74766   1.10738  1.10715    1.10721   1.10729   1.10730  1.10707    1.10712
# 74767   1.10744  1.10717    1.10743   1.10712   1.10736  1.10708    1.10734
# 74768   1.10754  1.10683    1.10690   1.10734   1.10745  1.10675    1.10682
#
#        Volume       atr        adx
# 0         662  0.000531  38.394956
# 1         490  0.000520  46.548073
# 2         548  0.000574  49.272128
# 3         698  0.000598  50.893711
# 4         398  0.000573  53.478762
# ...       ...       ...        ...
# 74764     291  0.000272   9.813219
# 74765     400  0.000299   9.807821
# 74766     183  0.000289  10.947864
# 74767     227  0.000294  12.020967
# 74768     439  0.000331  13.107870
#
# [74769 rows x 16 columns]

# %%
value_per_pip = 1.0
amounts_per_day = [-0.00008, -0.0001, -0.00012]
pair = 'EUR_USD'

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee

def get_n_units(open_price, stop_loss, mid_open, currency_pair):
    _, second = currency_pair.split('_')
  
    pips_to_risk = abs(open_price - stop_loss)
    pips_to_risk_calc = pips_to_risk * 10000 if second != 'JPY' else pips_to_risk * 100

    if second == 'USD':
        per_pip = 0.0001

    else:
        per_pip = 0.0001 / mid_open if second != 'JPY' else 0.01 / mid_open

    n_units = int(50 / (pips_to_risk_calc * per_pip))

    return n_units

def run_simulation(risk_reward_ratio, spread_cutoff, atr_multiplier, n_bars, adx_cutoff):
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    trade = None
    trade_lengths = []

    for i in range(n_bars + 1, len(df)):
        curr_date = df.loc[df.index[i], 'Date']
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, curr_mid_open, curr_mid_low = \
            df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_Low']]
        atr, adx, ask_low, bid_high, mid_low1, mid_high1 = df.loc[df.index[i - 1], ['atr', 'adx', 'Ask_Low', 'Bid_High', 'Mid_Low', 'Mid_High']]
        chop_signal = adx < adx_cutoff
        first_bar_mo = df.loc[df.index[i - 1 - n_bars], 'Mid_Open']
        first_bar_mc = df.loc[df.index[i - 1 - n_bars], 'Mid_Close']
        next_n_bars_mo = list(df.loc[df.index[i - n_bars:i], 'Mid_Open'])
        next_n_bars_mc = list(df.loc[df.index[i - n_bars:i], 'Mid_Close'])


        if trade is None:
            place_buy = chop_signal and first_bar_mo < first_bar_mc and all([next_n_bars_mc[idx] < next_n_bars_mo[idx] for idx in range(len(next_n_bars_mo))])
            place_sell = chop_signal and first_bar_mo > first_bar_mc and all([next_n_bars_mc[idx] > next_n_bars_mo[idx] for idx in range(len(next_n_bars_mo))])

            if place_buy:
                open_price = curr_ask_open
                stop_loss = mid_low1 - (atr * atr_multiplier)
                curr_pips_to_risk = open_price - stop_loss
                stop_gain = open_price + (risk_reward_ratio * curr_pips_to_risk)

                if stop_loss < open_price and stop_gain > open_price and spread <= curr_pips_to_risk * spread_cutoff:
                    n_units = get_n_units(open_price, stop_loss, curr_mid_open, pair)

                    trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                    'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                    'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None, 'index': i}

                    n_buys += 1

                    pips_risked.append(curr_pips_to_risk)

            elif place_sell:
                open_price = curr_bid_open
                stop_loss = mid_high1 + (atr * atr_multiplier)
                curr_pips_to_risk = stop_loss - open_price
                stop_gain = open_price - (risk_reward_ratio * curr_pips_to_risk)

                if stop_loss > open_price and stop_gain < open_price and spread <= curr_pips_to_risk * spread_cutoff:
                    n_units = get_n_units(open_price, stop_loss, curr_mid_open, pair)

                    trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                            'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                            'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None, 'index': i}

                    n_sells += 1

                    pips_risked.append(curr_pips_to_risk)

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
            trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
            trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
            trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
            trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked, trade_lengths

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
risk_reward_ratio_vals = [0.25, 0.5, 1.0]
spread_cutoffs = [0.1, 0.2, 0.3]
atr_multipliers = [0.5, 1.0, 1.5, 2.0]
n_bars_vals = [3, 4, 5]
adx_cutoffs = [20, 25, 30]

# risk_reward_ratio_vals = [0.5]
# spread_cutoffs = [0.2]
# atr_multipliers = [1.5]
# n_minutes_vals = [10]
# adx_cutoffs = [20]

all_combos = []


# use_half_sar, vo_cutoff, use_candles

for risk_reward_ratio in risk_reward_ratio_vals:
    for spread_val in spread_cutoffs:
        for atr_multiplier in atr_multipliers:
            for n_bars in n_bars_vals:
                for adx_cutoff in adx_cutoffs:
                    all_combos.append((risk_reward_ratio, spread_val, atr_multiplier, n_bars, adx_cutoff))

# percentage_to_try = 0.5
percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)
print('Num runs: '+ str(len(combos_to_try)) + '\n')

best_risk_reward = None
best_spread_cutoff = None
best_atr_multiplier = None
best_n_bars= None
best_adx_cutoff = None
top_n_results = 20
best_rewards = []
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, spread_val, atr_multiplier, n_bars, adx_cutoff in combos_to_try:
    reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked, trade_lengths = run_simulation(risk_reward_ratio, spread_val, atr_multiplier, n_bars, adx_cutoff)
    runs_finished += 1

    print(reward)
    print('Num buys: ' + str(n_buys))
    print('Num sells: ' + str(n_sells))
    print('Num trades: ' + str(n_buys + n_sells))
    print('Num wins: ' + str(n_wins))
    print('Num losses: ' + str(n_losses))
    print('Win streak: ' + str(win_streak))
    print('Loss streak: ' + str(loss_streak))
    avg_pips_risked = (sum(pips_risked) / len(pips_risked)) if len(pips_risked) > 0 else 'N/A'
    avg_trade_len = (sum(trade_lengths) / len(trade_lengths)) if len(trade_lengths) > 0 else 0
    print('Avg pips risked: ' + str(avg_pips_risked))
    print('Avg trade length: ' + str(avg_trade_len))
    print('Remaining runs: ' + str(n_runs - runs_finished))

    min_item = min(best_rewards, key=lambda entry: entry['reward']) if len(best_rewards) >= top_n_results else None

    if min_item is None or reward > min_item['reward']:
        if min_item is not None:
            best_rewards.remove(min_item)
            
        best_rewards.append({'reward': int(reward), 'ratio': risk_reward_ratio, 'spread_val': spread_val, 'atr_multiplier': atr_multiplier, 'n_bars': n_bars, 'adx_cutoff': adx_cutoff})


    if reward > best_reward:
        best_reward = reward
        best_risk_reward = risk_reward_ratio
        best_spread_cutoff = spread_val
        best_atr_multiplier = atr_multiplier
        best_n_bars = n_bars
        best_adx_cutoff = adx_cutoff

    print('Best reward so far: ' + str(best_reward))
    print()
# Out:
# Num runs: 324
#
# -599.9962278571472
# Num buys: 18
# Num sells: 20
# Num trades: 38
# Num wins: 13
# Num losses: 25
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.0009003853383458928
# Avg trade length: 5.421052631578948
# Remaining runs: 323
# Best reward so far: -599.9962278571472
#
# -22555.35104107181
# Num buys: 1231
# Num sells: 1247
# Num trades: 2478
# Num wins: 1353
# Num losses: 1125
# Win streak: 13
# Loss streak: 9
# Avg pips risked: 0.0008178006456820134
# Avg trade length: 7.152138821630347
# Remaining runs: 322
# Best reward so far: -599.9962278571472
#
# -6781.291505714773
# Num buys: 430
# Num sells: 438
# Num trades: 868
# Num wins: 368
# Num losses: 500
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0008248699802501729
# Avg trade length: 13.934331797235023
# Remaining runs: 321
# Best reward so far: -599.9962278571472
#
# 24.99879107142173
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 3
# Num losses: 1
# Win streak: 2
# Loss streak: 1
# Avg pips risked: 0.001821428571428585
# Avg trade length: 5.25
# Remaining runs: 320
# Best reward so far: 24.99879107142173
#
# 12.499845535709513
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 1
# Num losses: 0
# Win streak: 1
# Loss streak: 0
# Avg pips risked: 0.0016082142857141157
# Avg trade length: 28.0
# Remaining runs: 319
# Best reward so far: 24.99879107142173
#
# -639.7930474106793
# Num buys: 86
# Num sells: 89
# Num trades: 175
# Num wins: 130
# Num losses: 45
# Win streak: 11
# Loss streak: 3
# Avg pips risked: 0.0017359979591836908
# Avg trade length: 7.628571428571429
# Remaining runs: 318
# Best reward so far: 24.99879107142173
#
# -99.99604732144766
# Num buys: 16
# Num sells: 16
# Num trades: 32
# Num wins: 24
# Num losses: 8
# Win streak: 6
# Loss streak: 1
# Avg pips risked: 0.0017679687500000013
# Avg trade length: 2.375
# Remaining runs: 317
# Best reward so far: 24.99879107142173
#
# -99.99945357143014
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 1
# Num losses: 3
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.001821428571428585
# Avg trade length: 7.25
# Remaining runs: 316
# Best reward so far: 24.99879107142173
#
# 49.998740892852474
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 4
# Num losses: 0
# Win streak: 4
# Loss streak: 0
# Avg pips risked: 0.001821428571428585
# Avg trade length: 1.25
# Remaining runs: 315
# Best reward so far: 49.998740892852474
#
# -124.99761107143468
# Num buys: 5
# Num sells: 5
# Num trades: 10
# Num wins: 5
# Num losses: 5
# Win streak: 2
# Loss streak: 2
# Avg pips risked: 0.0016424285714285336
# Avg trade length: 9.2
# Remaining runs: 314
# Best reward so far: 49.998740892852474
#
# -449.9911957142749
# Num buys: 50
# Num sells: 54
# Num trades: 104
# Num wins: 76
# Num losses: 28
# Win streak: 9
# Loss streak: 3
# Avg pips risked: 0.001761043956043971
# Avg trade length: 7.240384615384615
# Remaining runs: 313
# Best reward so far: 49.998740892852474
#
# -212.49829776785782
# Num buys: 15
# Num sells: 18
# Num trades: 33
# Num wins: 23
# Num losses: 10
# Win streak: 6
# Loss streak: 2
# Avg pips risked: 0.0017430844155844043
# Avg trade length: 4.636363636363637
# Remaining runs: 312
# Best reward so far: 49.998740892852474
#
# 49.99938214285186
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 1
# Num losses: 0
# Win streak: 1
# Loss streak: 0
# Avg pips risked: 0.0016082142857141157
# Avg trade length: 62.0
# Remaining runs: 311
# Best reward so far: 49.99938214285186
#
# -1674.98756375005
# Num buys: 94
# Num sells: 85
# Num trades: 179
# Num wins: 97
# Num losses: 82
# Win streak: 6
# Loss streak: 6
# Avg pips risked: 0.0006041899441340718
# Avg trade length: 2.6201117318435756
# Remaining runs: 310
# Best reward so far: 49.99938214285186
#
# -488.41351160730136
# Num buys: 48
# Num sells: 53
# Num trades: 101
# Num wins: 61
# Num losses: 40
# Win streak: 5
# Loss streak: 4
# Avg pips risked: 0.0009349964639321263
# Avg trade length: 4.227722772277228
# Remaining runs: 309
# Best reward so far: 49.99938214285186
#
# -74.9985589285688
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.0016546428571428962
# Avg trade length: 3.3333333333333335
# Remaining runs: 308
# Best reward so far: 49.99938214285186
#
# -3485.157212500264
# Num buys: 227
# Num sells: 228
# Num trades: 455
# Num wins: 194
# Num losses: 261
# Win streak: 8
# Loss streak: 13
# Avg pips risked: 0.0007882692307692329
# Avg trade length: 14.338461538461539
# Remaining runs: 307
# Best reward so far: 49.99938214285186
#
# -8741.426237499958
# Num buys: 519
# Num sells: 526
# Num trades: 1045
# Num wins: 581
# Num losses: 464
# Win streak: 9
# Loss streak: 9
# Avg pips risked: 0.001002146274777862
# Avg trade length: 8.124401913875598
# Remaining runs: 306
# Best reward so far: 49.99938214285186
#
# -4882.268490000226
# Num buys: 288
# Num sells: 280
# Num trades: 568
# Num wins: 315
# Num losses: 253
# Win streak: 10
# Loss streak: 8
# Avg pips risked: 0.0009116549295774701
# Avg trade length: 11.741197183098592
# Remaining runs: 305
# Best reward so far: 49.99938214285186
#
# -2768.545101071409
# Num buys: 202
# Num sells: 167
# Num trades: 369
# Num wins: 251
# Num losses: 118
# Win streak: 10
# Loss streak: 5
# Avg pips risked: 0.0009068970189701954
# Avg trade length: 3.130081300813008
# Remaining runs: 304
# Best reward so far: 49.99938214285186
#
# -563.960973571426
# Num buys: 60
# Num sells: 56
# Num trades: 116
# Num wins: 70
# Num losses: 46
# Win streak: 12
# Loss streak: 7
# Avg pips risked: 0.0016882019704433755
# Avg trade length: 19.75
# Remaining runs: 303
# Best reward so far: 49.99938214285186
#
# -1118.1200271429138
# Num buys: 80
# Num sells: 85
# Num trades: 165
# Num wins: 72
# Num losses: 93
# Win streak: 6
# Loss streak: 6
# Avg pips risked: 0.0016625800865801028
# Avg trade length: 39.39393939393939
# Remaining runs: 302
# Best reward so far: 49.99938214285186
#
# -4122.989174285994
# Num buys: 304
# Num sells: 284
# Num trades: 588
# Num wins: 255
# Num losses: 333
# Win streak: 7
# Loss streak: 12
# Avg pips risked: 0.001087830417881459
# Avg trade length: 25.685374149659864
# Remaining runs: 301
# Best reward so far: 49.99938214285186
#
# -14912.098585714837
# Num buys: 610
# Num sells: 608
# Num trades: 1218
# Num wins: 461
# Num losses: 757
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0007035380014074654
# Avg trade length: 8.311165845648604
# Remaining runs: 300
# Best reward so far: 49.99938214285186
#
# -1021.6305957142325
# Num buys: 228
# Num sells: 226
# Num trades: 454
# Num wins: 290
# Num losses: 164
# Win streak: 17
# Loss streak: 8
# Avg pips risked: 0.0017393864065450176
# Avg trade length: 18.8215859030837
# Remaining runs: 299
# Best reward so far: 49.99938214285186
#
# -4819.286418571403
# Num buys: 245
# Num sells: 259
# Num trades: 504
# Num wins: 204
# Num losses: 300
# Win streak: 7
# Loss streak: 12
# Avg pips risked: 0.000685178571428569
# Avg trade length: 7.6686507936507935
# Remaining runs: 298
# Best reward so far: 49.99938214285186
#
# -5668.466905714597
# Num buys: 434
# Num sells: 435
# Num trades: 869
# Num wins: 381
# Num losses: 488
# Win streak: 8
# Loss streak: 11
# Avg pips risked: 0.001091918461285566
# Avg trade length: 23.58342922899885
# Remaining runs: 297
# Best reward so far: 49.99938214285186
#
# -23688.185474821297
# Num buys: 1050
# Num sells: 1076
# Num trades: 2126
# Num wins: 1322
# Num losses: 804
# Win streak: 16
# Loss streak: 7
# Avg pips risked: 0.0006776847869910041
# Avg trade length: 2.8579492003762934
# Remaining runs: 296
# Best reward so far: 49.99938214285186
#
# 24.99879107142173
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 3
# Num losses: 1
# Win streak: 2
# Loss streak: 1
# Avg pips risked: 0.001821428571428585
# Avg trade length: 5.25
# Remaining runs: 295
# Best reward so far: 49.99938214285186
#
# -5936.923641428444
# Num buys: 435
# Num sells: 438
# Num trades: 873
# Num wins: 378
# Num losses: 495
# Win streak: 8
# Loss streak: 11
# Avg pips risked: 0.0009032891507118417
# Avg trade length: 9.623138602520045
# Remaining runs: 294
# Best reward so far: 49.99938214285186
#
# -0.0005121428521377425
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 4
# Num losses: 2
# Win streak: 2
# Loss streak: 1
# Avg pips risked: 0.0014465476190475741
# Avg trade length: 8.5
# Remaining runs: 293
# Best reward so far: 49.99938214285186
#
# -502.1270649999836
# Num buys: 77
# Num sells: 74
# Num trades: 151
# Num wins: 71
# Num losses: 80
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0017267478713339816
# Avg trade length: 33.81456953642384
# Remaining runs: 292
# Best reward so far: 49.99938214285186
#
# -212.49769821423567
# Num buys: 22
# Num sells: 26
# Num trades: 48
# Num wins: 35
# Num losses: 13
# Win streak: 8
# Loss streak: 3
# Avg pips risked: 0.001649642857142868
# Avg trade length: 3.25
# Remaining runs: 291
# Best reward so far: 49.99938214285186
#
# -5407.109496785775
# Num buys: 384
# Num sells: 379
# Num trades: 763
# Num wins: 524
# Num losses: 239
# Win streak: 15
# Loss streak: 5
# Avg pips risked: 0.0010672907695188384
# Avg trade length: 6.993446920052425
# Remaining runs: 290
# Best reward so far: 49.99938214285186
#
# -1499.9866178570874
# Num buys: 61
# Num sells: 65
# Num trades: 126
# Num wins: 64
# Num losses: 62
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.000878449546485259
# Avg trade length: 2.8412698412698414
# Remaining runs: 289
# Best reward so far: 49.99938214285186
#
# -8753.468037232276
# Num buys: 519
# Num sells: 547
# Num trades: 1066
# Num wins: 713
# Num losses: 353
# Win streak: 26
# Loss streak: 7
# Avg pips risked: 0.0009511045966229022
# Avg trade length: 4.582551594746716
# Remaining runs: 288
# Best reward so far: 49.99938214285186
#
# -4374.967232321302
# Num buys: 242
# Num sells: 223
# Num trades: 465
# Num wins: 302
# Num losses: 163
# Win streak: 9
# Loss streak: 5
# Avg pips risked: 0.0008711459293394843
# Avg trade length: 2.9634408602150537
# Remaining runs: 287
# Best reward so far: 49.99938214285186
#
# -266.72868178572514
# Num buys: 27
# Num sells: 20
# Num trades: 47
# Num wins: 21
# Num losses: 26
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.001872386018237088
# Avg trade length: 28.914893617021278
# Remaining runs: 286
# Best reward so far: 49.99938214285186
#
# -5290.903277321645
# Num buys: 244
# Num sells: 214
# Num trades: 458
# Num wins: 235
# Num losses: 223
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0006304826887086754
# Avg trade length: 2.7532751091703056
# Remaining runs: 285
# Best reward so far: 49.99938214285186
#
# -10436.00168321448
# Num buys: 702
# Num sells: 727
# Num trades: 1429
# Num wins: 977
# Num losses: 452
# Win streak: 18
# Loss streak: 6
# Avg pips risked: 0.0010721423572928287
# Avg trade length: 6.740377886634009
# Remaining runs: 284
# Best reward so far: 49.99938214285186
#
# -9224.133331786177
# Num buys: 421
# Num sells: 400
# Num trades: 821
# Num wins: 320
# Num losses: 501
# Win streak: 7
# Loss streak: 23
# Avg pips risked: 0.0007955198364364165
# Avg trade length: 14.401948842874543
# Remaining runs: 283
# Best reward so far: 49.99938214285186
#
# -16967.26919250055
# Num buys: 879
# Num sells: 874
# Num trades: 1753
# Num wins: 944
# Num losses: 809
# Win streak: 9
# Loss streak: 9
# Avg pips risked: 0.0008299641431016356
# Avg trade length: 7.544209925841415
# Remaining runs: 282
# Best reward so far: 49.99938214285186
#
# -5418.502172142913
# Num buys: 243
# Num sells: 213
# Num trades: 456
# Num wins: 174
# Num losses: 282
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0006305325814536381
# Avg trade length: 4.219298245614035
# Remaining runs: 281
# Best reward so far: 49.99938214285186
#
# -599.9884314285689
# Num buys: 63
# Num sells: 59
# Num trades: 122
# Num wins: 88
# Num losses: 34
# Win streak: 14
# Loss streak: 5
# Avg pips risked: 0.0016785245901639596
# Avg trade length: 8.434426229508198
# Remaining runs: 280
# Best reward so far: 49.99938214285186
#
# -175.00070482149405
# Num buys: 18
# Num sells: 20
# Num trades: 38
# Num wins: 23
# Num losses: 15
# Win streak: 5
# Loss streak: 3
# Avg pips risked: 0.0009003853383458928
# Avg trade length: 2.5526315789473686
# Remaining runs: 279
# Best reward so far: 49.99938214285186
#
# -2155.243697857204
# Num buys: 94
# Num sells: 85
# Num trades: 179
# Num wins: 68
# Num losses: 111
# Win streak: 6
# Loss streak: 8
# Avg pips risked: 0.0006041899441340718
# Avg trade length: 4.385474860335195
# Remaining runs: 278
# Best reward so far: 49.99938214285186
#
# -11370.726118571301
# Num buys: 720
# Num sells: 752
# Num trades: 1472
# Num wins: 627
# Num losses: 845
# Win streak: 9
# Loss streak: 13
# Avg pips risked: 0.0011559559394410145
# Avg trade length: 24.766304347826086
# Remaining runs: 277
# Best reward so far: 49.99938214285186
#
# -15460.95483285734
# Num buys: 837
# Num sells: 864
# Num trades: 1701
# Num wins: 932
# Num losses: 769
# Win streak: 12
# Loss streak: 7
# Avg pips risked: 0.0009341630973377158
# Avg trade length: 11.261022927689595
# Remaining runs: 276
# Best reward so far: 49.99938214285186
#
# -14712.908676429091
# Num buys: 647
# Num sells: 641
# Num trades: 1288
# Num wins: 663
# Num losses: 625
# Win streak: 8
# Loss streak: 8
# Avg pips risked: 0.0007007287045252944
# Avg trade length: 4.434782608695652
# Remaining runs: 275
# Best reward so far: 49.99938214285186
#
# -112.4981310714348
# Num buys: 4
# Num sells: 7
# Num trades: 11
# Num wins: 7
# Num losses: 4
# Win streak: 2
# Loss streak: 1
# Avg pips risked: 0.001762792207792236
# Avg trade length: 5.454545454545454
# Remaining runs: 274
# Best reward so far: 49.99938214285186
#
# -337.4941999999975
# Num buys: 29
# Num sells: 39
# Num trades: 68
# Num wins: 49
# Num losses: 19
# Win streak: 8
# Loss streak: 3
# Avg pips risked: 0.0016352993697479074
# Avg trade length: 5.823529411764706
# Remaining runs: 273
# Best reward so far: 49.99938214285186
#
# -6129.100435535536
# Num buys: 389
# Num sells: 381
# Num trades: 770
# Num wins: 518
# Num losses: 252
# Win streak: 14
# Loss streak: 6
# Avg pips risked: 0.0008847207792207885
# Avg trade length: 3.101298701298701
# Remaining runs: 272
# Best reward so far: 49.99938214285186
#
# -2512.4770526786806
# Num buys: 208
# Num sells: 216
# Num trades: 424
# Num wins: 299
# Num losses: 125
# Win streak: 13
# Loss streak: 4
# Avg pips risked: 0.000976608827493266
# Avg trade length: 4.55188679245283
# Remaining runs: 271
# Best reward so far: 49.99938214285186
#
# -10618.009314643254
# Num buys: 577
# Num sells: 563
# Num trades: 1140
# Num wins: 743
# Num losses: 397
# Win streak: 12
# Loss streak: 6
# Avg pips risked: 0.0009082619047619242
# Avg trade length: 6.779824561403509
# Remaining runs: 270
# Best reward so far: 49.99938214285186
#
# -5658.674420714069
# Num buys: 214
# Num sells: 211
# Num trades: 425
# Num wins: 156
# Num losses: 269
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0005943403361344579
# Avg trade length: 3.988235294117647
# Remaining runs: 269
# Best reward so far: 49.99938214285186
#
# -1587.4881821429087
# Num buys: 95
# Num sells: 103
# Num trades: 198
# Num wins: 133
# Num losses: 65
# Win streak: 11
# Loss streak: 6
# Avg pips risked: 0.0008900793650793651
# Avg trade length: 2.9292929292929295
# Remaining runs: 268
# Best reward so far: 49.99938214285186
#
# -5062.463150803481
# Num buys: 265
# Num sells: 270
# Num trades: 535
# Num wins: 347
# Num losses: 188
# Win streak: 12
# Loss streak: 5
# Avg pips risked: 0.0009536288384512746
# Avg trade length: 4.314018691588785
# Remaining runs: 267
# Best reward so far: 49.99938214285186
#
# -50.0000453571432
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 4
# Num losses: 2
# Win streak: 2
# Loss streak: 1
# Avg pips risked: 0.0014465476190475741
# Avg trade length: 6.5
# Remaining runs: 266
# Best reward so far: 49.99938214285186
#
# -149.99799696424876
# Num buys: 14
# Num sells: 14
# Num trades: 28
# Num wins: 20
# Num losses: 8
# Win streak: 4
# Loss streak: 2
# Avg pips risked: 0.00165334183673472
# Avg trade length: 3.7142857142857144
# Remaining runs: 265
# Best reward so far: 49.99938214285186
#
# -153.44108357141377
# Num buys: 6
# Num sells: 5
# Num trades: 11
# Num wins: 4
# Num losses: 7
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.0017022727272727365
# Avg trade length: 25.727272727272727
# Remaining runs: 264
# Best reward so far: 49.99938214285186
#
# -1424.988010714251
# Num buys: 61
# Num sells: 65
# Num trades: 126
# Num wins: 78
# Num losses: 48
# Win streak: 5
# Loss streak: 5
# Avg pips risked: 0.000878449546485259
# Avg trade length: 1.9841269841269842
# Remaining runs: 263
# Best reward so far: 49.99938214285186
#
# -299.9975744643195
# Num buys: 15
# Num sells: 18
# Num trades: 33
# Num wins: 18
# Num losses: 15
# Win streak: 6
# Loss streak: 5
# Avg pips risked: 0.0017430844155844043
# Avg trade length: 8.93939393939394
# Remaining runs: 262
# Best reward so far: 49.99938214285186
#
# -222.11544285715095
# Num buys: 28
# Num sells: 36
# Num trades: 64
# Num wins: 30
# Num losses: 34
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0016391406250000108
# Avg trade length: 35.578125
# Remaining runs: 261
# Best reward so far: 49.99938214285186
#
# -1155.5565275000376
# Num buys: 31
# Num sells: 38
# Num trades: 69
# Num wins: 23
# Num losses: 46
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0009324896480331474
# Avg trade length: 6.463768115942029
# Remaining runs: 260
# Best reward so far: 49.99938214285186
#
# -124.99656250000876
# Num buys: 8
# Num sells: 7
# Num trades: 15
# Num wins: 10
# Num losses: 5
# Win streak: 3
# Loss streak: 2
# Avg pips risked: 0.0019557619047619362
# Avg trade length: 4.333333333333333
# Remaining runs: 259
# Best reward so far: 49.99938214285186
#
# -2027.6449960714933
# Num buys: 130
# Num sells: 125
# Num trades: 255
# Num wins: 143
# Num losses: 112
# Win streak: 9
# Loss streak: 8
# Avg pips risked: 0.000911411764705891
# Avg trade length: 4.235294117647059
# Remaining runs: 258
# Best reward so far: 49.99938214285186
#
# -478.65926785718466
# Num buys: 98
# Num sells: 97
# Num trades: 195
# Num wins: 124
# Num losses: 71
# Win streak: 12
# Loss streak: 4
# Avg pips risked: 0.001677406593406604
# Avg trade length: 16.620512820512822
# Remaining runs: 257
# Best reward so far: 49.99938214285186
#
# -1934.7603376786608
# Num buys: 206
# Num sells: 215
# Num trades: 421
# Num wins: 255
# Num losses: 166
# Win streak: 9
# Loss streak: 8
# Avg pips risked: 0.0009776102816423525
# Avg trade length: 7.4560570071258905
# Remaining runs: 256
# Best reward so far: 49.99938214285186
#
# -22495.11393785747
# Num buys: 1000
# Num sells: 1020
# Num trades: 2020
# Num wins: 1047
# Num losses: 973
# Win streak: 12
# Loss streak: 7
# Avg pips risked: 0.0006793857850070805
# Avg trade length: 4.157425742574257
# Remaining runs: 255
# Best reward so far: 49.99938214285186
#
# -3932.1039364284666
# Num buys: 213
# Num sells: 199
# Num trades: 412
# Num wins: 167
# Num losses: 245
# Win streak: 6
# Loss streak: 8
# Avg pips risked: 0.0008687135922330171
# Avg trade length: 8.91504854368932
# Remaining runs: 254
# Best reward so far: 49.99938214285186
#
# -1107.2031335713968
# Num buys: 102
# Num sells: 89
# Num trades: 191
# Num wins: 113
# Num losses: 78
# Win streak: 10
# Loss streak: 5
# Avg pips risked: 0.0017507703814510329
# Avg trade length: 20.670157068062828
# Remaining runs: 253
# Best reward so far: 49.99938214285186
#
# -49.99915303571061
# Num buys: 1
# Num sells: 3
# Num trades: 4
# Num wins: 2
# Num losses: 2
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0016180357142857593
# Avg trade length: 2.75
# Remaining runs: 252
# Best reward so far: 49.99938214285186
#
# -824.9945751786503
# Num buys: 63
# Num sells: 61
# Num trades: 124
# Num wins: 86
# Num losses: 38
# Win streak: 10
# Loss streak: 4
# Avg pips risked: 0.0008501267281105927
# Avg trade length: 2.7338709677419355
# Remaining runs: 251
# Best reward so far: 49.99938214285186
#
# -5687.46476375003
# Num buys: 249
# Num sells: 261
# Num trades: 510
# Num wins: 317
# Num losses: 193
# Win streak: 13
# Loss streak: 6
# Avg pips risked: 0.0006843235294117625
# Avg trade length: 2.8176470588235296
# Remaining runs: 250
# Best reward so far: 49.99938214285186
#
# -179.89235821425626
# Num buys: 22
# Num sells: 25
# Num trades: 47
# Num wins: 29
# Num losses: 18
# Win streak: 7
# Loss streak: 3
# Avg pips risked: 0.0016532218844984901
# Avg trade length: 10.319148936170214
# Remaining runs: 249
# Best reward so far: 49.99938214285186
#
# -2049.9849051784977
# Num buys: 84
# Num sells: 98
# Num trades: 182
# Num wins: 94
# Num losses: 88
# Win streak: 7
# Loss streak: 7
# Avg pips risked: 0.0008716424646781748
# Avg trade length: 2.9450549450549453
# Remaining runs: 248
# Best reward so far: 49.99938214285186
#
# -652.1158735713522
# Num buys: 166
# Num sells: 167
# Num trades: 333
# Num wins: 214
# Num losses: 119
# Win streak: 15
# Loss streak: 10
# Avg pips risked: 0.001699420849420865
# Avg trade length: 17.00900900900901
# Remaining runs: 247
# Best reward so far: 49.99938214285186
#
# -224.99695964286053
# Num buys: 8
# Num sells: 7
# Num trades: 15
# Num wins: 7
# Num losses: 8
# Win streak: 3
# Loss streak: 4
# Avg pips risked: 0.0019557619047619362
# Avg trade length: 6.333333333333333
# Remaining runs: 246
# Best reward so far: 49.99938214285186
#
# -5782.819761428652
# Num buys: 249
# Num sells: 261
# Num trades: 510
# Num wins: 263
# Num losses: 247
# Win streak: 9
# Loss streak: 7
# Avg pips risked: 0.0006843235294117625
# Avg trade length: 3.9705882352941178
# Remaining runs: 245
# Best reward so far: 49.99938214285186
#
# -2435.0580978571506
# Num buys: 285
# Num sells: 292
# Num trades: 577
# Num wins: 353
# Num losses: 224
# Win streak: 13
# Loss streak: 6
# Avg pips risked: 0.0011042287694974066
# Avg trade length: 12.001733102253032
# Remaining runs: 244
# Best reward so far: 49.99938214285186
#
# -1211.4018396427332
# Num buys: 180
# Num sells: 185
# Num trades: 365
# Num wins: 273
# Num losses: 92
# Win streak: 17
# Loss streak: 9
# Avg pips risked: 0.0017048727984344564
# Avg trade length: 9.682191780821919
# Remaining runs: 243
# Best reward so far: 49.99938214285186
#
# -4256.040602767877
# Num buys: 180
# Num sells: 155
# Num trades: 335
# Num wins: 200
# Num losses: 135
# Win streak: 11
# Loss streak: 8
# Avg pips risked: 0.000622567164179108
# Avg trade length: 1.955223880597015
# Remaining runs: 242
# Best reward so far: 49.99938214285186
#
# -4413.170031607451
# Num buys: 180
# Num sells: 154
# Num trades: 334
# Num wins: 164
# Num losses: 170
# Win streak: 6
# Loss streak: 8
# Avg pips risked: 0.0006231148417450846
# Avg trade length: 2.8233532934131738
# Remaining runs: 241
# Best reward so far: 49.99938214285186
#
# -128.09088035711932
# Num buys: 14
# Num sells: 14
# Num trades: 28
# Num wins: 17
# Num losses: 11
# Win streak: 3
# Loss streak: 2
# Avg pips risked: 0.00165334183673472
# Avg trade length: 8.678571428571429
# Remaining runs: 240
# Best reward so far: 49.99938214285186
#
# -23317.173612143477
# Num buys: 1064
# Num sells: 1077
# Num trades: 2141
# Num wins: 839
# Num losses: 1302
# Win streak: 10
# Loss streak: 14
# Avg pips risked: 0.000699011142990602
# Avg trade length: 7.677720691265764
# Remaining runs: 239
# Best reward so far: 49.99938214285186
#
# -3348.231695357354
# Num buys: 239
# Num sells: 241
# Num trades: 480
# Num wins: 331
# Num losses: 149
# Win streak: 13
# Loss streak: 5
# Avg pips risked: 0.0007856183035714319
# Avg trade length: 4.495833333333334
# Remaining runs: 238
# Best reward so far: 49.99938214285186
#
# -1865.6734714285772
# Num buys: 182
# Num sells: 186
# Num trades: 368
# Num wins: 167
# Num losses: 201
# Win streak: 11
# Loss streak: 10
# Avg pips risked: 0.0017391498447205203
# Avg trade length: 42.95108695652174
# Remaining runs: 237
# Best reward so far: 49.99938214285186
#
# -11.358444285626405
# Num buys: 124
# Num sells: 118
# Num trades: 242
# Num wins: 122
# Num losses: 120
# Win streak: 9
# Loss streak: 6
# Avg pips risked: 0.001784970484061414
# Avg trade length: 41.52892561983471
# Remaining runs: 236
# Best reward so far: 49.99938214285186
#
# -17249.258197142703
# Num buys: 958
# Num sells: 998
# Num trades: 1956
# Num wins: 813
# Num losses: 1143
# Win streak: 9
# Loss streak: 18
# Avg pips risked: 0.0010128242769500617
# Avg trade length: 22.379345603271982
# Remaining runs: 235
# Best reward so far: 49.99938214285186
#
# -592.135425178541
# Num buys: 82
# Num sells: 84
# Num trades: 166
# Num wins: 103
# Num losses: 63
# Win streak: 9
# Loss streak: 5
# Avg pips risked: 0.0017342125645439116
# Avg trade length: 13.903614457831326
# Remaining runs: 234
# Best reward so far: 49.99938214285186
#
# -799.9970900001346
# Num buys: 62
# Num sells: 48
# Num trades: 110
# Num wins: 47
# Num losses: 63
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0005763831168831057
# Avg trade length: 4.572727272727272
# Remaining runs: 233
# Best reward so far: 49.99938214285186
#
# -4045.812500714281
# Num buys: 231
# Num sells: 236
# Num trades: 467
# Num wins: 194
# Num losses: 273
# Win streak: 10
# Loss streak: 13
# Avg pips risked: 0.0009647124502906152
# Avg trade length: 16.56745182012848
# Remaining runs: 232
# Best reward so far: 49.99938214285186
#
# -11874.990424286241
# Num buys: 501
# Num sells: 498
# Num trades: 999
# Num wins: 508
# Num losses: 491
# Win streak: 8
# Loss streak: 8
# Avg pips risked: 0.0006863570713570785
# Avg trade length: 4.426426426426427
# Remaining runs: 231
# Best reward so far: 49.99938214285186
#
# -12649.704362142831
# Num buys: 875
# Num sells: 871
# Num trades: 1746
# Num wins: 998
# Num losses: 748
# Win streak: 12
# Loss streak: 9
# Avg pips risked: 0.0011107265586647215
# Avg trade length: 12.105383734249713
# Remaining runs: 230
# Best reward so far: 49.99938214285186
#
# -676.1744828572045
# Num buys: 25
# Num sells: 32
# Num trades: 57
# Num wins: 22
# Num losses: 35
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0017927255639097843
# Avg trade length: 34.824561403508774
# Remaining runs: 229
# Best reward so far: 49.99938214285186
#
# -14895.223350535733
# Num buys: 659
# Num sells: 651
# Num trades: 1310
# Num wins: 810
# Num losses: 500
# Win streak: 11
# Loss streak: 8
# Avg pips risked: 0.0007003331515812489
# Avg trade length: 2.9229007633587787
# Remaining runs: 228
# Best reward so far: 49.99938214285186
#
# -7485.192349999884
# Num buys: 484
# Num sells: 477
# Num trades: 961
# Num wins: 541
# Num losses: 420
# Win streak: 12
# Loss streak: 9
# Avg pips risked: 0.0009023294187602296
# Avg trade length: 4.826222684703434
# Remaining runs: 227
# Best reward so far: 49.99938214285186
#
# -1123.1720060713544
# Num buys: 105
# Num sells: 106
# Num trades: 211
# Num wins: 151
# Num losses: 60
# Win streak: 9
# Loss streak: 3
# Avg pips risked: 0.001674881516587687
# Avg trade length: 8.469194312796208
# Remaining runs: 226
# Best reward so far: 49.99938214285186
#
# -19534.249010000272
# Num buys: 863
# Num sells: 883
# Num trades: 1746
# Num wins: 679
# Num losses: 1067
# Win streak: 8
# Loss streak: 19
# Avg pips risked: 0.0006841703485518006
# Avg trade length: 7.491981672394044
# Remaining runs: 225
# Best reward so far: 49.99938214285186
#
# -356.93316196427276
# Num buys: 28
# Num sells: 21
# Num trades: 49
# Num wins: 28
# Num losses: 21
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0018515889212827987
# Avg trade length: 14.326530612244898
# Remaining runs: 224
# Best reward so far: 49.99938214285186
#
# -4524.963626785592
# Num buys: 231
# Num sells: 212
# Num trades: 443
# Num wins: 235
# Num losses: 208
# Win streak: 7
# Loss streak: 6
# Avg pips risked: 0.0008684682360528926
# Avg trade length: 4.562076749435666
# Remaining runs: 223
# Best reward so far: 49.99938214285186
#
# -6897.312681071754
# Num buys: 458
# Num sells: 465
# Num trades: 923
# Num wins: 524
# Num losses: 399
# Win streak: 8
# Loss streak: 8
# Avg pips risked: 0.0008178730072744229
# Avg trade length: 7.3358613217768145
# Remaining runs: 222
# Best reward so far: 49.99938214285186
#
# -15212.406185178856
# Num buys: 677
# Num sells: 696
# Num trades: 1373
# Num wins: 855
# Num losses: 518
# Win streak: 10
# Loss streak: 8
# Avg pips risked: 0.0006632852980959411
# Avg trade length: 2.8922068463219226
# Remaining runs: 221
# Best reward so far: 49.99938214285186
#
# -206.4519135713992
# Num buys: 12
# Num sells: 14
# Num trades: 26
# Num wins: 11
# Num losses: 15
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0016464285714285958
# Avg trade length: 22.307692307692307
# Remaining runs: 220
# Best reward so far: 49.99938214285186
#
# -11421.476671428996
# Num buys: 607
# Num sells: 609
# Num trades: 1216
# Num wins: 499
# Num losses: 717
# Win streak: 7
# Loss streak: 14
# Avg pips risked: 0.0009449847274436264
# Avg trade length: 21.036184210526315
# Remaining runs: 219
# Best reward so far: 49.99938214285186
#
# -1762.4897916964126
# Num buys: 94
# Num sells: 85
# Num trades: 179
# Num wins: 115
# Num losses: 64
# Win streak: 11
# Loss streak: 4
# Avg pips risked: 0.0006041899441340718
# Avg trade length: 1.9162011173184357
# Remaining runs: 218
# Best reward so far: 49.99938214285186
#
# -2424.988041428509
# Num buys: 104
# Num sells: 92
# Num trades: 196
# Num wins: 118
# Num losses: 78
# Win streak: 12
# Loss streak: 6
# Avg pips risked: 0.0006082434402332425
# Avg trade length: 1.9183673469387754
# Remaining runs: 217
# Best reward so far: 49.99938214285186
#
# -10497.672745714623
# Num buys: 737
# Num sells: 708
# Num trades: 1445
# Num wins: 623
# Num losses: 821
# Win streak: 7
# Loss streak: 11
# Avg pips risked: 0.0009944181908057511
# Avg trade length: 22.29639889196676
# Remaining runs: 216
# Best reward so far: 49.99938214285186
#
# -9487.444403750402
# Num buys: 355
# Num sells: 366
# Num trades: 721
# Num wins: 425
# Num losses: 296
# Win streak: 9
# Loss streak: 13
# Avg pips risked: 0.0006030176342381677
# Avg trade length: 1.8280166435506242
# Remaining runs: 215
# Best reward so far: 49.99938214285186
#
# -3609.4075289286343
# Num buys: 163
# Num sells: 161
# Num trades: 324
# Num wins: 168
# Num losses: 156
# Win streak: 10
# Loss streak: 7
# Avg pips risked: 0.0006674845679012275
# Avg trade length: 3.9382716049382718
# Remaining runs: 214
# Best reward so far: 49.99938214285186
#
# -212.4999864285347
# Num buys: 18
# Num sells: 20
# Num trades: 38
# Num wins: 27
# Num losses: 11
# Win streak: 7
# Loss streak: 2
# Avg pips risked: 0.0009003853383458928
# Avg trade length: 1.8157894736842106
# Remaining runs: 213
# Best reward so far: 49.99938214285186
#
# -6487.463228660977
# Num buys: 221
# Num sells: 215
# Num trades: 436
# Num wins: 245
# Num losses: 191
# Win streak: 6
# Loss streak: 13
# Avg pips risked: 0.0005950991153342122
# Avg trade length: 1.798165137614679
# Remaining runs: 212
# Best reward so far: 49.99938214285186
#
# -618.9594428571662
# Num buys: 48
# Num sells: 53
# Num trades: 101
# Num wins: 71
# Num losses: 30
# Win streak: 8
# Loss streak: 2
# Avg pips risked: 0.0009349964639321263
# Avg trade length: 2.3267326732673266
# Remaining runs: 211
# Best reward so far: 49.99938214285186
#
# -17932.158063929022
# Num buys: 1055
# Num sells: 1036
# Num trades: 2091
# Num wins: 1388
# Num losses: 703
# Win streak: 15
# Loss streak: 6
# Avg pips risked: 0.0009582127485140568
# Avg trade length: 7.03921568627451
# Remaining runs: 210
# Best reward so far: 49.99938214285186
#
# -2127.643953392958
# Num buys: 130
# Num sells: 125
# Num trades: 255
# Num wins: 170
# Num losses: 85
# Win streak: 10
# Loss streak: 5
# Avg pips risked: 0.000911411764705891
# Avg trade length: 3.1176470588235294
# Remaining runs: 209
# Best reward so far: 49.99938214285186
#
# -924.9907857142675
# Num buys: 31
# Num sells: 37
# Num trades: 68
# Num wins: 33
# Num losses: 35
# Win streak: 5
# Loss streak: 5
# Avg pips risked: 0.0008706460084033543
# Avg trade length: 3.0588235294117645
# Remaining runs: 208
# Best reward so far: 49.99938214285186
#
# -8262.06209178608
# Num buys: 547
# Num sells: 560
# Num trades: 1107
# Num wins: 755
# Num losses: 352
# Win streak: 14
# Loss streak: 9
# Avg pips risked: 0.0009472112530649226
# Avg trade length: 6.5483288166215
# Remaining runs: 207
# Best reward so far: 49.99938214285186
#
# -5773.779436517889
# Num buys: 244
# Num sells: 215
# Num trades: 459
# Num wins: 275
# Num losses: 184
# Win streak: 9
# Loss streak: 6
# Avg pips risked: 0.0006300669156551552
# Avg trade length: 2.0043572984749454
# Remaining runs: 206
# Best reward so far: 49.99938214285186
#
# -610.2925578571748
# Num buys: 61
# Num sells: 61
# Num trades: 122
# Num wins: 55
# Num losses: 67
# Win streak: 8
# Loss streak: 8
# Avg pips risked: 0.0008511299765807904
# Avg trade length: 10.540983606557377
# Remaining runs: 205
# Best reward so far: 49.99938214285186
#
# -598.2088562500081
# Num buys: 45
# Num sells: 53
# Num trades: 98
# Num wins: 69
# Num losses: 29
# Win streak: 9
# Loss streak: 3
# Avg pips risked: 0.001837044460641409
# Avg trade length: 7.948979591836735
# Remaining runs: 204
# Best reward so far: 49.99938214285186
#
# -200.5742628570874
# Num buys: 55
# Num sells: 52
# Num trades: 107
# Num wins: 52
# Num losses: 55
# Win streak: 6
# Loss streak: 6
# Avg pips risked: 0.001696635514018725
# Avg trade length: 42.76635514018692
# Remaining runs: 203
# Best reward so far: 49.99938214285186
#
# -258.3879592857337
# Num buys: 31
# Num sells: 28
# Num trades: 59
# Num wins: 36
# Num losses: 23
# Win streak: 6
# Loss streak: 4
# Avg pips risked: 0.0016779903147699702
# Avg trade length: 16.76271186440678
# Remaining runs: 202
# Best reward so far: 49.99938214285186
#
# -757.242495357234
# Num buys: 193
# Num sells: 209
# Num trades: 402
# Num wins: 194
# Num losses: 208
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0009820628997867862
# Avg trade length: 15.25870646766169
# Remaining runs: 201
# Best reward so far: 49.99938214285186
#
# -439.937796428565
# Num buys: 28
# Num sells: 22
# Num trades: 50
# Num wins: 33
# Num losses: 17
# Win streak: 6
# Loss streak: 3
# Avg pips risked: 0.001844435714285715
# Avg trade length: 6.04
# Remaining runs: 200
# Best reward so far: 49.99938214285186
#
# -4812.36618285718
# Num buys: 370
# Num sells: 391
# Num trades: 761
# Num wins: 334
# Num losses: 427
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0009607931293411012
# Avg trade length: 15.981603153745072
# Remaining runs: 199
# Best reward so far: 49.99938214285186
#
# -1481.322479285941
# Num buys: 132
# Num sells: 130
# Num trades: 262
# Num wins: 155
# Num losses: 107
# Win streak: 9
# Loss streak: 7
# Avg pips risked: 0.0009563154307524535
# Avg trade length: 7.400763358778626
# Remaining runs: 198
# Best reward so far: 49.99938214285186
#
# -350.70232428572
# Num buys: 47
# Num sells: 51
# Num trades: 98
# Num wins: 46
# Num losses: 52
# Win streak: 6
# Loss streak: 4
# Avg pips risked: 0.0017768658892128432
# Avg trade length: 42.98979591836735
# Remaining runs: 197
# Best reward so far: 49.99938214285186
#
# -3319.3186114285663
# Num buys: 160
# Num sells: 160
# Num trades: 320
# Num wins: 127
# Num losses: 193
# Win streak: 7
# Loss streak: 11
# Avg pips risked: 0.0006672968749999924
# Avg trade length: 8.028125
# Remaining runs: 196
# Best reward so far: 49.99938214285186
#
# -49.999534285718696
# Num buys: 4
# Num sells: 7
# Num trades: 11
# Num wins: 5
# Num losses: 6
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.001762792207792236
# Avg trade length: 11.454545454545455
# Remaining runs: 195
# Best reward so far: 49.99938214285186
#
# -1574.9890714286187
# Num buys: 95
# Num sells: 103
# Num trades: 198
# Num wins: 111
# Num losses: 87
# Win streak: 10
# Loss streak: 6
# Avg pips risked: 0.0008900793650793651
# Avg trade length: 4.055555555555555
# Remaining runs: 194
# Best reward so far: 49.99938214285186
#
# -14090.402233929099
# Num buys: 614
# Num sells: 589
# Num trades: 1203
# Num wins: 463
# Num losses: 740
# Win streak: 7
# Loss streak: 15
# Avg pips risked: 0.0008164359933499731
# Avg trade length: 13.965918536990856
# Remaining runs: 193
# Best reward so far: 49.99938214285186
#
# -28766.70752142886
# Num buys: 1483
# Num sells: 1532
# Num trades: 3015
# Num wins: 1629
# Num losses: 1386
# Win streak: 14
# Loss streak: 11
# Avg pips risked: 0.0008334380478559712
# Avg trade length: 7.258374792703151
# Remaining runs: 192
# Best reward so far: 49.99938214285186
#
# -5276.5861649107665
# Num buys: 357
# Num sells: 389
# Num trades: 746
# Num wins: 513
# Num losses: 233
# Win streak: 17
# Loss streak: 4
# Avg pips risked: 0.0008035283416315673
# Avg trade length: 4.64343163538874
# Remaining runs: 191
# Best reward so far: 49.99938214285186
#
# -15799.665829821864
# Num buys: 833
# Num sells: 822
# Num trades: 1655
# Num wins: 894
# Num losses: 761
# Win streak: 12
# Loss streak: 9
# Avg pips risked: 0.000799922097539935
# Avg trade length: 7.227190332326284
# Remaining runs: 190
# Best reward so far: 49.99938214285186
#
# -16289.466490714252
# Num buys: 1017
# Num sells: 1063
# Num trades: 2080
# Num wins: 1404
# Num losses: 676
# Win streak: 20
# Loss streak: 6
# Avg pips risked: 0.0009902242445055092
# Avg trade length: 4.602884615384616
# Remaining runs: 189
# Best reward so far: 49.99938214285186
#
# -33680.92458330351
# Num buys: 1728
# Num sells: 1757
# Num trades: 3485
# Num wins: 2251
# Num losses: 1234
# Win streak: 16
# Loss streak: 7
# Avg pips risked: 0.0008261093461775079
# Avg trade length: 4.62467718794835
# Remaining runs: 188
# Best reward so far: 49.99938214285186
#
# -1413.0994685714404
# Num buys: 93
# Num sells: 103
# Num trades: 196
# Num wins: 84
# Num losses: 112
# Win streak: 10
# Loss streak: 9
# Avg pips risked: 0.0008911115160349857
# Avg trade length: 9.760204081632653
# Remaining runs: 187
# Best reward so far: 49.99938214285186
#
# -1119.3715892856708
# Num buys: 138
# Num sells: 128
# Num trades: 266
# Num wins: 163
# Num losses: 103
# Win streak: 11
# Loss streak: 5
# Avg pips risked: 0.0017836895810956154
# Avg trade length: 21.218045112781954
# Remaining runs: 186
# Best reward so far: 49.99938214285186
#
# -1205.30757857142
# Num buys: 145
# Num sells: 135
# Num trades: 280
# Num wins: 205
# Num losses: 75
# Win streak: 10
# Loss streak: 5
# Avg pips risked: 0.0017836275510204273
# Avg trade length: 10.67142857142857
# Remaining runs: 185
# Best reward so far: 49.99938214285186
#
# -20986.17170107122
# Num buys: 1123
# Num sells: 1145
# Num trades: 2268
# Num wins: 929
# Num losses: 1339
# Win streak: 9
# Loss streak: 16
# Avg pips risked: 0.0008444885361552144
# Avg trade length: 13.926807760141093
# Remaining runs: 184
# Best reward so far: 49.99938214285186
#
# -9317.616802857414
# Num buys: 458
# Num sells: 451
# Num trades: 909
# Num wins: 365
# Num losses: 544
# Win streak: 7
# Loss streak: 11
# Avg pips risked: 0.0009726465503693336
# Avg trade length: 23.062706270627064
# Remaining runs: 183
# Best reward so far: 49.99938214285186
#
# -18158.636160714235
# Num buys: 940
# Num sells: 941
# Num trades: 1881
# Num wins: 763
# Num losses: 1118
# Win streak: 7
# Loss streak: 21
# Avg pips risked: 0.00082244171033646
# Avg trade length: 13.891547049441787
# Remaining runs: 182
# Best reward so far: 49.99938214285186
#
# -12541.679227143219
# Num buys: 571
# Num sells: 576
# Num trades: 1147
# Num wins: 449
# Num losses: 698
# Win streak: 8
# Loss streak: 14
# Avg pips risked: 0.000667753144849927
# Avg trade length: 7.596338273757628
# Remaining runs: 181
# Best reward so far: 49.99938214285186
#
# -6915.180716250226
# Num buys: 474
# Num sells: 490
# Num trades: 964
# Num wins: 551
# Num losses: 413
# Win streak: 10
# Loss streak: 7
# Avg pips risked: 0.0009553297273266283
# Avg trade length: 7.568464730290456
# Remaining runs: 180
# Best reward so far: 49.99938214285186
#
# -8000.432420000715
# Num buys: 309
# Num sells: 304
# Num trades: 613
# Num wins: 227
# Num losses: 386
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.0006745746912141779
# Avg trade length: 8.479608482871125
# Remaining runs: 179
# Best reward so far: 49.99938214285186
#
# -584.1798214285749
# Num buys: 52
# Num sells: 53
# Num trades: 105
# Num wins: 47
# Num losses: 58
# Win streak: 5
# Loss streak: 7
# Avg pips risked: 0.0016799625850340333
# Avg trade length: 31.466666666666665
# Remaining runs: 178
# Best reward so far: 49.99938214285186
#
# -6953.947393393104
# Num buys: 326
# Num sells: 323
# Num trades: 649
# Num wins: 408
# Num losses: 241
# Win streak: 15
# Loss streak: 6
# Avg pips risked: 0.0006967697556680622
# Avg trade length: 2.8505392912172574
# Remaining runs: 177
# Best reward so far: 49.99938214285186
#
# -2406.2239293749926
# Num buys: 127
# Num sells: 106
# Num trades: 233
# Num wins: 148
# Num losses: 85
# Win streak: 7
# Loss streak: 4
# Avg pips risked: 0.0006218408951563409
# Avg trade length: 2.0472103004291844
# Remaining runs: 176
# Best reward so far: 49.99938214285186
#
# -7601.75482946435
# Num buys: 400
# Num sells: 408
# Num trades: 808
# Num wins: 438
# Num losses: 370
# Win streak: 10
# Loss streak: 8
# Avg pips risked: 0.0009787084512022728
# Avg trade length: 8.248762376237623
# Remaining runs: 175
# Best reward so far: 49.99938214285186
#
# -27421.87139571442
# Num buys: 1502
# Num sells: 1540
# Num trades: 3042
# Num wins: 1999
# Num losses: 1043
# Win streak: 16
# Loss streak: 10
# Avg pips risked: 0.0009465530196299573
# Avg trade length: 7.02827087442472
# Remaining runs: 174
# Best reward so far: 49.99938214285186
#
# -99.9971948214453
# Num buys: 10
# Num sells: 12
# Num trades: 22
# Num wins: 16
# Num losses: 6
# Win streak: 5
# Loss streak: 2
# Avg pips risked: 0.001729383116883118
# Avg trade length: 2.5454545454545454
# Remaining runs: 173
# Best reward so far: 49.99938214285186
#
# -3485.138677142857
# Num buys: 369
# Num sells: 350
# Num trades: 719
# Num wins: 434
# Num losses: 285
# Win streak: 13
# Loss streak: 7
# Avg pips risked: 0.0011231154381084907
# Avg trade length: 11.98191933240612
# Remaining runs: 172
# Best reward so far: 49.99938214285186
#
# -111.83765571428695
# Num buys: 18
# Num sells: 18
# Num trades: 36
# Num wins: 17
# Num losses: 19
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.0017602480158730265
# Avg trade length: 25.77777777777778
# Remaining runs: 171
# Best reward so far: 49.99938214285186
#
# -9471.154397857124
# Num buys: 731
# Num sells: 736
# Num trades: 1467
# Num wins: 1023
# Num losses: 444
# Win streak: 16
# Loss streak: 5
# Avg pips risked: 0.0011163940013633432
# Avg trade length: 7.189502385821404
# Remaining runs: 170
# Best reward so far: 49.99938214285186
#
# -9589.307198928269
# Num buys: 562
# Num sells: 599
# Num trades: 1161
# Num wins: 487
# Num losses: 674
# Win streak: 10
# Loss streak: 14
# Avg pips risked: 0.000978425618309351
# Avg trade length: 15.691645133505599
# Remaining runs: 169
# Best reward so far: 49.99938214285186
#
# -437.04030285702714
# Num buys: 95
# Num sells: 82
# Num trades: 177
# Num wins: 85
# Num losses: 92
# Win streak: 5
# Loss streak: 5
# Avg pips risked: 0.001742187247780497
# Avg trade length: 40.40677966101695
# Remaining runs: 168
# Best reward so far: 49.99938214285186
#
# -587.4945212500011
# Num buys: 31
# Num sells: 37
# Num trades: 68
# Num wins: 45
# Num losses: 23
# Win streak: 8
# Loss streak: 5
# Avg pips risked: 0.0008706460084033543
# Avg trade length: 1.8529411764705883
# Remaining runs: 167
# Best reward so far: 49.99938214285186
#
# -9637.002001428857
# Num buys: 614
# Num sells: 582
# Num trades: 1196
# Num wins: 506
# Num losses: 689
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0009703953655040807
# Avg trade length: 21.88870292887029
# Remaining runs: 166
# Best reward so far: 49.99938214285186
#
# -5569.888023571225
# Num buys: 335
# Num sells: 341
# Num trades: 676
# Num wins: 283
# Num losses: 393
# Win streak: 7
# Loss streak: 10
# Avg pips risked: 0.0008833844040574911
# Avg trade length: 9.195266272189349
# Remaining runs: 165
# Best reward so far: 49.99938214285186
#
# -649.995505714374
# Num buys: 63
# Num sells: 61
# Num trades: 124
# Num wins: 74
# Num losses: 50
# Win streak: 10
# Loss streak: 4
# Avg pips risked: 0.0008501267281105927
# Avg trade length: 4.0
# Remaining runs: 164
# Best reward so far: 49.99938214285186
#
# -99.99945357143014
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 1
# Num losses: 3
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.001821428571428585
# Avg trade length: 7.25
# Remaining runs: 163
# Best reward so far: 49.99938214285186
#
# -6533.671721606881
# Num buys: 219
# Num sells: 213
# Num trades: 432
# Num wins: 201
# Num losses: 231
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0005949421296296332
# Avg trade length: 2.736111111111111
# Remaining runs: 162
# Best reward so far: 49.99938214285186
#
# -5114.177802857368
# Num buys: 360
# Num sells: 349
# Num trades: 709
# Num wins: 405
# Num losses: 304
# Win streak: 13
# Loss streak: 7
# Avg pips risked: 0.0010782389683659291
# Avg trade length: 12.688293370944994
# Remaining runs: 161
# Best reward so far: 49.99938214285186
#
# -10494.672498124999
# Num buys: 500
# Num sells: 478
# Num trades: 978
# Num wins: 615
# Num losses: 363
# Win streak: 11
# Loss streak: 5
# Avg pips risked: 0.000782237803096713
# Avg trade length: 4.502044989775051
# Remaining runs: 160
# Best reward so far: 49.99938214285186
#
# -13404.560818214204
# Num buys: 892
# Num sells: 951
# Num trades: 1843
# Num wins: 1051
# Num losses: 792
# Win streak: 14
# Loss streak: 11
# Avg pips risked: 0.0009950038756685667
# Avg trade length: 7.552902875746066
# Remaining runs: 159
# Best reward so far: 49.99938214285186
#
# -1449.988326071611
# Num buys: 133
# Num sells: 131
# Num trades: 264
# Num wins: 188
# Num losses: 76
# Win streak: 18
# Loss streak: 4
# Avg pips risked: 0.0009550906385281397
# Avg trade length: 4.231060606060606
# Remaining runs: 158
# Best reward so far: 49.99938214285186
#
# -132.69583428572835
# Num buys: 30
# Num sells: 26
# Num trades: 56
# Num wins: 27
# Num losses: 29
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.001688188775510199
# Avg trade length: 50.05357142857143
# Remaining runs: 157
# Best reward so far: 49.99938214285186
#
# -18828.96396767892
# Num buys: 936
# Num sells: 937
# Num trades: 1873
# Num wins: 1198
# Num losses: 675
# Win streak: 19
# Loss streak: 6
# Avg pips risked: 0.0007929955762337102
# Avg trade length: 4.630005339028297
# Remaining runs: 156
# Best reward so far: 49.99938214285186
#
# -74.99858392855896
# Num buys: 31
# Num sells: 28
# Num trades: 59
# Num wins: 46
# Num losses: 13
# Win streak: 12
# Loss streak: 3
# Avg pips risked: 0.0016779903147699702
# Avg trade length: 6.135593220338983
# Remaining runs: 155
# Best reward so far: 49.99938214285186
#
# -7495.400654286228
# Num buys: 327
# Num sells: 319
# Num trades: 646
# Num wins: 397
# Num losses: 249
# Win streak: 14
# Loss streak: 6
# Avg pips risked: 0.0006700608137992124
# Avg trade length: 2.869969040247678
# Remaining runs: 154
# Best reward so far: 49.99938214285186
#
# -1649.9858760715263
# Num buys: 119
# Num sells: 100
# Num trades: 219
# Num wins: 124
# Num losses: 95
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0008849151989563053
# Avg trade length: 4.6118721461187215
# Remaining runs: 153
# Best reward so far: 49.99938214285186
#
# -24.999841517862894
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 2
# Num losses: 1
# Win streak: 2
# Loss streak: 1
# Avg pips risked: 0.0016546428571428962
# Avg trade length: 2.0
# Remaining runs: 152
# Best reward so far: 49.99938214285186
#
# -174.99825535714842
# Num buys: 4
# Num sells: 7
# Num trades: 11
# Num wins: 5
# Num losses: 6
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.001762792207792236
# Avg trade length: 7.7272727272727275
# Remaining runs: 151
# Best reward so far: 49.99938214285186
#
# -319.71946142854887
# Num buys: 20
# Num sells: 24
# Num trades: 44
# Num wins: 19
# Num losses: 25
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.001656266233766241
# Avg trade length: 30.636363636363637
# Remaining runs: 150
# Best reward so far: 49.99938214285186
#
# -15223.95673669646
# Num buys: 744
# Num sells: 728
# Num trades: 1472
# Num wins: 935
# Num losses: 537
# Win streak: 13
# Loss streak: 5
# Avg pips risked: 0.0008040882181677164
# Avg trade length: 4.787364130434782
# Remaining runs: 149
# Best reward so far: 49.99938214285186
#
# -74.99784750000507
# Num buys: 0
# Num sells: 3
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.0017734523809523524
# Avg trade length: 14.666666666666666
# Remaining runs: 148
# Best reward so far: 49.99938214285186
#
# -11769.08715178579
# Num buys: 636
# Num sells: 649
# Num trades: 1285
# Num wins: 528
# Num losses: 757
# Win streak: 7
# Loss streak: 13
# Avg pips risked: 0.0008033001667593202
# Avg trade length: 14.011673151750973
# Remaining runs: 147
# Best reward so far: 49.99938214285186
#
# -7705.192081785706
# Num buys: 578
# Num sells: 588
# Num trades: 1166
# Num wins: 810
# Num losses: 356
# Win streak: 13
# Loss streak: 5
# Avg pips risked: 0.0010919345748591225
# Avg trade length: 7.021440823327616
# Remaining runs: 146
# Best reward so far: 49.99938214285186
#
# -1654.1433885714328
# Num buys: 196
# Num sells: 181
# Num trades: 377
# Num wins: 230
# Num losses: 147
# Win streak: 14
# Loss streak: 8
# Avg pips risked: 0.0010744713906782847
# Avg trade length: 12.416445623342176
# Remaining runs: 145
# Best reward so far: 49.99938214285186
#
# -21651.009842856878
# Num buys: 1216
# Num sells: 1219
# Num trades: 2435
# Num wins: 1340
# Num losses: 1095
# Win streak: 14
# Loss streak: 10
# Avg pips risked: 0.0009611240833089054
# Avg trade length: 11.727720739219713
# Remaining runs: 144
# Best reward so far: 49.99938214285186
#
# -317.59048857147235
# Num buys: 15
# Num sells: 17
# Num trades: 32
# Num wins: 13
# Num losses: 19
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0017565513392857057
# Avg trade length: 36.84375
# Remaining runs: 143
# Best reward so far: 49.99938214285186
#
# -3248.786502500036
# Num buys: 264
# Num sells: 237
# Num trades: 501
# Num wins: 291
# Num losses: 210
# Win streak: 13
# Loss streak: 9
# Avg pips risked: 0.0009230667236954693
# Avg trade length: 5.235528942115768
# Remaining runs: 142
# Best reward so far: 49.99938214285186
#
# -6660.218710000128
# Num buys: 422
# Num sells: 439
# Num trades: 861
# Num wins: 487
# Num losses: 374
# Win streak: 13
# Loss streak: 8
# Avg pips risked: 0.000935420607267305
# Avg trade length: 11.364692218350754
# Remaining runs: 141
# Best reward so far: 49.99938214285186
#
# -10514.095668571481
# Num buys: 439
# Num sells: 459
# Num trades: 898
# Num wins: 344
# Num losses: 554
# Win streak: 7
# Loss streak: 13
# Avg pips risked: 0.0006114249920458198
# Avg trade length: 4.0690423162583516
# Remaining runs: 140
# Best reward so far: 49.99938214285186
#
# -24.99983392857589
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 13
# Num losses: 7
# Win streak: 5
# Loss streak: 3
# Avg pips risked: 0.001588999999999985
# Avg trade length: 8.15
# Remaining runs: 139
# Best reward so far: 49.99938214285186
#
# -1549.9887212499823
# Num buys: 121
# Num sells: 100
# Num trades: 221
# Num wins: 152
# Num losses: 69
# Win streak: 12
# Loss streak: 6
# Avg pips risked: 0.0008843503555268361
# Avg trade length: 2.828054298642534
# Remaining runs: 138
# Best reward so far: 49.99938214285186
#
# -49.99866964285519
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Avg pips risked: 0.0017303571428570752
# Avg trade length: 5.0
# Remaining runs: 137
# Best reward so far: 49.99938214285186
#
# -489.4269957142849
# Num buys: 71
# Num sells: 65
# Num trades: 136
# Num wins: 101
# Num losses: 35
# Win streak: 9
# Loss streak: 3
# Avg pips risked: 0.001805451680672287
# Avg trade length: 7.213235294117647
# Remaining runs: 136
# Best reward so far: 49.99938214285186
#
# -11772.263355356927
# Num buys: 695
# Num sells: 735
# Num trades: 1430
# Num wins: 600
# Num losses: 830
# Win streak: 7
# Loss streak: 16
# ...
# Best reward so far: 49.99938214285186
#
# -5498.91700124999
# Num buys: 257
# Num sells: 265
# Num trades: 522
# Num wins: 275
# Num losses: 247
# Win streak: 11
# Loss streak: 6
# Avg pips risked: 0.0009559386973180142
# Avg trade length: 8.019157088122606
# Remaining runs: 62
# Best reward so far: 49.99938214285186
#
# -5461.1656442858475
# Num buys: 443
# Num sells: 421
# Num trades: 864
# Num wins: 380
# Num losses: 483
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.0011177083333333518
# Avg trade length: 24.69640787949015
# Remaining runs: 61
# Best reward so far: 49.99938214285186
#
# -937.4955774999354
# Num buys: 62
# Num sells: 48
# Num trades: 110
# Num wins: 73
# Num losses: 37
# Win streak: 9
# Loss streak: 3
# Avg pips risked: 0.0005763831168831057
# Avg trade length: 1.981818181818182
# Remaining runs: 60
# Best reward so far: 49.99938214285186
#
# -6962.524860000177
# Num buys: 526
# Num sells: 537
# Num trades: 1063
# Num wins: 617
# Num losses: 446
# Win streak: 12
# Loss streak: 7
# Avg pips risked: 0.0011042843703803456
# Avg trade length: 12.5964252116651
# Remaining runs: 59
# Best reward so far: 49.99938214285186
#
# -2399.988825893003
# Num buys: 104
# Num sells: 91
# Num trades: 195
# Num wins: 98
# Num losses: 97
# Win streak: 10
# Loss streak: 6
# Avg pips risked: 0.0006091080586080646
# Avg trade length: 2.4307692307692306
# Remaining runs: 58
# Best reward so far: 49.99938214285186
#
# -15800.325725000093
# Num buys: 1061
# Num sells: 1077
# Num trades: 2138
# Num wins: 1459
# Num losses: 679
# Win streak: 21
# Loss streak: 9
# Avg pips risked: 0.0010980896699184968
# Avg trade length: 6.930776426566885
# Remaining runs: 57
# Best reward so far: 49.99938214285186
#
# -1370.9122689286203
# Num buys: 197
# Num sells: 185
# Num trades: 382
# Num wins: 284
# Num losses: 98
# Win streak: 16
# Loss streak: 4
# Avg pips risked: 0.001073148840688106
# Avg trade length: 6.0837696335078535
# Remaining runs: 56
# Best reward so far: 49.99938214285186
#
# -149.9993431249877
# Num buys: 9
# Num sells: 9
# Num trades: 18
# Num wins: 12
# Num losses: 6
# Win streak: 6
# Loss streak: 2
# Avg pips risked: 0.0008578968253968064
# Avg trade length: 3.2222222222222223
# Remaining runs: 55
# Best reward so far: 49.99938214285186
#
# -257.2425778571443
# Num buys: 9
# Num sells: 12
# Num trades: 21
# Num wins: 8
# Num losses: 13
# Win streak: 3
# Loss streak: 4
# Avg pips risked: 0.0017343537414966001
# Avg trade length: 23.857142857142858
# Remaining runs: 54
# Best reward so far: 49.99938214285186
#
# -468.9024872321537
# Num buys: 57
# Num sells: 61
# Num trades: 118
# Num wins: 87
# Num losses: 31
# Win streak: 11
# Loss streak: 3
# Avg pips risked: 0.0016904903147699993
# Avg trade length: 7.177966101694915
# Remaining runs: 53
# Best reward so far: 49.99938214285186
#
# -7684.884155357794
# Num buys: 322
# Num sells: 316
# Num trades: 638
# Num wins: 323
# Num losses: 315
# Win streak: 8
# Loss streak: 6
# Avg pips risked: 0.0006710132109270125
# Avg trade length: 4.315047021943574
# Remaining runs: 52
# Best reward so far: 49.99938214285186
#
# -15571.696046428673
# Num buys: 1030
# Num sells: 1060
# Num trades: 2090
# Num wins: 1189
# Num losses: 901
# Win streak: 15
# Loss streak: 9
# Avg pips risked: 0.001137002734108016
# Avg trade length: 12.735885167464115
# Remaining runs: 51
# Best reward so far: 49.99938214285186
#
# -4788.33873500017
# Num buys: 353
# Num sells: 384
# Num trades: 737
# Num wins: 428
# Num losses: 309
# Win streak: 10
# Loss streak: 8
# Avg pips risked: 0.0008050470052335801
# Avg trade length: 7.255088195386703
# Remaining runs: 50
# Best reward so far: 49.99938214285186
#
# -6833.900336785904
# Num buys: 326
# Num sells: 322
# Num trades: 648
# Num wins: 341
# Num losses: 307
# Win streak: 11
# Loss streak: 8
# Avg pips risked: 0.0006970976631393312
# Avg trade length: 3.9753086419753085
# Remaining runs: 49
# Best reward so far: 49.99938214285186
#
# -744.5499550001081
# Num buys: 126
# Num sells: 126
# Num trades: 252
# Num wins: 119
# Num losses: 133
# Win streak: 9
# Loss streak: 8
# Avg pips risked: 0.0009564767573696148
# Avg trade length: 15.527777777777779
# Remaining runs: 48
# Best reward so far: 49.99938214285186
#
# -4219.013348928806
# Num buys: 295
# Num sells: 293
# Num trades: 588
# Num wins: 404
# Num losses: 184
# Win streak: 12
# Loss streak: 5
# Avg pips risked: 0.000903000485908656
# Avg trade length: 6.329931972789115
# Remaining runs: 47
# Best reward so far: 49.99938214285186
#
# -5780.546910714375
# Num buys: 320
# Num sells: 317
# Num trades: 637
# Num wins: 261
# Num losses: 376
# Win streak: 8
# Loss streak: 15
# Avg pips risked: 0.0006979905808477255
# Avg trade length: 7.750392464678179
# Remaining runs: 46
# Best reward so far: 49.99938214285186
#
# -786.1652521429114
# Num buys: 40
# Num sells: 47
# Num trades: 87
# Num wins: 36
# Num losses: 51
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0018517036124794893
# Avg trade length: 34.05747126436781
# Remaining runs: 45
# Best reward so far: 49.99938214285186
#
# -19709.820503928695
# Num buys: 1280
# Num sells: 1323
# Num trades: 2603
# Num wins: 1769
# Num losses: 834
# Win streak: 18
# Loss streak: 7
# Avg pips risked: 0.001122387904066752
# Avg trade length: 7.251632731463696
# Remaining runs: 44
# Best reward so far: 49.99938214285186
#
# -12.50013857143012
# Num buys: 1
# Num sells: 3
# Num trades: 4
# Num wins: 3
# Num losses: 1
# Win streak: 3
# Loss streak: 1
# Avg pips risked: 0.0016180357142857593
# Avg trade length: 1.75
# Remaining runs: 43
# Best reward so far: 49.99938214285186
#
# -178.09291035715367
# Num buys: 16
# Num sells: 16
# Num trades: 32
# Num wins: 19
# Num losses: 13
# Win streak: 6
# Loss streak: 5
# Avg pips risked: 0.0017679687500000013
# Avg trade length: 7.46875
# Remaining runs: 42
# Best reward so far: 49.99938214285186
#
# -13370.377492857835
# Num buys: 769
# Num sells: 757
# Num trades: 1526
# Num wins: 842
# Num losses: 684
# Win streak: 15
# Loss streak: 11
# Avg pips risked: 0.0009479105036510223
# Avg trade length: 11.825032765399738
# Remaining runs: 41
# Best reward so far: 49.99938214285186
#
# 37.49923017856882
# Num buys: 0
# Num sells: 3
# Num trades: 3
# Num wins: 3
# Num losses: 0
# Win streak: 3
# Loss streak: 0
# Avg pips risked: 0.0017734523809523524
# Avg trade length: 10.333333333333334
# Remaining runs: 40
# Best reward so far: 49.99938214285186
#
# -960.9437389286103
# Num buys: 48
# Num sells: 53
# Num trades: 101
# Num wins: 41
# Num losses: 60
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0009349964639321263
# Avg trade length: 6.267326732673268
# Remaining runs: 39
# Best reward so far: 49.99938214285186
#
# -124.99788312500517
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 14
# Num losses: 6
# Win streak: 5
# Loss streak: 2
# Avg pips risked: 0.001588999999999985
# Avg trade length: 5.6
# Remaining runs: 38
# Best reward so far: 49.99938214285186
#
# 12.499699821429772
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 1
# Num losses: 0
# Win streak: 1
# Loss streak: 0
# Avg pips risked: 0.001835357142857097
# Avg trade length: 1.0
# Remaining runs: 37
# Best reward so far: 49.99938214285186
#
# -2662.4728183930374
# Num buys: 273
# Num sells: 260
# Num trades: 533
# Num wins: 320
# Num losses: 213
# Win streak: 8
# Loss streak: 8
# Avg pips risked: 0.0009953584829804382
# Avg trade length: 7.7636022514071295
# Remaining runs: 36
# Best reward so far: 49.99938214285186
#
# -1047.4554653571545
# Num buys: 106
# Num sells: 96
# Num trades: 202
# Num wins: 145
# Num losses: 57
# Win streak: 11
# Loss streak: 4
# Avg pips risked: 0.0017418811881188352
# Avg trade length: 9.792079207920793
# Remaining runs: 35
# Best reward so far: 49.99938214285186
#
# -535.2036414286061
# Num buys: 48
# Num sells: 54
# Num trades: 102
# Num wins: 61
# Num losses: 41
# Win streak: 8
# Loss streak: 4
# Avg pips risked: 0.001766778711484608
# Avg trade length: 16.54901960784314
# Remaining runs: 34
# Best reward so far: 49.99938214285186
#
# -11849.929593571966
# Num buys: 452
# Num sells: 475
# Num trades: 927
# Num wins: 552
# Num losses: 375
# Win streak: 12
# Loss streak: 7
# Avg pips risked: 0.0006120241947911895
# Avg trade length: 1.8187702265372168
# Remaining runs: 33
# Best reward so far: 49.99938214285186
#
# -3699.9799158928945
# Num buys: 163
# Num sells: 161
# Num trades: 324
# Num wins: 200
# Num losses: 124
# Win streak: 11
# Loss streak: 5
# Avg pips risked: 0.0006674845679012275
# Avg trade length: 2.669753086419753
# Remaining runs: 32
# Best reward so far: 49.99938214285186
#
# -49.99866964285519
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Avg pips risked: 0.0017303571428570752
# Avg trade length: 5.0
# Remaining runs: 31
# Best reward so far: 49.99938214285186
#
# -0.000879285739728175
# Num buys: 9
# Num sells: 9
# Num trades: 18
# Num wins: 9
# Num losses: 9
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.0008578968253968064
# Avg trade length: 7.444444444444445
# Remaining runs: 30
# Best reward so far: 49.99938214285186
#
# -199.9950885714343
# Num buys: 1
# Num sells: 3
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Avg pips risked: 0.0016180357142857593
# Avg trade length: 8.25
# Remaining runs: 29
# Best reward so far: 49.99938214285186
#
# 49.998740892852474
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 4
# Num losses: 0
# Win streak: 4
# Loss streak: 0
# Avg pips risked: 0.001821428571428585
# Avg trade length: 1.25
# Remaining runs: 28
# Best reward so far: 49.99938214285186
#
# 99.99855428571456
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 4
# Num losses: 2
# Win streak: 2
# Loss streak: 1
# Avg pips risked: 0.0014465476190475741
# Avg trade length: 15.0
# Remaining runs: 27
# Best reward so far: 99.99855428571456
#
# -33358.67275714297
# Num buys: 1788
# Num sells: 1853
# Num trades: 3641
# Num wins: 2384
# Num losses: 1257
# Win streak: 17
# Loss streak: 7
# Avg pips risked: 0.0009701196688508013
# Avg trade length: 7.159846196099973
# Remaining runs: 26
# Best reward so far: 99.99855428571456
#
# -10296.69189946472
# Num buys: 479
# Num sells: 459
# Num trades: 938
# Num wins: 489
# Num losses: 449
# Win streak: 9
# Loss streak: 9
# Avg pips risked: 0.0007873994821809466
# Avg trade length: 7.6716417910447765
# Remaining runs: 25
# Best reward so far: 99.99855428571456
#
# -574.9935505357818
# Num buys: 16
# Num sells: 21
# Num trades: 37
# Num wins: 17
# Num losses: 20
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0009148552123552067
# Avg trade length: 3.5405405405405403
# Remaining runs: 24
# Best reward so far: 99.99855428571456
#
# -14982.10206571476
# Num buys: 853
# Num sells: 837
# Num trades: 1690
# Num wins: 1114
# Num losses: 576
# Win streak: 14
# Loss streak: 7
# Avg pips risked: 0.0009350549450549645
# Avg trade length: 6.991124260355029
# Remaining runs: 23
# Best reward so far: 99.99855428571456
#
# -1979.1903292858408
# Num buys: 116
# Num sells: 99
# Num trades: 215
# Num wins: 88
# Num losses: 127
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008857441860465225
# Avg trade length: 11.07906976744186
# Remaining runs: 22
# Best reward so far: 99.99855428571456
#
# -2528.0502192857657
# Num buys: 291
# Num sells: 304
# Num trades: 595
# Num wins: 436
# Num losses: 159
# Win streak: 18
# Loss streak: 5
# Avg pips risked: 0.0011001152460984463
# Avg trade length: 6.420168067226891
# Remaining runs: 21
# Best reward so far: 99.99855428571456
#
# -1121.478921428689
# Num buys: 257
# Num sells: 250
# Num trades: 507
# Num wins: 243
# Num losses: 264
# Win streak: 7
# Loss streak: 10
# Avg pips risked: 0.0010018582699351983
# Avg trade length: 15.658777120315582
# Remaining runs: 20
# Best reward so far: 99.99855428571456
#
# -15903.401997857773
# Num buys: 937
# Num sells: 927
# Num trades: 1864
# Num wins: 1034
# Num losses: 830
# Win streak: 17
# Loss streak: 11
# Avg pips risked: 0.0009711856223176149
# Avg trade length: 11.94206008583691
# Remaining runs: 19
# Best reward so far: 99.99855428571456
#
# -462.9610371428378
# Num buys: 65
# Num sells: 59
# Num trades: 124
# Num wins: 58
# Num losses: 66
# Win streak: 7
# Loss streak: 5
# Avg pips risked: 0.0018238940092166092
# Avg trade length: 45.04838709677419
# Remaining runs: 18
# Best reward so far: 99.99855428571456
#
# -641.6524577678401
# Num buys: 26
# Num sells: 23
# Num trades: 49
# Num wins: 29
# Num losses: 20
# Win streak: 7
# Loss streak: 3
# Avg pips risked: 0.0009594752186588868
# Avg trade length: 3.2653061224489797
# Remaining runs: 17
# Best reward so far: 99.99855428571456
#
# -11310.386050178351
# Num buys: 450
# Num sells: 472
# Num trades: 922
# Num wins: 464
# Num losses: 458
# Win streak: 9
# Loss streak: 13
# Avg pips risked: 0.0006120948249147852
# Avg trade length: 2.619305856832972
# Remaining runs: 16
# Best reward so far: 99.99855428571456
#
# -1795.9399549998654
# Num buys: 251
# Num sells: 253
# Num trades: 504
# Num wins: 375
# Num losses: 129
# Win streak: 20
# Loss streak: 7
# Avg pips risked: 0.0017393764172335812
# Avg trade length: 10.448412698412698
# Remaining runs: 15
# Best reward so far: 99.99855428571456
#
# -5302.148864286051
# Num buys: 332
# Num sells: 365
# Num trades: 697
# Num wins: 297
# Num losses: 400
# Win streak: 7
# Loss streak: 15
# Avg pips risked: 0.0008097566099610662
# Avg trade length: 13.942611190817791
# Remaining runs: 14
# Best reward so far: 99.99855428571456
#
# -5072.5653514286605
# Num buys: 261
# Num sells: 247
# Num trades: 508
# Num wins: 206
# Num losses: 302
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0009189510686164274
# Avg trade length: 23.543307086614174
# Remaining runs: 13
# Best reward so far: 99.99855428571456
#
# -6130.122767499876
# Num buys: 363
# Num sells: 355
# Num trades: 718
# Num wins: 299
# Num losses: 419
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.000981134102666145
# Avg trade length: 15.961002785515321
# Remaining runs: 12
# Best reward so far: 99.99855428571456
#
# -30226.455131607137
# Num buys: 1307
# Num sells: 1342
# Num trades: 2649
# Num wins: 1636
# Num losses: 1013
# Win streak: 20
# Loss streak: 7
# Avg pips risked: 0.0006900835894946972
# Avg trade length: 2.86560966402416
# Remaining runs: 11
# Best reward so far: 99.99855428571456
#
# -6373.120311071667
# Num buys: 435
# Num sells: 462
# Num trades: 897
# Num wins: 617
# Num losses: 280
# Win streak: 19
# Loss streak: 6
# Avg pips risked: 0.000928506131549619
# Avg trade length: 6.565217391304348
# Remaining runs: 10
# Best reward so far: 99.99855428571456
#
# -399.9924591071379
# Num buys: 19
# Num sells: 19
# Num trades: 38
# Num wins: 24
# Num losses: 14
# Win streak: 4
# Loss streak: 2
# Avg pips risked: 0.0017393327067669196
# Avg trade length: 5.105263157894737
# Remaining runs: 9
# Best reward so far: 99.99855428571456
#
# -5681.979610356991
# Num buys: 373
# Num sells: 366
# Num trades: 739
# Num wins: 417
# Num losses: 322
# Win streak: 9
# Loss streak: 7
# Avg pips risked: 0.000884439396868364
# Avg trade length: 4.783491204330176
# Remaining runs: 8
# Best reward so far: 99.99855428571456
#
# -28855.85485321492
# Num buys: 1241
# Num sells: 1263
# Num trades: 2504
# Num wins: 1285
# Num losses: 1219
# Win streak: 14
# Loss streak: 8
# Avg pips risked: 0.0006917583295299043
# Avg trade length: 4.232428115015974
# Remaining runs: 7
# Best reward so far: 99.99855428571456
#
# -7079.038224285528
# Num buys: 462
# Num sells: 460
# Num trades: 922
# Num wins: 392
# Num losses: 530
# Win streak: 7
# Loss streak: 12
# Avg pips risked: 0.0010074755965292918
# Avg trade length: 16.311279826464208
# Remaining runs: 6
# Best reward so far: 99.99855428571456
#
# -8118.238125714564
# Num buys: 435
# Num sells: 406
# Num trades: 841
# Num wins: 343
# Num losses: 498
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0009382860540173474
# Avg trade length: 22.15576694411415
# Remaining runs: 5
# Best reward so far: 99.99855428571456
#
# -26698.67808598213
# Num buys: 1417
# Num sells: 1418
# Num trades: 2835
# Num wins: 1842
# Num losses: 993
# Win streak: 15
# Loss streak: 6
# Avg pips risked: 0.0008102770219198911
# Avg trade length: 4.574603174603174
# Remaining runs: 4
# Best reward so far: 99.99855428571456
#
# -3214.8900316074337
# Num buys: 238
# Num sells: 238
# Num trades: 476
# Num wins: 275
# Num losses: 201
# Win streak: 9
# Loss streak: 9
# Avg pips risked: 0.0007864413265306149
# Avg trade length: 7.23109243697479
# Remaining runs: 3
# Best reward so far: 99.99855428571456
#
# -484.6445114285644
# Num buys: 55
# Num sells: 58
# Num trades: 113
# Num wins: 69
# Num losses: 44
# Win streak: 10
# Loss streak: 7
# Avg pips risked: 0.0016878919089760064
# Avg trade length: 14.097345132743364
# Remaining runs: 2
# Best reward so far: 99.99855428571456
#
# -9929.817312857658
# Num buys: 534
# Num sells: 514
# Num trades: 1048
# Num wins: 568
# Num losses: 480
# Win streak: 11
# Loss streak: 7
# Avg pips risked: 0.000919965921483117
# Avg trade length: 11.702290076335878
# Remaining runs: 1
# Best reward so far: 99.99855428571456
#
# -1299.9886739286083
# Num buys: 31
# Num sells: 37
# Num trades: 68
# Num wins: 21
# Num losses: 47
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.0008706460084033543
# Avg trade length: 5.397058823529412
# Remaining runs: 0
# Best reward so far: 99.99855428571456

# %%
# EUR/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('Best adx cutoff: ' + str(best_adx_cutoff))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 99.99855428571456
# Best risk/reward ratio: 1.0
# Best spread: 0.1
# Best atr multiplier: 1.0
# Best n bars: 5
# Best adx cutoff: 20
# -----------------------
# Top results:
# {'reward': 24, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 4, 'adx_cutoff': 25}
# {'reward': 12, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 49, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 4, 'adx_cutoff': 30}
# {'reward': 49, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 24, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 4, 'adx_cutoff': 30}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': -11, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_bars': 4, 'adx_cutoff': 30}
# {'reward': -24, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 3, 'adx_cutoff': 25}
# {'reward': -24, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 24, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 4, 'adx_cutoff': 20}
# {'reward': 40, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 24, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 12, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 5, 'adx_cutoff': 30}
# {'reward': 12, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 3, 'adx_cutoff': 20}
# {'reward': -12, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 3, 'adx_cutoff': 30}
# {'reward': 37, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 5, 'adx_cutoff': 25}
# {'reward': 12, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 4, 'adx_cutoff': 20}
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 0.5, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 49, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 4, 'adx_cutoff': 25}
# {'reward': 99, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_bars': 5, 'adx_cutoff': 20}
