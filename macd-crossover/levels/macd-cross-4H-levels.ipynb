# %%
import numpy as np
import pandas as pd
import random

# %%
file_path = '/Users/mymac/Google Drive/My Drive/Forex_Robot/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
# df = pd.read_csv(file_path + 'Oanda_Aud_Usd_M5_2021-2022.csv')
df = pd.read_csv(file_path + 'Oanda_Gbp_Usd_M5_2021-2022.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

# df_long = pd.read_csv(file_path + 'Oanda_Aud_Usd_H1_2021-2022.csv')
df_long = pd.read_csv(file_path + 'Oanda_Gbp_Usd_H1_2021-2022.csv')
df_long.Date = pd.to_datetime(df_long.Date)
df_long.reset_index(drop=True, inplace=True)

# df_h4 = pd.read_csv(file_path + 'Oanda_Aud_Usd_H4_2021-2022.csv')
df_h4 = pd.read_csv(file_path + 'Oanda_Gbp_Usd_H4_2021-2022.csv')
df_h4.Date = pd.to_datetime(df_h4.Date)
df_h4.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2021-01-03 22:00:00   1.36452   1.36495  1.36442    1.36461   1.36602
# 1 2021-01-03 22:05:00   1.36470   1.36487  1.36448    1.36470   1.36620
# 2 2021-01-03 22:10:00   1.36436   1.36491  1.36436    1.36488   1.36575
# 3 2021-01-03 22:15:00   1.36498   1.36504  1.36496    1.36496   1.36549
# 4 2021-01-03 22:20:00   1.36502   1.36613  1.36502    1.36544   1.36572
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0   1.36638  1.36557    1.36611   1.36527   1.36563  1.36500    1.36536
# 1   1.36628  1.36555    1.36555   1.36545   1.36553  1.36506    1.36512
# 2   1.36576  1.36544    1.36568   1.36506   1.36534  1.36506    1.36528
# 3   1.36559  1.36549    1.36556   1.36524   1.36532  1.36524    1.36526
# 4   1.36691  1.36572    1.36641   1.36537   1.36652  1.36537    1.36592
#
#    Volume
# 0      23
# 1      11
# 2       9
# 3       4
# 4      42
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 80534 2022-02-01 06:35:00   1.34495   1.34495  1.34471    1.34483   1.34518
# 80535 2022-02-01 06:40:00   1.34487   1.34492  1.34460    1.34466   1.34507
# 80536 2022-02-01 06:45:00   1.34469   1.34476  1.34446    1.34456   1.34490
# 80537 2022-02-01 06:50:00   1.34458   1.34467  1.34450    1.34459   1.34475
# 80538 2022-02-01 06:55:00   1.34456   1.34461  1.34422    1.34424   1.34477
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 80534   1.34518  1.34491    1.34505   1.34506   1.34506  1.34481    1.34494
# 80535   1.34514  1.34483    1.34488   1.34497   1.34503  1.34472    1.34477
# 80536   1.34498  1.34462    1.34472   1.34480   1.34487  1.34454    1.34464
# 80537   1.34487  1.34469    1.34478   1.34466   1.34476  1.34460    1.34468
# 80538   1.34477  1.34441    1.34443   1.34466   1.34469  1.34432    1.34434
#
#        Volume
# 80534      41
# 80535      37
# 80536      77
# 80537      40
# 80538      55

# %%
print(df_long.head())
print('-' * 75)
print(df_long.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2021-01-03 22:00:00   1.36452   1.36619  1.36436    1.36582   1.36602
# 1 2021-01-03 23:00:00   1.36560   1.36829  1.36528    1.36798   1.36710
# 2 2021-01-04 00:00:00   1.36800   1.36827  1.36589    1.36721   1.36821
# 3 2021-01-04 01:00:00   1.36719   1.36891  1.36705    1.36816   1.36737
# 4 2021-01-04 02:00:00   1.36815   1.36941  1.36801    1.36919   1.36833
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0   1.36691  1.36544    1.36670   1.36527   1.36652  1.36500    1.36626
# 1   1.36850  1.36590    1.36818   1.36635   1.36838  1.36576    1.36808
# 2   1.36845  1.36607    1.36739   1.36810   1.36836  1.36598    1.36730
# 3   1.36909  1.36723    1.36837   1.36728   1.36900  1.36715    1.36826
# 4   1.36957  1.36821    1.36935   1.36824   1.36948  1.36811    1.36927
#
#    Volume
# 0     146
# 1     831
# 2    1773
# 3    2164
# 4    1550
# ---------------------------------------------------------------------------
#                     Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 6741 2022-02-01 02:00:00   1.34376   1.34452  1.34369    1.34439   1.34400
# 6742 2022-02-01 03:00:00   1.34442   1.34475  1.34342    1.34397   1.34463
# 6743 2022-02-01 04:00:00   1.34400   1.34524  1.34395    1.34512   1.34419
# 6744 2022-02-01 05:00:00   1.34515   1.34563  1.34499    1.34513   1.34535
# 6745 2022-02-01 06:00:00   1.34510   1.34538  1.34422    1.34424   1.34534
#
#       Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 6741   1.34474  1.34390    1.34462   1.34388   1.34463  1.34380    1.34450
# 6742   1.34496  1.34366    1.34416   1.34452   1.34484  1.34354    1.34406
# 6743   1.34544  1.34414    1.34533   1.34410   1.34534  1.34404    1.34522
# 6744   1.34584  1.34525    1.34536   1.34525   1.34574  1.34512    1.34524
# 6745   1.34558  1.34441    1.34443   1.34522   1.34548  1.34432    1.34434
#
#       Volume
# 6741     458
# 6742     992
# 6743     554
# 6744     570
# 6745     706

# %%
print(df_h4.head())
print('-' * 75)
print(df_h4.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2021-01-03 22:00:00   1.36452   1.36891  1.36436    1.36816   1.36602
# 1 2021-01-04 02:00:00   1.36815   1.36975  1.36672    1.36828   1.36833
# 2 2021-01-04 06:00:00   1.36832   1.37023  1.36639    1.36721   1.36850
# 3 2021-01-04 10:00:00   1.36720   1.37028  1.36130    1.36252   1.36737
# 4 2021-01-04 14:00:00   1.36253   1.36310  1.35410    1.35655   1.36268
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0   1.36909  1.36544    1.36837   1.36527   1.36900  1.36500    1.36826
# 1   1.36996  1.36690    1.36849   1.36824   1.36986  1.36681    1.36838
# 2   1.37043  1.36655    1.36741   1.36841   1.37033  1.36648    1.36731
# 3   1.37051  1.36152    1.36273   1.36728   1.37039  1.36142    1.36262
# 4   1.36331  1.35428    1.35673   1.36260   1.36320  1.35419    1.35664
#
#    Volume
# 0    4914
# 1    4300
# 2   12315
# 3   13570
# 4   18317
# ---------------------------------------------------------------------------
#                     Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 1942 2022-03-31 13:00:00   1.31383   1.31749  1.31049    1.31374   1.31402
# 1943 2022-03-31 17:00:00   1.31372   1.31517  1.31295    1.31410   1.31391
# 1944 2022-03-31 21:00:00   1.31370   1.31505  1.31307    1.31361   1.31430
# 1945 2022-04-01 01:00:00   1.31364   1.31389  1.31211    1.31298   1.31383
# 1946 2022-04-01 05:00:00   1.31299   1.31383  1.31118    1.31282   1.31319
#
#       Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 1942   1.31770  1.31070    1.31393   1.31392   1.31760  1.31060    1.31384
# 1943   1.31535  1.31314    1.31470   1.31382   1.31526  1.31305    1.31440
# 1944   1.31534  1.31328    1.31382   1.31400   1.31520  1.31318    1.31372
# 1945   1.31411  1.31229    1.31319   1.31374   1.31400  1.31221    1.31308
# 1946   1.31402  1.31139    1.31297   1.31309   1.31392  1.31129    1.31290
#
#       Volume
# 1942   65467
# 1943   22138
# 1944   18903
# 1945   23149
# 1946   37511

# %%
def psar(barsdata, iaf=0.02, maxaf=0.2):
    length = len(barsdata)
    high = list(barsdata['Mid_High'])
    low = list(barsdata['Mid_Low'])
    close = list(barsdata['Mid_Close'])
    psar = close[0:len(close)]
    bull = True
    af = iaf
    hp = high[0]
    lp = low[0]
    for i in range(2, length):
        if bull:
            psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
        else:
            psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
        reverse = False
        if bull:
            if low[i] < psar[i]:
                bull = False
                reverse = True
                psar[i] = hp
                lp = low[i]
                af = iaf
        else:
            if high[i] > psar[i]:
                bull = True
                reverse = True
                psar[i] = lp
                hp = high[i]
                af = iaf
        if not reverse:
            if bull:
                if high[i] > hp:
                    hp = high[i]
                    af = min(af + iaf, maxaf)
                if low[i - 1] < psar[i]:
                    psar[i] = low[i - 1]
                if low[i - 2] < psar[i]:
                    psar[i] = low[i - 2]
            else:
                if low[i] < lp:
                    lp = low[i]
                    af = min(af + iaf, maxaf)
                if high[i - 1] > psar[i]:
                    psar[i] = high[i - 1]
                if high[i - 2] > psar[i]:
                    psar[i] = high[i - 2]
    return psar


def atr(barsdata, lookback=14):
    high_low = barsdata['Mid_High'] - barsdata['Mid_Low']
    high_close = np.abs(barsdata['Mid_High'] - barsdata['Mid_Close'].shift())
    low_close = np.abs(barsdata['Mid_Low'] - barsdata['Mid_Close'].shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = np.max(ranges, axis=1)

    return true_range.rolling(lookback).sum() / lookback


def rsi(barsdata, periods=14):
    close_delta = barsdata['Mid_Close'].diff()

    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)
    ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))

    return rsi

  
def adx(high, low, close, lookback=14):
    plus_dm = high.diff()
    minus_dm = low.diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0
    
    tr1 = pd.DataFrame(high - low)
    tr2 = pd.DataFrame(abs(high - close.shift(1)))
    tr3 = pd.DataFrame(abs(low - close.shift(1)))
    frames = [tr1, tr2, tr3]
    tr = pd.concat(frames, axis = 1, join = 'inner').max(axis = 1)
    atr = tr.rolling(lookback).mean()
    
    plus_di = 100 * (plus_dm.ewm(alpha = 1/lookback).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha = 1/lookback).mean() / atr))
    dx = (abs(plus_di - minus_di) / abs(plus_di + minus_di)) * 100
    adx = ((dx.shift(1) * (lookback - 1)) + dx) / lookback
    adx_smooth = adx.ewm(alpha = 1/lookback).mean()

    return adx_smooth


def stoch(high, low, close, lookback=14):
    high_lookback = high.rolling(lookback).max()
    low_lookback = low.rolling(lookback).min()
    slow_k = (close - low_lookback) * 100 / (high_lookback - low_lookback)
    slow_d = slow_k.rolling(3).mean()

    return slow_k, slow_d

def stoch_rsi(data, k_window=3, d_window=3, window=14):
    min_val = data.rolling(window=window, center=False).min()
    max_val = data.rolling(window=window, center=False).max()

    stoch = ((data - min_val) / (max_val - min_val)) * 100

    slow_k = stoch.rolling(window=k_window, center=False).mean()

    slow_d = slow_k.rolling(window=d_window, center=False).mean()

    return slow_k, slow_d

def n_macd(macd, macdsignal, lookback=50):
    n_macd = 2 * (((macd - macd.rolling(lookback).min()) / (macd.rolling(lookback).max() - macd.rolling(lookback).min()))) - 1
    n_macdsignal = 2 * (((macdsignal - macdsignal.rolling(lookback).min()) / (macdsignal.rolling(lookback).max() - macdsignal.rolling(lookback).min()))) - 1

    return n_macd, n_macdsignal

def chop(df, lookback=14):
    atr1 = atr(df, lookback=1)
    high, low = df['Mid_High'], df['Mid_Low']

    chop = np.log10(atr1.rolling(lookback).sum() / (high.rolling(lookback).max() - low.rolling(lookback).min())) / np.log10(lookback)

    return chop

def vo(volume, short_lookback=5, long_lookback=10):
    short_ema =  pd.Series.ewm(volume, span=short_lookback).mean()
    long_ema = pd.Series.ewm(volume, span=long_lookback).mean()

    volume_oscillator = (short_ema - long_ema) / long_ema

    return volume_oscillator

def bar_lengths(bar_lens, window=36):
    return bar_lens.rolling(window=window).mean(), bar_lens.rolling(window=window).std()

def sar_lengths(opens, sars, window=36):
    diffs = abs(opens - sars.shift(1))

    return diffs.rolling(window=window).mean(), diffs.rolling(window=window).std()

# %%
df_h4['Mid_Level'] = df_h4['Mid_Low'] + (df_h4['Mid_High'] - df_h4['Mid_Low']) / 2
df_h4.rename(columns={'Mid_Low': 'Low_Level', 'Mid_High': 'High_Level'}, inplace=True)
df_h4 = df_h4[['Date', 'Low_Level', 'Mid_Level', 'High_Level']]
df_h4.head()
# Out:
#                  Date  Low_Level  Mid_Level  High_Level
# 0 2021-01-03 22:00:00    1.36500   1.367000     1.36900
# 1 2021-01-04 02:00:00    1.36681   1.368335     1.36986
# 2 2021-01-04 06:00:00    1.36648   1.368405     1.37033
# 3 2021-01-04 10:00:00    1.36142   1.365905     1.37039
# 4 2021-01-04 14:00:00    1.35419   1.358695     1.36320

# %%
# Add technical indicators (for additional features)
df['ema200'] = pd.Series.ewm(df['Mid_Close'], span=200).mean()
df['ema100'] = pd.Series.ewm(df['Mid_Close'], span=100).mean()
df['ema50'] = pd.Series.ewm(df['Mid_Close'], span=50).mean()
df['ema25'] = pd.Series.ewm(df['Mid_Close'], span=25).mean()

df['atr'] = atr(df)
df['rsi'] = rsi(df, periods=18)
df['rsi_sma'] = df['rsi'].rolling(36).mean()
df['adx'] = adx(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])
df['macd'] = pd.Series.ewm(df['Mid_Close'], span=12).mean() - pd.Series.ewm(df['Mid_Close'], span=26).mean()
df['macdsignal'] = pd.Series.ewm(df['macd'], span=9).mean()
df['n_macd'], df['n_macdsignal'] = n_macd(df['macd'], df['macdsignal'])
df['slowk'], df['slowd'] = stoch(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])
df['slowk_rsi'], df['slowd_rsi'] = stoch_rsi(df['rsi'])

df['sar'] = psar(df)

df['chop14'] = chop(df)
df['chop36'] = chop(df, lookback=36)

df['vo'] = vo(df['Volume'], short_lookback=18, long_lookback=36)

df['len_avg'], df['len_std'] = bar_lengths(abs(df['Mid_High'] - df['Mid_Low']))
df['sar_len_avg'], df['sar_len_std'] = sar_lengths(df['Mid_Open'], df['sar'])

df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

df_long['rsi'] = rsi(df_long)
df_long['adx'] = adx(df_long['Mid_High'], df_long['Mid_Low'], df_long['Mid_Close'])
df_long['slowk_rsi'], df_long['slowd_rsi'] = stoch_rsi(df_long['rsi'])

df_long['sar'] = psar(df_long)

df_long['chop14'] = chop(df_long)
df_long['chop36'] = chop(df_long, lookback=36)

df_long['vo'] = vo(df_long['Volume'], short_lookback=18, long_lookback=36)

df_long.dropna(inplace=True)
df_long.reset_index(drop=True, inplace=True)

print(df)
# Out:
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0     2021-01-04 03:15:00   1.36925   1.36938  1.36903    1.36938   1.36944
# 1     2021-01-04 03:20:00   1.36942   1.36944  1.36928    1.36938   1.36957
# 2     2021-01-04 03:25:00   1.36937   1.36942  1.36935    1.36938   1.36954
# 3     2021-01-04 03:30:00   1.36936   1.36945  1.36921    1.36936   1.36954
# 4     2021-01-04 03:35:00   1.36934   1.36939  1.36924    1.36935   1.36953
# ...                   ...       ...       ...      ...        ...       ...
# 80471 2022-02-01 06:35:00   1.34495   1.34495  1.34471    1.34483   1.34518
# 80472 2022-02-01 06:40:00   1.34487   1.34492  1.34460    1.34466   1.34507
# 80473 2022-02-01 06:45:00   1.34469   1.34476  1.34446    1.34456   1.34490
# 80474 2022-02-01 06:50:00   1.34458   1.34467  1.34450    1.34459   1.34475
# 80475 2022-02-01 06:55:00   1.34456   1.34461  1.34422    1.34424   1.34477
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  ...  slowk_rsi  slowd_rsi  \
# 0       1.36956  1.36919    1.36956   1.36934  ...  58.828745  52.327934
# 1       1.36963  1.36948    1.36957   1.36950  ...  57.904481  54.418716
# 2       1.36958  1.36950    1.36957   1.36946  ...  64.182889  60.305372
# 3       1.36964  1.36939    1.36956   1.36945  ...  63.847816  61.978396
# 4       1.36958  1.36943    1.36953   1.36944  ...  61.649173  63.226626
# ...         ...      ...        ...       ...  ...        ...        ...
# 80471   1.34518  1.34491    1.34505   1.34506  ...  15.738356  10.691497
# 80472   1.34514  1.34483    1.34488   1.34497  ...  11.194091  12.908106
# 80473   1.34498  1.34462    1.34472   1.34480  ...   3.946483  10.292977
# 80474   1.34487  1.34469    1.34478   1.34466  ...   1.880121   5.673565
# 80475   1.34477  1.34441    1.34443   1.34466  ...   1.880121   2.568908
#
#             sar    chop14    chop36        vo   len_avg   len_std  \
# 0      1.368637  0.623842  0.448805 -0.063902  0.000485  0.000145
# 1      1.368706  0.592923  0.440151 -0.080606  0.000473  0.000155
# 2      1.368788  0.576593  0.436216 -0.114502  0.000466  0.000167
# 3      1.368861  0.553212  0.431154 -0.113443  0.000461  0.000171
# 4      1.368942  0.530740  0.461542 -0.124931  0.000451  0.000179
# ...         ...       ...       ...       ...       ...       ...
# 80471  1.345431  0.531298  0.376559  0.022643  0.000227  0.000093
# 80472  1.345380  0.493340  0.378245  0.003644  0.000228  0.000094
# 80473  1.345314  0.473638  0.386524  0.024627  0.000233  0.000095
# 80474  1.345221  0.468278  0.432265  0.008084  0.000225  0.000089
# 80475  1.345140  0.415261  0.447145  0.007853  0.000232  0.000090
#
#        sar_len_avg  sar_len_std
# 0         0.001072     0.000477
# 1         0.001067     0.000479
# 2         0.001049     0.000478
# 3         0.001025     0.000475
# 4         0.000993     0.000466
# ...            ...          ...
# 80471     0.000703     0.000367
# 80472     0.000687     0.000365
# 80473     0.000673     0.000358
# 80474     0.000660     0.000350
# 80475     0.000656     0.000350
#
# [80476 rows x 38 columns]

# %%
value_per_pip = 1.0
amounts_per_day = [-0.00008, -0.0001, -0.00012]

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee

def get_n_units(trade_type, stop_loss, ask_open, bid_open, mid_open, currency_pair):
    _, second = currency_pair.split('_')
  
    pips_to_risk = ask_open - stop_loss if trade_type == 'buy' else stop_loss - bid_open
    pips_to_risk_calc = pips_to_risk * 10000 if second != 'JPY' else pips_to_risk * 100

    if second == 'USD':
        per_pip = 0.0001

    else:
        per_pip = 0.0001 / mid_open if second != 'JPY' else 0.01 / mid_open

    n_units = int(50 / (pips_to_risk_calc * per_pip))

    return n_units

def run_simulation(risk_reward_ratio, spread_cutoff, chop_cutoff, chop_num, use_rsi, strict_rsi, use_long_stoch, use_half_sar, adx_cutoff, use_adx, use_candles, use_spread_cushion, use_sar_distances, std_mult, use_ema):
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    trade = None

    for i in range(38, len(df)):
        curr_date = df.loc[df.index[i], 'Date']
        curr_long = df_long.loc[df_long['Date'] <= curr_date]
        curr_h4 = df_h4.loc[df_h4['Date'] <= curr_date]
        if len(curr_long) < 2 or len(curr_h4) < 2:
            continue
        ema200_2, ema100_2, ema50_2, ema25_2, atr2, sar2, rsi2, rsi_sma2, mid_open2, mid_close2, mid_low2, mid_high2, vo2, adx2 = df.loc[df.index[i - 2], ['ema200', 'ema100', 'ema50', 'ema25', 'atr', 'sar', 'rsi', 'rsi_sma', 'Mid_Open', 'Mid_Close', 'Mid_Low', 'Mid_High', 'vo', 'adx']]
        ema200_1, ema100_1, ema50_1, ema25_1, atr1, sar1, rsi1, rsi_sma1, mid_open1, mid_close1, mid_low1, mid_high1, vo1, adx1 = df.loc[df.index[i - 1], ['ema200', 'ema100', 'ema50', 'ema25', 'atr', 'sar', 'rsi', 'rsi_sma', 'Mid_Open', 'Mid_Close', 'Mid_Low', 'Mid_High', 'vo', 'adx']]
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        macd2, macdsignal2 = df.loc[df.index[i - 2], ['macd', 'macdsignal']]
        macd1, macdsignal1 = df.loc[df.index[i - 1], ['macd', 'macdsignal']]
        macd_vals = [0, macd2, macdsignal2, macd1, macdsignal1]
        curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, curr_mid_open, curr_mid_low = \
            df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_Low']]
        chop2 = df.loc[df.index[i - 2], f'chop{chop_num}']
        chop1 = df.loc[df.index[i - 1], f'chop{chop_num}']

        vo_long, slowk_long, slowd_long = curr_long.loc[curr_long.index[-2], ['vo', 'slowk_rsi', 'slowd_rsi']]

        emas_buy_signal = ema200_1 < ema100_1 if use_ema else True
        emas_sell_signal = ema200_1 > ema100_1 if use_ema else True

        macd_buy_signal = macd2 < macdsignal2 and macd1 > macdsignal1 and max(macd_vals) == 0
        macd_sell_signal = macd2 > macdsignal2 and macd1 < macdsignal1 and min(macd_vals) == 0

        sar_buy_signal = sar1 < min([mid_low1, mid_high1])
        sar_sell_signal = sar1 > max([mid_low1, mid_high1])

        rsi_buy_signal = rsi1 > rsi_sma1 if use_rsi else True
        rsi_sell_signal = rsi1 < rsi_sma1 if use_rsi else True

        if strict_rsi and use_rsi:
            rsi_buy_signal = rsi_buy_signal and rsi1 > 50
            rsi_sell_signal = rsi_sell_signal and rsi1 < 50

        chop_signal = (chop1 + chop2) / 2 < chop_cutoff
        # chop_signal = True

        stoch_buy_signal = max([slowk_long, slowd_long, 20]) == 20 if use_long_stoch else True
        stoch_sell_signal = min([slowk_long, slowd_long, 80]) == 80 if use_long_stoch else True

        bullish_candle = mid_close1 > mid_open1 if use_candles else True
        bearish_candle = mid_close1 < mid_open1 if use_candles else True


        if not use_sar_distances:
            mean, std = df.loc[df.index[i - 3], ['len_avg', 'len_std']]

            bars_small_enough = abs(mid_high1 - mid_low1) <= mean + (std_mult * std) and abs(mid_high2 - mid_low2) <= mean + (std_mult * std)

        else:
            mean, std = df.loc[df.index[i - 1], ['sar_len_avg', 'sar_len_std']]

            bars_small_enough = abs(curr_mid_open - sar1) <= mean + (std_mult * std)

        # bars_small_enough = True

        buy_limit = curr_ask_low <= curr_ask_open
        sell_limit = curr_bid_open <= curr_bid_high

        adx_signal = (adx1 + adx2) / 2 > adx_cutoff if use_adx else True

        low_level, mid_level, high_level = curr_h4.loc[curr_h4.index[-2], ['Low_Level', 'Mid_Level', 'High_Level']]

        level_half_width = abs(high_level - low_level) / 2

        level_buy_signal = sar1 < low_level and abs(low_level - sar1) >= level_half_width and max([mid_open1, mid_close1, mid_open2, mid_close2]) < low_level
        level_sell_signal = sar1 > high_level and abs(sar1 - high_level) >= level_half_width and min([mid_open1, mid_close1, mid_open2, mid_close2]) > high_level

        if trade is None:
            if macd_buy_signal and emas_buy_signal and sar_buy_signal and rsi_buy_signal and chop_signal and stoch_buy_signal and bullish_candle and bars_small_enough and buy_limit and adx_signal and level_buy_signal:
                open_price = float(curr_ask_open)
                pullback = mid_low1 - abs(mid_low1 - sar1) / 2 if use_half_sar else sar1
                pullback -= spread if use_spread_cushion else 0

                stop_loss = round(pullback, 5)

                if stop_loss < open_price:
                    curr_pips_to_risk = open_price - stop_loss

                    if spread <= curr_pips_to_risk * spread_cutoff:
                        stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 5)
                        # stop_gain = round(open_price + 0.0005, 5)

                        n_units = get_n_units('buy', stop_loss, curr_ask_open, curr_bid_open, curr_mid_open, 'AUD_USD')

                        trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                        'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                        'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

                        n_buys += 1

                        pips_risked.append(curr_pips_to_risk)

            elif macd_sell_signal and emas_sell_signal and sar_sell_signal and rsi_sell_signal and chop_signal and stoch_sell_signal and bearish_candle and bars_small_enough and sell_limit and adx_signal and level_sell_signal:
                open_price = float(curr_bid_open)
                pullback = abs(sar1 - mid_high1) / 2 + mid_high1 if use_half_sar else sar1
                pullback += spread if use_spread_cushion else 0

                stop_loss = round(pullback, 5)

                if stop_loss > open_price:
                    curr_pips_to_risk = stop_loss - open_price

                    if spread <= curr_pips_to_risk * spread_cutoff:
                        stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 5)
                        # stop_gain = round(open_price - 0.0005, 5)

                        n_units = get_n_units('sell', stop_loss, curr_ask_open, curr_bid_open, curr_mid_open, 'AUD_USD')

                        trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                                'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

                        n_sells += 1

                        pips_risked.append(curr_pips_to_risk)


        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
            trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None    

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
            trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
            trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
            trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
# risk_reward_ratio_vals = [1.5, 2]
risk_reward_ratio_vals = [1.5]
# spread_cutoffs = [0.15, 0.20, 0.25]
spread_cutoffs = [0.20]
# chop_cutoff_vals = [0.50, 0.559, 0.618]
chop_cutoff_vals = [0.50]
# chop_nums = [14, 36]
chop_nums = [36]
use_rsi_vals = [True, False]
use_strict_rsi_vals = [True, False]
# use_rsi_vals = [True]
use_long_stoch_vals = [True, False]
# use_half_sar_vals = [True, False]
use_half_sar_vals = [False]
adx_cutoff_vals = [20, 30, 40]
use_adx_vals = [True, False]
use_candle_vals = [True, False]
# use_candle_vals = [True]
use_spread_cushion_vals = [True, False]
# use_spread_cushion_vals = [True]
use_sar_distances_vals = [True, False]
# use_sar_distances_vals = [False]
std_mult_vals = [1.0, 2.0]
# std_mult_vals = [2.0]
use_ema_vals = [True, False]
n_possibilities = len(risk_reward_ratio_vals) * len(spread_cutoffs) * len(chop_cutoff_vals) * len(chop_nums) * len(use_rsi_vals) * len(use_strict_rsi_vals) * len(use_long_stoch_vals) * len(use_half_sar_vals) * len(adx_cutoff_vals) * len(use_adx_vals) * len(use_candle_vals) * len(use_spread_cushion_vals) * len(use_sar_distances_vals) * len(std_mult_vals) * len(use_ema_vals)
all_combos = []


# use_half_sar, vo_cutoff, use_candles

for risk_reward_ratio in risk_reward_ratio_vals:
    for spread_val in spread_cutoffs:
        for chop_cutoff in chop_cutoff_vals:
            for chop_num in chop_nums:
                for use_rsi in use_rsi_vals:
                    for strict_rsi in use_strict_rsi_vals:
                        for use_long_stoch in use_long_stoch_vals:
                            for use_half_sar in use_half_sar_vals:
                                for adx_cutoff in adx_cutoff_vals:
                                    for use_adx in use_adx_vals:
                                        for use_candles in use_candle_vals:
                                            for use_spread_cushion in use_spread_cushion_vals:
                                                for use_sar_distances in use_sar_distances_vals:
                                                    for std_mult in std_mult_vals:
                                                        for use_ema in use_ema_vals:
                                                            all_combos.append((risk_reward_ratio, spread_val, chop_cutoff, chop_num, use_rsi, strict_rsi, use_long_stoch, use_half_sar, adx_cutoff, use_adx, use_candles, use_spread_cushion, use_sar_distances, std_mult, use_ema))

# percentage_to_try = 0.5
percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)
print('Num runs: '+ str(len(combos_to_try)) + '\n')

best_risk_reward = None
best_spread_cutoff = None
best_chop_cutoff_val = None
best_chop_num = None
best_use_rsi_val = None
best_strict_rsi_val = None
best_use_long_stoch_val = None
best_use_half_sar_val = None
best_adx_cutoff = None
best_use_adx = None
best_use_candle_val = None
best_use_spread_cushion_val = None
best_use_sar_distances_val = None
best_std_mult = None
best_use_ema = None
top_n_results = 20
best_rewards = []
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, spread_cutoff, chop_cutoff, chop_num, use_rsi, strict_rsi, use_long_stoch, use_half_sar, adx_cutoff, use_adx, use_candles, use_spread_cushion, use_sar_distances, std_mult, use_ema in combos_to_try:
    reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked = run_simulation(risk_reward_ratio, spread_cutoff, chop_cutoff, chop_num, use_rsi, strict_rsi, use_long_stoch, use_half_sar, adx_cutoff, use_adx, use_candles, use_spread_cushion, use_sar_distances, std_mult, use_ema)
    runs_finished += 1

    print(reward)
    print('Num buys: ' + str(n_buys))
    print('Num sells: ' + str(n_sells))
    print('Num trades: ' + str(n_buys + n_sells))
    print('Num wins: ' + str(n_wins))
    print('Num losses: ' + str(n_losses))
    print('Win streak: ' + str(win_streak))
    print('Loss streak: ' + str(loss_streak))
    # print('Avg pips risked: ' + str(sum(pips_risked) / len(pips_risked)))
    print('Remaining runs: ' + str(n_runs - runs_finished))

    min_item = min(best_rewards, key=lambda entry: entry['reward']) if len(best_rewards) >= top_n_results else None

    if min_item is None or reward > min_item['reward']:
        if min_item is not None:
            best_rewards.remove(min_item)
            
        best_rewards.append({'reward': int(reward), 'ratio': risk_reward_ratio, 'spread_cutoff': spread_cutoff, 'chop_cutoff': chop_cutoff, 'chop_num': chop_num, 'use_rsi': use_rsi, 'strict_rsi': strict_rsi, 'use_long_stoch': use_long_stoch, 'use_half_sar': use_half_sar, 'adx_cutoff': adx_cutoff, 'use_adx': use_adx, 'use_candles': use_candles, 'use_spread_cushion': use_spread_cushion, 'use_sar_distances': use_sar_distances, 'std_mult': std_mult, 'use_ema': use_ema})


    if reward > best_reward:
        best_reward = reward
        best_risk_reward = risk_reward_ratio
        best_spread_cutoff = spread_val
        best_chop_cutoff_val = chop_cutoff
        best_chop_num = chop_num
        best_use_rsi_val = use_rsi
        best_strict_rsi_val = strict_rsi
        best_use_long_stoch_val = use_long_stoch
        best_use_half_sar_val = use_half_sar
        best_adx_cutoff = adx_cutoff
        best_use_adx = use_adx
        best_use_candle_val = use_candles
        best_use_spread_cushion_val = use_spread_cushion
        best_use_sar_distances_val = use_sar_distances
        best_std_mult = std_mult
        best_use_ema = use_ema

    print('Best reward so far: ' + str(best_reward))
    print()
# Out:
# Num runs: 1536
#
# -274.7062899999959
# Num buys: 2
# Num sells: 6
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 7
# Remaining runs: 1535
# Best reward so far: -274.7062899999959
#
# -49.99949999999449
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1534
# Best reward so far: -49.99949999999449
#
# -718.1725700000192
# Num buys: 10
# Num sells: 19
# Num trades: 29
# Num wins: 6
# Num losses: 23
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1533
# Best reward so far: -49.99949999999449
#
# -5.000000199117949e-05
# Num buys: 1
# Num sells: 4
# Num trades: 5
# Num wins: 2
# Num losses: 3
# Win streak: 1
# Loss streak: 3
# Remaining runs: 1532
# Best reward so far: -5.000000199117949e-05
#
# -49.99854999999656
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1531
# Best reward so far: -5.000000199117949e-05
#
# -1644.9682499999828
# Num buys: 64
# Num sells: 83
# Num trades: 147
# Num wins: 46
# Num losses: 101
# Win streak: 4
# Loss streak: 9
# Remaining runs: 1530
# Best reward so far: -5.000000199117949e-05
#
# -149.99454999999685
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1529
# Best reward so far: -5.000000199117949e-05
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1528
# Best reward so far: 0
#
# -349.9927099999986
# Num buys: 4
# Num sells: 3
# Num trades: 7
# Num wins: 0
# Num losses: 7
# Win streak: 0
# Loss streak: 7
# Remaining runs: 1527
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1526
# Best reward so far: 0
#
# -405.029309999987
# Num buys: 17
# Num sells: 21
# Num trades: 38
# Num wins: 12
# Num losses: 26
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1525
# Best reward so far: 0
#
# -227.5999500000038
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 6
# Remaining runs: 1524
# Best reward so far: 0
#
# -1510.560169999983
# Num buys: 44
# Num sells: 53
# Num trades: 97
# Num wins: 27
# Num losses: 70
# Win streak: 3
# Loss streak: 14
# Remaining runs: 1523
# Best reward so far: 0
#
# 25.242339999988936
# Num buys: 1
# Num sells: 6
# Num trades: 7
# Num wins: 3
# Num losses: 4
# Win streak: 2
# Loss streak: 4
# Remaining runs: 1522
# Best reward so far: 25.242339999988936
#
# -252.81923999999728
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 0
# Num losses: 5
# Win streak: 0
# Loss streak: 5
# Remaining runs: 1521
# Best reward so far: 25.242339999988936
#
# -99.99906999998876
# Num buys: 1
# Num sells: 6
# Num trades: 7
# Num wins: 2
# Num losses: 5
# Win streak: 2
# Loss streak: 5
# Remaining runs: 1520
# Best reward so far: 25.242339999988936
#
# -1735.0220399999964
# Num buys: 74
# Num sells: 92
# Num trades: 166
# Num wins: 53
# Num losses: 113
# Win streak: 4
# Loss streak: 10
# Remaining runs: 1519
# Best reward so far: 25.242339999988936
#
# -535.7263899999791
# Num buys: 23
# Num sells: 30
# Num trades: 53
# Num wins: 17
# Num losses: 36
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1518
# Best reward so far: 25.242339999988936
#
# -532.7702199999933
# Num buys: 47
# Num sells: 43
# Num trades: 90
# Num wins: 32
# Num losses: 58
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1517
# Best reward so far: 25.242339999988936
#
# -891.0258000000098
# Num buys: 9
# Num sells: 16
# Num trades: 25
# Num wins: 3
# Num losses: 22
# Win streak: 1
# Loss streak: 16
# Remaining runs: 1516
# Best reward so far: 25.242339999988936
#
# -408.44824999999946
# Num buys: 19
# Num sells: 29
# Num trades: 48
# Num wins: 16
# Num losses: 32
# Win streak: 5
# Loss streak: 9
# Remaining runs: 1515
# Best reward so far: 25.242339999988936
#
# -2284.848319999983
# Num buys: 80
# Num sells: 102
# Num trades: 182
# Num wins: 55
# Num losses: 127
# Win streak: 4
# Loss streak: 10
# Remaining runs: 1514
# Best reward so far: 25.242339999988936
#
# -49.99949999999449
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1513
# Best reward so far: 25.242339999988936
#
# -636.7960099999805
# Num buys: 26
# Num sells: 34
# Num trades: 60
# Num wins: 19
# Num losses: 41
# Win streak: 3
# Loss streak: 9
# Remaining runs: 1512
# Best reward so far: 25.242339999988936
#
# -199.99438999999967
# Num buys: 5
# Num sells: 4
# Num trades: 9
# Num wins: 2
# Num losses: 7
# Win streak: 1
# Loss streak: 4
# Remaining runs: 1511
# Best reward so far: 25.242339999988936
#
# -99.99758999999759
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 1510
# Best reward so far: 25.242339999988936
#
# -991.5633300000039
# Num buys: 11
# Num sells: 21
# Num trades: 32
# Num wins: 5
# Num losses: 27
# Win streak: 1
# Loss streak: 17
# Remaining runs: 1509
# Best reward so far: 25.242339999988936
#
# -387.3291800000089
# Num buys: 13
# Num sells: 12
# Num trades: 25
# Num wins: 7
# Num losses: 18
# Win streak: 2
# Loss streak: 10
# Remaining runs: 1508
# Best reward so far: 25.242339999988936
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1507
# Best reward so far: 25.242339999988936
#
# -1914.5636699999986
# Num buys: 88
# Num sells: 89
# Num trades: 177
# Num wins: 56
# Num losses: 121
# Win streak: 4
# Loss streak: 8
# Remaining runs: 1506
# Best reward so far: 25.242339999988936
#
# -199.9969200000022
# Num buys: 1
# Num sells: 3
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 1505
# Best reward so far: 25.242339999988936
#
# -352.7082899999889
# Num buys: 3
# Num sells: 4
# Num trades: 7
# Num wins: 0
# Num losses: 7
# Win streak: 0
# Loss streak: 7
# Remaining runs: 1504
# Best reward so far: 25.242339999988936
#
# -324.9963699999877
# Num buys: 3
# Num sells: 6
# Num trades: 9
# Num wins: 1
# Num losses: 8
# Win streak: 1
# Loss streak: 8
# Remaining runs: 1503
# Best reward so far: 25.242339999988936
#
# 75.24265999998306
# Num buys: 2
# Num sells: 9
# Num trades: 11
# Num wins: 5
# Num losses: 6
# Win streak: 3
# Loss streak: 5
# Remaining runs: 1502
# Best reward so far: 75.24265999998306
#
# -227.66166999998126
# Num buys: 17
# Num sells: 15
# Num trades: 32
# Num wins: 11
# Num losses: 21
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1501
# Best reward so far: 75.24265999998306
#
# -1495.16811
# Num buys: 71
# Num sells: 73
# Num trades: 144
# Num wins: 46
# Num losses: 98
# Win streak: 4
# Loss streak: 8
# Remaining runs: 1500
# Best reward so far: 75.24265999998306
#
# -149.70876999999797
# Num buys: 0
# Num sells: 8
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 1
# Loss streak: 4
# Remaining runs: 1499
# Best reward so far: 75.24265999998306
#
# -452.6572699999779
# Num buys: 19
# Num sells: 25
# Num trades: 44
# Num wins: 14
# Num losses: 30
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1498
# Best reward so far: 75.24265999998306
#
# -584.0269000000047
# Num buys: 7
# Num sells: 12
# Num trades: 19
# Num wins: 3
# Num losses: 16
# Win streak: 1
# Loss streak: 12
# Remaining runs: 1497
# Best reward so far: 75.24265999998306
#
# -149.99794999999563
# Num buys: 0
# Num sells: 3
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1496
# Best reward so far: 75.24265999998306
#
# -74.71017999999148
# Num buys: 1
# Num sells: 8
# Num trades: 9
# Num wins: 3
# Num losses: 6
# Win streak: 3
# Loss streak: 6
# Remaining runs: 1495
# Best reward so far: 75.24265999998306
#
# -2288.174279999983
# Num buys: 80
# Num sells: 102
# Num trades: 182
# Num wins: 55
# Num losses: 127
# Win streak: 4
# Loss streak: 10
# Remaining runs: 1494
# Best reward so far: 75.24265999998306
#
# -299.9958899999902
# Num buys: 1
# Num sells: 5
# Num trades: 6
# Num wins: 0
# Num losses: 6
# Win streak: 0
# Loss streak: 6
# Remaining runs: 1493
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1492
# Best reward so far: 75.24265999998306
#
# -539.9676100000038
# Num buys: 35
# Num sells: 43
# Num trades: 78
# Num wins: 27
# Num losses: 51
# Win streak: 6
# Loss streak: 8
# Remaining runs: 1491
# Best reward so far: 75.24265999998306
#
# -562.4426000000066
# Num buys: 26
# Num sells: 25
# Num trades: 51
# Num wins: 16
# Num losses: 35
# Win streak: 2
# Loss streak: 5
# Remaining runs: 1490
# Best reward so far: 75.24265999998306
#
# -616.1566200000152
# Num buys: 25
# Num sells: 32
# Num trades: 57
# Num wins: 18
# Num losses: 39
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1489
# Best reward so far: 75.24265999998306
#
# -435.4374300000092
# Num buys: 9
# Num sells: 17
# Num trades: 26
# Num wins: 7
# Num losses: 19
# Win streak: 1
# Loss streak: 6
# Remaining runs: 1488
# Best reward so far: 75.24265999998306
#
# -329.16942000000597
# Num buys: 5
# Num sells: 9
# Num trades: 14
# Num wins: 3
# Num losses: 11
# Win streak: 1
# Loss streak: 8
# Remaining runs: 1487
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1486
# Best reward so far: 75.24265999998306
#
# -288.37520000000524
# Num buys: 19
# Num sells: 19
# Num trades: 38
# Num wins: 13
# Num losses: 25
# Win streak: 3
# Loss streak: 5
# Remaining runs: 1485
# Best reward so far: 75.24265999998306
#
# -1310.4732899999944
# Num buys: 58
# Num sells: 60
# Num trades: 118
# Num wins: 37
# Num losses: 81
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1484
# Best reward so far: 75.24265999998306
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1483
# Best reward so far: 75.24265999998306
#
# -1002.7353200000027
# Num buys: 28
# Num sells: 34
# Num trades: 62
# Num wins: 17
# Num losses: 45
# Win streak: 3
# Loss streak: 10
# Remaining runs: 1482
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1481
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1480
# Best reward so far: 75.24265999998306
#
# -99.99855999999457
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 1479
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1478
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1477
# Best reward so far: 75.24265999998306
#
# -1213.3999300000012
# Num buys: 50
# Num sells: 56
# Num trades: 106
# Num wins: 33
# Num losses: 73
# Win streak: 3
# Loss streak: 10
# Remaining runs: 1476
# Best reward so far: 75.24265999998306
#
# -1298.7773400000037
# Num buys: 32
# Num sells: 36
# Num trades: 68
# Num wins: 17
# Num losses: 51
# Win streak: 3
# Loss streak: 13
# Remaining runs: 1475
# Best reward so far: 75.24265999998306
#
# -2282.673319999983
# Num buys: 80
# Num sells: 102
# Num trades: 182
# Num wins: 55
# Num losses: 127
# Win streak: 4
# Loss streak: 10
# Remaining runs: 1474
# Best reward so far: 75.24265999998306
#
# -50.124270000018164
# Num buys: 10
# Num sells: 11
# Num trades: 21
# Num wins: 8
# Num losses: 13
# Win streak: 3
# Loss streak: 5
# Remaining runs: 1473
# Best reward so far: 75.24265999998306
#
# -49.99896000000139
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1472
# Best reward so far: 75.24265999998306
#
# -633.9278800000067
# Num buys: 6
# Num sells: 14
# Num trades: 20
# Num wins: 3
# Num losses: 17
# Win streak: 2
# Loss streak: 16
# Remaining runs: 1471
# Best reward so far: 75.24265999998306
#
# -149.99673999999288
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1470
# Best reward so far: 75.24265999998306
#
# -99.9991100000093
# Num buys: 4
# Num sells: 8
# Num trades: 12
# Num wins: 4
# Num losses: 8
# Win streak: 1
# Loss streak: 4
# Remaining runs: 1469
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1468
# Best reward so far: 75.24265999998306
#
# -811.3599899999942
# Num buys: 34
# Num sells: 37
# Num trades: 71
# Num wins: 22
# Num losses: 49
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1467
# Best reward so far: 75.24265999998306
#
# -2354.290859999975
# Num buys: 77
# Num sells: 84
# Num trades: 161
# Num wins: 46
# Num losses: 115
# Win streak: 3
# Loss streak: 10
# Remaining runs: 1466
# Best reward so far: 75.24265999998306
#
# -149.99866999999324
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1465
# Best reward so far: 75.24265999998306
#
# 3.999999032089363e-05
# Num buys: 3
# Num sells: 7
# Num trades: 10
# Num wins: 4
# Num losses: 6
# Win streak: 1
# Loss streak: 3
# Remaining runs: 1464
# Best reward so far: 75.24265999998306
#
# -463.37294000002515
# Num buys: 14
# Num sells: 25
# Num trades: 39
# Num wins: 12
# Num losses: 27
# Win streak: 2
# Loss streak: 8
# Remaining runs: 1463
# Best reward so far: 75.24265999998306
#
# -1996.2178699999995
# Num buys: 89
# Num sells: 92
# Num trades: 181
# Num wins: 57
# Num losses: 124
# Win streak: 4
# Loss streak: 9
# Remaining runs: 1462
# Best reward so far: 75.24265999998306
#
# -49.99949999999449
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1461
# Best reward so far: 75.24265999998306
#
# -2.9999993252260992e-05
# Num buys: 0
# Num sells: 5
# Num trades: 5
# Num wins: 2
# Num losses: 3
# Win streak: 2
# Loss streak: 3
# Remaining runs: 1460
# Best reward so far: 75.24265999998306
#
# -754.3135799999995
# Num buys: 42
# Num sells: 45
# Num trades: 87
# Num wins: 29
# Num losses: 58
# Win streak: 3
# Loss streak: 12
# Remaining runs: 1459
# Best reward so far: 75.24265999998306
#
# -817.8752800000082
# Num buys: 50
# Num sells: 61
# Num trades: 111
# Num wins: 38
# Num losses: 73
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1458
# Best reward so far: 75.24265999998306
#
# -890.0807200000097
# Num buys: 9
# Num sells: 16
# Num trades: 25
# Num wins: 3
# Num losses: 22
# Win streak: 1
# Loss streak: 16
# Remaining runs: 1457
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1456
# Best reward so far: 75.24265999998306
#
# -468.70249000000723
# Num buys: 22
# Num sells: 27
# Num trades: 49
# Num wins: 16
# Num losses: 33
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1455
# Best reward so far: 75.24265999998306
#
# -1520.2288899999803
# Num buys: 63
# Num sells: 59
# Num trades: 122
# Num wins: 37
# Num losses: 85
# Win streak: 5
# Loss streak: 10
# Remaining runs: 1454
# Best reward so far: 75.24265999998306
#
# -1246.1091000000033
# Num buys: 59
# Num sells: 70
# Num trades: 129
# Num wins: 42
# Num losses: 87
# Win streak: 4
# Loss streak: 9
# Remaining runs: 1453
# Best reward so far: 75.24265999998306
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1452
# Best reward so far: 75.24265999998306
#
# 3.999999032089363e-05
# Num buys: 3
# Num sells: 7
# Num trades: 10
# Num wins: 4
# Num losses: 6
# Win streak: 1
# Loss streak: 3
# Remaining runs: 1451
# Best reward so far: 75.24265999998306
#
# -199.53036999999296
# Num buys: 5
# Num sells: 14
# Num trades: 19
# Num wins: 6
# Num losses: 13
# Win streak: 4
# Loss streak: 8
# Remaining runs: 1450
# Best reward so far: 75.24265999998306
#
# -303.1202000000094
# Num buys: 4
# Num sells: 7
# Num trades: 11
# Num wins: 2
# Num losses: 9
# Win streak: 1
# Loss streak: 5
# Remaining runs: 1449
# Best reward so far: 75.24265999998306
#
# -898.2063500000143
# Num buys: 33
# Num sells: 37
# Num trades: 70
# Num wins: 21
# Num losses: 49
# Win streak: 3
# Loss streak: 9
# Remaining runs: 1448
# Best reward so far: 75.24265999998306
#
# -1453.0964999999871
# Num buys: 75
# Num sells: 88
# Num trades: 163
# Num wins: 54
# Num losses: 109
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1447
# Best reward so far: 75.24265999998306
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1446
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1445
# Best reward so far: 75.24265999998306
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1444
# Best reward so far: 75.24265999998306
#
# -74.99830000001037
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 1
# Num losses: 3
# Win streak: 1
# Loss streak: 3
# Remaining runs: 1443
# Best reward so far: 75.24265999998306
#
# -949.9816200000248
# Num buys: 15
# Num sells: 26
# Num trades: 41
# Num wins: 9
# Num losses: 32
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1442
# Best reward so far: 75.24265999998306
#
# -1060.262619999961
# Num buys: 36
# Num sells: 40
# Num trades: 76
# Num wins: 22
# Num losses: 54
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1441
# Best reward so far: 75.24265999998306
#
# -641.2546300000184
# Num buys: 27
# Num sells: 38
# Num trades: 65
# Num wins: 21
# Num losses: 44
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1440
# Best reward so far: 75.24265999998306
#
# -357.8608499999796
# Num buys: 21
# Num sells: 36
# Num trades: 57
# Num wins: 20
# Num losses: 37
# Win streak: 5
# Loss streak: 9
# Remaining runs: 1439
# Best reward so far: 75.24265999998306
#
# -149.99794999999563
# Num buys: 0
# Num sells: 3
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1438
# Best reward so far: 75.24265999998306
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1437
# Best reward so far: 75.24265999998306
#
# -583.1340600000048
# Num buys: 7
# Num sells: 12
# Num trades: 19
# Num wins: 3
# Num losses: 16
# Win streak: 1
# Loss streak: 12
# Remaining runs: 1436
# Best reward so far: 75.24265999998306
#
# -582.9565400000125
# Num buys: 11
# Num sells: 23
# Num trades: 34
# Num wins: 9
# Num losses: 25
# Win streak: 4
# Loss streak: 7
# Remaining runs: 1435
# Best reward so far: 75.24265999998306
#
# -149.99767999999128
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1434
# Best reward so far: 75.24265999998306
#
# -1689.5936299999794
# Num buys: 50
# Num sells: 63
# Num trades: 113
# Num wins: 32
# Num losses: 81
# Win streak: 3
# Loss streak: 16
# Remaining runs: 1433
# Best reward so far: 75.24265999998306
#
# -512.4096599999981
# Num buys: 35
# Num sells: 40
# Num trades: 75
# Num wins: 26
# Num losses: 49
# Win streak: 6
# Loss streak: 8
# Remaining runs: 1432
# Best reward so far: 75.24265999998306
#
# -149.99673999999288
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1431
# Best reward so far: 75.24265999998306
#
# -616.6678199999736
# Num buys: 21
# Num sells: 36
# Num trades: 57
# Num wins: 18
# Num losses: 39
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1430
# Best reward so far: 75.24265999998306
#
# -149.99454999999685
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1429
# Best reward so far: 75.24265999998306
#
# -1170.577180000013
# Num buys: 30
# Num sells: 33
# Num trades: 63
# Num wins: 16
# Num losses: 47
# Win streak: 3
# Loss streak: 9
# Remaining runs: 1428
# Best reward so far: 75.24265999998306
#
# -124.70867000000541
# Num buys: 0
# Num sells: 5
# Num trades: 5
# Num wins: 1
# Num losses: 4
# Win streak: 1
# Loss streak: 4
# Remaining runs: 1427
# Best reward so far: 75.24265999998306
#
# -2.9999993252260992e-05
# Num buys: 0
# Num sells: 5
# Num trades: 5
# Num wins: 2
# Num losses: 3
# Win streak: 2
# Loss streak: 3
# Remaining runs: 1426
# Best reward so far: 75.24265999998306
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1425
# Best reward so far: 75.24265999998306
#
# -1523.8977499999803
# Num buys: 63
# Num sells: 59
# Num trades: 122
# Num wins: 37
# Num losses: 85
# Win streak: 5
# Loss streak: 10
# Remaining runs: 1424
# Best reward so far: 75.24265999998306
#
# -299.902630000008
# Num buys: 10
# Num sells: 6
# Num trades: 16
# Num wins: 4
# Num losses: 12
# Win streak: 2
# Loss streak: 8
# Remaining runs: 1423
# Best reward so far: 75.24265999998306
#
# -912.5164899999784
# Num buys: 50
# Num sells: 45
# Num trades: 95
# Num wins: 31
# Num losses: 64
# Win streak: 4
# Loss streak: 12
# Remaining runs: 1422
# Best reward so far: 75.24265999998306
#
# -416.08630000000636
# Num buys: 24
# Num sells: 34
# Num trades: 58
# Num wins: 20
# Num losses: 38
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1421
# Best reward so far: 75.24265999998306
#
# 100.14228999999396
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 2
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Remaining runs: 1420
# Best reward so far: 100.14228999999396
#
# -253.38419999999726
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 0
# Num losses: 5
# Win streak: 0
# Loss streak: 5
# Remaining runs: 1419
# Best reward so far: 100.14228999999396
#
# -74.99888999998983
# Num buys: 0
# Num sells: 4
# Num trades: 4
# Num wins: 1
# Num losses: 3
# Win streak: 1
# Loss streak: 3
# Remaining runs: 1418
# Best reward so far: 100.14228999999396
#
# -352.25192000000163
# Num buys: 3
# Num sells: 4
# Num trades: 7
# Num wins: 0
# Num losses: 7
# Win streak: 0
# Loss streak: 7
# Remaining runs: 1417
# Best reward so far: 100.14228999999396
#
# -1543.4204799999848
# Num buys: 64
# Num sells: 81
# Num trades: 145
# Num wins: 46
# Num losses: 99
# Win streak: 4
# Loss streak: 9
# Remaining runs: 1416
# Best reward so far: 100.14228999999396
#
# -535.3832500000012
# Num buys: 9
# Num sells: 14
# Num trades: 23
# Num wins: 5
# Num losses: 18
# Win streak: 2
# Loss streak: 7
# Remaining runs: 1415
# Best reward so far: 100.14228999999396
#
# -388.7675099999833
# Num buys: 22
# Num sells: 23
# Num trades: 45
# Num wins: 15
# Num losses: 30
# Win streak: 3
# Loss streak: 6
# Remaining runs: 1414
# Best reward so far: 100.14228999999396
#
# -352.7082899999889
# Num buys: 3
# Num sells: 4
# Num trades: 7
# Num wins: 0
# Num losses: 7
# Win streak: 0
# Loss streak: 7
# Remaining runs: 1413
# Best reward so far: 100.14228999999396
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1412
# Best reward so far: 100.14228999999396
#
# -505.0560900000118
# Num buys: 15
# Num sells: 10
# Num trades: 25
# Num wins: 6
# Num losses: 19
# Win streak: 2
# Loss streak: 10
# Remaining runs: 1411
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1410
# Best reward so far: 100.14228999999396
#
# -1523.1523099999802
# Num buys: 63
# Num sells: 59
# Num trades: 122
# Num wins: 37
# Num losses: 85
# Win streak: 5
# Loss streak: 10
# Remaining runs: 1409
# Best reward so far: 100.14228999999396
#
# -917.8100100000144
# Num buys: 14
# Num sells: 29
# Num trades: 43
# Num wins: 10
# Num losses: 33
# Win streak: 4
# Loss streak: 10
# Remaining runs: 1408
# Best reward so far: 100.14228999999396
#
# -632.3406000000067
# Num buys: 6
# Num sells: 14
# Num trades: 20
# Num wins: 3
# Num losses: 17
# Win streak: 2
# Loss streak: 16
# Remaining runs: 1407
# Best reward so far: 100.14228999999396
#
# -1239.0440999999814
# Num buys: 41
# Num sells: 41
# Num trades: 82
# Num wins: 23
# Num losses: 59
# Win streak: 3
# Loss streak: 9
# Remaining runs: 1406
# Best reward so far: 100.14228999999396
#
# -274.9966400000006
# Num buys: 3
# Num sells: 5
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 4
# Remaining runs: 1405
# Best reward so far: 100.14228999999396
#
# -663.3102200000126
# Num buys: 26
# Num sells: 32
# Num trades: 58
# Num wins: 18
# Num losses: 40
# Win streak: 2
# Loss streak: 7
# Remaining runs: 1404
# Best reward so far: 100.14228999999396
#
# -254.81006999999317
# Num buys: 19
# Num sells: 31
# Num trades: 50
# Num wins: 18
# Num losses: 32
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1403
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1402
# Best reward so far: 100.14228999999396
#
# -288.55874000000523
# Num buys: 19
# Num sells: 19
# Num trades: 38
# Num wins: 13
# Num losses: 25
# Win streak: 3
# Loss streak: 5
# Remaining runs: 1401
# Best reward so far: 100.14228999999396
#
# -99.70792999999814
# Num buys: 2
# Num sells: 10
# Num trades: 12
# Num wins: 4
# Num losses: 8
# Win streak: 3
# Loss streak: 5
# Remaining runs: 1400
# Best reward so far: 100.14228999999396
#
# -308.54352000000733
# Num buys: 27
# Num sells: 24
# Num trades: 51
# Num wins: 18
# Num losses: 33
# Win streak: 3
# Loss streak: 6
# Remaining runs: 1399
# Best reward so far: 100.14228999999396
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1398
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1397
# Best reward so far: 100.14228999999396
#
# -816.4348499999726
# Num buys: 39
# Num sells: 52
# Num trades: 91
# Num wins: 30
# Num losses: 61
# Win streak: 2
# Loss streak: 11
# Remaining runs: 1396
# Best reward so far: 100.14228999999396
#
# -224.99732999999213
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 6
# Remaining runs: 1395
# Best reward so far: 100.14228999999396
#
# -288.4422700000167
# Num buys: 14
# Num sells: 14
# Num trades: 28
# Num wins: 9
# Num losses: 19
# Win streak: 4
# Loss streak: 10
# Remaining runs: 1394
# Best reward so far: 100.14228999999396
#
# -537.2596300000052
# Num buys: 27
# Num sells: 26
# Num trades: 53
# Num wins: 17
# Num losses: 36
# Win streak: 2
# Loss streak: 6
# Remaining runs: 1393
# Best reward so far: 100.14228999999396
#
# -149.99673999999288
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1392
# Best reward so far: 100.14228999999396
#
# -516.259449999979
# Num buys: 19
# Num sells: 31
# Num trades: 50
# Num wins: 16
# Num losses: 34
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1391
# Best reward so far: 100.14228999999396
#
# -417.8662800000064
# Num buys: 24
# Num sells: 34
# Num trades: 58
# Num wins: 20
# Num losses: 38
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1390
# Best reward so far: 100.14228999999396
#
# -99.99758999999435
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 1389
# Best reward so far: 100.14228999999396
#
# -352.8168800000016
# Num buys: 3
# Num sells: 4
# Num trades: 7
# Num wins: 0
# Num losses: 7
# Win streak: 0
# Loss streak: 7
# Remaining runs: 1388
# Best reward so far: 100.14228999999396
#
# -337.095650000002
# Num buys: 16
# Num sells: 13
# Num trades: 29
# Num wins: 9
# Num losses: 20
# Win streak: 2
# Loss streak: 5
# Remaining runs: 1387
# Best reward so far: 100.14228999999396
#
# -49.99949999999449
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1386
# Best reward so far: 100.14228999999396
#
# -99.82136999999736
# Num buys: 4
# Num sells: 8
# Num trades: 12
# Num wins: 4
# Num losses: 8
# Win streak: 3
# Loss streak: 4
# Remaining runs: 1385
# Best reward so far: 100.14228999999396
#
# -49.99949999999449
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1384
# Best reward so far: 100.14228999999396
#
# -274.7073699999914
# Num buys: 3
# Num sells: 10
# Num trades: 13
# Num wins: 3
# Num losses: 10
# Win streak: 2
# Loss streak: 8
# Remaining runs: 1383
# Best reward so far: 100.14228999999396
#
# -1726.168129999993
# Num buys: 72
# Num sells: 74
# Num trades: 146
# Num wins: 45
# Num losses: 101
# Win streak: 2
# Loss streak: 8
# Remaining runs: 1382
# Best reward so far: 100.14228999999396
#
# -458.7618099999915
# Num buys: 18
# Num sells: 26
# Num trades: 44
# Num wins: 14
# Num losses: 30
# Win streak: 5
# Loss streak: 9
# Remaining runs: 1381
# Best reward so far: 100.14228999999396
#
# -803.6799799999957
# Num buys: 43
# Num sells: 40
# Num trades: 83
# Num wins: 27
# Num losses: 56
# Win streak: 3
# Loss streak: 11
# Remaining runs: 1380
# Best reward so far: 100.14228999999396
#
# -1244.6677200000033
# Num buys: 59
# Num sells: 70
# Num trades: 129
# Num wins: 42
# Num losses: 87
# Win streak: 4
# Loss streak: 9
# Remaining runs: 1379
# Best reward so far: 100.14228999999396
#
# -202.34554999999924
# Num buys: 15
# Num sells: 14
# Num trades: 29
# Num wins: 10
# Num losses: 19
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1378
# Best reward so far: 100.14228999999396
#
# -149.99299999999857
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1377
# Best reward so far: 100.14228999999396
#
# -224.99732999999213
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 6
# Remaining runs: 1376
# Best reward so far: 100.14228999999396
#
# -274.7524100000098
# Num buys: 2
# Num sells: 6
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 7
# Remaining runs: 1375
# Best reward so far: 100.14228999999396
#
# -556.5822299999978
# Num buys: 23
# Num sells: 28
# Num trades: 51
# Num wins: 16
# Num losses: 35
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1374
# Best reward so far: 100.14228999999396
#
# -199.9968499999947
# Num buys: 0
# Num sells: 4
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 1373
# Best reward so far: 100.14228999999396
#
# -149.99767999999128
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1372
# Best reward so far: 100.14228999999396
#
# -149.99299999999857
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1371
# Best reward so far: 100.14228999999396
#
# -308.54154000000744
# Num buys: 6
# Num sells: 10
# Num trades: 16
# Num wins: 4
# Num losses: 12
# Win streak: 2
# Loss streak: 8
# Remaining runs: 1370
# Best reward so far: 100.14228999999396
#
# -333.56396999999754
# Num buys: 14
# Num sells: 10
# Num trades: 24
# Num wins: 7
# Num losses: 17
# Win streak: 3
# Loss streak: 5
# Remaining runs: 1369
# Best reward so far: 100.14228999999396
#
# -274.7073699999914
# Num buys: 3
# Num sells: 10
# Num trades: 13
# Num wins: 3
# Num losses: 10
# Win streak: 2
# Loss streak: 8
# Remaining runs: 1368
# Best reward so far: 100.14228999999396
#
# -250.29028999999002
# Num buys: 11
# Num sells: 9
# Num trades: 20
# Num wins: 6
# Num losses: 14
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1367
# Best reward so far: 100.14228999999396
#
# -149.99744999999564
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1366
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1365
# Best reward so far: 100.14228999999396
#
# -386.2582499999833
# Num buys: 22
# Num sells: 23
# Num trades: 45
# Num wins: 15
# Num losses: 30
# Win streak: 3
# Loss streak: 6
# Remaining runs: 1364
# Best reward so far: 100.14228999999396
#
# -199.99769000000245
# Num buys: 0
# Num sells: 4
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 1363
# Best reward so far: 100.14228999999396
#
# -594.8839799999777
# Num buys: 28
# Num sells: 46
# Num trades: 74
# Num wins: 25
# Num losses: 49
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1362
# Best reward so far: 100.14228999999396
#
# -1643.099889999983
# Num buys: 64
# Num sells: 83
# Num trades: 147
# Num wins: 46
# Num losses: 101
# Win streak: 4
# Loss streak: 9
# Remaining runs: 1361
# Best reward so far: 100.14228999999396
#
# -253.38419999999726
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 0
# Num losses: 5
# Win streak: 0
# Loss streak: 5
# Remaining runs: 1360
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1359
# Best reward so far: 100.14228999999396
#
# -1300.294280000004
# Num buys: 32
# Num sells: 36
# Num trades: 68
# Num wins: 17
# Num losses: 51
# Win streak: 3
# Loss streak: 13
# Remaining runs: 1358
# Best reward so far: 100.14228999999396
#
# -149.99767999999128
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1357
# Best reward so far: 100.14228999999396
#
# -2377.49929999998
# Num buys: 62
# Num sells: 82
# Num trades: 144
# Num wins: 39
# Num losses: 105
# Win streak: 3
# Loss streak: 12
# Remaining runs: 1356
# Best reward so far: 100.14228999999396
#
# -402.5985300000091
# Num buys: 5
# Num sells: 8
# Num trades: 13
# Num wins: 2
# Num losses: 11
# Win streak: 1
# Loss streak: 5
# Remaining runs: 1355
# Best reward so far: 100.14228999999396
#
# -49.99949999999449
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1354
# Best reward so far: 100.14228999999396
#
# -99.99777999999333
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 1353
# Best reward so far: 100.14228999999396
#
# -765.370529999984
# Num buys: 56
# Num sells: 51
# Num trades: 107
# Num wins: 37
# Num losses: 70
# Win streak: 4
# Loss streak: 6
# Remaining runs: 1352
# Best reward so far: 100.14228999999396
#
# -1375.285550000016
# Num buys: 74
# Num sells: 90
# Num trades: 164
# Num wins: 55
# Num losses: 109
# Win streak: 5
# Loss streak: 8
# Remaining runs: 1351
# Best reward so far: 100.14228999999396
#
# -1495.16653
# Num buys: 71
# Num sells: 73
# Num trades: 144
# Num wins: 46
# Num losses: 98
# Win streak: 4
# Loss streak: 8
# Remaining runs: 1350
# Best reward so far: 100.14228999999396
#
# -252.7105099999929
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 0
# Num losses: 5
# Win streak: 0
# Loss streak: 5
# Remaining runs: 1349
# Best reward so far: 100.14228999999396
#
# -991.8467100000039
# Num buys: 11
# Num sells: 21
# Num trades: 32
# Num wins: 5
# Num losses: 27
# Win streak: 1
# Loss streak: 17
# Remaining runs: 1348
# Best reward so far: 100.14228999999396
#
# -616.5301999999735
# Num buys: 21
# Num sells: 36
# Num trades: 57
# Num wins: 18
# Num losses: 39
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1347
# Best reward so far: 100.14228999999396
#
# -174.85580000001133
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 3
# Num losses: 8
# Win streak: 1
# Loss streak: 7
# Remaining runs: 1346
# Best reward so far: 100.14228999999396
#
# -402.8744099999838
# Num buys: 20
# Num sells: 28
# Num trades: 48
# Num wins: 16
# Num losses: 32
# Win streak: 3
# Loss streak: 6
# Remaining runs: 1345
# Best reward so far: 100.14228999999396
#
# -379.99059999998485
# Num buys: 14
# Num sells: 21
# Num trades: 35
# Num wins: 11
# Num losses: 24
# Win streak: 4
# Loss streak: 8
# Remaining runs: 1344
# Best reward so far: 100.14228999999396
#
# -199.9969200000022
# Num buys: 1
# Num sells: 3
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 1343
# Best reward so far: 100.14228999999396
#
# 74.99946999999591
# Num buys: 1
# Num sells: 5
# Num trades: 6
# Num wins: 3
# Num losses: 3
# Win streak: 2
# Loss streak: 3
# Remaining runs: 1342
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1341
# Best reward so far: 100.14228999999396
#
# -149.99673999999288
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1340
# Best reward so far: 100.14228999999396
#
# -252.7105099999929
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 0
# Num losses: 5
# Win streak: 0
# Loss streak: 5
# Remaining runs: 1339
# Best reward so far: 100.14228999999396
#
# -452.1138099999779
# Num buys: 19
# Num sells: 25
# Num trades: 44
# Num wins: 14
# Num losses: 30
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1338
# Best reward so far: 100.14228999999396
#
# -2.9999993252260992e-05
# Num buys: 0
# Num sells: 5
# Num trades: 5
# Num wins: 2
# Num losses: 3
# Win streak: 2
# Loss streak: 3
# Remaining runs: 1337
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1336
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1335
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1334
# Best reward so far: 100.14228999999396
#
# -1303.149470000015
# Num buys: 73
# Num sells: 87
# Num trades: 160
# Num wins: 54
# Num losses: 106
# Win streak: 5
# Loss streak: 8
# Remaining runs: 1333
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1332
# Best reward so far: 100.14228999999396
#
# -690.4151599999739
# Num buys: 43
# Num sells: 58
# Num trades: 101
# Num wins: 35
# Num losses: 66
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1331
# Best reward so far: 100.14228999999396
#
# -918.0634900000143
# Num buys: 14
# Num sells: 29
# Num trades: 43
# Num wins: 10
# Num losses: 33
# Win streak: 4
# Loss streak: 10
# Remaining runs: 1330
# Best reward so far: 100.14228999999396
#
# -402.5985300000091
# Num buys: 5
# Num sells: 8
# Num trades: 13
# Num wins: 2
# Num losses: 11
# Win streak: 1
# Loss streak: 5
# Remaining runs: 1329
# Best reward so far: 100.14228999999396
#
# 0.1434299999870774
# Num buys: 3
# Num sells: 2
# Num trades: 5
# Num wins: 2
# Num losses: 3
# Win streak: 1
# Loss streak: 2
# Remaining runs: 1328
# Best reward so far: 100.14228999999396
#
# -324.9963699999877
# Num buys: 3
# Num sells: 6
# Num trades: 9
# Num wins: 1
# Num losses: 8
# Win streak: 1
# Loss streak: 8
# Remaining runs: 1327
# Best reward so far: 100.14228999999396
#
# -1021.3767100000046
# Num buys: 35
# Num sells: 40
# Num trades: 75
# Num wins: 22
# Num losses: 53
# Win streak: 3
# Loss streak: 13
# Remaining runs: 1326
# Best reward so far: 100.14228999999396
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1325
# Best reward so far: 100.14228999999396
#
# -99.99777999999333
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 1324
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1323
# Best reward so far: 100.14228999999396
#
# -283.8550500000014
# Num buys: 15
# Num sells: 13
# Num trades: 28
# Num wins: 9
# Num losses: 19
# Win streak: 4
# Loss streak: 5
# Remaining runs: 1322
# Best reward so far: 100.14228999999396
#
# -890.6028600000097
# Num buys: 9
# Num sells: 16
# Num trades: 25
# Num wins: 3
# Num losses: 22
# Win streak: 1
# Loss streak: 16
# Remaining runs: 1321
# Best reward so far: 100.14228999999396
#
# -229.20014999999248
# Num buys: 20
# Num sells: 17
# Num trades: 37
# Num wins: 13
# Num losses: 24
# Win streak: 4
# Loss streak: 5
# Remaining runs: 1320
# Best reward so far: 100.14228999999396
#
# -535.5948900000012
# Num buys: 9
# Num sells: 14
# Num trades: 23
# Num wins: 5
# Num losses: 18
# Win streak: 2
# Loss streak: 7
# Remaining runs: 1319
# Best reward so far: 100.14228999999396
#
# -352.7082899999889
# Num buys: 3
# Num sells: 4
# Num trades: 7
# Num wins: 0
# Num losses: 7
# Win streak: 0
# Loss streak: 7
# Remaining runs: 1318
# Best reward so far: 100.14228999999396
#
# -1333.4457599999798
# Num buys: 72
# Num sells: 66
# Num trades: 138
# Num wins: 45
# Num losses: 93
# Win streak: 4
# Loss streak: 8
# Remaining runs: 1317
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1316
# Best reward so far: 100.14228999999396
#
# -24.999390000010976
# Num buys: 2
# Num sells: 6
# Num trades: 8
# Num wins: 3
# Num losses: 5
# Win streak: 1
# Loss streak: 4
# Remaining runs: 1315
# Best reward so far: 100.14228999999396
#
# -915.0752999999935
# Num buys: 27
# Num sells: 26
# Num trades: 53
# Num wins: 14
# Num losses: 39
# Win streak: 2
# Loss streak: 8
# Remaining runs: 1314
# Best reward so far: 100.14228999999396
#
# -2353.3824799999747
# Num buys: 77
# Num sells: 84
# Num trades: 161
# Num wins: 46
# Num losses: 115
# Win streak: 3
# Loss streak: 10
# Remaining runs: 1313
# Best reward so far: 100.14228999999396
#
# -415.47479999997717
# Num buys: 29
# Num sells: 39
# Num trades: 68
# Num wins: 24
# Num losses: 44
# Win streak: 5
# Loss streak: 5
# Remaining runs: 1312
# Best reward so far: 100.14228999999396
#
# -2.9999993252260992e-05
# Num buys: 0
# Num sells: 5
# Num trades: 5
# Num wins: 2
# Num losses: 3
# Win streak: 2
# Loss streak: 3
# Remaining runs: 1311
# Best reward so far: 100.14228999999396
#
# -99.99906999998876
# Num buys: 1
# Num sells: 6
# Num trades: 7
# Num wins: 2
# Num losses: 5
# Win streak: 2
# Loss streak: 5
# Remaining runs: 1310
# Best reward so far: 100.14228999999396
#
# -305.2551699999874
# Num buys: 18
# Num sells: 28
# Num trades: 46
# Num wins: 16
# Num losses: 30
# Win streak: 4
# Loss streak: 9
# Remaining runs: 1309
# Best reward so far: 100.14228999999396
#
# -299.99366999999756
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 0
# Num losses: 6
# Win streak: 0
# Loss streak: 6
# Remaining runs: 1308
# Best reward so far: 100.14228999999396
#
# -517.3290899999756
# Num buys: 29
# Num sells: 41
# Num trades: 70
# Num wins: 24
# Num losses: 46
# Win streak: 5
# Loss streak: 5
# Remaining runs: 1307
# Best reward so far: 100.14228999999396
#
# -111.60237000000575
# Num buys: 21
# Num sells: 21
# Num trades: 42
# Num wins: 16
# Num losses: 26
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1306
# Best reward so far: 100.14228999999396
#
# -1309.5733399999929
# Num buys: 53
# Num sells: 50
# Num trades: 103
# Num wins: 31
# Num losses: 72
# Win streak: 5
# Loss streak: 9
# Remaining runs: 1305
# Best reward so far: 100.14228999999396
#
# -633.1342400000067
# Num buys: 6
# Num sells: 14
# Num trades: 20
# Num wins: 3
# Num losses: 17
# Win streak: 2
# Loss streak: 16
# Remaining runs: 1304
# Best reward so far: 100.14228999999396
#
# -174.99749000000094
# Num buys: 2
# Num sells: 4
# Num trades: 6
# Num wins: 1
# Num losses: 5
# Win streak: 1
# Loss streak: 3
# Remaining runs: 1303
# Best reward so far: 100.14228999999396
#
# -1245.5194599999986
# Num buys: 58
# Num sells: 66
# Num trades: 124
# Num wins: 40
# Num losses: 84
# Win streak: 4
# Loss streak: 10
# Remaining runs: 1302
# Best reward so far: 100.14228999999396
#
# -457.12162999997736
# Num buys: 29
# Num sells: 25
# Num trades: 54
# Num wins: 18
# Num losses: 36
# Win streak: 2
# Loss streak: 6
# Remaining runs: 1301
# Best reward so far: 100.14228999999396
#
# -390.03857999999116
# Num buys: 24
# Num sells: 36
# Num trades: 60
# Num wins: 21
# Num losses: 39
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1300
# Best reward so far: 100.14228999999396
#
# -437.7517100000092
# Num buys: 9
# Num sells: 17
# Num trades: 26
# Num wins: 7
# Num losses: 19
# Win streak: 1
# Loss streak: 6
# Remaining runs: 1299
# Best reward so far: 100.14228999999396
#
# -99.99871999999573
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 1298
# Best reward so far: 100.14228999999396
#
# -127.3360899999871
# Num buys: 18
# Num sells: 17
# Num trades: 35
# Num wins: 13
# Num losses: 22
# Win streak: 4
# Loss streak: 4
# Remaining runs: 1297
# Best reward so far: 100.14228999999396
#
# -24.99806999999967
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Remaining runs: 1296
# Best reward so far: 100.14228999999396
#
# -671.4458600000206
# Num buys: 34
# Num sells: 49
# Num trades: 83
# Num wins: 28
# Num losses: 55
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1295
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1294
# Best reward so far: 100.14228999999396
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1293
# Best reward so far: 100.14228999999396
#
# -149.99673999999288
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1292
# Best reward so far: 100.14228999999396
#
# -537.9792499999791
# Num buys: 23
# Num sells: 30
# Num trades: 53
# Num wins: 17
# Num losses: 36
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1291
# Best reward so far: 100.14228999999396
#
# -49.998959999995535
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1290
# Best reward so far: 100.14228999999396
#
# -302.59938000000943
# Num buys: 4
# Num sells: 7
# Num trades: 11
# Num wins: 2
# Num losses: 9
# Win streak: 1
# Loss streak: 5
# Remaining runs: 1289
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1288
# Best reward so far: 100.14228999999396
#
# -274.7062899999959
# Num buys: 2
# Num sells: 6
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 7
# Remaining runs: 1287
# Best reward so far: 100.14228999999396
#
# -538.8032899999791
# Num buys: 23
# Num sells: 30
# Num trades: 53
# Num wins: 17
# Num losses: 36
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1286
# Best reward so far: 100.14228999999396
#
# -893.4886200000061
# Num buys: 12
# Num sells: 23
# Num trades: 35
# Num wins: 7
# Num losses: 28
# Win streak: 1
# Loss streak: 8
# Remaining runs: 1285
# Best reward so far: 100.14228999999396
#
# -274.9939099999976
# Num buys: 4
# Num sells: 4
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 4
# Remaining runs: 1284
# Best reward so far: 100.14228999999396
#
# -149.99299999999857
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1283
# Best reward so far: 100.14228999999396
#
# -149.99299999999857
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1282
# Best reward so far: 100.14228999999396
#
# -302.59938000000943
# Num buys: 4
# Num sells: 7
# Num trades: 11
# Num wins: 2
# Num losses: 9
# Win streak: 1
# Loss streak: 5
# Remaining runs: 1281
# Best reward so far: 100.14228999999396
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 1280
# Best reward so far: 100.14228999999396
#
# -664.655409999984
# Num buys: 35
# Num sells: 43
# Num trades: 78
# Num wins: 26
# Num losses: 52
# Win streak: 3
# Loss streak: 8
# Remaining runs: 1279
# Best reward so far: 100.14228999999396
#
# -462.8902700000019
# Num buys: 22
# Num sells: 27
# Num trades: 49
# Num wins: 16
# Num losses: 33
# Win streak: 2
# Loss streak: 7
# Remaining runs: 1278
# Best reward so far: 100.14228999999396
#
# -149.99744999999564
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1277
# Best reward so far: 100.14228999999396
#
# -49.999069999994276
# Num buys: 1
# Num sells: 5
# Num trades: 6
# Num wins: 2
# Num losses: 4
# Win streak: 2
# Loss streak: 4
# Remaining runs: 1276
# Best reward so far: 100.14228999999396
#
# -99.99954999999653
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 1275
# Best reward so far: 100.14228999999396
#
# -860.5178799999625
# Num buys: 39
# Num sells: 43
# Num trades: 82
# Num wins: 26
# Num losses: 56
# Win streak: 2
# Loss streak: 7
# Remaining runs: 1274
# Best reward so far: 100.14228999999396
#
# -224.99732999999213
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 6
# Remaining runs: 1273
# Best reward so far: 100.14228999999396
#
# -584.6430200000125
# Num buys: 11
# Num sells: 23
# Num trades: 34
# Num wins: 9
# Num losses: 25
# Win streak: 4
# Loss streak: 7
# Remaining runs: 1272
# Best reward so far: 100.14228999999396
#
# -74.99830000001037
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 1
# Num losses: 3
# Win streak: 1
# Loss streak: 3
# Remaining runs: 1271
# Best reward so far: 100.14228999999396
#
# -24.99870000000965
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Remaining runs: 1270
# Best reward so far: 100.14228999999396
#
# -436.5606200000018
# Num buys: 26
# Num sells: 40
# Num trades: 66
# Num wins: 23
# Num losses: 43
# Win streak: 4
# Loss streak: 9
# Remaining runs: 1269
# Best reward so far: 100.14228999999396
#
# -358.3953799999998
# Num buys: 25
# Num sells: 22
# Num trades: 47
# Num wins: 16
# Num losses: 31
# Win streak: 2
# Loss streak: 6
# Remaining runs: 1268
# Best reward so far: 100.14228999999396
#
# -944.9276600000221
# Num buys: 12
# Num sells: 24
# Num trades: 36
# Num wins: 7
# Num losses: 29
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1267
# Best reward so far: 100.14228999999396
#
# -289.2770500000184
# Num buys: 16
# Num sells: 17
# Num trades: 33
# Num wins: 11
# Num losses: 22
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1266
# Best reward so far: 100.14228999999396
#
# -847.5933700000251
# Num buys: 18
# Num sells: 31
# Num trades: 49
# Num wins: 13
# Num losses: 36
# Win streak: 2
# Loss streak: 10
# Remaining runs: 1265
# Best reward so far: 100.14228999999396
#
# -1332.0221999999796
# Num buys: 72
# Num sells: 66
# Num trades: 138
# Num wins: 45
# Num losses: 93
# Win streak: 4
# Loss streak: 8
# Remaining runs: 1264
# Best reward so far: 100.14228999999396
#
# -340.4317200000055
# Num buys: 15
# Num sells: 14
# Num trades: 29
# Num wins: 9
# Num losses: 20
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1263
# Best reward so far: 100.14228999999396
#
# -483.5401899999922
# Num buys: 34
# Num sells: 28
# Num trades: 62
# Num wins: 21
# Num losses: 41
# Win streak: 2
# Loss streak: 6
# Remaining runs: 1262
# Best reward so far: 100.14228999999396
#
# -893.4886200000061
# Num buys: 12
# Num sells: 23
# Num trades: 35
# Num wins: 7
# Num losses: 28
# ...
# Best reward so far: 125.14119999998837
#
# -308.41562000000744
# Num buys: 6
# Num sells: 10
# Num trades: 16
# Num wins: 4
# Num losses: 12
# Win streak: 2
# Loss streak: 8
# Remaining runs: 484
# Best reward so far: 125.14119999998837
#
# -398.35701000000574
# Num buys: 30
# Num sells: 45
# Num trades: 75
# Num wins: 27
# Num losses: 48
# Win streak: 3
# Loss streak: 8
# Remaining runs: 483
# Best reward so far: 125.14119999998837
#
# -227.5999500000038
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 6
# Remaining runs: 482
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 481
# Best reward so far: 125.14119999998837
#
# -804.6083599999956
# Num buys: 43
# Num sells: 40
# Num trades: 83
# Num wins: 27
# Num losses: 56
# Win streak: 3
# Loss streak: 11
# Remaining runs: 480
# Best reward so far: 125.14119999998837
#
# -2284.032279999983
# Num buys: 80
# Num sells: 102
# Num trades: 182
# Num wins: 55
# Num losses: 127
# Win streak: 4
# Loss streak: 10
# Remaining runs: 479
# Best reward so far: 125.14119999998837
#
# -74.71017999999148
# Num buys: 1
# Num sells: 8
# Num trades: 9
# Num wins: 3
# Num losses: 6
# Win streak: 3
# Loss streak: 6
# Remaining runs: 478
# Best reward so far: 125.14119999998837
#
# -231.79794999997708
# Num buys: 31
# Num sells: 26
# Num trades: 57
# Num wins: 21
# Num losses: 36
# Win streak: 2
# Loss streak: 6
# Remaining runs: 477
# Best reward so far: 125.14119999998837
#
# -49.71091999999209
# Num buys: 0
# Num sells: 6
# Num trades: 6
# Num wins: 2
# Num losses: 4
# Win streak: 2
# Loss streak: 4
# Remaining runs: 476
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 475
# Best reward so far: 125.14119999998837
#
# -124.85610000001202
# Num buys: 3
# Num sells: 7
# Num trades: 10
# Num wins: 3
# Num losses: 7
# Win streak: 1
# Loss streak: 6
# Remaining runs: 474
# Best reward so far: 125.14119999998837
#
# -537.3208100000012
# Num buys: 9
# Num sells: 14
# Num trades: 23
# Num wins: 5
# Num losses: 18
# Win streak: 2
# Loss streak: 7
# Remaining runs: 473
# Best reward so far: 125.14119999998837
#
# -224.99732999999213
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 6
# Remaining runs: 472
# Best reward so far: 125.14119999998837
#
# -1743.0244599999965
# Num buys: 74
# Num sells: 92
# Num trades: 166
# Num wins: 53
# Num losses: 113
# Win streak: 4
# Loss streak: 10
# Remaining runs: 471
# Best reward so far: 125.14119999998837
#
# -417.1840200000064
# Num buys: 24
# Num sells: 34
# Num trades: 58
# Num wins: 20
# Num losses: 38
# Win streak: 3
# Loss streak: 7
# Remaining runs: 470
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 469
# Best reward so far: 125.14119999998837
#
# -252.7105099999929
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 0
# Num losses: 5
# Win streak: 0
# Loss streak: 5
# Remaining runs: 468
# Best reward so far: 125.14119999998837
#
# -334.14122000000157
# Num buys: 17
# Num sells: 12
# Num trades: 29
# Num wins: 9
# Num losses: 20
# Win streak: 3
# Loss streak: 7
# Remaining runs: 467
# Best reward so far: 125.14119999998837
#
# -227.11820999998127
# Num buys: 17
# Num sells: 15
# Num trades: 32
# Num wins: 11
# Num losses: 21
# Win streak: 3
# Loss streak: 7
# Remaining runs: 466
# Best reward so far: 125.14119999998837
#
# -229.63304999999247
# Num buys: 20
# Num sells: 17
# Num trades: 37
# Num wins: 13
# Num losses: 24
# Win streak: 4
# Loss streak: 5
# Remaining runs: 465
# Best reward so far: 125.14119999998837
#
# -918.2047599999711
# Num buys: 39
# Num sells: 54
# Num trades: 93
# Num wins: 30
# Num losses: 63
# Win streak: 2
# Loss streak: 11
# Remaining runs: 464
# Best reward so far: 125.14119999998837
#
# -667.4389200000167
# Num buys: 28
# Num sells: 40
# Num trades: 68
# Num wins: 22
# Num losses: 46
# Win streak: 3
# Loss streak: 7
# Remaining runs: 463
# Best reward so far: 125.14119999998837
#
# -540.2788700000037
# Num buys: 35
# Num sells: 43
# Num trades: 78
# Num wins: 27
# Num losses: 51
# Win streak: 6
# Loss streak: 8
# Remaining runs: 462
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 461
# Best reward so far: 125.14119999998837
#
# -289.1045100000167
# Num buys: 14
# Num sells: 14
# Num trades: 28
# Num wins: 9
# Num losses: 19
# Win streak: 4
# Loss streak: 10
# Remaining runs: 460
# Best reward so far: 125.14119999998837
#
# -1747.7445400000097
# Num buys: 92
# Num sells: 109
# Num trades: 201
# Num wins: 67
# Num losses: 134
# Win streak: 5
# Loss streak: 8
# Remaining runs: 459
# Best reward so far: 125.14119999998837
#
# -252.25427999999727
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 0
# Num losses: 5
# Win streak: 0
# Loss streak: 5
# Remaining runs: 458
# Best reward so far: 125.14119999998837
#
# -49.822329999996306
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 4
# Num losses: 7
# Win streak: 3
# Loss streak: 4
# Remaining runs: 457
# Best reward so far: 125.14119999998837
#
# -274.7524100000098
# Num buys: 2
# Num sells: 6
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 7
# Remaining runs: 456
# Best reward so far: 125.14119999998837
#
# -583.9277000000047
# Num buys: 7
# Num sells: 12
# Num trades: 19
# Num wins: 3
# Num losses: 16
# Win streak: 1
# Loss streak: 12
# Remaining runs: 455
# Best reward so far: 125.14119999998837
#
# -537.750000000007
# Num buys: 8
# Num sells: 15
# Num trades: 23
# Num wins: 5
# Num losses: 18
# Win streak: 1
# Loss streak: 12
# Remaining runs: 454
# Best reward so far: 125.14119999998837
#
# -149.99299999999857
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 453
# Best reward so far: 125.14119999998837
#
# -1739.6043199999965
# Num buys: 74
# Num sells: 92
# Num trades: 166
# Num wins: 53
# Num losses: 113
# Win streak: 4
# Loss streak: 10
# Remaining runs: 452
# Best reward so far: 125.14119999998837
#
# -349.9953800000037
# Num buys: 3
# Num sells: 4
# Num trades: 7
# Num wins: 0
# Num losses: 7
# Win streak: 0
# Loss streak: 7
# Remaining runs: 451
# Best reward so far: 125.14119999998837
#
# -387.38008999999636
# Num buys: 19
# Num sells: 26
# Num trades: 45
# Num wins: 15
# Num losses: 30
# Win streak: 2
# Loss streak: 9
# Remaining runs: 450
# Best reward so far: 125.14119999998837
#
# -308.6656900000181
# Num buys: 18
# Num sells: 18
# Num trades: 36
# Num wins: 12
# Num losses: 24
# Win streak: 3
# Loss streak: 8
# Remaining runs: 449
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 448
# Best reward so far: 125.14119999998837
#
# -99.99891000000886
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 2
# Num losses: 5
# Win streak: 1
# Loss streak: 5
# Remaining runs: 447
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 446
# Best reward so far: 125.14119999998837
#
# -1917.2789299999695
# Num buys: 53
# Num sells: 67
# Num trades: 120
# Num wins: 33
# Num losses: 87
# Win streak: 3
# Loss streak: 10
# Remaining runs: 445
# Best reward so far: 125.14119999998837
#
# -366.5324500000008
# Num buys: 28
# Num sells: 34
# Num trades: 62
# Num wins: 22
# Num losses: 40
# Win streak: 4
# Loss streak: 12
# Remaining runs: 444
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 443
# Best reward so far: 125.14119999998837
#
# -308.82717000000986
# Num buys: 12
# Num sells: 9
# Num trades: 21
# Num wins: 6
# Num losses: 15
# Win streak: 3
# Loss streak: 9
# Remaining runs: 442
# Best reward so far: 125.14119999998837
#
# -488.2356999999838
# Num buys: 23
# Num sells: 29
# Num trades: 52
# Num wins: 17
# Num losses: 35
# Win streak: 2
# Loss streak: 9
# Remaining runs: 441
# Best reward so far: 125.14119999998837
#
# -1119.2505600000077
# Num buys: 33
# Num sells: 34
# Num trades: 67
# Num wins: 18
# Num losses: 49
# Win streak: 3
# Loss streak: 11
# Remaining runs: 440
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 439
# Best reward so far: 125.14119999998837
#
# -457.16158999999146
# Num buys: 18
# Num sells: 26
# Num trades: 44
# Num wins: 14
# Num losses: 30
# Win streak: 5
# Loss streak: 9
# Remaining runs: 438
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 437
# Best reward so far: 125.14119999998837
#
# -1372.359830000016
# Num buys: 74
# Num sells: 90
# Num trades: 164
# Num wins: 55
# Num losses: 109
# Win streak: 5
# Loss streak: 8
# Remaining runs: 436
# Best reward so far: 125.14119999998837
#
# -1737.2464199999922
# Num buys: 73
# Num sells: 88
# Num trades: 161
# Num wins: 51
# Num losses: 110
# Win streak: 4
# Loss streak: 11
# Remaining runs: 435
# Best reward so far: 125.14119999998837
#
# -174.99792999998533
# Num buys: 1
# Num sells: 5
# Num trades: 6
# Num wins: 1
# Num losses: 5
# Win streak: 1
# Loss streak: 5
# Remaining runs: 434
# Best reward so far: 125.14119999998837
#
# -2383.0674599999797
# Num buys: 62
# Num sells: 82
# Num trades: 144
# Num wins: 39
# Num losses: 105
# Win streak: 3
# Loss streak: 12
# Remaining runs: 433
# Best reward so far: 125.14119999998837
#
# -258.1968199999901
# Num buys: 22
# Num sells: 38
# Num trades: 60
# Num wins: 22
# Num losses: 38
# Win streak: 4
# Loss streak: 8
# Remaining runs: 432
# Best reward so far: 125.14119999998837
#
# 74.99946999999591
# Num buys: 1
# Num sells: 5
# Num trades: 6
# Num wins: 3
# Num losses: 3
# Win streak: 2
# Loss streak: 3
# Remaining runs: 431
# Best reward so far: 125.14119999998837
#
# -174.99749000000094
# Num buys: 2
# Num sells: 4
# Num trades: 6
# Num wins: 1
# Num losses: 5
# Win streak: 1
# Loss streak: 3
# Remaining runs: 430
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 429
# Best reward so far: 125.14119999998837
#
# -790.9114300000168
# Num buys: 31
# Num sells: 37
# Num trades: 68
# Num wins: 21
# Num losses: 47
# Win streak: 2
# Loss streak: 7
# Remaining runs: 428
# Best reward so far: 125.14119999998837
#
# -277.35695000001454
# Num buys: 3
# Num sells: 10
# Num trades: 13
# Num wins: 3
# Num losses: 10
# Win streak: 2
# Loss streak: 8
# Remaining runs: 427
# Best reward so far: 125.14119999998837
#
# -483.1466499999922
# Num buys: 34
# Num sells: 28
# Num trades: 62
# Num wins: 21
# Num losses: 41
# Win streak: 2
# Loss streak: 6
# Remaining runs: 426
# Best reward so far: 125.14119999998837
#
# -489.36583000002645
# Num buys: 13
# Num sells: 24
# Num trades: 37
# Num wins: 11
# Num losses: 26
# Win streak: 2
# Loss streak: 7
# Remaining runs: 425
# Best reward so far: 125.14119999998837
#
# -287.6971999999863
# Num buys: 19
# Num sells: 19
# Num trades: 38
# Num wins: 13
# Num losses: 25
# Win streak: 3
# Loss streak: 7
# Remaining runs: 424
# Best reward so far: 125.14119999998837
#
# -557.693909999987
# Num buys: 21
# Num sells: 25
# Num trades: 46
# Num wins: 14
# Num losses: 32
# Win streak: 3
# Loss streak: 8
# Remaining runs: 423
# Best reward so far: 125.14119999998837
#
# -583.2332600000047
# Num buys: 7
# Num sells: 12
# Num trades: 19
# Num wins: 3
# Num losses: 16
# Win streak: 1
# Loss streak: 12
# Remaining runs: 422
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 421
# Best reward so far: 125.14119999998837
#
# -49.99959999999903
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 420
# Best reward so far: 125.14119999998837
#
# -25.000050000006986
# Num buys: 0
# Num sells: 3
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 1
# Remaining runs: 419
# Best reward so far: 125.14119999998837
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 418
# Best reward so far: 125.14119999998837
#
# -1037.4999300000068
# Num buys: 8
# Num sells: 20
# Num trades: 28
# Num wins: 3
# Num losses: 25
# Win streak: 2
# Loss streak: 22
# Remaining runs: 417
# Best reward so far: 125.14119999998837
#
# -149.9986100000082
# Num buys: 2
# Num sells: 6
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 1
# Loss streak: 6
# Remaining runs: 416
# Best reward so far: 125.14119999998837
#
# -99.9991100000093
# Num buys: 4
# Num sells: 8
# Num trades: 12
# Num wins: 4
# Num losses: 8
# Win streak: 1
# Loss streak: 4
# Remaining runs: 415
# Best reward so far: 125.14119999998837
#
# -149.9966899999987
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 414
# Best reward so far: 125.14119999998837
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-7d91d2a0c4f5> in <module>
#      77
#      78 for risk_reward_ratio, spread_cutoff, chop_cutoff, chop_num, use_rsi, strict_rsi, use_long_stoch, use_half_sar, adx_cutoff, use_adx, use_candles, use_spread_cushion, use_sar_distances, std_mult, use_ema in combos_to_try:
# ---> 79     reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked = run_simulation(risk_reward_ratio, spread_cutoff, chop_cutoff, chop_num, use_rsi, strict_rsi, use_long_stoch, use_half_sar, adx_cutoff, use_adx, use_candles, use_spread_cushion, use_sar_distances, std_mult, use_ema)
#      80     runs_finished += 1
#      81
#
# <ipython-input-17-29f3f4e1b6ee> in run_simulation(risk_reward_ratio, spread_cutoff, chop_cutoff, chop_num, use_rsi, strict_rsi, use_long_stoch, use_half_sar, adx_cutoff, use_adx, use_candles, use_spread_cushion, use_sar_distances, std_mult, use_ema)
#      45             continue
#      46         ema200_2, ema100_2, ema50_2, ema25_2, atr2, sar2, rsi2, rsi_sma2, mid_open2, mid_close2, mid_low2, mid_high2, vo2, adx2 = df.loc[df.index[i - 2], ['ema200', 'ema100', 'ema50', 'ema25', 'atr', 'sar', 'rsi', 'rsi_sma', 'Mid_Open', 'Mid_Close', 'Mid_Low', 'Mid_High', 'vo', 'adx']]
# ---> 47         ema200_1, ema100_1, ema50_1, ema25_1, atr1, sar1, rsi1, rsi_sma1, mid_open1, mid_close1, mid_low1, mid_high1, vo1, adx1 = df.loc[df.index[i - 1], ['ema200', 'ema100', 'ema50', 'ema25', 'atr', 'sar', 'rsi', 'rsi_sma', 'Mid_Open', 'Mid_Close', 'Mid_Low', 'Mid_High', 'vo', 'adx']]
#      48         curr_ao = df.loc[df.index[i], 'Ask_Open']
#      49         curr_bo = df.loc[df.index[i], 'Bid_Open']
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     836                 # We don't need to check for tuples here because those are
#     837                 #  caught by the _is_nested_tuple_indexer check above.
# --> 838                 section = self._getitem_axis(key, axis=i)
#     839
#     840                 # We should never have a scalar section here, because
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1109         return self._getitem_tuple_same_dim(tup)
#    1110
# -> 1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
#    1113         return self.obj.xs(label, axis=axis)
#
# KeyboardInterrupt:

# %%
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best chop cutoff val: ' + str(best_chop_cutoff_val))
print('Best chop val: ' + str(best_chop_num))
print('Best use rsi val: ' + str(best_use_rsi_val))
print('Best strict rsi val: ' + str(best_strict_rsi_val))
print('Best use long stoch val: ' + str(best_use_long_stoch_val))
print('Best use half sar val: ' + str(best_use_half_sar_val))
print('Best adx cutoff: ' + str(best_adx_cutoff))
print('Best use adx val: ' + str(best_use_adx))
print('Best use candle val: ' + str(best_use_candle_val))
print('Best use spread cushion val: ' + str(best_use_spread_cushion_val))
print('Best use sar distances val: ' + str(best_use_sar_distances_val))
print('Best std mult: ' + str(best_std_mult))
print('Best use ema val: ' + str(best_use_ema))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 125.14119999998837
# Best risk/reward ratio: 1.5
# Best spread: 0.2
# Best chop cutoff val: 0.5
# Best chop val: 36
# Best use rsi val: True
# Best strict rsi val: False
# Best use long stoch val: False
# Best use half sar val: False
# Best adx cutoff: 40
# Best use adx val: True
# Best use candle val: False
# Best use spread cushion val: True
# Best use sar distances val: True
# Best std mult: 2.0
# Best use ema val: True
# -----------------------
# Top results:
# {'reward': 25, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': False, 'use_half_sar': False, 'adx_cutoff': 30, 'use_adx': True, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 75, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': False, 'use_half_sar': False, 'adx_cutoff': 30, 'use_adx': False, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 100, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 40, 'use_adx': True, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 2.0, 'use_ema': True}
# {'reward': 74, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 20, 'use_adx': False, 'use_candles': False, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 125, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': False, 'use_half_sar': False, 'adx_cutoff': 40, 'use_adx': True, 'use_candles': False, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 2.0, 'use_ema': True}
# {'reward': 75, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': False, 'use_half_sar': False, 'adx_cutoff': 20, 'use_adx': False, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 23, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 20, 'use_adx': False, 'use_candles': False, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 2.0, 'use_ema': True}
# {'reward': 25, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 40, 'use_adx': True, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 75, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': False, 'use_half_sar': False, 'adx_cutoff': 40, 'use_adx': False, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 25, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': False, 'use_half_sar': False, 'adx_cutoff': 30, 'use_adx': True, 'use_candles': False, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 22, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 40, 'use_adx': False, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 2.0, 'use_ema': True}
# {'reward': 22, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 20, 'use_adx': True, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 2.0, 'use_ema': True}
# {'reward': 25, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 40, 'use_adx': True, 'use_candles': False, 'use_spread_cushion': False, 'use_sar_distances': True, 'std_mult': 2.0, 'use_ema': True}
# {'reward': 74, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 40, 'use_adx': False, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 23, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 30, 'use_adx': False, 'use_candles': False, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 2.0, 'use_ema': True}
# {'reward': 74, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 30, 'use_adx': False, 'use_candles': False, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 74, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 20, 'use_adx': True, 'use_candles': True, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 50, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': False, 'use_half_sar': False, 'adx_cutoff': 40, 'use_adx': True, 'use_candles': True, 'use_spread_cushion': False, 'use_sar_distances': True, 'std_mult': 2.0, 'use_ema': True}
# {'reward': 74, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 40, 'use_adx': False, 'use_candles': False, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
# {'reward': 74, 'ratio': 1.5, 'spread_cutoff': 0.2, 'chop_cutoff': 0.5, 'chop_num': 36, 'use_rsi': True, 'strict_rsi': False, 'use_long_stoch': True, 'use_half_sar': False, 'adx_cutoff': 20, 'use_adx': True, 'use_candles': False, 'use_spread_cushion': True, 'use_sar_distances': True, 'std_mult': 1.0, 'use_ema': True}
