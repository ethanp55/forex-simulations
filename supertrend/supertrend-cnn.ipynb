# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from pyts.image import RecurrencePlot, GramianAngularField
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model, Sequential
import json
import time
from collections import deque
import warnings
from pickle import dump, load
from sklearn.preprocessing import StandardScaler

file_path = '/Users/mymac/Google Drive/My Drive/Forex_Robot/'

# %%
currencies = ['Usd_Chf', 'Gbp_Usd', 'Usd_Cad', 'Aud_Usd', 'Eur_Usd', 'Usd_Jpy', 'Nzd_Usd']
years = '2016-2022'

dfs, df_longs = [], []

# news = pd.read_csv(file_path + 'events_2016-2022.csv')
# news = news.rename(columns={'Start': 'Date'})
# news.Date = pd.to_datetime(news.Date)

for currency_pair in currencies:
    # currency1, currency2 = currency_pair.split('_')
    # currency1, currency2 = currency1.upper(), currency2.upper()

    # curr_news = news.loc[(news['Currency'] == currency1) | (news['Currency'] == currency2)]
    # curr_news.drop(['Id', 'Name', 'Currency'], axis=1, inplace=True)
    # curr_news.drop(curr_news[(curr_news['Impact'] != 'LOW') & (curr_news['Impact'] != 'MEDIUM') & (curr_news['Impact'] != 'HIGH')].index, inplace=True)
    # curr_news.loc[curr_news['Impact'] == 'LOW', 'Impact'] = 1
    # curr_news.loc[curr_news['Impact'] == 'MEDIUM', 'Impact'] = 2
    # curr_news.loc[curr_news['Impact'] == 'HIGH', 'Impact'] = 3
    # curr_news = curr_news.groupby('Date')['Impact'].mean().reset_index()

    df = pd.read_csv(file_path + f'Oanda_{currency_pair}_M5_{years}.csv')
    df.Date = pd.to_datetime(df.Date)
    # df.reset_index(drop=True, inplace=True)
    # df = pd.merge(df, curr_news, how='left', on='Date')
    # df.reset_index(drop=True, inplace=True)
    # df = df.fillna(method='ffill')
    df.dropna(inplace=True)
    df.reset_index(drop=True, inplace=True)

    dfs.append(df)

    df_long = pd.read_csv(file_path + f'Oanda_{currency_pair}_M30_{years}.csv')
    df_long.Date = pd.to_datetime(df_long.Date)
    df_long.dropna(inplace=True)
    df_long.reset_index(drop=True, inplace=True)
    df_longs.append(df_long)

# %%
for df in dfs:
    df['sin_hour'] = np.sin(2 * np.pi * df['Date'].dt.hour / 24)
    # df['cos_hour'] = np.cos(2 * np.pi * df['Date'].dt.hour / 24)
    df['sin_day'] = np.sin(2 * np.pi * df['Date'].dt.day / 7)
    # df['cos_day'] = np.cos(2 * np.pi * df['Date'].dt.day / 7)
    df['sin_month'] = np.sin(2 * np.pi * df['Date'].dt.month / 12)

# %%
def psar(barsdata, iaf=0.02, maxaf=0.2):
    length = len(barsdata)
    high = list(barsdata['Mid_High'])
    low = list(barsdata['Mid_Low'])
    close = list(barsdata['Mid_Close'])
    psar = close[0:len(close)]
    bull = True
    af = iaf
    hp = high[0]
    lp = low[0]
    for i in range(2, length):
        if bull:
            psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
        else:
            psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
        reverse = False
        if bull:
            if low[i] < psar[i]:
                bull = False
                reverse = True
                psar[i] = hp
                lp = low[i]
                af = iaf
        else:
            if high[i] > psar[i]:
                bull = True
                reverse = True
                psar[i] = lp
                hp = high[i]
                af = iaf
        if not reverse:
            if bull:
                if high[i] > hp:
                    hp = high[i]
                    af = min(af + iaf, maxaf)
                if low[i - 1] < psar[i]:
                    psar[i] = low[i - 1]
                if low[i - 2] < psar[i]:
                    psar[i] = low[i - 2]
            else:
                if low[i] < lp:
                    lp = low[i]
                    af = min(af + iaf, maxaf)
                if high[i - 1] > psar[i]:
                    psar[i] = high[i - 1]
                if high[i - 2] > psar[i]:
                    psar[i] = high[i - 2]
    return psar


def atr(high, low, close, lookback=14):
    high_low = high - low
    high_close = np.abs(high - close.shift())
    low_close = np.abs(low - close.shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = np.max(ranges, axis=1)

    return true_range.rolling(lookback).sum() / lookback


def rsi(closes, periods=14):
    close_delta = closes.diff()

    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)
    ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))

    return rsi

  
def adx(high, low, close, lookback=14):
    plus_dm = high.diff()
    minus_dm = low.diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0
    
    tr1 = pd.DataFrame(high - low)
    tr2 = pd.DataFrame(abs(high - close.shift(1)))
    tr3 = pd.DataFrame(abs(low - close.shift(1)))
    frames = [tr1, tr2, tr3]
    tr = pd.concat(frames, axis = 1, join = 'inner').max(axis = 1)
    atr = tr.rolling(lookback).mean()
    
    plus_di = 100 * (plus_dm.ewm(alpha = 1/lookback).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha = 1/lookback).mean() / atr))
    dx = (abs(plus_di - minus_di) / abs(plus_di + minus_di)) * 100
    adx = ((dx.shift(1) * (lookback - 1)) + dx) / lookback
    adx_smooth = adx.ewm(alpha = 1/lookback).mean()

    return adx_smooth


def stoch(high, low, close, lookback=14):
    high_lookback = high.rolling(lookback).max()
    low_lookback = low.rolling(lookback).min()
    slow_k = (close - low_lookback) * 100 / (high_lookback - low_lookback)
    slow_d = slow_k.rolling(3).mean()

    return slow_k, slow_d

def stoch_rsi(data, k_window=3, d_window=3, window=14):
    min_val = data.rolling(window=window, center=False).min()
    max_val = data.rolling(window=window, center=False).max()

    stoch = ((data - min_val) / (max_val - min_val)) * 100

    slow_k = stoch.rolling(window=k_window, center=False).mean()

    slow_d = slow_k.rolling(window=d_window, center=False).mean()

    return slow_k, slow_d

def n_macd(macd, macdsignal, lookback=50):
    n_macd = 2 * (((macd - macd.rolling(lookback).min()) / (macd.rolling(lookback).max() - macd.rolling(lookback).min()))) - 1
    n_macdsignal = 2 * (((macdsignal - macdsignal.rolling(lookback).min()) / (macdsignal.rolling(lookback).max() - macdsignal.rolling(lookback).min()))) - 1

    return n_macd, n_macdsignal

def chop(df, lookback=14):
    atr1 = atr(df, lookback=1)
    high, low = df['Mid_High'], df['Mid_Low']

    chop = np.log10(atr1.rolling(lookback).sum() / (high.rolling(lookback).max() - low.rolling(lookback).min())) / np.log10(lookback)

    return chop

def vo(volume, short_lookback=5, long_lookback=10):
    short_ema =  pd.Series.ewm(volume, span=short_lookback).mean()
    long_ema = pd.Series.ewm(volume, span=long_lookback).mean()

    volume_oscillator = (short_ema - long_ema) / long_ema

    return volume_oscillator

def bar_lengths(bar_lens, window=36):
    return bar_lens.rolling(window=window).mean(), bar_lens.rolling(window=window).std()

def sar_lengths(opens, sars, window=36):
    diffs = abs(opens - sars.shift(1))

    return diffs.rolling(window=window).mean(), diffs.rolling(window=window).std()

def supertrend(barsdata, atr_len=3, mult=3):
    curr_atr = atr(barsdata['Mid_High'], barsdata['Mid_Low'], barsdata['Mid_Close'], lookback=atr_len)
    highs, lows = barsdata['Mid_High'], barsdata['Mid_Low']
    hl2 = (highs + lows) / 2
    final_upperband = upper_band = hl2 + mult * curr_atr
    final_lowerband = lower_band = hl2 - mult * curr_atr

    # initialize Supertrend column to True
    supertrend = [True] * len(df)

    close = barsdata['Mid_Close']
    
    for i in range(1, len(df.index)):
        curr, prev = i, i - 1
        
        # if current close price crosses above upperband
        if close[curr] > final_upperband[prev]:
            supertrend[curr] = True

        # if current close price crosses below lowerband
        elif close[curr] < final_lowerband[prev]:
            supertrend[curr] = False

        # else, the trend continues
        else:
            supertrend[curr] = supertrend[prev]
            
            # adjustment to the final bands
            if supertrend[curr] == True and final_lowerband[curr] < final_lowerband[prev]:
                final_lowerband[curr] = final_lowerband[prev]

            if supertrend[curr] == False and final_upperband[curr] > final_upperband[prev]:
                final_upperband[curr] = final_upperband[prev]

    return supertrend, final_upperband, final_lowerband

# def supertrend(barsdata, atr_len=3, mult=3):
#     curr_atr = atr(barsdata['ha_high'], barsdata['ha_low'], barsdata['ha_close'], lookback=atr_len)
#     highs, lows = barsdata['ha_high'], barsdata['ha_low']
#     hl2 = (highs + lows) / 2
#     final_upperband = upper_band = hl2 + mult * curr_atr
#     final_lowerband = lower_band = hl2 - mult * curr_atr

#     # initialize Supertrend column to True
#     supertrend = [True] * len(df)

#     close = barsdata['ha_close']
    
#     for i in range(1, len(df.index)):
#         curr, prev = i, i - 1
        
#         # if current close price crosses above upperband
#         if close[curr] > final_upperband[prev]:
#             supertrend[curr] = True

#         # if current close price crosses below lowerband
#         elif close[curr] < final_lowerband[prev]:
#             supertrend[curr] = False

#         # else, the trend continues
#         else:
#             supertrend[curr] = supertrend[prev]
            
#             # adjustment to the final bands
#             if supertrend[curr] == True and final_lowerband[curr] < final_lowerband[prev]:
#                 final_lowerband[curr] = final_lowerband[prev]

#             if supertrend[curr] == False and final_upperband[curr] > final_upperband[prev]:
#                 final_upperband[curr] = final_upperband[prev]

#     return supertrend, final_upperband, final_lowerband

def heikin_ashi(opens, highs, lows, closes):
    ha_close = list((opens + highs + lows + closes) / 4)
    ha_opens = []

    opens_list, closes_list = list(opens), list(closes)

    for i in range(len(ha_close)):
        if i == 0:
            ha_opens.append((opens_list[i] + closes_list[i]) / 2)

        else:
            ha_opens.append((ha_opens[i - 1] + ha_close[i - 1]) / 2)

    ha_highs = list(pd.DataFrame({'ha_open': ha_opens, 'ha_close': ha_close, 'high': list(highs)}).max(axis=1))
    ha_lows = list(pd.DataFrame({'ha_open': ha_opens, 'ha_close': ha_close, 'low': list(lows)}).min(axis=1))

    return ha_opens, ha_highs, ha_lows, ha_close

def trend_indicator(opens, highs, lows, closes, ema_period=50, smoothing_period=10):
    ha_open, ha_high, ha_low, ha_close = heikin_ashi(opens, highs, lows, closes)

    ha_o_ema = pd.Series.ewm(pd.DataFrame({'ha_open': ha_open}), span=ema_period).mean()
    ha_h_ema = pd.Series.ewm(pd.DataFrame({'ha_high': ha_high}), span=ema_period).mean()
    ha_l_ema = pd.Series.ewm(pd.DataFrame({'ha_low': ha_low}), span=ema_period).mean()
    ha_c_ema = pd.Series.ewm(pd.DataFrame({'ha_close': ha_close}), span=ema_period).mean()

    return pd.Series.ewm(ha_o_ema, span=smoothing_period).mean(), pd.Series.ewm(ha_h_ema, span=smoothing_period).mean(), pd.Series.ewm(ha_l_ema, span=smoothing_period).mean(), pd.Series.ewm(ha_c_ema, span=smoothing_period).mean()

def qqe_mod(barsdata, rsi_period=6, smoothing=5, qqe_factor=5, qqe2_factor=1.61, threshold=3, mult=0.35, sma_length=50):
    wilders_period = rsi_period * 2 - 1

    curr_rsi = rsi(barsdata, periods=rsi_period)
    rsi_ema = pd.Series.ewm(curr_rsi, span=smoothing).mean()
    atr_rsi = abs(rsi_ema.shift(1) - rsi_ema)
    atr_rsi_ema = pd.Series.ewm(atr_rsi, span=wilders_period).mean()
    dar = pd.Series.ewm(atr_rsi_ema, span=wilders_period).mean() * qqe_factor

    newshortband = rsi_ema + dar
    newlongband = rsi_ema - dar

    rsi_ema_list = list(rsi_ema)

    longband = [0]
    for i in range(1, len(rsi_ema_list)):
        if rsi_ema_list[i - 1] > longband[i - 1] and rsi_ema_list[i] > longband[i - 1]:
            longband.append(max(longband[i - 1],newlongband[i]))

        else:
            longband.append(newlongband[i])

    shortband = [0]
    for i in range(1,len(rsi_ema_list)):
        if rsi_ema_list[i - 1] < shortband[i - 1] and rsi_ema_list[i] < shortband[i - 1]:
            shortband.append(min(shortband[i - 1],newshortband[i]))
            
        else:
            shortband.append(newshortband[i])

    longband = pd.Series(longband)
    shortband = pd.Series(shortband)

    trend = np.where(rsi_ema > longband.shift(1), 1, -1)    
    fastatrrsitl = pd.Series(np.where(trend == 1, longband, shortband))

    basis = (fastatrrsitl - 50).rolling(window=sma_length).mean()
    dev = (fastatrrsitl - 50).rolling(window=sma_length).std() * mult
    upper = basis + dev
    lower = basis - dev

    greenbar1 = rsi_ema - 50 > threshold
    greenbar2 = rsi_ema - 50 > upper
    redbar1 = rsi_ema - 50 < threshold
    redbar2 = rsi_ema - 50 < lower

    # uptrend = np.where((greenbar1 & greenbar2), True, False)
    # downtrend = np.where((redbar1 & redbar2), True, False)

    uptrend = np.where((greenbar2), True, False)
    downtrend = np.where((redbar2), True, False)

    return uptrend, downtrend

def williams_r(highs, lows, closes, length=21, ema_length=15):
    highest_highs = highs.rolling(window=length).max()
    lowest_lows = lows.rolling(window=length).min()

    willy = 100 * (closes - highest_highs) / (highest_highs - lowest_lows)
    willy_ema = pd.Series.ewm(willy, span=ema_length).mean()

    return willy, willy_ema

# %%
# bid_ask_mid_prices_list = []

# for df in dfs:
#     # Add technical indicators (for additional features)
#     df['ha_open'], df['ha_high'], df['ha_low'], df['ha_close'] = heikin_ashi(df['Mid_Open'], df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

#     df['ema200'] = pd.Series.ewm(df['ha_close'], span=200).mean()
#     df['ema100'] = pd.Series.ewm(df['ha_close'], span=100).mean()
#     df['ema50'] = pd.Series.ewm(df['ha_close'], span=50).mean()

#     df['atr'] = atr(df['ha_high'], df['ha_low'], df['ha_close'])
#     df['atr_sma'] = df['atr'].rolling(window=20).mean()
#     df['rsi'] = rsi(df['ha_close'])
#     df['rsi_sma'] = df['rsi'].rolling(50).mean()
#     df['adx'] = adx(df['ha_high'], df['ha_low'], df['ha_close'])
#     df['macd'] = pd.Series.ewm(df['ha_close'], span=12).mean() - pd.Series.ewm(df['ha_close'], span=26).mean()
#     df['macdsignal'] = pd.Series.ewm(df['macd'], span=9).mean()
#     df['slowk_rsi'], df['slowd_rsi'] = stoch_rsi(df['rsi'])

#     df['vo'] = vo(df['Volume'])

#     df['willy'], df['willy_ema'] = williams_r(df['ha_high'], df['ha_low'], df['ha_close'])

#     df['supertrend'], df['supertrend_ub'], df['supertrend_lb'] = supertrend(df)
#     df['ti_o'], df['ti_h'], df['ti_l'], df['ti_c'] = trend_indicator(df['ha_open'], df['ha_high'], df['ha_low'], df['ha_close'])

#     df.dropna(inplace=True)
#     df.reset_index(drop=True, inplace=True)

#     # Extract the bid and ask prices and fractals and remove them from the df
#     bid_ask_mid_prices = df[['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'ha_open', 'ha_high', 'ha_low', 'ha_close']]
#     df.drop(['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'Volume', 'ha_open', 'ha_high', 'ha_low', 'ha_close'], axis=1, inplace=True)
#     bid_ask_mid_prices_list.append(bid_ask_mid_prices)

#     df.dropna(inplace=True)
#     df.reset_index(drop=True, inplace=True)

# for df_long in df_longs:
#     df_long['ha_open'], df_long['ha_high'], df_long['ha_low'], df_long['ha_close'] = heikin_ashi(df_long['Mid_Open'], df_long['Mid_High'], df_long['Mid_Low'], df_long['Mid_Close'])

#     df_long['ema200'] = pd.Series.ewm(df_long['ha_close'], span=200).mean()
#     df_long['ema100'] = pd.Series.ewm(df_long['ha_close'], span=100).mean()
#     df_long['ema50'] = pd.Series.ewm(df_long['ha_close'], span=50).mean()

#     df_long['atr'] = atr(df_long['ha_high'], df_long['ha_low'], df_long['ha_close'])
#     df_long['atr_sma'] = df_long['atr'].rolling(window=20).mean()
#     df_long['rsi'] = rsi(df_long['ha_close'])
#     df_long['rsi_sma'] = df_long['rsi'].rolling(50).mean()
#     df_long['adx'] = adx(df_long['ha_high'], df_long['ha_low'], df_long['ha_close'])
#     df_long['macd'] = pd.Series.ewm(df_long['ha_close'], span=12).mean() - pd.Series.ewm(df_long['ha_close'], span=26).mean()
#     df_long['macdsignal'] = pd.Series.ewm(df_long['macd'], span=9).mean()
#     df_long['slowk_rsi'], df_long['slowd_rsi'] = stoch_rsi(df_long['rsi'])

#     df_long['vo'] = vo(df_long['Volume'])

#     df_long['willy'], df_long['willy_ema'] = williams_r(df_long['ha_high'], df_long['ha_low'], df_long['ha_close'])

#     df_long.dropna(inplace=True)
#     df_long.reset_index(drop=True, inplace=True)

#     df_long.drop(['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'Volume', 'ha_open', 'ha_high', 'ha_low', 'ha_close'], axis=1, inplace=True)

#     df_long.dropna(inplace=True)
#     df_long.reset_index(drop=True, inplace=True)

# %%
bid_ask_mid_prices_list = []

for df in dfs:
    # Add technical indicators (for additional features)
    df['ema200'] = pd.Series.ewm(df['Mid_Close'], span=200).mean()
    df['ema100'] = pd.Series.ewm(df['Mid_Close'], span=100).mean()
    # df['ema50'] = pd.Series.ewm(df['Mid_Close'], span=50).mean()

    df['atr'] = atr(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])
    df['atr_sma'] = df['atr'].rolling(window=20).mean()
    df['rsi'] = rsi(df['Mid_Close'])
    df['rsi_sma'] = df['rsi'].rolling(50).mean()
    df['adx'] = adx(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])
    df['macd'] = pd.Series.ewm(df['Mid_Close'], span=12).mean() - pd.Series.ewm(df['Mid_Close'], span=26).mean()
    df['macdsignal'] = pd.Series.ewm(df['macd'], span=9).mean()
    df['slowk_rsi'], df['slowd_rsi'] = stoch_rsi(df['rsi'])

    df['vo'] = vo(df['Volume'])

    df['willy'], df['willy_ema'] = williams_r(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

    df['supertrend'], df['supertrend_ub'], df['supertrend_lb'] = supertrend(df)
    df['ti_o'], df['ti_h'], df['ti_l'], df['ti_c'] = trend_indicator(df['Mid_Open'], df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

    df.dropna(inplace=True)
    df.reset_index(drop=True, inplace=True)

    # Extract the bid and ask prices and fractals and remove them from the df
    bid_ask_mid_prices = df[['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close']]
    df.drop(['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'Volume'], axis=1, inplace=True)
    bid_ask_mid_prices_list.append(bid_ask_mid_prices)

    df.dropna(inplace=True)
    df.reset_index(drop=True, inplace=True)

for df_long in df_longs:
    df_long['ema200'] = pd.Series.ewm(df_long['Mid_Close'], span=200).mean()
    df_long['ema100'] = pd.Series.ewm(df_long['Mid_Close'], span=100).mean()
    # df_long['ema50'] = pd.Series.ewm(df_long['Mid_Close'], span=50).mean()

    df_long['atr'] = atr(df_long['Mid_High'], df_long['Mid_Low'], df_long['Mid_Close'])
    df_long['atr_sma'] = df_long['atr'].rolling(window=20).mean()
    df_long['rsi'] = rsi(df_long['Mid_Close'])
    df_long['rsi_sma'] = df_long['rsi'].rolling(50).mean()
    df_long['adx'] = adx(df_long['Mid_High'], df_long['Mid_Low'], df_long['Mid_Close'])
    df_long['macd'] = pd.Series.ewm(df_long['Mid_Close'], span=12).mean() - pd.Series.ewm(df_long['Mid_Close'], span=26).mean()
    df_long['macdsignal'] = pd.Series.ewm(df_long['macd'], span=9).mean()
    df_long['slowk_rsi'], df_long['slowd_rsi'] = stoch_rsi(df_long['rsi'])

    df_long['vo'] = vo(df_long['Volume'])

    df_long['willy'], df_long['willy_ema'] = williams_r(df_long['Mid_High'], df_long['Mid_Low'], df_long['Mid_Close'])

    df_long.dropna(inplace=True)
    df_long.reset_index(drop=True, inplace=True)

    df_long.drop(['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'Volume'], axis=1, inplace=True)

    df_long.dropna(inplace=True)
    df_long.reset_index(drop=True, inplace=True)

# %%
look_back_size = 100

# %%
def grab_image_data(subset):
  # rp_transformer = RecurrencePlot()
  # rp_subset = rp_transformer.transform(subset)

  # return rp_subset

  gasf_transformer = GramianAngularField(method='summation')
  gasf_subset = gasf_transformer.transform(subset)

  return gasf_subset

  # gadf_transformer = GramianAngularField(method='difference')
  # gadf_subset = gadf_transformer.transform(subset)

  # return gadf_subset

  # image_data = np.append(rp_subset, gasf_subset, axis=-1)
  # image_data = np.append(image_data, gadf_subset ,axis=-1)
  
  # return image_data

# %%
buys_list = []
sells_list = []
nones_list = []

value_per_pip = 1.0
amounts_per_day = [-0.00008, -0.0001, -0.00012]
spread_cutoff = 0.10
risk_reward_ratio = 1.5

def get_n_units(trade_type, stop_loss, ask_open, bid_open, mid_open, currency_pair):
    _, second = currency_pair.split('_')
  
    pips_to_risk = ask_open - stop_loss if trade_type == 'buy' else stop_loss - bid_open
    pips_to_risk_calc = pips_to_risk * 10000 if second != 'Jpy' else pips_to_risk * 100

    if second == 'Usd':
        per_pip = 0.0001

    else:
        per_pip = 0.0001 / mid_open if second != 'Jpy' else 0.01 / mid_open

    n_units = int(50 / (pips_to_risk_calc * per_pip))

    return n_units

def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee

for idx in range(len(currencies)):
    currency_pair, df, df_long, bid_ask_mid_prices = currencies[idx], dfs[idx], df_longs[idx], bid_ask_mid_prices_list[idx]
    rounding = 3 if 'Jpy' in currency_pair else 5
    buys, sells, nones = [], [], []
    trade, prev_year = None, None

    print(f'RUNNING SIMULATION FOR {currency_pair}...')

    for i in range(look_back_size, len(df)):
        curr_date = df.loc[df.index[i], 'Date']
        if prev_year is None or curr_date.year > prev_year:
            prev_year = curr_date.year
            print(prev_year)
            print(f'Buys: {len(buys)}')
            print(f'Sells: {len(sells)}')
            print(f'Nones: {len(nones)}\n')
        curr_long = df_long.loc[df_long['Date'] < curr_date]
        if len(curr_long) < look_back_size + 1:
            continue
        ema200_2, ema100_2, atr2, rsi2, rsi_sma2, vo2 = df.loc[df.index[i - 2], ['ema200', 'ema100', 'atr', 'rsi', 'rsi_sma', 'vo']]
        ema200_1, ema100_1, atr1, rsi1, rsi_sma1, vo1, adx1, atr_sma1 = df.loc[df.index[i - 1], ['ema200', 'ema100', 'atr', 'rsi', 'rsi_sma', 'vo', 'adx', 'atr_sma']]
        mid_open2, mid_close2, mid_low2, mid_high2 = bid_ask_mid_prices.loc[bid_ask_mid_prices.index[i - 2], ['Mid_Open', 'Mid_Close', 'Mid_Low', 'Mid_High']]
        mid_open1, mid_close1, mid_low1, mid_high1 = bid_ask_mid_prices.loc[bid_ask_mid_prices.index[i - 1], ['Mid_Open', 'Mid_Close', 'Mid_Low', 'Mid_High']]
        curr_ao, curr_bo, curr_mid_open, curr_ask_low, curr_bid_high = bid_ask_mid_prices.loc[bid_ask_mid_prices.index[i], ['Ask_Open', 'Bid_Open', 'Mid_Open', 'Ask_Low', 'Bid_High']]
        spread = abs(curr_ao - curr_bo)
        enough_volatility = spread <= spread_cutoff

        emas_buy_signal = ema200_1 < ema100_1
        emas_sell_signal = ema200_1 > ema100_1

        supertrend2 = df.loc[df.index[i - 2], 'supertrend']
        supertrend1, supertrend_ub1, supertrend_lb1 = df.loc[df.index[i - 1], ['supertrend', 'supertrend_ub', 'supertrend_lb']]

        supertrend_buy_signal = not supertrend2 and supertrend1
        supertrend_sell_signal = supertrend2 and not supertrend1

        ti_o1, ti_c1 = df.loc[df.index[i - 1], ['ti_o', 'ti_c']]

        ti_buy_signal = ti_c1 - ti_o1 > 0
        ti_sell_signal = ti_c1 - ti_o1 < 0

        rsi_buy_signal = rsi1 > rsi_sma1
        rsi_sell_signal = rsi1 < rsi_sma1

        if trade is None:
            if emas_buy_signal and supertrend_buy_signal and ti_buy_signal:
                open_price = float(curr_ao)
                pullback = float(supertrend_lb1) - spread

                stop_loss = round(pullback, rounding)

                if stop_loss < open_price:
                    curr_pips_to_risk = open_price - stop_loss

                    if spread <= curr_pips_to_risk * spread_cutoff:
                        stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), rounding)

                        n_units = get_n_units('buy', stop_loss, curr_ao, curr_bo, curr_mid_open, currency_pair)

                        trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                        'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                        'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

            elif emas_sell_signal and supertrend_sell_signal and ti_sell_signal:
                open_price = float(curr_bo)
                pullback = float(supertrend_ub1) + spread

                stop_loss = round(pullback, rounding)

                if stop_loss > open_price:
                    curr_pips_to_risk = stop_loss - open_price

                    if spread <= curr_pips_to_risk * spread_cutoff:
                        stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), rounding)

                        n_units = get_n_units('sell', stop_loss, curr_ao, curr_bo, curr_mid_open, currency_pair)

                        trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                                'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

        if trade is not None:
            for j in range(i, len(df)):
                curr_date = df.loc[df.index[j], 'Date']
                curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = bid_ask_mid_prices.loc[bid_ask_mid_prices.index[j], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close']]

                if trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
                    nones.append(trade['start_date']) 

                    trade = None
                    break


                if trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
                    trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
                    day_fees = calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

                    if trade_amount + day_fees > 0:
                        buys.append(trade['start_date'])

                    trade = None
                    break

                if trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
                    nones.append(trade['start_date'])

                    trade = None
                    break

                if trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
                    trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
                    day_fees = calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

                    if trade_amount + day_fees > 0:
                        sells.append(trade['start_date'])

                    trade = None
                    break
    
    buys_list.append(buys)
    sells_list.append(sells)
    nones_list.append(nones)

    print(f'Buys: {len(buys)}')
    print(f'Sells: {len(sells)}')
    print(f'Nones: {len(nones)}\n')
# Out:
# RUNNING SIMULATION FOR Usd_Chf...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 20
# Sells: 23
# Nones: 104
#
# 2018
# Buys: 46
# Sells: 54
# Nones: 214
#
# 2019
# Buys: 72
# Sells: 80
# Nones: 315
#
# 2020
# Buys: 85
# Sells: 99
# Nones: 390
#
# 2021
# Buys: 107
# Sells: 118
# Nones: 487
#
# Buys: 139
# Sells: 143
# Nones: 572
#
# RUNNING SIMULATION FOR Gbp_Usd...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 50
# Sells: 48
# Nones: 151
#
# 2018
# Buys: 85
# Sells: 77
# Nones: 315
#
# 2019
# Buys: 135
# Sells: 125
# Nones: 456
#
# 2020
# Buys: 160
# Sells: 175
# Nones: 599
#
# 2021
# Buys: 238
# Sells: 219
# Nones: 763
#
# Buys: 278
# Sells: 265
# Nones: 915
#
# RUNNING SIMULATION FOR Usd_Cad...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 39
# Sells: 56
# Nones: 135
#
# 2018
# Buys: 83
# Sells: 96
# Nones: 277
#
# 2019
# Buys: 127
# Sells: 124
# Nones: 410
#
# 2020
# Buys: 141
# Sells: 152
# Nones: 493
#
# 2021
# Buys: 169
# Sells: 186
# Nones: 643
#
# Buys: 206
# Sells: 217
# Nones: 773
#
# RUNNING SIMULATION FOR Aud_Usd...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 56
# Sells: 47
# Nones: 145
#
# 2018
# Buys: 83
# Sells: 67
# Nones: 286
#
# 2019
# Buys: 113
# Sells: 107
# Nones: 416
#
# 2020
# Buys: 131
# Sells: 123
# Nones: 478
#
# 2021
# Buys: 189
# Sells: 166
# Nones: 638
#
# Buys: 217
# Sells: 212
# Nones: 783
#
# RUNNING SIMULATION FOR Eur_Usd...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 53
# Sells: 44
# Nones: 173
#
# 2018
# Buys: 108
# Sells: 80
# Nones: 353
#
# 2019
# Buys: 154
# Sells: 148
# Nones: 549
#
# 2020
# Buys: 176
# Sells: 174
# Nones: 645
#
# 2021
# Buys: 232
# Sells: 217
# Nones: 809
#
# Buys: 262
# Sells: 252
# Nones: 940
#
# RUNNING SIMULATION FOR Usd_Jpy...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 75
# Sells: 65
# Nones: 209
#
# 2018
# Buys: 136
# Sells: 127
# Nones: 397
#
# 2019
# Buys: 181
# Sells: 179
# Nones: 540
#
# 2020
# Buys: 206
# Sells: 212
# Nones: 648
#
# 2021
# Buys: 236
# Sells: 264
# Nones: 756
#
# Buys: 277
# Sells: 287
# Nones: 859
#
# RUNNING SIMULATION FOR Nzd_Usd...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 30
# Sells: 24
# Nones: 93
#
# 2018
# Buys: 53
# Sells: 47
# Nones: 199
#
# 2019
# Buys: 76
# Sells: 70
# Nones: 266
#
# 2020
# Buys: 87
# Sells: 74
# Nones: 296
#
# 2021
# Buys: 126
# Sells: 110
# Nones: 399
#
# Buys: 142
# Sells: 141
# Nones: 500

# %%
buy_indices_list = []
sell_indices_list = []
nones_indices_list = []

for i in range(len(dfs)):
    buys, sells, nones, df = buys_list[i], sells_list[i], nones_list[i], dfs[i]
    
    buy_indices = [df.index[df['Date'] == curr_date] - 1 for curr_date in buys]
    sell_indices = [df.index[df['Date'] == curr_date] - 1 for curr_date in sells]
    nones_indices = [df.index[df['Date'] == curr_date] - 1 for curr_date in nones]

    buy_indices_list.append(buy_indices)
    sell_indices_list.append(sell_indices)
    nones_indices_list.append(nones_indices)

    print(len(buy_indices))
    print(len(sell_indices))
    print(len(nones_indices))
# Out:
# 139
# 143
# 572
# 278
# 265
# 915
# 206
# 217
# 773
# 217
# 212
# 783
# 262
# 252
# 940
# 277
# 287
# 859
# 142
# 141
# 500

# %%
i = 5000
foo = dfs[0].iloc[i - look_back_size + 1:i + 1, 1:]
curr_date = dfs[0].iloc[i, 0]
curr_long = df_longs[0].loc[df_longs[0]['Date'] < curr_date]
foo2 = curr_long.iloc[-look_back_size - 1:-1, 1:]
foo3 = pd.concat([foo.reset_index(drop=True), foo2.reset_index(drop=True)], axis=1, ignore_index=True)
correct_shape = grab_image_data(foo3).shape
correct_shape
# Out:
# (100, 38, 38)

# %%
def get_sequential_data():
    no_actions = []
    buys = []
    sells = []

    for z in range(len(dfs)):
        df, df_long = dfs[z], df_longs[z]

        buy_indices, sell_indices, nones_indices = buy_indices_list[z], sell_indices_list[z], nones_indices_list[z]

        for i in buy_indices:
            if len(i) == 1:
                i = i[0]
                seq1 = df.iloc[i - look_back_size + 1:i + 1, 1:]
                curr_date = df.iloc[i, 0]
                curr_long = df_long.loc[df_long['Date'] < curr_date]
                seq2 = curr_long.iloc[-look_back_size - 1:-1, 1:]
                seq = pd.concat([seq1.reset_index(drop=True), seq2.reset_index(drop=True)], axis=1, ignore_index=True)

                if seq.shape == correct_shape[:-1] and not seq.isnull().values.any():
                    seq = grab_image_data(seq)
                    buys.append([seq, np.array([0, 1, 0])])

        for i in sell_indices:
            if len(i) == 1:
                i = i[0]
                seq1 = df.iloc[i - look_back_size + 1:i + 1, 1:]
                curr_date = df.iloc[i, 0]
                curr_long = df_long.loc[df_long['Date'] < curr_date]
                seq2 = curr_long.iloc[-look_back_size - 1:-1, 1:]
                seq = pd.concat([seq1.reset_index(drop=True), seq2.reset_index(drop=True)], axis=1, ignore_index=True)

                if seq.shape == correct_shape[:-1] and not seq.isnull().values.any():
                    seq = grab_image_data(seq)
                    sells.append([seq, np.array([0, 0, 1])])

        for i in nones_indices:
            if len(i) == 1:
                i = i[0]
                seq1 = df.iloc[i - look_back_size + 1:i + 1, 1:]
                curr_date = df.iloc[i, 0]
                curr_long = df_long.loc[df_long['Date'] < curr_date]
                seq2 = curr_long.iloc[-look_back_size - 1:-1, 1:]
                seq = pd.concat([seq1.reset_index(drop=True), seq2.reset_index(drop=True)], axis=1, ignore_index=True)

                if seq.shape == correct_shape[:-1] and not seq.isnull().values.any():
                    seq = grab_image_data(seq)
                    no_actions.append([seq, np.array([1, 0, 0])])

    np.random.shuffle(no_actions)
    np.random.shuffle(buys)
    np.random.shuffle(sells)

    lower = min(len(no_actions), len(buys), len(sells))

    no_actions = no_actions[:int(lower * 1.2)]

    sequential_data = no_actions + buys + sells
    np.random.shuffle(sequential_data)

    return sequential_data

# %%
sequential_data = get_sequential_data()

# %%
len(sequential_data)
# Out:
# 4858

# %%
training_proportion = 0.70
train_test_cutoff_index = int(len(sequential_data) * training_proportion)

train_set = sequential_data[0:train_test_cutoff_index]
test_set = sequential_data[train_test_cutoff_index:]

print('Dataset shapes:')
print(len(train_set))
print(len(test_set))
# Out:
# Dataset shapes:
# 3400
# 1458

# %%
x_train = []
y_train = []

for seq, target in train_set:
  x_train.append(seq)
  y_train.append(target)

x_test = []
y_test = []

for seq, target in test_set:
  x_test.append(seq)
  y_test.append(target)

x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
x_train.shape
# Out:
# (3400, 100, 38, 38)

# %%
y_train.shape
# Out:
# (3400, 3)

# %%
# scaler = StandardScaler()

# x_train_scaled = scaler.fit_transform(x_train)
# x_test_scaled = scaler.transform(x_test)

# %%
# # Number of possible actions to take - determines the output dimension of the
# #  neural network
# n_actions = 3
# input_data_shape = x_train.shape[1:]

# model = Sequential()

# model.add(Conv2D(filters = 32, kernel_size = (3,3), padding ='Same', activation ='relu', input_shape = input_data_shape))
# model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = 'Same', activation ='relu'))

# model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
# model.add(Dropout(0.25))

# model.add(Flatten())
# model.add(Dense(128, activation = "relu"))
# model.add(Dropout(0.5))
# model.add(Dense(n_actions, activation = "softmax"))

n_actions = 3
input_data_shape = x_train.shape[1:]

model = Sequential()

model.add(Conv2D(filters = 16, kernel_size = (3,3), padding ='Same', activation ='relu', input_shape = input_data_shape))
model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'Same', activation ='relu'))
model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = 'Same', activation ='relu'))

model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = "relu"))
model.add(Dropout(0.5))
# model.add(Dense(128, activation = "relu"))
# model.add(Dropout(0.5))
model.add(Dense(64, activation = "relu"))
model.add(Dropout(0.25))
model.add(Dense(32, activation = "relu"))
model.add(Dense(n_actions, activation = "softmax"))

# %%
# Hyperparameters
n_epochs = 1000
batch_size = 32
n_steps = len(x_train) // batch_size 
mean_loss = tf.keras.metrics.Mean() 
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.categorical_crossentropy
metrics = [tf.keras.metrics.CategoricalAccuracy()]
# loss_fn = tf.keras.losses.MeanAbsoluteError
# metrics = [tf.keras.metrics.MeanAbsoluteError()]

# %%
early_stop = EarlyStopping(monitor='val_accuracy', verbose=1, patience=n_epochs)
model_checkpoint = ModelCheckpoint('/Users/mymac/forex_supertrend_cnn', monitor='val_accuracy', save_best_only=True, verbose=1)

optimizer = Adam()

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
history = model.fit(
    x_train, y_train,
    batch_size=batch_size,
    epochs=n_epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, model_checkpoint]
)
# Out:
# Epoch 1/1000
# 107/107 [==============================] - ETA: 0s - loss: 1.1301 - accuracy: 0.3815
# Epoch 00001: val_accuracy improved from -inf to 0.46639, saving model to /Users/mymac/forex_supertrend_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_cnn/assets
# 107/107 [==============================] - 8s 69ms/step - loss: 1.1301 - accuracy: 0.3815 - val_loss: 0.9559 - val_accuracy: 0.4664
# Epoch 2/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.8354 - accuracy: 0.5438
# Epoch 00002: val_accuracy improved from 0.46639 to 0.56653, saving model to /Users/mymac/forex_supertrend_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_cnn/assets
# 107/107 [==============================] - 6s 54ms/step - loss: 0.8354 - accuracy: 0.5438 - val_loss: 0.7164 - val_accuracy: 0.5665
# Epoch 3/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.7048 - accuracy: 0.6044
# Epoch 00003: val_accuracy improved from 0.56653 to 0.60768, saving model to /Users/mymac/forex_supertrend_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_cnn/assets
# 107/107 [==============================] - 6s 57ms/step - loss: 0.7048 - accuracy: 0.6044 - val_loss: 0.6834 - val_accuracy: 0.6077
# Epoch 4/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.6804 - accuracy: 0.6141
# Epoch 00004: val_accuracy did not improve from 0.60768
# 107/107 [==============================] - 5s 47ms/step - loss: 0.6804 - accuracy: 0.6141 - val_loss: 0.6901 - val_accuracy: 0.6036
# Epoch 5/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.6702 - accuracy: 0.6256
# Epoch 00005: val_accuracy improved from 0.60768 to 0.60974, saving model to /Users/mymac/forex_supertrend_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_cnn/assets
# 107/107 [==============================] - 6s 56ms/step - loss: 0.6702 - accuracy: 0.6256 - val_loss: 0.6746 - val_accuracy: 0.6097
# Epoch 6/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.6654 - accuracy: 0.6247
# Epoch 00006: val_accuracy improved from 0.60974 to 0.61111, saving model to /Users/mymac/forex_supertrend_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_cnn/assets
# 107/107 [==============================] - 6s 55ms/step - loss: 0.6654 - accuracy: 0.6247 - val_loss: 0.6731 - val_accuracy: 0.6111
# Epoch 7/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.6529 - accuracy: 0.6332
# Epoch 00007: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.6529 - accuracy: 0.6332 - val_loss: 0.6802 - val_accuracy: 0.6001
# Epoch 8/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.6451 - accuracy: 0.6379
# Epoch 00008: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.6451 - accuracy: 0.6379 - val_loss: 0.6779 - val_accuracy: 0.5981
# Epoch 9/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.6283 - accuracy: 0.6582
# Epoch 00009: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.6283 - accuracy: 0.6582 - val_loss: 0.6834 - val_accuracy: 0.6056
# Epoch 10/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.6011 - accuracy: 0.6797
# Epoch 00010: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 6s 52ms/step - loss: 0.6011 - accuracy: 0.6797 - val_loss: 0.6893 - val_accuracy: 0.5768
# Epoch 11/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.5708 - accuracy: 0.7115
# Epoch 00011: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.5708 - accuracy: 0.7115 - val_loss: 0.7381 - val_accuracy: 0.5919
# Epoch 12/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.5268 - accuracy: 0.7382
# Epoch 00012: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 50ms/step - loss: 0.5268 - accuracy: 0.7382 - val_loss: 0.7454 - val_accuracy: 0.5741
# Epoch 13/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.7824
# Epoch 00013: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.4672 - accuracy: 0.7824 - val_loss: 0.7506 - val_accuracy: 0.5761
# Epoch 14/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.4068 - accuracy: 0.8176
# Epoch 00014: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.4068 - accuracy: 0.8176 - val_loss: 0.8587 - val_accuracy: 0.5912
# Epoch 15/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.8456
# Epoch 00015: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.3451 - accuracy: 0.8456 - val_loss: 0.8820 - val_accuracy: 0.5693
# Epoch 16/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.8697
# Epoch 00016: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.3117 - accuracy: 0.8697 - val_loss: 1.0351 - val_accuracy: 0.5535
# Epoch 17/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.2477 - accuracy: 0.9003
# Epoch 00017: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.2477 - accuracy: 0.9003 - val_loss: 1.0838 - val_accuracy: 0.5473
# Epoch 18/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9203
# Epoch 00018: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.1940 - accuracy: 0.9203 - val_loss: 1.3572 - val_accuracy: 0.5658
# Epoch 19/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.1762 - accuracy: 0.9348
# Epoch 00019: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.1759 - accuracy: 0.9350 - val_loss: 1.3966 - val_accuracy: 0.5501
# Epoch 20/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.1590 - accuracy: 0.9362
# Epoch 00020: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 50ms/step - loss: 0.1590 - accuracy: 0.9362 - val_loss: 1.3372 - val_accuracy: 0.5514
# Epoch 21/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.1516 - accuracy: 0.9394
# Epoch 00021: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.1516 - accuracy: 0.9394 - val_loss: 1.4583 - val_accuracy: 0.5412
# Epoch 22/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9515
# Epoch 00022: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.1294 - accuracy: 0.9515 - val_loss: 1.6322 - val_accuracy: 0.5638
# Epoch 23/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9647
# Epoch 00023: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.1038 - accuracy: 0.9647 - val_loss: 1.6926 - val_accuracy: 0.5466
# Epoch 24/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9644
# Epoch 00024: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0998 - accuracy: 0.9644 - val_loss: 1.6510 - val_accuracy: 0.5453
# Epoch 25/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9688
# Epoch 00025: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0814 - accuracy: 0.9688 - val_loss: 1.7481 - val_accuracy: 0.5398
# Epoch 26/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9700
# Epoch 00026: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0806 - accuracy: 0.9700 - val_loss: 1.9852 - val_accuracy: 0.5645
# Epoch 27/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9652
# Epoch 00027: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0979 - accuracy: 0.9647 - val_loss: 1.8301 - val_accuracy: 0.5521
# Epoch 28/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9724
# Epoch 00028: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0812 - accuracy: 0.9724 - val_loss: 1.8356 - val_accuracy: 0.5624
# Epoch 29/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9765
# Epoch 00029: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0650 - accuracy: 0.9765 - val_loss: 1.8321 - val_accuracy: 0.5562
# Epoch 30/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9785
# Epoch 00030: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0629 - accuracy: 0.9785 - val_loss: 2.0348 - val_accuracy: 0.5446
# Epoch 31/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9794
# Epoch 00031: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0583 - accuracy: 0.9794 - val_loss: 1.9448 - val_accuracy: 0.5672
# Epoch 32/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9832
# Epoch 00032: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0504 - accuracy: 0.9832 - val_loss: 2.0686 - val_accuracy: 0.5610
# Epoch 33/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9832
# Epoch 00033: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0520 - accuracy: 0.9832 - val_loss: 1.9561 - val_accuracy: 0.5583
# Epoch 34/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0606 - accuracy: 0.9808
# Epoch 00034: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0605 - accuracy: 0.9809 - val_loss: 1.8011 - val_accuracy: 0.5562
# Epoch 35/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9835
# Epoch 00035: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0443 - accuracy: 0.9835 - val_loss: 2.0329 - val_accuracy: 0.5446
# Epoch 36/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9841
# Epoch 00036: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0408 - accuracy: 0.9841 - val_loss: 2.3179 - val_accuracy: 0.5713
# Epoch 37/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.9871
# Epoch 00037: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0410 - accuracy: 0.9871 - val_loss: 2.0412 - val_accuracy: 0.5377
# Epoch 38/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9909
# Epoch 00038: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0311 - accuracy: 0.9909 - val_loss: 2.4026 - val_accuracy: 0.5439
# Epoch 39/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9847
# Epoch 00039: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0519 - accuracy: 0.9847 - val_loss: 2.1920 - val_accuracy: 0.5727
# Epoch 40/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9862
# Epoch 00040: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0368 - accuracy: 0.9862 - val_loss: 2.3230 - val_accuracy: 0.5597
# Epoch 41/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9865
# Epoch 00041: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0366 - accuracy: 0.9865 - val_loss: 2.1746 - val_accuracy: 0.5597
# Epoch 42/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9826
# Epoch 00042: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0519 - accuracy: 0.9826 - val_loss: 2.1336 - val_accuracy: 0.5494
# Epoch 43/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9885
# Epoch 00043: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0336 - accuracy: 0.9885 - val_loss: 2.5651 - val_accuracy: 0.5604
# Epoch 44/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9888
# Epoch 00044: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0325 - accuracy: 0.9888 - val_loss: 2.3844 - val_accuracy: 0.5556
# Epoch 45/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9903
# Epoch 00045: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0283 - accuracy: 0.9903 - val_loss: 2.4347 - val_accuracy: 0.5604
# Epoch 46/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9821
# Epoch 00046: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0498 - accuracy: 0.9821 - val_loss: 2.5843 - val_accuracy: 0.5645
# Epoch 47/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9853
# Epoch 00047: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0442 - accuracy: 0.9853 - val_loss: 2.3955 - val_accuracy: 0.5549
# Epoch 48/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9874
# Epoch 00048: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0328 - accuracy: 0.9874 - val_loss: 2.4618 - val_accuracy: 0.5782
# Epoch 49/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9891
# Epoch 00049: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0322 - accuracy: 0.9891 - val_loss: 2.4121 - val_accuracy: 0.5480
# Epoch 50/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9844
# Epoch 00050: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 51ms/step - loss: 0.0503 - accuracy: 0.9844 - val_loss: 2.2514 - val_accuracy: 0.5645
# Epoch 51/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9924
# Epoch 00051: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0201 - accuracy: 0.9924 - val_loss: 2.3810 - val_accuracy: 0.5501
# Epoch 52/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9923
# Epoch 00052: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 51ms/step - loss: 0.0231 - accuracy: 0.9924 - val_loss: 2.4263 - val_accuracy: 0.5658
# Epoch 53/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9909
# Epoch 00053: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0276 - accuracy: 0.9909 - val_loss: 2.5391 - val_accuracy: 0.5652
# Epoch 54/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9821
# Epoch 00054: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0546 - accuracy: 0.9821 - val_loss: 2.1301 - val_accuracy: 0.5508
# Epoch 55/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9929
# Epoch 00055: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 2.8750 - val_accuracy: 0.5631
# Epoch 56/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9897
# Epoch 00056: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0277 - accuracy: 0.9897 - val_loss: 2.7096 - val_accuracy: 0.5665
# Epoch 57/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9918
# Epoch 00057: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0222 - accuracy: 0.9918 - val_loss: 2.4127 - val_accuracy: 0.5412
# Epoch 58/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0303 - accuracy: 0.9894
# Epoch 00058: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0302 - accuracy: 0.9894 - val_loss: 2.5754 - val_accuracy: 0.5617
# Epoch 59/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9897
# Epoch 00059: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0416 - accuracy: 0.9897 - val_loss: 2.2006 - val_accuracy: 0.5569
# Epoch 60/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9921
# Epoch 00060: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0284 - accuracy: 0.9921 - val_loss: 2.0728 - val_accuracy: 0.5466
# Epoch 61/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9944
# Epoch 00061: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 2.7398 - val_accuracy: 0.5679
# Epoch 62/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9915
# Epoch 00062: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0302 - accuracy: 0.9915 - val_loss: 3.0568 - val_accuracy: 0.5549
# Epoch 63/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0645 - accuracy: 0.9756
# Epoch 00063: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0645 - accuracy: 0.9756 - val_loss: 2.0810 - val_accuracy: 0.5549
# Epoch 64/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9938
# Epoch 00064: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0213 - accuracy: 0.9938 - val_loss: 2.4900 - val_accuracy: 0.5549
# Epoch 65/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9944
# Epoch 00065: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0238 - accuracy: 0.9944 - val_loss: 2.3285 - val_accuracy: 0.5418
# Epoch 66/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9912
# Epoch 00066: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0297 - accuracy: 0.9912 - val_loss: 2.4734 - val_accuracy: 0.5597
# Epoch 67/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9938
# Epoch 00067: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 2.3655 - val_accuracy: 0.5446
# Epoch 68/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9929
# Epoch 00068: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0218 - accuracy: 0.9929 - val_loss: 2.7679 - val_accuracy: 0.5741
# Epoch 69/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9962
# Epoch 00069: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0109 - accuracy: 0.9959 - val_loss: 2.4763 - val_accuracy: 0.5569
# Epoch 70/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9962
# Epoch 00070: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 2.7474 - val_accuracy: 0.5439
# Epoch 71/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9971
# Epoch 00071: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0133 - accuracy: 0.9971 - val_loss: 3.0640 - val_accuracy: 0.5597
# Epoch 72/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9923
# Epoch 00072: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0237 - accuracy: 0.9921 - val_loss: 3.0315 - val_accuracy: 0.5364
# Epoch 73/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9885
# Epoch 00073: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0452 - accuracy: 0.9885 - val_loss: 2.1185 - val_accuracy: 0.5446
# Epoch 74/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9953
# Epoch 00074: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0189 - accuracy: 0.9953 - val_loss: 2.5616 - val_accuracy: 0.5590
# Epoch 75/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 0.9973
# Epoch 00075: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 50ms/step - loss: 0.0091 - accuracy: 0.9974 - val_loss: 3.1968 - val_accuracy: 0.5748
# Epoch 76/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 0.9959
# Epoch 00076: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 2.6891 - val_accuracy: 0.5377
# Epoch 77/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9965
# Epoch 00077: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 2.8907 - val_accuracy: 0.5556
# Epoch 78/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9953
# Epoch 00078: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 50ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 2.6980 - val_accuracy: 0.5418
# Epoch 79/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9953
# Epoch 00079: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 2.7644 - val_accuracy: 0.5631
# Epoch 80/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9956
# Epoch 00080: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 50ms/step - loss: 0.0125 - accuracy: 0.9956 - val_loss: 2.9067 - val_accuracy: 0.5309
# Epoch 81/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0215 - accuracy: 0.9929
# Epoch 00081: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0215 - accuracy: 0.9929 - val_loss: 2.8446 - val_accuracy: 0.5713
# Epoch 82/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9956
# Epoch 00082: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 2.9852 - val_accuracy: 0.5604
# Epoch 83/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9944
# Epoch 00083: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0150 - accuracy: 0.9944 - val_loss: 3.1887 - val_accuracy: 0.5706
# Epoch 84/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9918
# Epoch 00084: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0236 - accuracy: 0.9918 - val_loss: 2.7399 - val_accuracy: 0.5521
# Epoch 85/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9932
# Epoch 00085: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0178 - accuracy: 0.9932 - val_loss: 2.8015 - val_accuracy: 0.5487
# Epoch 86/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9921
# Epoch 00086: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0271 - accuracy: 0.9921 - val_loss: 2.8747 - val_accuracy: 0.5706
# Epoch 87/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9947
# Epoch 00087: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0214 - accuracy: 0.9947 - val_loss: 2.6357 - val_accuracy: 0.5672
# Epoch 88/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9938
# Epoch 00088: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0200 - accuracy: 0.9938 - val_loss: 2.6008 - val_accuracy: 0.5597
# Epoch 89/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9941
# Epoch 00089: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0165 - accuracy: 0.9941 - val_loss: 2.5243 - val_accuracy: 0.5473
# Epoch 90/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9979
# Epoch 00090: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 2.6430 - val_accuracy: 0.5624
# Epoch 91/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9950
# Epoch 00091: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0187 - accuracy: 0.9950 - val_loss: 2.3037 - val_accuracy: 0.5528
# Epoch 92/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9953
# Epoch 00092: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 2.5938 - val_accuracy: 0.5610
# Epoch 93/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9929
# Epoch 00093: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0224 - accuracy: 0.9929 - val_loss: 2.4776 - val_accuracy: 0.5569
# Epoch 94/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9950
# Epoch 00094: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 2.7386 - val_accuracy: 0.5556
# Epoch 95/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9918
# Epoch 00095: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0234 - accuracy: 0.9918 - val_loss: 2.8321 - val_accuracy: 0.5473
# Epoch 96/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9915
# Epoch 00096: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0215 - accuracy: 0.9915 - val_loss: 2.5841 - val_accuracy: 0.5631
# Epoch 97/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9947
# Epoch 00097: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 2.6050 - val_accuracy: 0.5514
# Epoch 98/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9950
# Epoch 00098: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 2.8664 - val_accuracy: 0.5665
# Epoch 99/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9947
# Epoch 00099: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 3.1064 - val_accuracy: 0.5610
# Epoch 100/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9944
# Epoch 00100: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0153 - accuracy: 0.9944 - val_loss: 2.6901 - val_accuracy: 0.5617
# Epoch 101/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9962
# Epoch 00101: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0155 - accuracy: 0.9962 - val_loss: 2.5567 - val_accuracy: 0.5521
# Epoch 102/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9912
# Epoch 00102: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0257 - accuracy: 0.9912 - val_loss: 2.5409 - val_accuracy: 0.5720
# Epoch 103/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9971
# Epoch 00103: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 2.9190 - val_accuracy: 0.5782
# Epoch 104/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9956
# Epoch 00104: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 2.5145 - val_accuracy: 0.5329
# Epoch 105/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9956
# Epoch 00105: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 2.8261 - val_accuracy: 0.5446
# Epoch 106/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9935
# Epoch 00106: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0208 - accuracy: 0.9935 - val_loss: 2.4532 - val_accuracy: 0.5494
# Epoch 107/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9926
# Epoch 00107: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 47ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 3.3882 - val_accuracy: 0.5734
# Epoch 108/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9959
# Epoch 00108: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 2.9279 - val_accuracy: 0.5528
# Epoch 109/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9929
# Epoch 00109: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0271 - accuracy: 0.9929 - val_loss: 2.6377 - val_accuracy: 0.5460
# Epoch 110/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9915
# Epoch 00110: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0313 - accuracy: 0.9915 - val_loss: 2.1976 - val_accuracy: 0.5528
# Epoch 111/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9959
# Epoch 00111: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0153 - accuracy: 0.9959 - val_loss: 2.6102 - val_accuracy: 0.5604
# Epoch 112/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9976
# Epoch 00112: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 2.9979 - val_accuracy: 0.5617
# Epoch 113/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9973
# Epoch 00113: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 2.8708 - val_accuracy: 0.5562
# Epoch 114/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9965
# Epoch 00114: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 3.3145 - val_accuracy: 0.5645
# Epoch 115/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9953
# Epoch 00115: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0164 - accuracy: 0.9953 - val_loss: 2.5069 - val_accuracy: 0.5521
# Epoch 116/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9974
# Epoch 00116: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0120 - accuracy: 0.9974 - val_loss: 2.6465 - val_accuracy: 0.5439
# Epoch 117/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9974
# Epoch 00117: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 3.3779 - val_accuracy: 0.5508
# Epoch 118/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9985
# Epoch 00118: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 3.6097 - val_accuracy: 0.5556
# Epoch 119/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9985
# Epoch 00119: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 3.5421 - val_accuracy: 0.5322
# Epoch 120/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9912
# Epoch 00120: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0295 - accuracy: 0.9912 - val_loss: 2.3526 - val_accuracy: 0.5569
# Epoch 121/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9918
# Epoch 00121: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0186 - accuracy: 0.9918 - val_loss: 2.5499 - val_accuracy: 0.5638
# Epoch 122/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9976
# Epoch 00122: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 3.0848 - val_accuracy: 0.5617
# Epoch 123/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9979
# Epoch 00123: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0085 - accuracy: 0.9979 - val_loss: 3.3316 - val_accuracy: 0.5569
# Epoch 124/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9956
# Epoch 00124: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 2.8930 - val_accuracy: 0.5432
# Epoch 125/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9956
# Epoch 00125: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0175 - accuracy: 0.9956 - val_loss: 2.6433 - val_accuracy: 0.5508
# Epoch 126/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 0.9976
# Epoch 00126: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 2.9556 - val_accuracy: 0.5439
# Epoch 127/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9988
# Epoch 00127: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0063 - accuracy: 0.9988 - val_loss: 2.9848 - val_accuracy: 0.5466
# Epoch 128/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9985
# Epoch 00128: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 3.0667 - val_accuracy: 0.5432
# Epoch 129/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9953
# Epoch 00129: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0167 - accuracy: 0.9953 - val_loss: 3.0401 - val_accuracy: 0.5460
# Epoch 130/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0240 - accuracy: 0.9932
# Epoch 00130: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0239 - accuracy: 0.9932 - val_loss: 2.9942 - val_accuracy: 0.5610
# Epoch 131/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9947
# Epoch 00131: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0157 - accuracy: 0.9947 - val_loss: 2.9722 - val_accuracy: 0.5508
# Epoch 132/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9985
# Epoch 00132: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 3.4412 - val_accuracy: 0.5569
# Epoch 133/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9979
# Epoch 00133: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 3.7559 - val_accuracy: 0.5789
# Epoch 134/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9947
# Epoch 00134: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0145 - accuracy: 0.9947 - val_loss: 3.2814 - val_accuracy: 0.5610
# Epoch 135/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9962
# Epoch 00135: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 3.2787 - val_accuracy: 0.5562
# Epoch 136/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9959
# Epoch 00136: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0139 - accuracy: 0.9959 - val_loss: 2.9265 - val_accuracy: 0.5514
# Epoch 137/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9988
# Epoch 00137: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0078 - accuracy: 0.9988 - val_loss: 2.9265 - val_accuracy: 0.5350
# Epoch 138/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9950
# Epoch 00138: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 3.2593 - val_accuracy: 0.5466
# Epoch 139/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9950
# Epoch 00139: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0155 - accuracy: 0.9950 - val_loss: 3.1351 - val_accuracy: 0.5535
# Epoch 140/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9956
# Epoch 00140: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 2.6544 - val_accuracy: 0.5412
# Epoch 141/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9971
# Epoch 00141: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0073 - accuracy: 0.9971 - val_loss: 3.3188 - val_accuracy: 0.5658
# Epoch 142/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9985
# Epoch 00142: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 3.3516 - val_accuracy: 0.5494
# Epoch 143/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9962
# Epoch 00143: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0096 - accuracy: 0.9962 - val_loss: 3.8518 - val_accuracy: 0.5700
# Epoch 144/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9953
# Epoch 00144: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 3.8891 - val_accuracy: 0.5576
# Epoch 145/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9953
# Epoch 00145: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0118 - accuracy: 0.9953 - val_loss: 3.2732 - val_accuracy: 0.5604
# Epoch 146/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9926
# Epoch 00146: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0296 - accuracy: 0.9926 - val_loss: 2.4870 - val_accuracy: 0.5521
# Epoch 147/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9968
# Epoch 00147: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0101 - accuracy: 0.9968 - val_loss: 2.7962 - val_accuracy: 0.5418
# Epoch 148/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9974
# Epoch 00148: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 3.2861 - val_accuracy: 0.5453
# Epoch 149/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9944
# Epoch 00149: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0181 - accuracy: 0.9944 - val_loss: 3.1997 - val_accuracy: 0.5480
# Epoch 150/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9950
# Epoch 00150: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0178 - accuracy: 0.9950 - val_loss: 3.4021 - val_accuracy: 0.5658
# Epoch 151/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9959
# Epoch 00151: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0103 - accuracy: 0.9959 - val_loss: 3.1789 - val_accuracy: 0.5418
# Epoch 152/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9976
# Epoch 00152: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0107 - accuracy: 0.9976 - val_loss: 3.2863 - val_accuracy: 0.5665
# Epoch 153/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9965
# Epoch 00153: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 2.7530 - val_accuracy: 0.5418
# Epoch 154/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9976
# Epoch 00154: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0084 - accuracy: 0.9976 - val_loss: 3.5322 - val_accuracy: 0.5665
# Epoch 155/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9950
# Epoch 00155: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0251 - accuracy: 0.9950 - val_loss: 2.9236 - val_accuracy: 0.5562
# Epoch 156/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9979
# Epoch 00156: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 3.1338 - val_accuracy: 0.5706
# Epoch 157/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9976
# Epoch 00157: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 2.9349 - val_accuracy: 0.5562
# Epoch 158/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9988
# Epoch 00158: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 3.1779 - val_accuracy: 0.5672
# Epoch 159/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9994
# Epoch 00159: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 3.5816 - val_accuracy: 0.5583
# Epoch 160/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9976
# Epoch 00160: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 2.5437 - val_accuracy: 0.5466
# Epoch 161/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9974
# Epoch 00161: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 4.0239 - val_accuracy: 0.5583
# Epoch 162/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9971
# Epoch 00162: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 4.2032 - val_accuracy: 0.5672
# Epoch 163/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9965
# Epoch 00163: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0075 - accuracy: 0.9965 - val_loss: 3.8861 - val_accuracy: 0.5693
# Epoch 164/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9965
# Epoch 00164: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0192 - accuracy: 0.9965 - val_loss: 3.1144 - val_accuracy: 0.5562
# Epoch 165/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9941
# Epoch 00165: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 49ms/step - loss: 0.0228 - accuracy: 0.9941 - val_loss: 3.0019 - val_accuracy: 0.5631
# Epoch 166/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9962
# ...
# Epoch 946/1000
# 107/107 [==============================] - ETA: 0s - loss: 1.9174e-04 - accuracy: 1.0000
# Epoch 00946: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 1.9174e-04 - accuracy: 1.0000 - val_loss: 10.1384 - val_accuracy: 0.5686
# Epoch 947/1000
# 106/107 [============================>.] - ETA: 0s - loss: 1.4857e-04 - accuracy: 1.0000
# Epoch 00947: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 1.4822e-04 - accuracy: 1.0000 - val_loss: 10.5657 - val_accuracy: 0.5706
# Epoch 948/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9994
# Epoch 00948: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 8.5567 - val_accuracy: 0.5576
# Epoch 949/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9988
# Epoch 00949: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 8.6360 - val_accuracy: 0.5528
# Epoch 950/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9997
# Epoch 00950: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 8.0426 - val_accuracy: 0.5302
# Epoch 951/1000
# 107/107 [==============================] - ETA: 0s - loss: 9.6582e-04 - accuracy: 0.9997
# Epoch 00951: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 9.6582e-04 - accuracy: 0.9997 - val_loss: 8.7119 - val_accuracy: 0.5638
# Epoch 952/1000
# 106/107 [============================>.] - ETA: 0s - loss: 4.4335e-05 - accuracy: 1.0000
# Epoch 00952: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 4.4231e-05 - accuracy: 1.0000 - val_loss: 9.0943 - val_accuracy: 0.5604
# Epoch 953/1000
# 107/107 [==============================] - ETA: 0s - loss: 2.8905e-04 - accuracy: 1.0000
# Epoch 00953: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 2.8905e-04 - accuracy: 1.0000 - val_loss: 9.2528 - val_accuracy: 0.5617
# Epoch 954/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9991
# Epoch 00954: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0054 - accuracy: 0.9991 - val_loss: 10.5374 - val_accuracy: 0.5542
# Epoch 955/1000
# 107/107 [==============================] - ETA: 0s - loss: 2.2487e-05 - accuracy: 1.0000
# Epoch 00955: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 2.2487e-05 - accuracy: 1.0000 - val_loss: 10.8320 - val_accuracy: 0.5590
# Epoch 956/1000
# 107/107 [==============================] - ETA: 0s - loss: 6.1053e-04 - accuracy: 0.9997
# Epoch 00956: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 6.1053e-04 - accuracy: 0.9997 - val_loss: 11.3632 - val_accuracy: 0.5590
# Epoch 957/1000
# 107/107 [==============================] - ETA: 0s - loss: 3.1553e-05 - accuracy: 1.0000
# Epoch 00957: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 3.1553e-05 - accuracy: 1.0000 - val_loss: 11.5924 - val_accuracy: 0.5542
# Epoch 958/1000
# 107/107 [==============================] - ETA: 0s - loss: 4.5413e-04 - accuracy: 0.9997
# Epoch 00958: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 4.5413e-04 - accuracy: 0.9997 - val_loss: 11.6450 - val_accuracy: 0.5556
# Epoch 959/1000
# 107/107 [==============================] - ETA: 0s - loss: 1.8984e-04 - accuracy: 1.0000
# Epoch 00959: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 1.8984e-04 - accuracy: 1.0000 - val_loss: 12.0734 - val_accuracy: 0.5521
# Epoch 960/1000
# 106/107 [============================>.] - ETA: 0s - loss: 1.1814e-06 - accuracy: 1.0000
# Epoch 00960: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 1.1787e-06 - accuracy: 1.0000 - val_loss: 12.0911 - val_accuracy: 0.5542
# Epoch 961/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9968
# Epoch 00961: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0254 - accuracy: 0.9968 - val_loss: 10.3314 - val_accuracy: 0.5453
# Epoch 962/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9965
# Epoch 00962: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0229 - accuracy: 0.9965 - val_loss: 7.0952 - val_accuracy: 0.5508
# Epoch 963/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9985
# Epoch 00963: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 10.3128 - val_accuracy: 0.5617
# Epoch 964/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9982
# Epoch 00964: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0126 - accuracy: 0.9982 - val_loss: 7.6054 - val_accuracy: 0.5521
# Epoch 965/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9991
# Epoch 00965: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 7.3599 - val_accuracy: 0.5652
# Epoch 966/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9991
# Epoch 00966: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 7.2683 - val_accuracy: 0.5556
# Epoch 967/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9994
# Epoch 00967: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 7.6198 - val_accuracy: 0.5624
# Epoch 968/1000
# 107/107 [==============================] - ETA: 0s - loss: 1.0810e-04 - accuracy: 1.0000
# Epoch 00968: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 1.0810e-04 - accuracy: 1.0000 - val_loss: 8.2877 - val_accuracy: 0.5631
# Epoch 969/1000
# 107/107 [==============================] - ETA: 0s - loss: 4.8535e-05 - accuracy: 1.0000
# Epoch 00969: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 4.8535e-05 - accuracy: 1.0000 - val_loss: 8.6007 - val_accuracy: 0.5645
# Epoch 970/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9991
# Epoch 00970: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 7.6805 - val_accuracy: 0.5576
# Epoch 971/1000
# 107/107 [==============================] - ETA: 0s - loss: 6.4776e-04 - accuracy: 0.9997
# Epoch 00971: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 6.4776e-04 - accuracy: 0.9997 - val_loss: 8.1082 - val_accuracy: 0.5569
# Epoch 972/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9994
# Epoch 00972: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0010 - accuracy: 0.9994 - val_loss: 8.6213 - val_accuracy: 0.5535
# Epoch 973/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9994
# Epoch 00973: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 8.2773 - val_accuracy: 0.5556
# Epoch 974/1000
# 107/107 [==============================] - ETA: 0s - loss: 7.5148e-04 - accuracy: 0.9997
# Epoch 00974: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 7.5148e-04 - accuracy: 0.9997 - val_loss: 8.5557 - val_accuracy: 0.5604
# Epoch 975/1000
# 106/107 [============================>.] - ETA: 0s - loss: 4.3934e-05 - accuracy: 1.0000
# Epoch 00975: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 4.3833e-05 - accuracy: 1.0000 - val_loss: 8.9085 - val_accuracy: 0.5617
# Epoch 976/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 00976: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 8.6681 - val_accuracy: 0.5576
# Epoch 977/1000
# 107/107 [==============================] - ETA: 0s - loss: 1.7505e-04 - accuracy: 1.0000
# Epoch 00977: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 1.7505e-04 - accuracy: 1.0000 - val_loss: 8.9039 - val_accuracy: 0.5597
# Epoch 978/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9997
# Epoch 00978: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 9.0606 - val_accuracy: 0.5466
# Epoch 979/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9997
# Epoch 00979: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 9.5144 - val_accuracy: 0.5679
# Epoch 980/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9985
# Epoch 00980: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 9.2406 - val_accuracy: 0.5665
# Epoch 981/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9982
# Epoch 00981: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 8.7597 - val_accuracy: 0.5672
# Epoch 982/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9994
# Epoch 00982: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 10.3575 - val_accuracy: 0.5384
# Epoch 983/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994
# Epoch 00983: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 10.0185 - val_accuracy: 0.5713
# Epoch 984/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9991
# Epoch 00984: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0069 - accuracy: 0.9991 - val_loss: 6.7929 - val_accuracy: 0.5562
# Epoch 985/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9997
# Epoch 00985: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 8.0742 - val_accuracy: 0.5761
# Epoch 986/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9988
# Epoch 00986: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0058 - accuracy: 0.9988 - val_loss: 8.2166 - val_accuracy: 0.5672
# Epoch 987/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9997
# Epoch 00987: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 9.8913 - val_accuracy: 0.5864
# Epoch 988/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9991
# Epoch 00988: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 9.9902 - val_accuracy: 0.5514
# Epoch 989/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9991
# Epoch 00989: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0133 - accuracy: 0.9991 - val_loss: 11.4090 - val_accuracy: 0.5898
# Epoch 990/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9944
# Epoch 00990: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0313 - accuracy: 0.9944 - val_loss: 11.0338 - val_accuracy: 0.5775
# Epoch 991/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9991
# Epoch 00991: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 11.7379 - val_accuracy: 0.5693
# Epoch 992/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9991
# Epoch 00992: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0067 - accuracy: 0.9991 - val_loss: 12.1654 - val_accuracy: 0.5604
# Epoch 993/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994
# Epoch 00993: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 12.0561 - val_accuracy: 0.5617
# Epoch 994/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9994
# Epoch 00994: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 10.9069 - val_accuracy: 0.5796
# Epoch 995/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 00995: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 17.6413 - val_accuracy: 0.5775
# Epoch 996/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9997
# Epoch 00996: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 17.5898 - val_accuracy: 0.5610
# Epoch 997/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997
# Epoch 00997: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 17.3849 - val_accuracy: 0.5645
# Epoch 998/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 00998: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 17.5958 - val_accuracy: 0.5727
# Epoch 999/1000
# 106/107 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00999: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 18.4791 - val_accuracy: 0.5556
# Epoch 1000/1000
# 107/107 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9982
# Epoch 01000: val_accuracy did not improve from 0.61111
# 107/107 [==============================] - 5s 48ms/step - loss: 0.0042 - accuracy: 0.9982 - val_loss: 20.6077 - val_accuracy: 0.5686
