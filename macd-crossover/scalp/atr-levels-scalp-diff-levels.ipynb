# %%
import numpy as np
import pandas as pd
import random

# %%
file_path = '../../bar_movement/data/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
df = pd.read_csv(file_path + 'Oanda_Eur_Usd_M5_2021-2022.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

df_small = pd.read_csv(file_path + 'Oanda_Eur_Usd_M1_2021-2022.csv')
df_small.Date = pd.to_datetime(df_small.Date)
df_small.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2021-04-01 06:00:00   1.17170   1.17172  1.17141    1.17141   1.17184
# 1 2021-04-01 06:05:00   1.17140   1.17182  1.17119    1.17154   1.17153
# 2 2021-04-01 06:10:00   1.17153   1.17162  1.17140    1.17161   1.17166
# 3 2021-04-01 06:15:00   1.17160   1.17187  1.17153    1.17185   1.17173
# 4 2021-04-01 06:20:00   1.17184   1.17253  1.17171    1.17232   1.17196
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0   1.17187  1.17154    1.17154   1.17177   1.17180  1.17148    1.17148
# 1   1.17194  1.17133    1.17167   1.17146   1.17188  1.17126    1.17160
# 2   1.17175  1.17151    1.17174   1.17160   1.17168  1.17146    1.17168
# 3   1.17200  1.17165    1.17197   1.17166   1.17194  1.17160    1.17191
# 4   1.17266  1.17185    1.17244   1.17190   1.17259  1.17178    1.17238
#
#    Volume
# 0     348
# 1     451
# 2     324
# 3     275
# 4     646
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 74778 2022-04-01 05:35:00   1.10690   1.10694  1.10668    1.10676   1.10707
# 74779 2022-04-01 05:40:00   1.10675   1.10727  1.10672    1.10720   1.10691
# 74780 2022-04-01 05:45:00   1.10721   1.10722  1.10698    1.10704   1.10737
# 74781 2022-04-01 05:50:00   1.10703   1.10729  1.10700    1.10726   1.10721
# 74782 2022-04-01 05:55:00   1.10727   1.10737  1.10667    1.10673   1.10742
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 74778   1.10710  1.10683    1.10691   1.10698   1.10702  1.10676    1.10684
# 74779   1.10744  1.10689    1.10737   1.10683   1.10735  1.10680    1.10728
# 74780   1.10738  1.10715    1.10721   1.10729   1.10730  1.10707    1.10712
# 74781   1.10744  1.10717    1.10743   1.10712   1.10736  1.10708    1.10734
# 74782   1.10754  1.10683    1.10690   1.10734   1.10745  1.10675    1.10682
#
#        Volume
# 74778     291
# 74779     400
# 74780     183
# 74781     227
# 74782     439

# %%
print(df_small.head())
print('-' * 75)
print(df_small.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2021-04-01 06:00:00   1.17170   1.17172  1.17144    1.17148   1.17184
# 1 2021-04-01 06:01:00   1.17148   1.17157  1.17146    1.17155   1.17159
# 2 2021-04-01 06:02:00   1.17154   1.17158  1.17141    1.17146   1.17167
# 3 2021-04-01 06:03:00   1.17145   1.17162  1.17141    1.17160   1.17157
# 4 2021-04-01 06:04:00   1.17160   1.17160  1.17141    1.17141   1.17171
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0   1.17187  1.17157    1.17161   1.17177   1.17180  1.17150    1.17154
# 1   1.17169  1.17159    1.17168   1.17154   1.17163  1.17152    1.17162
# 2   1.17170  1.17154    1.17158   1.17160   1.17164  1.17148    1.17152
# 3   1.17174  1.17154    1.17173   1.17151   1.17168  1.17148    1.17166
# 4   1.17171  1.17154    1.17154   1.17166   1.17166  1.17148    1.17148
#
#    Volume
# 0     100
# 1      60
# 2      73
# 3      72
# 4      43
# ---------------------------------------------------------------------------
#                       Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 363798 2022-04-01 05:55:00   1.10727   1.10737  1.10716    1.10716   1.10742
# 363799 2022-04-01 05:56:00   1.10717   1.10717  1.10693    1.10695   1.10732
# 363800 2022-04-01 05:57:00   1.10698   1.10705  1.10691    1.10695   1.10713
# 363801 2022-04-01 05:58:00   1.10695   1.10698  1.10685    1.10686   1.10713
# 363802 2022-04-01 05:59:00   1.10684   1.10685  1.10667    1.10673   1.10700
#
#         Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 363798   1.10754  1.10732    1.10732   1.10734   1.10745  1.10724    1.10724
# 363799   1.10732  1.10709    1.10711   1.10724   1.10724  1.10701    1.10703
# 363800   1.10721  1.10707    1.10711   1.10706   1.10713  1.10699    1.10703
# 363801   1.10713  1.10701    1.10701   1.10704   1.10706  1.10693    1.10694
# 363802   1.10702  1.10683    1.10690   1.10692   1.10694  1.10675    1.10682
#
#         Volume
# 363798      84
# 363799      80
# 363800      42
# 363801     104
# 363802     129

# %%
def psar(barsdata, iaf=0.02, maxaf=0.2):
    length = len(barsdata)
    high = list(barsdata['Mid_High'])
    low = list(barsdata['Mid_Low'])
    close = list(barsdata['Mid_Close'])
    psar = close[0:len(close)]
    bull = True
    af = iaf
    hp = high[0]
    lp = low[0]
    for i in range(2, length):
        if bull:
            psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
        else:
            psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
        reverse = False
        if bull:
            if low[i] < psar[i]:
                bull = False
                reverse = True
                psar[i] = hp
                lp = low[i]
                af = iaf
        else:
            if high[i] > psar[i]:
                bull = True
                reverse = True
                psar[i] = lp
                hp = high[i]
                af = iaf
        if not reverse:
            if bull:
                if high[i] > hp:
                    hp = high[i]
                    af = min(af + iaf, maxaf)
                if low[i - 1] < psar[i]:
                    psar[i] = low[i - 1]
                if low[i - 2] < psar[i]:
                    psar[i] = low[i - 2]
            else:
                if low[i] < lp:
                    lp = low[i]
                    af = min(af + iaf, maxaf)
                if high[i - 1] > psar[i]:
                    psar[i] = high[i - 1]
                if high[i - 2] > psar[i]:
                    psar[i] = high[i - 2]
    return psar


def atr(barsdata, lookback=14):
    high_low = barsdata['Mid_High'] - barsdata['Mid_Low']
    high_close = np.abs(barsdata['Mid_High'] - barsdata['Mid_Close'].shift())
    low_close = np.abs(barsdata['Mid_Low'] - barsdata['Mid_Close'].shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = np.max(ranges, axis=1)

    return true_range.rolling(lookback).sum() / lookback


def rsi(barsdata, periods=14):
    close_delta = barsdata['Mid_Close'].diff()

    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)
    ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))

    return rsi

  
def adx(high, low, close, lookback=14):
    plus_dm = high.diff()
    minus_dm = low.diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0
    
    tr1 = pd.DataFrame(high - low)
    tr2 = pd.DataFrame(abs(high - close.shift(1)))
    tr3 = pd.DataFrame(abs(low - close.shift(1)))
    frames = [tr1, tr2, tr3]
    tr = pd.concat(frames, axis = 1, join = 'inner').max(axis = 1)
    atr = tr.rolling(lookback).mean()
    
    plus_di = 100 * (plus_dm.ewm(alpha = 1/lookback).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha = 1/lookback).mean() / atr))
    dx = (abs(plus_di - minus_di) / abs(plus_di + minus_di)) * 100
    adx = ((dx.shift(1) * (lookback - 1)) + dx) / lookback
    adx_smooth = adx.ewm(alpha = 1/lookback).mean()

    return adx_smooth


def stoch(high, low, close, lookback=14):
    high_lookback = high.rolling(lookback).max()
    low_lookback = low.rolling(lookback).min()
    slow_k = (close - low_lookback) * 100 / (high_lookback - low_lookback)
    slow_d = slow_k.rolling(3).mean()

    return slow_k, slow_d

def stoch_rsi(data, k_window=3, d_window=3, window=14):
    min_val = data.rolling(window=window, center=False).min()
    max_val = data.rolling(window=window, center=False).max()

    stoch = ((data - min_val) / (max_val - min_val)) * 100

    slow_k = stoch.rolling(window=k_window, center=False).mean()

    slow_d = slow_k.rolling(window=d_window, center=False).mean()

    return slow_k, slow_d

def n_macd(macd, macdsignal, lookback=50):
    n_macd = 2 * (((macd - macd.rolling(lookback).min()) / (macd.rolling(lookback).max() - macd.rolling(lookback).min()))) - 1
    n_macdsignal = 2 * (((macdsignal - macdsignal.rolling(lookback).min()) / (macdsignal.rolling(lookback).max() - macdsignal.rolling(lookback).min()))) - 1

    return n_macd, n_macdsignal

def chop(df, lookback=14):
    atr1 = atr(df, lookback=1)
    high, low = df['Mid_High'], df['Mid_Low']

    chop = np.log10(atr1.rolling(lookback).sum() / (high.rolling(lookback).max() - low.rolling(lookback).min())) / np.log10(lookback)

    return chop

def vo(volume, short_lookback=5, long_lookback=10):
    short_ema =  pd.Series.ewm(volume, span=short_lookback).mean()
    long_ema = pd.Series.ewm(volume, span=long_lookback).mean()

    volume_oscillator = (short_ema - long_ema) / long_ema

    return volume_oscillator

def bar_lengths(bar_lens, window=36):
    return bar_lens.rolling(window=window).mean(), bar_lens.rolling(window=window).std()

def sar_lengths(opens, sars, window=36):
    diffs = abs(opens - sars.shift(1))

    return diffs.rolling(window=window).mean(), diffs.rolling(window=window).std()

def range_high_lows(df, i, n_histograms=6):
    green, red = False, False
    curr_color, curr_streak = None, 0
    high, low = -np.inf, np.inf

    while i >= 0:
        hist = df.loc[df.index[i], 'macdhist']
        curr_high, curr_low = df.loc[df.index[i], ['Mid_High', 'Mid_Low']]
        new_color = 'green' if hist > 0 else 'red'

        if curr_color != new_color:
            curr_color = new_color
            curr_streak = 0

            if green and red:
                break

        curr_streak += 1

        if curr_streak >= n_histograms:
            high = max(high, curr_high)
            low = min(low, curr_low)

            if curr_color == 'red':
                red = True

            else:
                green = True

        i -= 1

    return high, low if (high > -np.inf and low < np.inf) else np.nan, np.nan

# def range_high_lows(df, i):
#     green, red = False, False
#     curr_color, curr_streak = None, 0
#     high, low = -np.inf, np.inf

#     while i >= 0:
#         hist = df.loc[df.index[i], 'macdhist']
#         curr_high, curr_low = df.loc[df.index[i], ['Mid_High', 'Mid_Low']]
#         new_color = 'green' if hist > 0 else 'red'

#         if curr_color != new_color:
#             curr_color = new_color
#             curr_streak = 0

#             if green and red:
#                 break

#         curr_streak += 1

#         if curr_streak >= 3:
#             if curr_color == 'red':
#                 low = min(low, curr_low)
#                 red = True

#             else:
#                 high = max(high, curr_high)
#                 green = True

#         i -= 1

#     return high, low if (high > -np.inf and low < np.inf) else np.nan, np.nan

# %%
# Add technical indicators (for additional features)
df['atr'] = atr(df)
df['adx'] = adx(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

print(df)
# Out:
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0     2021-04-01 07:10:00   1.17239   1.17334  1.17239    1.17316   1.17252
# 1     2021-04-01 07:15:00   1.17315   1.17321  1.17274    1.17297   1.17329
# 2     2021-04-01 07:20:00   1.17298   1.17362  1.17263    1.17362   1.17311
# 3     2021-04-01 07:25:00   1.17364   1.17420  1.17352    1.17414   1.17377
# 4     2021-04-01 07:30:00   1.17412   1.17425  1.17381    1.17394   1.17425
# ...                   ...       ...       ...      ...        ...       ...
# 74764 2022-04-01 05:35:00   1.10690   1.10694  1.10668    1.10676   1.10707
# 74765 2022-04-01 05:40:00   1.10675   1.10727  1.10672    1.10720   1.10691
# 74766 2022-04-01 05:45:00   1.10721   1.10722  1.10698    1.10704   1.10737
# 74767 2022-04-01 05:50:00   1.10703   1.10729  1.10700    1.10726   1.10721
# 74768 2022-04-01 05:55:00   1.10727   1.10737  1.10667    1.10673   1.10742
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0       1.17348  1.17252    1.17330   1.17246   1.17341  1.17246    1.17323
# 1       1.17334  1.17287    1.17310   1.17322   1.17328  1.17281    1.17304
# 2       1.17375  1.17276    1.17375   1.17304   1.17368  1.17270    1.17368
# 3       1.17433  1.17366    1.17427   1.17370   1.17426  1.17359    1.17420
# 4       1.17438  1.17391    1.17405   1.17418   1.17432  1.17386    1.17400
# ...         ...      ...        ...       ...       ...      ...        ...
# 74764   1.10710  1.10683    1.10691   1.10698   1.10702  1.10676    1.10684
# 74765   1.10744  1.10689    1.10737   1.10683   1.10735  1.10680    1.10728
# 74766   1.10738  1.10715    1.10721   1.10729   1.10730  1.10707    1.10712
# 74767   1.10744  1.10717    1.10743   1.10712   1.10736  1.10708    1.10734
# 74768   1.10754  1.10683    1.10690   1.10734   1.10745  1.10675    1.10682
#
#        Volume       atr        adx
# 0         662  0.000531  38.394956
# 1         490  0.000520  46.548073
# 2         548  0.000574  49.272128
# 3         698  0.000598  50.893711
# 4         398  0.000573  53.478762
# ...       ...       ...        ...
# 74764     291  0.000272   9.813219
# 74765     400  0.000299   9.807821
# 74766     183  0.000289  10.947864
# 74767     227  0.000294  12.020967
# 74768     439  0.000331  13.107870
#
# [74769 rows x 16 columns]

# %%
value_per_pip = 1.0
amounts_per_day = [-0.00008, -0.0001, -0.00012]
pair = 'EUR_USD'

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee

def get_n_units(open_price, stop_loss, mid_open, currency_pair):
    _, second = currency_pair.split('_')
  
    pips_to_risk = abs(open_price - stop_loss)
    pips_to_risk_calc = pips_to_risk * 10000 if second != 'JPY' else pips_to_risk * 100

    if second == 'USD':
        per_pip = 0.0001

    else:
        per_pip = 0.0001 / mid_open if second != 'JPY' else 0.01 / mid_open

    n_units = int(50 / (pips_to_risk_calc * per_pip))

    return n_units

def run_simulation(risk_reward_ratio, spread_cutoff, atr_multiplier, n_minutes, adx_cutoff):
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    end_date = None
    limit_order = None

    def iterate_thru_small_data(lo):
        def get_end_date(j):
            return df_small.loc[df_small.index[j + 1], 'Date'] if j + 1 < len(df_small) else None

        filtered = df_small[df_small.Date >= lo['start_date']]

        if len(filtered) == 0:
            return -1

        j = filtered.index[0]

        nonlocal reward
        nonlocal day_fees
        nonlocal n_losses
        nonlocal n_wins
        nonlocal n_buys
        nonlocal n_sells
        nonlocal curr_win_streak
        nonlocal curr_loss_streak
        nonlocal win_streak
        nonlocal loss_streak
        nonlocal pips_risked
        trade = None

        while j < len(df_small):
            curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, cur_date = df_small.loc[df_small.index[j], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Date']]

            if lo is not None:
                minutes_elapsed = (cur_date - lo['start_date']).total_seconds() / 60
                curr_long = df[df.Date < cur_date]
                adx_long = curr_long.loc[curr_long.index[-1], 'adx']

                if minutes_elapsed >= n_minutes or adx_long >= adx_cutoff:
                    return cur_date

            if trade is None and lo is not None:
                place_buy = curr_ask_low <= lo['buy_open_price']
                place_sell = curr_bid_high >= lo['sell_open_price']

                if place_buy:
                    open_price = lo['buy_open_price']
                    stop_gain = lo['buy_stop_gain']
                    pips_gained = stop_gain - open_price
                    curr_pips_to_risk = pips_gained / risk_reward_ratio
                    stop_loss = lo['buy_stop_loss']

                    if stop_loss < open_price and stop_gain > open_price:
                        n_units = lo['buy_n_units']

                        trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                        'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                        'n_units': n_units, 'original_units': n_units, 'start_date': cur_date, 'end_date': None}

                        n_buys += 1

                        pips_risked.append(curr_pips_to_risk)
                        
                        lo = None

                elif place_sell:
                    open_price = lo['sell_open_price']
                    stop_gain = lo['sell_stop_gain']
                    pips_gained = open_price - stop_gain
                    curr_pips_to_risk = pips_gained / risk_reward_ratio
                    stop_loss = lo['sell_stop_loss']

                    if stop_loss > open_price and stop_gain < open_price:
                        n_units = lo['sell_n_units']

                        trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                                'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                'n_units': n_units, 'original_units': n_units, 'start_date': cur_date, 'end_date': None}

                        n_sells += 1

                        pips_risked.append(curr_pips_to_risk)

                        lo = None

            if trade is not None and trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
                trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
                reward += trade_amount
                day_fees += calculate_day_fees(trade['start_date'], cur_date, trade['n_units'])

                n_wins += 1 if trade_amount > 0 else 0
                n_losses += 1 if trade_amount < 0 else 0
                curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
                curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

                if curr_win_streak > win_streak:
                    win_streak = curr_win_streak

                if curr_loss_streak > loss_streak:
                    loss_streak = curr_loss_streak

                break

            if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
                trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
                reward += trade_amount
                day_fees += calculate_day_fees(trade['start_date'], cur_date, trade['n_units'])

                n_wins += 1 if trade_amount > 0 else 0
                n_losses += 1 if trade_amount < 0 else 0
                curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
                curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

                if curr_win_streak > win_streak:
                    win_streak = curr_win_streak

                if curr_loss_streak > loss_streak:
                    loss_streak = curr_loss_streak

                break

            if trade is not None and trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
                trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
                reward += trade_amount
                day_fees += calculate_day_fees(trade['start_date'], cur_date, trade['n_units'])

                n_wins += 1 if trade_amount > 0 else 0
                n_losses += 1 if trade_amount < 0 else 0
                curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
                curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

                if curr_win_streak > win_streak:
                    win_streak = curr_win_streak

                if curr_loss_streak > loss_streak:
                    loss_streak = curr_loss_streak

                break

            if trade is not None and trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
                trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
                reward += trade_amount
                day_fees += calculate_day_fees(trade['start_date'], cur_date, trade['n_units'])

                n_wins += 1 if trade_amount > 0 else 0
                n_losses += 1 if trade_amount < 0 else 0
                curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
                curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

                if curr_win_streak > win_streak:
                    win_streak = curr_win_streak

                if curr_loss_streak > loss_streak:
                    loss_streak = curr_loss_streak

                break

            j += 1

        return cur_date

    for i in range(1, len(df)):
        if end_date == -1:
            break

        curr_date = df.loc[df.index[i], 'Date']

        if end_date is not None and end_date >= curr_date:
            continue

        end_date = None
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, curr_mid_open, curr_mid_low = \
            df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_Low']]
        atr, adx, mid_low, mid_high = df.loc[df.index[i - 1], ['atr', 'adx', 'Mid_Low', 'Mid_High']]
        chop_signal = adx < adx_cutoff

        if limit_order is None and chop_signal:
            mid_price = abs(mid_high - mid_low) / 2 + mid_low
            rang = atr * atr_multiplier
            range_high, range_low = mid_price + (rang / 2), mid_price - (rang / 2)
            pips_gain = (rang / 2) * risk_reward_ratio
            pips_to_risk = pips_gain / risk_reward_ratio
            
            if range_high > range_low and spread <= pips_to_risk * spread_cutoff:
                buy_open_price = float(range_low)
                buy_stop_gain = buy_open_price + (rang / 2) * risk_reward_ratio
                buy_pips_gained = buy_stop_gain - buy_open_price
                buy_pips_to_risk = buy_pips_gained / risk_reward_ratio
                buy_pullback = buy_open_price - buy_pips_to_risk
                buy_stop_loss = round(buy_pullback, 5)
                buy_mo = buy_open_price - (spread / 2)
                buy_n_units = get_n_units(buy_open_price, buy_stop_loss, buy_mo, pair)

                sell_open_price = float(range_high)
                sell_stop_gain = sell_open_price - (rang / 2) * risk_reward_ratio
                sell_pips_gained = sell_open_price - sell_stop_gain
                sell_pips_to_risk = sell_pips_gained / risk_reward_ratio
                sell_pullback = sell_open_price + sell_pips_to_risk
                sell_stop_loss = round(sell_pullback, 5)
                sell_mo = sell_open_price + (spread / 2)
                sell_n_units = get_n_units(sell_open_price, sell_stop_loss, sell_mo, pair)

                limit_order = {'buy_open_price': buy_open_price, 'buy_stop_gain': buy_stop_gain, 'buy_stop_loss': buy_stop_loss, 'buy_n_units': buy_n_units, 
                               'sell_open_price': sell_open_price, 'sell_stop_gain': sell_stop_gain, 'sell_stop_loss': sell_stop_loss, 'sell_n_units': sell_n_units, 'start_date': curr_date}

        if limit_order is not None:
            end_date = iterate_thru_small_data(limit_order)
            limit_order = None

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
risk_reward_ratio_vals = [0.25, 0.5, 1.0]
spread_cutoffs = [0.10, 0.20, 0.30]
atr_multipliers = [0.5, 1.0, 1.5, 2.0]  # Determines how wide to make the sideways range
n_minutes_vals = [5, 10, 15]
adx_cutoffs = [20, 25]
all_combos = []


# use_half_sar, vo_cutoff, use_candles

for risk_reward_ratio in risk_reward_ratio_vals:
    for spread_val in spread_cutoffs:
        for atr_multiplier in atr_multipliers:
            for n_minutes in n_minutes_vals:
                for adx_cutoff in adx_cutoffs:
                    all_combos.append((risk_reward_ratio, spread_val, atr_multiplier, n_minutes, adx_cutoff))

# percentage_to_try = 0.5
percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)
print('Num runs: '+ str(len(combos_to_try)) + '\n')

best_risk_reward = None
best_spread_cutoff = None
best_atr_multiplier = None
best_n_minutes= None
best_adx_cutoff = None
top_n_results = 20
best_rewards = []
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, spread_val, atr_multiplier, n_minutes, adx_cutoff in combos_to_try:
    reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked = run_simulation(risk_reward_ratio, spread_val, atr_multiplier, n_minutes, adx_cutoff)
    runs_finished += 1

    print(reward)
    print('Num buys: ' + str(n_buys))
    print('Num sells: ' + str(n_sells))
    print('Num trades: ' + str(n_buys + n_sells))
    print('Num wins: ' + str(n_wins))
    print('Num losses: ' + str(n_losses))
    print('Win streak: ' + str(win_streak))
    print('Loss streak: ' + str(loss_streak))
    # print('Avg pips risked: ' + str(sum(pips_risked) / len(pips_risked)))
    print('Remaining runs: ' + str(n_runs - runs_finished))

    min_item = min(best_rewards, key=lambda entry: entry['reward']) if len(best_rewards) >= top_n_results else None

    if min_item is None or reward > min_item['reward']:
        if min_item is not None:
            best_rewards.remove(min_item)
            
        best_rewards.append({'reward': int(reward), 'ratio': risk_reward_ratio, 'spread_val': spread_val, 'atr_multiplier': atr_multiplier, 'n_minutes': n_minutes, 'adx_cutoff': adx_cutoff})


    if reward > best_reward:
        best_reward = reward
        best_risk_reward = risk_reward_ratio
        best_spread_cutoff = spread_val
        best_atr_multiplier = atr_multiplier
        best_n_minutes = n_minutes
        best_adx_cutoff = adx_cutoff

    print('Best reward so far: ' + str(best_reward))
    print()
# Out:
# Num runs: 216
#
# -24.71396785714942
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 7
# Num losses: 4
# Win streak: 7
# Loss streak: 2
# Remaining runs: 215
# Best reward so far: -24.71396785714942
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 214
# Best reward so far: 0
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 213
# Best reward so far: 0
#
# -7947.448732142543
# Num buys: 289
# Num sells: 314
# Num trades: 603
# Num wins: 222
# Num losses: 381
# Win streak: 5
# Loss streak: 9
# Remaining runs: 212
# Best reward so far: 0
#
# -8638.251754642419
# Num buys: 467
# Num sells: 472
# Num trades: 939
# Num wins: 613
# Num losses: 326
# Win streak: 13
# Loss streak: 6
# Remaining runs: 211
# Best reward so far: 0
#
# -9100.926253839125
# Num buys: 346
# Num sells: 334
# Num trades: 680
# Num wins: 332
# Num losses: 348
# Win streak: 9
# Loss streak: 10
# Remaining runs: 210
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 209
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 208
# Best reward so far: 0
#
# -9076.647384464088
# Num buys: 249
# Num sells: 246
# Num trades: 495
# Num wins: 209
# Num losses: 286
# Win streak: 5
# Loss streak: 8
# Remaining runs: 207
# Best reward so far: 0
#
# -3147.1699414283435
# Num buys: 153
# Num sells: 150
# Num trades: 303
# Num wins: 120
# Num losses: 183
# Win streak: 7
# Loss streak: 12
# Remaining runs: 206
# Best reward so far: 0
#
# -37.49415660714196
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Remaining runs: 205
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 204
# Best reward so far: 0
#
# -24.946922321426676
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 2
# Num losses: 1
# Win streak: 2
# Loss streak: 1
# Remaining runs: 203
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 202
# Best reward so far: 0
#
# -1499.147507500105
# Num buys: 93
# Num sells: 97
# Num trades: 190
# Num wins: 128
# Num losses: 62
# Win streak: 9
# Loss streak: 4
# Remaining runs: 201
# Best reward so far: 0
#
# -1424.2966156250839
# Num buys: 91
# Num sells: 95
# Num trades: 186
# Num wins: 126
# Num losses: 60
# Win streak: 11
# Loss streak: 5
# Remaining runs: 200
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 199
# Best reward so far: 0
#
# -2051.941757856975
# Num buys: 76
# Num sells: 77
# Num trades: 153
# Num wins: 56
# Num losses: 97
# Win streak: 6
# Loss streak: 7
# Remaining runs: 198
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 197
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 196
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 195
# Best reward so far: 0
#
# -6399.908178794469
# Num buys: 292
# Num sells: 286
# Num trades: 578
# Num wins: 360
# Num losses: 218
# Win streak: 11
# Loss streak: 6
# Remaining runs: 194
# Best reward so far: 0
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 193
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 192
# Best reward so far: 0
#
# -13871.310221428466
# Num buys: 499
# Num sells: 557
# Num trades: 1056
# Num wins: 519
# Num losses: 537
# Win streak: 9
# Loss streak: 8
# Remaining runs: 191
# Best reward so far: 0
#
# -14453.063197320573
# Num buys: 408
# Num sells: 401
# Num trades: 809
# Num wins: 260
# Num losses: 549
# Win streak: 6
# Loss streak: 13
# Remaining runs: 190
# Best reward so far: 0
#
# -24.988631785717317
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Remaining runs: 189
# Best reward so far: 0
#
# -4600.853705357076
# Num buys: 209
# Num sells: 198
# Num trades: 407
# Num wins: 252
# Num losses: 155
# Win streak: 10
# Loss streak: 5
# Remaining runs: 188
# Best reward so far: 0
#
# -3351.840891785621
# Num buys: 71
# Num sells: 82
# Num trades: 153
# Num wins: 43
# Num losses: 110
# Win streak: 4
# Loss streak: 15
# Remaining runs: 187
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 186
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 185
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 184
# Best reward so far: 0
#
# -452.549958035534
# Num buys: 29
# Num sells: 38
# Num trades: 67
# Num wins: 29
# Num losses: 38
# Win streak: 6
# Loss streak: 5
# Remaining runs: 183
# Best reward so far: 0
#
# -350.2596705356455
# Num buys: 22
# Num sells: 30
# Num trades: 52
# Num wins: 36
# Num losses: 16
# Win streak: 11
# Loss streak: 2
# Remaining runs: 182
# Best reward so far: 0
#
# -1262.3688066964382
# Num buys: 73
# Num sells: 71
# Num trades: 144
# Num wins: 95
# Num losses: 49
# Win streak: 10
# Loss streak: 3
# Remaining runs: 181
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 180
# Best reward so far: 0
#
# -1201.4979489285427
# Num buys: 31
# Num sells: 33
# Num trades: 64
# Num wins: 20
# Num losses: 44
# Win streak: 2
# Loss streak: 7
# Remaining runs: 179
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 178
# Best reward so far: 0
#
# -787.2383609821484
# Num buys: 39
# Num sells: 38
# Num trades: 77
# Num wins: 49
# Num losses: 28
# Win streak: 7
# Loss streak: 4
# Remaining runs: 177
# Best reward so far: 0
#
# -175.482657053475
# Num buys: 33
# Num sells: 43
# Num trades: 76
# Num wins: 58
# Num losses: 18
# Win streak: 18
# Loss streak: 2
# Remaining runs: 176
# Best reward so far: 0
#
# -1224.8837155355288
# Num buys: 166
# Num sells: 171
# Num trades: 337
# Num wins: 250
# Num losses: 87
# Win streak: 16
# Loss streak: 4
# Remaining runs: 175
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 174
# Best reward so far: 0
#
# -10404.281001963904
# Num buys: 324
# Num sells: 312
# Num trades: 636
# Num wins: 214
# Num losses: 422
# Win streak: 6
# Loss streak: 16
# Remaining runs: 173
# Best reward so far: 0
#
# -1300.4534855355787
# Num buys: 100
# Num sells: 101
# Num trades: 201
# Num wins: 140
# Num losses: 61
# Win streak: 16
# Loss streak: 3
# Remaining runs: 172
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 171
# Best reward so far: 0
#
# -99.99964714286618
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 170
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 169
# Best reward so far: 0
#
# -4963.925044821176
# Num buys: 321
# Num sells: 347
# Num trades: 668
# Num wins: 455
# Num losses: 213
# Win streak: 18
# Loss streak: 6
# Remaining runs: 168
# Best reward so far: 0
#
# -9812.71873307983
# Num buys: 508
# Num sells: 522
# Num trades: 1030
# Num wins: 667
# Num losses: 363
# Win streak: 14
# Loss streak: 7
# Remaining runs: 167
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 166
# Best reward so far: 0
#
# -350.98164642848525
# Num buys: 16
# Num sells: 17
# Num trades: 33
# Num wins: 13
# Num losses: 20
# Win streak: 4
# Loss streak: 4
# Remaining runs: 165
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 164
# Best reward so far: 0
#
# -99.99964714286618
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 163
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 162
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 161
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 160
# Best reward so far: 0
#
# -15003.154352856458
# Num buys: 438
# Num sells: 498
# Num trades: 936
# Num wins: 318
# Num losses: 618
# Win streak: 6
# Loss streak: 16
# Remaining runs: 159
# Best reward so far: 0
#
# -17548.884398213613
# Num buys: 766
# Num sells: 788
# Num trades: 1554
# Num wins: 802
# Num losses: 752
# Win streak: 10
# Loss streak: 8
# Remaining runs: 158
# Best reward so far: 0
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 157
# Best reward so far: 0
#
# -675.7007931248787
# Num buys: 58
# Num sells: 58
# Num trades: 116
# Num wins: 82
# Num losses: 34
# Win streak: 16
# Loss streak: 3
# Remaining runs: 156
# Best reward so far: 0
#
# 75.02642205355575
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 10
# Num losses: 1
# Win streak: 9
# Loss streak: 1
# Remaining runs: 155
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 154
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 153
# Best reward so far: 75.02642205355575
#
# -7749.567253571551
# Num buys: 307
# Num sells: 340
# Num trades: 647
# Num wins: 328
# Num losses: 319
# Win streak: 9
# Loss streak: 7
# Remaining runs: 152
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 151
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 150
# Best reward so far: 75.02642205355575
#
# -99.99964714286618
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 149
# Best reward so far: 75.02642205355575
#
# -2874.6664624998657
# Num buys: 155
# Num sells: 156
# Num trades: 311
# Num wins: 169
# Num losses: 142
# Win streak: 6
# Loss streak: 8
# Remaining runs: 148
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 147
# Best reward so far: 75.02642205355575
#
# -149.81261321433416
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 4
# Num losses: 7
# Win streak: 3
# Loss streak: 3
# Remaining runs: 146
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 145
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 144
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 143
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 142
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 141
# Best reward so far: 75.02642205355575
#
# -2200.9789364284993
# Num buys: 82
# Num sells: 85
# Num trades: 167
# Num wins: 82
# Num losses: 85
# Win streak: 7
# Loss streak: 6
# Remaining runs: 140
# Best reward so far: 75.02642205355575
#
# 12.542118749976787
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 5
# Num losses: 1
# Win streak: 4
# Loss streak: 1
# Remaining runs: 139
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 138
# Best reward so far: 75.02642205355575
#
# -11197.300076427891
# Num buys: 501
# Num sells: 517
# Num trades: 1018
# Num wins: 397
# Num losses: 621
# Win streak: 7
# Loss streak: 10
# Remaining runs: 137
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 136
# Best reward so far: 75.02642205355575
#
# -2199.8420957142534
# Num buys: 94
# Num sells: 94
# Num trades: 188
# Num wins: 96
# Num losses: 92
# Win streak: 10
# Loss streak: 5
# Remaining runs: 135
# Best reward so far: 75.02642205355575
#
# -1825.735265357167
# Num buys: 68
# Num sells: 66
# Num trades: 134
# Num wins: 65
# Num losses: 69
# Win streak: 5
# Loss streak: 5
# Remaining runs: 134
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 133
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 132
# Best reward so far: 75.02642205355575
#
# -1951.494898571298
# Num buys: 87
# Num sells: 82
# Num trades: 169
# Num wins: 65
# Num losses: 104
# Win streak: 8
# Loss streak: 10
# Remaining runs: 131
# Best reward so far: 75.02642205355575
#
# -8050.8786819640645
# Num buys: 572
# Num sells: 584
# Num trades: 1156
# Num wins: 796
# Num losses: 360
# Win streak: 17
# Loss streak: 6
# Remaining runs: 130
# Best reward so far: 75.02642205355575
#
# -601.5180848213515
# Num buys: 18
# Num sells: 22
# Num trades: 40
# Num wins: 14
# Num losses: 26
# Win streak: 2
# Loss streak: 5
# Remaining runs: 129
# Best reward so far: 75.02642205355575
#
# -99.99964714286618
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 128
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 127
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 126
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 125
# Best reward so far: 75.02642205355575
#
# -99.99964714286618
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 124
# Best reward so far: 75.02642205355575
#
# -476.51552169628434
# Num buys: 48
# Num sells: 47
# Num trades: 95
# Num wins: 57
# Num losses: 38
# Win streak: 10
# Loss streak: 4
# Remaining runs: 123
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 122
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 121
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 120
# Best reward so far: 75.02642205355575
#
# -787.1576192857157
# Num buys: 39
# Num sells: 38
# Num trades: 77
# Num wins: 49
# Num losses: 28
# Win streak: 7
# Loss streak: 4
# Remaining runs: 119
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 118
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 117
# Best reward so far: 75.02642205355575
#
# -876.7240940177481
# Num buys: 52
# Num sells: 57
# Num trades: 109
# Num wins: 61
# Num losses: 48
# Win streak: 9
# Loss streak: 4
# Remaining runs: 116
# Best reward so far: 75.02642205355575
#
# -99.66325500001713
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 6
# Num losses: 5
# Win streak: 6
# Loss streak: 3
# Remaining runs: 115
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 114
# Best reward so far: 75.02642205355575
#
# 0.16696249999958468
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 4
# Num losses: 2
# Win streak: 4
# Loss streak: 2
# Remaining runs: 113
# Best reward so far: 75.02642205355575
#
# 12.551795624975705
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 9
# Num losses: 2
# Win streak: 8
# Loss streak: 2
# Remaining runs: 112
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 111
# Best reward so far: 75.02642205355575
#
# -600.6557386606776
# Num buys: 23
# Num sells: 28
# Num trades: 51
# Num wins: 26
# Num losses: 25
# Win streak: 6
# Loss streak: 6
# Remaining runs: 110
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 109
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 108
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 107
# Best reward so far: 75.02642205355575
#
# -362.8142662945819
# Num buys: 23
# Num sells: 28
# Num trades: 51
# Num wins: 35
# Num losses: 16
# Win streak: 11
# Loss streak: 3
# Remaining runs: 106
# Best reward so far: 75.02642205355575
#
# -300.425930937363
# Num buys: 53
# Num sells: 53
# Num trades: 106
# Num wins: 80
# Num losses: 26
# Win streak: 18
# Loss streak: 2
# Remaining runs: 105
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 104
# Best reward so far: 75.02642205355575
#
# -1423.7001024999277
# Num buys: 91
# Num sells: 113
# Num trades: 204
# Num wins: 117
# Num losses: 87
# Win streak: 8
# Loss streak: 5
# Remaining runs: 103
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 102
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 101
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 100
# Best reward so far: 75.02642205355575
#
# -652.0577221426911
# Num buys: 41
# Num sells: 40
# Num trades: 81
# Num wins: 34
# Num losses: 47
# Win streak: 3
# Loss streak: 5
# Remaining runs: 99
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 98
# Best reward so far: 75.02642205355575
#
# -1074.0165528571924
# Num buys: 36
# Num sells: 38
# Num trades: 74
# Num wins: 35
# Num losses: 39
# Win streak: 4
# Loss streak: 4
# Remaining runs: 97
# Best reward so far: 75.02642205355575
#
# -2748.895087856921
# Num buys: 143
# Num sells: 142
# Num trades: 285
# Num wins: 115
# Num losses: 170
# Win streak: 5
# Loss streak: 12
# Remaining runs: 96
# Best reward so far: 75.02642205355575
#
# -9999.690277321033
# Num buys: 252
# Num sells: 252
# Num trades: 504
# Num wins: 152
# Num losses: 352
# Win streak: 4
# Loss streak: 13
# Remaining runs: 95
# Best reward so far: 75.02642205355575
#
# -49.977365000009264
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 1
# Remaining runs: 94
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 93
# Best reward so far: 75.02642205355575
#
# -37.54118607143433
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Remaining runs: 92
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 91
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 90
# Best reward so far: 75.02642205355575
#
# -12123.010087499708
# Num buys: 547
# Num sells: 570
# Num trades: 1117
# Num wins: 583
# Num losses: 534
# Win streak: 9
# Loss streak: 8
# Remaining runs: 89
# Best reward so far: 75.02642205355575
#
# -425.6948658928176
# Num buys: 22
# Num sells: 27
# Num trades: 49
# Num wins: 27
# Num losses: 22
# Win streak: 6
# Loss streak: 5
# Remaining runs: 88
# Best reward so far: 75.02642205355575
#
# -1548.227237856905
# Num buys: 86
# Num sells: 103
# Num trades: 189
# Num wins: 79
# Num losses: 110
# Win streak: 6
# Loss streak: 8
# Remaining runs: 87
# Best reward so far: 75.02642205355575
#
# -22299.762744284497
# Num buys: 777
# Num sells: 797
# Num trades: 1574
# Num wins: 564
# Num losses: 1010
# Win streak: 9
# Loss streak: 10
# Remaining runs: 86
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 85
# Best reward so far: 75.02642205355575
#
# -1202.7836112498724
# Num buys: 47
# Num sells: 49
# Num trades: 96
# Num wins: 36
# Num losses: 60
# Win streak: 3
# Loss streak: 4
# Remaining runs: 84
# Best reward so far: 75.02642205355575
#
# -1899.3504051786906
# Num buys: 83
# Num sells: 87
# Num trades: 170
# Num wins: 88
# Num losses: 82
# Win streak: 9
# Loss streak: 6
# Remaining runs: 83
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 82
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 81
# Best reward so far: 75.02642205355575
#
# -999.9926871428789
# Num buys: 29
# Num sells: 30
# Num trades: 59
# Num wins: 26
# Num losses: 33
# Win streak: 3
# Loss streak: 6
# Remaining runs: 80
# Best reward so far: 75.02642205355575
#
# -20492.95625785638
# Num buys: 871
# Num sells: 916
# Num trades: 1787
# Num wins: 918
# Num losses: 869
# Win streak: 9
# Loss streak: 9
# Remaining runs: 79
# Best reward so far: 75.02642205355575
#
# -9752.342716964207
# Num buys: 271
# Num sells: 272
# Num trades: 543
# Num wins: 232
# Num losses: 311
# Win streak: 7
# Loss streak: 11
# Remaining runs: 78
# Best reward so far: 75.02642205355575
#
# -675.6801718749416
# Num buys: 17
# Num sells: 22
# Num trades: 39
# Num wins: 17
# Num losses: 22
# Win streak: 3
# Loss streak: 4
# Remaining runs: 77
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 76
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 75
# Best reward so far: 75.02642205355575
#
# -37.54118607143433
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Remaining runs: 74
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 73
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 72
# Best reward so far: 75.02642205355575
#
# -99.81264750004173
# Num buys: 3
# Num sells: 7
# Num trades: 10
# Num wins: 4
# Num losses: 6
# Win streak: 3
# Loss streak: 2
# Remaining runs: 71
# Best reward so far: 75.02642205355575
#
# -3252.0270139284926
# Num buys: 76
# Num sells: 85
# Num trades: 161
# Num wins: 48
# Num losses: 113
# Win streak: 4
# Loss streak: 11
# Remaining runs: 70
# Best reward so far: 75.02642205355575
#
# 0.10583678571325095
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 2
# Num losses: 1
# Win streak: 2
# Loss streak: 1
# Remaining runs: 69
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 68
# Best reward so far: 75.02642205355575
#
# -15500.710327856159
# Num buys: 934
# Num sells: 991
# Num trades: 1925
# Num wins: 1292
# Num losses: 633
# Win streak: 16
# Loss streak: 7
# Remaining runs: 67
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 66
# Best reward so far: 75.02642205355575
#
# -37.54118607143433
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Remaining runs: 65
# Best reward so far: 75.02642205355575
#
# -712.4969994641428
# Num buys: 97
# Num sells: 116
# Num trades: 213
# Num wins: 159
# Num losses: 54
# Win streak: 19
# Loss streak: 3
# Remaining runs: 64
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 63
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 62
# Best reward so far: 75.02642205355575
#
# -5837.63896749989
# Num buys: 266
# Num sells: 267
# Num trades: 533
# Num wins: 333
# Num losses: 200
# Win streak: 9
# Loss streak: 6
# Remaining runs: 61
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 60
# Best reward so far: 75.02642205355575
#
# -626.145276517715
# Num buys: 33
# Num sells: 44
# Num trades: 77
# Num wins: 43
# Num losses: 34
# Win streak: 8
# Loss streak: 4
# Remaining runs: 59
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 58
# Best reward so far: 75.02642205355575
#
# -10637.618208570895
# Num buys: 533
# Num sells: 606
# Num trades: 1139
# Num wins: 741
# Num losses: 398
# Win streak: 12
# Loss streak: 5
# Remaining runs: 57
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 56
# Best reward so far: 75.02642205355575
#
# -2653.7407578570183
# Num buys: 63
# Num sells: 66
# Num trades: 129
# Num wins: 38
# Num losses: 91
# Win streak: 3
# Loss streak: 9
# Remaining runs: 55
# Best reward so far: 75.02642205355575
#
# -12928.584011606756
# Num buys: 438
# Num sells: 431
# Num trades: 869
# Num wins: 407
# Num losses: 462
# Win streak: 9
# Loss streak: 9
# Remaining runs: 54
# Best reward so far: 75.02642205355575
#
# -99.99964714286618
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Remaining runs: 53
# Best reward so far: 75.02642205355575
#
# -14304.538329374622
# Num buys: 471
# Num sells: 487
# Num trades: 958
# Num wins: 448
# Num losses: 510
# Win streak: 8
# Loss streak: 12
# Remaining runs: 52
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 51
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 50
# Best reward so far: 75.02642205355575
#
# -10049.473647320952
# Num buys: 239
# Num sells: 232
# Num trades: 471
# Num wins: 135
# Num losses: 336
# Win streak: 4
# Loss streak: 15
# Remaining runs: 49
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 48
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 47
# Best reward so far: 75.02642205355575
#
# -18305.04718142746
# Num buys: 675
# Num sells: 697
# Num trades: 1372
# Num wins: 503
# Num losses: 869
# Win streak: 5
# Loss streak: 12
# Remaining runs: 46
# Best reward so far: 75.02642205355575
#
# -287.81899709817776
# Num buys: 16
# Num sells: 21
# Num trades: 37
# Num wins: 25
# Num losses: 12
# Win streak: 8
# Loss streak: 2
# Remaining runs: 45
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 44
# Best reward so far: 75.02642205355575
#
# -13963.35213107065
# Num buys: 819
# Num sells: 859
# Num trades: 1678
# Num wins: 1119
# Num losses: 559
# Win streak: 22
# Loss streak: 5
# Remaining runs: 43
# Best reward so far: 75.02642205355575
#
# -100.15092785717188
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 2
# Num losses: 4
# Win streak: 2
# Loss streak: 4
# Remaining runs: 42
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 41
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 40
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 39
# Best reward so far: 75.02642205355575
#
# -6012.602092231738
# Num buys: 365
# Num sells: 354
# Num trades: 719
# Num wins: 479
# Num losses: 240
# Win streak: 15
# Loss streak: 6
# Remaining runs: 38
# Best reward so far: 75.02642205355575
#
# -6302.802202678386
# Num buys: 185
# Num sells: 181
# Num trades: 366
# Num wins: 120
# Num losses: 246
# Win streak: 5
# Loss streak: 13
# Remaining runs: 37
# Best reward so far: 75.02642205355575
#
# -662.365050714139
# Num buys: 50
# Num sells: 62
# Num trades: 112
# Num wins: 79
# Num losses: 33
# Win streak: 13
# Loss streak: 3
# Remaining runs: 36
# Best reward so far: 75.02642205355575
#
# -1252.1409378570918
# Num buys: 26
# Num sells: 29
# Num trades: 55
# Num wins: 15
# Num losses: 40
# Win streak: 2
# Loss streak: 9
# Remaining runs: 35
# Best reward so far: 75.02642205355575
#
# -1137.752297678435
# Num buys: 89
# Num sells: 90
# Num trades: 179
# Num wins: 125
# Num losses: 54
# Win streak: 11
# Loss streak: 3
# Remaining runs: 34
# Best reward so far: 75.02642205355575
#
# -701.3096464285182
# Num buys: 21
# Num sells: 21
# Num trades: 42
# Num wins: 14
# Num losses: 28
# Win streak: 3
# Loss streak: 6
# Remaining runs: 33
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 32
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 31
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 30
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 29
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 28
# Best reward so far: 75.02642205355575
#
# -1074.0984148215077
# Num buys: 35
# Num sells: 39
# Num trades: 74
# Num wins: 35
# Num losses: 39
# Win streak: 4
# Loss streak: 4
# Remaining runs: 27
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 26
# Best reward so far: 75.02642205355575
#
# -1049.6562857141664
# Num buys: 45
# Num sells: 54
# Num trades: 99
# Num wins: 39
# Num losses: 60
# Win streak: 7
# Loss streak: 6
# Remaining runs: 25
# Best reward so far: 75.02642205355575
#
# 0.022417857139146236
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Remaining runs: 24
# Best reward so far: 75.02642205355575
#
# -49.99968142857378
# Num buys: 0
# Num sells: 1
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 23
# Best reward so far: 75.02642205355575
#
# -1536.70072571406
# Num buys: 183
# Num sells: 189
# Num trades: 372
# Num wins: 273
# Num losses: 99
# Win streak: 14
# Loss streak: 3
# Remaining runs: 22
# Best reward so far: 75.02642205355575
#
# -11421.482335713954
# Num buys: 437
# Num sells: 492
# Num trades: 929
# Num wins: 467
# Num losses: 462
# Win streak: 10
# Loss streak: 10
# Remaining runs: 21
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 20
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 19
# Best reward so far: 75.02642205355575
#
# -1124.3650882142688
# Num buys: 47
# Num sells: 61
# Num trades: 108
# Num wins: 57
# Num losses: 51
# Win streak: 7
# Loss streak: 6
# Remaining runs: 18
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 17
# Best reward so far: 75.02642205355575
#
# -15553.54827696372
# Num buys: 428
# Num sells: 441
# Num trades: 869
# Num wins: 279
# Num losses: 590
# Win streak: 6
# Loss streak: 16
# Remaining runs: 16
# Best reward so far: 75.02642205355575
#
# -612.5800982143159
# Num buys: 31
# Num sells: 30
# Num trades: 61
# Num wins: 39
# Num losses: 22
# Win streak: 8
# Loss streak: 3
# Remaining runs: 15
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 14
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 13
# Best reward so far: 75.02642205355575
#
# -2149.4186021430473
# Num buys: 83
# Num sells: 89
# Num trades: 172
# Num wins: 86
# Num losses: 86
# Win streak: 6
# Loss streak: 6
# Remaining runs: 12
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 11
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 10
# Best reward so far: 75.02642205355575
#
# -11399.254448570726
# Num buys: 379
# Num sells: 447
# Num trades: 826
# Num wins: 299
# Num losses: 527
# Win streak: 5
# Loss streak: 13
# Remaining runs: 9
# Best reward so far: 75.02642205355575
#
# -1251.7237692856859
# Num buys: 32
# Num sells: 35
# Num trades: 67
# Num wins: 21
# Num losses: 46
# Win streak: 2
# Loss streak: 6
# Remaining runs: 8
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 7
# Best reward so far: 75.02642205355575
#
# -8724.577624285213
# Num buys: 462
# Num sells: 530
# Num trades: 992
# Num wins: 654
# Num losses: 338
# Win streak: 15
# Loss streak: 4
# Remaining runs: 6
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 5
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 4
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 3
# Best reward so far: 75.02642205355575
#
# -6751.271800535656
# Num buys: 199
# Num sells: 191
# Num trades: 390
# Num wins: 170
# Num losses: 220
# Win streak: 7
# Loss streak: 8
# Remaining runs: 2
# Best reward so far: 75.02642205355575
#
# -3397.5110478570214
# Num buys: 168
# Num sells: 167
# Num trades: 335
# Num wins: 178
# Num losses: 157
# Win streak: 8
# Loss streak: 7
# Remaining runs: 1
# Best reward so far: 75.02642205355575
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Remaining runs: 0
# Best reward so far: 75.02642205355575

# %%
# EUR/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n minutes: ' + str(best_n_minutes))
print('Best adx cutoff: ' + str(best_adx_cutoff))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 75.02642205355575
# Best risk/reward ratio: 0.25
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n minutes: 15
# Best adx cutoff: 25
# -----------------------
# Top results:
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_minutes': 10, 'adx_cutoff': 20}
# {'reward': 0, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_minutes': 5, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 15, 'adx_cutoff': 20}
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 20}
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.3, 'atr_multiplier': 0.5, 'n_minutes': 15, 'adx_cutoff': 20}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 15, 'adx_cutoff': 20}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 0.25, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.3, 'atr_multiplier': 0.5, 'n_minutes': 15, 'adx_cutoff': 20}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 0.5, 'n_minutes': 5, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 0.25, 'spread_val': 0.3, 'atr_multiplier': 0.5, 'n_minutes': 5, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 75, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 12, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 5, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 5, 'adx_cutoff': 25}
# {'reward': 12, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_minutes': 10, 'adx_cutoff': 25}

# %%
# GBP/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 4223.3566550000905
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 4124, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 2249, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 2668, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 3674, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 2172, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 1450, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 4223, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 2473, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 2275, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}

# %%
# AUD/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1876.0760714286596
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 95, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 1798, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 1876, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 1650, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 1700, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 1497, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 50, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 850, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 1199, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}

# %%
# USD/CAD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 4048.6535253571433
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 1
# -----------------------
# Top results:
# {'reward': 2053, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 716, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 4048, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 636, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 523, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 2977, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 3480, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 2039, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 2445, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}

# %%
# USD/JPY
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 250758.18965857464
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 1
# -----------------------
# Top results:
# {'reward': 145619, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 192316, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 37162, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 176101, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 225827, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 250758, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 206984, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 135342, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 148785, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}

# %%
# USD/CHF
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1456.2561146429143
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 1456, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 1316, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 225, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 1034, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 207, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 690, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 296, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 302, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 1339, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}

# %%
# NZD/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1074.2768450000149
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 3
# -----------------------
# Top results:
# {'reward': 725, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 1074, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': -25, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 624, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 750, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 449, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 549, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 774, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 1049, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}

# %%
# GBP/CHF
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n minutes: ' + str(best_n_minutes))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 259.48194125004545
# Best risk/reward ratio: 1.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n minutes: 5
# -----------------------
# Top results:
# {'reward': 259, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5}
# {'reward': -282, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 10}
# {'reward': -1, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 5}
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 5}
# {'reward': -51, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 5}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 10}
# {'reward': -24, 'ratio': 0.5, 'spread_val': 0.3, 'atr_multiplier': 2.0, 'n_minutes': 5}
# {'reward': -105, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_minutes': 10}
# {'reward': -126, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 10}
# {'reward': -278, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_minutes': 10}
# {'reward': -50, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 5}
# {'reward': 49, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 5}
# {'reward': -75, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_minutes': 5}
# {'reward': -2, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 5}
# {'reward': -1, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 10}
# {'reward': 0, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_minutes': 5}
# {'reward': -50, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_minutes': 5}
# {'reward': 0, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_minutes': 10}
# {'reward': -25, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5}
# {'reward': -150, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 5}

# %%
# EUR/JPY
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 403452.127566436
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 222544, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 127405, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 285747, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 171298, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 199570, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 403452, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 178521, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 100253, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 30516, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
