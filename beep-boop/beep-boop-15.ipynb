# %%
import talib
import numpy as np
import pandas as pd
import random
from collections import deque

# %%
file_path = '/Users/mymac/Google_Drive/Forex_Robot/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
df = pd.read_csv(file_path + 'Oanda_Gbp_Usd_M15_2014-2021.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

df_small = pd.read_csv(file_path + 'Oanda_Gbp_Usd_M5_2014-2021.csv')
df_small.Date = pd.to_datetime(df_small.Date)
df_small.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2014-07-30 07:00:00   1.69402   1.69402  1.69323    1.69332   1.69417
# 1 2014-07-30 07:15:00   1.69332   1.69356  1.69278    1.69323   1.69348
# 2 2014-07-30 07:30:00   1.69319   1.69351  1.69304    1.69343   1.69334
# 3 2014-07-30 07:45:00   1.69343   1.69364  1.69314    1.69338   1.69359
# 4 2014-07-30 08:00:00   1.69339   1.69361  1.69334    1.69348   1.69353
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 0   1.69417  1.69338    1.69347   1.69410   1.69410  1.69330    1.69340
# 1   1.69372  1.69296    1.69337   1.69340   1.69364  1.69287    1.69330
# 2   1.69367  1.69320    1.69357   1.69326   1.69359  1.69312    1.69350
# 3   1.69379  1.69329    1.69354   1.69351   1.69372  1.69322    1.69346
# 4   1.69376  1.69348    1.69363   1.69346   1.69368  1.69342    1.69356
# ---------------------------------------------------------------------------
#                       Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 173795 2021-07-30 05:45:00   1.39359   1.39380  1.39337    1.39379   1.39376
# 173796 2021-07-30 06:00:00   1.39380   1.39432  1.39376    1.39422   1.39394
# 173797 2021-07-30 06:15:00   1.39419   1.39456  1.39401    1.39428   1.39435
# 173798 2021-07-30 06:30:00   1.39430   1.39452  1.39378    1.39422   1.39447
# 173799 2021-07-30 06:45:00   1.39420   1.39503  1.39400    1.39503   1.39436
#
#         Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 173795   1.39400  1.39356    1.39399   1.39368   1.39390  1.39346    1.39389
# 173796   1.39448  1.39392    1.39438   1.39387   1.39440  1.39384    1.39430
# 173797   1.39474  1.39418    1.39445   1.39427   1.39465  1.39410    1.39436
# 173798   1.39467  1.39394    1.39440   1.39438   1.39459  1.39386    1.39431
# 173799   1.39518  1.39418    1.39518   1.39428   1.39510  1.39409    1.39510

# %%
print(df_small.head())
print('-' * 75)
print(df_small.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2014-07-30 07:00:00   1.69402   1.69402  1.69359    1.69360   1.69417
# 1 2014-07-30 07:05:00   1.69360   1.69373  1.69344    1.69359   1.69375
# 2 2014-07-30 07:10:00   1.69357   1.69382  1.69323    1.69332   1.69372
# 3 2014-07-30 07:15:00   1.69332   1.69336  1.69278    1.69310   1.69348
# 4 2014-07-30 07:20:00   1.69309   1.69356  1.69306    1.69345   1.69323
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 0   1.69417  1.69374    1.69374   1.69410   1.69410  1.69366    1.69367
# 1   1.69388  1.69359    1.69372   1.69368   1.69380  1.69352    1.69366
# 2   1.69398  1.69338    1.69347   1.69364   1.69390  1.69330    1.69340
# 3   1.69352  1.69296    1.69323   1.69340   1.69344  1.69287    1.69316
# 4   1.69372  1.69320    1.69361   1.69316   1.69364  1.69313    1.69353
# ---------------------------------------------------------------------------
#                       Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 519477 2021-07-30 06:35:00   1.39401   1.39451  1.39401    1.39430   1.39417
# 519478 2021-07-30 06:40:00   1.39433   1.39452  1.39415    1.39422   1.39449
# 519479 2021-07-30 06:45:00   1.39420   1.39455  1.39400    1.39451   1.39436
# 519480 2021-07-30 06:50:00   1.39454   1.39481  1.39447    1.39470   1.39469
# 519481 2021-07-30 06:55:00   1.39469   1.39503  1.39462    1.39503   1.39486
#
#         Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 519477   1.39467  1.39417    1.39447   1.39409   1.39459  1.39409    1.39438
# 519478   1.39466  1.39433    1.39440   1.39441   1.39459  1.39424    1.39431
# 519479   1.39472  1.39418    1.39466   1.39428   1.39464  1.39409    1.39458
# 519480   1.39499  1.39462    1.39490   1.39462   1.39490  1.39454    1.39480
# 519481   1.39518  1.39477    1.39518   1.39478   1.39510  1.39470    1.39510

# %%
def add_fractal(df, i, look_back=3):
  if i >= look_back and i < df.shape[0] - look_back:
    lows = []
    highs = []

    for j in range(1, look_back + 1):
      prev_bid_low, prev_bid_high = df.loc[df.index[i - j], ['Mid_Low', 'Mid_High']]
      future_bid_low, future_bid_high = df.loc[df.index[i + j], ['Mid_Low', 'Mid_High']]

      lows.append(float(prev_bid_low))
      lows.append(float(future_bid_low))
      highs.append(float(prev_bid_high))
      highs.append(float(future_bid_high))

    bid_low, bid_high = df.loc[df.index[i], ['Mid_Low', 'Mid_High']]

    if float(bid_low) < min(lows):
      return 1

    elif float(bid_high) > max(highs):
      return 2

    else:
      return 0

  else:
    return np.nan


def add_beep_boop(row):
  macdhist, ema50, mid_low, mid_high = row[['macdhist', 'ema50', 'Mid_Low', 'Mid_High']]

  if float(macdhist) > 0 and float(mid_low) > float(ema50):
    return 1

  elif float(macdhist) < 0 and float(mid_high) < float(ema50):
    return 2

  else:
    return 0

# %%
df['macd'], df['macdsignal'], df['macdhist'] = talib.MACD(df['Mid_Close'])
df['ema200'] = talib.EMA(df['Mid_Close'], timeperiod=200)
df['ema50'] = talib.EMA(df['Mid_Close'], timeperiod=50)
df['ema30'] = talib.EMA(df['Mid_Close'], timeperiod=30)
df['ema25'] = talib.EMA(df['Mid_Close'], timeperiod=25)
df['ema20'] = talib.EMA(df['Mid_Close'], timeperiod=20)
df['ema15'] = talib.EMA(df['Mid_Close'], timeperiod=15)
df['atr'] = talib.ATR(df['Mid_High'], df['Mid_Low'], df['Mid_Close'], timeperiod=500)
# df['fractal'] = [add_fractal(df, i) for i in range(df.shape[0])]
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df['beep_boop'] = df.apply(add_beep_boop, axis=1)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

print(df['beep_boop'].value_counts())
# print(df['fractal'].value_counts())
# Out:
# 0    88559
# 2    42803
# 1    41938
# Name: beep_boop, dtype: int64

# %%
value_per_pip = 1.0
max_pips_to_risk = 0.0100
amounts_per_day = [-4, -5, -6]

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25])
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee


def run_simulation(risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length, ema_val, max_open_trades=1):
    pullback_cushion /= 10000
    fractal_distance /= 10000
    bar_length /= 10000
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    n_units = 50000 / max_open_trades
    trades = deque(maxlen=max_open_trades)

    def iterate_thru_small_data(trade):
        def get_end_date(j):
          return df_small.loc[df_small.index[j + 1], 'Date'] if j + 1 < len(df_small) else None

        j = df_small[df_small.Date >= trade['start_date']].index[0]

        nonlocal reward
        nonlocal day_fees
        nonlocal n_losses
        nonlocal n_wins
        nonlocal curr_win_streak
        nonlocal curr_loss_streak
        nonlocal win_streak
        nonlocal loss_streak

        while j < len(df_small):
          curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, curr_date = \
          df_small.loc[df_small.index[j], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low',
                                         'Ask_Close', 'Date']]

          if trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
            trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date)

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade['end_date'] = get_end_date(j)

            break

          if trade['trade_type'] == 'buy' and curr_bid_high - trade['pips_risked'] > trade['stop_loss']:
              trade['stop_loss'] = curr_bid_high - trade['pips_risked']

          if trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
            trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date)

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade['end_date'] = get_end_date(j)

            break

          if trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
            trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date)

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade['end_date'] = get_end_date(j)

            break

          if trade['trade_type'] == 'sell' and trade['pips_risked'] + curr_ask_low < trade['stop_loss']:
            trade['stop_loss'] = trade['pips_risked'] + curr_ask_low

          if trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
            trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date)

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade['end_date'] = get_end_date(j)

            break

          j += 1


    i = 2

    while i < len(df):
        if i < last_x_bars:
            i += 1
            continue

        curr_date = df.loc[df.index[i], 'Date']

        # Remove any expired trades -----------------------------------------
        trades_to_remove = []

        for trade in trades:
          if trade['end_date'] is not None and trade['end_date'] >= curr_date:
            trades_to_remove.append(trade)

        for trade in trades_to_remove:
          trades.remove(trade)
        # -------------------------------------------------------------------

        ema200 = df.loc[df.index[i - 1], 'ema200']
        pullback = df.loc[df.index[i - 1], ema_val]
        atr = df.loc[df.index[i - 1], 'atr']
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        enough_volatility = (spread / atr) <= atr_percentage
        curr_al = df.loc[df.index[i - 1], 'Ask_Low']
        curr_bh = df.loc[df.index[i - 1], 'Bid_High']
        previous_ask_lows = []
        previous_bid_highs = []
        curr_ml = df.loc[df.index[i - 1], 'Mid_Low']
        curr_mh = df.loc[df.index[i - 1], 'Mid_High']
        curr_bar_length = abs(curr_mh - curr_ml)
        beep_boop1 = df.loc[df.index[i - 1], 'beep_boop']
        beep_boop2 = df.loc[df.index[i - 2], 'beep_boop']

        for ind in range(i - last_x_bars, i):
          previous_ask_lows.append(df.loc[df.index[ind], 'Ask_Low'])
          previous_bid_highs.append(df.loc[df.index[ind], 'Bid_High'])

        process_trade = False

        if beep_boop2 == 1 and beep_boop1 == 1 and curr_ml > ema200 and enough_volatility and len(trades) < max_open_trades and curr_al <= min(previous_ask_lows) and curr_bar_length <= bar_length:
            all_buys = True

            for trade in trades:
                if trade['trade_type'] != 'buy':
                    all_buys = False
                    break

            if all_buys:
              # pullback = None
              # u = i - 4

              # while u >= 0:
              #     if df.loc[df.index[u], 'fractal'] == 1:
              #         curr_pullback = float(df.loc[df.index[u], 'Bid_Low'])
              #         curr_fractal_distance = curr_ao - curr_pullback

              #         if curr_fractal_distance >= fractal_distance:
              #             pullback = curr_pullback
              #             break

              #     u -= 1

              if pullback is not None:
                  curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
                  df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                                'Ask_Low', 'Ask_Close']]
                  open_price = float(curr_ask_open)
                  stop_loss = round(pullback - pullback_cushion, 5)
                  # stop_loss = round(pullback - pullback_cushion, 3)

                  if stop_loss < open_price:
                      curr_pips_to_risk = open_price - stop_loss

                      if curr_pips_to_risk <= max_pips_to_risk:
                          stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 5)
                          # stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 3)

                          trades.append({'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                            'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                            'n_units': n_units, 'start_date': curr_date, 'end_date': None})

                          n_buys += 1

                          pips_risked.append(curr_pips_to_risk)

                          process_trade = True

        elif beep_boop2 == 2 and beep_boop1 == 2 and curr_mh < ema200 and enough_volatility and len(trades) < max_open_trades and curr_bh >= max(previous_bid_highs) and curr_bar_length <= bar_length:
            all_sells = True

            for trade in trades:
                if trade['trade_type'] != 'sell':
                    all_sells = False
                    break

            if all_sells:
              # pullback = None
              # u = i - 4

              # while u >= 0:
              #     if df.loc[df.index[u], 'fractal'] == 2:
              #         curr_pullback = float(df.loc[df.index[u], 'Ask_High'])
              #         curr_fractal_distance = curr_pullback - curr_bo

              #         if curr_fractal_distance >= fractal_distance:
              #             pullback = curr_pullback
              #             break

              #     u -= 1

              if pullback is not None:
                  curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
                  df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                                'Ask_Low', 'Ask_Close']]
                  open_price = float(curr_bid_open)
                  stop_loss = round(pullback + pullback_cushion, 5)
                  # stop_loss = round(pullback + pullback_cushion, 3)

                  if stop_loss > open_price:
                      curr_pips_to_risk = stop_loss - open_price

                      if curr_pips_to_risk <= max_pips_to_risk:
                          stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 5)
                          # stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 3)

                          trades.append({'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                                  'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                  'n_units': n_units, 'start_date': curr_date, 'end_date': None})

                          n_sells += 1

                          pips_risked.append(curr_pips_to_risk)

                          process_trade = True

        if process_trade:
          iterate_thru_small_data(trades[-1])

        i += 1

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
risk_reward_ratio_vals = [1.7, 1.8, 1.9, 2]
# risk_reward_ratio_vals = [2]
pullback_cushion_vals = [0, 5, 10]
# pullback_cushion_vals = [10]
atr_percentages = [0.20, 0.25, 0.30]
# atr_percentages = [0.25]
last_x_bars_vals = [1, 2, 3]
# last_x_bars_vals = [2]
# fractal_distances = [0, 5, 10]
fractal_distances = [10]
bar_lengths = [5, 10]
# bar_lengths = [5]
ema_vals = ['ema50']
max_open_trades_vals = [1, 2, 3, 5, 10]
n_possibilities = len(risk_reward_ratio_vals) * len(pullback_cushion_vals) * len(atr_percentages) * len(last_x_bars_vals) * len(fractal_distances) * len(bar_lengths) * len(ema_vals) * len(max_open_trades_vals)
all_combos = []

for risk_reward_ratio in risk_reward_ratio_vals:
  for pullback_cushion in pullback_cushion_vals:
    for atr_percentage in atr_percentages:
      for last_x_bars in last_x_bars_vals:
        for fractal_distance in fractal_distances:
          for bar_length in bar_lengths:
            for ema_val in ema_vals:
              for max_open_trades_val in max_open_trades_vals:
                all_combos.append((risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length, ema_val, max_open_trades_val))

# percentage_to_try = 0.75
percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)
print('Num runs: '+ str(len(combos_to_try)) + '\n')

best_risk_reward = None
best_pullback_cushion = None
best_atr_percentage = None
best_last_x_bars_val = None
best_fractal_distance = None
best_bar_length = None
best_ema_val = None
best_max_open_trades_val = None
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length, ema_val, max_open_trades_val in combos_to_try:
  reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak = run_simulation(risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length, ema_val, max_open_trades_val)
  runs_finished += 1

  print(reward)
  print('Num buys: ' + str(n_sells))
  print('Num sells: ' + str(n_buys))
  print('Num trades: ' + str(n_buys + n_sells))
  print('Num wins: ' + str(n_wins))
  print('Num losses: ' + str(n_losses))
  print('Win streak: ' + str(win_streak))
  print('Loss streak: ' + str(loss_streak))
  print('Remaining runs: ' + str(n_runs - runs_finished))

  if reward > best_reward:
    best_reward = reward
    best_risk_reward = risk_reward_ratio
    best_pullback_cushion = pullback_cushion
    best_atr_percentage = atr_percentage
    best_last_x_bars_val = last_x_bars
    best_fractal_distance = fractal_distance
    best_bar_length = bar_length
    best_ema_val = ema_val
    best_max_open_trades_val = max_open_trades_val

  print('Best reward so far: ' + str(best_reward))
  print()
# Out:
# Num runs: 1080
#
# -988.300000000014
# Num buys: 481
# Num sells: 2
# Num trades: 483
# Num wins: 153
# Num losses: 329
# Win streak: 9
# Loss streak: 15
# Remaining runs: 1079
# Best reward so far: -988.300000000014
#
# -21272.49999999999
# Num buys: 259
# Num sells: 679
# Num trades: 938
# Num wins: 246
# Num losses: 692
# Win streak: 26
# Loss streak: 38
# Remaining runs: 1078
# Best reward so far: -988.300000000014
#
# -83.00000000001074
# Num buys: 10
# Num sells: 0
# Num trades: 10
# Num wins: 1
# Num losses: 9
# Win streak: 1
# Loss streak: 8
# Remaining runs: 1077
# Best reward so far: -83.00000000001074
#
# 213.9999999999904
# Num buys: 59
# Num sells: 4
# Num trades: 63
# Num wins: 23
# Num losses: 40
# Win streak: 8
# Loss streak: 12
# Remaining runs: 1076
# Best reward so far: 213.9999999999904
#
# -2323.4000000000005
# Num buys: 7
# Num sells: 637
# Num trades: 644
# Num wins: 181
# Num losses: 463
# Win streak: 6
# Loss streak: 23
# Remaining runs: 1075
# Best reward so far: 213.9999999999904
#
# -1086.0000000000916
# Num buys: 28
# Num sells: 23
# Num trades: 51
# Num wins: 15
# Num losses: 36
# Win streak: 4
# Loss streak: 7
# Remaining runs: 1074
# Best reward so far: 213.9999999999904
#
# 23.399999999978533
# Num buys: 73
# Num sells: 3
# Num trades: 76
# Num wins: 24
# Num losses: 51
# Win streak: 8
# Loss streak: 22
# Remaining runs: 1073
# Best reward so far: 213.9999999999904
#
# -3805.900000000008
# Num buys: 1774
# Num sells: 319
# Num trades: 2093
# Num wins: 736
# Num losses: 1355
# Win streak: 16
# Loss streak: 26
# Remaining runs: 1072
# Best reward so far: 213.9999999999904
#
# -9755.549999999912
# Num buys: 94
# Num sells: 3434
# Num trades: 3528
# Num wins: 1238
# Num losses: 2287
# Win streak: 20
# Loss streak: 35
# Remaining runs: 1071
# Best reward so far: 213.9999999999904
#
# -4858.700000000019
# Num buys: 1774
# Num sells: 319
# Num trades: 2093
# Num wins: 736
# Num losses: 1355
# Win streak: 16
# Loss streak: 26
# Remaining runs: 1070
# Best reward so far: 213.9999999999904
#
# -159.4999999999902
# Num buys: 4
# Num sells: 0
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 1069
# Best reward so far: 213.9999999999904
#
# -549.2500000000222
# Num buys: 16
# Num sells: 17
# Num trades: 33
# Num wins: 10
# Num losses: 23
# Win streak: 4
# Loss streak: 7
# Remaining runs: 1068
# Best reward so far: 213.9999999999904
#
# -609.0000000000493
# Num buys: 10
# Num sells: 11
# Num trades: 21
# Num wins: 5
# Num losses: 16
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1067
# Best reward so far: 213.9999999999904
#
# -2005.6000000000115
# Num buys: 10
# Num sells: 398
# Num trades: 408
# Num wins: 105
# Num losses: 303
# Win streak: 8
# Loss streak: 18
# Remaining runs: 1066
# Best reward so far: 213.9999999999904
#
# -624.3999999999974
# Num buys: 3
# Num sells: 782
# Num trades: 785
# Num wins: 292
# Num losses: 492
# Win streak: 9
# Loss streak: 17
# Remaining runs: 1065
# Best reward so far: 213.9999999999904
#
# -22042.24999999991
# Num buys: 259
# Num sells: 7386
# Num trades: 7645
# Num wins: 2642
# Num losses: 4999
# Win streak: 38
# Loss streak: 52
# Remaining runs: 1064
# Best reward so far: 213.9999999999904
#
# -11272.00000000004
# Num buys: 136
# Num sells: 379
# Num trades: 515
# Num wins: 138
# Num losses: 377
# Win streak: 18
# Loss streak: 29
# Remaining runs: 1063
# Best reward so far: 213.9999999999904
#
# -983.1666666666625
# Num buys: 3
# Num sells: 184
# Num trades: 187
# Num wins: 55
# Num losses: 132
# Win streak: 6
# Loss streak: 17
# Remaining runs: 1062
# Best reward so far: 213.9999999999904
#
# -159.4999999999902
# Num buys: 4
# Num sells: 0
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 1061
# Best reward so far: 213.9999999999904
#
# -3191.50000000004
# Num buys: 250
# Num sells: 65
# Num trades: 315
# Num wins: 78
# Num losses: 237
# Win streak: 16
# Loss streak: 40
# Remaining runs: 1060
# Best reward so far: 213.9999999999904
#
# -211.50000000000887
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1059
# Best reward so far: 213.9999999999904
#
# -246.2500000000119
# Num buys: 18
# Num sells: 2
# Num trades: 20
# Num wins: 4
# Num losses: 16
# Win streak: 3
# Loss streak: 7
# Remaining runs: 1058
# Best reward so far: 213.9999999999904
#
# -4731.800000000016
# Num buys: 1774
# Num sells: 319
# Num trades: 2093
# Num wins: 736
# Num losses: 1355
# Win streak: 16
# Loss streak: 26
# Remaining runs: 1057
# Best reward so far: 213.9999999999904
#
# -216.30000000001715
# Num buys: 113
# Num sells: 2
# Num trades: 115
# Num wins: 33
# Num losses: 82
# Win streak: 5
# Loss streak: 15
# Remaining runs: 1056
# Best reward so far: 213.9999999999904
#
# -2106.949999999997
# Num buys: 1028
# Num sells: 536
# Num trades: 1564
# Num wins: 589
# Num losses: 973
# Win streak: 12
# Loss streak: 16
# Remaining runs: 1055
# Best reward so far: 213.9999999999904
#
# -2909.6666666666515
# Num buys: 781
# Num sells: 414
# Num trades: 1195
# Num wins: 442
# Num losses: 751
# Win streak: 11
# Loss streak: 16
# Remaining runs: 1054
# Best reward so far: 213.9999999999904
#
# 131.74999999998744
# Num buys: 14
# Num sells: 0
# Num trades: 14
# Num wins: 4
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Remaining runs: 1053
# Best reward so far: 213.9999999999904
#
# -4795.833333333415
# Num buys: 905
# Num sells: 319
# Num trades: 1224
# Num wins: 420
# Num losses: 804
# Win streak: 12
# Loss streak: 26
# Remaining runs: 1052
# Best reward so far: 213.9999999999904
#
# -9761.149999999925
# Num buys: 94
# Num sells: 3434
# Num trades: 3528
# Num wins: 1238
# Num losses: 2287
# Win streak: 20
# Loss streak: 35
# Remaining runs: 1051
# Best reward so far: 213.9999999999904
#
# 173.50000000001808
# Num buys: 50
# Num sells: 11
# Num trades: 61
# Num wins: 20
# Num losses: 41
# Win streak: 4
# Loss streak: 6
# Remaining runs: 1050
# Best reward so far: 213.9999999999904
#
# -1035.2000000000185
# Num buys: 481
# Num sells: 2
# Num trades: 483
# Num wins: 153
# Num losses: 329
# Win streak: 9
# Loss streak: 15
# Remaining runs: 1049
# Best reward so far: 213.9999999999904
#
# -224.2500000000283
# Num buys: 23
# Num sells: 3
# Num trades: 26
# Num wins: 6
# Num losses: 20
# Win streak: 2
# Loss streak: 8
# Remaining runs: 1048
# Best reward so far: 213.9999999999904
#
# -69.9000000000056
# Num buys: 15
# Num sells: 0
# Num trades: 15
# Num wins: 2
# Num losses: 13
# Win streak: 1
# Loss streak: 11
# Remaining runs: 1047
# Best reward so far: 213.9999999999904
#
# -67.35000000001136
# Num buys: 79
# Num sells: 2
# Num trades: 81
# Num wins: 26
# Num losses: 55
# Win streak: 4
# Loss streak: 11
# Remaining runs: 1046
# Best reward so far: 213.9999999999904
#
# -76.50000000001377
# Num buys: 3
# Num sells: 0
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 1045
# Best reward so far: 213.9999999999904
#
# 284.75000000001313
# Num buys: 11
# Num sells: 4
# Num trades: 15
# Num wins: 7
# Num losses: 8
# Win streak: 6
# Loss streak: 5
# Remaining runs: 1044
# Best reward so far: 284.75000000001313
#
# -28.49999999999797
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1043
# Best reward so far: 284.75000000001313
#
# -17594.999999999993
# Num buys: 1196
# Num sells: 636
# Num trades: 1832
# Num wins: 581
# Num losses: 1250
# Win streak: 15
# Loss streak: 69
# Remaining runs: 1042
# Best reward so far: 284.75000000001313
#
# 141.49999999998664
# Num buys: 14
# Num sells: 0
# Num trades: 14
# Num wins: 4
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Remaining runs: 1041
# Best reward so far: 284.75000000001313
#
# -17489.000000000044
# Num buys: 652
# Num sells: 1397
# Num trades: 2049
# Num wins: 682
# Num losses: 1364
# Win streak: 20
# Loss streak: 72
# Remaining runs: 1040
# Best reward so far: 284.75000000001313
#
# -3090.4999999999973
# Num buys: 396
# Num sells: 414
# Num trades: 810
# Num wins: 305
# Num losses: 504
# Win streak: 11
# Loss streak: 16
# Remaining runs: 1039
# Best reward so far: 284.75000000001313
#
# -2860.2499999999864
# Num buys: 741
# Num sells: 414
# Num trades: 1155
# Num wins: 428
# Num losses: 726
# Win streak: 11
# Loss streak: 16
# Remaining runs: 1038
# Best reward so far: 284.75000000001313
#
# -9126.899999999921
# Num buys: 2595
# Num sells: 636
# Num trades: 3231
# Num wins: 1114
# Num losses: 2115
# Win streak: 20
# Loss streak: 69
# Remaining runs: 1037
# Best reward so far: 284.75000000001313
#
# -8525.999999999938
# Num buys: 1351
# Num sells: 580
# Num trades: 1931
# Num wins: 686
# Num losses: 1243
# Win streak: 20
# Loss streak: 42
# Remaining runs: 1036
# Best reward so far: 284.75000000001313
#
# -1806.7499999999877
# Num buys: 486
# Num sells: 212
# Num trades: 698
# Num wins: 238
# Num losses: 460
# Win streak: 8
# Loss streak: 19
# Remaining runs: 1035
# Best reward so far: 284.75000000001313
#
# -357.8333333333527
# Num buys: 10
# Num sells: 18
# Num trades: 28
# Num wins: 6
# Num losses: 22
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1034
# Best reward so far: 284.75000000001313
#
# -1452.500000000074
# Num buys: 30
# Num sells: 11
# Num trades: 41
# Num wins: 6
# Num losses: 35
# Win streak: 3
# Loss streak: 22
# Remaining runs: 1033
# Best reward so far: 284.75000000001313
#
# -1639.3999999999885
# Num buys: 16
# Num sells: 189
# Num trades: 205
# Num wins: 50
# Num losses: 155
# Win streak: 7
# Loss streak: 23
# Remaining runs: 1032
# Best reward so far: 284.75000000001313
#
# -296.9999999999884
# Num buys: 45
# Num sells: 34
# Num trades: 79
# Num wins: 29
# Num losses: 50
# Win streak: 6
# Loss streak: 11
# Remaining runs: 1031
# Best reward so far: 284.75000000001313
#
# -249.25000000001225
# Num buys: 4
# Num sells: 6
# Num trades: 10
# Num wins: 2
# Num losses: 8
# Win streak: 1
# Loss streak: 7
# Remaining runs: 1030
# Best reward so far: 284.75000000001313
#
# -15947.24999999984
# Num buys: 136
# Num sells: 5455
# Num trades: 5591
# Num wins: 1943
# Num losses: 3646
# Win streak: 31
# Loss streak: 35
# Remaining runs: 1029
# Best reward so far: 284.75000000001313
#
# -1937.0999999999744
# Num buys: 4
# Num sells: 930
# Num trades: 934
# Num wins: 314
# Num losses: 620
# Win streak: 10
# Loss streak: 24
# Remaining runs: 1028
# Best reward so far: 284.75000000001313
#
# -289.79999999999677
# Num buys: 111
# Num sells: 23
# Num trades: 134
# Num wins: 37
# Num losses: 96
# Win streak: 7
# Loss streak: 11
# Remaining runs: 1027
# Best reward so far: 284.75000000001313
#
# -84.15000000001297
# Num buys: 79
# Num sells: 2
# Num trades: 81
# Num wins: 26
# Num losses: 55
# Win streak: 4
# Loss streak: 11
# Remaining runs: 1026
# Best reward so far: 284.75000000001313
#
# -20.500000000009834
# Num buys: 3
# Num sells: 1
# Num trades: 4
# Num wins: 2
# Num losses: 2
# Win streak: 1
# Loss streak: 1
# Remaining runs: 1025
# Best reward so far: 284.75000000001313
#
# -9067.999999999947
# Num buys: 158
# Num sells: 65
# Num trades: 223
# Num wins: 42
# Num losses: 181
# Win streak: 7
# Loss streak: 40
# Remaining runs: 1024
# Best reward so far: 284.75000000001313
#
# 329.3000000000187
# Num buys: 107
# Num sells: 4
# Num trades: 111
# Num wins: 39
# Num losses: 72
# Win streak: 10
# Loss streak: 12
# Remaining runs: 1023
# Best reward so far: 329.3000000000187
#
# -127.30000000000695
# Num buys: 43
# Num sells: 0
# Num trades: 43
# Num wins: 10
# Num losses: 33
# Win streak: 4
# Loss streak: 8
# Remaining runs: 1022
# Best reward so far: 329.3000000000187
#
# -2284.750000000042
# Num buys: 979
# Num sells: 536
# Num trades: 1515
# Num wins: 573
# Num losses: 941
# Win streak: 12
# Loss streak: 16
# Remaining runs: 1021
# Best reward so far: 329.3000000000187
#
# 257.09999999998917
# Num buys: 59
# Num sells: 4
# Num trades: 63
# Num wins: 23
# Num losses: 40
# Win streak: 8
# Loss streak: 12
# Remaining runs: 1020
# Best reward so far: 329.3000000000187
#
# -22174.500000000244
# Num buys: 429
# Num sells: 253
# Num trades: 682
# Num wins: 199
# Num losses: 483
# Win streak: 28
# Loss streak: 40
# Remaining runs: 1019
# Best reward so far: 329.3000000000187
#
# -3622.6000000000413
# Num buys: 28
# Num sells: 1310
# Num trades: 1338
# Num wins: 484
# Num losses: 854
# Win streak: 13
# Loss streak: 25
# Remaining runs: 1018
# Best reward so far: 329.3000000000187
#
# -1077.3000000000106
# Num buys: 7
# Num sells: 146
# Num trades: 153
# Num wins: 44
# Num losses: 109
# Win streak: 5
# Loss streak: 16
# Remaining runs: 1017
# Best reward so far: 329.3000000000187
#
# -326.2000000000044
# Num buys: 48
# Num sells: 2
# Num trades: 50
# Num wins: 8
# Num losses: 42
# Win streak: 4
# Loss streak: 18
# Remaining runs: 1016
# Best reward so far: 329.3000000000187
#
# -681.7500000000232
# Num buys: 38
# Num sells: 7
# Num trades: 45
# Num wins: 9
# Num losses: 36
# Win streak: 3
# Loss streak: 12
# Remaining runs: 1015
# Best reward so far: 329.3000000000187
#
# 74.29999999998374
# Num buys: 41
# Num sells: 0
# Num trades: 41
# Num wins: 11
# Num losses: 30
# Win streak: 4
# Loss streak: 16
# Remaining runs: 1014
# Best reward so far: 329.3000000000187
#
# -68.24999999999586
# Num buys: 17
# Num sells: 0
# Num trades: 17
# Num wins: 7
# Num losses: 10
# Win streak: 3
# Loss streak: 5
# Remaining runs: 1013
# Best reward so far: 329.3000000000187
#
# -81.50000000001488
# Num buys: 8
# Num sells: 0
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 6
# Remaining runs: 1012
# Best reward so far: 329.3000000000187
#
# -17632.700000000066
# Num buys: 136
# Num sells: 2910
# Num trades: 3046
# Num wins: 994
# Num losses: 2050
# Win streak: 21
# Loss streak: 33
# Remaining runs: 1011
# Best reward so far: 329.3000000000187
#
# -163.10000000000608
# Num buys: 28
# Num sells: 2
# Num trades: 30
# Num wins: 5
# Num losses: 25
# Win streak: 3
# Loss streak: 14
# Remaining runs: 1010
# Best reward so far: 329.3000000000187
#
# -17837.600000000042
# Num buys: 136
# Num sells: 2910
# Num trades: 3046
# Num wins: 994
# Num losses: 2050
# Win streak: 21
# Loss streak: 33
# Remaining runs: 1009
# Best reward so far: 329.3000000000187
#
# -1789.8999999999942
# Num buys: 781
# Num sells: 414
# Num trades: 1195
# Num wins: 442
# Num losses: 751
# Win streak: 11
# Loss streak: 16
# Remaining runs: 1008
# Best reward so far: 329.3000000000187
#
# -458.00000000002603
# Num buys: 10
# Num sells: 16
# Num trades: 26
# Num wins: 6
# Num losses: 20
# Win streak: 2
# Loss streak: 9
# Remaining runs: 1007
# Best reward so far: 329.3000000000187
#
# 10.999999999992497
# Num buys: 9
# Num sells: 3
# Num trades: 12
# Num wins: 5
# Num losses: 7
# Win streak: 2
# Loss streak: 5
# Remaining runs: 1006
# Best reward so far: 329.3000000000187
#
# 197.5000000000436
# Num buys: 16
# Num sells: 11
# Num trades: 27
# Num wins: 9
# Num losses: 18
# Win streak: 3
# Loss streak: 6
# Remaining runs: 1005
# Best reward so far: 329.3000000000187
#
# -28.49999999999797
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 1004
# Best reward so far: 329.3000000000187
#
# -1351.5000000000882
# Num buys: 190
# Num sells: 31
# Num trades: 221
# Num wins: 66
# Num losses: 155
# Win streak: 9
# Loss streak: 42
# Remaining runs: 1003
# Best reward so far: 329.3000000000187
#
# -163.2000000000004
# Num buys: 44
# Num sells: 0
# Num trades: 44
# Num wins: 6
# Num losses: 38
# Win streak: 2
# Loss streak: 18
# Remaining runs: 1002
# Best reward so far: 329.3000000000187
#
# 4.166666666647501
# Num buys: 33
# Num sells: 2
# Num trades: 35
# Num wins: 9
# Num losses: 26
# Win streak: 5
# Loss streak: 9
# Remaining runs: 1001
# Best reward so far: 329.3000000000187
#
# -1096.9999999999704
# Num buys: 281
# Num sells: 306
# Num trades: 587
# Num wins: 215
# Num losses: 372
# Win streak: 10
# Loss streak: 16
# Remaining runs: 1000
# Best reward so far: 329.3000000000187
#
# -50.74999999999225
# Num buys: 17
# Num sells: 0
# Num trades: 17
# Num wins: 7
# Num losses: 10
# Win streak: 3
# Loss streak: 5
# Remaining runs: 999
# Best reward so far: 329.3000000000187
#
# -6284.600000000022
# Num buys: 95
# Num sells: 1579
# Num trades: 1674
# Num wins: 618
# Num losses: 1054
# Win streak: 13
# Loss streak: 24
# Remaining runs: 998
# Best reward so far: 329.3000000000187
#
# -4210.099999999959
# Num buys: 1350
# Num sells: 249
# Num trades: 1599
# Num wins: 557
# Num losses: 1041
# Win streak: 10
# Loss streak: 24
# Remaining runs: 997
# Best reward so far: 329.3000000000187
#
# -549.6666666666782
# Num buys: 146
# Num sells: 34
# Num trades: 180
# Num wins: 58
# Num losses: 122
# Win streak: 6
# Loss streak: 15
# Remaining runs: 996
# Best reward so far: 329.3000000000187
#
# -30990.500000000087
# Num buys: 680
# Num sells: 636
# Num trades: 1316
# Num wins: 394
# Num losses: 921
# Win streak: 15
# Loss streak: 69
# Remaining runs: 995
# Best reward so far: 329.3000000000187
#
# -2004.8500000000233
# Num buys: 889
# Num sells: 65
# Num trades: 954
# Num wins: 305
# Num losses: 648
# Win streak: 27
# Loss streak: 40
# Remaining runs: 994
# Best reward so far: 329.3000000000187
#
# -874.950000000001
# Num buys: 281
# Num sells: 119
# Num trades: 400
# Num wins: 121
# Num losses: 279
# Win streak: 7
# Loss streak: 17
# Remaining runs: 993
# Best reward so far: 329.3000000000187
#
# 115.00000000002001
# Num buys: 50
# Num sells: 11
# Num trades: 61
# Num wins: 20
# Num losses: 41
# Win streak: 4
# Loss streak: 6
# Remaining runs: 992
# Best reward so far: 329.3000000000187
#
# -18105.499999999993
# Num buys: 652
# Num sells: 1397
# Num trades: 2049
# Num wins: 682
# Num losses: 1364
# Win streak: 20
# Loss streak: 72
# Remaining runs: 991
# Best reward so far: 329.3000000000187
#
# -1120.3333333333671
# Num buys: 35
# Num sells: 49
# Num trades: 84
# Num wins: 20
# Num losses: 64
# Win streak: 7
# Loss streak: 16
# Remaining runs: 990
# Best reward so far: 329.3000000000187
#
# -184.25000000000165
# Num buys: 107
# Num sells: 4
# Num trades: 111
# Num wins: 35
# Num losses: 76
# Win streak: 8
# Loss streak: 12
# Remaining runs: 989
# Best reward so far: 329.3000000000187
#
# 765.3333333333303
# Num buys: 59
# Num sells: 4
# Num trades: 63
# Num wins: 24
# Num losses: 39
# Win streak: 10
# Loss streak: 8
# Remaining runs: 988
# Best reward so far: 765.3333333333303
#
# -2277.1499999999915
# Num buys: 7
# Num sells: 637
# Num trades: 644
# Num wins: 181
# Num losses: 463
# Win streak: 6
# Loss streak: 23
# Remaining runs: 987
# Best reward so far: 765.3333333333303
#
# -1768.000000000184
# Num buys: 51
# Num sells: 41
# Num trades: 92
# Num wins: 31
# Num losses: 61
# Win streak: 5
# Loss streak: 13
# Remaining runs: 986
# Best reward so far: 765.3333333333303
#
# -216.2500000000065
# Num buys: 98
# Num sells: 34
# Num trades: 132
# Num wins: 47
# Num losses: 85
# Win streak: 6
# Loss streak: 11
# Remaining runs: 985
# Best reward so far: 765.3333333333303
#
# -1866.1999999999794
# Num buys: 4
# Num sells: 930
# Num trades: 934
# Num wins: 314
# Num losses: 620
# Win streak: 10
# Loss streak: 24
# Remaining runs: 984
# Best reward so far: 765.3333333333303
#
# -309.9999999999981
# Num buys: 31
# Num sells: 11
# Num trades: 42
# Num wins: 10
# Num losses: 32
# Win streak: 2
# Loss streak: 6
# Remaining runs: 983
# Best reward so far: 765.3333333333303
#
# -18156.500000000062
# Num buys: 652
# Num sells: 1397
# Num trades: 2049
# Num wins: 682
# Num losses: 1364
# Win streak: 20
# Loss streak: 72
# Remaining runs: 982
# Best reward so far: 765.3333333333303
#
# -2001.7500000000664
# Num buys: 28
# Num sells: 89
# Num trades: 117
# Num wins: 37
# Num losses: 80
# Win streak: 6
# Loss streak: 9
# Remaining runs: 981
# Best reward so far: 765.3333333333303
#
# -588.4999999999917
# Num buys: 2
# Num sells: 10
# Num trades: 12
# Num wins: 2
# Num losses: 10
# Win streak: 2
# Loss streak: 10
# Remaining runs: 980
# Best reward so far: 765.3333333333303
#
# -54.16666666666677
# Num buys: 104
# Num sells: 11
# Num trades: 115
# Num wins: 37
# Num losses: 78
# Win streak: 4
# Loss streak: 12
# Remaining runs: 979
# Best reward so far: 765.3333333333303
#
# -558.5000000000111
# Num buys: 16
# Num sells: 17
# Num trades: 33
# Num wins: 10
# Num losses: 23
# Win streak: 4
# Loss streak: 7
# Remaining runs: 978
# Best reward so far: 765.3333333333303
#
# -7799.0999999999885
# Num buys: 50
# Num sells: 1622
# Num trades: 1672
# Num wins: 578
# Num losses: 1094
# Win streak: 13
# Loss streak: 20
# Remaining runs: 977
# Best reward so far: 765.3333333333303
#
# -29128.833333333343
# Num buys: 429
# Num sells: 1632
# Num trades: 2061
# Num wins: 556
# Num losses: 1505
# Win streak: 28
# Loss streak: 53
# Remaining runs: 976
# Best reward so far: 765.3333333333303
#
# -1245.8000000000043
# Num buys: 281
# Num sells: 119
# Num trades: 400
# Num wins: 121
# Num losses: 279
# Win streak: 7
# Loss streak: 17
# Remaining runs: 975
# Best reward so far: 765.3333333333303
#
# -301.6500000000053
# Num buys: 77
# Num sells: 2
# Num trades: 79
# Num wins: 13
# Num losses: 66
# Win streak: 5
# Loss streak: 20
# Remaining runs: 974
# Best reward so far: 765.3333333333303
#
# -1201.9999999999811
# Num buys: 281
# Num sells: 306
# Num trades: 587
# Num wins: 215
# Num losses: 372
# Win streak: 10
# Loss streak: 16
# Remaining runs: 973
# Best reward so far: 765.3333333333303
#
# -28.000000000012015
# Num buys: 16
# Num sells: 0
# Num trades: 16
# Num wins: 3
# Num losses: 13
# Win streak: 3
# Loss streak: 12
# Remaining runs: 972
# Best reward so far: 765.3333333333303
#
# -83.49999999999191
# Num buys: 3
# Num sells: 0
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 971
# Best reward so far: 765.3333333333303
#
# -978.0000000000508
# Num buys: 52
# Num sells: 12
# Num trades: 64
# Num wins: 15
# Num losses: 49
# Win streak: 4
# Loss streak: 14
# Remaining runs: 970
# Best reward so far: 765.3333333333303
#
# -3915.75000000008
# Num buys: 51
# Num sells: 162
# Num trades: 213
# Num wins: 67
# Num losses: 146
# Win streak: 6
# Loss streak: 16
# Remaining runs: 969
# Best reward so far: 765.3333333333303
#
# -166.25000000000452
# Num buys: 98
# Num sells: 34
# Num trades: 132
# Num wins: 47
# Num losses: 85
# Win streak: 6
# Loss streak: 11
# Remaining runs: 968
# Best reward so far: 765.3333333333303
#
# -8323.166666666584
# Num buys: 1351
# Num sells: 580
# Num trades: 1931
# Num wins: 686
# Num losses: 1243
# Win streak: 20
# Loss streak: 42
# Remaining runs: 967
# Best reward so far: 765.3333333333303
#
# -1667.1999999999866
# Num buys: 16
# Num sells: 189
# Num trades: 205
# Num wins: 50
# Num losses: 155
# Win streak: 7
# Loss streak: 23
# Remaining runs: 966
# Best reward so far: 765.3333333333303
#
# -1799.0000000001494
# Num buys: 51
# Num sells: 41
# Num trades: 92
# Num wins: 31
# Num losses: 61
# Win streak: 5
# Loss streak: 13
# Remaining runs: 965
# Best reward so far: 765.3333333333303
#
# -273.0999999999935
# Num buys: 248
# Num sells: 11
# Num trades: 259
# Num wins: 87
# Num losses: 172
# Win streak: 8
# Loss streak: 12
# Remaining runs: 964
# Best reward so far: 765.3333333333303
#
# -20442.499999999975
# Num buys: 259
# Num sells: 679
# Num trades: 938
# Num wins: 246
# Num losses: 692
# Win streak: 26
# Loss streak: 38
# Remaining runs: 963
# Best reward so far: 765.3333333333303
#
# -214.99999999999852
# Num buys: 1
# Num sells: 4
# Num trades: 5
# Num wins: 1
# Num losses: 4
# Win streak: 1
# Loss streak: 4
# Remaining runs: 962
# Best reward so far: 765.3333333333303
#
# -311.79999999999666
# Num buys: 111
# Num sells: 23
# Num trades: 134
# Num wins: 37
# Num losses: 96
# Win streak: 7
# Loss streak: 11
# Remaining runs: 961
# Best reward so far: 765.3333333333303
#
# -32708.99999999995
# Num buys: 652
# Num sells: 562
# Num trades: 1214
# Num wins: 347
# Num losses: 866
# Win streak: 17
# Loss streak: 72
# Remaining runs: 960
# Best reward so far: 765.3333333333303
#
# -497.33333333333786
# Num buys: 46
# Num sells: 2
# Num trades: 48
# Num wins: 8
# Num losses: 40
# Win streak: 4
# Loss streak: 18
# Remaining runs: 959
# Best reward so far: 765.3333333333303
#
# -951.3333333333326
# Num buys: 3
# Num sells: 184
# Num trades: 187
# Num wins: 55
# Num losses: 132
# Win streak: 6
# Loss streak: 17
# Remaining runs: 958
# Best reward so far: 765.3333333333303
#
# -5685.799999999965
# Num buys: 50
# Num sells: 2344
# Num trades: 2394
# Num wins: 858
# Num losses: 1536
# Win streak: 19
# Loss streak: 20
# Remaining runs: 957
# Best reward so far: 765.3333333333303
#
# -2226.3000000000648
# Num buys: 460
# Num sells: 65
# Num trades: 525
# Num wins: 149
# Num losses: 376
# Win streak: 26
# Loss streak: 40
# Remaining runs: 956
# Best reward so far: 765.3333333333303
#
# -640.0000000000455
# Num buys: 10
# Num sells: 11
# Num trades: 21
# Num wins: 5
# Num losses: 16
# Win streak: 2
# Loss streak: 9
# Remaining runs: 955
# Best reward so far: 765.3333333333303
#
# -15514.099999999842
# Num buys: 136
# Num sells: 5455
# Num trades: 5591
# Num wins: 1943
# Num losses: 3646
# Win streak: 31
# Loss streak: 35
# Remaining runs: 954
# Best reward so far: 765.3333333333303
#
# -918.3333333333306
# Num buys: 3
# Num sells: 184
# Num trades: 187
# Num wins: 55
# Num losses: 132
# Win streak: 6
# Loss streak: 17
# Remaining runs: 953
# Best reward so far: 765.3333333333303
#
# -589.1000000000231
# Num buys: 122
# Num sells: 12
# Num trades: 134
# Num wins: 34
# Num losses: 100
# Win streak: 4
# Loss streak: 14
# Remaining runs: 952
# Best reward so far: 765.3333333333303
#
# 4.349999999995674
# Num buys: 163
# Num sells: 10
# Num trades: 173
# Num wins: 54
# Num losses: 118
# Win streak: 14
# Loss streak: 29
# Remaining runs: 951
# Best reward so far: 765.3333333333303
#
# -57.500000000005876
# Num buys: 4
# Num sells: 0
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 950
# Best reward so far: 765.3333333333303
#
# 15.499999999994657
# Num buys: 9
# Num sells: 3
# Num trades: 12
# Num wins: 5
# Num losses: 7
# Win streak: 2
# Loss streak: 5
# Remaining runs: 949
# Best reward so far: 765.3333333333303
#
# -2328.6999999999953
# Num buys: 486
# Num sells: 212
# Num trades: 698
# Num wins: 238
# Num losses: 460
# Win streak: 8
# Loss streak: 19
# Remaining runs: 948
# Best reward so far: 765.3333333333303
#
# -3102.8333333333035
# Num buys: 486
# Num sells: 212
# Num trades: 698
# Num wins: 238
# Num losses: 460
# Win streak: 8
# Loss streak: 19
# Remaining runs: 947
# Best reward so far: 765.3333333333303
#
# -125.166666666673
# Num buys: 20
# Num sells: 0
# Num trades: 20
# Num wins: 3
# Num losses: 17
# Win streak: 2
# Loss streak: 12
# Remaining runs: 946
# Best reward so far: 765.3333333333303
#
# -3621.500000000103
# Num buys: 136
# Num sells: 101
# Num trades: 237
# Num wins: 77
# Num losses: 160
# Win streak: 18
# Loss streak: 22
# Remaining runs: 945
# Best reward so far: 765.3333333333303
#
# 46.849999999978536
# Num buys: 203
# Num sells: 0
# Num trades: 203
# Num wins: 70
# Num losses: 132
# Win streak: 22
# Loss streak: 51
# Remaining runs: 944
# Best reward so far: 765.3333333333303
#
# -244.7500000000196
# Num buys: 175
# Num sells: 0
# Num trades: 175
# Num wins: 48
# Num losses: 126
# Win streak: 16
# Loss streak: 51
# Remaining runs: 943
# Best reward so far: 765.3333333333303
#
# -17051.000000000015
# Num buys: 136
# Num sells: 2910
# Num trades: 3046
# Num wins: 994
# Num losses: 2050
# Win streak: 21
# Loss streak: 33
# Remaining runs: 942
# Best reward so far: 765.3333333333303
#
# -3759.000000000076
# Num buys: 51
# Num sells: 162
# Num trades: 213
# Num wins: 67
# Num losses: 146
# Win streak: 6
# Loss streak: 16
# Remaining runs: 941
# Best reward so far: 765.3333333333303
#
# -5418.500000000075
# Num buys: 221
# Num sells: 65
# Num trades: 286
# Num wins: 62
# Num losses: 224
# Win streak: 9
# Loss streak: 40
# Remaining runs: 940
# Best reward so far: 765.3333333333303
#
# -9340.99999999988
# Num buys: 2595
# Num sells: 636
# Num trades: 3231
# Num wins: 1114
# Num losses: 2115
# Win streak: 20
# Loss streak: 69
# Remaining runs: 939
# Best reward so far: 765.3333333333303
#
# -632.8000000000368
# Num buys: 188
# Num sells: 21
# Num trades: 209
# Num wins: 58
# Num losses: 151
# Win streak: 12
# Loss streak: 15
# Remaining runs: 938
# Best reward so far: 765.3333333333303
#
# -12684.399999999941
# Num buys: 652
# Num sells: 3319
# Num trades: 3971
# Num wins: 1371
# Num losses: 2594
# Win streak: 29
# Loss streak: 72
# Remaining runs: 937
# Best reward so far: 765.3333333333303
#
# -30927.000000000033
# Num buys: 652
# Num sells: 562
# Num trades: 1214
# Num wins: 347
# Num losses: 866
# Win streak: 17
# Loss streak: 72
# Remaining runs: 936
# Best reward so far: 765.3333333333303
#
# -2813.549999999952
# Num buys: 1351
# Num sells: 34
# Num trades: 1385
# Num wins: 479
# Num losses: 906
# Win streak: 21
# Loss streak: 28
# Remaining runs: 935
# Best reward so far: 765.3333333333303
#
# 828.2500000000143
# Num buys: 28
# Num sells: 10
# Num trades: 38
# Num wins: 15
# Num losses: 23
# Win streak: 13
# Loss streak: 14
# Remaining runs: 934
# Best reward so far: 828.2500000000143
#
# -2181.5000000000027
# Num buys: 1028
# Num sells: 536
# Num trades: 1564
# Num wins: 589
# Num losses: 973
# Win streak: 12
# Loss streak: 16
# Remaining runs: 933
# Best reward so far: 828.2500000000143
#
# -1607.750000000082
# Num buys: 89
# Num sells: 21
# Num trades: 110
# Num wins: 26
# Num losses: 84
# Win streak: 4
# Loss streak: 15
# Remaining runs: 932
# Best reward so far: 828.2500000000143
#
# -6176.199999999944
# Num buys: 1351
# Num sells: 580
# Num trades: 1931
# Num wins: 686
# Num losses: 1243
# Win streak: 20
# Loss streak: 42
# Remaining runs: 931
# Best reward so far: 828.2500000000143
#
# -57.9999999999914
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Remaining runs: 930
# Best reward so far: 828.2500000000143
#
# -41.250000000011795
# Num buys: 105
# Num sells: 0
# Num trades: 105
# Num wins: 33
# Num losses: 72
# Win streak: 10
# Loss streak: 23
# Remaining runs: 929
# Best reward so far: 828.2500000000143
#
# -1800.0000000001376
# Num buys: 174
# Num sells: 31
# Num trades: 205
# Num wins: 59
# Num losses: 146
# Win streak: 9
# Loss streak: 42
# Remaining runs: 928
# Best reward so far: 828.2500000000143
#
# -2109.549999999998
# Num buys: 7
# Num sells: 637
# Num trades: 644
# Num wins: 181
# Num losses: 463
# Win streak: 6
# Loss streak: 23
# Remaining runs: 927
# Best reward so far: 828.2500000000143
#
# -620.5000000000687
# Num buys: 68
# Num sells: 11
# Num trades: 79
# Num wins: 19
# Num losses: 60
# Win streak: 4
# Loss streak: 22
# Remaining runs: 926
# Best reward so far: 828.2500000000143
#
# -7730.199999999983
# Num buys: 50
# Num sells: 1622
# Num trades: 1672
# Num wins: 578
# Num losses: 1094
# Win streak: 13
# Loss streak: 20
# Remaining runs: 925
# Best reward so far: 828.2500000000143
#
# -5636.500000000102
# Num buys: 95
# Num sells: 188
# Num trades: 283
# Num wins: 85
# Num losses: 198
# Win streak: 6
# Loss streak: 16
# Remaining runs: 924
# Best reward so far: 828.2500000000143
#
# -1596.7500000000452
# Num buys: 35
# Num sells: 43
# Num trades: 78
# Num wins: 20
# Num losses: 58
# Win streak: 7
# Loss streak: 16
# Remaining runs: 923
# Best reward so far: 828.2500000000143
#
# -3435.0000000000514
# Num buys: 50
# Num sells: 160
# Num trades: 210
# Num wins: 61
# Num losses: 149
# Win streak: 10
# Loss streak: 11
# Remaining runs: 922
# Best reward so far: 828.2500000000143
#
# -150.0000000000099
# Num buys: 84
# Num sells: 0
# Num trades: 84
# Num wins: 20
# Num losses: 64
# Win streak: 4
# Loss streak: 18
# Remaining runs: 921
# Best reward so far: 828.2500000000143
#
# -9306.599999999966
# Num buys: 3469
# Num sells: 636
# Num trades: 4105
# Num wins: 1427
# Num losses: 2674
# Win streak: 20
# Loss streak: 69
# Remaining runs: 920
# Best reward so far: 828.2500000000143
#
# -3384.166666666642
# Num buys: 486
# Num sells: 212
# Num trades: 698
# Num wins: 238
# Num losses: 460
# Win streak: 8
# Loss streak: 19
# Remaining runs: 919
# Best reward so far: 828.2500000000143
#
# -1464.5000000000136
# Num buys: 662
# Num sells: 11
# Num trades: 673
# Num wins: 198
# Num losses: 475
# Win streak: 7
# Loss streak: 22
# Remaining runs: 918
# Best reward so far: 828.2500000000143
#
# -940.5000000001003
# Num buys: 28
# Num sells: 23
# Num trades: 51
# Num wins: 15
# Num losses: 36
# Win streak: 4
# Loss streak: 7
# Remaining runs: 917
# Best reward so far: 828.2500000000143
#
# -128.00000000000588
# Num buys: 1
# Num sells: 4
# Num trades: 5
# Num wins: 1
# Num losses: 4
# Win streak: 1
# Loss streak: 4
# Remaining runs: 916
# Best reward so far: 828.2500000000143
#
# -125.66666666667001
# Num buys: 20
# Num sells: 0
# Num trades: 20
# Num wins: 3
# Num losses: 17
# Win streak: 2
# Loss streak: 12
# Remaining runs: 915
# Best reward so far: 828.2500000000143
#
# -424.50000000001836
# Num buys: 4
# Num sells: 5
# Num trades: 9
# Num wins: 2
# Num losses: 7
# Win streak: 1
# Loss streak: 6
# Remaining runs: 914
# Best reward so far: 828.2500000000143
#
# -410.833333333355
# Num buys: 45
# Num sells: 0
# Num trades: 45
# Num wins: 9
# Num losses: 36
# Win streak: 3
# Loss streak: 19
# Remaining runs: 913
# Best reward so far: 828.2500000000143
#
# -55.500000000005876
# Num buys: 4
# Num sells: 0
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 912
# Best reward so far: 828.2500000000143
#
# -1075.4999999999984
# Num buys: 32
# Num sells: 23
# Num trades: 55
# Num wins: 17
# Num losses: 37
# Win streak: 7
# Loss streak: 11
# Remaining runs: 911
# Best reward so far: 828.2500000000143
#
# -118.2000000000028
# Num buys: 43
# Num sells: 0
# Num trades: 43
# Num wins: 10
# Num losses: 33
# Win streak: 4
# Loss streak: 8
# Remaining runs: 910
# Best reward so far: 828.2500000000143
#
# -4746.00000000019
# Num buys: 95
# Num sells: 56
# Num trades: 151
# Num wins: 45
# Num losses: 106
# Win streak: 5
# Loss streak: 14
# Remaining runs: 909
# Best reward so far: 828.2500000000143
#
# -3125.2500000000528
# Num buys: 1168
# Num sells: 31
# Num trades: 1199
# Num wins: 372
# Num losses: 826
# Win streak: 13
# Loss streak: 42
# Remaining runs: 908
# Best reward so far: 828.2500000000143
#
# -229.80000000001553
# Num buys: 113
# Num sells: 2
# Num trades: 115
# Num wins: 33
# Num losses: 82
# Win streak: 5
# Loss streak: 15
# Remaining runs: 907
# Best reward so far: 828.2500000000143
#
# -1679.2500000001285
# Num buys: 174
# Num sells: 31
# Num trades: 205
# Num wins: 59
# Num losses: 146
# Win streak: 9
# Loss streak: 42
# Remaining runs: 906
# Best reward so far: 828.2500000000143
#
# -2958.333333333354
# Num buys: 711
# Num sells: 249
# Num trades: 960
# Num wins: 338
# Num losses: 622
# Win streak: 10
# Loss streak: 24
# Remaining runs: 905
# Best reward so far: 828.2500000000143
#
# -2448.4999999999754
# Num buys: 486
# Num sells: 212
# Num trades: 698
# Num wins: 238
# Num losses: 460
# Win streak: 8
# Loss streak: 19
# Remaining runs: 904
# Best reward so far: 828.2500000000143
#
# -9651.750000000098
# Num buys: 171
# Num sells: 318
# Num trades: 489
# Num wins: 136
# Num losses: 353
# Win streak: 12
# Loss streak: 18
# Remaining runs: 903
# Best reward so far: 828.2500000000143
#
# -359.49999999999517
# Num buys: 45
# Num sells: 34
# Num trades: 79
# Num wins: 29
# Num losses: 50
# Win streak: 6
# Loss streak: 11
# Remaining runs: 902
# Best reward so far: 828.2500000000143
#
# -97.20000000000235
# Num buys: 40
# Num sells: 0
# Num trades: 40
# Num wins: 8
# Num losses: 32
# Win streak: 3
# Loss streak: 12
# Remaining runs: 901
# Best reward so far: 828.2500000000143
#
# -24.499999999994515
# Num buys: 2
# Num sells: 10
# Num trades: 12
# Num wins: 3
# Num losses: 9
# Win streak: 3
# Loss streak: 9
# Remaining runs: 900
# Best reward so far: 828.2500000000143
#
# -39.83333333333718
# Num buys: 104
# Num sells: 11
# Num trades: 115
# Num wins: 37
# Num losses: 78
# Win streak: 4
# Loss streak: 12
# Remaining runs: 899
# Best reward so far: 828.2500000000143
#
# -9638.19999999995
# Num buys: 94
# Num sells: 2456
# Num trades: 2550
# Num wins: 907
# Num losses: 1642
# Win streak: 20
# Loss streak: 20
# Remaining runs: 898
# Best reward so far: 828.2500000000143
#
# -1913.4000000000165
# Num buys: 889
# Num sells: 65
# Num trades: 954
# Num wins: 305
# Num losses: 648
# Win streak: 27
# Loss streak: 40
# Remaining runs: 897
# Best reward so far: 828.2500000000143
#
# -160.54999999999856
# Num buys: 107
# Num sells: 4
# Num trades: 111
# Num wins: 35
# Num losses: 76
# Win streak: 8
# Loss streak: 12
# Remaining runs: 896
# Best reward so far: 828.2500000000143
#
# -803.0499999999853
# Num buys: 385
# Num sells: 4
# Num trades: 389
# Num wins: 123
# Num losses: 266
# Win streak: 10
# Loss streak: 18
# Remaining runs: 895
# Best reward so far: 828.2500000000143
#
# -71.95000000001303
# Num buys: 108
# Num sells: 0
# Num trades: 108
# Num wins: 33
# Num losses: 75
# Win streak: 10
# Loss streak: 23
# Remaining runs: 894
# Best reward so far: 828.2500000000143
#
# -178.0000000000016
# Num buys: 12
# Num sells: 1
# Num trades: 13
# Num wins: 3
# Num losses: 10
# Win streak: 1
# Loss streak: 5
# Remaining runs: 893
# Best reward so far: 828.2500000000143
#
# -3847.0000000000728
# Num buys: 136
# Num sells: 101
# Num trades: 237
# Num wins: 77
# Num losses: 160
# Win streak: 18
# Loss streak: 22
# Remaining runs: 892
# Best reward so far: 828.2500000000143
#
# -122.35000000000069
# Num buys: 92
# Num sells: 6
# Num trades: 98
# Num wins: 30
# Num losses: 68
# Win streak: 3
# Loss streak: 8
# Remaining runs: 891
# Best reward so far: 828.2500000000143
#
# 56.19999999998272
# Num buys: 41
# Num sells: 0
# Num trades: 41
# Num wins: 11
# Num losses: 30
# Win streak: 4
# Loss streak: 16
# Remaining runs: 890
# Best reward so far: 828.2500000000143
#
# -182.5000000000437
# Num buys: 7
# Num sells: 4
# Num trades: 11
# Num wins: 4
# Num losses: 7
# Win streak: 2
# Loss streak: 3
# Remaining runs: 889
# Best reward so far: 828.2500000000143
#
# -3274.6666666667033
# Num buys: 250
# Num sells: 65
# Num trades: 315
# Num wins: 78
# Num losses: 237
# Win streak: 16
# Loss streak: 40
# Remaining runs: 888
# Best reward so far: 828.2500000000143
#
# -922.0000000000236
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 10
# Num losses: 21
# Win streak: 4
# Loss streak: 7
# Remaining runs: 887
# Best reward so far: 828.2500000000143
#
# -4407.000000000031
# Num buys: 705
# Num sells: 249
# Num trades: 954
# Num wins: 336
# Num losses: 618
# Win streak: 10
# Loss streak: 24
# Remaining runs: 886
# Best reward so far: 828.2500000000143
#
# 315.49999999998363
# Num buys: 123
# Num sells: 10
# Num trades: 133
# Num wins: 45
# Num losses: 87
# Win streak: 14
# Loss streak: 29
# Remaining runs: 885
# Best reward so far: 828.2500000000143
#
# -9331.899999999903
# Num buys: 2595
# Num sells: 636
# Num trades: 3231
# Num wins: 1114
# Num losses: 2115
# Win streak: 20
# Loss streak: 69
# Remaining runs: 884
# Best reward so far: 828.2500000000143
#
# -76.50000000001377
# Num buys: 3
# Num sells: 0
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 883
# Best reward so far: 828.2500000000143
#
# -9608.149999999889
# Num buys: 652
# Num sells: 4714
# Num trades: 5366
# Num wins: 1947
# Num losses: 3408
# Win streak: 29
# Loss streak: 72
# Remaining runs: 882
# Best reward so far: 828.2500000000143
#
# -2901.550000000023
# Num buys: 28
# Num sells: 1310
# Num trades: 1338
# Num wins: 484
# Num losses: 854
# Win streak: 13
# Loss streak: 25
# Remaining runs: 881
# Best reward so far: 828.2500000000143
#
# -1656.2499999999764
# Num buys: 281
# Num sells: 306
# Num trades: 587
# Num wins: 215
# Num losses: 372
# Win streak: 10
# Loss streak: 16
# Remaining runs: 880
# Best reward so far: 828.2500000000143
#
# -13822.83333333341
# Num buys: 136
# Num sells: 885
# Num trades: 1021
# Num wins: 283
# Num losses: 738
# Win streak: 18
# Loss streak: 29
# Remaining runs: 879
# Best reward so far: 828.2500000000143
#
# -235.5000000000152
# Num buys: 18
# Num sells: 2
# Num trades: 20
# Num wins: 4
# Num losses: 16
# Win streak: 3
# Loss streak: 7
# Remaining runs: 878
# Best reward so far: 828.2500000000143
#
# -27734.49999999996
# Num buys: 429
# Num sells: 791
# Num trades: 1220
# Num wins: 314
# Num losses: 906
# Win streak: 28
# Loss streak: 40
# Remaining runs: 877
# Best reward so far: 828.2500000000143
#
# -382.3333333333521
# Num buys: 10
# Num sells: 18
# Num trades: 28
# Num wins: 6
# Num losses: 22
# Win streak: 2
# Loss streak: 9
# Remaining runs: 876
# Best reward so far: 828.2500000000143
#
# -28.49999999999797
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 875
# Best reward so far: 828.2500000000143
#
# -1259.09999999999
# Num buys: 281
# Num sells: 306
# Num trades: 587
# Num wins: 215
# Num losses: 372
# Win streak: 10
# Loss streak: 16
# Remaining runs: 874
# Best reward so far: 828.2500000000143
#
# -138.60000000000514
# Num buys: 22
# Num sells: 0
# Num trades: 22
# Num wins: 2
# Num losses: 20
# Win streak: 1
# Loss streak: 12
# Remaining runs: 873
# Best reward so far: 828.2500000000143
#
# -1752.649999999991
# Num buys: 486
# Num sells: 212
# Num trades: 698
# Num wins: 238
# Num losses: 460
# Win streak: 8
# Loss streak: 19
# Remaining runs: 872
# Best reward so far: 828.2500000000143
#
# -694.0000000000132
# Num buys: 17
# Num sells: 7
# Num trades: 24
# Num wins: 5
# Num losses: 19
# Win streak: 3
# Loss streak: 12
# Remaining runs: 871
# Best reward so far: 828.2500000000143
#
# -237.25000000001037
# Num buys: 4
# Num sells: 6
# Num trades: 10
# Num wins: 2
# Num losses: 8
# Win streak: 1
# Loss streak: 7
# Remaining runs: 870
# Best reward so far: 828.2500000000143
#
# -1091.0000000000077
# Num buys: 582
# Num sells: 10
# Num trades: 592
# Num wins: 206
# Num losses: 385
# Win streak: 23
# Loss streak: 32
# Remaining runs: 869
# Best reward so far: 828.2500000000143
#
# -2957.000000000051
# Num buys: 509
# Num sells: 536
# Num trades: 1045
# Num wins: 399
# Num losses: 645
# Win streak: 12
# Loss streak: 14
# Remaining runs: 868
# Best reward so far: 828.2500000000143
#
# -4417.500000000042
# Num buys: 50
# Num sells: 361
# Num trades: 411
# Num wins: 120
# Num losses: 291
# Win streak: 10
# Loss streak: 17
# Remaining runs: 867
# Best reward so far: 828.2500000000143
#
# -11.200000000019713
# Num buys: 35
# Num sells: 2
# Num trades: 37
# Num wins: 9
# Num losses: 28
# Win streak: 4
# Loss streak: 11
# Remaining runs: 866
# Best reward so far: 828.2500000000143
#
# -5371.50000000008
# Num buys: 28
# Num sells: 909
# Num trades: 937
# Num wins: 323
# Num losses: 614
# Win streak: 10
# Loss streak: 25
# Remaining runs: 865
# Best reward so far: 828.2500000000143
#
# 7.500000000010715
# Num buys: 2
# Num sells: 10
# Num trades: 12
# Num wins: 3
# Num losses: 9
# Win streak: 3
# Loss streak: 9
# Remaining runs: 864
# Best reward so far: 828.2500000000143
#
# -11.500000000014092
# Num buys: 16
# Num sells: 0
# Num trades: 16
# Num wins: 3
# Num losses: 13
# Win streak: 3
# Loss streak: 12
# Remaining runs: 863
# Best reward so far: 828.2500000000143
#
# -57.500000000005876
# Num buys: 4
# Num sells: 0
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 862
# Best reward so far: 828.2500000000143
#
# -116.55000000000082
# Num buys: 92
# Num sells: 6
# Num trades: 98
# Num wins: 30
# Num losses: 68
# Win streak: 3
# Loss streak: 8
# Remaining runs: 861
# Best reward so far: 828.2500000000143
#
# -167.00000000002098
# Num buys: 7
# Num sells: 8
# Num trades: 15
# Num wins: 5
# Num losses: 10
# Win streak: 2
# Loss streak: 4
# Remaining runs: 860
# Best reward so far: 828.2500000000143
#
# -4553.500000000054
# Num buys: 50
# Num sells: 361
# Num trades: 411
# Num wins: 120
# Num losses: 291
# Win streak: 10
# Loss streak: 17
# Remaining runs: 859
# Best reward so far: 828.2500000000143
#
# 56.69999999998187
# Num buys: 73
# Num sells: 3
# Num trades: 76
# Num wins: 24
# Num losses: 51
# Win streak: 8
# Loss streak: 22
# Remaining runs: 858
# Best reward so far: 828.2500000000143
#
# -58.99999999999201
# Num buys: 2
# Num sells: 10
# Num trades: 12
# Num wins: 3
# Num losses: 9
# Win streak: 3
# Loss streak: 9
# Remaining runs: 857
# Best reward so far: 828.2500000000143
#
# -10497.54999999995
# Num buys: 171
# Num sells: 3793
# Num trades: 3964
# Num wins: 1398
# Num losses: 2561
# Win streak: 20
# Loss streak: 26
# Remaining runs: 856
# Best reward so far: 828.2500000000143
#
# -15665.000000000247
# Num buys: 348
# Num sells: 319
# Num trades: 667
# Num wins: 201
# Num losses: 466
# Win streak: 10
# Loss streak: 26
# Remaining runs: 855
# Best reward so far: 828.2500000000143
#
# -87.80000000000604
# Num buys: 43
# Num sells: 0
# Num trades: 43
# Num wins: 8
# Num losses: 35
# Win streak: 4
# Loss streak: 12
# Remaining runs: 854
# Best reward so far: 828.2500000000143
#
# -186.69999999999158
# Num buys: 43
# Num sells: 11
# Num trades: 54
# Num wins: 13
# Num losses: 41
# Win streak: 2
# Loss streak: 8
# Remaining runs: 853
# Best reward so far: 828.2500000000143
#
# -128.00000000000588
# Num buys: 1
# Num sells: 4
# Num trades: 5
# Num wins: 1
# Num losses: 4
# Win streak: 1
# Loss streak: 4
# Remaining runs: 852
# Best reward so far: 828.2500000000143
#
# -827.2499999999739
# Num buys: 281
# Num sells: 306
# Num trades: 587
# Num wins: 215
# Num losses: 372
# Win streak: 10
# Loss streak: 16
# Remaining runs: 851
# Best reward so far: 828.2500000000143
#
# -3701.500000000005
# Num buys: 396
# Num sells: 414
# Num trades: 810
# Num wins: 305
# Num losses: 504
# Win streak: 11
# Loss streak: 16
# Remaining runs: 850
# Best reward so far: 828.2500000000143
#
# -153.24999999999366
# Num buys: 9
# Num sells: 0
# Num trades: 9
# Num wins: 1
# Num losses: 8
# Win streak: 1
# Loss streak: 8
# Remaining runs: 849
# Best reward so far: 828.2500000000143
#
# -665.8333333333356
# Num buys: 146
# Num sells: 34
# Num trades: 180
# Num wins: 58
# Num losses: 122
# Win streak: 6
# Loss streak: 15
# Remaining runs: 848
# Best reward so far: 828.2500000000143
#
# -658.0000000000185
# Num buys: 38
# Num sells: 7
# Num trades: 45
# Num wins: 9
# Num losses: 36
# Win streak: 3
# Loss streak: 12
# Remaining runs: 847
# Best reward so far: 828.2500000000143
#
# -1777.3333333333412
# Num buys: 281
# Num sells: 119
# Num trades: 400
# Num wins: 121
# Num losses: 279
# Win streak: 7
# Loss streak: 17
# Remaining runs: 846
# Best reward so far: 828.2500000000143
#
# -9338.249999999949
# Num buys: 3469
# Num sells: 636
# Num trades: 4105
# Num wins: 1427
# Num losses: 2674
# Win streak: 20
# Loss streak: 69
# Remaining runs: 845
# Best reward so far: 828.2500000000143
#
# -663.6666666666688
# Num buys: 146
# Num sells: 34
# Num trades: 180
# Num wins: 58
# Num losses: 122
# Win streak: 6
# Loss streak: 15
# Remaining runs: 844
# Best reward so far: 828.2500000000143
#
# -23410.166666666675
# Num buys: 259
# Num sells: 1487
# Num trades: 1746
# Num wins: 478
# Num losses: 1268
# Win streak: 26
# Loss streak: 52
# Remaining runs: 843
# Best reward so far: 828.2500000000143
#
# -129.30000000001144
# Num buys: 101
# Num sells: 3
# Num trades: 104
# Num wins: 27
# Num losses: 76
# Win streak: 8
# Loss streak: 22
# Remaining runs: 842
# Best reward so far: 828.2500000000143
#
# -330.00000000000455
# Num buys: 48
# Num sells: 2
# Num trades: 50
# Num wins: 8
# Num losses: 42
# Win streak: 4
# Loss streak: 18
# Remaining runs: 841
# Best reward so far: 828.2500000000143
#
# -6188.599999999962
# Num buys: 95
# Num sells: 3143
# Num trades: 3238
# Num wins: 1208
# Num losses: 2026
# Win streak: 13
# Loss streak: 24
# Remaining runs: 840
# Best reward so far: 828.2500000000143
#
# 519.750000000028
# Num buys: 28
# Num sells: 10
# Num trades: 38
# Num wins: 16
# Num losses: 22
# Win streak: 13
# Loss streak: 13
# Remaining runs: 839
# Best reward so far: 828.2500000000143
#
# -6697.500000000053
# Num buys: 94
# Num sells: 276
# Num trades: 370
# Num wins: 105
# Num losses: 265
# Win streak: 12
# Loss streak: 19
# Remaining runs: 838
# Best reward so far: 828.2500000000143
#
# -36.83333333334855
# Num buys: 16
# Num sells: 0
# Num trades: 16
# Num wins: 3
# Num losses: 13
# Win streak: 3
# Loss streak: 12
# Remaining runs: 837
# Best reward so far: 828.2500000000143
#
# 400.00000000000335
# Num buys: 28
# Num sells: 10
# Num trades: 38
# Num wins: 15
# Num losses: 23
# Win streak: 13
# Loss streak: 14
# Remaining runs: 836
# Best reward so far: 828.2500000000143
#
# -423.50000000002007
# Num buys: 17
# Num sells: 2
# Num trades: 19
# Num wins: 4
# Num losses: 15
# Win streak: 3
# Loss streak: 6
# Remaining runs: 835
# Best reward so far: 828.2500000000143
#
# -23804.00000000001
# Num buys: 259
# Num sells: 1487
# Num trades: 1746
# Num wins: 478
# Num losses: 1268
# Win streak: 26
# Loss streak: 52
# Remaining runs: 834
# Best reward so far: 828.2500000000143
#
# -1872.1499999999685
# Num buys: 4
# Num sells: 930
# Num trades: 934
# Num wins: 314
# Num losses: 620
# Win streak: 10
# Loss streak: 24
# Remaining runs: 833
# Best reward so far: 828.2500000000143
#
# -60.999999999988844
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Remaining runs: 832
# Best reward so far: 828.2500000000143
#
# -1542.9000000000142
# Num buys: 662
# Num sells: 11
# Num trades: 673
# Num wins: 198
# Num losses: 475
# Win streak: 7
# Loss streak: 22
# Remaining runs: 831
# Best reward so far: 828.2500000000143
#
# -125.00000000000354
# Num buys: 16
# Num sells: 0
# Num trades: 16
# Num wins: 2
# Num losses: 14
# Win streak: 1
# Loss streak: 9
# Remaining runs: 830
# Best reward so far: 828.2500000000143
#
# -801.4999999999987
# Num buys: 281
# Num sells: 119
# Num trades: 400
# Num wins: 121
# Num losses: 279
# Win streak: 7
# Loss streak: 17
# Remaining runs: 829
# Best reward so far: 828.2500000000143
#
# -173.1499999999929
# Num buys: 76
# Num sells: 11
# Num trades: 87
# Num wins: 24
# Num losses: 63
# Win streak: 4
# Loss streak: 11
# Remaining runs: 828
# Best reward so far: 828.2500000000143
#
# -85.2500000000127
# Num buys: 8
# Num sells: 0
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 6
# Remaining runs: 827
# Best reward so far: 828.2500000000143
#
# -138.00000000002322
# Num buys: 7
# Num sells: 0
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 5
# Remaining runs: 826
# Best reward so far: 828.2500000000143
#
# -80.75000000001296
# Num buys: 8
# Num sells: 0
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 6
# Remaining runs: 825
# Best reward so far: 828.2500000000143
#
# 266.0000000000109
# Num buys: 11
# Num sells: 4
# Num trades: 15
# Num wins: 7
# Num losses: 8
# Win streak: 6
# Loss streak: 5
# Remaining runs: 824
# Best reward so far: 828.2500000000143
#
# -1543.5000000000844
# Num buys: 30
# Num sells: 11
# Num trades: 41
# Num wins: 6
# Num losses: 35
# Win streak: 3
# Loss streak: 22
# Remaining runs: 823
# Best reward so far: 828.2500000000143
#
# -5695.750000000118
# Num buys: 95
# Num sells: 188
# Num trades: 283
# Num wins: 85
# Num losses: 198
# Win streak: 6
# Loss streak: 16
# Remaining runs: 822
# Best reward so far: 828.2500000000143
#
# -146.70000000000826
# Num buys: 84
# Num sells: 0
# Num trades: 84
# Num wins: 20
# Num losses: 64
# Win streak: 4
# Loss streak: 18
# Remaining runs: 821
# Best reward so far: 828.2500000000143
#
# -5954.200000000024
# Num buys: 95
# Num sells: 1579
# Num trades: 1674
# Num wins: 618
# Num losses: 1054
# Win streak: 13
# Loss streak: 24
# Remaining runs: 820
# Best reward so far: 828.2500000000143
#
# -28.49999999999797
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 0
# Num losses: 1
# Win streak: 0
# Loss streak: 1
# Remaining runs: 819
# Best reward so far: 828.2500000000143
#
# -13654.333333333407
# Num buys: 136
# Num sells: 885
# Num trades: 1021
# Num wins: 283
# Num losses: 738
# Win streak: 18
# Loss streak: 29
# Remaining runs: 818
# Best reward so far: 828.2500000000143
#
# 259.5000000000167
# Num buys: 107
# Num sells: 4
# Num trades: 111
# Num wins: 39
# Num losses: 72
# Win streak: 10
# Loss streak: 12
# Remaining runs: 817
# Best reward so far: 828.2500000000143
#
# -21376.44999999987
# Num buys: 259
# Num sells: 7306
# Num trades: 7565
# Num wins: 2608
# Num losses: 4953
# Win streak: 38
# Loss streak: 52
# Remaining runs: 816
# Best reward so far: 828.2500000000143
#
# -20318.699999999917
# Num buys: 429
# Num sells: 7231
# Num trades: 7660
# Num wins: 2681
# Num losses: 4973
# Win streak: 48
# Loss streak: 53
# Remaining runs: 815
# Best reward so far: 828.2500000000143
#
# -1157.5000000000045
# Num buys: 16
# Num sells: 90
# Num trades: 106
# Num wins: 29
# Num losses: 77
# Win streak: 7
# ...
# Num sells: 1
# Num trades: 14
# Num wins: 3
# Num losses: 11
# Win streak: 1
# Loss streak: 6
# Remaining runs: 88
# Best reward so far: 1192.9999999999704
#
# -271.2500000000101
# Num buys: 3
# Num sells: 30
# Num trades: 33
# Num wins: 11
# Num losses: 22
# Win streak: 3
# Loss streak: 8
# Remaining runs: 87
# Best reward so far: 1192.9999999999704
#
# -111.16666666667541
# Num buys: 35
# Num sells: 0
# Num trades: 35
# Num wins: 8
# Num losses: 27
# Win streak: 4
# Loss streak: 8
# Remaining runs: 86
# Best reward so far: 1192.9999999999704
#
# -7788.8333333334
# Num buys: 95
# Num sells: 943
# Num trades: 1038
# Num wins: 361
# Num losses: 676
# Win streak: 12
# Loss streak: 24
# Remaining runs: 85
# Best reward so far: 1192.9999999999704
#
# -88.00000000000657
# Num buys: 43
# Num sells: 0
# Num trades: 43
# Num wins: 8
# Num losses: 35
# Win streak: 4
# Loss streak: 12
# Remaining runs: 84
# Best reward so far: 1192.9999999999704
#
# -470.0499999999944
# Num buys: 105
# Num sells: 2
# Num trades: 107
# Num wins: 20
# Num losses: 87
# Win streak: 5
# Loss streak: 18
# Remaining runs: 83
# Best reward so far: 1192.9999999999704
#
# -1108.049999999995
# Num buys: 281
# Num sells: 306
# Num trades: 587
# Num wins: 215
# Num losses: 372
# Win streak: 10
# Loss streak: 16
# Remaining runs: 82
# Best reward so far: 1192.9999999999704
#
# -460.83333333337
# Num buys: 75
# Num sells: 11
# Num trades: 86
# Num wins: 21
# Num losses: 65
# Win streak: 4
# Loss streak: 22
# Remaining runs: 81
# Best reward so far: 1192.9999999999704
#
# -666.599999999988
# Num buys: 3
# Num sells: 782
# Num trades: 785
# Num wins: 292
# Num losses: 492
# Win streak: 9
# Loss streak: 17
# Remaining runs: 80
# Best reward so far: 1192.9999999999704
#
# -1653.599999999992
# Num buys: 4
# Num sells: 309
# Num trades: 313
# Num wins: 83
# Num losses: 230
# Win streak: 7
# Loss streak: 24
# Remaining runs: 79
# Best reward so far: 1192.9999999999704
#
# -7133.250000000066
# Num buys: 94
# Num sells: 276
# Num trades: 370
# Num wins: 105
# Num losses: 265
# Win streak: 12
# Loss streak: 19
# Remaining runs: 78
# Best reward so far: 1192.9999999999704
#
# -138.10000000000375
# Num buys: 22
# Num sells: 0
# Num trades: 22
# Num wins: 2
# Num losses: 20
# Win streak: 1
# Loss streak: 12
# Remaining runs: 77
# Best reward so far: 1192.9999999999704
#
# -7842.500000000002
# Num buys: 95
# Num sells: 2167
# Num trades: 2262
# Num wins: 822
# Num losses: 1438
# Win streak: 13
# Loss streak: 24
# Remaining runs: 76
# Best reward so far: 1192.9999999999704
#
# -1652.250000000108
# Num buys: 174
# Num sells: 31
# Num trades: 205
# Num wins: 59
# Num losses: 146
# Win streak: 9
# Loss streak: 42
# Remaining runs: 75
# Best reward so far: 1192.9999999999704
#
# -665.5000000000107
# Num buys: 38
# Num sells: 7
# Num trades: 45
# Num wins: 9
# Num losses: 36
# Win streak: 3
# Loss streak: 12
# Remaining runs: 74
# Best reward so far: 1192.9999999999704
#
# -8958.099999999973
# Num buys: 94
# Num sells: 2301
# Num trades: 2395
# Num wins: 842
# Num losses: 1552
# Win streak: 20
# Loss streak: 20
# Remaining runs: 73
# Best reward so far: 1192.9999999999704
#
# -9146.999999999907
# Num buys: 158
# Num sells: 65
# Num trades: 223
# Num wins: 42
# Num losses: 181
# Win streak: 7
# Loss streak: 40
# Remaining runs: 72
# Best reward so far: 1192.9999999999704
#
# -499.5000000000424
# Num buys: 75
# Num sells: 11
# Num trades: 86
# Num wins: 21
# Num losses: 65
# Win streak: 4
# Loss streak: 22
# Remaining runs: 71
# Best reward so far: 1192.9999999999704
#
# -134.40000000000617
# Num buys: 22
# Num sells: 0
# Num trades: 22
# Num wins: 2
# Num losses: 20
# Win streak: 1
# Loss streak: 12
# Remaining runs: 70
# Best reward so far: 1192.9999999999704
#
# -10618.666666666735
# Num buys: 171
# Num sells: 666
# Num trades: 837
# Num wins: 242
# Num losses: 595
# Win streak: 14
# Loss streak: 21
# Remaining runs: 69
# Best reward so far: 1192.9999999999704
#
# -3.4000000000151402
# Num buys: 35
# Num sells: 2
# Num trades: 37
# Num wins: 9
# Num losses: 28
# Win streak: 4
# Loss streak: 11
# Remaining runs: 68
# Best reward so far: 1192.9999999999704
#
# -127.70000000000066
# Num buys: 24
# Num sells: 1
# Num trades: 25
# Num wins: 4
# Num losses: 21
# Win streak: 1
# Loss streak: 12
# Remaining runs: 67
# Best reward so far: 1192.9999999999704
#
# -101.40000000000612
# Num buys: 43
# Num sells: 0
# Num trades: 43
# Num wins: 8
# Num losses: 35
# Win streak: 4
# Loss streak: 12
# Remaining runs: 66
# Best reward so far: 1192.9999999999704
#
# -184.75000000000097
# Num buys: 106
# Num sells: 0
# Num trades: 106
# Num wins: 27
# Num losses: 79
# Win streak: 6
# Loss streak: 10
# Remaining runs: 65
# Best reward so far: 1192.9999999999704
#
# -3535.000000000045
# Num buys: 50
# Num sells: 160
# Num trades: 210
# Num wins: 61
# Num losses: 149
# Win streak: 10
# Loss streak: 11
# Remaining runs: 64
# Best reward so far: 1192.9999999999704
#
# -3458.500000000052
# Num buys: 267
# Num sells: 212
# Num trades: 479
# Num wins: 175
# Num losses: 304
# Win streak: 8
# Loss streak: 17
# Remaining runs: 63
# Best reward so far: 1192.9999999999704
#
# 229.09999999998388
# Num buys: 89
# Num sells: 0
# Num trades: 89
# Num wins: 34
# Num losses: 55
# Win streak: 16
# Loss streak: 19
# Remaining runs: 62
# Best reward so far: 1192.9999999999704
#
# -29036.000000000164
# Num buys: 680
# Num sells: 636
# Num trades: 1316
# Num wins: 394
# Num losses: 921
# Win streak: 15
# Loss streak: 69
# Remaining runs: 61
# Best reward so far: 1192.9999999999704
#
# -3177.5000000000873
# Num buys: 65
# Num sells: 21
# Num trades: 86
# Num wins: 16
# Num losses: 70
# Win streak: 4
# Loss streak: 15
# Remaining runs: 60
# Best reward so far: 1192.9999999999704
#
# -265.0500000000206
# Num buys: 175
# Num sells: 0
# Num trades: 175
# Num wins: 48
# Num losses: 126
# Win streak: 16
# Loss streak: 51
# Remaining runs: 59
# Best reward so far: 1192.9999999999704
#
# -13714.166666666739
# Num buys: 136
# Num sells: 885
# Num trades: 1021
# Num wins: 283
# Num losses: 738
# Win streak: 18
# Loss streak: 29
# Remaining runs: 58
# Best reward so far: 1192.9999999999704
#
# 44.99999999998438
# Num buys: 6
# Num sells: 2
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 2
# Loss streak: 3
# Remaining runs: 57
# Best reward so far: 1192.9999999999704
#
# -117.66666666667226
# Num buys: 20
# Num sells: 0
# Num trades: 20
# Num wins: 3
# Num losses: 17
# Win streak: 2
# Loss streak: 12
# Remaining runs: 56
# Best reward so far: 1192.9999999999704
#
# -812.1666666667147
# Num buys: 101
# Num sells: 21
# Num trades: 122
# Num wins: 34
# Num losses: 88
# Win streak: 8
# Loss streak: 15
# Remaining runs: 55
# Best reward so far: 1192.9999999999704
#
# 131.6666666666426
# Num buys: 26
# Num sells: 2
# Num trades: 28
# Num wins: 8
# Num losses: 20
# Win streak: 4
# Loss streak: 11
# Remaining runs: 54
# Best reward so far: 1192.9999999999704
#
# -20577.34999999992
# Num buys: 429
# Num sells: 7231
# Num trades: 7660
# Num wins: 2681
# Num losses: 4973
# Win streak: 48
# Loss streak: 53
# Remaining runs: 53
# Best reward so far: 1192.9999999999704
#
# -333.99999999996504
# Num buys: 15
# Num sells: 11
# Num trades: 26
# Num wins: 7
# Num losses: 19
# Win streak: 2
# Loss streak: 4
# Remaining runs: 52
# Best reward so far: 1192.9999999999704
#
# -9597.699999999888
# Num buys: 2595
# Num sells: 636
# Num trades: 3231
# Num wins: 1114
# Num losses: 2115
# Win streak: 20
# Loss streak: 69
# Remaining runs: 51
# Best reward so far: 1192.9999999999704
#
# -1873.5000000000155
# Num buys: 889
# Num sells: 65
# Num trades: 954
# Num wins: 305
# Num losses: 648
# Win streak: 27
# Loss streak: 40
# Remaining runs: 50
# Best reward so far: 1192.9999999999704
#
# -1432.500000000052
# Num buys: 35
# Num sells: 43
# Num trades: 78
# Num wins: 20
# Num losses: 58
# Win streak: 7
# Loss streak: 16
# Remaining runs: 49
# Best reward so far: 1192.9999999999704
#
# -3078.500000000016
# Num buys: 35
# Num sells: 301
# Num trades: 336
# Num wins: 86
# Num losses: 249
# Win streak: 16
# Loss streak: 29
# Remaining runs: 48
# Best reward so far: 1192.9999999999704
#
# -78.50000000001377
# Num buys: 3
# Num sells: 0
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 47
# Best reward so far: 1192.9999999999704
#
# -12325.499999999889
# Num buys: 751
# Num sells: 580
# Num trades: 1331
# Num wins: 473
# Num losses: 857
# Win streak: 20
# Loss streak: 42
# Remaining runs: 46
# Best reward so far: 1192.9999999999704
#
# -2022.0000000000405
# Num buys: 35
# Num sells: 29
# Num trades: 64
# Num wins: 17
# Num losses: 47
# Win streak: 7
# Loss streak: 10
# Remaining runs: 45
# Best reward so far: 1192.9999999999704
#
# -1704.999999999942
# Num buys: 281
# Num sells: 306
# Num trades: 587
# Num wins: 215
# Num losses: 372
# Win streak: 10
# Loss streak: 16
# Remaining runs: 44
# Best reward so far: 1192.9999999999704
#
# -2036.4999999999914
# Num buys: 781
# Num sells: 414
# Num trades: 1195
# Num wins: 442
# Num losses: 751
# Win streak: 11
# Loss streak: 16
# Remaining runs: 43
# Best reward so far: 1192.9999999999704
#
# -697.7500000000184
# Num buys: 297
# Num sells: 12
# Num trades: 309
# Num wins: 91
# Num losses: 218
# Win streak: 7
# Loss streak: 14
# Remaining runs: 42
# Best reward so far: 1192.9999999999704
#
# -59.500000000005876
# Num buys: 4
# Num sells: 0
# Num trades: 4
# Num wins: 0
# Num losses: 4
# Win streak: 0
# Loss streak: 4
# Remaining runs: 41
# Best reward so far: 1192.9999999999704
#
# -8948.666666666704
# Num buys: 95
# Num sells: 1320
# Num trades: 1415
# Num wins: 510
# Num losses: 904
# Win streak: 13
# Loss streak: 24
# Remaining runs: 40
# Best reward so far: 1192.9999999999704
#
# -102.25000000000384
# Num buys: 12
# Num sells: 6
# Num trades: 18
# Num wins: 4
# Num losses: 14
# Win streak: 1
# Loss streak: 5
# Remaining runs: 39
# Best reward so far: 1192.9999999999704
#
# -81.2500000000168
# Num buys: 8
# Num sells: 0
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 6
# Remaining runs: 38
# Best reward so far: 1192.9999999999704
#
# -6641.5000000002265
# Num buys: 171
# Num sells: 90
# Num trades: 261
# Num wins: 81
# Num losses: 180
# Win streak: 12
# Loss streak: 17
# Remaining runs: 37
# Best reward so far: 1192.9999999999704
#
# 26.999999999999247
# Num buys: 1
# Num sells: 0
# Num trades: 1
# Num wins: 1
# Num losses: 0
# Win streak: 1
# Loss streak: 0
# Remaining runs: 36
# Best reward so far: 1192.9999999999704
#
# -1038.5000000000005
# Num buys: 409
# Num sells: 34
# Num trades: 443
# Num wins: 156
# Num losses: 287
# Win streak: 19
# Loss streak: 15
# Remaining runs: 35
# Best reward so far: 1192.9999999999704
#
# 359.99999999998954
# Num buys: 89
# Num sells: 0
# Num trades: 89
# Num wins: 34
# Num losses: 55
# Win streak: 16
# Loss streak: 19
# Remaining runs: 34
# Best reward so far: 1192.9999999999704
#
# -2283.899999999994
# Num buys: 1028
# Num sells: 536
# Num trades: 1564
# Num wins: 589
# Num losses: 973
# Win streak: 12
# Loss streak: 16
# Remaining runs: 33
# Best reward so far: 1192.9999999999704
#
# -1093.6000000000117
# Num buys: 10
# Num sells: 115
# Num trades: 125
# Num wins: 33
# Num losses: 92
# Win streak: 6
# Loss streak: 13
# Remaining runs: 32
# Best reward so far: 1192.9999999999704
#
# -194.50000000000568
# Num buys: 16
# Num sells: 0
# Num trades: 16
# Num wins: 1
# Num losses: 15
# Win streak: 1
# Loss streak: 11
# Remaining runs: 31
# Best reward so far: 1192.9999999999704
#
# -111.0000000000062
# Num buys: 11
# Num sells: 0
# Num trades: 11
# Num wins: 1
# Num losses: 10
# Win streak: 1
# Loss streak: 6
# Remaining runs: 30
# Best reward so far: 1192.9999999999704
#
# -18645.00000000001
# Num buys: 429
# Num sells: 2154
# Num trades: 2583
# Num wins: 772
# Num losses: 1811
# Win streak: 28
# Loss streak: 53
# Remaining runs: 29
# Best reward so far: 1192.9999999999704
#
# -1561.0000000001085
# Num buys: 174
# Num sells: 31
# Num trades: 205
# Num wins: 59
# Num losses: 146
# Win streak: 9
# Loss streak: 42
# Remaining runs: 28
# Best reward so far: 1192.9999999999704
#
# -914.5000000000457
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 10
# Num losses: 21
# Win streak: 4
# Loss streak: 7
# Remaining runs: 27
# Best reward so far: 1192.9999999999704
#
# -797.000000000045
# Num buys: 101
# Num sells: 21
# Num trades: 122
# Num wins: 34
# Num losses: 88
# Win streak: 8
# Loss streak: 15
# Remaining runs: 26
# Best reward so far: 1192.9999999999704
#
# 54.24999999998293
# Num buys: 6
# Num sells: 2
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 2
# Loss streak: 3
# Remaining runs: 25
# Best reward so far: 1192.9999999999704
#
# -171.5000000000011
# Num buys: 73
# Num sells: 0
# Num trades: 73
# Num wins: 17
# Num losses: 56
# Win streak: 3
# Loss streak: 12
# Remaining runs: 24
# Best reward so far: 1192.9999999999704
#
# -1711.6999999999894
# Num buys: 4
# Num sells: 309
# Num trades: 313
# Num wins: 83
# Num losses: 230
# Win streak: 7
# Loss streak: 24
# Remaining runs: 23
# Best reward so far: 1192.9999999999704
#
# -132.75000000001003
# Num buys: 98
# Num sells: 34
# Num trades: 132
# Num wins: 47
# Num losses: 85
# Win streak: 6
# Loss streak: 11
# Remaining runs: 22
# Best reward so far: 1192.9999999999704
#
# -7076.00000000006
# Num buys: 94
# Num sells: 276
# Num trades: 370
# Num wins: 105
# Num losses: 265
# Win streak: 12
# Loss streak: 19
# Remaining runs: 21
# Best reward so far: 1192.9999999999704
#
# 139.50000000004292
# Num buys: 16
# Num sells: 11
# Num trades: 27
# Num wins: 9
# Num losses: 18
# Win streak: 3
# Loss streak: 6
# Remaining runs: 20
# Best reward so far: 1192.9999999999704
#
# -33334.50000000001
# Num buys: 652
# Num sells: 562
# Num trades: 1214
# Num wins: 347
# Num losses: 866
# Win streak: 17
# Loss streak: 72
# Remaining runs: 19
# Best reward so far: 1192.9999999999704
#
# -1619.6999999999928
# Num buys: 16
# Num sells: 189
# Num trades: 205
# Num wins: 50
# Num losses: 155
# Win streak: 7
# Loss streak: 23
# Remaining runs: 18
# Best reward so far: 1192.9999999999704
#
# -56.499999999992674
# Num buys: 1
# Num sells: 2
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Remaining runs: 17
# Best reward so far: 1192.9999999999704
#
# -1606.4000000000049
# Num buys: 854
# Num sells: 7
# Num trades: 861
# Num wins: 278
# Num losses: 582
# Win streak: 7
# Loss streak: 25
# Remaining runs: 16
# Best reward so far: 1192.9999999999704
#
# -1270.4000000000024
# Num buys: 281
# Num sells: 119
# Num trades: 400
# Num wins: 121
# Num losses: 279
# Win streak: 7
# Loss streak: 17
# Remaining runs: 15
# Best reward so far: 1192.9999999999704
#
# -1448.0000000000546
# Num buys: 348
# Num sells: 11
# Num trades: 359
# Num wins: 99
# Num losses: 260
# Win streak: 6
# Loss streak: 22
# Remaining runs: 14
# Best reward so far: 1192.9999999999704
#
# -3792.0000000000964
# Num buys: 136
# Num sells: 101
# Num trades: 237
# Num wins: 77
# Num losses: 160
# Win streak: 18
# Loss streak: 22
# Remaining runs: 13
# Best reward so far: 1192.9999999999704
#
# -1651.250000000085
# Num buys: 89
# Num sells: 21
# Num trades: 110
# Num wins: 26
# Num losses: 84
# Win streak: 4
# Loss streak: 15
# Remaining runs: 12
# Best reward so far: 1192.9999999999704
#
# -6340.29999999993
# Num buys: 1351
# Num sells: 580
# Num trades: 1931
# Num wins: 686
# Num losses: 1243
# Win streak: 20
# Loss streak: 42
# Remaining runs: 11
# Best reward so far: 1192.9999999999704
#
# -83.49999999999191
# Num buys: 3
# Num sells: 0
# Num trades: 3
# Num wins: 0
# Num losses: 3
# Win streak: 0
# Loss streak: 3
# Remaining runs: 10
# Best reward so far: 1192.9999999999704
#
# -3205.600000000062
# Num buys: 1168
# Num sells: 31
# Num trades: 1199
# Num wins: 372
# Num losses: 826
# Win streak: 13
# Loss streak: 42
# Remaining runs: 9
# Best reward so far: 1192.9999999999704
#
# -6192.749999999977
# Num buys: 95
# Num sells: 3142
# Num trades: 3237
# Num wins: 1208
# Num losses: 2026
# Win streak: 13
# Loss streak: 24
# Remaining runs: 8
# Best reward so far: 1192.9999999999704
#
# -2315.299999999982
# Num buys: 486
# Num sells: 212
# Num trades: 698
# Num wins: 238
# Num losses: 460
# Win streak: 8
# Loss streak: 19
# Remaining runs: 7
# Best reward so far: 1192.9999999999704
#
# -92.30000000000365
# Num buys: 40
# Num sells: 0
# Num trades: 40
# Num wins: 8
# Num losses: 32
# Win streak: 3
# Loss streak: 12
# Remaining runs: 6
# Best reward so far: 1192.9999999999704
#
# -3093.0000000000878
# Num buys: 65
# Num sells: 21
# Num trades: 86
# Num wins: 16
# Num losses: 70
# Win streak: 4
# Loss streak: 15
# Remaining runs: 5
# Best reward so far: 1192.9999999999704
#
# -4233.599999999988
# Num buys: 1350
# Num sells: 249
# Num trades: 1599
# Num wins: 557
# Num losses: 1041
# Win streak: 10
# Loss streak: 24
# Remaining runs: 4
# Best reward so far: 1192.9999999999704
#
# -129.3333333333407
# Num buys: 35
# Num sells: 0
# Num trades: 35
# Num wins: 8
# Num losses: 27
# Win streak: 4
# Loss streak: 8
# Remaining runs: 3
# Best reward so far: 1192.9999999999704
#
# -5687.299999999948
# Num buys: 50
# Num sells: 2344
# Num trades: 2394
# Num wins: 858
# Num losses: 1536
# Win streak: 19
# Loss streak: 20
# Remaining runs: 2
# Best reward so far: 1192.9999999999704
#
# -5889.0000000001055
# Num buys: 95
# Num sells: 188
# Num trades: 283
# Num wins: 85
# Num losses: 198
# Win streak: 6
# Loss streak: 16
# Remaining runs: 1
# Best reward so far: 1192.9999999999704
#
# -5446.699999999984
# Num buys: 51
# Num sells: 2672
# Num trades: 2723
# Num wins: 1012
# Num losses: 1708
# Win streak: 13
# Loss streak: 25
# Remaining runs: 0
# Best reward so far: 1192.9999999999704

# %%
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best pullback cushion: ' + str(best_pullback_cushion))
print('Best atr percentage: ' + str(best_atr_percentage))
print('Best last x bars: ' + str(best_last_x_bars_val))
print('Best fractal distance: ' + str(best_fractal_distance))
print('Best bar length: ' + str(best_bar_length))
print('Best ema val: ' + str(best_ema_val))
print('Best max open trades: ' + str(best_max_open_trades_val))

# 2014-2015:
# Best reward: 766.3333333333303
# Best risk/reward ratio: 2
# Best pullback cushion: 5
# Best atr percentage: 0.2
# Best last x bars: 2
# Best fractal distance: 10
# Best bar length: 10
# Best ema val: ema50
# Best max open trades: 3

# 2015-2016:
# Best reward: 2658.000000000001
# Best risk/reward ratio: 2
# Best pullback cushion: 5
# Best atr percentage: 0.2
# Best last x bars: 3
# Best fractal distance: 10
# Best bar length: 10
# Best ema val: ema50
# Best max open trades: 1

# 2016-2017:
# Best reward: 2608.000000000024
# Best risk/reward ratio: 2
# Best pullback cushion: 10
# Best atr percentage: 0.3
# Best last x bars: 3
# Best fractal distance: 10
# Best bar length: 5
# Best ema val: ema50
# Best max open trades: 1

# 2017-2018:
# Best reward: 5668.00000000005
# Best risk/reward ratio: 1.8
# Best pullback cushion: 10
# Best atr percentage: 0.3
# Best last x bars: 2
# Best fractal distance: 10
# Best bar length: 5
# Best ema val: ema50
# Best max open trades: 1

# 2018-2019:
# Best reward: 184.0000000000245
# Best risk/reward ratio: 1.7
# Best pullback cushion: 10
# Best atr percentage: 0.2
# Best last x bars: 2
# Best fractal distance: 10
# Best bar length: 10
# Best ema val: ema50
# Best max open trades: 1

# 2019-2020:
# Best reward: 1254.4999999999902
# Best risk/reward ratio: 2
# Best pullback cushion: 10
# Best atr percentage: 0.3
# Best last x bars: 3
# Best fractal distance: 10
# Best bar length: 5
# Best ema val: ema50
# Best max open trades: 2

# 2020-2021:
# Best reward: 4274.000000000465
# Best risk/reward ratio: 1.8
# Best pullback cushion: 10
# Best atr percentage: 0.3
# Best last x bars: 2
# Best fractal distance: 10
# Best bar length: 5
# Best ema val: ema50
# Best max open trades: 1

# --------------------------------------------
# --------------------------------------------
# --------------------------------------------

# 2014-2021:
# Best reward: 1192.9999999999704
# Best risk/reward ratio: 1.9
# Best pullback cushion: 5
# Best atr percentage: 0.2
# Best last x bars: 1
# Best fractal distance: 10
# Best bar length: 10
# Best ema val: ema50
# Best max open trades: 3

# 2014-2020:

# 2015-2021:
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1192.9999999999704
# Best risk/reward ratio: 1.9
# Best pullback cushion: 5
# Best atr percentage: 0.2
# Best last x bars: 1
# Best fractal distance: 10
# Best bar length: 10
# Best ema val: ema50
# Best max open trades: 3
