# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from pyts.image import RecurrencePlot, GramianAngularField
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model, Sequential
import json
import time
from collections import deque
import warnings
from pickle import dump, load
from sklearn.preprocessing import StandardScaler

file_path = '/Users/mymac/Google Drive/My Drive/Forex_Robot/'

# %%
currencies = ['Usd_Chf', 'Gbp_Usd', 'Usd_Cad', 'Aud_Usd', 'Eur_Usd', 'Usd_Jpy', 'Nzd_Usd']
years = '2016-2022'

dfs, df_longs = [], []

# news = pd.read_csv(file_path + 'events_2016-2022.csv')
# news = news.rename(columns={'Start': 'Date'})
# news.Date = pd.to_datetime(news.Date)

for currency_pair in currencies:
    # currency1, currency2 = currency_pair.split('_')
    # currency1, currency2 = currency1.upper(), currency2.upper()

    # curr_news = news.loc[(news['Currency'] == currency1) | (news['Currency'] == currency2)]
    # curr_news.drop(['Id', 'Name', 'Currency'], axis=1, inplace=True)
    # curr_news.drop(curr_news[(curr_news['Impact'] != 'LOW') & (curr_news['Impact'] != 'MEDIUM') & (curr_news['Impact'] != 'HIGH')].index, inplace=True)
    # curr_news.loc[curr_news['Impact'] == 'LOW', 'Impact'] = 1
    # curr_news.loc[curr_news['Impact'] == 'MEDIUM', 'Impact'] = 2
    # curr_news.loc[curr_news['Impact'] == 'HIGH', 'Impact'] = 3
    # curr_news = curr_news.groupby('Date')['Impact'].mean().reset_index()

    df = pd.read_csv(file_path + f'Oanda_{currency_pair}_M5_{years}.csv')
    df.Date = pd.to_datetime(df.Date)
    # df.reset_index(drop=True, inplace=True)
    # df = pd.merge(df, curr_news, how='left', on='Date')
    # df.reset_index(drop=True, inplace=True)
    # df = df.fillna(method='ffill')
    df.dropna(inplace=True)
    df.reset_index(drop=True, inplace=True)

    dfs.append(df)

    df_long = pd.read_csv(file_path + f'Oanda_{currency_pair}_M30_{years}.csv')
    df_long.Date = pd.to_datetime(df_long.Date)
    df_long.dropna(inplace=True)
    df_long.reset_index(drop=True, inplace=True)
    df_longs.append(df_long)

# %%
for df in dfs:
    df['sin_hour'] = np.sin(2 * np.pi * df['Date'].dt.hour / 24)
    # df['cos_hour'] = np.cos(2 * np.pi * df['Date'].dt.hour / 24)
    df['sin_day'] = np.sin(2 * np.pi * df['Date'].dt.day / 7)
    # df['cos_day'] = np.cos(2 * np.pi * df['Date'].dt.day / 7)
    df['sin_month'] = np.sin(2 * np.pi * df['Date'].dt.month / 12)

# %%
def psar(barsdata, iaf=0.02, maxaf=0.2):
    length = len(barsdata)
    high = list(barsdata['Mid_High'])
    low = list(barsdata['Mid_Low'])
    close = list(barsdata['Mid_Close'])
    psar = close[0:len(close)]
    bull = True
    af = iaf
    hp = high[0]
    lp = low[0]
    for i in range(2, length):
        if bull:
            psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
        else:
            psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
        reverse = False
        if bull:
            if low[i] < psar[i]:
                bull = False
                reverse = True
                psar[i] = hp
                lp = low[i]
                af = iaf
        else:
            if high[i] > psar[i]:
                bull = True
                reverse = True
                psar[i] = lp
                hp = high[i]
                af = iaf
        if not reverse:
            if bull:
                if high[i] > hp:
                    hp = high[i]
                    af = min(af + iaf, maxaf)
                if low[i - 1] < psar[i]:
                    psar[i] = low[i - 1]
                if low[i - 2] < psar[i]:
                    psar[i] = low[i - 2]
            else:
                if low[i] < lp:
                    lp = low[i]
                    af = min(af + iaf, maxaf)
                if high[i - 1] > psar[i]:
                    psar[i] = high[i - 1]
                if high[i - 2] > psar[i]:
                    psar[i] = high[i - 2]
    return psar


def atr(high, low, close, lookback=14):
    high_low = high - low
    high_close = np.abs(high - close.shift())
    low_close = np.abs(low - close.shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = np.max(ranges, axis=1)

    return true_range.rolling(lookback).sum() / lookback


def rsi(closes, periods=14):
    close_delta = closes.diff()

    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)
    ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))

    return rsi

  
def adx(high, low, close, lookback=14):
    plus_dm = high.diff()
    minus_dm = low.diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0
    
    tr1 = pd.DataFrame(high - low)
    tr2 = pd.DataFrame(abs(high - close.shift(1)))
    tr3 = pd.DataFrame(abs(low - close.shift(1)))
    frames = [tr1, tr2, tr3]
    tr = pd.concat(frames, axis = 1, join = 'inner').max(axis = 1)
    atr = tr.rolling(lookback).mean()
    
    plus_di = 100 * (plus_dm.ewm(alpha = 1/lookback).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha = 1/lookback).mean() / atr))
    dx = (abs(plus_di - minus_di) / abs(plus_di + minus_di)) * 100
    adx = ((dx.shift(1) * (lookback - 1)) + dx) / lookback
    adx_smooth = adx.ewm(alpha = 1/lookback).mean()

    return adx_smooth


def stoch(high, low, close, lookback=14):
    high_lookback = high.rolling(lookback).max()
    low_lookback = low.rolling(lookback).min()
    slow_k = (close - low_lookback) * 100 / (high_lookback - low_lookback)
    slow_d = slow_k.rolling(3).mean()

    return slow_k, slow_d

def stoch_rsi(data, k_window=3, d_window=3, window=14):
    min_val = data.rolling(window=window, center=False).min()
    max_val = data.rolling(window=window, center=False).max()

    stoch = ((data - min_val) / (max_val - min_val)) * 100

    slow_k = stoch.rolling(window=k_window, center=False).mean()

    slow_d = slow_k.rolling(window=d_window, center=False).mean()

    return slow_k, slow_d

def n_macd(macd, macdsignal, lookback=50):
    n_macd = 2 * (((macd - macd.rolling(lookback).min()) / (macd.rolling(lookback).max() - macd.rolling(lookback).min()))) - 1
    n_macdsignal = 2 * (((macdsignal - macdsignal.rolling(lookback).min()) / (macdsignal.rolling(lookback).max() - macdsignal.rolling(lookback).min()))) - 1

    return n_macd, n_macdsignal

def chop(df, lookback=14):
    atr1 = atr(df, lookback=1)
    high, low = df['Mid_High'], df['Mid_Low']

    chop = np.log10(atr1.rolling(lookback).sum() / (high.rolling(lookback).max() - low.rolling(lookback).min())) / np.log10(lookback)

    return chop

def vo(volume, short_lookback=5, long_lookback=10):
    short_ema =  pd.Series.ewm(volume, span=short_lookback).mean()
    long_ema = pd.Series.ewm(volume, span=long_lookback).mean()

    volume_oscillator = (short_ema - long_ema) / long_ema

    return volume_oscillator

def bar_lengths(bar_lens, window=36):
    return bar_lens.rolling(window=window).mean(), bar_lens.rolling(window=window).std()

def sar_lengths(opens, sars, window=36):
    diffs = abs(opens - sars.shift(1))

    return diffs.rolling(window=window).mean(), diffs.rolling(window=window).std()

def supertrend(barsdata, atr_len=3, mult=3):
    curr_atr = atr(barsdata['Mid_High'], barsdata['Mid_Low'], barsdata['Mid_Close'], lookback=atr_len)
    highs, lows = barsdata['Mid_High'], barsdata['Mid_Low']
    hl2 = (highs + lows) / 2
    final_upperband = upper_band = hl2 + mult * curr_atr
    final_lowerband = lower_band = hl2 - mult * curr_atr

    # initialize Supertrend column to True
    supertrend = [True] * len(df)

    close = barsdata['Mid_Close']
    
    for i in range(1, len(df.index)):
        curr, prev = i, i - 1
        
        # if current close price crosses above upperband
        if close[curr] > final_upperband[prev]:
            supertrend[curr] = True

        # if current close price crosses below lowerband
        elif close[curr] < final_lowerband[prev]:
            supertrend[curr] = False

        # else, the trend continues
        else:
            supertrend[curr] = supertrend[prev]
            
            # adjustment to the final bands
            if supertrend[curr] == True and final_lowerband[curr] < final_lowerband[prev]:
                final_lowerband[curr] = final_lowerband[prev]

            if supertrend[curr] == False and final_upperband[curr] > final_upperband[prev]:
                final_upperband[curr] = final_upperband[prev]

    return supertrend, final_upperband, final_lowerband

# def supertrend(barsdata, atr_len=3, mult=3):
#     curr_atr = atr(barsdata['ha_high'], barsdata['ha_low'], barsdata['ha_close'], lookback=atr_len)
#     highs, lows = barsdata['ha_high'], barsdata['ha_low']
#     hl2 = (highs + lows) / 2
#     final_upperband = upper_band = hl2 + mult * curr_atr
#     final_lowerband = lower_band = hl2 - mult * curr_atr

#     # initialize Supertrend column to True
#     supertrend = [True] * len(df)

#     close = barsdata['ha_close']
    
#     for i in range(1, len(df.index)):
#         curr, prev = i, i - 1
        
#         # if current close price crosses above upperband
#         if close[curr] > final_upperband[prev]:
#             supertrend[curr] = True

#         # if current close price crosses below lowerband
#         elif close[curr] < final_lowerband[prev]:
#             supertrend[curr] = False

#         # else, the trend continues
#         else:
#             supertrend[curr] = supertrend[prev]
            
#             # adjustment to the final bands
#             if supertrend[curr] == True and final_lowerband[curr] < final_lowerband[prev]:
#                 final_lowerband[curr] = final_lowerband[prev]

#             if supertrend[curr] == False and final_upperband[curr] > final_upperband[prev]:
#                 final_upperband[curr] = final_upperband[prev]

#     return supertrend, final_upperband, final_lowerband

def heikin_ashi(opens, highs, lows, closes):
    ha_close = list((opens + highs + lows + closes) / 4)
    ha_opens = []

    opens_list, closes_list = list(opens), list(closes)

    for i in range(len(ha_close)):
        if i == 0:
            ha_opens.append((opens_list[i] + closes_list[i]) / 2)

        else:
            ha_opens.append((ha_opens[i - 1] + ha_close[i - 1]) / 2)

    ha_highs = list(pd.DataFrame({'ha_open': ha_opens, 'ha_close': ha_close, 'high': list(highs)}).max(axis=1))
    ha_lows = list(pd.DataFrame({'ha_open': ha_opens, 'ha_close': ha_close, 'low': list(lows)}).min(axis=1))

    return ha_opens, ha_highs, ha_lows, ha_close

def trend_indicator(opens, highs, lows, closes, ema_period=50, smoothing_period=10):
    ha_open, ha_high, ha_low, ha_close = heikin_ashi(opens, highs, lows, closes)

    ha_o_ema = pd.Series.ewm(pd.DataFrame({'ha_open': ha_open}), span=ema_period).mean()
    ha_h_ema = pd.Series.ewm(pd.DataFrame({'ha_high': ha_high}), span=ema_period).mean()
    ha_l_ema = pd.Series.ewm(pd.DataFrame({'ha_low': ha_low}), span=ema_period).mean()
    ha_c_ema = pd.Series.ewm(pd.DataFrame({'ha_close': ha_close}), span=ema_period).mean()

    return pd.Series.ewm(ha_o_ema, span=smoothing_period).mean(), pd.Series.ewm(ha_h_ema, span=smoothing_period).mean(), pd.Series.ewm(ha_l_ema, span=smoothing_period).mean(), pd.Series.ewm(ha_c_ema, span=smoothing_period).mean()

def qqe_mod(barsdata, rsi_period=6, smoothing=5, qqe_factor=5, qqe2_factor=1.61, threshold=3, mult=0.35, sma_length=50):
    wilders_period = rsi_period * 2 - 1

    curr_rsi = rsi(barsdata, periods=rsi_period)
    rsi_ema = pd.Series.ewm(curr_rsi, span=smoothing).mean()
    atr_rsi = abs(rsi_ema.shift(1) - rsi_ema)
    atr_rsi_ema = pd.Series.ewm(atr_rsi, span=wilders_period).mean()
    dar = pd.Series.ewm(atr_rsi_ema, span=wilders_period).mean() * qqe_factor

    newshortband = rsi_ema + dar
    newlongband = rsi_ema - dar

    rsi_ema_list = list(rsi_ema)

    longband = [0]
    for i in range(1, len(rsi_ema_list)):
        if rsi_ema_list[i - 1] > longband[i - 1] and rsi_ema_list[i] > longband[i - 1]:
            longband.append(max(longband[i - 1],newlongband[i]))

        else:
            longband.append(newlongband[i])

    shortband = [0]
    for i in range(1,len(rsi_ema_list)):
        if rsi_ema_list[i - 1] < shortband[i - 1] and rsi_ema_list[i] < shortband[i - 1]:
            shortband.append(min(shortband[i - 1],newshortband[i]))
            
        else:
            shortband.append(newshortband[i])

    longband = pd.Series(longband)
    shortband = pd.Series(shortband)

    trend = np.where(rsi_ema > longband.shift(1), 1, -1)    
    fastatrrsitl = pd.Series(np.where(trend == 1, longband, shortband))

    basis = (fastatrrsitl - 50).rolling(window=sma_length).mean()
    dev = (fastatrrsitl - 50).rolling(window=sma_length).std() * mult
    upper = basis + dev
    lower = basis - dev

    greenbar1 = rsi_ema - 50 > threshold
    greenbar2 = rsi_ema - 50 > upper
    redbar1 = rsi_ema - 50 < threshold
    redbar2 = rsi_ema - 50 < lower

    # uptrend = np.where((greenbar1 & greenbar2), True, False)
    # downtrend = np.where((redbar1 & redbar2), True, False)

    uptrend = np.where((greenbar2), True, False)
    downtrend = np.where((redbar2), True, False)

    return uptrend, downtrend

def williams_r(highs, lows, closes, length=21, ema_length=15):
    highest_highs = highs.rolling(window=length).max()
    lowest_lows = lows.rolling(window=length).min()

    willy = 100 * (closes - highest_highs) / (highest_highs - lowest_lows)
    willy_ema = pd.Series.ewm(willy, span=ema_length).mean()

    return willy, willy_ema

# %%
# bid_ask_mid_prices_list = []

# for df in dfs:
#     # Add technical indicators (for additional features)
#     df['ha_open'], df['ha_high'], df['ha_low'], df['ha_close'] = heikin_ashi(df['Mid_Open'], df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

#     df['ema200'] = pd.Series.ewm(df['ha_close'], span=200).mean()
#     df['ema100'] = pd.Series.ewm(df['ha_close'], span=100).mean()
#     df['ema50'] = pd.Series.ewm(df['ha_close'], span=50).mean()

#     df['atr'] = atr(df['ha_high'], df['ha_low'], df['ha_close'])
#     df['atr_sma'] = df['atr'].rolling(window=20).mean()
#     df['rsi'] = rsi(df['ha_close'])
#     df['rsi_sma'] = df['rsi'].rolling(50).mean()
#     df['adx'] = adx(df['ha_high'], df['ha_low'], df['ha_close'])
#     df['macd'] = pd.Series.ewm(df['ha_close'], span=12).mean() - pd.Series.ewm(df['ha_close'], span=26).mean()
#     df['macdsignal'] = pd.Series.ewm(df['macd'], span=9).mean()
#     df['slowk_rsi'], df['slowd_rsi'] = stoch_rsi(df['rsi'])

#     df['vo'] = vo(df['Volume'])

#     df['willy'], df['willy_ema'] = williams_r(df['ha_high'], df['ha_low'], df['ha_close'])

#     df['supertrend'], df['supertrend_ub'], df['supertrend_lb'] = supertrend(df)
#     df['ti_o'], df['ti_h'], df['ti_l'], df['ti_c'] = trend_indicator(df['ha_open'], df['ha_high'], df['ha_low'], df['ha_close'])

#     df.dropna(inplace=True)
#     df.reset_index(drop=True, inplace=True)

#     # Extract the bid and ask prices and fractals and remove them from the df
#     bid_ask_mid_prices = df[['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'ha_open', 'ha_high', 'ha_low', 'ha_close']]
#     df.drop(['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'Volume', 'ha_open', 'ha_high', 'ha_low', 'ha_close'], axis=1, inplace=True)
#     bid_ask_mid_prices_list.append(bid_ask_mid_prices)

#     df.dropna(inplace=True)
#     df.reset_index(drop=True, inplace=True)

# for df_long in df_longs:
#     df_long['ha_open'], df_long['ha_high'], df_long['ha_low'], df_long['ha_close'] = heikin_ashi(df_long['Mid_Open'], df_long['Mid_High'], df_long['Mid_Low'], df_long['Mid_Close'])

#     df_long['ema200'] = pd.Series.ewm(df_long['ha_close'], span=200).mean()
#     df_long['ema100'] = pd.Series.ewm(df_long['ha_close'], span=100).mean()
#     df_long['ema50'] = pd.Series.ewm(df_long['ha_close'], span=50).mean()

#     df_long['atr'] = atr(df_long['ha_high'], df_long['ha_low'], df_long['ha_close'])
#     df_long['atr_sma'] = df_long['atr'].rolling(window=20).mean()
#     df_long['rsi'] = rsi(df_long['ha_close'])
#     df_long['rsi_sma'] = df_long['rsi'].rolling(50).mean()
#     df_long['adx'] = adx(df_long['ha_high'], df_long['ha_low'], df_long['ha_close'])
#     df_long['macd'] = pd.Series.ewm(df_long['ha_close'], span=12).mean() - pd.Series.ewm(df_long['ha_close'], span=26).mean()
#     df_long['macdsignal'] = pd.Series.ewm(df_long['macd'], span=9).mean()
#     df_long['slowk_rsi'], df_long['slowd_rsi'] = stoch_rsi(df_long['rsi'])

#     df_long['vo'] = vo(df_long['Volume'])

#     df_long['willy'], df_long['willy_ema'] = williams_r(df_long['ha_high'], df_long['ha_low'], df_long['ha_close'])

#     df_long.dropna(inplace=True)
#     df_long.reset_index(drop=True, inplace=True)

#     df_long.drop(['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'Volume', 'ha_open', 'ha_high', 'ha_low', 'ha_close'], axis=1, inplace=True)

#     df_long.dropna(inplace=True)
#     df_long.reset_index(drop=True, inplace=True)

# %%
bid_ask_mid_prices_list = []

for df in dfs:
    # Add technical indicators (for additional features)
    df['ema200'] = pd.Series.ewm(df['Mid_Close'], span=200).mean()
    df['ema100'] = pd.Series.ewm(df['Mid_Close'], span=100).mean()
    # df['ema50'] = pd.Series.ewm(df['Mid_Close'], span=50).mean()

    df['atr'] = atr(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])
    df['atr_sma'] = df['atr'].rolling(window=20).mean()
    df['rsi'] = rsi(df['Mid_Close'])
    df['rsi_sma'] = df['rsi'].rolling(50).mean()
    df['adx'] = adx(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])
    df['macd'] = pd.Series.ewm(df['Mid_Close'], span=12).mean() - pd.Series.ewm(df['Mid_Close'], span=26).mean()
    df['macdsignal'] = pd.Series.ewm(df['macd'], span=9).mean()
    df['slowk_rsi'], df['slowd_rsi'] = stoch_rsi(df['rsi'])

    df['vo'] = vo(df['Volume'])

    df['willy'], df['willy_ema'] = williams_r(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

    df['supertrend'], df['supertrend_ub'], df['supertrend_lb'] = supertrend(df)
    df['ti_o'], df['ti_h'], df['ti_l'], df['ti_c'] = trend_indicator(df['Mid_Open'], df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

    df.dropna(inplace=True)
    df.reset_index(drop=True, inplace=True)

    # Extract the bid and ask prices and fractals and remove them from the df
    bid_ask_mid_prices = df[['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close']]
    df.drop(['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'Volume'], axis=1, inplace=True)
    bid_ask_mid_prices_list.append(bid_ask_mid_prices)

    df.dropna(inplace=True)
    df.reset_index(drop=True, inplace=True)

for df_long in df_longs:
    df_long['ema200'] = pd.Series.ewm(df_long['Mid_Close'], span=200).mean()
    df_long['ema100'] = pd.Series.ewm(df_long['Mid_Close'], span=100).mean()
    df_long['ema50'] = pd.Series.ewm(df_long['Mid_Close'], span=50).mean()

    df_long['atr'] = atr(df_long['Mid_High'], df_long['Mid_Low'], df_long['Mid_Close'])
    df_long['atr_sma'] = df_long['atr'].rolling(window=20).mean()
    df_long['rsi'] = rsi(df_long['Mid_Close'])
    df_long['rsi_sma'] = df_long['rsi'].rolling(50).mean()
    df_long['adx'] = adx(df_long['Mid_High'], df_long['Mid_Low'], df_long['Mid_Close'])
    df_long['macd'] = pd.Series.ewm(df_long['Mid_Close'], span=12).mean() - pd.Series.ewm(df_long['Mid_Close'], span=26).mean()
    df_long['macdsignal'] = pd.Series.ewm(df_long['macd'], span=9).mean()
    df_long['slowk_rsi'], df_long['slowd_rsi'] = stoch_rsi(df_long['rsi'])

    df_long['vo'] = vo(df_long['Volume'])

    df_long['willy'], df_long['willy_ema'] = williams_r(df_long['Mid_High'], df_long['Mid_Low'], df_long['Mid_Close'])

    df_long.dropna(inplace=True)
    df_long.reset_index(drop=True, inplace=True)

    df_long.drop(['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_High', 'Mid_Low', 'Mid_Close', 'Volume'], axis=1, inplace=True)

    df_long.dropna(inplace=True)
    df_long.reset_index(drop=True, inplace=True)

# %%
look_back_size = 100

# %%
def grab_image_data(subset):
  # rp_transformer = RecurrencePlot()
  # rp_subset = rp_transformer.transform(subset)

  # return rp_subset

  gasf_transformer = GramianAngularField(method='summation')
  gasf_subset = gasf_transformer.transform(subset)

  return gasf_subset

  # gadf_transformer = GramianAngularField(method='difference')
  # gadf_subset = gadf_transformer.transform(subset)

  # return gadf_subset

  # image_data = np.append(rp_subset, gasf_subset, axis=-1)
  # image_data = np.append(image_data, gadf_subset ,axis=-1)
  
  # return image_data

# %%
buys_list = []
sells_list = []
nones_list = []

value_per_pip = 1.0
amounts_per_day = [-0.00008, -0.0001, -0.00012]
spread_cutoff = 0.10
risk_reward_ratio = 1.5

def get_n_units(trade_type, stop_loss, ask_open, bid_open, mid_open, currency_pair):
    _, second = currency_pair.split('_')
  
    pips_to_risk = ask_open - stop_loss if trade_type == 'buy' else stop_loss - bid_open
    pips_to_risk_calc = pips_to_risk * 10000 if second != 'Jpy' else pips_to_risk * 100

    if second == 'Usd':
        per_pip = 0.0001

    else:
        per_pip = 0.0001 / mid_open if second != 'Jpy' else 0.01 / mid_open

    n_units = int(50 / (pips_to_risk_calc * per_pip))

    return n_units

def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee

for idx in range(len(currencies)):
    currency_pair, df, df_long, bid_ask_mid_prices = currencies[idx], dfs[idx], df_longs[idx], bid_ask_mid_prices_list[idx]
    rounding = 3 if 'Jpy' in currency_pair else 5
    buys, sells, nones = [], [], []
    trade, prev_year = None, None

    print(f'RUNNING SIMULATION FOR {currency_pair}...')

    for i in range(look_back_size, len(df)):
        curr_date = df.loc[df.index[i], 'Date']
        if prev_year is None or curr_date.year > prev_year:
            prev_year = curr_date.year
            print(prev_year)
            print(f'Buys: {len(buys)}')
            print(f'Sells: {len(sells)}')
            print(f'Nones: {len(nones)}\n')
        curr_long = df_long.loc[df_long['Date'] < curr_date]
        if len(curr_long) < look_back_size + 1:
            continue
        ema200_2, ema100_2, ema50_2, atr2, rsi2, rsi_sma2, vo2 = df.loc[df.index[i - 2], ['ema200', 'ema100', 'ema50', 'atr', 'rsi', 'rsi_sma', 'vo']]
        ema200_1, ema100_1, ema50_1, atr1, rsi1, rsi_sma1, vo1, adx1, atr_sma1 = df.loc[df.index[i - 1], ['ema200', 'ema100', 'ema50', 'atr', 'rsi', 'rsi_sma', 'vo', 'adx', 'atr_sma']]
        mid_open2, mid_close2, mid_low2, mid_high2 = bid_ask_mid_prices.loc[bid_ask_mid_prices.index[i - 2], ['Mid_Open', 'Mid_Close', 'Mid_Low', 'Mid_High']]
        mid_open1, mid_close1, mid_low1, mid_high1 = bid_ask_mid_prices.loc[bid_ask_mid_prices.index[i - 1], ['Mid_Open', 'Mid_Close', 'Mid_Low', 'Mid_High']]
        curr_ao, curr_bo, curr_mid_open, curr_ask_low, curr_bid_high = bid_ask_mid_prices.loc[bid_ask_mid_prices.index[i], ['Ask_Open', 'Bid_Open', 'Mid_Open', 'Ask_Low', 'Bid_High']]
        slowk_rsi_long, slowd_rsi_long = curr_long.loc[curr_long.index[-2], ['slowk_rsi', 'slowd_rsi']]
        spread = abs(curr_ao - curr_bo)
        enough_volatility = spread <= spread_cutoff

        macd2, macdsignal2 = df.loc[df.index[i - 2], ['macd', 'macdsignal']]
        macd1, macdsignal1 = df.loc[df.index[i - 1], ['macd', 'macdsignal']]
        macd_vals = [0, macd2, macdsignal2, macd1, macdsignal1]

        macd_buy_signal = macd2 < macdsignal2 and macd1 > macdsignal1 and max(macd_vals) == 0
        macd_sell_signal = macd2 > macdsignal2 and macd1 < macdsignal1 and min(macd_vals) == 0

        emas_buy_signal = ema200_1 < mid_close1
        emas_sell_signal = ema200_1 > mid_close1

        # stoch_buy_signal = max([slowk_rsi_long, slowd_rsi_long, 20]) == 20
        # stoch_sell_signal = min([slowk_rsi_long, slowd_rsi_long, 80]) == 80
        # stoch_buy_signal = max([slowk_rsi_long, slowd_rsi_long, 50]) == 50
        # stoch_sell_signal = min([slowk_rsi_long, slowd_rsi_long, 50]) == 50
        # stoch_buy_signal = max([slowk_rsi_long, slowd_rsi_long]) < 80 and (slowk_rsi_long < 50 or slowd_rsi_long < 50)
        # stoch_sell_signal = min([slowk_rsi_long, slowd_rsi_long]) > 20 and (slowk_rsi_long > 50 or slowd_rsi_long > 50)
        stoch_buy_signal = True
        stoch_sell_signal = True

        sideways = adx1 < 25 and atr1 < atr_sma1

        supertrend2 = df.loc[df.index[i - 2], 'supertrend']
        supertrend1, supertrend_ub1, supertrend_lb1 = df.loc[df.index[i - 1], ['supertrend', 'supertrend_ub', 'supertrend_lb']]

        supertrend_buy_signal = supertrend1
        supertrend_sell_signal = not supertrend1

        ti_o1, ti_c1 = df.loc[df.index[i - 1], ['ti_o', 'ti_c']]

        # ti_buy_signal = ti_c1 - ti_o1 > 0
        # ti_sell_signal = ti_c1 - ti_o1 < 0
        ti_buy_signal = True
        ti_sell_signal = True

        willy_vals = list(df.loc[df.index[i - 4:i], 'willy'])
        willy_ema_vals = list(df.loc[df.index[i - 4:i], 'willy_ema'])

        willy_buy, willy_sell = False, False

        for idx in range(len(willy_vals) - 1):
            willy1, willy2, willy_ema1, willy_ema2 = willy_vals[idx], willy_vals[idx +
                                                                                 1], willy_ema_vals[idx], willy_ema_vals[idx + 1]

            if willy1 < willy_ema1 and willy2 > willy_ema2:
                willy_buy = True

            if willy1 > willy_ema1 and willy2 < willy_ema2:
                willy_sell = True

        if trade is None:
            if macd_buy_signal and emas_buy_signal and stoch_buy_signal and not sideways and supertrend_buy_signal and ti_buy_signal and willy_buy:
                open_price = float(curr_ao)
                pullback = float(supertrend_lb1) - spread

                stop_loss = round(pullback, rounding)

                if stop_loss < open_price:
                    curr_pips_to_risk = open_price - stop_loss

                    if spread <= curr_pips_to_risk * spread_cutoff:
                        stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), rounding)

                        n_units = get_n_units('buy', stop_loss, curr_ao, curr_bo, curr_mid_open, currency_pair)

                        trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                        'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                        'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

            elif macd_sell_signal and emas_sell_signal and stoch_sell_signal and not sideways and supertrend_sell_signal and ti_sell_signal and willy_sell:
                open_price = float(curr_bo)
                pullback = float(supertrend_ub1) + spread

                stop_loss = round(pullback, rounding)

                if stop_loss > open_price:
                    curr_pips_to_risk = stop_loss - open_price

                    if spread <= curr_pips_to_risk * spread_cutoff:
                        stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), rounding)

                        n_units = get_n_units('sell', stop_loss, curr_ao, curr_bo, curr_mid_open, currency_pair)

                        trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                                'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

        if trade is not None:
            for j in range(i, len(df)):
                curr_date = df.loc[df.index[j], 'Date']
                curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = bid_ask_mid_prices.loc[bid_ask_mid_prices.index[j], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low', 'Ask_Close']]

                if trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
                    nones.append(trade['start_date']) 

                    trade = None
                    break


                if trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
                    trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
                    day_fees = calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

                    if trade_amount + day_fees > 0:
                        buys.append(trade['start_date'])

                    trade = None
                    break

                if trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
                    nones.append(trade['start_date'])

                    trade = None
                    break

                if trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
                    trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
                    day_fees = calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

                    if trade_amount + day_fees > 0:
                        sells.append(trade['start_date'])

                    trade = None
                    break
    
    buys_list.append(buys)
    sells_list.append(sells)
    nones_list.append(nones)

    print(f'Buys: {len(buys)}')
    print(f'Sells: {len(sells)}')
    print(f'Nones: {len(nones)}\n')
# Out:
# RUNNING SIMULATION FOR Usd_Chf...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 15
# Sells: 6
# Nones: 32
#
# 2018
# Buys: 22
# Sells: 17
# Nones: 63
#
# 2019
# Buys: 29
# Sells: 27
# Nones: 90
#
# 2020
# Buys: 38
# Sells: 38
# Nones: 124
#
# 2021
# Buys: 46
# Sells: 50
# Nones: 156
#
# Buys: 57
# Sells: 59
# Nones: 194
#
# RUNNING SIMULATION FOR Gbp_Usd...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 15
# Sells: 18
# Nones: 50
#
# 2018
# Buys: 30
# Sells: 27
# Nones: 93
#
# 2019
# Buys: 45
# Sells: 40
# Nones: 137
#
# 2020
# Buys: 61
# Sells: 51
# Nones: 189
#
# 2021
# Buys: 75
# Sells: 61
# Nones: 244
#
# Buys: 86
# Sells: 78
# Nones: 284
#
# RUNNING SIMULATION FOR Usd_Cad...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 22
# Sells: 17
# Nones: 33
#
# 2018
# Buys: 35
# Sells: 30
# Nones: 88
#
# 2019
# Buys: 50
# Sells: 41
# Nones: 134
#
# 2020
# Buys: 55
# Sells: 48
# Nones: 157
#
# 2021
# Buys: 67
# Sells: 65
# Nones: 204
#
# Buys: 78
# Sells: 80
# Nones: 250
#
# RUNNING SIMULATION FOR Aud_Usd...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 16
# Sells: 13
# Nones: 50
#
# 2018
# Buys: 29
# Sells: 23
# Nones: 94
#
# 2019
# Buys: 37
# Sells: 42
# Nones: 141
#
# 2020
# Buys: 52
# Sells: 55
# Nones: 160
#
# 2021
# Buys: 62
# Sells: 69
# Nones: 202
#
# Buys: 82
# Sells: 80
# Nones: 248
#
# RUNNING SIMULATION FOR Eur_Usd...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 22
# Sells: 17
# Nones: 62
#
# 2018
# Buys: 36
# Sells: 27
# Nones: 111
#
# 2019
# Buys: 45
# Sells: 44
# Nones: 156
#
# 2020
# Buys: 52
# Sells: 58
# Nones: 200
#
# 2021
# Buys: 69
# Sells: 67
# Nones: 252
#
# Buys: 77
# Sells: 76
# Nones: 299
#
# RUNNING SIMULATION FOR Usd_Jpy...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 11
# Sells: 17
# Nones: 43
#
# 2018
# Buys: 20
# Sells: 31
# Nones: 95
#
# 2019
# Buys: 37
# Sells: 46
# Nones: 134
#
# 2020
# Buys: 44
# Sells: 50
# Nones: 182
#
# 2021
# Buys: 52
# Sells: 59
# Nones: 210
#
# Buys: 60
# Sells: 64
# Nones: 241
#
# RUNNING SIMULATION FOR Nzd_Usd...
# 2016
# Buys: 0
# Sells: 0
# Nones: 0
#
# 2017
# Buys: 7
# Sells: 8
# Nones: 41
#
# 2018
# Buys: 14
# Sells: 18
# Nones: 73
#
# 2019
# Buys: 19
# Sells: 21
# Nones: 90
#
# 2020
# Buys: 21
# Sells: 30
# Nones: 107
#
# 2021
# Buys: 28
# Sells: 36
# Nones: 140
#
# Buys: 37
# Sells: 50
# Nones: 173

# %%
buy_indices_list = []
sell_indices_list = []
nones_indices_list = []

for i in range(len(dfs)):
    buys, sells, nones, df = buys_list[i], sells_list[i], nones_list[i], dfs[i]
    
    buy_indices = [df.index[df['Date'] == curr_date] - 1 for curr_date in buys]
    sell_indices = [df.index[df['Date'] == curr_date] - 1 for curr_date in sells]
    nones_indices = [df.index[df['Date'] == curr_date] - 1 for curr_date in nones]

    buy_indices_list.append(buy_indices)
    sell_indices_list.append(sell_indices)
    nones_indices_list.append(nones_indices)

    print(len(buy_indices))
    print(len(sell_indices))
    print(len(nones_indices))
# Out:
# 57
# 59
# 194
# 86
# 78
# 284
# 78
# 80
# 250
# 82
# 80
# 248
# 77
# 76
# 299
# 60
# 64
# 241
# 37
# 50
# 173

# %%
i = 5000
foo = dfs[0].iloc[i - look_back_size + 1:i + 1, 1:]
curr_date = dfs[0].iloc[i, 0]
curr_long = df_longs[0].loc[df_longs[0]['Date'] < curr_date]
foo2 = curr_long.iloc[-look_back_size - 1:-1, 1:]
foo3 = pd.concat([foo.reset_index(drop=True), foo2.reset_index(drop=True)], axis=1, ignore_index=True)
correct_shape = grab_image_data(foo3).shape
correct_shape
# Out:
# (100, 41, 41)

# %%
def get_sequential_data():
    no_actions = []
    buys = []
    sells = []

    for z in range(len(dfs)):
        df, df_long = dfs[z], df_longs[z]

        buy_indices, sell_indices, nones_indices = buy_indices_list[z], sell_indices_list[z], nones_indices_list[z]

        for i in buy_indices:
            if len(i) == 1:
                i = i[0]
                seq1 = df.iloc[i - look_back_size + 1:i + 1, 1:]
                curr_date = df.iloc[i, 0]
                curr_long = df_long.loc[df_long['Date'] < curr_date]
                seq2 = curr_long.iloc[-look_back_size - 1:-1, 1:]
                seq = pd.concat([seq1.reset_index(drop=True), seq2.reset_index(drop=True)], axis=1, ignore_index=True)

                if seq.shape == correct_shape[:-1] and not seq.isnull().values.any():
                    seq = grab_image_data(seq)
                    buys.append([seq, np.array([0, 1, 0])])

        for i in sell_indices:
            if len(i) == 1:
                i = i[0]
                seq1 = df.iloc[i - look_back_size + 1:i + 1, 1:]
                curr_date = df.iloc[i, 0]
                curr_long = df_long.loc[df_long['Date'] < curr_date]
                seq2 = curr_long.iloc[-look_back_size - 1:-1, 1:]
                seq = pd.concat([seq1.reset_index(drop=True), seq2.reset_index(drop=True)], axis=1, ignore_index=True)

                if seq.shape == correct_shape[:-1] and not seq.isnull().values.any():
                    seq = grab_image_data(seq)
                    sells.append([seq, np.array([0, 0, 1])])

        for i in nones_indices:
            if len(i) == 1:
                i = i[0]
                seq1 = df.iloc[i - look_back_size + 1:i + 1, 1:]
                curr_date = df.iloc[i, 0]
                curr_long = df_long.loc[df_long['Date'] < curr_date]
                seq2 = curr_long.iloc[-look_back_size - 1:-1, 1:]
                seq = pd.concat([seq1.reset_index(drop=True), seq2.reset_index(drop=True)], axis=1, ignore_index=True)

                if seq.shape == correct_shape[:-1] and not seq.isnull().values.any():
                    seq = grab_image_data(seq)
                    no_actions.append([seq, np.array([1, 0, 0])])

    np.random.shuffle(no_actions)
    np.random.shuffle(buys)
    np.random.shuffle(sells)

    lower = min(len(no_actions), len(buys), len(sells))

    no_actions = no_actions[:int(lower * 1.2)]

    sequential_data = no_actions + buys + sells
    np.random.shuffle(sequential_data)

    return sequential_data

# %%
sequential_data = get_sequential_data()

# %%
len(sequential_data)
# Out:
# 1536

# %%
training_proportion = 0.70
train_test_cutoff_index = int(len(sequential_data) * training_proportion)

train_set = sequential_data[0:train_test_cutoff_index]
test_set = sequential_data[train_test_cutoff_index:]

print('Dataset shapes:')
print(len(train_set))
print(len(test_set))
# Out:
# Dataset shapes:
# 1075
# 461

# %%
x_train = []
y_train = []

for seq, target in train_set:
  x_train.append(seq)
  y_train.append(target)

x_test = []
y_test = []

for seq, target in test_set:
  x_test.append(seq)
  y_test.append(target)

x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-376a4cc220ed> in <module>
#       2 y_train = []
#       3
# ----> 4 for seq, target in train_set:
#       5   x_train.append(seq)
#       6   y_train.append(target)
#
# NameError: name 'train_set' is not defined

# %%
x_train.shape
# Out:
# (1075, 100, 41, 41)

# %%
y_train.shape
# Out:
# (1075, 3)

# %%
# scaler = StandardScaler()

# x_train_scaled = scaler.fit_transform(x_train)
# x_test_scaled = scaler.transform(x_test)

# %%
# Number of possible actions to take - determines the output dimension of the
#  neural network
n_actions = 3
input_data_shape = x_train.shape[1:]

model = Sequential()

model.add(Conv2D(filters = 32, kernel_size = (3,3), padding ='Same', 
                 activation ='relu', input_shape = input_data_shape))
model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = 'Same', 
                 activation ='relu'))

model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(n_actions, activation = "softmax"))

# %%
# Hyperparameters
n_epochs = 1000
batch_size = 32
n_steps = len(x_train) // batch_size 
mean_loss = tf.keras.metrics.Mean() 
optimizer = tf.keras.optimizers.Adam()
loss_fn = tf.keras.losses.categorical_crossentropy
metrics = [tf.keras.metrics.CategoricalAccuracy()]
# loss_fn = tf.keras.losses.MeanAbsoluteError
# metrics = [tf.keras.metrics.MeanAbsoluteError()]

# %%
early_stop = EarlyStopping(monitor='val_accuracy', verbose=1, patience=n_epochs)
model_checkpoint = ModelCheckpoint('/Users/mymac/forex_supertrend_macd_cnn', monitor='val_accuracy', save_best_only=True, verbose=1)

optimizer = Adam()

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
history = model.fit(
    x_train, y_train,
    batch_size=batch_size,
    epochs=n_epochs,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, model_checkpoint]
)
# Out:
# Epoch 1/1000
# 34/34 [==============================] - ETA: 0s - loss: 3.2381 - accuracy: 0.4019
# Epoch 00001: val_accuracy improved from -inf to 0.47939, saving model to /Users/mymac/forex_supertrend_macd_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_macd_cnn/assets
# 34/34 [==============================] - 8s 147ms/step - loss: 3.2381 - accuracy: 0.4019 - val_loss: 0.9417 - val_accuracy: 0.4794
# Epoch 2/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.9181 - accuracy: 0.5088
# Epoch 00002: val_accuracy improved from 0.47939 to 0.52711, saving model to /Users/mymac/forex_supertrend_macd_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_macd_cnn/assets
# 34/34 [==============================] - 3s 82ms/step - loss: 0.9181 - accuracy: 0.5088 - val_loss: 0.8334 - val_accuracy: 0.5271
# Epoch 3/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.7870 - accuracy: 0.5786
# Epoch 00003: val_accuracy improved from 0.52711 to 0.56616, saving model to /Users/mymac/forex_supertrend_macd_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_macd_cnn/assets
# 34/34 [==============================] - 3s 78ms/step - loss: 0.7858 - accuracy: 0.5805 - val_loss: 0.7731 - val_accuracy: 0.5662
# Epoch 4/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.7206 - accuracy: 0.6108
# Epoch 00004: val_accuracy improved from 0.56616 to 0.57267, saving model to /Users/mymac/forex_supertrend_macd_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_macd_cnn/assets
# 34/34 [==============================] - 3s 84ms/step - loss: 0.7197 - accuracy: 0.6130 - val_loss: 0.7568 - val_accuracy: 0.5727
# Epoch 5/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.6758 - accuracy: 0.6484
# Epoch 00005: val_accuracy did not improve from 0.57267
# 34/34 [==============================] - 2s 61ms/step - loss: 0.6758 - accuracy: 0.6484 - val_loss: 0.7865 - val_accuracy: 0.5184
# Epoch 6/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.6366 - accuracy: 0.6698
# Epoch 00006: val_accuracy improved from 0.57267 to 0.57484, saving model to /Users/mymac/forex_supertrend_macd_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_macd_cnn/assets
# 34/34 [==============================] - 3s 79ms/step - loss: 0.6366 - accuracy: 0.6698 - val_loss: 0.7254 - val_accuracy: 0.5748
# Epoch 7/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.5868 - accuracy: 0.7263
# Epoch 00007: val_accuracy improved from 0.57484 to 0.57701, saving model to /Users/mymac/forex_supertrend_macd_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_macd_cnn/assets
# 34/34 [==============================] - 3s 78ms/step - loss: 0.5847 - accuracy: 0.7293 - val_loss: 0.7502 - val_accuracy: 0.5770
# Epoch 8/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.5596 - accuracy: 0.7244
# Epoch 00008: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 63ms/step - loss: 0.5582 - accuracy: 0.7256 - val_loss: 0.7649 - val_accuracy: 0.5510
# Epoch 9/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.5035 - accuracy: 0.7547
# Epoch 00009: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 62ms/step - loss: 0.5058 - accuracy: 0.7526 - val_loss: 0.7524 - val_accuracy: 0.5553
# Epoch 10/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.4386 - accuracy: 0.8116
# Epoch 00010: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 61ms/step - loss: 0.4405 - accuracy: 0.8093 - val_loss: 0.7940 - val_accuracy: 0.5488
# Epoch 11/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.4016 - accuracy: 0.8260
# Epoch 00011: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 61ms/step - loss: 0.4016 - accuracy: 0.8260 - val_loss: 0.8563 - val_accuracy: 0.4946
# Epoch 12/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.3349 - accuracy: 0.8617
# Epoch 00012: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 62ms/step - loss: 0.3341 - accuracy: 0.8614 - val_loss: 0.9369 - val_accuracy: 0.5076
# Epoch 13/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.2899 - accuracy: 0.8769
# Epoch 00013: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 66ms/step - loss: 0.2865 - accuracy: 0.8791 - val_loss: 0.9348 - val_accuracy: 0.5401
# Epoch 14/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.8977
# Epoch 00014: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 64ms/step - loss: 0.2524 - accuracy: 0.8977 - val_loss: 1.0152 - val_accuracy: 0.5445
# Epoch 15/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.2373 - accuracy: 0.9015
# Epoch 00015: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 60ms/step - loss: 0.2386 - accuracy: 0.9005 - val_loss: 1.2584 - val_accuracy: 0.4577
# Epoch 16/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.1864 - accuracy: 0.9299
# Epoch 00016: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 60ms/step - loss: 0.1856 - accuracy: 0.9302 - val_loss: 1.1719 - val_accuracy: 0.4946
# Epoch 17/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9377
# Epoch 00017: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 64ms/step - loss: 0.1679 - accuracy: 0.9377 - val_loss: 1.3756 - val_accuracy: 0.5206
# Epoch 18/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.1355 - accuracy: 0.9508
# Epoch 00018: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 63ms/step - loss: 0.1357 - accuracy: 0.9507 - val_loss: 1.2323 - val_accuracy: 0.5597
# Epoch 19/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.1222 - accuracy: 0.9536
# Epoch 00019: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 64ms/step - loss: 0.1205 - accuracy: 0.9544 - val_loss: 1.4154 - val_accuracy: 0.5401
# Epoch 20/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.1219 - accuracy: 0.9536
# Epoch 00020: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 61ms/step - loss: 0.1203 - accuracy: 0.9544 - val_loss: 1.4069 - val_accuracy: 0.4989
# Epoch 21/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9740
# Epoch 00021: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0776 - accuracy: 0.9740 - val_loss: 1.5396 - val_accuracy: 0.5553
# Epoch 22/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9758
# Epoch 00022: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0707 - accuracy: 0.9758 - val_loss: 1.5388 - val_accuracy: 0.5380
# Epoch 23/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0698 - accuracy: 0.9725
# Epoch 00023: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 68ms/step - loss: 0.0693 - accuracy: 0.9730 - val_loss: 1.6205 - val_accuracy: 0.5662
# Epoch 24/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0580 - accuracy: 0.9754
# Epoch 00024: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 3s 77ms/step - loss: 0.0576 - accuracy: 0.9758 - val_loss: 1.6752 - val_accuracy: 0.5293
# Epoch 25/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9767
# Epoch 00025: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0609 - accuracy: 0.9767 - val_loss: 1.6365 - val_accuracy: 0.5423
# Epoch 26/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9898
# Epoch 00026: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0401 - accuracy: 0.9898 - val_loss: 1.9108 - val_accuracy: 0.5618
# Epoch 27/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9935
# Epoch 00027: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 68ms/step - loss: 0.0254 - accuracy: 0.9935 - val_loss: 1.8044 - val_accuracy: 0.5184
# Epoch 28/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9823
# Epoch 00028: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 67ms/step - loss: 0.0388 - accuracy: 0.9823 - val_loss: 1.7626 - val_accuracy: 0.5336
# Epoch 29/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0353 - accuracy: 0.9915
# Epoch 00029: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0348 - accuracy: 0.9916 - val_loss: 1.9264 - val_accuracy: 0.5401
# Epoch 30/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9823
# Epoch 00030: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0651 - accuracy: 0.9823 - val_loss: 1.5707 - val_accuracy: 0.5423
# Epoch 31/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9823
# Epoch 00031: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 3s 85ms/step - loss: 0.0473 - accuracy: 0.9823 - val_loss: 1.8218 - val_accuracy: 0.4967
# Epoch 32/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9935
# Epoch 00032: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0247 - accuracy: 0.9935 - val_loss: 2.0337 - val_accuracy: 0.5141
# Epoch 33/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0243 - accuracy: 0.9934
# Epoch 00033: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0246 - accuracy: 0.9926 - val_loss: 2.1655 - val_accuracy: 0.5597
# Epoch 34/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9860
# Epoch 00034: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0365 - accuracy: 0.9860 - val_loss: 2.0532 - val_accuracy: 0.5401
# Epoch 35/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9870
# Epoch 00035: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0368 - accuracy: 0.9870 - val_loss: 2.1339 - val_accuracy: 0.5510
# Epoch 36/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 0.9934
# Epoch 00036: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0213 - accuracy: 0.9935 - val_loss: 2.3991 - val_accuracy: 0.5271
# Epoch 37/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9805
# Epoch 00037: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 66ms/step - loss: 0.0488 - accuracy: 0.9805 - val_loss: 2.0634 - val_accuracy: 0.5358
# Epoch 38/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9860
# Epoch 00038: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0551 - accuracy: 0.9860 - val_loss: 1.6935 - val_accuracy: 0.5597
# Epoch 39/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9916
# Epoch 00039: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 3s 82ms/step - loss: 0.0333 - accuracy: 0.9916 - val_loss: 2.4680 - val_accuracy: 0.5249
# Epoch 40/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9924
# Epoch 00040: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 69ms/step - loss: 0.0228 - accuracy: 0.9916 - val_loss: 2.2153 - val_accuracy: 0.5358
# Epoch 41/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.9905
# Epoch 00041: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 68ms/step - loss: 0.0287 - accuracy: 0.9907 - val_loss: 2.2729 - val_accuracy: 0.5206
# Epoch 42/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9833
# Epoch 00042: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0486 - accuracy: 0.9833 - val_loss: 2.3726 - val_accuracy: 0.5098
# Epoch 43/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9674
# Epoch 00043: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 65ms/step - loss: 0.0839 - accuracy: 0.9674 - val_loss: 1.7430 - val_accuracy: 0.5315
# Epoch 44/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9870
# Epoch 00044: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 66ms/step - loss: 0.0397 - accuracy: 0.9870 - val_loss: 2.0631 - val_accuracy: 0.5510
# Epoch 45/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9877
# Epoch 00045: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0436 - accuracy: 0.9879 - val_loss: 2.3130 - val_accuracy: 0.4989
# Epoch 46/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0416 - accuracy: 0.9848
# Epoch 00046: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0409 - accuracy: 0.9851 - val_loss: 1.8322 - val_accuracy: 0.5293
# Epoch 47/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9953
# Epoch 00047: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0168 - accuracy: 0.9953 - val_loss: 2.4367 - val_accuracy: 0.5141
# Epoch 48/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9915
# Epoch 00048: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0216 - accuracy: 0.9916 - val_loss: 2.2998 - val_accuracy: 0.5488
# Epoch 49/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9934
# Epoch 00049: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0151 - accuracy: 0.9935 - val_loss: 2.7055 - val_accuracy: 0.5445
# Epoch 50/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9972
# Epoch 00050: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0118 - accuracy: 0.9972 - val_loss: 2.4928 - val_accuracy: 0.5358
# Epoch 51/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9981
# Epoch 00051: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 65ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 2.6896 - val_accuracy: 0.5336
# Epoch 52/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9972
# Epoch 00052: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 2.6582 - val_accuracy: 0.5293
# Epoch 53/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0163 - accuracy: 0.9953
# Epoch 00053: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 65ms/step - loss: 0.0160 - accuracy: 0.9953 - val_loss: 2.7344 - val_accuracy: 0.5401
# Epoch 54/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9963
# Epoch 00054: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 62ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 2.6265 - val_accuracy: 0.5380
# Epoch 55/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0153 - accuracy: 0.9934
# Epoch 00055: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 60ms/step - loss: 0.0152 - accuracy: 0.9935 - val_loss: 2.6814 - val_accuracy: 0.5575
# Epoch 56/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9926
# Epoch 00056: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0175 - accuracy: 0.9926 - val_loss: 2.7800 - val_accuracy: 0.5380
# Epoch 57/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0151 - accuracy: 0.9953
# Epoch 00057: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 2.2925 - val_accuracy: 0.5488
# Epoch 58/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9972
# Epoch 00058: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 61ms/step - loss: 0.0144 - accuracy: 0.9972 - val_loss: 2.4826 - val_accuracy: 0.5575
# Epoch 59/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9962
# Epoch 00059: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 66ms/step - loss: 0.0130 - accuracy: 0.9963 - val_loss: 2.4184 - val_accuracy: 0.5662
# Epoch 60/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9907
# Epoch 00060: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 64ms/step - loss: 0.0216 - accuracy: 0.9907 - val_loss: 2.5516 - val_accuracy: 0.5228
# Epoch 61/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9888
# Epoch 00061: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0341 - accuracy: 0.9888 - val_loss: 2.4553 - val_accuracy: 0.5618
# Epoch 62/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0156 - accuracy: 0.9962
# Epoch 00062: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0154 - accuracy: 0.9963 - val_loss: 2.6392 - val_accuracy: 0.5358
# Epoch 63/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0202 - accuracy: 0.9934
# Epoch 00063: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 2.2769 - val_accuracy: 0.5228
# Epoch 64/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9924
# Epoch 00064: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0227 - accuracy: 0.9916 - val_loss: 2.6165 - val_accuracy: 0.5184
# Epoch 65/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9905
# Epoch 00065: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0203 - accuracy: 0.9907 - val_loss: 2.8627 - val_accuracy: 0.5401
# Epoch 66/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9991
# Epoch 00066: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0052 - accuracy: 0.9991 - val_loss: 3.1131 - val_accuracy: 0.5488
# Epoch 67/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9981
# Epoch 00067: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 3.1537 - val_accuracy: 0.5423
# Epoch 68/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 0.9924
# Epoch 00068: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0216 - accuracy: 0.9926 - val_loss: 2.6563 - val_accuracy: 0.5423
# Epoch 69/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9972
# Epoch 00069: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0148 - accuracy: 0.9963 - val_loss: 2.9878 - val_accuracy: 0.5249
# Epoch 70/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0236 - accuracy: 0.9915
# Epoch 00070: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0237 - accuracy: 0.9916 - val_loss: 2.6039 - val_accuracy: 0.5401
# Epoch 71/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9767
# Epoch 00071: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0550 - accuracy: 0.9767 - val_loss: 2.3183 - val_accuracy: 0.5336
# Epoch 72/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9924
# Epoch 00072: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0204 - accuracy: 0.9926 - val_loss: 2.8862 - val_accuracy: 0.5662
# Epoch 73/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9763
# Epoch 00073: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0653 - accuracy: 0.9767 - val_loss: 2.3920 - val_accuracy: 0.5488
# Epoch 74/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0242 - accuracy: 0.9934
# Epoch 00074: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0240 - accuracy: 0.9935 - val_loss: 2.7240 - val_accuracy: 0.5466
# Epoch 75/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9934
# Epoch 00075: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0176 - accuracy: 0.9935 - val_loss: 2.6677 - val_accuracy: 0.5597
# Epoch 76/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0371 - accuracy: 0.9905
# Epoch 00076: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0365 - accuracy: 0.9907 - val_loss: 2.7636 - val_accuracy: 0.5315
# Epoch 77/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9773
# Epoch 00077: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0526 - accuracy: 0.9777 - val_loss: 2.7242 - val_accuracy: 0.5358
# Epoch 78/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0334 - accuracy: 0.9858
# Epoch 00078: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0329 - accuracy: 0.9860 - val_loss: 2.1733 - val_accuracy: 0.5380
# Epoch 79/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9944
# Epoch 00079: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0257 - accuracy: 0.9944 - val_loss: 2.5829 - val_accuracy: 0.5228
# Epoch 80/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9943
# Epoch 00080: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 58ms/step - loss: 0.0175 - accuracy: 0.9944 - val_loss: 3.5896 - val_accuracy: 0.5445
# Epoch 81/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 0.9943
# Epoch 00081: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0170 - accuracy: 0.9944 - val_loss: 3.2737 - val_accuracy: 0.5401
# Epoch 82/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 0.9953
# Epoch 00082: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0165 - accuracy: 0.9953 - val_loss: 2.8210 - val_accuracy: 0.5401
# Epoch 83/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9915
# Epoch 00083: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0180 - accuracy: 0.9916 - val_loss: 3.1379 - val_accuracy: 0.5445
# Epoch 84/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9972
# Epoch 00084: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 3.2196 - val_accuracy: 0.5380
# Epoch 85/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9962
# Epoch 00085: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0124 - accuracy: 0.9953 - val_loss: 3.1858 - val_accuracy: 0.5662
# Epoch 86/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9972
# Epoch 00086: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 3.7424 - val_accuracy: 0.5466
# Epoch 87/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9953
# Epoch 00087: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0140 - accuracy: 0.9944 - val_loss: 2.6516 - val_accuracy: 0.5206
# Epoch 88/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0465 - accuracy: 0.9905
# Epoch 00088: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0457 - accuracy: 0.9907 - val_loss: 2.6131 - val_accuracy: 0.5358
# Epoch 89/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9886
# Epoch 00089: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0299 - accuracy: 0.9888 - val_loss: 3.1149 - val_accuracy: 0.5401
# Epoch 90/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9981
# Epoch 00090: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0080 - accuracy: 0.9981 - val_loss: 2.8741 - val_accuracy: 0.5445
# Epoch 91/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9962
# Epoch 00091: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 2.9387 - val_accuracy: 0.5466
# Epoch 92/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.9934
# Epoch 00092: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0260 - accuracy: 0.9935 - val_loss: 3.0415 - val_accuracy: 0.5445
# Epoch 93/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0236 - accuracy: 0.9915
# Epoch 00093: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0233 - accuracy: 0.9916 - val_loss: 2.6294 - val_accuracy: 0.5358
# Epoch 94/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9991
# Epoch 00094: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0069 - accuracy: 0.9991 - val_loss: 3.8289 - val_accuracy: 0.5640
# Epoch 95/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9991
# Epoch 00095: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0049 - accuracy: 0.9991 - val_loss: 4.1222 - val_accuracy: 0.5531
# Epoch 96/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9972
# Epoch 00096: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0052 - accuracy: 0.9972 - val_loss: 3.6619 - val_accuracy: 0.5401
# Epoch 97/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9991
# Epoch 00097: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 3.5331 - val_accuracy: 0.5510
# Epoch 98/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9991
# Epoch 00098: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 4.1377 - val_accuracy: 0.5488
# Epoch 99/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9991
# Epoch 00099: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 3.9819 - val_accuracy: 0.5401
# Epoch 100/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0115 - accuracy: 0.9972
# Epoch 00100: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0114 - accuracy: 0.9972 - val_loss: 2.9756 - val_accuracy: 0.5315
# Epoch 101/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9972
# Epoch 00101: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 3.7786 - val_accuracy: 0.5380
# Epoch 102/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0141 - accuracy: 0.9953
# Epoch 00102: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0138 - accuracy: 0.9953 - val_loss: 3.8103 - val_accuracy: 0.5618
# Epoch 103/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0151 - accuracy: 0.9972
# Epoch 00103: val_accuracy did not improve from 0.57701
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0148 - accuracy: 0.9972 - val_loss: 3.5644 - val_accuracy: 0.5076
# Epoch 104/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9934
# Epoch 00104: val_accuracy improved from 0.57701 to 0.58785, saving model to /Users/mymac/forex_supertrend_macd_cnn
# INFO:tensorflow:Assets written to: /Users/mymac/forex_supertrend_macd_cnn/assets
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0226 - accuracy: 0.9935 - val_loss: 4.4434 - val_accuracy: 0.5879
# Epoch 105/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9858
# Epoch 00105: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0408 - accuracy: 0.9860 - val_loss: 2.7570 - val_accuracy: 0.5748
# Epoch 106/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9915
# Epoch 00106: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0207 - accuracy: 0.9916 - val_loss: 3.2642 - val_accuracy: 0.5705
# Epoch 107/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9886
# Epoch 00107: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0318 - accuracy: 0.9888 - val_loss: 3.9415 - val_accuracy: 0.4859
# Epoch 108/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0446 - accuracy: 0.9896
# Epoch 00108: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0439 - accuracy: 0.9898 - val_loss: 3.3692 - val_accuracy: 0.5336
# Epoch 109/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9972
# Epoch 00109: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0071 - accuracy: 0.9972 - val_loss: 3.3037 - val_accuracy: 0.5531
# Epoch 110/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9981
# Epoch 00110: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 3.7934 - val_accuracy: 0.5445
# Epoch 111/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 0.9972
# Epoch 00111: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0122 - accuracy: 0.9972 - val_loss: 3.6180 - val_accuracy: 0.5315
# Epoch 112/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9981
# Epoch 00112: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 3.6024 - val_accuracy: 0.5531
# Epoch 113/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9962
# Epoch 00113: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0107 - accuracy: 0.9953 - val_loss: 3.0641 - val_accuracy: 0.5466
# Epoch 114/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9877
# Epoch 00114: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0513 - accuracy: 0.9879 - val_loss: 2.7921 - val_accuracy: 0.5618
# Epoch 115/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9896
# Epoch 00115: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0305 - accuracy: 0.9898 - val_loss: 3.0648 - val_accuracy: 0.5423
# Epoch 116/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 0.9972
# Epoch 00116: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0110 - accuracy: 0.9972 - val_loss: 3.2281 - val_accuracy: 0.5184
# Epoch 117/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9943
# Epoch 00117: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 57ms/step - loss: 0.0130 - accuracy: 0.9944 - val_loss: 2.8910 - val_accuracy: 0.5466
# Epoch 118/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0208 - accuracy: 0.9915
# Epoch 00118: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0205 - accuracy: 0.9916 - val_loss: 3.1047 - val_accuracy: 0.5662
# Epoch 119/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9943
# Epoch 00119: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0202 - accuracy: 0.9944 - val_loss: 3.1034 - val_accuracy: 0.5683
# Epoch 120/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9953
# Epoch 00120: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0108 - accuracy: 0.9953 - val_loss: 3.2631 - val_accuracy: 0.5510
# Epoch 121/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9926
# Epoch 00121: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0293 - accuracy: 0.9926 - val_loss: 3.2609 - val_accuracy: 0.5553
# Epoch 122/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9943
# Epoch 00122: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0168 - accuracy: 0.9944 - val_loss: 3.5102 - val_accuracy: 0.5662
# Epoch 123/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9991
# Epoch 00123: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0074 - accuracy: 0.9991 - val_loss: 3.5589 - val_accuracy: 0.5575
# Epoch 124/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9972
# Epoch 00124: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 3.4955 - val_accuracy: 0.5488
# Epoch 125/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9972
# Epoch 00125: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0061 - accuracy: 0.9972 - val_loss: 4.0614 - val_accuracy: 0.5423
# Epoch 126/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9972
# Epoch 00126: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0070 - accuracy: 0.9963 - val_loss: 3.4714 - val_accuracy: 0.5466
# Epoch 127/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9981
# Epoch 00127: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 3.5942 - val_accuracy: 0.5662
# Epoch 128/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9972
# Epoch 00128: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 3.7052 - val_accuracy: 0.5575
# Epoch 129/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9991
# Epoch 00129: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 3.6134 - val_accuracy: 0.5401
# Epoch 130/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.7924 - val_accuracy: 0.5445
# Epoch 131/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 0.9972
# Epoch 00131: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 4.3491 - val_accuracy: 0.5553
# Epoch 132/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9934
# Epoch 00132: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0311 - accuracy: 0.9935 - val_loss: 4.5595 - val_accuracy: 0.5423
# Epoch 133/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9792
# Epoch 00133: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0653 - accuracy: 0.9795 - val_loss: 3.6617 - val_accuracy: 0.5445
# Epoch 134/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9877
# Epoch 00134: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0225 - accuracy: 0.9879 - val_loss: 3.2322 - val_accuracy: 0.5228
# Epoch 135/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0363 - accuracy: 0.9905
# Epoch 00135: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0357 - accuracy: 0.9907 - val_loss: 3.1473 - val_accuracy: 0.5249
# Epoch 136/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9905
# Epoch 00136: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0292 - accuracy: 0.9907 - val_loss: 3.2937 - val_accuracy: 0.5380
# Epoch 137/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9962
# Epoch 00137: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0066 - accuracy: 0.9963 - val_loss: 3.3985 - val_accuracy: 0.5401
# Epoch 138/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9962
# Epoch 00138: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 3.0564 - val_accuracy: 0.5293
# Epoch 139/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9981
# Epoch 00139: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 3.4739 - val_accuracy: 0.5358
# Epoch 140/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9953
# Epoch 00140: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 3.3438 - val_accuracy: 0.5531
# Epoch 141/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9943
# Epoch 00141: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0180 - accuracy: 0.9944 - val_loss: 3.1817 - val_accuracy: 0.5531
# Epoch 142/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0115 - accuracy: 0.9953
# Epoch 00142: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0113 - accuracy: 0.9953 - val_loss: 3.1365 - val_accuracy: 0.5770
# Epoch 143/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9991
# Epoch 00143: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 3.5237 - val_accuracy: 0.5553
# Epoch 144/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9981
# Epoch 00144: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0026 - accuracy: 0.9981 - val_loss: 3.7360 - val_accuracy: 0.5597
# Epoch 145/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9991
# Epoch 00145: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 3.9059 - val_accuracy: 0.5618
# Epoch 146/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.9739 - val_accuracy: 0.5531
# Epoch 147/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9981
# Epoch 00147: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 3.9343 - val_accuracy: 0.5380
# Epoch 148/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9991
# Epoch 00148: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 4.1789 - val_accuracy: 0.5640
# Epoch 149/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00149: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 4.3425 - val_accuracy: 0.5553
# Epoch 150/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9981
# Epoch 00150: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 3.7834 - val_accuracy: 0.5488
# Epoch 151/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9991
# Epoch 00151: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 3.5591 - val_accuracy: 0.5510
# Epoch 152/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9981
# Epoch 00152: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 3.7195 - val_accuracy: 0.5315
# Epoch 153/1000
# 33/34 [============================>.] - ETA: 0s - loss: 8.8340e-04 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 54ms/step - loss: 8.7210e-04 - accuracy: 1.0000 - val_loss: 3.7144 - val_accuracy: 0.5445
# Epoch 154/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0096 - accuracy: 0.9962
# Epoch 00154: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 3.6197 - val_accuracy: 0.5488
# Epoch 155/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9981
# Epoch 00155: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0048 - accuracy: 0.9981 - val_loss: 4.2085 - val_accuracy: 0.5445
# Epoch 156/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9972
# Epoch 00156: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 3.5456 - val_accuracy: 0.5705
# Epoch 157/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9953
# Epoch 00157: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0105 - accuracy: 0.9953 - val_loss: 4.1039 - val_accuracy: 0.5249
# Epoch 158/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 4.2587 - val_accuracy: 0.5640
# Epoch 159/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9991
# Epoch 00159: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 4.3466 - val_accuracy: 0.5466
# Epoch 160/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9972
# Epoch 00160: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0058 - accuracy: 0.9972 - val_loss: 4.4062 - val_accuracy: 0.5141
# Epoch 161/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9943
# Epoch 00161: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0110 - accuracy: 0.9944 - val_loss: 4.6401 - val_accuracy: 0.5618
# Epoch 162/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9886
# Epoch 00162: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0372 - accuracy: 0.9888 - val_loss: 5.0512 - val_accuracy: 0.5466
# Epoch 163/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 0.9934
# Epoch 00163: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0214 - accuracy: 0.9935 - val_loss: 3.7778 - val_accuracy: 0.5336
# Epoch 164/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0216 - accuracy: 0.9953
# Epoch 00164: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0212 - accuracy: 0.9953 - val_loss: 3.8315 - val_accuracy: 0.5597
# Epoch 165/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9877
# Epoch 00165: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0343 - accuracy: 0.9879 - val_loss: 3.9210 - val_accuracy: 0.5705
# Epoch 166/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9962
# Epoch 00166: val_accuracy did not improve from 0.58785
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0124 - accuracy: 0.9963 - val_loss: 3.8334 - val_accuracy: 0.5488
# Epoch 167/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9962
# ...
# Epoch 593/1000
# 33/34 [============================>.] - ETA: 0s - loss: 8.8950e-06 - accuracy: 1.0000
# Epoch 00593: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 8.7417e-06 - accuracy: 1.0000 - val_loss: 9.5698 - val_accuracy: 0.5879
# Epoch 594/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9991
# Epoch 00594: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0011 - accuracy: 0.9991 - val_loss: 9.6910 - val_accuracy: 0.5792
# Epoch 595/1000
# 33/34 [============================>.] - ETA: 0s - loss: 6.0826e-04 - accuracy: 1.0000
# Epoch 00595: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 5.9751e-04 - accuracy: 1.0000 - val_loss: 9.9078 - val_accuracy: 0.5640
# Epoch 596/1000
# 33/34 [============================>.] - ETA: 0s - loss: 4.3193e-04 - accuracy: 1.0000
# Epoch 00596: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 4.2430e-04 - accuracy: 1.0000 - val_loss: 9.7634 - val_accuracy: 0.5640
# Epoch 597/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9981
# Epoch 00597: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0043 - accuracy: 0.9981 - val_loss: 9.0240 - val_accuracy: 0.5510
# Epoch 598/1000
# 33/34 [============================>.] - ETA: 0s - loss: 8.2917e-04 - accuracy: 1.0000
# Epoch 00598: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 8.1452e-04 - accuracy: 1.0000 - val_loss: 10.1452 - val_accuracy: 0.5488
# Epoch 599/1000
# 34/34 [==============================] - ETA: 0s - loss: 1.5743e-05 - accuracy: 1.0000
# Epoch 00599: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 55ms/step - loss: 1.5743e-05 - accuracy: 1.0000 - val_loss: 10.2581 - val_accuracy: 0.5510
# Epoch 600/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9991
# Epoch 00600: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0016 - accuracy: 0.9991 - val_loss: 11.7079 - val_accuracy: 0.5770
# Epoch 601/1000
# 33/34 [============================>.] - ETA: 0s - loss: 2.5233e-06 - accuracy: 1.0000
# Epoch 00601: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 2.4787e-06 - accuracy: 1.0000 - val_loss: 12.0002 - val_accuracy: 0.5748
# Epoch 602/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9991
# Epoch 00602: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 9.8649e-04 - accuracy: 0.9991 - val_loss: 11.8744 - val_accuracy: 0.5618
# Epoch 603/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9991
# Epoch 00603: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0178 - accuracy: 0.9991 - val_loss: 11.0398 - val_accuracy: 0.5423
# Epoch 604/1000
# 33/34 [============================>.] - ETA: 0s - loss: 6.2919e-07 - accuracy: 1.0000
# Epoch 00604: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 6.1807e-07 - accuracy: 1.0000 - val_loss: 11.0673 - val_accuracy: 0.5423
# Epoch 605/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0140 - accuracy: 0.9981
# Epoch 00605: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0138 - accuracy: 0.9981 - val_loss: 11.1858 - val_accuracy: 0.5553
# Epoch 606/1000
# 33/34 [============================>.] - ETA: 0s - loss: 3.9817e-06 - accuracy: 1.0000
# Epoch 00606: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 54ms/step - loss: 3.9113e-06 - accuracy: 1.0000 - val_loss: 9.4950 - val_accuracy: 0.5531
# Epoch 607/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9991
# Epoch 00607: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 10.3850 - val_accuracy: 0.5727
# Epoch 608/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 0.9972
# Epoch 00608: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0188 - accuracy: 0.9972 - val_loss: 10.2839 - val_accuracy: 0.5900
# Epoch 609/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9934
# Epoch 00609: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0303 - accuracy: 0.9935 - val_loss: 10.4439 - val_accuracy: 0.5488
# Epoch 610/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9981
# Epoch 00610: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0357 - accuracy: 0.9981 - val_loss: 13.6057 - val_accuracy: 0.5640
# Epoch 611/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0426 - accuracy: 0.9943
# Epoch 00611: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0418 - accuracy: 0.9944 - val_loss: 9.1964 - val_accuracy: 0.5380
# Epoch 612/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9953
# Epoch 00612: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0319 - accuracy: 0.9953 - val_loss: 10.4311 - val_accuracy: 0.5597
# Epoch 613/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9972
# Epoch 00613: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 9.4244 - val_accuracy: 0.5510
# Epoch 614/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 0.9972
# Epoch 00614: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0235 - accuracy: 0.9963 - val_loss: 10.1631 - val_accuracy: 0.5640
# Epoch 615/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9935
# Epoch 00615: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0587 - accuracy: 0.9935 - val_loss: 15.2643 - val_accuracy: 0.5445
# Epoch 616/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9962
# Epoch 00616: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0357 - accuracy: 0.9963 - val_loss: 10.1022 - val_accuracy: 0.5683
# Epoch 617/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0204 - accuracy: 0.9943
# Epoch 00617: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0200 - accuracy: 0.9944 - val_loss: 9.2189 - val_accuracy: 0.5445
# Epoch 618/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0334 - accuracy: 0.9981
# Epoch 00618: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0329 - accuracy: 0.9981 - val_loss: 11.1697 - val_accuracy: 0.5510
# Epoch 619/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9991
# Epoch 00619: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0106 - accuracy: 0.9991 - val_loss: 10.8447 - val_accuracy: 0.5401
# Epoch 620/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9943
# Epoch 00620: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0533 - accuracy: 0.9944 - val_loss: 13.4323 - val_accuracy: 0.5727
# Epoch 621/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9953
# Epoch 00621: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0390 - accuracy: 0.9953 - val_loss: 10.1504 - val_accuracy: 0.5423
# Epoch 622/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0464 - accuracy: 0.9943
# Epoch 00622: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0456 - accuracy: 0.9944 - val_loss: 11.0064 - val_accuracy: 0.5618
# Epoch 623/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9962
# Epoch 00623: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0130 - accuracy: 0.9963 - val_loss: 10.5380 - val_accuracy: 0.5727
# Epoch 624/1000
# 33/34 [============================>.] - ETA: 0s - loss: 1.7954e-05 - accuracy: 1.0000
# Epoch 00624: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 1.7638e-05 - accuracy: 1.0000 - val_loss: 10.1279 - val_accuracy: 0.5640
# Epoch 625/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9991
# Epoch 00625: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 11.4045 - val_accuracy: 0.5466
# Epoch 626/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9981
# Epoch 00626: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 9.6429 - val_accuracy: 0.5618
# Epoch 627/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0210 - accuracy: 0.9943
# Epoch 00627: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0207 - accuracy: 0.9944 - val_loss: 11.4843 - val_accuracy: 0.5466
# Epoch 628/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9991
# Epoch 00628: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0080 - accuracy: 0.9991 - val_loss: 11.3560 - val_accuracy: 0.5618
# Epoch 629/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9981
# Epoch 00629: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 57ms/step - loss: 0.0142 - accuracy: 0.9981 - val_loss: 11.0029 - val_accuracy: 0.5423
# Epoch 630/1000
# 33/34 [============================>.] - ETA: 0s - loss: 2.0745e-05 - accuracy: 1.0000
# Epoch 00630: val_accuracy did not improve from 0.60521
# 34/34 [==============================] - 2s 55ms/step - loss: 2.0425e-05 - accuracy: 1.0000 - val_loss: 11.2843 - val_accuracy: 0.5358
# Epoch 631/1000
# 33/34 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9991
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-7af7dcac3212> in <module>
# ----> 1 history = model.fit(
#       2     x_train, y_train,
#       3     batch_size=batch_size,
#       4     epochs=n_epochs,
#       5     validation_data=(x_test, y_test),
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1250                 model=self,
#    1251                 steps_per_execution=self._steps_per_execution)
# -> 1252           val_logs = self.evaluate(
#    1253               x=val_x,
#    1254               y=val_y,
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1535             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1536               callbacks.on_test_batch_begin(step)
# -> 1537               tmp_logs = self.test_function(iterator)
#    1538               if data_handler.should_sync:
#    1539                 context.async_wait()
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     947       # In this case we have not created variables on the first call. So we can
#     948       # run the first trace but we should fail if variables are created.
# --> 949       results = self._stateful_fn(*args, **kwds)
#     950       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     951         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~/miniforge3/envs/forex/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
