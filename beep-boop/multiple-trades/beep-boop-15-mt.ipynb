# %%
import talib
import numpy as np
import pandas as pd
import random
from collections import deque

# %%
file_path = '/Users/mymac/Google_Drive/Forex_Robot/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
df = pd.read_csv(file_path + 'Oanda_Gbp_Usd_M15_2020-2021.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

df_small = pd.read_csv(file_path + 'Oanda_Gbp_Usd_M5_2020-2021.csv')
df_small.Date = pd.to_datetime(df_small.Date)
df_small.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
print('-' * 75)
print('-' * 75)
print('-' * 75)
print(df_small.head())
print('-' * 75)
print(df_small.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2020-07-30 07:00:00   1.29543   1.29607  1.29505    1.29559   1.29562
# 1 2020-07-30 07:15:00   1.29561   1.29649  1.29501    1.29569   1.29577
# 2 2020-07-30 07:30:00   1.29572   1.29754  1.29549    1.29718   1.29588
# 3 2020-07-30 07:45:00   1.29720   1.29867  1.29687    1.29846   1.29737
# 4 2020-07-30 08:00:00   1.29848   1.29929  1.29819    1.29901   1.29865
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 0   1.29623  1.29522    1.29575   1.29552   1.29615  1.29514    1.29567
# 1   1.29667  1.29518    1.29586   1.29569   1.29658  1.29510    1.29578
# 2   1.29770  1.29564    1.29735   1.29580   1.29762  1.29556    1.29726
# 3   1.29885  1.29703    1.29863   1.29728   1.29876  1.29695    1.29854
# 4   1.29951  1.29835    1.29918   1.29856   1.29939  1.29828    1.29910
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 24833 2021-07-30 05:45:00   1.39359   1.39380  1.39337    1.39379   1.39376
# 24834 2021-07-30 06:00:00   1.39380   1.39432  1.39376    1.39422   1.39394
# 24835 2021-07-30 06:15:00   1.39419   1.39456  1.39401    1.39428   1.39435
# 24836 2021-07-30 06:30:00   1.39430   1.39452  1.39378    1.39422   1.39447
# 24837 2021-07-30 06:45:00   1.39420   1.39503  1.39400    1.39503   1.39436
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 24833   1.39400  1.39356    1.39399   1.39368   1.39390  1.39346    1.39389
# 24834   1.39448  1.39392    1.39438   1.39387   1.39440  1.39384    1.39430
# 24835   1.39474  1.39418    1.39445   1.39427   1.39465  1.39410    1.39436
# 24836   1.39467  1.39394    1.39440   1.39438   1.39459  1.39386    1.39431
# 24837   1.39518  1.39418    1.39518   1.39428   1.39510  1.39409    1.39510
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2020-07-30 07:00:00   1.29543   1.29607  1.29540    1.29572   1.29562
# 1 2020-07-30 07:05:00   1.29569   1.29591  1.29505    1.29542   1.29588
# 2 2020-07-30 07:10:00   1.29541   1.29590  1.29514    1.29559   1.29557
# 3 2020-07-30 07:15:00   1.29561   1.29567  1.29510    1.29515   1.29577
# 4 2020-07-30 07:20:00   1.29514   1.29643  1.29501    1.29642   1.29529
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 0   1.29623  1.29560    1.29589   1.29552   1.29615  1.29550    1.29580
# 1   1.29608  1.29522    1.29560   1.29578   1.29600  1.29514    1.29551
# 2   1.29606  1.29535    1.29575   1.29549   1.29598  1.29524    1.29567
# 3   1.29584  1.29530    1.29533   1.29569   1.29576  1.29520    1.29524
# 4   1.29660  1.29518    1.29660   1.29522   1.29652  1.29510    1.29651
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 74259 2021-07-30 06:35:00   1.39401   1.39451  1.39401    1.39430   1.39417
# 74260 2021-07-30 06:40:00   1.39433   1.39452  1.39415    1.39422   1.39449
# 74261 2021-07-30 06:45:00   1.39420   1.39455  1.39400    1.39451   1.39436
# 74262 2021-07-30 06:50:00   1.39454   1.39481  1.39447    1.39470   1.39469
# 74263 2021-07-30 06:55:00   1.39469   1.39503  1.39462    1.39503   1.39486
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 74259   1.39467  1.39417    1.39447   1.39409   1.39459  1.39409    1.39438
# 74260   1.39466  1.39433    1.39440   1.39441   1.39459  1.39424    1.39431
# 74261   1.39472  1.39418    1.39466   1.39428   1.39464  1.39409    1.39458
# 74262   1.39499  1.39462    1.39490   1.39462   1.39490  1.39454    1.39480
# 74263   1.39518  1.39477    1.39518   1.39478   1.39510  1.39470    1.39510

# %%
def add_fractal(df, i, look_back=3):
  if i >= look_back and i < df.shape[0] - look_back:
    lows = []
    highs = []

    for j in range(1, look_back + 1):
      prev_bid_low, prev_bid_high = df.loc[df.index[i - j], ['Mid_Low', 'Mid_High']]
      future_bid_low, future_bid_high = df.loc[df.index[i + j], ['Mid_Low', 'Mid_High']]

      lows.append(float(prev_bid_low))
      lows.append(float(future_bid_low))
      highs.append(float(prev_bid_high))
      highs.append(float(future_bid_high))

    bid_low, bid_high = df.loc[df.index[i], ['Mid_Low', 'Mid_High']]

    if float(bid_low) < min(lows):
      return 1

    elif float(bid_high) > max(highs):
      return 2

    else:
      return 0

  else:
    return np.nan


def add_beep_boop(row):
  macdhist, ema50, mid_low, mid_high = row[['macdhist', 'ema50', 'Mid_Low', 'Mid_High']]

  if float(macdhist) > 0 and float(mid_low) > float(ema50):
    return 1

  elif float(macdhist) < 0 and float(mid_high) < float(ema50):
    return 2

  else:
    return 0

# %%
df['macd'], df['macdsignal'], df['macdhist'] = talib.MACD(df['Mid_Close'])
df['ema200'] = talib.EMA(df['Mid_Close'], timeperiod=200)
df['ema50'] = talib.EMA(df['Mid_Close'], timeperiod=50)
df['atr'] = talib.ATR(df['Mid_High'], df['Mid_Low'], df['Mid_Close'], timeperiod=500)
df['fractal'] = [add_fractal(df, i) for i in range(df.shape[0])]
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df['beep_boop'] = df.apply(add_beep_boop, axis=1)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

print(df['beep_boop'].value_counts())
print(df['fractal'].value_counts())

# %%
value_per_pip = 1.0
max_pips_to_risk = 0.0100
amounts_per_day = [-4, -5, -6]

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25])
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee


def run_simulation(risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length, max_open_trades=5):
    pullback_cushion /= 10000
    fractal_distance /= 10000
    bar_length /= 10000
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    n_units = 10000
    trades = deque(maxlen=max_open_trades)

    def iterate_thru_small_data(trade):
        def get_end_date(j):
          return df_small.loc[df_small.index[j + 1], 'Date'] if j + 1 < len(df_small) else None

        j = df_small[df_small.Date >= trade['start_date']].index[0]

        nonlocal reward
        nonlocal day_fees
        nonlocal n_losses
        nonlocal n_wins
        nonlocal curr_win_streak
        nonlocal curr_loss_streak
        nonlocal win_streak
        nonlocal loss_streak

        while j < len(df_small):
          curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, curr_date = \
          df_small.loc[df_small.index[j], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low',
                                         'Ask_Close', 'Date']]

          if trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
            trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date)

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade['end_date'] = get_end_date(j)

            break

          if trade['trade_type'] == 'buy' and curr_bid_high - trade['pips_risked'] > trade['stop_loss']:
              trade['stop_loss'] = curr_bid_high - trade['pips_risked']

          if trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
            trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date)

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade['end_date'] = get_end_date(j)

            break

          if trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
            trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date)

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade['end_date'] = get_end_date(j)

            break

          if trade['trade_type'] == 'sell' and trade['pips_risked'] + curr_ask_low < trade['stop_loss']:
            trade['stop_loss'] = trade['pips_risked'] + curr_ask_low

          if trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
            trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date)

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade['end_date'] = get_end_date(j)

            break

          j += 1


    i = 3

    while i < len(df):
        if i < last_x_bars:
            i += 1
            continue

        curr_date = df.loc[df.index[i], 'Date']

        # Remove any expired trades -----------------------------------------
        trades_to_remove = []

        for trade in trades:
          if trade['end_date'] is not None and trade['end_date'] >= curr_date:
            trades_to_remove.append(trade)

        for trade in trades_to_remove:
          trades.remove(trade)
        # -------------------------------------------------------------------

        ema200 = df.loc[df.index[i - 1], 'ema200']
        atr = df.loc[df.index[i - 1], 'atr']
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        enough_volatility = (spread / atr) <= atr_percentage
        curr_al = df.loc[df.index[i - 1], 'Ask_Low']
        curr_bh = df.loc[df.index[i - 1], 'Bid_High']
        previous_ask_lows = []
        previous_bid_highs = []
        curr_ml = df.loc[df.index[i - 1], 'Mid_Low']
        curr_mh = df.loc[df.index[i - 1], 'Mid_High']
        curr_bar_length = abs(curr_mh - curr_ml)
        beep_boop1 = df.loc[df.index[i - 1], 'beep_boop']
        beep_boop2 = df.loc[df.index[i - 2], 'beep_boop']
        beep_boop3 = df.loc[df.index[i - 3], 'beep_boop']

        for ind in range(i - last_x_bars, i):
          previous_ask_lows.append(df.loc[df.index[ind], 'Ask_Low'])
          previous_bid_highs.append(df.loc[df.index[ind], 'Bid_High'])

        process_trade = False

        if beep_boop3 == 1 and beep_boop2 == 1 and beep_boop1 == 1 and curr_ml > ema200 and enough_volatility and len(trades) < max_open_trades and curr_al <= min(previous_ask_lows) and curr_bar_length <= bar_length:
            all_buys = True

            for trade in trades:
                if trade['trade_type'] != 'buy':
                    all_buys = False
                    break

            if all_buys:
              pullback = None
              u = i - 4

              while u >= 0:
                  if df.loc[df.index[u], 'fractal'] == 1:
                      curr_pullback = float(df.loc[df.index[u], 'Bid_Low'])
                      curr_fractal_distance = curr_ao - curr_pullback

                      if curr_fractal_distance >= fractal_distance:
                          pullback = curr_pullback
                          break

                  u -= 1

              if pullback is not None:
                  curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
                  df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                                'Ask_Low', 'Ask_Close']]
                  open_price = float(curr_ask_open)
                  stop_loss = round(pullback - pullback_cushion, 5)
                  # stop_loss = round(pullback - pullback_cushion, 3)

                  if stop_loss < open_price:
                      curr_pips_to_risk = open_price - stop_loss

                      if curr_pips_to_risk <= max_pips_to_risk:
                          stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 5)
                          # stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 3)

                          trades.append({'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                            'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                            'n_units': n_units, 'start_date': curr_date, 'end_date': None})

                          n_buys += 1

                          pips_risked.append(curr_pips_to_risk)

                          process_trade = True

        elif beep_boop3 == 2 and beep_boop2 == 2 and beep_boop1 == 2 and curr_mh < ema200 and enough_volatility and len(trades) < max_open_trades and curr_bh >= max(previous_bid_highs) and curr_bar_length <= bar_length:
            all_sells = True

            for trade in trades:
                if trade['trade_type'] != 'sell':
                    all_sells = False
                    break

            if all_sells:
              pullback = None
              u = i - 4

              while u >= 0:
                  if df.loc[df.index[u], 'fractal'] == 2:
                      curr_pullback = float(df.loc[df.index[u], 'Ask_High'])
                      curr_fractal_distance = curr_pullback - curr_bo

                      if curr_fractal_distance >= fractal_distance:
                          pullback = curr_pullback
                          break

                  u -= 1

              if pullback is not None:
                  curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
                  df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                                'Ask_Low', 'Ask_Close']]
                  open_price = float(curr_bid_open)
                  stop_loss = round(pullback + pullback_cushion, 5)
                  # stop_loss = round(pullback + pullback_cushion, 3)

                  if stop_loss > open_price:
                      curr_pips_to_risk = stop_loss - open_price

                      if curr_pips_to_risk <= max_pips_to_risk:
                          stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 5)
                          # stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 3)

                          trades.append({'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                                  'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                  'n_units': n_units, 'start_date': curr_date, 'end_date': None})

                          n_sells += 1

                          pips_risked.append(curr_pips_to_risk)

                          process_trade = True

        if process_trade:
          iterate_thru_small_data(trades[-1])

        i += 1

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
risk_reward_ratio_vals = [1.5, 1.6, 1.7, 1.8, 1.9, 2]
# risk_reward_ratio_vals = [1.9]
# pullback_cushion_vals = [5, 10, 15, 20, 25, 30, 35, 40]
pullback_cushion_vals = [5, 10]
# atr_percentages = [0.20, 0.25, 0.30, 0.35, 0.40]
atr_percentages = [0.25]
# last_x_bars_vals = [2, 3, 4, 5]
last_x_bars_vals = [2, 3]
# fractal_distances = [0, 5, 10, 15]
fractal_distances = [10]
# bar_lengths = [5, 10, 15, np.inf]
bar_lengths = [5]
n_possibilities = len(risk_reward_ratio_vals) * len(pullback_cushion_vals) * len(atr_percentages) * len(last_x_bars_vals) * len(fractal_distances) * len(bar_lengths)
all_combos = []

for risk_reward_ratio in risk_reward_ratio_vals:
  for pullback_cushion in pullback_cushion_vals:
    for atr_percentage in atr_percentages:
      for last_x_bars in last_x_bars_vals:
        for fractal_distance in fractal_distances:
          for bar_length in bar_lengths:
            all_combos.append((risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length))

percentage_to_try = 0.05
# percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)

best_risk_reward = None
best_pullback_cushion = None
best_atr_percentage = None
best_last_x_bars_val = None
best_fractal_distance = None
best_bar_length = None
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length in combos_to_try:
  reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak = run_simulation(risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length)
  runs_finished += 1

  print(reward)
  print('Num buys: ' + str(n_sells))
  print('Num sells: ' + str(n_buys))
  print('Num trades: ' + str(n_buys + n_sells))
  print('Num wins: ' + str(n_wins))
  print('Num losses: ' + str(n_losses))
  print('Win streak: ' + str(win_streak))
  print('Loss streak: ' + str(loss_streak))
  print('Remaining runs: ' + str(n_runs - runs_finished))

  if reward > best_reward:
    best_reward = reward
    best_risk_reward = risk_reward_ratio
    best_pullback_cushion = pullback_cushion
    best_atr_percentage = atr_percentage
    best_last_x_bars_val = last_x_bars
    best_fractal_distance = fractal_distance
    best_bar_length = bar_length

  print('Best reward so far: ' + str(best_reward))
  print()
# Out:
# -175.29999999995186
# Num buys: 144
# Num sells: 202
# Num trades: 346
# Num wins: 142
# Num losses: 203
# Win streak: 6
# Loss streak: 22
# Remaining runs: 767
# Best reward so far: -175.29999999995186
#
# -6973.500000000001
# Num buys: 526
# Num sells: 642
# Num trades: 1168
# Num wins: 427
# Num losses: 737
# Win streak: 14
# Loss streak: 36
# Remaining runs: 766
# Best reward so far: -175.29999999995186
#
# -1198.199999999983
# Num buys: 162
# Num sells: 146
# Num trades: 308
# Num wins: 121
# Num losses: 187
# Win streak: 11
# Loss streak: 17
# Remaining runs: 765
# Best reward so far: -175.29999999995186
#
# -14636.799999999925
# Num buys: 1034
# Num sells: 1229
# Num trades: 2263
# Num wins: 806
# Num losses: 1452
# Win streak: 23
# Loss streak: 59
# Remaining runs: 764
# Best reward so far: -175.29999999995186
#
# -2254.9999999999973
# Num buys: 236
# Num sells: 312
# Num trades: 548
# Num wins: 215
# Num losses: 328
# Win streak: 10
# Loss streak: 16
# Remaining runs: 763
# Best reward so far: -175.29999999995186
#
# -607.899999999993
# Num buys: 67
# Num sells: 312
# Num trades: 379
# Num wins: 144
# Num losses: 234
# Win streak: 11
# Loss streak: 13
# Remaining runs: 762
# Best reward so far: -175.29999999995186
#
# -4676.099999999984
# Num buys: 440
# Num sells: 578
# Num trades: 1018
# Num wins: 373
# Num losses: 643
# Win streak: 16
# Loss streak: 43
# Remaining runs: 761
# Best reward so far: -175.29999999995186
#
# -3182.7999999999834
# Num buys: 184
# Num sells: 767
# Num trades: 951
# Num wins: 342
# Num losses: 606
# Win streak: 16
# Loss streak: 32
# Remaining runs: 760
# Best reward so far: -175.29999999995186
#
# -2775.0999999999676
# Num buys: 267
# Num sells: 360
# Num trades: 627
# Num wins: 229
# Num losses: 397
# Win streak: 11
# Loss streak: 28
# Remaining runs: 759
# Best reward so far: -175.29999999995186
#
# -957.3000000000015
# Num buys: 110
# Num sells: 103
# Num trades: 213
# Num wins: 73
# Num losses: 139
# Win streak: 9
# Loss streak: 18
# Remaining runs: 758
# Best reward so far: -175.29999999995186
#
# -2900.5000000000314
# Num buys: 271
# Num sells: 366
# Num trades: 637
# Num wins: 250
# Num losses: 382
# Win streak: 14
# Loss streak: 24
# Remaining runs: 757
# Best reward so far: -175.29999999995186
#
# -4548.300000000006
# Num buys: 376
# Num sells: 460
# Num trades: 836
# Num wins: 315
# Num losses: 520
# Win streak: 12
# Loss streak: 22
# Remaining runs: 756
# Best reward so far: -175.29999999995186
#
# 96.10000000001207
# Num buys: 55
# Num sells: 73
# Num trades: 128
# Num wins: 56
# Num losses: 72
# Win streak: 7
# Loss streak: 7
# Remaining runs: 755
# Best reward so far: 96.10000000001207
#
# -1660.399999999945
# Num buys: 178
# Num sells: 232
# Num trades: 410
# Num wins: 155
# Num losses: 252
# Win streak: 15
# Loss streak: 18
# Remaining runs: 754
# Best reward so far: 96.10000000001207
#
# -6559.999999999949
# Num buys: 351
# Num sells: 419
# Num trades: 770
# Num wins: 272
# Num losses: 496
# Win streak: 16
# Loss streak: 24
# Remaining runs: 753
# Best reward so far: 96.10000000001207
#
# -6618.699999999911
# Num buys: 769
# Num sells: 0
# Num trades: 769
# Num wins: 266
# Num losses: 503
# Win streak: 17
# Loss streak: 34
# Remaining runs: 752
# Best reward so far: 96.10000000001207
#
# 219.69999999999789
# Num buys: 55
# Num sells: 71
# Num trades: 126
# Num wins: 57
# Num losses: 69
# Win streak: 6
# Loss streak: 7
# Remaining runs: 751
# Best reward so far: 219.69999999999789
#
# -17235.199999999957
# Num buys: 853
# Num sells: 1003
# Num trades: 1856
# Num wins: 663
# Num losses: 1188
# Win streak: 21
# Loss streak: 51
# Remaining runs: 750
# Best reward so far: 219.69999999999789
#
# -1531.9999999999936
# Num buys: 99
# Num sells: 136
# Num trades: 235
# Num wins: 86
# Num losses: 148
# Win streak: 11
# Loss streak: 18
# Remaining runs: 749
# Best reward so far: 219.69999999999789
#
# -4215.100000000002
# Num buys: 378
# Num sells: 480
# Num trades: 858
# Num wins: 339
# Num losses: 514
# Win streak: 14
# Loss streak: 20
# Remaining runs: 748
# Best reward so far: 219.69999999999789
#
# -11158.799999999981
# Num buys: 780
# Num sells: 1037
# Num trades: 1817
# Num wins: 685
# Num losses: 1126
# Win streak: 26
# Loss streak: 63
# Remaining runs: 747
# Best reward so far: 219.69999999999789
#
# -1561.2999999999752
# Num buys: 139
# Num sells: 120
# Num trades: 259
# Num wins: 91
# Num losses: 168
# Win streak: 8
# Loss streak: 13
# Remaining runs: 746
# Best reward so far: 219.69999999999789
#
# 147.79999999999404
# Num buys: 62
# Num sells: 59
# Num trades: 121
# Num wins: 55
# Num losses: 66
# Win streak: 10
# Loss streak: 9
# Remaining runs: 745
# Best reward so far: 219.69999999999789
#
# -2103.199999999968
# Num buys: 466
# Num sells: 602
# Num trades: 1068
# Num wins: 394
# Num losses: 673
# Win streak: 17
# Loss streak: 45
# Remaining runs: 744
# Best reward so far: 219.69999999999789
#
# -18272.699999999913
# Num buys: 997
# Num sells: 1205
# Num trades: 2202
# Num wins: 811
# Num losses: 1386
# Win streak: 29
# Loss streak: 52
# Remaining runs: 743
# Best reward so far: 219.69999999999789
#
# 360.5
# Num buys: 108
# Num sells: 23
# Num trades: 131
# Num wins: 55
# Num losses: 76
# Win streak: 8
# Loss streak: 10
# Remaining runs: 742
# Best reward so far: 360.5
#
# 114.40000000001595
# Num buys: 52
# Num sells: 68
# Num trades: 120
# Num wins: 50
# Num losses: 70
# Win streak: 9
# Loss streak: 7
# Remaining runs: 741
# Best reward so far: 360.5
#
# -598.5999999999789
# Num buys: 99
# Num sells: 97
# Num trades: 196
# Num wins: 84
# Num losses: 111
# Win streak: 11
# Loss streak: 13
# Remaining runs: 740
# Best reward so far: 360.5
#
# -1810.8999999999764
# Num buys: 259
# Num sells: 0
# Num trades: 259
# Num wins: 88
# Num losses: 170
# Win streak: 8
# Loss streak: 14
# Remaining runs: 739
# Best reward so far: 360.5
#
# 167.5000000000225
# Num buys: 143
# Num sells: 200
# Num trades: 343
# Num wins: 150
# Num losses: 191
# Win streak: 8
# Loss streak: 14
# Remaining runs: 738
# Best reward so far: 360.5
#
# -14451.099999999988
# Num buys: 1058
# Num sells: 1351
# Num trades: 2409
# Num wins: 902
# Num losses: 1501
# Win streak: 41
# Loss streak: 55
# Remaining runs: 737
# Best reward so far: 360.5
#
# 417.8000000000301
# Num buys: 83
# Num sells: 107
# Num trades: 190
# Num wins: 82
# Num losses: 108
# Win streak: 8
# Loss streak: 15
# Remaining runs: 736
# Best reward so far: 417.8000000000301
#
# -6632.399999999955
# Num buys: 475
# Num sells: 404
# Num trades: 879
# Num wins: 321
# Num losses: 554
# Win streak: 18
# Loss streak: 38
# Remaining runs: 735
# Best reward so far: 417.8000000000301
#
# -417.79999999997267
# Num buys: 78
# Num sells: 202
# Num trades: 280
# Num wins: 110
# Num losses: 169
# Win streak: 8
# Loss streak: 17
# Remaining runs: 734
# Best reward so far: 417.8000000000301
#
# 54.40000000002402
# Num buys: 60
# Num sells: 82
# Num trades: 142
# Num wins: 56
# Num losses: 85
# Win streak: 5
# Loss streak: 15
# Remaining runs: 733
# Best reward so far: 417.8000000000301
#
# -5900.199999999975
# Num buys: 423
# Num sells: 529
# Num trades: 952
# Num wins: 365
# Num losses: 583
# Win streak: 14
# Loss streak: 21
# Remaining runs: 732
# Best reward so far: 417.8000000000301
#
# -19.199999999996436
# Num buys: 15
# Num sells: 15
# Num trades: 30
# Num wins: 12
# Num losses: 18
# Win streak: 3
# Loss streak: 5
# Remaining runs: 731
# Best reward so far: 417.8000000000301
#
# -763.3999999999974
# Num buys: 79
# Num sells: 365
# Num trades: 444
# Num wins: 169
# Num losses: 272
# Win streak: 12
# Loss streak: 14
# Remaining runs: 730
# Best reward so far: 417.8000000000301
#
# -1318.3999999999564
# Num buys: 285
# Num sells: 387
# Num trades: 672
# Num wins: 256
# Num losses: 415
# Win streak: 15
# Loss streak: 18
# Remaining runs: 729
# Best reward so far: 417.8000000000301
#
# -155.1999999999863
# Num buys: 43
# Num sells: 54
# Num trades: 97
# Num wins: 35
# Num losses: 62
# Win streak: 5
# Loss streak: 9
# Remaining runs: 728
# Best reward so far: 417.8000000000301
#
# -657.3999999999754
# Num buys: 68
# Num sells: 49
# Num trades: 117
# Num wins: 40
# Num losses: 77
# Win streak: 8
# Loss streak: 14
# Remaining runs: 727
# Best reward so far: 417.8000000000301
#
# -4912.599999999892
# Num buys: 543
# Num sells: 1011
# Num trades: 1554
# Num wins: 546
# Num losses: 1005
# Win streak: 19
# Loss streak: 42
# Remaining runs: 726
# Best reward so far: 417.8000000000301
#
# -226.59999999999604
# Num buys: 68
# Num sells: 49
# Num trades: 117
# Num wins: 45
# Num losses: 72
# Win streak: 8
# Loss streak: 13
# Remaining runs: 725
# Best reward so far: 417.8000000000301
#
# -2688.4999999999745
# Num buys: 294
# Num sells: 0
# Num trades: 294
# Num wins: 94
# Num losses: 200
# Win streak: 8
# Loss streak: 20
# Remaining runs: 724
# Best reward so far: 417.8000000000301
#
# -303.599999999988
# Num buys: 15
# Num sells: 14
# Num trades: 29
# Num wins: 12
# Num losses: 17
# Win streak: 3
# Loss streak: 6
# Remaining runs: 723
# Best reward so far: 417.8000000000301
#
# -1405.3999999999621
# Num buys: 468
# Num sells: 53
# Num trades: 521
# Num wins: 176
# Num losses: 345
# Win streak: 14
# Loss streak: 29
# Remaining runs: 722
# Best reward so far: 417.8000000000301
#
# -4037.7999999999556
# Num buys: 482
# Num sells: 0
# Num trades: 482
# Num wins: 166
# Num losses: 315
# Win streak: 11
# Loss streak: 27
# Remaining runs: 721
# Best reward so far: 417.8000000000301
#
# -2778.0999999999854
# Num buys: 222
# Num sells: 298
# Num trades: 520
# Num wins: 186
# Num losses: 334
# Win streak: 9
# Loss streak: 23
# Remaining runs: 720
# Best reward so far: 417.8000000000301
#
# -403.2999999999762
# Num buys: 190
# Num sells: 244
# Num trades: 434
# Num wins: 168
# Num losses: 265
# Win streak: 10
# Loss streak: 24
# Remaining runs: 719
# Best reward so far: 417.8000000000301
#
# -15928.399999999976
# Num buys: 1032
# Num sells: 1310
# Num trades: 2342
# Num wins: 886
# Num losses: 1450
# Win streak: 30
# Loss streak: 64
# Remaining runs: 718
# Best reward so far: 417.8000000000301
#
# -635.6999999999829
# Num buys: 35
# Num sells: 30
# Num trades: 65
# Num wins: 24
# Num losses: 41
# Win streak: 6
# Loss streak: 9
# Remaining runs: 717
# Best reward so far: 417.8000000000301
#
# -287.4000000000045
# Num buys: 52
# Num sells: 68
# Num trades: 120
# Num wins: 45
# Num losses: 75
# Win streak: 6
# Loss streak: 14
# Remaining runs: 716
# Best reward so far: 417.8000000000301
#
# -101.79999999995869
# Num buys: 144
# Num sells: 199
# Num trades: 343
# Num wins: 141
# Num losses: 201
# Win streak: 6
# Loss streak: 22
# Remaining runs: 715
# Best reward so far: 417.8000000000301
#
# -20199.799999999945
# Num buys: 970
# Num sells: 1156
# Num trades: 2126
# Num wins: 769
# Num losses: 1352
# Win streak: 27
# Loss streak: 53
# Remaining runs: 714
# Best reward so far: 417.8000000000301
#
# -1596.0999999999806
# Num buys: 222
# Num sells: 298
# Num trades: 520
# Num wins: 194
# Num losses: 325
# Win streak: 9
# Loss streak: 27
# Remaining runs: 713
# Best reward so far: 417.8000000000301
#
# -142.79999999999143
# Num buys: 67
# Num sells: 61
# Num trades: 128
# Num wins: 52
# Num losses: 76
# Win streak: 7
# Loss streak: 8
# Remaining runs: 712
# Best reward so far: 417.8000000000301
#
# -3068.699999999996
# Num buys: 159
# Num sells: 651
# Num trades: 810
# Num wins: 291
# Num losses: 518
# Win streak: 14
# Loss streak: 30
# Remaining runs: 711
# Best reward so far: 417.8000000000301
#
# -40.59999999997251
# Num buys: 145
# Num sells: 200
# Num trades: 345
# Num wins: 135
# Num losses: 209
# Win streak: 9
# Loss streak: 22
# Remaining runs: 710
# Best reward so far: 417.8000000000301
#
# -73.49999999999613
# Num buys: 109
# Num sells: 3
# Num trades: 112
# Num wins: 46
# Num losses: 66
# Win streak: 8
# Loss streak: 11
# Remaining runs: 709
# Best reward so far: 417.8000000000301
#
# 774.7000000000321
# Num buys: 87
# Num sells: 113
# Num trades: 200
# Num wins: 93
# Num losses: 107
# Win streak: 7
# Loss streak: 9
# Remaining runs: 708
# Best reward so far: 774.7000000000321
#
# -3160.8999999999724
# Num buys: 457
# Num sells: 369
# Num trades: 826
# Num wins: 319
# Num losses: 506
# Win streak: 18
# Loss streak: 25
# Remaining runs: 707
# Best reward so far: 774.7000000000321
#
# -4852.300000000007
# Num buys: 342
# Num sells: 442
# Num trades: 784
# Num wins: 299
# Num losses: 484
# Win streak: 14
# Loss streak: 29
# Remaining runs: 706
# Best reward so far: 774.7000000000321
#
# 327.80000000001087
# Num buys: 144
# Num sells: 199
# Num trades: 343
# Num wins: 139
# Num losses: 204
# Win streak: 9
# Loss streak: 18
# Remaining runs: 705
# Best reward so far: 774.7000000000321
#
# -3666.5999999999617
# Num buys: 323
# Num sells: 280
# Num trades: 603
# Num wins: 213
# Num losses: 390
# Win streak: 14
# Loss streak: 21
# Remaining runs: 704
# Best reward so far: 774.7000000000321
#
# -1439.1999999999407
# Num buys: 260
# Num sells: 362
# Num trades: 622
# Num wins: 248
# Num losses: 369
# Win streak: 13
# Loss streak: 18
# Remaining runs: 703
# Best reward so far: 774.7000000000321
#
# -2321.4999999999613
# Num buys: 262
# Num sells: 361
# Num trades: 623
# Num wins: 233
# Num losses: 389
# Win streak: 17
# Loss streak: 38
# Remaining runs: 702
# Best reward so far: 774.7000000000321
#
# -4819.59999999999
# Num buys: 261
# Num sells: 328
# Num trades: 589
# Num wins: 213
# Num losses: 371
# Win streak: 15
# Loss streak: 26
# Remaining runs: 701
# Best reward so far: 774.7000000000321
#
# -17019.299999999923
# Num buys: 832
# Num sells: 969
# Num trades: 1801
# Num wins: 658
# Num losses: 1138
# Win streak: 31
# Loss streak: 50
# Remaining runs: 700
# Best reward so far: 774.7000000000321
#
# -5277.299999999904
# Num buys: 353
# Num sells: 1492
# Num trades: 1845
# Num wins: 712
# Num losses: 1129
# Win streak: 29
# Loss streak: 46
# Remaining runs: 699
# Best reward so far: 774.7000000000321
#
# -1898.8999999999955
# Num buys: 168
# Num sells: 160
# Num trades: 328
# Num wins: 113
# Num losses: 213
# Win streak: 10
# Loss streak: 22
# Remaining runs: 698
# Best reward so far: 774.7000000000321
#
# -2895.099999999956
# Num buys: 164
# Num sells: 265
# Num trades: 429
# Num wins: 142
# Num losses: 287
# Win streak: 12
# Loss streak: 19
# Remaining runs: 697
# Best reward so far: 774.7000000000321
#
# 12.300000000008112
# Num buys: 15
# Num sells: 15
# Num trades: 30
# Num wins: 12
# Num losses: 18
# Win streak: 3
# Loss streak: 5
# Remaining runs: 696
# Best reward so far: 774.7000000000321
#
# -1038.49999999997
# Num buys: 265
# Num sells: 365
# Num trades: 630
# Num wins: 236
# Num losses: 394
# Win streak: 10
# Loss streak: 31
# Remaining runs: 695
# Best reward so far: 774.7000000000321
#
# -75.19999999997435
# Num buys: 145
# Num sells: 200
# Num trades: 345
# Num wins: 135
# Num losses: 209
# Win streak: 9
# Loss streak: 22
# Remaining runs: 694
# Best reward so far: 774.7000000000321
#
# -3495.599999999965
# Num buys: 334
# Num sells: 291
# Num trades: 625
# Num wins: 233
# Num losses: 392
# Win streak: 15
# Loss streak: 20
# Remaining runs: 693
# Best reward so far: 774.7000000000321
#
# -9075.699999999935
# Num buys: 786
# Num sells: 1058
# Num trades: 1844
# Num wins: 689
# Num losses: 1149
# Win streak: 25
# Loss streak: 65
# Remaining runs: 692
# Best reward so far: 774.7000000000321
#
# -6116.199999999925
# Num buys: 764
# Num sells: 1010
# Num trades: 1774
# Num wins: 644
# Num losses: 1122
# Win streak: 21
# Loss streak: 53
# Remaining runs: 691
# Best reward so far: 774.7000000000321
#
# -1138.899999999936
# Num buys: 247
# Num sells: 339
# Num trades: 586
# Num wins: 227
# Num losses: 358
# Win streak: 11
# Loss streak: 38
# Remaining runs: 690
# Best reward so far: 774.7000000000321
#
# 6.100000000018554
# Num buys: 96
# Num sells: 135
# Num trades: 231
# Num wins: 103
# Num losses: 126
# Win streak: 8
# Loss streak: 11
# Remaining runs: 689
# Best reward so far: 774.7000000000321
#
# -1010.4999999999654
# Num buys: 63
# Num sells: 42
# Num trades: 105
# Num wins: 39
# Num losses: 65
# Win streak: 7
# Loss streak: 14
# Remaining runs: 688
# Best reward so far: 774.7000000000321
#
# -2971.8000000000284
# Num buys: 374
# Num sells: 485
# Num trades: 859
# Num wins: 346
# Num losses: 508
# Win streak: 18
# Loss streak: 20
# Remaining runs: 687
# Best reward so far: 774.7000000000321
#
# -7253.399999999938
# Num buys: 413
# Num sells: 493
# Num trades: 906
# Num wins: 319
# Num losses: 583
# Win streak: 18
# Loss streak: 26
# Remaining runs: 686
# Best reward so far: 774.7000000000321
#
# -5590.79999999997
# Num buys: 324
# Num sells: 1379
# Num trades: 1703
# Num wins: 616
# Num losses: 1083
# Win streak: 20
# Loss streak: 55
# Remaining runs: 685
# Best reward so far: 774.7000000000321
#
# 37.90000000001561
# Num buys: 52
# Num sells: 68
# Num trades: 120
# Num wins: 50
# Num losses: 70
# Win streak: 9
# Loss streak: 7
# Remaining runs: 684
# Best reward so far: 774.7000000000321
#
# -18478.999999999898
# Num buys: 1152
# Num sells: 1381
# Num trades: 2533
# Num wins: 924
# Num losses: 1602
# Win streak: 31
# Loss streak: 63
# Remaining runs: 683
# Best reward so far: 774.7000000000321
#
# -2022.2999999999877
# Num buys: 267
# Num sells: 361
# Num trades: 628
# Num wins: 228
# Num losses: 398
# Win streak: 11
# Loss streak: 32
# Remaining runs: 682
# Best reward so far: 774.7000000000321
#
# -32.49999999999508
# Num buys: 15
# Num sells: 15
# Num trades: 30
# Num wins: 12
# Num losses: 18
# Win streak: 3
# Loss streak: 6
# Remaining runs: 681
# Best reward so far: 774.7000000000321
#
# -4844.500000000025
# Num buys: 270
# Num sells: 352
# Num trades: 622
# Num wins: 239
# Num losses: 379
# Win streak: 16
# Loss streak: 16
# Remaining runs: 680
# Best reward so far: 774.7000000000321
#
# -1637.599999999965
# Num buys: 271
# Num sells: 361
# Num trades: 632
# Num wins: 232
# Num losses: 399
# Win streak: 13
# Loss streak: 23
# Remaining runs: 679
# Best reward so far: 774.7000000000321
#
# -2731.999999999972
# Num buys: 298
# Num sells: 0
# Num trades: 298
# Num wins: 99
# Num losses: 198
# Win streak: 8
# Loss streak: 20
# Remaining runs: 678
# Best reward so far: 774.7000000000321
#
# -3106.7999999999756
# Num buys: 273
# Num sells: 342
# Num trades: 615
# Num wins: 232
# Num losses: 379
# Win streak: 9
# Loss streak: 17
# Remaining runs: 677
# Best reward so far: 774.7000000000321
#
# -2553.499999999946
# Num buys: 267
# Num sells: 360
# Num trades: 627
# Num wins: 229
# Num losses: 397
# Win streak: 11
# Loss streak: 28
# Remaining runs: 676
# Best reward so far: 774.7000000000321
#
# -2975.6999999999603
# Num buys: 243
# Num sells: 207
# Num trades: 450
# Num wins: 166
# Num losses: 284
# Win streak: 10
# Loss streak: 23
# Remaining runs: 675
# Best reward so far: 774.7000000000321
#
# -549.5999999999758
# Num buys: 272
# Num sells: 32
# Num trades: 304
# Num wins: 101
# Num losses: 203
# Win streak: 8
# Loss streak: 17
# Remaining runs: 674
# Best reward so far: 774.7000000000321
#
# -5745.699999999947
# Num buys: 338
# Num sells: 422
# Num trades: 760
# Num wins: 283
# Num losses: 472
# Win streak: 17
# Loss streak: 25
# Remaining runs: 673
# Best reward so far: 774.7000000000321
#
# -975.099999999999
# Num buys: 81
# Num sells: 365
# Num trades: 446
# Num wins: 171
# Num losses: 273
# Win streak: 12
# Loss streak: 14
# Remaining runs: 672
# Best reward so far: 774.7000000000321
#
# -2340.4999999999745
# Num buys: 464
# Num sells: 605
# Num trades: 1069
# Num wins: 400
# Num losses: 667
# Win streak: 19
# Loss streak: 39
# Remaining runs: 671
# Best reward so far: 774.7000000000321
#
# -9912.79999999994
# Num buys: 576
# Num sells: 733
# Num trades: 1309
# Num wins: 497
# Num losses: 807
# Win streak: 24
# Loss streak: 40
# Remaining runs: 670
# Best reward so far: 774.7000000000321
#
# -1641.8999999999703
# Num buys: 125
# Num sells: 547
# Num trades: 672
# Num wins: 250
# Num losses: 420
# Win streak: 13
# Loss streak: 17
# Remaining runs: 669
# Best reward so far: 774.7000000000321
#
# -350.999999999985
# Num buys: 43
# Num sells: 54
# Num trades: 97
# Num wins: 43
# Num losses: 54
# Win streak: 7
# Loss streak: 7
# Remaining runs: 668
# Best reward so far: 774.7000000000321
#
# -3146.9999999999886
# Num buys: 288
# Num sells: 256
# Num trades: 544
# Num wins: 199
# Num losses: 345
# Win streak: 12
# Loss streak: 25
# Remaining runs: 667
# Best reward so far: 774.7000000000321
#
# -1766.700000000038
# Num buys: 231
# Num sells: 297
# Num trades: 528
# Num wins: 211
# Num losses: 315
# Win streak: 16
# Loss streak: 16
# Remaining runs: 666
# Best reward so far: 774.7000000000321
#
# -5613.19999999997
# Num buys: 408
# Num sells: 345
# Num trades: 753
# Num wins: 278
# Num losses: 471
# Win streak: 16
# Loss streak: 34
# Remaining runs: 665
# Best reward so far: 774.7000000000321
#
# -100.29999999999217
# Num buys: 15
# Num sells: 13
# Num trades: 28
# Num wins: 12
# Num losses: 16
# Win streak: 7
# Loss streak: 6
# Remaining runs: 664
# Best reward so far: 774.7000000000321
#
# -5868.899999999916
# Num buys: 769
# Num sells: 0
# Num trades: 769
# Num wins: 266
# Num losses: 503
# Win streak: 17
# Loss streak: 34
# Remaining runs: 663
# Best reward so far: 774.7000000000321
#
# -28.299999999994697
# Num buys: 15
# Num sells: 15
# Num trades: 30
# Num wins: 12
# Num losses: 18
# Win streak: 3
# Loss streak: 6
# Remaining runs: 662
# Best reward so far: 774.7000000000321
#
# -6288.999999999943
# Num buys: 444
# Num sells: 559
# Num trades: 1003
# Num wins: 386
# Num losses: 612
# Win streak: 14
# Loss streak: 23
# Remaining runs: 661
# Best reward so far: 774.7000000000321
#
# -994.6999999999778
# Num buys: 248
# Num sells: 347
# Num trades: 595
# Num wins: 230
# Num losses: 360
# Win streak: 18
# Loss streak: 20
# Remaining runs: 660
# Best reward so far: 774.7000000000321
#
# -6583.09999999995
# Num buys: 475
# Num sells: 404
# Num trades: 879
# Num wins: 321
# Num losses: 554
# Win streak: 18
# Loss streak: 38
# Remaining runs: 659
# Best reward so far: 774.7000000000321
#
# -2568.1999999999907
# Num buys: 211
# Num sells: 191
# Num trades: 402
# Num wins: 131
# Num losses: 270
# Win streak: 10
# Loss streak: 18
# Remaining runs: 658
# Best reward so far: 774.7000000000321
#
# -2040.600000000029
# Num buys: 270
# Num sells: 375
# Num trades: 645
# Num wins: 253
# Num losses: 388
# Win streak: 14
# Loss streak: 24
# Remaining runs: 657
# Best reward so far: 774.7000000000321
#
# -926.9999999999945
# Num buys: 96
# Num sells: 94
# Num trades: 190
# Num wins: 79
# Num losses: 111
# Win streak: 11
# Loss streak: 13
# Remaining runs: 656
# Best reward so far: 774.7000000000321
#
# -4681.699999999948
# Num buys: 807
# Num sells: 971
# Num trades: 1778
# Num wins: 666
# Num losses: 1111
# Win streak: 19
# Loss streak: 31
# Remaining runs: 655
# Best reward so far: 774.7000000000321
#
# -6120.799999999934
# Num buys: 805
# Num sells: 1069
# Num trades: 1874
# Num wins: 692
# Num losses: 1174
# Win streak: 24
# Loss streak: 54
# Remaining runs: 654
# Best reward so far: 774.7000000000321
#
# -3495.3999999999833
# Num buys: 191
# Num sells: 805
# Num trades: 996
# Num wins: 370
# Num losses: 622
# Win streak: 18
# Loss streak: 30
# Remaining runs: 653
# Best reward so far: 774.7000000000321
#
# -3082.0999999999913
# Num buys: 280
# Num sells: 357
# Num trades: 637
# Num wins: 248
# Num losses: 384
# Win streak: 10
# Loss streak: 17
# Remaining runs: 652
# Best reward so far: 774.7000000000321
#
# -6047.59999999989
# Num buys: 1079
# Num sells: 127
# Num trades: 1206
# Num wins: 403
# Num losses: 803
# Win streak: 19
# Loss streak: 58
# Remaining runs: 651
# Best reward so far: 774.7000000000321
#
# -3349.899999999995
# Num buys: 434
# Num sells: 582
# Num trades: 1016
# Num wins: 416
# Num losses: 595
# Win streak: 18
# Loss streak: 28
# Remaining runs: 650
# Best reward so far: 774.7000000000321
#
# -5387.59999999994
# Num buys: 315
# Num sells: 1340
# Num trades: 1655
# Num wins: 638
# Num losses: 1013
# Win streak: 28
# Loss streak: 44
# Remaining runs: 649
# Best reward so far: 774.7000000000321
#
# -266.19999999997844
# Num buys: 78
# Num sells: 199
# Num trades: 277
# Num wins: 108
# Num losses: 168
# Win streak: 8
# Loss streak: 17
# Remaining runs: 648
# Best reward so far: 774.7000000000321
#
# 705.000000000023
# Num buys: 87
# Num sells: 113
# Num trades: 200
# Num wins: 93
# Num losses: 107
# Win streak: 7
# Loss streak: 9
# Remaining runs: 647
# Best reward so far: 774.7000000000321
#
# -2133.1000000000013
# Num buys: 137
# Num sells: 182
# Num trades: 319
# Num wins: 131
# Num losses: 187
# Win streak: 8
# Loss streak: 19
# Remaining runs: 646
# Best reward so far: 774.7000000000321
#
# -5245.699999999988
# Num buys: 363
# Num sells: 461
# Num trades: 824
# Num wins: 325
# Num losses: 495
# Win streak: 13
# Loss streak: 20
# Remaining runs: 645
# Best reward so far: 774.7000000000321
#
# -5356.599999999982
# Num buys: 228
# Num sells: 272
# Num trades: 500
# Num wins: 178
# Num losses: 321
# Win streak: 13
# Loss streak: 24
# Remaining runs: 644
# Best reward so far: 774.7000000000321
#
# -7911.500000000029
# Num buys: 602
# Num sells: 736
# Num trades: 1338
# Num wins: 492
# Num losses: 842
# Win streak: 25
# Loss streak: 35
# Remaining runs: 643
# Best reward so far: 774.7000000000321
#
# -837.4999999999808
# Num buys: 173
# Num sells: 229
# Num trades: 402
# Num wins: 154
# Num losses: 247
# Win streak: 10
# Loss streak: 22
# Remaining runs: 642
# Best reward so far: 774.7000000000321
#
# -2501.6000000000067
# Num buys: 242
# Num sells: 296
# Num trades: 538
# Num wins: 211
# Num losses: 326
# Win streak: 10
# Loss streak: 16
# Remaining runs: 641
# Best reward so far: 774.7000000000321
#
# -3.2999999999804572
# Num buys: 43
# Num sells: 54
# Num trades: 97
# Num wins: 38
# Num losses: 58
# Win streak: 4
# Loss streak: 13
# Remaining runs: 640
# Best reward so far: 774.7000000000321
#
# -3249.4999999999745
# Num buys: 194
# Num sells: 813
# Num trades: 1007
# Num wins: 361
# Num losses: 644
# Win streak: 19
# Loss streak: 32
# Remaining runs: 639
# Best reward so far: 774.7000000000321
#
# -3111.2999999999915
# Num buys: 258
# Num sells: 233
# Num trades: 491
# Num wins: 173
# Num losses: 315
# Win streak: 11
# Loss streak: 23
# Remaining runs: 638
# Best reward so far: 774.7000000000321
#
# -45.79999999995937
# Num buys: 88
# Num sells: 115
# Num trades: 203
# Num wins: 82
# Num losses: 121
# Win streak: 7
# Loss streak: 15
# Remaining runs: 637
# Best reward so far: 774.7000000000321
#
# -1158.900000000005
# Num buys: 68
# Num sells: 319
# Num trades: 387
# Num wins: 140
# Num losses: 245
# Win streak: 11
# Loss streak: 15
# Remaining runs: 636
# Best reward so far: 774.7000000000321
#
# -3262.599999999959
# Num buys: 310
# Num sells: 276
# Num trades: 586
# Num wins: 214
# Num losses: 369
# Win streak: 11
# Loss streak: 21
# Remaining runs: 635
# Best reward so far: 774.7000000000321
#
# -1607.1999999999807
# Num buys: 104
# Num sells: 474
# Num trades: 578
# Num wins: 213
# Num losses: 361
# Win streak: 9
# Loss streak: 20
# Remaining runs: 634
# Best reward so far: 774.7000000000321
#
# -1417.7000000000082
# Num buys: 56
# Num sells: 260
# Num trades: 316
# Num wins: 109
# Num losses: 207
# Win streak: 7
# Loss streak: 16
# Remaining runs: 633
# Best reward so far: 774.7000000000321
#
# -1551.099999999991
# Num buys: 122
# Num sells: 111
# Num trades: 233
# Num wins: 91
# Num losses: 142
# Win streak: 8
# Loss streak: 13
# Remaining runs: 632
# Best reward so far: 774.7000000000321
#
# -2449.199999999993
# Num buys: 217
# Num sells: 295
# Num trades: 512
# Num wins: 206
# Num losses: 305
# Win streak: 9
# Loss streak: 23
# Remaining runs: 631
# Best reward so far: 774.7000000000321
#
# -2066.1999999999703
# Num buys: 108
# Num sells: 476
# Num trades: 584
# Num wins: 212
# Num losses: 370
# Win streak: 9
# Loss streak: 19
# Remaining runs: 630
# Best reward so far: 774.7000000000321
#
# -152.2999999999771
# Num buys: 52
# Num sells: 66
# Num trades: 118
# Num wins: 54
# Num losses: 64
# Win streak: 6
# Loss streak: 7
# Remaining runs: 629
# Best reward so far: 774.7000000000321
#
# -985.6000000000017
# Num buys: 171
# Num sells: 237
# Num trades: 408
# Num wins: 153
# Num losses: 253
# Win streak: 11
# Loss streak: 22
# Remaining runs: 628
# Best reward so far: 774.7000000000321
#
# -1738.6999999999591
# Num buys: 371
# Num sells: 475
# Num trades: 846
# Num wins: 311
# Num losses: 534
# Win streak: 13
# Loss streak: 37
# Remaining runs: 627
# Best reward so far: 774.7000000000321
#
# -2363.599999999967
# Num buys: 277
# Num sells: 241
# Num trades: 518
# Num wins: 188
# Num losses: 330
# Win streak: 9
# Loss streak: 18
# Remaining runs: 626
# Best reward so far: 774.7000000000321
#
# -8459.599999999962
# Num buys: 711
# Num sells: 876
# Num trades: 1587
# Num wins: 594
# Num losses: 987
# Win streak: 20
# Loss streak: 42
# Remaining runs: 625
# Best reward so far: 774.7000000000321
#
# -476.6999999999791
# Num buys: 68
# Num sells: 49
# Num trades: 117
# Num wins: 41
# Num losses: 76
# Win streak: 8
# Loss streak: 13
# Remaining runs: 624
# Best reward so far: 774.7000000000321
#
# -1600.1999999999664
# Num buys: 413
# Num sells: 50
# Num trades: 463
# Num wins: 150
# Num losses: 313
# Win streak: 8
# Loss streak: 24
# Remaining runs: 623
# Best reward so far: 774.7000000000321
#
# -51.599999999978536
# Num buys: 111
# Num sells: 102
# Num trades: 213
# Num wins: 82
# Num losses: 131
# Win streak: 10
# Loss streak: 14
# Remaining runs: 622
# Best reward so far: 774.7000000000321
#
# -1035.6999999999882
# Num buys: 165
# Num sells: 220
# Num trades: 385
# Num wins: 142
# Num losses: 241
# Win streak: 7
# Loss streak: 22
# Remaining runs: 621
# Best reward so far: 774.7000000000321
#
# -187.39999999999372
# Num buys: 78
# Num sells: 347
# Num trades: 425
# Num wins: 168
# Num losses: 254
# Win streak: 9
# Loss streak: 14
# Remaining runs: 620
# Best reward so far: 774.7000000000321
#
# -41.8999999999877
# Num buys: 88
# Num sells: 115
# Num trades: 203
# Num wins: 80
# Num losses: 123
# Win streak: 8
# Loss streak: 18
# Remaining runs: 619
# Best reward so far: 774.7000000000321
#
# -5407.099999999954
# Num buys: 507
# Num sells: 458
# Num trades: 965
# Num wins: 349
# Num losses: 611
# Win streak: 15
# Loss streak: 28
# Remaining runs: 618
# Best reward so far: 774.7000000000321
#
# -3604.9999999999877
# Num buys: 64
# Num sells: 483
# Num trades: 547
# Num wins: 189
# Num losses: 358
# Win streak: 16
# Loss streak: 27
# Remaining runs: 617
# Best reward so far: 774.7000000000321
#
# -4235.399999999917
# Num buys: 626
# Num sells: 8
# Num trades: 634
# Num wins: 196
# Num losses: 438
# Win streak: 13
# Loss streak: 38
# Remaining runs: 616
# Best reward so far: 774.7000000000321
#
# -9072.899999999992
# Num buys: 581
# Num sells: 696
# Num trades: 1277
# Num wins: 465
# Num losses: 809
# Win streak: 24
# Loss streak: 33
# Remaining runs: 615
# Best reward so far: 774.7000000000321
#
# -659.6999999999997
# Num buys: 169
# Num sells: 228
# Num trades: 397
# Num wins: 162
# Num losses: 233
# Win streak: 10
# Loss streak: 21
# Remaining runs: 614
# Best reward so far: 774.7000000000321
#
# -1938.6000000000097
# Num buys: 156
# Num sells: 221
# Num trades: 377
# Num wins: 147
# Num losses: 226
# Win streak: 10
# Loss streak: 20
# Remaining runs: 613
# Best reward so far: 774.7000000000321
#
# -13588.799999999974
# Num buys: 866
# Num sells: 1040
# Num trades: 1906
# Num wins: 686
# Num losses: 1217
# Win streak: 40
# Loss streak: 51
# Remaining runs: 612
# Best reward so far: 774.7000000000321
#
# 65.90000000002658
# Num buys: 145
# Num sells: 200
# Num trades: 345
# Num wins: 135
# Num losses: 209
# Win streak: 9
# Loss streak: 22
# Remaining runs: 611
# Best reward so far: 774.7000000000321
#
# -4264.899999999965
# Num buys: 275
# Num sells: 359
# Num trades: 634
# Num wins: 249
# Num losses: 380
# Win streak: 11
# Loss streak: 15
# Remaining runs: 610
# Best reward so far: 774.7000000000321
#
# -1224.8999999999523
# Num buys: 259
# Num sells: 359
# Num trades: 618
# Num wins: 249
# Num losses: 366
# Win streak: 15
# Loss streak: 18
# Remaining runs: 609
# Best reward so far: 774.7000000000321
#
# -11427.899999999947
# Num buys: 667
# Num sells: 809
# Num trades: 1476
# Num wins: 535
# Num losses: 936
# Win streak: 22
# Loss streak: 41
# Remaining runs: 608
# Best reward so far: 774.7000000000321
#
# -8.799999999962665
# Num buys: 138
# Num sells: 189
# Num trades: 327
# Num wins: 132
# Num losses: 194
# Win streak: 6
# Loss streak: 22
# Remaining runs: 607
# Best reward so far: 774.7000000000321
#
# -863.6999999999728
# Num buys: 172
# Num sells: 156
# Num trades: 328
# Num wins: 134
# Num losses: 194
# Win streak: 9
# Loss streak: 17
# Remaining runs: 606
# Best reward so far: 774.7000000000321
#
# -1207.500000000009
# Num buys: 56
# Num sells: 260
# Num trades: 316
# Num wins: 109
# Num losses: 207
# Win streak: 7
# Loss streak: 16
# Remaining runs: 605
# Best reward so far: 774.7000000000321
#
# -2453.3999999999555
# Num buys: 262
# Num sells: 361
# Num trades: 623
# Num wins: 231
# Num losses: 389
# Win streak: 15
# Loss streak: 38
# Remaining runs: 604
# Best reward so far: 774.7000000000321
#
# -1444.9999999999802
# Num buys: 144
# Num sells: 200
# Num trades: 344
# Num wins: 130
# Num losses: 210
# Win streak: 12
# Loss streak: 21
# Remaining runs: 603
# Best reward so far: 774.7000000000321
#
# -701.200000000003
# Num buys: 139
# Num sells: 182
# Num trades: 321
# Num wins: 134
# Num losses: 187
# Win streak: 8
# Loss streak: 19
# Remaining runs: 602
# Best reward so far: 774.7000000000321
#
# -3070.700000000033
# Num buys: 189
# Num sells: 800
# Num trades: 989
# Num wins: 359
# Num losses: 627
# Win streak: 18
# Loss streak: 32
# Remaining runs: 601
# Best reward so far: 774.7000000000321
#
# -2285.2000000000003
# Num buys: 261
# Num sells: 355
# Num trades: 616
# Num wins: 252
# Num losses: 363
# Win streak: 13
# Loss streak: 28
# Remaining runs: 600
# Best reward so far: 774.7000000000321
#
# -1457.8999999999678
# Num buys: 63
# Num sells: 45
# Num trades: 108
# Num wins: 36
# Num losses: 71
# Win streak: 7
# Loss streak: 16
# Remaining runs: 599
# Best reward so far: 774.7000000000321
#
# -1044.8999999999755
# Num buys: 166
# Num sells: 155
# Num trades: 321
# Num wins: 120
# Num losses: 198
# Win streak: 9
# Loss streak: 19
# Remaining runs: 598
# Best reward so far: 774.7000000000321
#
# -146.29999999999666
# Num buys: 62
# Num sells: 59
# Num trades: 121
# Num wins: 53
# Num losses: 68
# Win streak: 10
# Loss streak: 9
# Remaining runs: 597
# Best reward so far: 774.7000000000321
#
# -20438.19999999991
# Num buys: 1148
# Num sells: 1388
# Num trades: 2536
# Num wins: 917
# Num losses: 1613
# Win streak: 31
# Loss streak: 49
# Remaining runs: 596
# Best reward so far: 774.7000000000321
#
# 221.5000000000108
# Num buys: 67
# Num sells: 62
# Num trades: 129
# Num wins: 53
# Num losses: 76
# Win streak: 7
# Loss streak: 15
# Remaining runs: 595
# Best reward so far: 774.7000000000321
#
# -2919.500000000019
# Num buys: 221
# Num sells: 281
# Num trades: 502
# Num wins: 190
# Num losses: 308
# Win streak: 14
# Loss streak: 22
# Remaining runs: 594
# Best reward so far: 774.7000000000321
#
# -3946.6999999999525
# Num buys: 490
# Num sells: 0
# Num trades: 490
# Num wins: 165
# Num losses: 324
# Win streak: 11
# Loss streak: 27
# Remaining runs: 593
# Best reward so far: 774.7000000000321
#
# -2892.6999999999694
# Num buys: 281
# Num sells: 364
# Num trades: 645
# Num wins: 253
# Num losses: 388
# Win streak: 11
# Loss streak: 16
# Remaining runs: 592
# Best reward so far: 774.7000000000321
#
# -4462.499999999933
# Num buys: 656
# Num sells: 0
# Num trades: 656
# Num wins: 231
# Num losses: 424
# Win streak: 14
# Loss streak: 22
# Remaining runs: 591
# Best reward so far: 774.7000000000321
#
# -1099.7999999999702
# Num buys: 92
# Num sells: 84
# Num trades: 176
# Num wins: 75
# Num losses: 101
# Win streak: 10
# Loss streak: 13
# Remaining runs: 590
# Best reward so far: 774.7000000000321
#
# -12682.899999999947
# Num buys: 1048
# Num sells: 1338
# Num trades: 2386
# Num wins: 903
# Num losses: 1476
# Win streak: 26
# Loss streak: 58
# Remaining runs: 589
# Best reward so far: 774.7000000000321
#
# -4934.799999999931
# Num buys: 643
# Num sells: 819
# Num trades: 1462
# Num wins: 523
# Num losses: 937
# Win streak: 21
# Loss streak: 52
# Remaining runs: 588
# Best reward so far: 774.7000000000321
#
# -2588.7999999999593
# Num buys: 466
# Num sells: 605
# Num trades: 1071
# Num wins: 406
# Num losses: 664
# Win streak: 19
# Loss streak: 29
# Remaining runs: 587
# Best reward so far: 774.7000000000321
#
# -4724.799999999982
# Num buys: 295
# Num sells: 263
# Num trades: 558
# Num wins: 199
# Num losses: 358
# Win streak: 12
# Loss streak: 27
# Remaining runs: 586
# Best reward so far: 774.7000000000321
#
# -692.1999999999925
# Num buys: 174
# Num sells: 237
# Num trades: 411
# Num wins: 149
# Num losses: 261
# Win streak: 11
# Loss streak: 22
# Remaining runs: 585
# Best reward so far: 774.7000000000321
#
# -3341.599999999983
# Num buys: 192
# Num sells: 805
# Num trades: 997
# Num wins: 375
# Num losses: 618
# Win streak: 18
# Loss streak: 30
# Remaining runs: 584
# Best reward so far: 774.7000000000321
#
# -526.8999999999725
# Num buys: 266
# Num sells: 362
# Num trades: 628
# Num wins: 241
# Num losses: 387
# Win streak: 10
# Loss streak: 30
# Remaining runs: 583
# Best reward so far: 774.7000000000321
#
# -8923.999999999989
# Num buys: 739
# Num sells: 988
# Num trades: 1727
# Num wins: 652
# Num losses: 1069
# Win streak: 28
# Loss streak: 62
# Remaining runs: 582
# Best reward so far: 774.7000000000321
#
# -6053.899999999987
# Num buys: 313
# Num sells: 1328
# Num trades: 1641
# Num wins: 585
# Num losses: 1052
# Win streak: 20
# Loss streak: 55
# Remaining runs: 581
# Best reward so far: 774.7000000000321
#
# -2846.4999999999604
# Num buys: 314
# Num sells: 0
# Num trades: 314
# Num wins: 89
# Num losses: 225
# Win streak: 10
# Loss streak: 33
# Remaining runs: 580
# Best reward so far: 774.7000000000321
#
# -852.5999999999555
# Num buys: 247
# Num sells: 336
# Num trades: 583
# Num wins: 234
# Num losses: 348
# Win streak: 14
# Loss streak: 29
# Remaining runs: 579
# Best reward so far: 774.7000000000321
#
# -11302.199999999895
# Num buys: 1284
# Num sells: 0
# Num trades: 1284
# Num wins: 430
# Num losses: 852
# Win streak: 25
# Loss streak: 58
# Remaining runs: 578
# Best reward so far: 774.7000000000321
#
# 744.1000000000508
# Num buys: 249
# Num sells: 350
# Num trades: 599
# Num wins: 245
# Num losses: 349
# Win streak: 18
# Loss streak: 20
# Remaining runs: 577
# Best reward so far: 774.7000000000321
#
# -2051.3999999999987
# Num buys: 272
# Num sells: 373
# Num trades: 645
# Num wins: 264
# Num losses: 379
# Win streak: 16
# Loss streak: 29
# Remaining runs: 576
# Best reward so far: 774.7000000000321
#
# -4436.9000000000115
# Num buys: 432
# Num sells: 562
# Num trades: 994
# Num wins: 381
# Num losses: 608
# Win streak: 17
# Loss streak: 33
# Remaining runs: 575
# Best reward so far: 774.7000000000321
#
# -2135.7999999999747
# Num buys: 220
# Num sells: 297
# Num trades: 517
# Num wins: 200
# Num losses: 317
# Win streak: 11
# Loss streak: 23
# Remaining runs: 574
# Best reward so far: 774.7000000000321
#
# -288.6999999999878
# Num buys: 66
# Num sells: 62
# Num trades: 128
# Num wins: 47
# Num losses: 80
# Win streak: 7
# Loss streak: 14
# Remaining runs: 573
# Best reward so far: 774.7000000000321
#
# -8612.599999999973
# Num buys: 591
# Num sells: 712
# Num trades: 1303
# Num wins: 497
# Num losses: 801
# Win streak: 18
# Loss streak: 37
# Remaining runs: 572
# Best reward so far: 774.7000000000321
#
# -3378.3999999999505
# Num buys: 471
# Num sells: 0
# Num trades: 471
# Num wins: 155
# Num losses: 315
# Win streak: 11
# Loss streak: 27
# Remaining runs: 571
# Best reward so far: 774.7000000000321
#
# -2734.2000000000244
# Num buys: 189
# Num sells: 800
# Num trades: 989
# Num wins: 360
# Num losses: 627
# Win streak: 18
# Loss streak: 32
# Remaining runs: 570
# Best reward so far: 774.7000000000321
#
# -15483.800000000003
# Num buys: 1041
# Num sells: 1326
# Num trades: 2367
# Num wins: 896
# Num losses: 1465
# Win streak: 30
# Loss streak: 64
# Remaining runs: 569
# Best reward so far: 774.7000000000321
#
# -2965.8999999999824
# Num buys: 275
# Num sells: 241
# Num trades: 516
# Num wins: 187
# Num losses: 328
# Win streak: 13
# Loss streak: 18
# Remaining runs: 568
# Best reward so far: 774.7000000000321
#
# -6849.699999999927
# Num buys: 747
# Num sells: 0
# Num trades: 747
# Num wins: 251
# Num losses: 495
# Win streak: 17
# Loss streak: 34
# Remaining runs: 567
# Best reward so far: 774.7000000000321
#
# -2625.2999999999693
# Num buys: 278
# Num sells: 357
# Num trades: 635
# Num wins: 250
# Num losses: 382
# Win streak: 10
# Loss streak: 16
# Remaining runs: 566
# Best reward so far: 774.7000000000321
#
# -6156.400000000034
# Num buys: 519
# Num sells: 634
# Num trades: 1153
# Num wins: 442
# Num losses: 710
# Win streak: 16
# Loss streak: 34
# Remaining runs: 565
# Best reward so far: 774.7000000000321
#
# -52.59999999999796
# Num buys: 23
# Num sells: 23
# Num trades: 46
# Num wins: 18
# Num losses: 28
# Win streak: 4
# Loss streak: 7
# Remaining runs: 564
# Best reward so far: 774.7000000000321
#
# -140.19999999999598
# Num buys: 15
# Num sells: 15
# Num trades: 30
# Num wins: 12
# Num losses: 18
# Win streak: 3
# Loss streak: 7
# Remaining runs: 563
# Best reward so far: 774.7000000000321
#
# -1644.1999999999894
# Num buys: 168
# Num sells: 160
# Num trades: 328
# Num wins: 113
# Num losses: 213
# Win streak: 10
# Loss streak: 22
# Remaining runs: 562
# Best reward so far: 774.7000000000321
#
# -9770.799999999974
# Num buys: 591
# Num sells: 724
# Num trades: 1315
# Num wins: 483
# Num losses: 827
# Win streak: 22
# Loss streak: 35
# Remaining runs: 561
# Best reward so far: 774.7000000000321
#
# -3932.29999999998
# Num buys: 241
# Num sells: 296
# Num trades: 537
# Num wins: 210
# Num losses: 325
# Win streak: 10
# Loss streak: 15
# Remaining runs: 560
# Best reward so far: 774.7000000000321
#
# -4599.699999999997
# Num buys: 263
# Num sells: 335
# Num trades: 598
# Num wins: 219
# Num losses: 374
# Win streak: 15
# Loss streak: 27
# Remaining runs: 559
# Best reward so far: 774.7000000000321
#
# -959.6999999999649
# Num buys: 135
# Num sells: 187
# Num trades: 322
# Num wins: 122
# Num losses: 198
# Win streak: 12
# Loss streak: 21
# Remaining runs: 558
# Best reward so far: 774.7000000000321
#
# -6662.299999999922
# Num buys: 781
# Num sells: 1042
# Num trades: 1823
# Num wins: 697
# Num losses: 1121
# Win streak: 23
# Loss streak: 45
# Remaining runs: 557
# Best reward so far: 774.7000000000321
#
# -5788.899999999984
# Num buys: 358
# Num sells: 456
# Num trades: 814
# Num wins: 302
# Num losses: 507
# Win streak: 18
# Loss streak: 23
# Remaining runs: 556
# Best reward so far: 774.7000000000321
#
# -912.7999999999639
# Num buys: 264
# Num sells: 367
# Num trades: 631
# Num wins: 242
# Num losses: 388
# Win streak: 11
# Loss streak: 30
# Remaining runs: 555
# Best reward so far: 774.7000000000321
#
# -3478.799999999949
# Num buys: 485
# Num sells: 0
# Num trades: 485
# Num wins: 153
# Num losses: 332
# Win streak: 11
# Loss streak: 26
# Remaining runs: 554
# Best reward so far: 774.7000000000321
#
# -626.0999999999796
# Num buys: 68
# Num sells: 49
# Num trades: 117
# Num wins: 41
# Num losses: 76
# Win streak: 8
# Loss streak: 13
# Remaining runs: 553
# Best reward so far: 774.7000000000321
#
# -2054.9999999999923
# Num buys: 212
# Num sells: 191
# Num trades: 403
# Num wins: 132
# Num losses: 270
# Win streak: 10
# Loss streak: 18
# Remaining runs: 552
# Best reward so far: 774.7000000000321
#
# -3765.1999999999707
# Num buys: 186
# Num sells: 772
# Num trades: 958
# Num wins: 335
# Num losses: 621
# Win streak: 16
# Loss streak: 32
# Remaining runs: 551
# Best reward so far: 774.7000000000321
#
# -4355.599999999901
# Num buys: 314
# Num sells: 1328
# Num trades: 1642
# Num wins: 589
# Num losses: 1050
# Win streak: 20
# Loss streak: 54
# Remaining runs: 550
# Best reward so far: 774.7000000000321
#
# -1052.7999999999727
# Num buys: 172
# Num sells: 156
# Num trades: 328
# Num wins: 134
# Num losses: 194
# Win streak: 9
# Loss streak: 17
# Remaining runs: 549
# Best reward so far: 774.7000000000321
#
# -1026.8999999999917
# Num buys: 165
# Num sells: 220
# Num trades: 385
# Num wins: 142
# Num losses: 241
# Win streak: 7
# Loss streak: 22
# Remaining runs: 548
# Best reward so far: 774.7000000000321
#
# -351.2999999999923
# Num buys: 23
# Num sells: 23
# Num trades: 46
# Num wins: 15
# Num losses: 31
# Win streak: 4
# Loss streak: 7
# Remaining runs: 547
# Best reward so far: 774.7000000000321
#
# -870.1999999999728
# Num buys: 285
# Num sells: 385
# Num trades: 670
# Num wins: 253
# Num losses: 416
# Win streak: 17
# Loss streak: 29
# Remaining runs: 546
# Best reward so far: 774.7000000000321
#
# -7951.099999999993
# Num buys: 736
# Num sells: 988
# Num trades: 1724
# Num wins: 662
# Num losses: 1056
# Win streak: 28
# Loss streak: 62
# Remaining runs: 545
# Best reward so far: 774.7000000000321
#
# -1555.6999999999698
# Num buys: 139
# Num sells: 120
# Num trades: 259
# Num wins: 91
# Num losses: 168
# Win streak: 8
# Loss streak: 13
# Remaining runs: 544
# Best reward so far: 774.7000000000321
#
# -4082.4000000000005
# Num buys: 190
# Num sells: 230
# Num trades: 420
# Num wins: 154
# Num losses: 265
# Win streak: 12
# Loss streak: 21
# Remaining runs: 543
# Best reward so far: 774.7000000000321
#
# -6109.799999999918
# Num buys: 802
# Num sells: 1073
# Num trades: 1875
# Num wins: 691
# Num losses: 1178
# Win streak: 24
# Loss streak: 65
# Remaining runs: 542
# Best reward so far: 774.7000000000321
#
# -1577.7999999999747
# Num buys: 218
# Num sells: 181
# Num trades: 399
# Num wins: 141
# Num losses: 258
# Win streak: 11
# Loss streak: 20
# Remaining runs: 541
# Best reward so far: 774.7000000000321
#
# -258.59999999998035
# Num buys: 53
# Num sells: 66
# Num trades: 119
# Num wins: 42
# Num losses: 76
# Win streak: 5
# Loss streak: 10
# Remaining runs: 540
# Best reward so far: 774.7000000000321
#
# -729.5999999999938
# Num buys: 144
# Num sells: 185
# Num trades: 329
# Num wins: 116
# Num losses: 213
# Win streak: 11
# Loss streak: 21
# Remaining runs: 539
# Best reward so far: 774.7000000000321
#
# -746.4999999999686
# Num buys: 345
# Num sells: 49
# Num trades: 394
# Num wins: 134
# Num losses: 260
# Win streak: 8
# Loss streak: 24
# Remaining runs: 538
# Best reward so far: 774.7000000000321
#
# -5535.099999999993
# Num buys: 415
# Num sells: 560
# Num trades: 975
# Num wins: 366
# Num losses: 604
# Win streak: 17
# Loss streak: 32
# Remaining runs: 537
# Best reward so far: 774.7000000000321
#
# -2512.7999999999993
# Num buys: 169
# Num sells: 154
# Num trades: 323
# Num wins: 112
# Num losses: 211
# Win streak: 9
# Loss streak: 16
# Remaining runs: 536
# Best reward so far: 774.7000000000321
#
# -2224.39999999996
# Num buys: 467
# Num sells: 605
# Num trades: 1072
# Num wins: 404
# Num losses: 666
# Win streak: 19
# Loss streak: 30
# Remaining runs: 535
# Best reward so far: 774.7000000000321
#
# -10715.699999999968
# Num buys: 500
# Num sells: 593
# Num trades: 1093
# Num wins: 392
# Num losses: 697
# Win streak: 16
# Loss streak: 28
# Remaining runs: 534
# Best reward so far: 774.7000000000321
#
# -1173.399999999945
# Num buys: 260
# Num sells: 364
# Num trades: 624
# Num wins: 252
# Num losses: 369
# Win streak: 15
# Loss streak: 18
# Remaining runs: 533
# Best reward so far: 774.7000000000321
#
# -1093.3000000000309
# Num buys: 65
# Num sells: 314
# Num trades: 379
# Num wins: 137
# Num losses: 240
# Win streak: 13
# Loss streak: 15
# Remaining runs: 532
# Best reward so far: 774.7000000000321
#
# -654.0000000000084
# Num buys: 166
# Num sells: 225
# Num trades: 391
# Num wins: 164
# Num losses: 224
# Win streak: 10
# Loss streak: 20
# Remaining runs: 531
# Best reward so far: 774.7000000000321
#
# -5217.699999999897
# Num buys: 729
# Num sells: 8
# Num trades: 737
# Num wins: 218
# Num losses: 519
# Win streak: 15
# Loss streak: 55
# Remaining runs: 530
# Best reward so far: 774.7000000000321
#
# -773.4999999999958
# Num buys: 173
# Num sells: 229
# Num trades: 402
# Num wins: 154
# Num losses: 247
# Win streak: 10
# Loss streak: 22
# Remaining runs: 529
# Best reward so far: 774.7000000000321
#
# -2380.7999999999683
# Num buys: 328
# Num sells: 0
# Num trades: 328
# Num wins: 93
# Num losses: 235
# Win streak: 9
# Loss streak: 26
# Remaining runs: 528
# Best reward so far: 774.7000000000321
#
# -1381.2999999999731
# Num buys: 127
# Num sells: 579
# Num trades: 706
# Num wins: 266
# Num losses: 438
# Win streak: 12
# Loss streak: 20
# Remaining runs: 527
# Best reward so far: 774.7000000000321
#
# -3295.599999999939
# Num buys: 195
# Num sells: 813
# Num trades: 1008
# Num wins: 367
# Num losses: 640
# Win streak: 12
# Loss streak: 32
# Remaining runs: 526
# Best reward so far: 774.7000000000321
#
# -7466.29999999992
# Num buys: 747
# Num sells: 997
# Num trades: 1744
# Num wins: 659
# Num losses: 1080
# Win streak: 21
# Loss streak: 44
# Remaining runs: 525
# Best reward so far: 774.7000000000321
#
# -17855.799999999945
# Num buys: 1166
# Num sells: 1450
# Num trades: 2616
# Num wins: 951
# Num losses: 1659
# Win streak: 31
# Loss streak: 64
# Remaining runs: 524
# Best reward so far: 774.7000000000321
#
# 375.00000000004184
# Num buys: 87
# Num sells: 113
# Num trades: 200
# Num wins: 91
# Num losses: 109
# Win streak: 7
# Loss streak: 9
# Remaining runs: 523
# Best reward so far: 774.7000000000321
#
# -1787.0999999999824
# Num buys: 106
# Num sells: 476
# Num trades: 582
# Num wins: 214
# Num losses: 368
# Win streak: 9
# Loss streak: 20
# Remaining runs: 522
# Best reward so far: 774.7000000000321
#
# -611.9999999999941
# Num buys: 144
# Num sells: 185
# Num trades: 329
# Num wins: 119
# Num losses: 210
# Win streak: 11
# Loss streak: 21
# Remaining runs: 521
# Best reward so far: 774.7000000000321
#
# -365.59999999994966
# Num buys: 264
# Num sells: 360
# Num trades: 624
# Num wins: 242
# Num losses: 381
# Win streak: 12
# Loss streak: 31
# Remaining runs: 520
# Best reward so far: 774.7000000000321
#
# -10029.999999999965
# Num buys: 593
# Num sells: 724
# Num trades: 1317
# Num wins: 482
# Num losses: 830
# Win streak: 21
# Loss streak: 35
# Remaining runs: 519
# Best reward so far: 774.7000000000321
#
# -6521.599999999906
# Num buys: 795
# Num sells: 1054
# Num trades: 1849
# Num wins: 680
# Num losses: 1161
# Win streak: 23
# Loss streak: 65
# Remaining runs: 518
# Best reward so far: 774.7000000000321
#
# -4637.299999999886
# Num buys: 578
# Num sells: 1071
# Num trades: 1649
# Num wins: 587
# Num losses: 1059
# Win streak: 19
# Loss streak: 42
# Remaining runs: 517
# Best reward so far: 774.7000000000321
#
# -2609.3999999999855
# Num buys: 268
# Num sells: 366
# Num trades: 634
# Num wins: 264
# Num losses: 365
# Win streak: 9
# Loss streak: 25
# Remaining runs: 516
# Best reward so far: 774.7000000000321
#
# -438.899999999953
# Num buys: 299
# Num sells: 47
# Num trades: 346
# Num wins: 142
# Num losses: 204
# Win streak: 12
# Loss streak: 17
# Remaining runs: 515
# Best reward so far: 774.7000000000321
#
# -19606.499999999905
# Num buys: 1169
# Num sells: 1441
# Num trades: 2610
# Num wins: 945
# Num losses: 1659
# Win streak: 31
# Loss streak: 57
# Remaining runs: 514
# Best reward so far: 774.7000000000321
#
# -881.6999999999978
# Num buys: 167
# Num sells: 220
# Num trades: 387
# Num wins: 139
# Num losses: 247
# Win streak: 9
# Loss streak: 22
# Remaining runs: 513
# Best reward so far: 774.7000000000321
#
# -3617.7999999999656
# Num buys: 328
# Num sells: 288
# Num trades: 616
# Num wins: 208
# Num losses: 407
# Win streak: 15
# Loss streak: 22
# Remaining runs: 512
# Best reward so far: 774.7000000000321
#
# -2742.3999999999887
# Num buys: 194
# Num sells: 174
# Num trades: 368
# Num wins: 133
# Num losses: 235
# Win streak: 10
# Loss streak: 16
# Remaining runs: 511
# Best reward so far: 774.7000000000321
#
# -6781.099999999989
# Num buys: 623
# Num sells: 785
# Num trades: 1408
# Num wins: 526
# Num losses: 876
# Win streak: 19
# Loss streak: 38
# Remaining runs: 510
# Best reward so far: 774.7000000000321
#
# -462.8999999999708
# Num buys: 58
# Num sells: 77
# Num trades: 135
# Num wins: 55
# Num losses: 80
# Win streak: 12
# Loss streak: 9
# Remaining runs: 509
# Best reward so far: 774.7000000000321
#
# -4499.199999999933
# Num buys: 506
# Num sells: 454
# Num trades: 960
# Num wins: 350
# Num losses: 606
# Win streak: 15
# Loss streak: 32
# Remaining runs: 508
# Best reward so far: 774.7000000000321
#
# -4568.999999999883
# Num buys: 329
# Num sells: 1396
# Num trades: 1725
# Num wins: 627
# Num losses: 1095
# Win streak: 20
# Loss streak: 54
# Remaining runs: 507
# Best reward so far: 774.7000000000321
#
# -6233.699999999884
# Num buys: 1069
# Num sells: 125
# Num trades: 1194
# Num wins: 400
# Num losses: 794
# Win streak: 18
# Loss streak: 57
# Remaining runs: 506
# ...
# Num losses: 415
# Win streak: 15
# Loss streak: 20
# Remaining runs: 383
# Best reward so far: 774.7000000000321
#
# -783.0999999999644
# Num buys: 136
# Num sells: 367
# Num trades: 503
# Num wins: 192
# Num losses: 310
# Win streak: 14
# Loss streak: 24
# Remaining runs: 382
# Best reward so far: 774.7000000000321
#
# -170.59999999997854
# Num buys: 21
# Num sells: 19
# Num trades: 40
# Num wins: 15
# Num losses: 25
# Win streak: 9
# Loss streak: 7
# Remaining runs: 381
# Best reward so far: 774.7000000000321
#
# -20456.29999999995
# Num buys: 1005
# Num sells: 1198
# Num trades: 2203
# Num wins: 797
# Num losses: 1401
# Win streak: 29
# Loss streak: 54
# Remaining runs: 380
# Best reward so far: 774.7000000000321
#
# -3314.199999999976
# Num buys: 281
# Num sells: 364
# Num trades: 645
# Num wins: 252
# Num losses: 388
# Win streak: 11
# Loss streak: 16
# Remaining runs: 379
# Best reward so far: 774.7000000000321
#
# -376.0999999999753
# Num buys: 285
# Num sells: 32
# Num trades: 317
# Num wins: 107
# Num losses: 210
# Win streak: 8
# Loss streak: 17
# Remaining runs: 378
# Best reward so far: 774.7000000000321
#
# -3994.4999999999145
# Num buys: 557
# Num sells: 11
# Num trades: 568
# Num wins: 207
# Num losses: 360
# Win streak: 13
# Loss streak: 31
# Remaining runs: 377
# Best reward so far: 774.7000000000321
#
# -34.49999999999508
# Num buys: 15
# Num sells: 15
# Num trades: 30
# Num wins: 12
# Num losses: 18
# Win streak: 3
# Loss streak: 6
# Remaining runs: 376
# Best reward so far: 774.7000000000321
#
# -4859.199999999986
# Num buys: 435
# Num sells: 552
# Num trades: 987
# Num wins: 382
# Num losses: 601
# Win streak: 17
# Loss streak: 22
# Remaining runs: 375
# Best reward so far: 774.7000000000321
#
# -20398.199999999873
# Num buys: 1097
# Num sells: 1322
# Num trades: 2419
# Num wins: 873
# Num losses: 1540
# Win streak: 29
# Loss streak: 61
# Remaining runs: 374
# Best reward so far: 774.7000000000321
#
# -2821.5999999999776
# Num buys: 288
# Num sells: 0
# Num trades: 288
# Num wins: 96
# Num losses: 191
# Win streak: 8
# Loss streak: 20
# Remaining runs: 373
# Best reward so far: 774.7000000000321
#
# -685.1999999999689
# Num buys: 172
# Num sells: 155
# Num trades: 327
# Num wins: 125
# Num losses: 202
# Win streak: 10
# Loss streak: 17
# Remaining runs: 372
# Best reward so far: 774.7000000000321
#
# -3156.5999999999585
# Num buys: 219
# Num sells: 904
# Num trades: 1123
# Num wins: 419
# Num losses: 700
# Win streak: 21
# Loss streak: 30
# Remaining runs: 371
# Best reward so far: 774.7000000000321
#
# -2846.900000000033
# Num buys: 223
# Num sells: 284
# Num trades: 507
# Num wins: 198
# Num losses: 306
# Win streak: 15
# Loss streak: 15
# Remaining runs: 370
# Best reward so far: 774.7000000000321
#
# -3070.4999999999345
# Num buys: 252
# Num sells: 357
# Num trades: 609
# Num wins: 221
# Num losses: 383
# Win streak: 18
# Loss streak: 20
# Remaining runs: 369
# Best reward so far: 774.7000000000321
#
# -7226.899999999992
# Num buys: 297
# Num sells: 366
# Num trades: 663
# Num wins: 238
# Num losses: 423
# Win streak: 15
# Loss streak: 20
# Remaining runs: 368
# Best reward so far: 774.7000000000321
#
# -2557.0999999999713
# Num buys: 301
# Num sells: 0
# Num trades: 301
# Num wins: 97
# Num losses: 204
# Win streak: 8
# Loss streak: 20
# Remaining runs: 367
# Best reward so far: 774.7000000000321
#
# -2253.3999999999564
# Num buys: 193
# Num sells: 808
# Num trades: 1001
# Num wins: 368
# Num losses: 632
# Win streak: 13
# Loss streak: 32
# Remaining runs: 366
# Best reward so far: 774.7000000000321
#
# -92.29999999998864
# Num buys: 173
# Num sells: 19
# Num trades: 192
# Num wins: 67
# Num losses: 125
# Win streak: 9
# Loss streak: 10
# Remaining runs: 365
# Best reward so far: 774.7000000000321
#
# 261.70000000006394
# Num buys: 238
# Num sells: 339
# Num trades: 577
# Num wins: 237
# Num losses: 335
# Win streak: 18
# Loss streak: 19
# Remaining runs: 364
# Best reward so far: 774.7000000000321
#
# -11120.799999999897
# Num buys: 1255
# Num sells: 0
# Num trades: 1255
# Num wins: 420
# Num losses: 835
# Win streak: 22
# Loss streak: 56
# Remaining runs: 363
# Best reward so far: 774.7000000000321
#
# -724.0999999999973
# Num buys: 173
# Num sells: 229
# Num trades: 402
# Num wins: 154
# Num losses: 247
# Win streak: 10
# Loss streak: 22
# Remaining runs: 362
# Best reward so far: 774.7000000000321
#
# -1406.2000000000085
# Num buys: 161
# Num sells: 216
# Num trades: 377
# Num wins: 151
# Num losses: 225
# Win streak: 8
# Loss streak: 20
# Remaining runs: 361
# Best reward so far: 774.7000000000321
#
# -2023.9000000000262
# Num buys: 160
# Num sells: 224
# Num trades: 384
# Num wins: 153
# Num losses: 228
# Win streak: 10
# Loss streak: 20
# Remaining runs: 360
# Best reward so far: 774.7000000000321
#
# -5864.4999999999445
# Num buys: 736
# Num sells: 0
# Num trades: 736
# Num wins: 249
# Num losses: 486
# Win streak: 17
# Loss streak: 33
# Remaining runs: 359
# Best reward so far: 774.7000000000321
#
# -25.599999999978593
# Num buys: 43
# Num sells: 54
# Num trades: 97
# Num wins: 39
# Num losses: 57
# Win streak: 4
# Loss streak: 13
# Remaining runs: 358
# Best reward so far: 774.7000000000321
#
# -11520.899999999987
# Num buys: 691
# Num sells: 856
# Num trades: 1547
# Num wins: 566
# Num losses: 976
# Win streak: 30
# Loss streak: 34
# Remaining runs: 357
# Best reward so far: 774.7000000000321
#
# -1947.3000000000195
# Num buys: 88
# Num sells: 408
# Num trades: 496
# Num wins: 178
# Num losses: 318
# Win streak: 12
# Loss streak: 21
# Remaining runs: 356
# Best reward so far: 774.7000000000321
#
# -11199.299999999981
# Num buys: 712
# Num sells: 957
# Num trades: 1669
# Num wins: 617
# Num losses: 1047
# Win streak: 25
# Loss streak: 44
# Remaining runs: 355
# Best reward so far: 774.7000000000321
#
# -1807.5000000000116
# Num buys: 162
# Num sells: 152
# Num trades: 314
# Num wins: 119
# Num losses: 194
# Win streak: 8
# Loss streak: 16
# Remaining runs: 354
# Best reward so far: 774.7000000000321
#
# -504.89999999998446
# Num buys: 23
# Num sells: 23
# Num trades: 46
# Num wins: 15
# Num losses: 31
# Win streak: 4
# Loss streak: 7
# Remaining runs: 353
# Best reward so far: 774.7000000000321
#
# -769.8999999999852
# Num buys: 91
# Num sells: 244
# Num trades: 335
# Num wins: 125
# Num losses: 209
# Win streak: 9
# Loss streak: 25
# Remaining runs: 352
# Best reward so far: 774.7000000000321
#
# -7322.100000000003
# Num buys: 424
# Num sells: 536
# Num trades: 960
# Num wins: 357
# Num losses: 598
# Win streak: 20
# Loss streak: 24
# Remaining runs: 351
# Best reward so far: 774.7000000000321
#
# -2830.2999999999715
# Num buys: 274
# Num sells: 342
# Num trades: 616
# Num wins: 238
# Num losses: 375
# Win streak: 9
# Loss streak: 17
# Remaining runs: 350
# Best reward so far: 774.7000000000321
#
# -3988.2999999999493
# Num buys: 468
# Num sells: 0
# Num trades: 468
# Num wins: 156
# Num losses: 312
# Win streak: 11
# Loss streak: 27
# Remaining runs: 349
# Best reward so far: 774.7000000000321
#
# -2321.1999999999684
# Num buys: 279
# Num sells: 383
# Num trades: 662
# Num wins: 264
# Num losses: 394
# Win streak: 12
# Loss streak: 29
# Remaining runs: 348
# Best reward so far: 774.7000000000321
#
# -8432.799999999957
# Num buys: 765
# Num sells: 1014
# Num trades: 1779
# Num wins: 666
# Num losses: 1108
# Win streak: 34
# Loss streak: 44
# Remaining runs: 347
# Best reward so far: 774.7000000000321
#
# -1965.1000000000267
# Num buys: 273
# Num sells: 375
# Num trades: 648
# Num wins: 257
# Num losses: 387
# Win streak: 14
# Loss streak: 24
# Remaining runs: 346
# Best reward so far: 774.7000000000321
#
# -8433.799999999952
# Num buys: 706
# Num sells: 882
# Num trades: 1588
# Num wins: 603
# Num losses: 980
# Win streak: 26
# Loss streak: 41
# Remaining runs: 345
# Best reward so far: 774.7000000000321
#
# -3115.299999999973
# Num buys: 270
# Num sells: 243
# Num trades: 513
# Num wins: 173
# Num losses: 339
# Win streak: 14
# Loss streak: 23
# Remaining runs: 344
# Best reward so far: 774.7000000000321
#
# -1023.6999999999944
# Num buys: 106
# Num sells: 97
# Num trades: 203
# Num wins: 81
# Num losses: 122
# Win streak: 8
# Loss streak: 13
# Remaining runs: 343
# Best reward so far: 774.7000000000321
#
# -440.7999999999985
# Num buys: 35
# Num sells: 32
# Num trades: 67
# Num wins: 25
# Num losses: 42
# Win streak: 6
# Loss streak: 9
# Remaining runs: 342
# Best reward so far: 774.7000000000321
#
# -3104.5999999999294
# Num buys: 187
# Num sells: 772
# Num trades: 959
# Num wins: 342
# Num losses: 616
# Win streak: 12
# Loss streak: 33
# Remaining runs: 341
# Best reward so far: 774.7000000000321
#
# -2379.50000000001
# Num buys: 273
# Num sells: 354
# Num trades: 627
# Num wins: 252
# Num losses: 371
# Win streak: 11
# Loss streak: 15
# Remaining runs: 340
# Best reward so far: 774.7000000000321
#
# -5474.899999999922
# Num buys: 757
# Num sells: 8
# Num trades: 765
# Num wins: 226
# Num losses: 539
# Win streak: 15
# Loss streak: 57
# Remaining runs: 339
# Best reward so far: 774.7000000000321
#
# -680.7999999999422
# Num buys: 248
# Num sells: 340
# Num trades: 588
# Num wins: 223
# Num losses: 365
# Win streak: 10
# Loss streak: 38
# Remaining runs: 338
# Best reward so far: 774.7000000000321
#
# -702.8999999999601
# Num buys: 180
# Num sells: 232
# Num trades: 412
# Num wins: 158
# Num losses: 254
# Win streak: 15
# Loss streak: 18
# Remaining runs: 337
# Best reward so far: 774.7000000000321
#
# -856.0000000000002
# Num buys: 110
# Num sells: 103
# Num trades: 213
# Num wins: 73
# Num losses: 139
# Win streak: 9
# Loss streak: 18
# Remaining runs: 336
# Best reward so far: 774.7000000000321
#
# -2591.4999999999695
# Num buys: 246
# Num sells: 299
# Num trades: 545
# Num wins: 216
# Num losses: 327
# Win streak: 10
# Loss streak: 16
# Remaining runs: 335
# Best reward so far: 774.7000000000321
#
# -5167.999999999996
# Num buys: 279
# Num sells: 1112
# Num trades: 1391
# Num wins: 486
# Num losses: 905
# Win streak: 20
# Loss streak: 52
# Remaining runs: 334
# Best reward so far: 774.7000000000321
#
# -526.2999999999589
# Num buys: 264
# Num sells: 367
# Num trades: 631
# Num wins: 243
# Num losses: 388
# Win streak: 12
# Loss streak: 30
# Remaining runs: 333
# Best reward so far: 774.7000000000321
#
# -1073.1999999999962
# Num buys: 167
# Num sells: 220
# Num trades: 387
# Num wins: 135
# Num losses: 251
# Win streak: 9
# Loss streak: 22
# Remaining runs: 332
# Best reward so far: 774.7000000000321
#
# -685.999999999995
# Num buys: 108
# Num sells: 101
# Num trades: 209
# Num wins: 83
# Num losses: 126
# Win streak: 9
# Loss streak: 12
# Remaining runs: 331
# Best reward so far: 774.7000000000321
#
# -9092.599999999968
# Num buys: 574
# Num sells: 702
# Num trades: 1276
# Num wins: 469
# Num losses: 802
# Win streak: 19
# Loss streak: 34
# Remaining runs: 330
# Best reward so far: 774.7000000000321
#
# 29.10000000001537
# Num buys: 87
# Num sells: 117
# Num trades: 204
# Num wins: 84
# Num losses: 120
# Win streak: 7
# Loss streak: 15
# Remaining runs: 329
# Best reward so far: 774.7000000000321
#
# -14115.199999999943
# Num buys: 1054
# Num sells: 1351
# Num trades: 2405
# Num wins: 891
# Num losses: 1507
# Win streak: 29
# Loss streak: 58
# Remaining runs: 328
# Best reward so far: 774.7000000000321
#
# -324.3999999999909
# Num buys: 53
# Num sells: 68
# Num trades: 121
# Num wins: 42
# Num losses: 79
# Win streak: 6
# Loss streak: 9
# Remaining runs: 327
# Best reward so far: 774.7000000000321
#
# -983.6999999999866
# Num buys: 67
# Num sells: 43
# Num trades: 110
# Num wins: 38
# Num losses: 72
# Win streak: 7
# Loss streak: 14
# Remaining runs: 326
# Best reward so far: 774.7000000000321
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/y1/r6lw81g960n148db75yhq7140000gn/T/ipykernel_70739/3514014092.py in <module>
#      40
#      41 for risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length in combos_to_try:
# ---> 42   reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak = run_simulation(risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length)
#      43   runs_finished += 1
#      44
#
# /var/folders/y1/r6lw81g960n148db75yhq7140000gn/T/ipykernel_70739/2957063881.py in run_simulation(risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars, fractal_distance, bar_length, max_open_trades)
#     276
#     277         if process_trade:
# --> 278           iterate_thru_small_data(trades[-1])
#     279
#     280         i += 1
#
# /var/folders/y1/r6lw81g960n148db75yhq7140000gn/T/ipykernel_70739/2957063881.py in iterate_thru_small_data(trade)
#      45           curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, curr_date = \
#      46           df_small.loc[df_small.index[j], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low',
# ---> 47                                          'Ask_Close', 'Date']]
#      48
#      49           if trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     829                     return section
#     830                 # This is an elided recursive call to iloc/loc
# --> 831                 return getattr(section, self.name)[new_key]
#     832
#     833         raise IndexingError("not applicable")
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1051
#    1052         # A collection of keys
# -> 1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
#    1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1260         if ax._index_as_unique:
#    1261             indexer = ax.get_indexer_for(keyarr)
# -> 1262             keyarr = ax.reindex(keyarr)[0]
#    1263         else:
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3501             target = self[:0]
#    3502         else:
# -> 3503             target = ensure_index(target)
#    3504
#    3505         if level is not None:
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5915             index_like = copy_func(index_like)
#    5916
# -> 5917     return Index(index_like)
#    5918
#    5919
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     356
#     357             if dtype is None:
# --> 358                 new_data, new_dtype = _maybe_cast_data_without_dtype(subarr)
#     359                 if new_dtype is not None:
#     360                     return cls(
#
# ~/Forex_Robot/sp500/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in _maybe_cast_data_without_dtype(subarr)
#    6036     """
#    6037     # Runtime import needed bc IntervalArray imports Index
# -> 6038     from pandas.core.arrays import (
#    6039         DatetimeArray,
#    6040         IntervalArray,
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best pullback cushion: ' + str(best_pullback_cushion))
print('Best atr percentage: ' + str(best_atr_percentage))
print('Best last x bars: ' + str(best_last_x_bars_val))
print('Best fractal distance: ' + str(best_fractal_distance))
print('Best bar length: ' + str(best_bar_length))

# 2017-2018:
# Best reward: 774.7000000000321
# Best risk/reward ratio: 1.7
# Best pullback cushion: 25
# Best atr percentage: 0.35
# Best last x bars: 4
# Best fractal distance: 15
# Best bar length: 5
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 774.7000000000321
# Best risk/reward ratio: 1.7
# Best pullback cushion: 25
# Best atr percentage: 0.35
# Best last x bars: 4
# Best fractal distance: 15
# Best bar length: 5
