# %%
import numpy as np
import pandas as pd
import random

# %%
file_path = '../../bar_movement/data/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
df = pd.read_csv(file_path + 'Oanda_Eur_Usd_M5_2021-2022.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2021-04-01 06:00:00   1.17170   1.17172  1.17141    1.17141   1.17184
# 1 2021-04-01 06:05:00   1.17140   1.17182  1.17119    1.17154   1.17153
# 2 2021-04-01 06:10:00   1.17153   1.17162  1.17140    1.17161   1.17166
# 3 2021-04-01 06:15:00   1.17160   1.17187  1.17153    1.17185   1.17173
# 4 2021-04-01 06:20:00   1.17184   1.17253  1.17171    1.17232   1.17196
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0   1.17187  1.17154    1.17154   1.17177   1.17180  1.17148    1.17148
# 1   1.17194  1.17133    1.17167   1.17146   1.17188  1.17126    1.17160
# 2   1.17175  1.17151    1.17174   1.17160   1.17168  1.17146    1.17168
# 3   1.17200  1.17165    1.17197   1.17166   1.17194  1.17160    1.17191
# 4   1.17266  1.17185    1.17244   1.17190   1.17259  1.17178    1.17238
#
#    Volume
# 0     348
# 1     451
# 2     324
# 3     275
# 4     646
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 74778 2022-04-01 05:35:00   1.10690   1.10694  1.10668    1.10676   1.10707
# 74779 2022-04-01 05:40:00   1.10675   1.10727  1.10672    1.10720   1.10691
# 74780 2022-04-01 05:45:00   1.10721   1.10722  1.10698    1.10704   1.10737
# 74781 2022-04-01 05:50:00   1.10703   1.10729  1.10700    1.10726   1.10721
# 74782 2022-04-01 05:55:00   1.10727   1.10737  1.10667    1.10673   1.10742
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 74778   1.10710  1.10683    1.10691   1.10698   1.10702  1.10676    1.10684
# 74779   1.10744  1.10689    1.10737   1.10683   1.10735  1.10680    1.10728
# 74780   1.10738  1.10715    1.10721   1.10729   1.10730  1.10707    1.10712
# 74781   1.10744  1.10717    1.10743   1.10712   1.10736  1.10708    1.10734
# 74782   1.10754  1.10683    1.10690   1.10734   1.10745  1.10675    1.10682
#
#        Volume
# 74778     291
# 74779     400
# 74780     183
# 74781     227
# 74782     439

# %%
def psar(barsdata, iaf=0.02, maxaf=0.2):
    length = len(barsdata)
    high = list(barsdata['Mid_High'])
    low = list(barsdata['Mid_Low'])
    close = list(barsdata['Mid_Close'])
    psar = close[0:len(close)]
    bull = True
    af = iaf
    hp = high[0]
    lp = low[0]
    for i in range(2, length):
        if bull:
            psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
        else:
            psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
        reverse = False
        if bull:
            if low[i] < psar[i]:
                bull = False
                reverse = True
                psar[i] = hp
                lp = low[i]
                af = iaf
        else:
            if high[i] > psar[i]:
                bull = True
                reverse = True
                psar[i] = lp
                hp = high[i]
                af = iaf
        if not reverse:
            if bull:
                if high[i] > hp:
                    hp = high[i]
                    af = min(af + iaf, maxaf)
                if low[i - 1] < psar[i]:
                    psar[i] = low[i - 1]
                if low[i - 2] < psar[i]:
                    psar[i] = low[i - 2]
            else:
                if low[i] < lp:
                    lp = low[i]
                    af = min(af + iaf, maxaf)
                if high[i - 1] > psar[i]:
                    psar[i] = high[i - 1]
                if high[i - 2] > psar[i]:
                    psar[i] = high[i - 2]
    return psar


def atr(barsdata, lookback=14):
    high_low = barsdata['Mid_High'] - barsdata['Mid_Low']
    high_close = np.abs(barsdata['Mid_High'] - barsdata['Mid_Close'].shift())
    low_close = np.abs(barsdata['Mid_Low'] - barsdata['Mid_Close'].shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = np.max(ranges, axis=1)

    return true_range.rolling(lookback).sum() / lookback


def rsi(barsdata, periods=14):
    close_delta = barsdata['Mid_Close'].diff()

    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)
    ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))

    return rsi

  
def adx(high, low, close, lookback=14):
    plus_dm = high.diff()
    minus_dm = low.diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0
    
    tr1 = pd.DataFrame(high - low)
    tr2 = pd.DataFrame(abs(high - close.shift(1)))
    tr3 = pd.DataFrame(abs(low - close.shift(1)))
    frames = [tr1, tr2, tr3]
    tr = pd.concat(frames, axis = 1, join = 'inner').max(axis = 1)
    atr = tr.rolling(lookback).mean()
    
    plus_di = 100 * (plus_dm.ewm(alpha = 1/lookback).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha = 1/lookback).mean() / atr))
    dx = (abs(plus_di - minus_di) / abs(plus_di + minus_di)) * 100
    adx = ((dx.shift(1) * (lookback - 1)) + dx) / lookback
    adx_smooth = adx.ewm(alpha = 1/lookback).mean()

    return adx_smooth


def stoch(high, low, close, lookback=14):
    high_lookback = high.rolling(lookback).max()
    low_lookback = low.rolling(lookback).min()
    slow_k = (close - low_lookback) * 100 / (high_lookback - low_lookback)
    slow_d = slow_k.rolling(3).mean()

    return slow_k, slow_d

def stoch_rsi(data, k_window=3, d_window=3, window=14):
    min_val = data.rolling(window=window, center=False).min()
    max_val = data.rolling(window=window, center=False).max()

    stoch = ((data - min_val) / (max_val - min_val)) * 100

    slow_k = stoch.rolling(window=k_window, center=False).mean()

    slow_d = slow_k.rolling(window=d_window, center=False).mean()

    return slow_k, slow_d

def n_macd(macd, macdsignal, lookback=50):
    n_macd = 2 * (((macd - macd.rolling(lookback).min()) / (macd.rolling(lookback).max() - macd.rolling(lookback).min()))) - 1
    n_macdsignal = 2 * (((macdsignal - macdsignal.rolling(lookback).min()) / (macdsignal.rolling(lookback).max() - macdsignal.rolling(lookback).min()))) - 1

    return n_macd, n_macdsignal

def chop(df, lookback=14):
    atr1 = atr(df, lookback=1)
    high, low = df['Mid_High'], df['Mid_Low']

    chop = np.log10(atr1.rolling(lookback).sum() / (high.rolling(lookback).max() - low.rolling(lookback).min())) / np.log10(lookback)

    return chop

def vo(volume, short_lookback=5, long_lookback=10):
    short_ema =  pd.Series.ewm(volume, span=short_lookback).mean()
    long_ema = pd.Series.ewm(volume, span=long_lookback).mean()

    volume_oscillator = (short_ema - long_ema) / long_ema

    return volume_oscillator

def bar_lengths(bar_lens, window=36):
    return bar_lens.rolling(window=window).mean(), bar_lens.rolling(window=window).std()

def sar_lengths(opens, sars, window=36):
    diffs = abs(opens - sars.shift(1))

    return diffs.rolling(window=window).mean(), diffs.rolling(window=window).std()

def range_high_lows(df, i, n_histograms=6):
    green, red = False, False
    curr_color, curr_streak = None, 0
    high, low = -np.inf, np.inf

    while i >= 0:
        hist = df.loc[df.index[i], 'macdhist']
        curr_high, curr_low = df.loc[df.index[i], ['Mid_High', 'Mid_Low']]
        new_color = 'green' if hist > 0 else 'red'

        if curr_color != new_color:
            curr_color = new_color
            curr_streak = 0

            if green and red:
                break

        curr_streak += 1

        if curr_streak >= n_histograms:
            high = max(high, curr_high)
            low = min(low, curr_low)

            if curr_color == 'red':
                red = True

            else:
                green = True

        i -= 1

    return high, low if (high > -np.inf and low < np.inf) else np.nan, np.nan

# def range_high_lows(df, i):
#     green, red = False, False
#     curr_color, curr_streak = None, 0
#     high, low = -np.inf, np.inf

#     while i >= 0:
#         hist = df.loc[df.index[i], 'macdhist']
#         curr_high, curr_low = df.loc[df.index[i], ['Mid_High', 'Mid_Low']]
#         new_color = 'green' if hist > 0 else 'red'

#         if curr_color != new_color:
#             curr_color = new_color
#             curr_streak = 0

#             if green and red:
#                 break

#         curr_streak += 1

#         if curr_streak >= 3:
#             if curr_color == 'red':
#                 low = min(low, curr_low)
#                 red = True

#             else:
#                 high = max(high, curr_high)
#                 green = True

#         i -= 1

#     return high, low if (high > -np.inf and low < np.inf) else np.nan, np.nan

# %%
# Add technical indicators (for additional features)
df['atr'] = atr(df)
df['adx'] = adx(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

print(df)
# Out:
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0     2021-04-01 07:10:00   1.17239   1.17334  1.17239    1.17316   1.17252
# 1     2021-04-01 07:15:00   1.17315   1.17321  1.17274    1.17297   1.17329
# 2     2021-04-01 07:20:00   1.17298   1.17362  1.17263    1.17362   1.17311
# 3     2021-04-01 07:25:00   1.17364   1.17420  1.17352    1.17414   1.17377
# 4     2021-04-01 07:30:00   1.17412   1.17425  1.17381    1.17394   1.17425
# ...                   ...       ...       ...      ...        ...       ...
# 74764 2022-04-01 05:35:00   1.10690   1.10694  1.10668    1.10676   1.10707
# 74765 2022-04-01 05:40:00   1.10675   1.10727  1.10672    1.10720   1.10691
# 74766 2022-04-01 05:45:00   1.10721   1.10722  1.10698    1.10704   1.10737
# 74767 2022-04-01 05:50:00   1.10703   1.10729  1.10700    1.10726   1.10721
# 74768 2022-04-01 05:55:00   1.10727   1.10737  1.10667    1.10673   1.10742
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0       1.17348  1.17252    1.17330   1.17246   1.17341  1.17246    1.17323
# 1       1.17334  1.17287    1.17310   1.17322   1.17328  1.17281    1.17304
# 2       1.17375  1.17276    1.17375   1.17304   1.17368  1.17270    1.17368
# 3       1.17433  1.17366    1.17427   1.17370   1.17426  1.17359    1.17420
# 4       1.17438  1.17391    1.17405   1.17418   1.17432  1.17386    1.17400
# ...         ...      ...        ...       ...       ...      ...        ...
# 74764   1.10710  1.10683    1.10691   1.10698   1.10702  1.10676    1.10684
# 74765   1.10744  1.10689    1.10737   1.10683   1.10735  1.10680    1.10728
# 74766   1.10738  1.10715    1.10721   1.10729   1.10730  1.10707    1.10712
# 74767   1.10744  1.10717    1.10743   1.10712   1.10736  1.10708    1.10734
# 74768   1.10754  1.10683    1.10690   1.10734   1.10745  1.10675    1.10682
#
#        Volume       atr        adx
# 0         662  0.000531  38.394956
# 1         490  0.000520  46.548073
# 2         548  0.000574  49.272128
# 3         698  0.000598  50.893711
# 4         398  0.000573  53.478762
# ...       ...       ...        ...
# 74764     291  0.000272   9.813219
# 74765     400  0.000299   9.807821
# 74766     183  0.000289  10.947864
# 74767     227  0.000294  12.020967
# 74768     439  0.000331  13.107870
#
# [74769 rows x 16 columns]

# %%
value_per_pip = 1.0
amounts_per_day = [-0.00008, -0.0001, -0.00012]
pair = 'EUR_USD'

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee

def get_n_units(open_price, stop_loss, mid_open, currency_pair):
    _, second = currency_pair.split('_')
  
    pips_to_risk = abs(open_price - stop_loss)
    pips_to_risk_calc = pips_to_risk * 10000 if second != 'JPY' else pips_to_risk * 100

    if second == 'USD':
        per_pip = 0.0001

    else:
        per_pip = 0.0001 / mid_open if second != 'JPY' else 0.01 / mid_open

    n_units = int(50 / (pips_to_risk_calc * per_pip))

    return n_units

def run_simulation(risk_reward_ratio, spread_cutoff, atr_multiplier, n_minutes, adx_cutoff):
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    lo = None
    trade = None
    placed_trade = False
    trade_lengths = []

    for i in range(1, len(df)):
        curr_date = df.loc[df.index[i], 'Date']
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, curr_mid_open, curr_mid_low = \
            df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_Low']]
        atr, adx, ask_low, bid_high = df.loc[df.index[i - 1], ['atr', 'adx', 'Ask_Low', 'Bid_High']]
        chop_signal = adx < adx_cutoff

        if not chop_signal:
            placed_trade = False

        if lo is not None:
            minutes_elapsed = (curr_date - lo['start_date']).total_seconds() / 60
            stop_signal = adx >= adx_cutoff or minutes_elapsed >= n_minutes
            # stop_signal = minutes_elapsed >= n_minutes

            if stop_signal:
                lo = None

        if lo is None and trade is None and chop_signal and not placed_trade:
            range_high, range_low = bid_high + (atr * atr_multiplier), ask_low - (atr * atr_multiplier)
            rang = abs(float(range_high) - float(range_low))
            pips_gain = (rang / 2) * risk_reward_ratio
            pips_to_risk = pips_gain / risk_reward_ratio
            
            if range_high > range_low and spread <= pips_to_risk * spread_cutoff:
                buy_open_price = float(range_low)
                buy_stop_gain = buy_open_price + (rang / 2) * risk_reward_ratio
                buy_pips_gained = buy_stop_gain - buy_open_price
                buy_pips_to_risk = buy_pips_gained / risk_reward_ratio
                buy_pullback = buy_open_price - buy_pips_to_risk
                buy_stop_loss = round(buy_pullback, 5)
                buy_mo = buy_open_price - (spread / 2)
                buy_n_units = get_n_units(buy_open_price, buy_stop_loss, buy_mo, pair)

                sell_open_price = float(range_high)
                sell_stop_gain = sell_open_price - (rang / 2) * risk_reward_ratio
                sell_pips_gained = sell_open_price - sell_stop_gain
                sell_pips_to_risk = sell_pips_gained / risk_reward_ratio
                sell_pullback = sell_open_price + sell_pips_to_risk
                sell_stop_loss = round(sell_pullback, 5)
                sell_mo = sell_open_price + (spread / 2)
                sell_n_units = get_n_units(sell_open_price, sell_stop_loss, sell_mo, pair)

                lo = {'buy_open_price': buy_open_price, 'buy_stop_gain': buy_stop_gain, 'buy_stop_loss': buy_stop_loss, 'buy_n_units': buy_n_units, 
                               'sell_open_price': sell_open_price, 'sell_stop_gain': sell_stop_gain, 'sell_stop_loss': sell_stop_loss, 'sell_n_units': sell_n_units, 'start_date': curr_date}

        if trade is None and lo is not None:
            place_buy = curr_ask_low <= lo['buy_open_price']
            place_sell = curr_bid_high >= lo['sell_open_price']

            if place_buy:
                open_price = lo['buy_open_price']
                stop_gain = lo['buy_stop_gain']
                pips_gained = stop_gain - open_price
                curr_pips_to_risk = pips_gained / risk_reward_ratio
                stop_loss = lo['buy_stop_loss']

                if stop_loss < open_price and stop_gain > open_price:
                    n_units = lo['buy_n_units']

                    trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                    'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                    'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None, 'index': i}

                    n_buys += 1

                    pips_risked.append(curr_pips_to_risk)
                    
                    lo = None
                    placed_trade = True

            elif place_sell:
                open_price = lo['sell_open_price']
                stop_gain = lo['sell_stop_gain']
                pips_gained = open_price - stop_gain
                curr_pips_to_risk = pips_gained / risk_reward_ratio
                stop_loss = lo['sell_stop_loss']

                if stop_loss > open_price and stop_gain < open_price:
                    n_units = lo['sell_n_units']

                    trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                            'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                            'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None, 'index': i}

                    n_sells += 1

                    pips_risked.append(curr_pips_to_risk)

                    lo = None
                    placed_trade = True

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
            trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
            trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
            trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
            trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked, trade_lengths

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
risk_reward_ratio_vals = [0.25, 0.5, 1.0, 1.5, 2.0]
spread_cutoffs = [0.10, 0.20]
atr_multipliers = [1.0, 1.5, 2.0]
adx_cutoffs = [15, 20, 25]
n_bars_vals = [5, 10, 15, 20, 25, 30]
all_combos = []


# use_half_sar, vo_cutoff, use_candles

for risk_reward_ratio in risk_reward_ratio_vals:
    for spread_val in spread_cutoffs:
        for atr_multiplier in atr_multipliers:
            for n_bars in n_bars_vals:
                for adx_cutoff in adx_cutoffs:
                    all_combos.append((risk_reward_ratio, spread_val, atr_multiplier, n_bars, adx_cutoff))

# percentage_to_try = 0.5
percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)
print('Num runs: '+ str(len(combos_to_try)) + '\n')

best_risk_reward = None
best_spread_cutoff = None
best_atr_multiplier = None
best_n_bars= None
best_adx_cutoff = None
top_n_results = 20
best_rewards = []
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, spread_val, atr_multiplier, n_bars, adx_cutoff in combos_to_try:
    reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked, trade_lengths = run_simulation(risk_reward_ratio, spread_val, atr_multiplier, n_bars, adx_cutoff)
    runs_finished += 1

    print(reward)
    print('Num buys: ' + str(n_buys))
    print('Num sells: ' + str(n_sells))
    print('Num trades: ' + str(n_buys + n_sells))
    print('Num wins: ' + str(n_wins))
    print('Num losses: ' + str(n_losses))
    print('Win streak: ' + str(win_streak))
    print('Loss streak: ' + str(loss_streak))
    avg_pips_risked = (sum(pips_risked) / len(pips_risked)) if len(pips_risked) > 0 else 'N/A'
    avg_trade_len = (sum(trade_lengths) / len(trade_lengths)) if len(trade_lengths) > 0 else 'N/A'
    print('Avg pips risked: ' + str(avg_pips_risked))
    print('Trade length: ' + str(avg_trade_len))
    print('Remaining runs: ' + str(n_runs - runs_finished))

    min_item = min(best_rewards, key=lambda entry: entry['reward']) if len(best_rewards) >= top_n_results else None

    if min_item is None or reward > min_item['reward']:
        if min_item is not None:
            best_rewards.remove(min_item)
            
        best_rewards.append({'reward': int(reward), 'ratio': risk_reward_ratio, 'spread_val': spread_val, 'atr_multiplier': atr_multiplier, 'n_bars': n_bars, 'adx_cutoff': adx_cutoff})


    if reward > best_reward:
        best_reward = reward
        best_risk_reward = risk_reward_ratio
        best_spread_cutoff = spread_val
        best_atr_multiplier = atr_multiplier
        best_n_bars = n_bars
        best_adx_cutoff = adx_cutoff

    print('Best reward so far: ' + str(best_reward))
    print()
# Out:
# Num runs: 540
#
# -27.630413571434747
# Num buys: 4
# Num sells: 4
# Num trades: 8
# Num wins: 3
# Num losses: 5
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.0018086607142856481
# Trade length: 20.0
# Remaining runs: 539
# Best reward so far: -27.630413571434747
#
# -4073.172084642426
# Num buys: 203
# Num sells: 225
# Num trades: 428
# Num wins: 139
# Num losses: 289
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.000848029038718307
# Trade length: 11.607476635514018
# Remaining runs: 538
# Best reward so far: -27.630413571434747
#
# -408.13314357142286
# Num buys: 17
# Num sells: 23
# Num trades: 40
# Num wins: 16
# Num losses: 24
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0018142857142857017
# Trade length: 17.425
# Remaining runs: 537
# Best reward so far: -27.630413571434747
#
# 699.5441764285766
# Num buys: 12
# Num sells: 22
# Num trades: 34
# Num wins: 32
# Num losses: 2
# Win streak: 22
# Loss streak: 1
# Avg pips risked: 0.0019013445378151365
# Trade length: 1.0
# Remaining runs: 536
# Best reward so far: 699.5441764285766
#
# -5305.099935356265
# Num buys: 206
# Num sells: 232
# Num trades: 438
# Num wins: 112
# Num losses: 326
# Win streak: 5
# Loss streak: 21
# Avg pips risked: 0.0008921273646445125
# Trade length: 27.30821917808219
# Remaining runs: 535
# Best reward so far: 699.5441764285766
#
# -3154.1499610712085
# Num buys: 104
# Num sells: 98
# Num trades: 202
# Num wins: 56
# Num losses: 146
# Win streak: 3
# Loss streak: 24
# Avg pips risked: 0.0008778394625176924
# Trade length: 13.698019801980198
# Remaining runs: 534
# Best reward so far: 699.5441764285766
#
# -455.5044221427705
# Num buys: 31
# Num sells: 28
# Num trades: 59
# Num wins: 17
# Num losses: 42
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.001601089588377757
# Trade length: 64.33898305084746
# Remaining runs: 533
# Best reward so far: 699.5441764285766
#
# 44.66285178573651
# Num buys: 16
# Num sells: 17
# Num trades: 33
# Num wins: 17
# Num losses: 16
# Win streak: 5
# Loss streak: 5
# Avg pips risked: 0.0017871861471861399
# Trade length: 18.060606060606062
# Remaining runs: 532
# Best reward so far: 699.5441764285766
#
# -80.78579892850686
# Num buys: 40
# Num sells: 51
# Num trades: 91
# Num wins: 36
# Num losses: 55
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0016850000000000229
# Trade length: 39.61538461538461
# Remaining runs: 531
# Best reward so far: 699.5441764285766
#
# -468.30561571424425
# Num buys: 12
# Num sells: 21
# Num trades: 33
# Num wins: 8
# Num losses: 25
# Win streak: 2
# Loss streak: 8
# Avg pips risked: 0.0017913419913420103
# Trade length: 56.60606060606061
# Remaining runs: 530
# Best reward so far: 699.5441764285766
#
# -209.51394357140154
# Num buys: 9
# Num sells: 10
# Num trades: 19
# Num wins: 6
# Num losses: 13
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0018064661654135469
# Trade length: 32.21052631578947
# Remaining runs: 529
# Best reward so far: 699.5441764285766
#
# 637.1009007142876
# Num buys: 49
# Num sells: 42
# Num trades: 91
# Num wins: 83
# Num losses: 8
# Win streak: 21
# Loss streak: 1
# Avg pips risked: 0.0015988618524332915
# Trade length: 2.1868131868131866
# Remaining runs: 528
# Best reward so far: 699.5441764285766
#
# -102.79693714285636
# Num buys: 4
# Num sells: 4
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.001822232142857122
# Trade length: 25.5
# Remaining runs: 527
# Best reward so far: 699.5441764285766
#
# 3699.0789821430026
# Num buys: 102
# Num sells: 88
# Num trades: 190
# Num wins: 176
# Num losses: 14
# Win streak: 52
# Loss streak: 2
# Avg pips risked: 0.0009716184210526563
# Trade length: 1.1842105263157894
# Remaining runs: 526
# Best reward so far: 3699.0789821430026
#
# 1836.7902405361801
# Num buys: 259
# Num sells: 253
# Num trades: 512
# Num wins: 439
# Num losses: 73
# Win streak: 31
# Loss streak: 4
# Avg pips risked: 0.0008922767857143191
# Trade length: 2.12890625
# Remaining runs: 525
# Best reward so far: 3699.0789821430026
#
# -1117.4446164282162
# Num buys: 74
# Num sells: 64
# Num trades: 138
# Num wins: 39
# Num losses: 99
# Win streak: 3
# Loss streak: 19
# Avg pips risked: 0.0008874508281573774
# Trade length: 22.68840579710145
# Remaining runs: 524
# Best reward so far: 3699.0789821430026
#
# 150.06591267856803
# Num buys: 11
# Num sells: 6
# Num trades: 17
# Num wins: 16
# Num losses: 1
# Win streak: 10
# Loss streak: 1
# Avg pips risked: 0.0017150000000000156
# Trade length: 4.294117647058823
# Remaining runs: 523
# Best reward so far: 3699.0789821430026
#
# -126.28131142853007
# Num buys: 15
# Num sells: 23
# Num trades: 38
# Num wins: 12
# Num losses: 26
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.0018216729323308376
# Trade length: 70.42105263157895
# Remaining runs: 522
# Best reward so far: 3699.0789821430026
#
# 351.41995464308036
# Num buys: 165
# Num sells: 167
# Num trades: 332
# Num wins: 226
# Num losses: 106
# Win streak: 15
# Loss streak: 4
# Avg pips risked: 0.0008358218588640477
# Trade length: 2.9487951807228914
# Remaining runs: 521
# Best reward so far: 3699.0789821430026
#
# -898.7740785712194
# Num buys: 61
# Num sells: 75
# Num trades: 136
# Num wins: 40
# Num losses: 96
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0016240126050420505
# Trade length: 64.5
# Remaining runs: 520
# Best reward so far: 3699.0789821430026
#
# 963.647068928647
# Num buys: 182
# Num sells: 170
# Num trades: 352
# Num wins: 297
# Num losses: 55
# Win streak: 26
# Loss streak: 3
# Avg pips risked: 0.0008305154220779345
# Trade length: 1.6875
# Remaining runs: 519
# Best reward so far: 3699.0789821430026
#
# 62.325139285742225
# Num buys: 24
# Num sells: 22
# Num trades: 46
# Num wins: 19
# Num losses: 27
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0018430124223602683
# Trade length: 24.369565217391305
# Remaining runs: 518
# Best reward so far: 3699.0789821430026
#
# -3.670255714293315
# Num buys: 5
# Num sells: 5
# Num trades: 10
# Num wins: 5
# Num losses: 5
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.001824857142857117
# Trade length: 18.2
# Remaining runs: 517
# Best reward so far: 3699.0789821430026
#
# -170.9410385714347
# Num buys: 18
# Num sells: 15
# Num trades: 33
# Num wins: 12
# Num losses: 21
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0017073809523809485
# Trade length: 49.09090909090909
# Remaining runs: 516
# Best reward so far: 3699.0789821430026
#
# -767.5981392856536
# Num buys: 35
# Num sells: 32
# Num trades: 67
# Num wins: 26
# Num losses: 41
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0015901812366737882
# Trade length: 25.55223880597015
# Remaining runs: 515
# Best reward so far: 3699.0789821430026
#
# 225.48155321443213
# Num buys: 80
# Num sells: 67
# Num trades: 147
# Num wins: 101
# Num losses: 46
# Win streak: 14
# Loss streak: 3
# Avg pips risked: 0.0008171914480077943
# Trade length: 2.748299319727891
# Remaining runs: 514
# Best reward so far: 3699.0789821430026
#
# 224.44282678572608
# Num buys: 16
# Num sells: 23
# Num trades: 39
# Num wins: 29
# Num losses: 10
# Win streak: 7
# Loss streak: 2
# Avg pips risked: 0.0018234981684981787
# Trade length: 3.2051282051282053
# Remaining runs: 513
# Best reward so far: 3699.0789821430026
#
# 999.3877369642778
# Num buys: 184
# Num sells: 181
# Num trades: 365
# Num wins: 308
# Num losses: 57
# Win streak: 17
# Loss streak: 2
# Avg pips risked: 0.000992436399217226
# Trade length: 1.8054794520547945
# Remaining runs: 512
# Best reward so far: 3699.0789821430026
#
# 731.1467453574115
# Num buys: 131
# Num sells: 122
# Num trades: 253
# Num wins: 134
# Num losses: 119
# Win streak: 7
# Loss streak: 6
# Avg pips risked: 0.0009657763975155496
# Trade length: 8.375494071146244
# Remaining runs: 511
# Best reward so far: 3699.0789821430026
#
# -704.5343471427044
# Num buys: 57
# Num sells: 49
# Num trades: 106
# Num wins: 46
# Num losses: 60
# Win streak: 8
# Loss streak: 6
# Avg pips risked: 0.0009855323450135016
# Trade length: 12.39622641509434
# Remaining runs: 510
# Best reward so far: 3699.0789821430026
#
# 824.9766643750194
# Num buys: 47
# Num sells: 39
# Num trades: 86
# Num wins: 82
# Num losses: 4
# Win streak: 28
# Loss streak: 1
# Avg pips risked: 0.0016789368770764623
# Trade length: 2.2906976744186047
# Remaining runs: 509
# Best reward so far: 3699.0789821430026
#
# 662.361891517988
# Num buys: 63
# Num sells: 45
# Num trades: 108
# Num wins: 97
# Num losses: 11
# Win streak: 23
# Loss streak: 2
# Avg pips risked: 0.0009427943121693705
# Trade length: 1.3055555555555556
# Remaining runs: 508
# Best reward so far: 3699.0789821430026
#
# -54.0218192856768
# Num buys: 9
# Num sells: 12
# Num trades: 21
# Num wins: 10
# Num losses: 11
# Win streak: 5
# Loss streak: 3
# Avg pips risked: 0.0018422959183673707
# Trade length: 10.952380952380953
# Remaining runs: 507
# Best reward so far: 3699.0789821430026
#
# -116.51836142857282
# Num buys: 16
# Num sells: 13
# Num trades: 29
# Num wins: 9
# Num losses: 20
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0017915270935960482
# Trade length: 59.55172413793103
# Remaining runs: 506
# Best reward so far: 3699.0789821430026
#
# -261.12132571427173
# Num buys: 19
# Num sells: 22
# Num trades: 41
# Num wins: 18
# Num losses: 23
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0018618466898954731
# Trade length: 16.658536585365855
# Remaining runs: 505
# Best reward so far: 3699.0789821430026
#
# -6083.078532141975
# Num buys: 271
# Num sells: 259
# Num trades: 530
# Num wins: 205
# Num losses: 325
# Win streak: 6
# Loss streak: 13
# Avg pips risked: 0.0009721832884097312
# Trade length: 14.062264150943395
# Remaining runs: 504
# Best reward so far: 3699.0789821430026
#
# 400.0207926785864
# Num buys: 24
# Num sells: 23
# Num trades: 47
# Num wins: 44
# Num losses: 3
# Win streak: 20
# Loss streak: 1
# Avg pips risked: 0.001846291793313129
# Trade length: 1.553191489361702
# Remaining runs: 503
# Best reward so far: 3699.0789821430026
#
# -2755.3417499994875
# Num buys: 177
# Num sells: 195
# Num trades: 372
# Num wins: 127
# Num losses: 245
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.0008678897849462544
# Trade length: 11.190860215053764
# Remaining runs: 502
# Best reward so far: 3699.0789821430026
#
# -431.7596151780705
# Num buys: 233
# Num sells: 260
# Num trades: 493
# Num wins: 323
# Num losses: 170
# Win streak: 12
# Loss streak: 5
# Avg pips risked: 0.0008882736887858859
# Trade length: 4.537525354969574
# Remaining runs: 501
# Best reward so far: 3699.0789821430026
#
# 107.4634246428996
# Num buys: 20
# Num sells: 16
# Num trades: 36
# Num wins: 13
# Num losses: 23
# Win streak: 3
# Loss streak: 4
# Avg pips risked: 0.0016861111111111352
# Trade length: 80.08333333333333
# Remaining runs: 500
# Best reward so far: 3699.0789821430026
#
# 99.05551142862294
# Num buys: 26
# Num sells: 37
# Num trades: 63
# Num wins: 22
# Num losses: 41
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0017153287981859435
# Trade length: 71.04761904761905
# Remaining runs: 499
# Best reward so far: 3699.0789821430026
#
# 312.5445775000053
# Num buys: 17
# Num sells: 23
# Num trades: 40
# Num wins: 37
# Num losses: 3
# Win streak: 13
# Loss streak: 1
# Avg pips risked: 0.0018142857142857461
# Trade length: 1.0
# Remaining runs: 498
# Best reward so far: 3699.0789821430026
#
# -5.655297857114888
# Num buys: 30
# Num sells: 26
# Num trades: 56
# Num wins: 19
# Num losses: 37
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.0017622321428571552
# Trade length: 81.71428571428571
# Remaining runs: 497
# Best reward so far: 3699.0789821430026
#
# 496.2288682142986
# Num buys: 19
# Num sells: 22
# Num trades: 41
# Num wins: 34
# Num losses: 7
# Win streak: 10
# Loss streak: 2
# Avg pips risked: 0.001861846689895484
# Trade length: 4.560975609756097
# Remaining runs: 496
# Best reward so far: 3699.0789821430026
#
# -2236.049080356802
# Num buys: 88
# Num sells: 78
# Num trades: 166
# Num wins: 41
# Num losses: 125
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.0008891566265060466
# Trade length: 26.33132530120482
# Remaining runs: 495
# Best reward so far: 3699.0789821430026
#
# -5958.51288749896
# Num buys: 267
# Num sells: 254
# Num trades: 521
# Num wins: 162
# Num losses: 359
# Win streak: 6
# Loss streak: 15
# Avg pips risked: 0.000977478749657282
# Trade length: 22.228406909788866
# Remaining runs: 494
# Best reward so far: 3699.0789821430026
#
# 149.99793642856173
# Num buys: 5
# Num sells: 4
# Num trades: 9
# Num wins: 8
# Num losses: 1
# Win streak: 8
# Loss streak: 1
# Avg pips risked: 0.0018919047619047429
# Trade length: 4.111111111111111
# Remaining runs: 493
# Best reward so far: 3699.0789821430026
#
# 348.0983642857097
# Num buys: 15
# Num sells: 11
# Num trades: 26
# Num wins: 22
# Num losses: 4
# Win streak: 8
# Loss streak: 1
# Avg pips risked: 0.0018909340659340511
# Trade length: 8.26923076923077
# Remaining runs: 492
# Best reward so far: 3699.0789821430026
#
# 70.02661428573614
# Num buys: 90
# Num sells: 75
# Num trades: 165
# Num wins: 111
# Num losses: 54
# Win streak: 9
# Loss streak: 6
# Avg pips risked: 0.000982389610389624
# Trade length: 5.648484848484848
# Remaining runs: 491
# Best reward so far: 3699.0789821430026
#
# 1079.6826760717977
# Num buys: 230
# Num sells: 247
# Num trades: 477
# Num wins: 399
# Num losses: 78
# Win streak: 20
# Loss streak: 3
# Avg pips risked: 0.000885402066487014
# Trade length: 2.708595387840671
# Remaining runs: 490
# Best reward so far: 3699.0789821430026
#
# -1162.2646157140462
# Num buys: 80
# Num sells: 67
# Num trades: 147
# Num wins: 62
# Num losses: 85
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0008176579203110065
# Trade length: 8.02721088435374
# Remaining runs: 489
# Best reward so far: 3699.0789821430026
#
# 1962.5765321430586
# Num buys: 151
# Num sells: 186
# Num trades: 337
# Num wins: 301
# Num losses: 36
# Win streak: 60
# Loss streak: 2
# Avg pips risked: 0.0008752861381941892
# Trade length: 1.3234421364985163
# Remaining runs: 488
# Best reward so far: 3699.0789821430026
#
# -2224.028129285195
# Num buys: 167
# Num sells: 175
# Num trades: 342
# Num wins: 149
# Num losses: 193
# Win streak: 8
# Loss streak: 8
# Avg pips risked: 0.0008220572263993533
# Trade length: 7.3391812865497075
# Remaining runs: 487
# Best reward so far: 3699.0789821430026
#
# 0.044836249990073185
# Num buys: 17
# Num sells: 13
# Num trades: 30
# Num wins: 24
# Num losses: 6
# Win streak: 6
# Loss streak: 1
# Avg pips risked: 0.001785476190476191
# Trade length: 2.0
# Remaining runs: 486
# Best reward so far: 3699.0789821430026
#
# -2124.3247089279703
# Num buys: 279
# Num sells: 260
# Num trades: 539
# Num wins: 331
# Num losses: 208
# Win streak: 13
# Loss streak: 6
# Avg pips risked: 0.0009672024913861982
# Trade length: 5.263450834879406
# Remaining runs: 485
# Best reward so far: 3699.0789821430026
#
# -1217.9068521425854
# Num buys: 136
# Num sells: 132
# Num trades: 268
# Num wins: 122
# Num losses: 146
# Win streak: 7
# Loss streak: 7
# Avg pips risked: 0.0008610447761194182
# Trade length: 7.279850746268656
# Remaining runs: 484
# Best reward so far: 3699.0789821430026
#
# -932.3308842855939
# Num buys: 45
# Num sells: 41
# Num trades: 86
# Num wins: 23
# Num losses: 63
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0016060382059800828
# Trade length: 69.6046511627907
# Remaining runs: 483
# Best reward so far: 3699.0789821430026
#
# -501.33384142852606
# Num buys: 30
# Num sells: 39
# Num trades: 69
# Num wins: 20
# Num losses: 49
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0016410559006211276
# Trade length: 63.55072463768116
# Remaining runs: 482
# Best reward so far: 3699.0789821430026
#
# -928.4253178569919
# Num buys: 71
# Num sells: 52
# Num trades: 123
# Num wins: 35
# Num losses: 88
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0008555052264808515
# Trade length: 15.560975609756097
# Remaining runs: 481
# Best reward so far: 3699.0789821430026
#
# 225.04697892855307
# Num buys: 17
# Num sells: 13
# Num trades: 30
# Num wins: 23
# Num losses: 7
# Win streak: 6
# Loss streak: 1
# Avg pips risked: 0.0017854761904761763
# Trade length: 3.3666666666666667
# Remaining runs: 480
# Best reward so far: 3699.0789821430026
#
# 250.05070660714821
# Num buys: 7
# Num sells: 6
# Num trades: 13
# Num wins: 12
# Num losses: 1
# Win streak: 8
# Loss streak: 1
# Avg pips risked: 0.00179510989010996
# Trade length: 1.5384615384615385
# Remaining runs: 479
# Best reward so far: 3699.0789821430026
#
# 1498.0134760718797
# Num buys: 200
# Num sells: 226
# Num trades: 426
# Num wins: 304
# Num losses: 122
# Win streak: 18
# Loss streak: 4
# Avg pips risked: 0.0008556136820925817
# Trade length: 3.535211267605634
# Remaining runs: 478
# Best reward so far: 3699.0789821430026
#
# -2116.318844999593
# Num buys: 164
# Num sells: 166
# Num trades: 330
# Num wins: 144
# Num losses: 186
# Win streak: 10
# Loss streak: 7
# Avg pips risked: 0.0008356883116883274
# Trade length: 7.236363636363636
# Remaining runs: 477
# Best reward so far: 3699.0789821430026
#
# 478.67708571426635
# Num buys: 12
# Num sells: 14
# Num trades: 26
# Num wins: 12
# Num losses: 14
# Win streak: 5
# Loss streak: 5
# Avg pips risked: 0.0017225824175824112
# Trade length: 65.92307692307692
# Remaining runs: 476
# Best reward so far: 3699.0789821430026
#
# -1165.6641403567887
# Num buys: 232
# Num sells: 250
# Num trades: 482
# Num wins: 306
# Num losses: 176
# Win streak: 12
# Loss streak: 6
# Avg pips risked: 0.000964684350918817
# Trade length: 6.174273858921162
# Remaining runs: 475
# Best reward so far: 3699.0789821430026
#
# 49.70062053569791
# Num buys: 19
# Num sells: 15
# Num trades: 34
# Num wins: 28
# Num losses: 6
# Win streak: 12
# Loss streak: 2
# Avg pips risked: 0.0017048109243696864
# Trade length: 2.2941176470588234
# Remaining runs: 474
# Best reward so far: 3699.0789821430026
#
# -214.48580571426646
# Num buys: 9
# Num sells: 10
# Num trades: 19
# Num wins: 5
# Num losses: 14
# Win streak: 2
# Loss streak: 8
# Avg pips risked: 0.0018064661654135373
# Trade length: 68.10526315789474
# Remaining runs: 473
# Best reward so far: 3699.0789821430026
#
# -288.01994928566404
# Num buys: 47
# Num sells: 42
# Num trades: 89
# Num wins: 42
# Num losses: 47
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.00160095505617979
# Trade length: 31.831460674157302
# Remaining runs: 472
# Best reward so far: 3699.0789821430026
#
# -1242.420497142768
# Num buys: 95
# Num sells: 78
# Num trades: 173
# Num wins: 50
# Num losses: 123
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0009613253509496426
# Trade length: 27.670520231213874
# Remaining runs: 471
# Best reward so far: 3699.0789821430026
#
# -35.87989321426503
# Num buys: 7
# Num sells: 6
# Num trades: 13
# Num wins: 5
# Num losses: 8
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.001795109890109926
# Trade length: 51.07692307692308
# Remaining runs: 470
# Best reward so far: 3699.0789821430026
#
# -4939.677265356338
# Num buys: 251
# Num sells: 232
# Num trades: 483
# Num wins: 155
# Num losses: 328
# Win streak: 7
# Loss streak: 14
# Avg pips risked: 0.0009836157941437653
# Trade length: 22.34368530020704
# Remaining runs: 469
# Best reward so far: 3699.0789821430026
#
# 3275.5235487502573
# Num buys: 150
# Num sells: 161
# Num trades: 311
# Num wins: 251
# Num losses: 60
# Win streak: 29
# Loss streak: 2
# Avg pips risked: 0.0009071221864952072
# Trade length: 2.8906752411575565
# Remaining runs: 468
# Best reward so far: 3699.0789821430026
#
# 94.72188857141788
# Num buys: 3
# Num sells: 4
# Num trades: 7
# Num wins: 3
# Num losses: 4
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.002281938775510179
# Trade length: 70.71428571428571
# Remaining runs: 467
# Best reward so far: 3699.0789821430026
#
# 349.94958214284867
# Num buys: 24
# Num sells: 24
# Num trades: 48
# Num wins: 44
# Num losses: 4
# Win streak: 19
# Loss streak: 1
# Avg pips risked: 0.001666049107142853
# Trade length: 1.4583333333333333
# Remaining runs: 466
# Best reward so far: 3699.0789821430026
#
# -3787.337412142042
# Num buys: 223
# Num sells: 243
# Num trades: 466
# Num wins: 196
# Num losses: 270
# Win streak: 7
# Loss streak: 10
# Avg pips risked: 0.0008872654812998481
# Trade length: 12.96351931330472
# Remaining runs: 465
# Best reward so far: 3699.0789821430026
#
# 355.83352571434443
# Num buys: 47
# Num sells: 51
# Num trades: 98
# Num wins: 53
# Num losses: 45
# Win streak: 8
# Loss streak: 7
# Avg pips risked: 0.0016200583090379202
# Trade length: 34.36734693877551
# Remaining runs: 464
# Best reward so far: 3699.0789821430026
#
# 250.05951535714848
# Num buys: 8
# Num sells: 5
# Num trades: 13
# Num wins: 12
# Num losses: 1
# Win streak: 8
# Loss streak: 1
# Avg pips risked: 0.0017981043956044691
# Trade length: 2.1538461538461537
# Remaining runs: 463
# Best reward so far: 3699.0789821430026
#
# 99.91088428571663
# Num buys: 3
# Num sells: 4
# Num trades: 7
# Num wins: 6
# Num losses: 1
# Win streak: 5
# Loss streak: 1
# Avg pips risked: 0.002281938775510195
# Trade length: 1.0
# Remaining runs: 462
# Best reward so far: 3699.0789821430026
#
# -102.46273571414824
# Num buys: 79
# Num sells: 57
# Num trades: 136
# Num wins: 54
# Num losses: 82
# Win streak: 5
# Loss streak: 9
# Avg pips risked: 0.0009618487394958053
# Trade length: 24.676470588235293
# Remaining runs: 461
# Best reward so far: 3699.0789821430026
#
# 1587.4592066073167
# Num buys: 178
# Num sells: 199
# Num trades: 377
# Num wins: 327
# Num losses: 50
# Win streak: 25
# Loss streak: 3
# Avg pips risked: 0.0008718226600985435
# Trade length: 1.490716180371353
# Remaining runs: 460
# Best reward so far: 3699.0789821430026
#
# -3072.5220549994515
# Num buys: 204
# Num sells: 227
# Num trades: 431
# Num wins: 185
# Num losses: 246
# Win streak: 6
# Loss streak: 9
# Avg pips risked: 0.0008517517401392292
# Trade length: 7.951276102088167
# Remaining runs: 459
# Best reward so far: 3699.0789821430026
#
# -1465.7101414280698
# Num buys: 177
# Num sells: 198
# Num trades: 375
# Num wins: 173
# Num losses: 202
# Win streak: 8
# Loss streak: 6
# Avg pips risked: 0.0008719504761904885
# Trade length: 7.466666666666667
# Remaining runs: 458
# Best reward so far: 3699.0789821430026
#
# -2075.452434999592
# Num buys: 180
# Num sells: 174
# Num trades: 354
# Num wins: 157
# Num losses: 197
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.000997534301856366
# Trade length: 14.658192090395481
# Remaining runs: 457
# Best reward so far: 3699.0789821430026
#
# 1024.551927768043
# Num buys: 79
# Num sells: 68
# Num trades: 147
# Num wins: 134
# Num losses: 13
# Win streak: 29
# Loss streak: 1
# Avg pips risked: 0.0008834110787172586
# Trade length: 1.598639455782313
# Remaining runs: 456
# Best reward so far: 3699.0789821430026
#
# 927.1435192860872
# Num buys: 182
# Num sells: 170
# Num trades: 352
# Num wins: 247
# Num losses: 105
# Win streak: 13
# Loss streak: 5
# Avg pips risked: 0.0008305154220779535
# Trade length: 3.272727272727273
# Remaining runs: 455
# Best reward so far: 3699.0789821430026
#
# 2549.8642465180105
# Num buys: 132
# Num sells: 122
# Num trades: 254
# Num wins: 244
# Num losses: 10
# Win streak: 88
# Loss streak: 3
# Avg pips risked: 0.0009663174915635956
# Trade length: 1.0
# Remaining runs: 454
# Best reward so far: 3699.0789821430026
#
# -12.51946142855337
# Num buys: 29
# Num sells: 25
# Num trades: 54
# Num wins: 43
# Num losses: 11
# Win streak: 16
# Loss streak: 2
# Avg pips risked: 0.0010397222222222366
# Trade length: 1.0
# Remaining runs: 453
# Best reward so far: 3699.0789821430026
#
# -188.55112642853146
# Num buys: 9
# Num sells: 12
# Num trades: 21
# Num wins: 7
# Num losses: 14
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.001842295918367388
# Trade length: 46.76190476190476
# Remaining runs: 452
# Best reward so far: 3699.0789821430026
#
# 1225.9781110714605
# Num buys: 201
# Num sells: 197
# Num trades: 398
# Num wins: 338
# Num losses: 60
# Win streak: 25
# Loss streak: 2
# Avg pips risked: 0.0009750071787509042
# Trade length: 2.0854271356783918
# Remaining runs: 451
# Best reward so far: 3699.0789821430026
#
# 100.02555937499422
# Num buys: 7
# Num sells: 6
# Num trades: 13
# Num wins: 12
# Num losses: 1
# Win streak: 8
# Loss streak: 1
# Avg pips risked: 0.0017951098901098916
# Trade length: 1.0
# Remaining runs: 450
# Best reward so far: 3699.0789821430026
#
# 649.871173571478
# Num buys: 69
# Num sells: 73
# Num trades: 142
# Num wins: 124
# Num losses: 18
# Win streak: 29
# Loss streak: 2
# Avg pips risked: 0.0010877917505030415
# Trade length: 1.0
# Remaining runs: 449
# Best reward so far: 3699.0789821430026
#
# -4891.047673570902
# Num buys: 212
# Num sells: 198
# Num trades: 410
# Num wins: 126
# Num losses: 284
# Win streak: 7
# Loss streak: 16
# Avg pips risked: 0.000977172473867617
# Trade length: 25.682926829268293
# Remaining runs: 448
# Best reward so far: 3699.0789821430026
#
# -64.05524678569022
# Num buys: 8
# Num sells: 5
# Num trades: 13
# Num wins: 4
# Num losses: 9
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017981043956044435
# Trade length: 69.38461538461539
# Remaining runs: 447
# Best reward so far: 3699.0789821430026
#
# -715.8847510712914
# Num buys: 71
# Num sells: 53
# Num trades: 124
# Num wins: 44
# Num losses: 80
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0008537730414746717
# Trade length: 10.10483870967742
# Remaining runs: 446
# Best reward so far: 3699.0789821430026
#
# -1972.1955562491753
# Num buys: 259
# Num sells: 246
# Num trades: 505
# Num wins: 187
# Num losses: 318
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.000899599009901013
# Trade length: 16.73861386138614
# Remaining runs: 445
# Best reward so far: 3699.0789821430026
#
# -428.36354964288876
# Num buys: 37
# Num sells: 25
# Num trades: 62
# Num wins: 18
# Num losses: 44
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0010108640552995392
# Trade length: 26.548387096774192
# Remaining runs: 444
# Best reward so far: 3699.0789821430026
#
# 987.4151601786781
# Num buys: 151
# Num sells: 163
# Num trades: 314
# Num wins: 267
# Num losses: 47
# Win streak: 27
# Loss streak: 3
# Avg pips risked: 0.0008374749772520639
# Trade length: 1.3471337579617835
# Remaining runs: 443
# Best reward so far: 3699.0789821430026
#
# -4.559458571381456
# Num buys: 49
# Num sells: 31
# Num trades: 80
# Num wins: 40
# Num losses: 40
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.0008768303571428549
# Trade length: 9.5125
# Remaining runs: 442
# Best reward so far: 3699.0789821430026
#
# 112.51691214285134
# Num buys: 5
# Num sells: 4
# Num trades: 9
# Num wins: 9
# Num losses: 0
# Win streak: 9
# Loss streak: 0
# Avg pips risked: 0.0018919047619046442
# Trade length: 1.0
# Remaining runs: 441
# Best reward so far: 3699.0789821430026
#
# -678.9720814280494
# Num buys: 151
# Num sells: 186
# Num trades: 337
# Num wins: 162
# Num losses: 175
# Win streak: 8
# Loss streak: 7
# Avg pips risked: 0.0008757397202204548
# Trade length: 7.946587537091988
# Remaining runs: 440
# Best reward so far: 3699.0789821430026
#
# -219.57526107141095
# Num buys: 12
# Num sells: 12
# Num trades: 24
# Num wins: 8
# Num losses: 16
# Win streak: 3
# Loss streak: 8
# Avg pips risked: 0.0018723809523809463
# Trade length: 90.16666666666667
# Remaining runs: 439
# Best reward so far: 3699.0789821430026
#
# -3977.5584964279215
# Num buys: 190
# Num sells: 209
# Num trades: 399
# Num wins: 107
# Num losses: 292
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0008598693161475314
# Trade length: 17.137844611528823
# Remaining runs: 438
# Best reward so far: 3699.0789821430026
#
# 237.390153571417
# Num buys: 13
# Num sells: 14
# Num trades: 27
# Num wins: 16
# Num losses: 11
# Win streak: 5
# Loss streak: 5
# Avg pips risked: 0.001727751322751315
# Trade length: 38.0
# Remaining runs: 437
# Best reward so far: 3699.0789821430026
#
# 62.5177078571336
# Num buys: 5
# Num sells: 5
# Num trades: 10
# Num wins: 9
# Num losses: 1
# Win streak: 6
# Loss streak: 1
# Avg pips risked: 0.001824857142857006
# Trade length: 1.4
# Remaining runs: 436
# Best reward so far: 3699.0789821430026
#
# -697.7886507142722
# Num buys: 24
# Num sells: 22
# Num trades: 46
# Num wins: 11
# Num losses: 35
# Win streak: 2
# Loss streak: 13
# Avg pips risked: 0.0016725698757764182
# Trade length: 74.41304347826087
# Remaining runs: 435
# Best reward so far: 3699.0789821430026
#
# 499.6561010714771
# Num buys: 47
# Num sells: 39
# Num trades: 86
# Num wins: 64
# Num losses: 22
# Win streak: 12
# Loss streak: 5
# Avg pips risked: 0.0016789368770764518
# Trade length: 4.732558139534884
# Remaining runs: 434
# Best reward so far: 3699.0789821430026
#
# -356.5779171428497
# Num buys: 9
# Num sells: 10
# Num trades: 19
# Num wins: 6
# Num losses: 13
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0018064661654135083
# Trade length: 20.0
# Remaining runs: 433
# Best reward so far: 3699.0789821430026
#
# 37.5996182142881
# Num buys: 4
# Num sells: 4
# Num trades: 8
# Num wins: 7
# Num losses: 1
# Win streak: 5
# Loss streak: 1
# Avg pips risked: 0.0018222321428570387
# Trade length: 1.0
# Remaining runs: 432
# Best reward so far: 3699.0789821430026
#
# 121.85702714285176
# Num buys: 5
# Num sells: 5
# Num trades: 10
# Num wins: 5
# Num losses: 5
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.0018248571428570947
# Trade length: 23.0
# Remaining runs: 431
# Best reward so far: 3699.0789821430026
#
# 121.26582714285176
# Num buys: 5
# Num sells: 5
# Num trades: 10
# Num wins: 5
# Num losses: 5
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.0018248571428570947
# Trade length: 23.0
# Remaining runs: 430
# Best reward so far: 3699.0789821430026
#
# 1950.8381483040398
# Num buys: 191
# Num sells: 200
# Num trades: 391
# Num wins: 344
# Num losses: 47
# Win streak: 37
# Loss streak: 3
# Avg pips risked: 0.0008991925465839127
# Trade length: 1.7953964194373402
# Remaining runs: 429
# Best reward so far: 3699.0789821430026
#
# 762.62519750017
# Num buys: 100
# Num sells: 81
# Num trades: 181
# Num wins: 157
# Num losses: 24
# Win streak: 30
# Loss streak: 2
# Avg pips risked: 0.0008760438042620858
# Trade length: 2.044198895027624
# Remaining runs: 428
# Best reward so far: 3699.0789821430026
#
# 374.9635099106948
# Num buys: 31
# Num sells: 29
# Num trades: 60
# Num wins: 54
# Num losses: 6
# Win streak: 16
# Loss streak: 1
# Avg pips risked: 0.001598374999999989
# Trade length: 2.7333333333333334
# Remaining runs: 427
# Best reward so far: 3699.0789821430026
#
# -2828.562920892124
# Num buys: 253
# Num sells: 244
# Num trades: 497
# Num wins: 177
# Num losses: 320
# Win streak: 7
# Loss streak: 11
# Avg pips risked: 0.0009014256970394005
# Trade length: 16.285714285714285
# Remaining runs: 426
# Best reward so far: 3699.0789821430026
#
# -2416.232207499354
# Num buys: 138
# Num sells: 157
# Num trades: 295
# Num wins: 83
# Num losses: 212
# Win streak: 5
# Loss streak: 15
# Avg pips risked: 0.0009152130750605593
# Trade length: 27.030508474576273
# Remaining runs: 425
# Best reward so far: 3699.0789821430026
#
# 424.71594071430513
# Num buys: 26
# Num sells: 38
# Num trades: 64
# Num wins: 58
# Num losses: 6
# Win streak: 20
# Loss streak: 1
# Avg pips risked: 0.0017536495535714486
# Trade length: 1.171875
# Remaining runs: 424
# Best reward so far: 3699.0789821430026
#
# -1441.769569285383
# Num buys: 96
# Num sells: 79
# Num trades: 175
# Num wins: 59
# Num losses: 116
# Win streak: 3
# Loss streak: 9
# Avg pips risked: 0.0008753897959183905
# Trade length: 18.725714285714286
# Remaining runs: 423
# Best reward so far: 3699.0789821430026
#
# 599.6735080357385
# Num buys: 42
# Num sells: 51
# Num trades: 93
# Num wins: 84
# Num losses: 9
# Win streak: 22
# Loss streak: 1
# Avg pips risked: 0.0016797158218126232
# Trade length: 1.4946236559139785
# Remaining runs: 422
# Best reward so far: 3699.0789821430026
#
# -193.75913571427043
# Num buys: 15
# Num sells: 11
# Num trades: 26
# Num wins: 9
# Num losses: 17
# Win streak: 3
# Loss streak: 8
# Avg pips risked: 0.0018909340659340622
# Trade length: 76.3076923076923
# Remaining runs: 421
# Best reward so far: 3699.0789821430026
#
# -166.63484071428846
# Num buys: 15
# Num sells: 12
# Num trades: 27
# Num wins: 8
# Num losses: 19
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0017857142857142794
# Trade length: 62.51851851851852
# Remaining runs: 420
# Best reward so far: 3699.0789821430026
#
# 21.104705714320872
# Num buys: 49
# Num sells: 42
# Num trades: 91
# Num wins: 61
# Num losses: 30
# Win streak: 11
# Loss streak: 4
# Avg pips risked: 0.0015988618524332865
# Trade length: 8.373626373626374
# Remaining runs: 419
# Best reward so far: 3699.0789821430026
#
# -286.391945357102
# Num buys: 12
# Num sells: 21
# Num trades: 33
# Num wins: 11
# Num losses: 22
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0017913419913420082
# Trade length: 28.272727272727273
# Remaining runs: 418
# Best reward so far: 3699.0789821430026
#
# -1341.7768160710796
# Num buys: 84
# Num sells: 88
# Num trades: 172
# Num wins: 49
# Num losses: 123
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0008813102159468665
# Trade length: 25.203488372093023
# Remaining runs: 417
# Best reward so far: 3699.0789821430026
#
# 374.88237392858355
# Num buys: 9
# Num sells: 12
# Num trades: 21
# Num wins: 19
# Num losses: 2
# Win streak: 9
# Loss streak: 1
# Avg pips risked: 0.0018422959183673811
# Trade length: 1.2857142857142858
# Remaining runs: 416
# Best reward so far: 3699.0789821430026
#
# 615.1984708930086
# Num buys: 100
# Num sells: 81
# Num trades: 181
# Num wins: 129
# Num losses: 52
# Win streak: 12
# Loss streak: 2
# Avg pips risked: 0.0008760438042620563
# Trade length: 5.027624309392265
# Remaining runs: 415
# Best reward so far: 3699.0789821430026
#
# -320.293495714293
# Num buys: 24
# Num sells: 24
# Num trades: 48
# Num wins: 21
# Num losses: 27
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0016660491071428668
# Trade length: 22.4375
# Remaining runs: 414
# Best reward so far: 3699.0789821430026
#
# 450.0057750000059
# Num buys: 29
# Num sells: 25
# Num trades: 54
# Num wins: 42
# Num losses: 12
# Win streak: 16
# Loss streak: 2
# Avg pips risked: 0.00103972222222222
# Trade length: 1.4259259259259258
# Remaining runs: 413
# Best reward so far: 3699.0789821430026
#
# -639.344981428423
# Num buys: 64
# Num sells: 74
# Num trades: 138
# Num wins: 63
# Num losses: 75
# Win streak: 7
# Loss streak: 7
# Avg pips risked: 0.001615253623188434
# Trade length: 25.797101449275363
# Remaining runs: 412
# Best reward so far: 3699.0789821430026
#
# -1933.2266778571636
# Num buys: 109
# Num sells: 83
# Num trades: 192
# Num wins: 77
# Num losses: 115
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0009679761904761962
# Trade length: 14.828125
# Remaining runs: 411
# Best reward so far: 3699.0789821430026
#
# 112.51691214285134
# Num buys: 5
# Num sells: 4
# Num trades: 9
# Num wins: 9
# Num losses: 0
# Win streak: 9
# Loss streak: 0
# Avg pips risked: 0.0018919047619046442
# Trade length: 1.0
# Remaining runs: 410
# Best reward so far: 3699.0789821430026
#
# 28.189835000043693
# Num buys: 11
# Num sells: 6
# Num trades: 17
# Num wins: 6
# Num losses: 11
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0017150000000000548
# Trade length: 91.05882352941177
# Remaining runs: 409
# Best reward so far: 3699.0789821430026
#
# -3608.1537142849083
# Num buys: 230
# Num sells: 207
# Num trades: 437
# Num wins: 183
# Num losses: 254
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0009696289637136648
# Trade length: 12.883295194508008
# Remaining runs: 408
# Best reward so far: 3699.0789821430026
#
# -938.1999535711495
# Num buys: 97
# Num sells: 91
# Num trades: 188
# Num wins: 85
# Num losses: 103
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0008635638297872541
# Trade length: 13.457446808510639
# Remaining runs: 407
# Best reward so far: 3699.0789821430026
#
# -1235.4810758925576
# Num buys: 101
# Num sells: 85
# Num trades: 186
# Num wins: 65
# Num losses: 121
# Win streak: 5
# Loss streak: 9
# Avg pips risked: 0.0009787442396313603
# Trade length: 21.973118279569892
# Remaining runs: 406
# Best reward so far: 3699.0789821430026
#
# 160.52776749999398
# Num buys: 12
# Num sells: 22
# Num trades: 34
# Num wins: 15
# Num losses: 19
# Win streak: 3
# Loss streak: 4
# Avg pips risked: 0.001901344537815123
# Trade length: 49.55882352941177
# Remaining runs: 405
# Best reward so far: 3699.0789821430026
#
# 1273.6586935717955
# Num buys: 173
# Num sells: 166
# Num trades: 339
# Num wins: 243
# Num losses: 96
# Win streak: 11
# Loss streak: 5
# Avg pips risked: 0.0010005520438264208
# Trade length: 3.9410029498525074
# Remaining runs: 404
# Best reward so far: 3699.0789821430026
#
# -3072.3607403566234
# Num buys: 163
# Num sells: 163
# Num trades: 326
# Num wins: 106
# Num losses: 220
# Win streak: 5
# Loss streak: 18
# Avg pips risked: 0.0008411590709903799
# Trade length: 10.389570552147239
# Remaining runs: 403
# Best reward so far: 3699.0789821430026
#
# 49.66884178574128
# Num buys: 34
# Num sells: 40
# Num trades: 74
# Num wins: 50
# Num losses: 24
# Win streak: 7
# Loss streak: 3
# Avg pips risked: 0.0016364671814671945
# Trade length: 5.527027027027027
# Remaining runs: 402
# Best reward so far: 3699.0789821430026
#
# -173.57314499998174
# Num buys: 23
# Num sells: 22
# Num trades: 45
# Num wins: 14
# Num losses: 31
# Win streak: 3
# Loss streak: 9
# Avg pips risked: 0.0018488253968254066
# Trade length: 56.888888888888886
# Remaining runs: 401
# Best reward so far: 3699.0789821430026
#
# 145.48808642875014
# Num buys: 68
# Num sells: 73
# Num trades: 141
# Num wins: 72
# Num losses: 69
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.001090065856129712
# Trade length: 8.75177304964539
# Remaining runs: 400
# Best reward so far: 3699.0789821430026
#
# 417.5630675001653
# Num buys: 62
# Num sells: 45
# Num trades: 107
# Num wins: 58
# Num losses: 49
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.0009640921228304752
# Trade length: 14.158878504672897
# Remaining runs: 399
# Best reward so far: 3699.0789821430026
#
# -3156.132625356455
# Num buys: 197
# Num sells: 217
# Num trades: 414
# Num wins: 176
# Num losses: 238
# Win streak: 5
# Loss streak: 7
# Avg pips risked: 0.0008810015527950533
# Trade length: 11.956521739130435
# Remaining runs: 398
# Best reward so far: 3699.0789821430026
#
# -808.0554424999416
# Num buys: 41
# Num sells: 31
# Num trades: 72
# Num wins: 19
# Num losses: 53
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.0017208234126984351
# Trade length: 66.95833333333333
# Remaining runs: 397
# Best reward so far: 3699.0789821430026
#
# -215.6153010712809
# Num buys: 44
# Num sells: 40
# Num trades: 84
# Num wins: 27
# Num losses: 57
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.0016788562925170447
# Trade length: 62.916666666666664
# Remaining runs: 396
# Best reward so far: 3699.0789821430026
#
# 1019.0992073218572
# Num buys: 258
# Num sells: 254
# Num trades: 512
# Num wins: 355
# Num losses: 157
# Win streak: 15
# Loss streak: 6
# Avg pips risked: 0.000892171456473234
# Trade length: 4.41015625
# Remaining runs: 395
# Best reward so far: 3699.0789821430026
#
# -4061.96270357038
# Num buys: 267
# Num sells: 273
# Num trades: 540
# Num wins: 185
# Num losses: 354
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.0009761891534391788
# Trade length: 24.682745825602968
# Remaining runs: 394
# Best reward so far: 3699.0789821430026
#
# 1562.3450973215351
# Num buys: 102
# Num sells: 88
# Num trades: 190
# Num wins: 177
# Num losses: 13
# Win streak: 52
# Loss streak: 2
# Avg pips risked: 0.000971618421052675
# Trade length: 1.0
# Remaining runs: 393
# Best reward so far: 3699.0789821430026
#
# 674.9151448214304
# Num buys: 16
# Num sells: 17
# Num trades: 33
# Num wins: 31
# Num losses: 2
# Win streak: 11
# Loss streak: 1
# Avg pips risked: 0.0017871861471861399
# Trade length: 1.4242424242424243
# Remaining runs: 392
# Best reward so far: 3699.0789821430026
#
# -6112.349604463444
# Num buys: 226
# Num sells: 254
# Num trades: 480
# Num wins: 144
# Num losses: 336
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.000892093750000023
# Trade length: 16.910416666666666
# Remaining runs: 391
# Best reward so far: 3699.0789821430026
#
# -149.53867053576866
# Num buys: 112
# Num sells: 86
# Num trades: 198
# Num wins: 156
# Num losses: 42
# Win streak: 14
# Loss streak: 4
# Avg pips risked: 0.0009618470418470297
# Trade length: 2.606060606060606
# Remaining runs: 390
# Best reward so far: 3699.0789821430026
#
# -4396.790865713466
# Num buys: 242
# Num sells: 226
# Num trades: 468
# Num wins: 128
# Num losses: 340
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.00098514346764349
# Trade length: 27.995726495726494
# Remaining runs: 389
# Best reward so far: 3699.0789821430026
#
# 276.35954821464964
# Num buys: 168
# Num sells: 176
# Num trades: 344
# Num wins: 233
# Num losses: 111
# Win streak: 13
# Loss streak: 5
# Avg pips risked: 0.000822041112956841
# Trade length: 3.188953488372093
# Remaining runs: 388
# Best reward so far: 3699.0789821430026
#
# -62.00860821416162
# Num buys: 47
# Num sells: 40
# Num trades: 87
# Num wins: 43
# Num losses: 44
# Win streak: 6
# Loss streak: 5
# Avg pips risked: 0.0016761699507389562
# Trade length: 21.977011494252874
# Remaining runs: 387
# Best reward so far: 3699.0789821430026
#
# -1277.833143570688
# Num buys: 263
# Num sells: 252
# Num trades: 515
# Num wins: 245
# Num losses: 270
# Win streak: 6
# Loss streak: 6
# Avg pips risked: 0.0008930478502080658
# Trade length: 10.118446601941747
# Remaining runs: 386
# Best reward so far: 3699.0789821430026
#
# 712.4779089287279
# Num buys: 98
# Num sells: 94
# Num trades: 192
# Num wins: 165
# Num losses: 27
# Win streak: 31
# Loss streak: 2
# Avg pips risked: 0.0008653273809524168
# Trade length: 2.4583333333333335
# Remaining runs: 385
# Best reward so far: 3699.0789821430026
#
# 153.704688214457
# Num buys: 61
# Num sells: 45
# Num trades: 106
# Num wins: 44
# Num losses: 62
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0009655424528302086
# Trade length: 22.735849056603772
# Remaining runs: 384
# Best reward so far: 3699.0789821430026
#
# -24.954753928578892
# Num buys: 16
# Num sells: 12
# Num trades: 28
# Num wins: 22
# Num losses: 6
# Win streak: 5
# Loss streak: 1
# Avg pips risked: 0.0017794387755102178
# Trade length: 1.7857142857142858
# Remaining runs: 383
# Best reward so far: 3699.0789821430026
#
# 226.99945428580745
# Num buys: 27
# Num sells: 25
# Num trades: 52
# Num wins: 19
# Num losses: 33
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0010414835164835345
# Trade length: 31.21153846153846
# Remaining runs: 382
# Best reward so far: 3699.0789821430026
#
# -2468.504081428067
# Num buys: 171
# Num sells: 164
# Num trades: 335
# Num wins: 143
# Num losses: 192
# Win streak: 9
# Loss streak: 11
# Avg pips risked: 0.0010049488272921372
# Trade length: 11.02089552238806
# Remaining runs: 381
# Best reward so far: 3699.0789821430026
#
# -1637.83852821401
# Num buys: 135
# Num sells: 132
# Num trades: 267
# Num wins: 94
# Num losses: 173
# Win streak: 7
# Loss streak: 9
# Avg pips risked: 0.0008591305510968605
# Trade length: 11.153558052434457
# Remaining runs: 380
# Best reward so far: 3699.0789821430026
#
# -161.57794035714898
# Num buys: 5
# Num sells: 8
# Num trades: 13
# Num wins: 4
# Num losses: 9
# Win streak: 3
# Loss streak: 8
# Avg pips risked: 0.0020120879120879
# Trade length: 71.84615384615384
# Remaining runs: 379
# Best reward so far: 3699.0789821430026
#
# 174.91235714286034
# Num buys: 4
# Num sells: 3
# Num trades: 7
# Num wins: 7
# Num losses: 0
# Win streak: 7
# Loss streak: 0
# Avg pips risked: 0.0020573979591837093
# Trade length: 1.4285714285714286
# Remaining runs: 378
# Best reward so far: 3699.0789821430026
#
# 19.80798857141913
# Num buys: 3
# Num sells: 4
# Num trades: 7
# Num wins: 3
# Num losses: 4
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0022819387755101737
# Trade length: 66.14285714285714
# Remaining runs: 377
# Best reward so far: 3699.0789821430026
#
# -187.6746299999765
# Num buys: 22
# Num sells: 24
# Num trades: 46
# Num wins: 17
# Num losses: 29
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.001838276397515545
# Trade length: 24.391304347826086
# Remaining runs: 376
# Best reward so far: 3699.0789821430026
#
# 1025.6028353571455
# Num buys: 49
# Num sells: 31
# Num trades: 80
# Num wins: 67
# Num losses: 13
# Win streak: 15
# Loss streak: 3
# Avg pips risked: 0.0008768303571428604
# Trade length: 1.4
# Remaining runs: 375
# Best reward so far: 3699.0789821430026
#
# -156.5519824999692
# Num buys: 14
# Num sells: 16
# Num trades: 30
# Num wins: 18
# Num losses: 12
# Win streak: 5
# Loss streak: 2
# Avg pips risked: 0.0016864523809524041
# Trade length: 13.633333333333333
# Remaining runs: 374
# Best reward so far: 3699.0789821430026
#
# -585.2880049999203
# Num buys: 49
# Num sells: 31
# Num trades: 80
# Num wins: 23
# Num losses: 57
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0008768303571428631
# Trade length: 19.325
# Remaining runs: 373
# Best reward so far: 3699.0789821430026
#
# 247.38430999999213
# Num buys: 5
# Num sells: 5
# Num trades: 10
# Num wins: 5
# Num losses: 5
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.001824857142857106
# Trade length: 33.5
# Remaining runs: 372
# Best reward so far: 3699.0789821430026
#
# -419.41937499985596
# Num buys: 53
# Num sells: 47
# Num trades: 100
# Num wins: 46
# Num losses: 54
# Win streak: 6
# Loss streak: 5
# Avg pips risked: 0.0016610464285714687
# Trade length: 23.72
# Remaining runs: 371
# Best reward so far: 3699.0789821430026
#
# 382.1717951789699
# Num buys: 219
# Num sells: 238
# Num trades: 457
# Num wins: 310
# Num losses: 147
# Win streak: 11
# Loss streak: 4
# Avg pips risked: 0.0008829579556111583
# Trade length: 4.9431072210065645
# Remaining runs: 370
# Best reward so far: 3699.0789821430026
#
# 1424.8459012501937
# Num buys: 173
# Num sells: 166
# Num trades: 339
# Num wins: 294
# Num losses: 45
# Win streak: 27
# Loss streak: 2
# Avg pips risked: 0.0010005520438264195
# Trade length: 1.4867256637168142
# Remaining runs: 369
# Best reward so far: 3699.0789821430026
#
# 293.6723053572627
# Num buys: 82
# Num sells: 59
# Num trades: 141
# Num wins: 98
# Num losses: 43
# Win streak: 12
# Loss streak: 3
# Avg pips risked: 0.0009560992907801725
# Trade length: 4.815602836879433
# Remaining runs: 368
# Best reward so far: 3699.0789821430026
#
# 599.9265387501226
# Num buys: 262
# Num sells: 236
# Num trades: 498
# Num wins: 408
# Num losses: 90
# Win streak: 22
# Loss streak: 3
# Avg pips risked: 0.0009721242111302608
# Trade length: 2.4136546184738954
# Remaining runs: 367
# Best reward so far: 3699.0789821430026
#
# -3641.6986357133965
# Num buys: 218
# Num sells: 197
# Num trades: 415
# Num wins: 115
# Num losses: 300
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.0009760447504303189
# Trade length: 27.06024096385542
# Remaining runs: 366
# Best reward so far: 3699.0789821430026
#
# 133.6833200000313
# Num buys: 31
# Num sells: 26
# Num trades: 57
# Num wins: 30
# Num losses: 27
# Win streak: 6
# Loss streak: 4
# Avg pips risked: 0.0017542982456140478
# Trade length: 23.105263157894736
# Remaining runs: 365
# Best reward so far: 3699.0789821430026
#
# -4266.178196249365
# Num buys: 203
# Num sells: 220
# Num trades: 423
# Num wins: 136
# Num losses: 287
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0008916759540695923
# Trade length: 19.54373522458629
# Remaining runs: 364
# Best reward so far: 3699.0789821430026
#
# 325.0358632142917
# Num buys: 19
# Num sells: 22
# Num trades: 41
# Num wins: 38
# Num losses: 3
# Win streak: 12
# Loss streak: 1
# Avg pips risked: 0.0018618466898954948
# Trade length: 1.0975609756097562
# Remaining runs: 363
# Best reward so far: 3699.0789821430026
#
# -368.5738785713879
# Num buys: 17
# Num sells: 23
# Num trades: 40
# Num wins: 11
# Num losses: 29
# Win streak: 2
# Loss streak: 9
# Avg pips risked: 0.0018142857142857266
# Trade length: 50.475
# Remaining runs: 362
# Best reward so far: 3699.0789821430026
#
# 174.70313089286242
# Num buys: 16
# Num sells: 23
# Num trades: 39
# Num wins: 34
# Num losses: 5
# Win streak: 16
# Loss streak: 1
# Avg pips risked: 0.0018234981684981787
# Trade length: 1.2820512820512822
# Remaining runs: 361
# Best reward so far: 3699.0789821430026
#
# -262.526472499996
# Num buys: 17
# Num sells: 13
# Num trades: 30
# Num wins: 10
# Num losses: 20
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.001785476190476176
# Trade length: 34.56666666666667
# Remaining runs: 360
# Best reward so far: 3699.0789821430026
#
# 1224.8890528572515
# Num buys: 232
# Num sells: 211
# Num trades: 443
# Num wins: 374
# Num losses: 69
# Win streak: 22
# Loss streak: 3
# Avg pips risked: 0.0009654127700741998
# Trade length: 1.8826185101580135
# Remaining runs: 359
# Best reward so far: 3699.0789821430026
#
# 2149.612642857389
# Num buys: 178
# Num sells: 199
# Num trades: 377
# Num wins: 280
# Num losses: 97
# Win streak: 19
# Loss streak: 4
# Avg pips risked: 0.0008718226600985423
# Trade length: 2.750663129973475
# Remaining runs: 358
# Best reward so far: 3699.0789821430026
#
# -58.59583928571713
# Num buys: 5
# Num sells: 8
# Num trades: 13
# Num wins: 6
# Num losses: 7
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0020120879120879053
# Trade length: 53.30769230769231
# Remaining runs: 357
# Best reward so far: 3699.0789821430026
#
# -2657.5918821425266
# Num buys: 172
# Num sells: 166
# Num trades: 338
# Num wins: 115
# Num losses: 223
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0010004184277261346
# Trade length: 23.87869822485207
# Remaining runs: 356
# Best reward so far: 3699.0789821430026
#
# 874.8116064285839
# Num buys: 42
# Num sells: 33
# Num trades: 75
# Num wins: 74
# Num losses: 1
# Win streak: 49
# Loss streak: 1
# Avg pips risked: 0.0017165095238095536
# Trade length: 1.4666666666666666
# Remaining runs: 355
# Best reward so far: 3699.0789821430026
#
# 34.848181428612236
# Num buys: 10
# Num sells: 7
# Num trades: 17
# Num wins: 6
# Num losses: 11
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.0016998739495798873
# Trade length: 64.41176470588235
# Remaining runs: 354
# Best reward so far: 3699.0789821430026
#
# -240.72796071413518
# Num buys: 63
# Num sells: 83
# Num trades: 146
# Num wins: 71
# Num losses: 75
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0016245547945205753
# Trade length: 25.458904109589042
# Remaining runs: 353
# Best reward so far: 3699.0789821430026
#
# -280.93749000000963
# Num buys: 17
# Num sells: 15
# Num trades: 32
# Num wins: 9
# Num losses: 23
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0017025446428571393
# Trade length: 61.3125
# Remaining runs: 352
# Best reward so far: 3699.0789821430026
#
# -37.31639321425217
# Num buys: 58
# Num sells: 49
# Num trades: 107
# Num wins: 85
# Num losses: 22
# Win streak: 15
# Loss streak: 3
# Avg pips risked: 0.0009821361815754671
# Trade length: 1.5981308411214954
# Remaining runs: 351
# Best reward so far: 3699.0789821430026
#
# 298.7414557142799
# Num buys: 16
# Num sells: 11
# Num trades: 27
# Num wins: 22
# Num losses: 5
# Win streak: 7
# Loss streak: 1
# Avg pips risked: 0.0018748677248677094
# Trade length: 8.592592592592593
# Remaining runs: 350
# Best reward so far: 3699.0789821430026
#
# 949.9229901786625
# Num buys: 87
# Num sells: 94
# Num trades: 181
# Num wins: 160
# Num losses: 21
# Win streak: 31
# Loss streak: 2
# Avg pips risked: 0.001083441199684317
# Trade length: 1.0
# Remaining runs: 349
# Best reward so far: 3699.0789821430026
#
# -2984.5000435709467
# Num buys: 150
# Num sells: 154
# Num trades: 304
# Num wins: 82
# Num losses: 222
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.000844064849624075
# Trade length: 19.549342105263158
# Remaining runs: 348
# Best reward so far: 3699.0789821430026
#
# -4751.291699642041
# Num buys: 224
# Num sells: 204
# Num trades: 428
# Num wins: 134
# Num losses: 294
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009764836448598359
# Trade length: 21.25
# Remaining runs: 347
# Best reward so far: 3699.0789821430026
#
# 224.98229428572918
# Num buys: 12
# Num sells: 21
# Num trades: 33
# Num wins: 30
# ...
# Trade length: 59.20779220779221
# Remaining runs: 65
# Best reward so far: 5449.29430857158
#
# -112.52160857141811
# Num buys: 14
# Num sells: 16
# Num trades: 30
# Num wins: 14
# Num losses: 16
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.0016864523809524041
# Trade length: 37.4
# Remaining runs: 64
# Best reward so far: 5449.29430857158
#
# 297.38351428570985
# Num buys: 5
# Num sells: 4
# Num trades: 9
# Num wins: 5
# Num losses: 4
# Win streak: 3
# Loss streak: 2
# Avg pips risked: 0.0018919047619047305
# Trade length: 36.666666666666664
# Remaining runs: 63
# Best reward so far: 5449.29430857158
#
# -308.21429857136735
# Num buys: 40
# Num sells: 38
# Num trades: 78
# Num wins: 36
# Num losses: 42
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0016963278388278623
# Trade length: 18.653846153846153
# Remaining runs: 62
# Best reward so far: 5449.29430857158
#
# -261.17721321425506
# Num buys: 17
# Num sells: 23
# Num trades: 40
# Num wins: 14
# Num losses: 26
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0018142857142857203
# Trade length: 26.475
# Remaining runs: 61
# Best reward so far: 5449.29430857158
#
# -311.01495142856095
# Num buys: 12
# Num sells: 12
# Num trades: 24
# Num wins: 9
# Num losses: 15
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0018723809523809403
# Trade length: 37.916666666666664
# Remaining runs: 60
# Best reward so far: 5449.29430857158
#
# -308.8808328571386
# Num buys: 15
# Num sells: 11
# Num trades: 26
# Num wins: 10
# Num losses: 16
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.0018909340659340511
# Trade length: 28.0
# Remaining runs: 59
# Best reward so far: 5449.29430857158
#
# -137.29308071426027
# Num buys: 22
# Num sells: 23
# Num trades: 45
# Num wins: 17
# Num losses: 28
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0018290000000000198
# Trade length: 25.155555555555555
# Remaining runs: 58
# Best reward so far: 5449.29430857158
#
# 373.50545000000295
# Num buys: 12
# Num sells: 12
# Num trades: 24
# Num wins: 21
# Num losses: 3
# Win streak: 13
# Loss streak: 1
# Avg pips risked: 0.0018723809523809587
# Trade length: 9.083333333333334
# Remaining runs: 57
# Best reward so far: 5449.29430857158
#
# 370.0637173214088
# Num buys: 24
# Num sells: 24
# Num trades: 48
# Num wins: 37
# Num losses: 11
# Win streak: 14
# Loss streak: 3
# Avg pips risked: 0.001666049107142853
# Trade length: 5.979166666666667
# Remaining runs: 56
# Best reward so far: 5449.29430857158
#
# 400.03591142856834
# Num buys: 20
# Num sells: 17
# Num trades: 37
# Num wins: 30
# Num losses: 7
# Win streak: 13
# Loss streak: 2
# Avg pips risked: 0.001683619691119703
# Trade length: 2.2972972972972974
# Remaining runs: 55
# Best reward so far: 5449.29430857158
#
# 2049.8072119643984
# Num buys: 134
# Num sells: 135
# Num trades: 269
# Num wins: 248
# Num losses: 21
# Win streak: 41
# Loss streak: 2
# Avg pips risked: 0.0008969516728624723
# Trade length: 1.0
# Remaining runs: 54
# Best reward so far: 5449.29430857158
#
# -472.98228160714496
# Num buys: 39
# Num sells: 25
# Num trades: 64
# Num wins: 22
# Num losses: 42
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.001019056919642864
# Trade length: 21.515625
# Remaining runs: 53
# Best reward so far: 5449.29430857158
#
# -174.0048773214747
# Num buys: 90
# Num sells: 76
# Num trades: 166
# Num wins: 130
# Num losses: 36
# Win streak: 22
# Loss streak: 3
# Avg pips risked: 0.0009802495697074003
# Trade length: 2.3855421686746987
# Remaining runs: 52
# Best reward so far: 5449.29430857158
#
# -2997.9004567849142
# Num buys: 187
# Num sells: 196
# Num trades: 383
# Num wins: 162
# Num losses: 221
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.0009008961208504655
# Trade length: 11.77284595300261
# Remaining runs: 51
# Best reward so far: 5449.29430857158
#
# -3881.7738835708524
# Num buys: 196
# Num sells: 225
# Num trades: 421
# Num wins: 115
# Num losses: 306
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0008490668476416862
# Trade length: 17.356294536817103
# Remaining runs: 50
# Best reward so far: 5449.29430857158
#
# -340.68257285701634
# Num buys: 45
# Num sells: 47
# Num trades: 92
# Num wins: 29
# Num losses: 63
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.001630225155279523
# Trade length: 79.73913043478261
# Remaining runs: 49
# Best reward so far: 5449.29430857158
#
# -116.06921035711285
# Num buys: 11
# Num sells: 6
# Num trades: 17
# Num wins: 6
# Num losses: 11
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0017150000000000414
# Trade length: 70.29411764705883
# Remaining runs: 48
# Best reward so far: 5449.29430857158
#
# -3888.989107142231
# Num buys: 260
# Num sells: 234
# Num trades: 494
# Num wins: 209
# Num losses: 285
# Win streak: 10
# Loss streak: 11
# Avg pips risked: 0.0009728947368421286
# Trade length: 13.947368421052632
# Remaining runs: 47
# Best reward so far: 5449.29430857158
#
# -3192.1170696422287
# Num buys: 166
# Num sells: 172
# Num trades: 338
# Num wins: 110
# Num losses: 228
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0008269885883347651
# Trade length: 11.195266272189349
# Remaining runs: 46
# Best reward so far: 5449.29430857158
#
# 149.7962028571768
# Num buys: 31
# Num sells: 29
# Num trades: 60
# Num wins: 42
# Num losses: 18
# Win streak: 10
# Loss streak: 4
# Avg pips risked: 0.0015983750000000555
# Trade length: 5.4
# Remaining runs: 45
# Best reward so far: 5449.29430857158
#
# -1885.2390964280198
# Num buys: 151
# Num sells: 183
# Num trades: 334
# Num wins: 119
# Num losses: 215
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.0008773567151411688
# Trade length: 13.239520958083832
# Remaining runs: 44
# Best reward so far: 5449.29430857158
#
# -3222.9274771424216
# Num buys: 132
# Num sells: 132
# Num trades: 264
# Num wins: 67
# Num losses: 197
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0008973890692640837
# Trade length: 18.564393939393938
# Remaining runs: 43
# Best reward so far: 5449.29430857158
#
# 1581.3079410716655
# Num buys: 220
# Num sells: 237
# Num trades: 457
# Num wins: 391
# Num losses: 66
# Win streak: 33
# Loss streak: 3
# Avg pips risked: 0.0008818810565802013
# Trade length: 2.4857768052516414
# Remaining runs: 42
# Best reward so far: 5449.29430857158
#
# 1764.4598650001967
# Num buys: 200
# Num sells: 226
# Num trades: 426
# Num wins: 369
# Num losses: 57
# Win streak: 31
# Loss streak: 3
# Avg pips risked: 0.0008556136820925817
# Trade length: 1.6948356807511737
# Remaining runs: 41
# Best reward so far: 5449.29430857158
#
# 149.8142841071359
# Num buys: 13
# Num sells: 14
# Num trades: 27
# Num wins: 24
# Num losses: 3
# Win streak: 21
# Loss streak: 2
# Avg pips risked: 0.001727751322751282
# Trade length: 1.7407407407407407
# Remaining runs: 40
# Best reward so far: 5449.29430857158
#
# 112.7007221428926
# Num buys: 19
# Num sells: 21
# Num trades: 40
# Num wins: 17
# Num losses: 23
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0018584642857143046
# Trade length: 26.3
# Remaining runs: 39
# Best reward so far: 5449.29430857158
#
# 812.5642916964591
# Num buys: 53
# Num sells: 47
# Num trades: 100
# Num wins: 93
# Num losses: 7
# Win streak: 34
# Loss streak: 1
# Avg pips risked: 0.0016585857142857564
# Trade length: 2.53
# Remaining runs: 38
# Best reward so far: 5449.29430857158
#
# -1229.2246296425285
# Num buys: 98
# Num sells: 84
# Num trades: 182
# Num wins: 53
# Num losses: 129
# Win streak: 4
# Loss streak: 15
# Avg pips risked: 0.0009751236263736497
# Trade length: 28.791208791208792
# Remaining runs: 37
# Best reward so far: 5449.29430857158
#
# 195.62500357148073
# Num buys: 25
# Num sells: 38
# Num trades: 63
# Num wins: 27
# Num losses: 36
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0017579478458050037
# Trade length: 52.74603174603175
# Remaining runs: 36
# Best reward so far: 5449.29430857158
#
# 231.79164285713674
# Num buys: 12
# Num sells: 22
# Num trades: 34
# Num wins: 13
# Num losses: 21
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0019013445378151268
# Trade length: 60.705882352941174
# Remaining runs: 35
# Best reward so far: 5449.29430857158
#
# 524.6955953571679
# Num buys: 40
# Num sells: 38
# Num trades: 78
# Num wins: 59
# Num losses: 19
# Win streak: 11
# Loss streak: 3
# Avg pips risked: 0.001696561355311374
# Trade length: 3.8205128205128207
# Remaining runs: 34
# Best reward so far: 5449.29430857158
#
# 220.98539535714465
# Num buys: 7
# Num sells: 8
# Num trades: 15
# Num wins: 13
# Num losses: 2
# Win streak: 9
# Loss streak: 1
# Avg pips risked: 0.001762452380952458
# Trade length: 10.0
# Remaining runs: 33
# Best reward so far: 5449.29430857158
#
# -484.9329385710569
# Num buys: 83
# Num sells: 91
# Num trades: 174
# Num wins: 55
# Num losses: 119
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0010970443349753959
# Trade length: 24.379310344827587
# Remaining runs: 32
# Best reward so far: 5449.29430857158
#
# -4283.8562249994475
# Num buys: 191
# Num sells: 209
# Num trades: 400
# Num wins: 126
# Num losses: 274
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0008612892857143063
# Trade length: 11.4
# Remaining runs: 31
# Best reward so far: 5449.29430857158
#
# -263.5881124999833
# Num buys: 26
# Num sells: 25
# Num trades: 51
# Num wins: 23
# Num losses: 28
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0016322128851540753
# Trade length: 17.352941176470587
# Remaining runs: 30
# Best reward so far: 5449.29430857158
#
# -4454.653117142169
# Num buys: 229
# Num sells: 259
# Num trades: 488
# Num wins: 200
# Num losses: 288
# Win streak: 6
# Loss streak: 8
# Avg pips risked: 0.0008913956381733258
# Trade length: 10.813524590163935
# Remaining runs: 29
# Best reward so far: 5449.29430857158
#
# 99.99873214284395
# Num buys: 5
# Num sells: 5
# Num trades: 10
# Num wins: 8
# Num losses: 2
# Win streak: 6
# Loss streak: 1
# Avg pips risked: 0.0018248571428571391
# Trade length: 4.2
# Remaining runs: 28
# Best reward so far: 5449.29430857158
#
# -7.0369889285445275
# Num buys: 20
# Num sells: 17
# Num trades: 37
# Num wins: 15
# Num losses: 22
# Win streak: 3
# Loss streak: 4
# Avg pips risked: 0.0016836196911197152
# Trade length: 62.13513513513514
# Remaining runs: 27
# Best reward so far: 5449.29430857158
#
# -3049.077198927758
# Num buys: 254
# Num sells: 236
# Num trades: 490
# Num wins: 144
# Num losses: 346
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.0008991537900874836
# Trade length: 22.3734693877551
# Remaining runs: 26
# Best reward so far: 5449.29430857158
#
# -53.56929499998755
# Num buys: 4
# Num sells: 3
# Num trades: 7
# Num wins: 2
# Num losses: 5
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0020573979591837093
# Trade length: 21.0
# Remaining runs: 25
# Best reward so far: 5449.29430857158
#
# 149.99793642856173
# Num buys: 5
# Num sells: 4
# Num trades: 9
# Num wins: 8
# Num losses: 1
# Win streak: 8
# Loss streak: 1
# Avg pips risked: 0.0018919047619047429
# Trade length: 4.111111111111111
# Remaining runs: 24
# Best reward so far: 5449.29430857158
#
# -333.6409453570111
# Num buys: 46
# Num sells: 40
# Num trades: 86
# Num wins: 32
# Num losses: 54
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0016755315614618296
# Trade length: 42.26744186046512
# Remaining runs: 23
# Best reward so far: 5449.29430857158
#
# 28.407990000014824
# Num buys: 9
# Num sells: 14
# Num trades: 23
# Num wins: 8
# Num losses: 15
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.001966397515527967
# Trade length: 84.0
# Remaining runs: 22
# Best reward so far: 5449.29430857158
#
# -2935.373954285032
# Num buys: 222
# Num sells: 241
# Num trades: 463
# Num wins: 203
# Num losses: 260
# Win streak: 6
# Loss streak: 9
# Avg pips risked: 0.0009693397099660916
# Trade length: 15.91792656587473
# Remaining runs: 21
# Best reward so far: 5449.29430857158
#
# -766.3829387498508
# Num buys: 52
# Num sells: 45
# Num trades: 97
# Num wins: 33
# Num losses: 64
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.0016628350515464252
# Trade length: 42.21649484536083
# Remaining runs: 20
# Best reward so far: 5449.29430857158
#
# -219.29474928573072
# Num buys: 19
# Num sells: 15
# Num trades: 34
# Num wins: 15
# Num losses: 19
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0017048109243697452
# Trade length: 36.205882352941174
# Remaining runs: 19
# Best reward so far: 5449.29430857158
#
# 171.85623142856954
# Num buys: 5
# Num sells: 4
# Num trades: 9
# Num wins: 5
# Num losses: 4
# Win streak: 3
# Loss streak: 2
# Avg pips risked: 0.0018919047619047266
# Trade length: 25.0
# Remaining runs: 18
# Best reward so far: 5449.29430857158
#
# -1479.237722856849
# Num buys: 151
# Num sells: 162
# Num trades: 313
# Num wins: 142
# Num losses: 171
# Win streak: 7
# Loss streak: 7
# Avg pips risked: 0.0008376449109995539
# Trade length: 8.34185303514377
# Remaining runs: 17
# Best reward so far: 5449.29430857158
#
# -1281.0570635709025
# Num buys: 129
# Num sells: 136
# Num trades: 265
# Num wins: 120
# Num losses: 145
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.00101050673854451
# Trade length: 12.573584905660377
# Remaining runs: 16
# Best reward so far: 5449.29430857158
#
# -123.49730071427447
# Num buys: 15
# Num sells: 11
# Num trades: 26
# Num wins: 8
# Num losses: 18
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.001885054945054946
# Trade length: 103.38461538461539
# Remaining runs: 15
# Best reward so far: 5449.29430857158
#
# 50.34004625013404
# Num buys: 81
# Num sells: 68
# Num trades: 149
# Num wins: 120
# Num losses: 29
# Win streak: 19
# Loss streak: 3
# Avg pips risked: 0.000817363374880216
# Trade length: 1.610738255033557
# Remaining runs: 14
# Best reward so far: 5449.29430857158
#
# 1062.7679766072015
# Num buys: 133
# Num sells: 137
# Num trades: 270
# Num wins: 233
# Num losses: 37
# Win streak: 37
# Loss streak: 2
# Avg pips risked: 0.0010037407407407588
# Trade length: 1.5666666666666667
# Remaining runs: 13
# Best reward so far: 5449.29430857158
#
# -15.309371071408467
# Num buys: 7
# Num sells: 8
# Num trades: 15
# Num wins: 5
# Num losses: 10
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.001762452380952421
# Trade length: 69.4
# Remaining runs: 12
# Best reward so far: 5449.29430857158
#
# 150.15698044641417
# Num buys: 10
# Num sells: 7
# Num trades: 17
# Num wins: 16
# Num losses: 1
# Win streak: 11
# Loss streak: 1
# Avg pips risked: 0.0016998739495797633
# Trade length: 2.411764705882353
# Remaining runs: 11
# Best reward so far: 5449.29430857158
#
# -241.22918428570023
# Num buys: 16
# Num sells: 11
# Num trades: 27
# Num wins: 9
# Num losses: 18
# Win streak: 3
# Loss streak: 8
# Avg pips risked: 0.0018748677248677256
# Trade length: 74.11111111111111
# Remaining runs: 10
# Best reward so far: 5449.29430857158
#
# 86.66824250002901
# Num buys: 7
# Num sells: 6
# Num trades: 13
# Num wins: 5
# Num losses: 8
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.0017951098901099344
# Trade length: 68.6923076923077
# Remaining runs: 9
# Best reward so far: 5449.29430857158
#
# 105.04551000027195
# Num buys: 63
# Num sells: 72
# Num trades: 135
# Num wins: 46
# Num losses: 89
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0010954285714285983
# Trade length: 31.607407407407408
# Remaining runs: 8
# Best reward so far: 5449.29430857158
#
# 124.48815892856454
# Num buys: 29
# Num sells: 39
# Num trades: 68
# Num wins: 47
# Num losses: 21
# Win streak: 8
# Loss streak: 4
# Avg pips risked: 0.001702878151260487
# Trade length: 4.735294117647059
# Remaining runs: 7
# Best reward so far: 5449.29430857158
#
# -640.5343107139645
# Num buys: 80
# Num sells: 68
# Num trades: 148
# Num wins: 68
# Num losses: 80
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.0008858711389961739
# Trade length: 11.97972972972973
# Remaining runs: 6
# Best reward so far: 5449.29430857158
#
# 457.6295207142961
# Num buys: 9
# Num sells: 14
# Num trades: 23
# Num wins: 13
# Num losses: 10
# Win streak: 5
# Loss streak: 4
# Avg pips risked: 0.0017797826086956654
# Trade length: 71.26086956521739
# Remaining runs: 5
# Best reward so far: 5449.29430857158
#
# -693.9062517854007
# Num buys: 84
# Num sells: 75
# Num trades: 159
# Num wins: 73
# Num losses: 86
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0008975404312668821
# Trade length: 12.930817610062894
# Remaining runs: 4
# Best reward so far: 5449.29430857158
#
# -2178.0810303566836
# Num buys: 152
# Num sells: 158
# Num trades: 310
# Num wins: 107
# Num losses: 203
# Win streak: 4
# Loss streak: 15
# Avg pips risked: 0.0008435299539170665
# Trade length: 12.287096774193548
# Remaining runs: 3
# Best reward so far: 5449.29430857158
#
# 233.8507189285861
# Num buys: 20
# Num sells: 17
# Num trades: 37
# Num wins: 21
# Num losses: 16
# Win streak: 6
# Loss streak: 4
# Avg pips risked: 0.001683619691119703
# Trade length: 22.783783783783782
# Remaining runs: 2
# Best reward so far: 5449.29430857158
#
# 410.628414285776
# Num buys: 25
# Num sells: 38
# Num trades: 63
# Num wins: 24
# Num losses: 39
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.001757947845805004
# Trade length: 62.34920634920635
# Remaining runs: 1
# Best reward so far: 5449.29430857158
#
# -886.9763353567165
# Num buys: 146
# Num sells: 157
# Num trades: 303
# Num wins: 143
# Num losses: 160
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.000913592644978809
# Trade length: 11.006600660066006
# Remaining runs: 0
# Best reward so far: 5449.29430857158

# %%
# EUR/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(n_bars))
print('Best adx cutoff: ' + str(best_adx_cutoff))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 5449.29430857158
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n bars: 10
# Best adx cutoff: 25
# -----------------------
# Top results:
# {'reward': 3699, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 1962, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 10, 'adx_cutoff': 25}
# {'reward': 3275, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 10, 'adx_cutoff': 20}
# {'reward': 2549, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 5, 'adx_cutoff': 25}
# {'reward': 1950, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 15, 'adx_cutoff': 20}
# {'reward': 2149, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 15, 'adx_cutoff': 25}
# {'reward': 2137, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 10, 'adx_cutoff': 20}
# {'reward': 2799, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 5, 'adx_cutoff': 25}
# {'reward': 3225, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 10, 'adx_cutoff': 25}
# {'reward': 4324, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 5, 'adx_cutoff': 25}
# {'reward': 2049, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 2199, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 30, 'adx_cutoff': 25}
# {'reward': 5449, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 5, 'adx_cutoff': 25}
# {'reward': 3475, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 10, 'adx_cutoff': 25}
# {'reward': 2024, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 15, 'adx_cutoff': 25}
# {'reward': 2951, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 2850, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 10, 'adx_cutoff': 25}
# {'reward': 1874, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 10, 'adx_cutoff': 20}
# {'reward': 2125, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 10, 'adx_cutoff': 20}
# {'reward': 2049, 'ratio': 0.25, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 5, 'adx_cutoff': 25}

# %%
# GBP/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 4223.3566550000905
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 4124, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 2249, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 2668, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 3674, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 2172, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 1450, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 4223, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 2473, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 2275, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}

# %%
# AUD/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1876.0760714286596
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 95, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 1798, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 1876, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 1650, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 1700, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 1497, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 50, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 850, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 1199, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}

# %%
# USD/CAD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 4048.6535253571433
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 1
# -----------------------
# Top results:
# {'reward': 2053, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 716, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 4048, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 636, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 523, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 2977, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 3480, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 2039, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 2445, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}

# %%
# USD/JPY
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 250758.18965857464
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 1
# -----------------------
# Top results:
# {'reward': 145619, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 192316, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 37162, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 176101, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 225827, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 250758, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 206984, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 135342, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 148785, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}

# %%
# USD/CHF
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1456.2561146429143
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 1456, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 1316, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 225, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 1034, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 207, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 690, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 296, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 302, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 1339, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}

# %%
# NZD/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1074.2768450000149
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 3
# -----------------------
# Top results:
# {'reward': 725, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 1074, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': -25, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 624, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 750, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 449, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 549, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 774, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 1049, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}

# %%
# GBP/CHF
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n minutes: ' + str(best_n_minutes))
print('Best adx cutoff: ' + str(best_adx_cutoff))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 527.8893594643564
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n minutes: 5
# Best adx cutoff: 25
# -----------------------
# Top results:
# {'reward': 300, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 10, 'adx_cutoff': 15}
# {'reward': 527, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 25}
# {'reward': 367, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 15}
# {'reward': 339, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 2.5, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 371, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 25}
# {'reward': 488, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 5, 'adx_cutoff': 20}
# {'reward': 244, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 15, 'adx_cutoff': 15}
# {'reward': 433, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 2.5, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 302, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 20}
# {'reward': 485, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 15, 'adx_cutoff': 15}
# {'reward': 243, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 10, 'adx_cutoff': 25}
# {'reward': 366, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 5, 'adx_cutoff': 20}
# {'reward': 317, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 10, 'adx_cutoff': 25}
# {'reward': 336, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 10, 'adx_cutoff': 20}
# {'reward': 399, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 2.5, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 241, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 20}
# {'reward': 402, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 15}
# {'reward': 189, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 25}
# {'reward': 319, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 20}
# {'reward': 395, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 25}

# %%
# EUR/JPY
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 403452.127566436
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 222544, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 127405, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 285747, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 171298, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 199570, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 403452, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 178521, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 100253, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 30516, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
