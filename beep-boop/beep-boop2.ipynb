# %%
import talib
import numpy as np
import pandas as pd

# %%
file_path = '/Users/mymac/Google_Drive/Forex_Robot/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
# df = pd.read_csv(file_path + 'test1.csv')
# df = pd.read_csv(file_path + 'Oanda_Gbp_Usd_M5.csv')
df = pd.read_csv(file_path + 'Oanda_Gbp_Usd_M5_2-2.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2018-07-22 21:00:00   1.31233   1.31244  1.31173    1.31220   1.31323
# 1 2018-07-22 21:05:00   1.31221   1.31235  1.31178    1.31189   1.31305
# 2 2018-07-22 21:10:00   1.31187   1.31226  1.31147    1.31156   1.31268
# 3 2018-07-22 21:15:00   1.31156   1.31211  1.31146    1.31197   1.31236
# 4 2018-07-22 21:20:00   1.31198   1.31269  1.31165    1.31230   1.31283
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 0   1.31334  1.31246    1.31299   1.31278   1.31289  1.31214    1.31260
# 1   1.31312  1.31267    1.31268   1.31263   1.31273  1.31222    1.31228
# 2   1.31312  1.31232    1.31236   1.31228   1.31268  1.31192    1.31196
# 3   1.31310  1.31232    1.31285   1.31196   1.31259  1.31192    1.31241
# 4   1.31355  1.31263    1.31309   1.31240   1.31308  1.31214    1.31270
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 37198 2019-01-22 07:35:00   1.28582   1.28598  1.28553    1.28592   1.28603
# 37199 2019-01-22 07:40:00   1.28590   1.28644  1.28580    1.28628   1.28611
# 37200 2019-01-22 07:45:00   1.28628   1.28673  1.28619    1.28669   1.28648
# 37201 2019-01-22 07:50:00   1.28670   1.28702  1.28669    1.28681   1.28687
# 37202 2019-01-22 07:55:00   1.28682   1.28699  1.28670    1.28679   1.28701
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 37198   1.28616  1.28572    1.28611   1.28592   1.28606  1.28563    1.28602
# 37199   1.28666  1.28599    1.28647   1.28600   1.28654  1.28590    1.28638
# 37200   1.28694  1.28639    1.28688   1.28638   1.28683  1.28629    1.28678
# 37201   1.28721  1.28686    1.28701   1.28678   1.28711  1.28678    1.28691
# 37202   1.28719  1.28687    1.28696   1.28692   1.28709  1.28678    1.28688

# %%
def add_fractal(df, i, look_back=3):
  if i >= look_back and i < df.shape[0] - look_back:
    lows = []
    highs = []

    for j in range(1, look_back + 1):
      prev_bid_low, prev_bid_high = df.loc[df.index[i - j], ['Mid_Low', 'Mid_High']]
      future_bid_low, future_bid_high = df.loc[df.index[i + j], ['Mid_Low', 'Mid_High']]

      lows.append(float(prev_bid_low))
      lows.append(float(future_bid_low))
      highs.append(float(prev_bid_high))
      highs.append(float(future_bid_high))

    bid_low, bid_high = df.loc[df.index[i], ['Mid_Low', 'Mid_High']]

    if float(bid_low) < min(lows):
      return 1

    elif float(bid_high) > max(highs):
      return 2

    else:
      return 0

  else:
    return np.nan


def add_beep_boop(df, i):
  macdhist, ema50, ema200, bid_low, bid_high = df.loc[df.index[i], ['macdhist', 'ema50', 'ema200', 'Mid_Low', 'Mid_High']]

  if float(macdhist) > 0 and float(bid_low) > float(ema50):
    return 1

  elif float(macdhist) < 0 and float(bid_high) < float(ema50):
    return 2

  else:
    return 0

# %%
df['macd'], df['macdsignal'], df['macdhist'] = talib.MACD(df['Mid_Close'])
df['ema200'] = talib.EMA(df['Mid_Close'], timeperiod=200)
df['ema50'] = talib.EMA(df['Mid_Close'], timeperiod=50)
df['atr'] = talib.ATR(df['Mid_High'], df['Mid_Low'], df['Mid_Close'], timeperiod=500)
df['fractal'] = [add_fractal(df, i) for i in range(df.shape[0])]
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df['beep_boop'] = [add_beep_boop(df, i) for i in range(df.shape[0])]
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

print(df['beep_boop'].value_counts())
print(df['fractal'].value_counts())

# %%
value_per_pip = 1.0
max_pips_to_risk = 0.0100
amounts_per_day = [-4, -5, -6]

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25])
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee


def run_simulation(risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars):
    pullback_cushion /= 10000
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    n_units = 50000
    trade = None

    for i in range(3, df.shape[0]):
        if i < last_x_bars:
            continue

        beep_boop1 = df.loc[df.index[i - 1], 'beep_boop']
        beep_boop2 = df.loc[df.index[i - 2], 'beep_boop']
        beep_boop3 = df.loc[df.index[i - 3], 'beep_boop']
        ema200 = df.loc[df.index[i - 1], 'ema200']
        bid_low1 = df.loc[df.index[i - 1], 'Mid_Low']
        bid_high1 = df.loc[df.index[i - 1], 'Mid_High']
        bid_open1 = df.loc[df.index[i - 1], 'Mid_Open']
        bid_close1 = df.loc[df.index[i - 1], 'Mid_Close']
        atr = df.loc[df.index[i - 1], 'atr']
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        enough_volatility = (spread / atr) <= atr_percentage
        curr_date = df.loc[df.index[i], 'Date']
        curr_al = df.loc[df.index[i - 1], 'Ask_Low']
        curr_bh = df.loc[df.index[i - 1], 'Bid_High']
        previous_ask_lows = []
        previous_bid_highs = []

        for ind in range(i - last_x_bars, i):
            previous_ask_lows.append(df.loc[df.index[ind], 'Ask_Low'])
            previous_bid_highs.append(df.loc[df.index[ind], 'Bid_High'])

        if beep_boop3 == 1 and beep_boop2 == 1 and beep_boop1 == 1 and enough_volatility and trade is None and curr_al <= min(previous_ask_lows):
            pullback = None
            j = i - 4

            while j >= 0:
                if df.loc[df.index[j], 'fractal'] == 1:
                    curr_pullback = float(df.loc[df.index[j], 'Bid_Low'])
                    pullback = curr_pullback
                    break

                j -= 1

            if pullback is not None:
                curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
                df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                               'Ask_Low', 'Ask_Close']]
                open_price = float(curr_ask_open)
                stop_loss = round(pullback - pullback_cushion, 5)
                # stop_loss = round(pullback - pullback_cushion, 3)

                if stop_loss < open_price:
                    curr_pips_to_risk = open_price - stop_loss

                    if curr_pips_to_risk <= max_pips_to_risk:
                        stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 5)
                        # stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 3)

                        trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                 'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                 'n_units': n_units, 'start_date': curr_date}

                        n_buys += 1

                        pips_risked.append(curr_pips_to_risk)

        elif beep_boop3 == 2 and beep_boop2 == 2 and beep_boop1 == 2 and enough_volatility and trade is None and curr_bh >= max(previous_bid_highs):
            pullback = None
            j = i - 4

            while j >= 0:
                if df.loc[df.index[j], 'fractal'] == 2:
                    curr_pullback = float(df.loc[df.index[j], 'Ask_High'])
                    pullback = curr_pullback
                    break

                j -= 1

            if pullback is not None:
                curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
                df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                               'Ask_Low', 'Ask_Close']]
                open_price = float(curr_bid_open)
                stop_loss = round(pullback + pullback_cushion, 5)
                # stop_loss = round(pullback + pullback_cushion, 3)

                if stop_loss > open_price:
                    curr_pips_to_risk = stop_loss - open_price

                    if curr_pips_to_risk <= max_pips_to_risk:
                        stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 5)
                        # stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 3)

                        trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                                 'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                 'n_units': n_units, 'start_date': curr_date}

                        n_sells += 1

                        pips_risked.append(curr_pips_to_risk)

        if trade is not None:
            curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
            df.loc[
                df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High', 'Ask_Low',
                                   'Ask_Close']]

            if trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
                trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
                # trade_amount = (trade['stop_loss'] - trade['open_price']) * 100 * value_per_pip
                reward += trade_amount
                day_fees += calculate_day_fees(trade['start_date'], curr_date)

                n_wins += 1 if trade_amount > 0 else 0
                n_losses += 1 if trade_amount < 0 else 0
                curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
                curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

                if curr_win_streak > win_streak:
                    win_streak = curr_win_streak

                if curr_loss_streak > loss_streak:
                    loss_streak = curr_loss_streak

                trade = None

                continue

            if trade['trade_type'] == 'buy' and curr_bid_high - trade['pips_risked'] > trade['stop_loss']:
                trade['stop_loss'] = curr_bid_high - trade['pips_risked']

            if trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
                trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
                # trade_amount = (trade['stop_gain'] - trade['open_price']) * 100 * value_per_pip
                reward += trade_amount
                day_fees += calculate_day_fees(trade['start_date'], curr_date)

                n_wins += 1 if trade_amount > 0 else 0
                n_losses += 1 if trade_amount < 0 else 0
                curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
                curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

                if curr_win_streak > win_streak:
                    win_streak = curr_win_streak

                if curr_loss_streak > loss_streak:
                    loss_streak = curr_loss_streak

                trade = None

                continue

            if trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
                trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
                # trade_amount = (trade['open_price'] - trade['stop_loss']) * 100 * value_per_pip
                reward += trade_amount
                day_fees += calculate_day_fees(trade['start_date'], curr_date)

                n_wins += 1 if trade_amount > 0 else 0
                n_losses += 1 if trade_amount < 0 else 0
                curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
                curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

                if curr_win_streak > win_streak:
                    win_streak = curr_win_streak

                if curr_loss_streak > loss_streak:
                    loss_streak = curr_loss_streak

                trade = None

                continue

            if trade['trade_type'] == 'sell' and trade['pips_risked'] + curr_ask_low < trade['stop_loss']:
                trade['stop_loss'] = trade['pips_risked'] + curr_ask_low

            if trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
                trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
                # trade_amount = (trade['open_price'] - trade['stop_gain']) * 100 * value_per_pip
                reward += trade_amount
                day_fees += calculate_day_fees(trade['start_date'], curr_date)

                n_wins += 1 if trade_amount > 0 else 0
                n_losses += 1 if trade_amount < 0 else 0
                curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
                curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

                if curr_win_streak > win_streak:
                    win_streak = curr_win_streak

                if curr_loss_streak > loss_streak:
                    loss_streak = curr_loss_streak

                trade = None

                continue

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
# risk_reward_ratio_vals = [1.5, 1.6, 1.7, 1.8, 1.9, 2]
risk_reward_ratio_vals = [1.6]
# pullback_cushion_vals = [0, 5, 10, 15, 20, 25, 30, 35, 40]
pullback_cushion_vals = [15]
# atr_percentages = [0.25, 0.30, 0.35]
atr_percentages = [0.35]
# last_x_bars_vals = [2, 3, 4, 5]
last_x_bars_vals = [4]
n_runs = len(risk_reward_ratio_vals) * len(pullback_cushion_vals) * len(atr_percentages) * len(last_x_bars_vals)
best_risk_reward = None
best_pullback_cushion = None
best_atr_percentage = None
best_last_x_bars_val = None
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio in risk_reward_ratio_vals:
  for pullback_cushion in pullback_cushion_vals:
      for atr_percentage in atr_percentages:
          for last_x_bars in last_x_bars_vals:
            reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak = run_simulation(risk_reward_ratio, pullback_cushion, atr_percentage, last_x_bars)
            runs_finished += 1

            print(risk_reward_ratio)
            print(pullback_cushion)
            print(reward)
            print('Num buys: ' + str(n_sells))
            print('Num sells: ' + str(n_buys))
            print('Num trades: ' + str(n_buys + n_sells))
            print('Num wins: ' + str(n_wins))
            print('Num losses: ' + str(n_losses))
            print('Win streak: ' + str(win_streak))
            print('Loss streak: ' + str(loss_streak))
            print('Remaining runs: ' + str(n_runs - runs_finished))

            if reward > best_reward:
              best_reward = reward
              best_risk_reward = risk_reward_ratio
              best_pullback_cushion = pullback_cushion
              best_atr_percentage = atr_percentage
              best_last_x_bars_val = last_x_bars

            print('Best reward so far: ' + str(best_reward))
            print()

print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best pullback cushion: ' + str(best_pullback_cushion))
print('Best atr percentage: ' + str(best_atr_percentage))
print('Best last x bars: ' + str(best_last_x_bars_val))

# Beep boop with atr 500 and TL:
# Best reward: 11577.300000000156
# Best risk/reward ratio: 1.7
# Best pullback cushion: 15
# Best atr percentage: 0.3

# Newer data
# Best reward: 13531.999999999987
# Best risk/reward ratio: 1.7
# Best pullback cushion: 15
# Best atr percentage: 0.3
# Best last x bars: 2

# Older data
# Best reward: 9802.499999999884
# Best risk/reward ratio: 2
# Best pullback cushion: 15
# Best atr percentage: 0.3
# Best last x bars: 2

    # Newer data with same params:
    # Best reward: 12088.499999999995
    # Best risk/reward ratio: 2
    # Best pullback cushion: 15
    # Best atr percentage: 0.3
    # Best last x bars: 2

# 8379.00000000008
# Out:
# 1.5
# 0
# -575.4999999999259
# Num buys: 48
# Num sells: 48
# Num trades: 96
# Num wins: 32
# Num losses: 64
# Win streak: 3
# Loss streak: 6
# Remaining runs: 647
# Best reward so far: -575.4999999999259
#
# 1.5
# 0
# -480.9999999999054
# Num buys: 42
# Num sells: 36
# Num trades: 78
# Num wins: 22
# Num losses: 56
# Win streak: 3
# Loss streak: 8
# Remaining runs: 646
# Best reward so far: -480.9999999999054
#
# 1.5
# 0
# -653.9999999999034
# Num buys: 35
# Num sells: 29
# Num trades: 64
# Num wins: 20
# Num losses: 44
# Win streak: 3
# Loss streak: 6
# Remaining runs: 645
# Best reward so far: -480.9999999999054
#
# 1.5
# 0
# 407.50000000005076
# Num buys: 22
# Num sells: 22
# Num trades: 44
# Num wins: 16
# Num losses: 28
# Win streak: 4
# Loss streak: 6
# Remaining runs: 644
# Best reward so far: 407.50000000005076
#
# 1.5
# 0
# -4359.4999999999745
# Num buys: 136
# Num sells: 134
# Num trades: 270
# Num wins: 81
# Num losses: 188
# Win streak: 4
# Loss streak: 16
# Remaining runs: 643
# Best reward so far: 407.50000000005076
#
# 1.5
# 0
# -2140.4999999999854
# Num buys: 117
# Num sells: 109
# Num trades: 226
# Num wins: 71
# Num losses: 154
# Win streak: 3
# Loss streak: 15
# Remaining runs: 642
# Best reward so far: 407.50000000005076
#
# 1.5
# 0
# -1421.4999999999263
# Num buys: 86
# Num sells: 91
# Num trades: 177
# Num wins: 56
# Num losses: 120
# Win streak: 4
# Loss streak: 10
# Remaining runs: 641
# Best reward so far: 407.50000000005076
#
# 1.5
# 0
# -661.5000000000205
# Num buys: 65
# Num sells: 77
# Num trades: 142
# Num wins: 48
# Num losses: 93
# Win streak: 4
# Loss streak: 7
# Remaining runs: 640
# Best reward so far: 407.50000000005076
#
# 1.5
# 0
# -5041.999999999768
# Num buys: 229
# Num sells: 230
# Num trades: 459
# Num wins: 143
# Num losses: 315
# Win streak: 5
# Loss streak: 14
# Remaining runs: 639
# Best reward so far: 407.50000000005076
#
# 1.5
# 0
# -5941.999999999562
# Num buys: 215
# Num sells: 217
# Num trades: 432
# Num wins: 138
# Num losses: 293
# Win streak: 4
# Loss streak: 12
# Remaining runs: 638
# Best reward so far: 407.50000000005076
#
# 1.5
# 0
# -4014.999999999714
# Num buys: 192
# Num sells: 179
# Num trades: 371
# Num wins: 121
# Num losses: 249
# Win streak: 4
# Loss streak: 13
# Remaining runs: 637
# Best reward so far: 407.50000000005076
#
# 1.5
# 0
# -2703.499999999827
# Num buys: 147
# Num sells: 153
# Num trades: 300
# Num wins: 100
# Num losses: 199
# Win streak: 4
# Loss streak: 12
# Remaining runs: 636
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# -158.99999999995458
# Num buys: 40
# Num sells: 42
# Num trades: 82
# Num wins: 27
# Num losses: 55
# Win streak: 3
# Loss streak: 12
# Remaining runs: 635
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# -314.4999999999215
# Num buys: 38
# Num sells: 31
# Num trades: 69
# Num wins: 21
# Num losses: 48
# Win streak: 3
# Loss streak: 8
# Remaining runs: 634
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# -135.4999999999293
# Num buys: 33
# Num sells: 29
# Num trades: 62
# Num wins: 20
# Num losses: 42
# Win streak: 3
# Loss streak: 7
# Remaining runs: 633
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# 337.5000000000556
# Num buys: 18
# Num sells: 20
# Num trades: 38
# Num wins: 13
# Num losses: 25
# Win streak: 3
# Loss streak: 6
# Remaining runs: 632
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# -303.9999999999671
# Num buys: 107
# Num sells: 94
# Num trades: 201
# Num wins: 68
# Num losses: 131
# Win streak: 3
# Loss streak: 13
# Remaining runs: 631
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# -1369.4999999998963
# Num buys: 98
# Num sells: 84
# Num trades: 182
# Num wins: 58
# Num losses: 123
# Win streak: 3
# Loss streak: 10
# Remaining runs: 630
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# 281.00000000009595
# Num buys: 75
# Num sells: 79
# Num trades: 154
# Num wins: 54
# Num losses: 99
# Win streak: 4
# Loss streak: 12
# Remaining runs: 629
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# 35.00000000006378
# Num buys: 53
# Num sells: 67
# Num trades: 120
# Num wins: 42
# Num losses: 77
# Win streak: 4
# Loss streak: 9
# Remaining runs: 628
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# -3431.9999999998327
# Num buys: 174
# Num sells: 162
# Num trades: 336
# Num wins: 108
# Num losses: 226
# Win streak: 4
# Loss streak: 13
# Remaining runs: 627
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# -6187.999999999662
# Num buys: 175
# Num sells: 164
# Num trades: 339
# Num wins: 107
# Num losses: 231
# Win streak: 4
# Loss streak: 13
# Remaining runs: 626
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# -2541.99999999978
# Num buys: 160
# Num sells: 140
# Num trades: 300
# Num wins: 105
# Num losses: 194
# Win streak: 6
# Loss streak: 12
# Remaining runs: 625
# Best reward so far: 407.50000000005076
#
# 1.5
# 5
# -3298.4999999998345
# Num buys: 129
# Num sells: 131
# Num trades: 260
# Num wins: 85
# Num losses: 174
# Win streak: 6
# Loss streak: 11
# Remaining runs: 624
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# -516.0000000000045
# Num buys: 37
# Num sells: 38
# Num trades: 75
# Num wins: 22
# Num losses: 53
# Win streak: 2
# Loss streak: 12
# Remaining runs: 623
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# -684.00000000001
# Num buys: 35
# Num sells: 26
# Num trades: 61
# Num wins: 19
# Num losses: 42
# Win streak: 2
# Loss streak: 7
# Remaining runs: 622
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# -316.50000000001023
# Num buys: 30
# Num sells: 22
# Num trades: 52
# Num wins: 18
# Num losses: 34
# Win streak: 2
# Loss streak: 6
# Remaining runs: 621
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# 79.00000000000949
# Num buys: 16
# Num sells: 16
# Num trades: 32
# Num wins: 11
# Num losses: 21
# Win streak: 2
# Loss streak: 6
# Remaining runs: 620
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# -474.4999999999389
# Num buys: 92
# Num sells: 79
# Num trades: 171
# Num wins: 60
# Num losses: 110
# Win streak: 3
# Loss streak: 10
# Remaining runs: 619
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# -1737.4999999998408
# Num buys: 88
# Num sells: 71
# Num trades: 159
# Num wins: 51
# Num losses: 107
# Win streak: 3
# Loss streak: 9
# Remaining runs: 618
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# 178.50000000005252
# Num buys: 68
# Num sells: 60
# Num trades: 128
# Num wins: 49
# Num losses: 78
# Win streak: 3
# Loss streak: 8
# Remaining runs: 617
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# 359.50000000014165
# Num buys: 47
# Num sells: 57
# Num trades: 104
# Num wins: 39
# Num losses: 64
# Win streak: 4
# Loss streak: 6
# Remaining runs: 616
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# -4579.499999999878
# Num buys: 148
# Num sells: 134
# Num trades: 282
# Num wins: 93
# Num losses: 188
# Win streak: 3
# Loss streak: 12
# Remaining runs: 615
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# -2748.4999999997976
# Num buys: 138
# Num sells: 127
# Num trades: 265
# Num wins: 99
# Num losses: 165
# Win streak: 6
# Loss streak: 11
# Remaining runs: 614
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# -2231.9999999998367
# Num buys: 130
# Num sells: 110
# Num trades: 240
# Num wins: 85
# Num losses: 154
# Win streak: 4
# Loss streak: 12
# Remaining runs: 613
# Best reward so far: 407.50000000005076
#
# 1.5
# 10
# -795.999999999878
# Num buys: 108
# Num sells: 104
# Num trades: 212
# Num wins: 77
# Num losses: 134
# Win streak: 6
# Loss streak: 9
# Remaining runs: 612
# Best reward so far: 407.50000000005076
#
# 1.5
# 15
# -107.4999999999661
# Num buys: 35
# Num sells: 32
# Num trades: 67
# Num wins: 22
# Num losses: 45
# Win streak: 2
# Loss streak: 6
# Remaining runs: 611
# Best reward so far: 407.50000000005076
#
# 1.5
# 15
# -286.99999999996794
# Num buys: 31
# Num sells: 22
# Num trades: 53
# Num wins: 19
# Num losses: 34
# Win streak: 4
# Loss streak: 6
# Remaining runs: 610
# Best reward so far: 407.50000000005076
#
# 1.5
# 15
# -746.9999999999925
# Num buys: 28
# Num sells: 20
# Num trades: 48
# Num wins: 17
# Num losses: 31
# Win streak: 3
# Loss streak: 5
# Remaining runs: 609
# Best reward so far: 407.50000000005076
#
# 1.5
# 15
# -820.5000000000109
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 9
# Num losses: 22
# Win streak: 2
# Loss streak: 6
# Remaining runs: 608
# Best reward so far: 407.50000000005076
#
# 1.5
# 15
# 210.999999999956
# Num buys: 76
# Num sells: 74
# Num trades: 150
# Num wins: 57
# Num losses: 93
# Win streak: 5
# Loss streak: 5
# Remaining runs: 607
# Best reward so far: 407.50000000005076
#
# 1.5
# 15
# 3031.5000000000764
# Num buys: 73
# Num sells: 61
# Num trades: 134
# Num wins: 56
# Num losses: 78
# Win streak: 5
# Loss streak: 10
# Remaining runs: 606
# Best reward so far: 3031.5000000000764
#
# 1.5
# 15
# 3255.0000000000346
# Num buys: 57
# Num sells: 56
# Num trades: 113
# Num wins: 48
# Num losses: 65
# Win streak: 4
# Loss streak: 6
# Remaining runs: 605
# Best reward so far: 3255.0000000000346
#
# 1.5
# 15
# 2389.0000000000528
# Num buys: 44
# Num sells: 50
# Num trades: 94
# Num wins: 39
# Num losses: 55
# Win streak: 5
# Loss streak: 7
# Remaining runs: 604
# Best reward so far: 3255.0000000000346
#
# 1.5
# 15
# -254.49999999997897
# Num buys: 111
# Num sells: 112
# Num trades: 223
# Num wins: 80
# Num losses: 142
# Win streak: 6
# Loss streak: 14
# Remaining runs: 603
# Best reward so far: 3255.0000000000346
#
# 1.5
# 15
# 3409.0000000001282
# Num buys: 108
# Num sells: 103
# Num trades: 211
# Num wins: 90
# Num losses: 120
# Win streak: 5
# Loss streak: 9
# Remaining runs: 602
# Best reward so far: 3409.0000000001282
#
# 1.5
# 15
# 3378.500000000121
# Num buys: 102
# Num sells: 93
# Num trades: 195
# Num wins: 83
# Num losses: 111
# Win streak: 5
# Loss streak: 9
# Remaining runs: 601
# Best reward so far: 3409.0000000001282
#
# 1.5
# 15
# 690.0000000000935
# Num buys: 97
# Num sells: 88
# Num trades: 185
# Num wins: 73
# Num losses: 111
# Win streak: 6
# Loss streak: 10
# Remaining runs: 600
# Best reward so far: 3409.0000000001282
#
# 1.5
# 20
# -853.4999999999666
# Num buys: 33
# Num sells: 30
# Num trades: 63
# Num wins: 24
# Num losses: 39
# Win streak: 2
# Loss streak: 5
# Remaining runs: 599
# Best reward so far: 3409.0000000001282
#
# 1.5
# 20
# -1319.4999999999845
# Num buys: 28
# Num sells: 20
# Num trades: 48
# Num wins: 17
# Num losses: 31
# Win streak: 3
# Loss streak: 6
# Remaining runs: 598
# Best reward so far: 3409.0000000001282
#
# 1.5
# 20
# -1555.4999999999718
# Num buys: 23
# Num sells: 17
# Num trades: 40
# Num wins: 13
# Num losses: 27
# Win streak: 3
# Loss streak: 8
# Remaining runs: 597
# Best reward so far: 3409.0000000001282
#
# 1.5
# 20
# -444.99999999998516
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 10
# Num losses: 21
# Win streak: 2
# Loss streak: 6
# Remaining runs: 596
# Best reward so far: 3409.0000000001282
#
# 1.5
# 20
# -1954.9999999999745
# Num buys: 81
# Num sells: 71
# Num trades: 152
# Num wins: 55
# Num losses: 97
# Win streak: 3
# Loss streak: 7
# Remaining runs: 595
# Best reward so far: 3409.0000000001282
#
# 1.5
# 20
# 589.5000000000721
# Num buys: 71
# Num sells: 54
# Num trades: 125
# Num wins: 50
# Num losses: 75
# Win streak: 3
# Loss streak: 6
# Remaining runs: 594
# Best reward so far: 3409.0000000001282
#
# 1.5
# 20
# 3582.5000000000073
# Num buys: 56
# Num sells: 50
# Num trades: 106
# Num wins: 47
# Num losses: 59
# Win streak: 4
# Loss streak: 6
# Remaining runs: 593
# Best reward so far: 3582.5000000000073
#
# 1.5
# 20
# 3708.999999999987
# Num buys: 41
# Num sells: 44
# Num trades: 85
# Num wins: 38
# Num losses: 47
# Win streak: 4
# Loss streak: 8
# Remaining runs: 592
# Best reward so far: 3708.999999999987
#
# 1.5
# 20
# 2490.5000000000973
# Num buys: 100
# Num sells: 97
# Num trades: 197
# Num wins: 75
# Num losses: 121
# Win streak: 3
# Loss streak: 9
# Remaining runs: 591
# Best reward so far: 3708.999999999987
#
# 1.5
# 20
# 4310.000000000186
# Num buys: 96
# Num sells: 89
# Num trades: 185
# Num wins: 77
# Num losses: 107
# Win streak: 4
# Loss streak: 8
# Remaining runs: 590
# Best reward so far: 4310.000000000186
#
# 1.5
# 20
# 2250.5000000000978
# Num buys: 97
# Num sells: 88
# Num trades: 185
# Num wins: 74
# Num losses: 110
# Win streak: 4
# Loss streak: 8
# Remaining runs: 589
# Best reward so far: 4310.000000000186
#
# 1.5
# 20
# 3759.000000000078
# Num buys: 79
# Num sells: 81
# Num trades: 160
# Num wins: 69
# Num losses: 90
# Win streak: 5
# Loss streak: 7
# Remaining runs: 588
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# -1521.9999999999109
# Num buys: 31
# Num sells: 28
# Num trades: 59
# Num wins: 20
# Num losses: 39
# Win streak: 2
# Loss streak: 11
# Remaining runs: 587
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# -1244.499999999998
# Num buys: 26
# Num sells: 18
# Num trades: 44
# Num wins: 16
# Num losses: 28
# Win streak: 4
# Loss streak: 8
# Remaining runs: 586
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# -964.9999999999594
# Num buys: 21
# Num sells: 16
# Num trades: 37
# Num wins: 15
# Num losses: 22
# Win streak: 3
# Loss streak: 7
# Remaining runs: 585
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# -521.9999999999563
# Num buys: 14
# Num sells: 14
# Num trades: 28
# Num wins: 11
# Num losses: 17
# Win streak: 3
# Loss streak: 6
# Remaining runs: 584
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# 905.50000000004
# Num buys: 68
# Num sells: 60
# Num trades: 128
# Num wins: 50
# Num losses: 78
# Win streak: 4
# Loss streak: 8
# Remaining runs: 583
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# -2417.4999999999345
# Num buys: 67
# Num sells: 53
# Num trades: 120
# Num wins: 39
# Num losses: 81
# Win streak: 3
# Loss streak: 10
# Remaining runs: 582
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# 1912.4999999999618
# Num buys: 52
# Num sells: 45
# Num trades: 97
# Num wins: 41
# Num losses: 56
# Win streak: 4
# Loss streak: 6
# Remaining runs: 581
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# 2730.4999999999973
# Num buys: 39
# Num sells: 41
# Num trades: 80
# Num wins: 35
# Num losses: 45
# Win streak: 4
# Loss streak: 8
# Remaining runs: 580
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# 2172.000000000133
# Num buys: 85
# Num sells: 82
# Num trades: 167
# Num wins: 70
# Num losses: 96
# Win streak: 4
# Loss streak: 7
# Remaining runs: 579
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# 3295.5000000001537
# Num buys: 92
# Num sells: 83
# Num trades: 175
# Num wins: 71
# Num losses: 103
# Win streak: 4
# Loss streak: 8
# Remaining runs: 578
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# 2274.5000000000405
# Num buys: 82
# Num sells: 81
# Num trades: 163
# Num wins: 69
# Num losses: 93
# Win streak: 4
# Loss streak: 9
# Remaining runs: 577
# Best reward so far: 4310.000000000186
#
# 1.5
# 25
# 3332.5000000001382
# Num buys: 74
# Num sells: 76
# Num trades: 150
# Num wins: 67
# Num losses: 82
# Win streak: 5
# Loss streak: 8
# Remaining runs: 576
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -403.49999999997425
# Num buys: 30
# Num sells: 25
# Num trades: 55
# Num wins: 20
# Num losses: 35
# Win streak: 4
# Loss streak: 7
# Remaining runs: 575
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -328.49999999996186
# Num buys: 25
# Num sells: 16
# Num trades: 41
# Num wins: 15
# Num losses: 26
# Win streak: 4
# Loss streak: 9
# Remaining runs: 574
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -186.49999999996078
# Num buys: 20
# Num sells: 14
# Num trades: 34
# Num wins: 12
# Num losses: 22
# Win streak: 3
# Loss streak: 7
# Remaining runs: 573
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -169.49999999997698
# Num buys: 13
# Num sells: 12
# Num trades: 25
# Num wins: 9
# Num losses: 16
# Win streak: 3
# Loss streak: 6
# Remaining runs: 572
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -3753.499999999927
# Num buys: 67
# Num sells: 58
# Num trades: 125
# Num wins: 43
# Num losses: 81
# Win streak: 6
# Loss streak: 8
# Remaining runs: 571
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -2732.9999999999227
# Num buys: 62
# Num sells: 49
# Num trades: 111
# Num wins: 37
# Num losses: 73
# Win streak: 3
# Loss streak: 8
# Remaining runs: 570
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# 554.5000000000348
# Num buys: 51
# Num sells: 42
# Num trades: 93
# Num wins: 34
# Num losses: 58
# Win streak: 4
# Loss streak: 9
# Remaining runs: 569
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# 1102.0000000000216
# Num buys: 37
# Num sells: 39
# Num trades: 76
# Num wins: 30
# Num losses: 45
# Win streak: 4
# Loss streak: 12
# Remaining runs: 568
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -8036.499999999937
# Num buys: 96
# Num sells: 83
# Num trades: 179
# Num wins: 58
# Num losses: 120
# Win streak: 3
# Loss streak: 11
# Remaining runs: 567
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -4744.499999999945
# Num buys: 93
# Num sells: 80
# Num trades: 173
# Num wins: 56
# Num losses: 116
# Win streak: 3
# Loss streak: 16
# Remaining runs: 566
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -2464.9999999999727
# Num buys: 77
# Num sells: 76
# Num trades: 153
# Num wins: 52
# Num losses: 100
# Win streak: 3
# Loss streak: 10
# Remaining runs: 565
# Best reward so far: 4310.000000000186
#
# 1.5
# 30
# -983.499999999914
# Num buys: 69
# Num sells: 72
# Num trades: 141
# Num wins: 53
# Num losses: 87
# Win streak: 5
# Loss streak: 13
# Remaining runs: 564
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# 525.0000000000102
# Num buys: 26
# Num sells: 24
# Num trades: 50
# Num wins: 17
# Num losses: 31
# Win streak: 4
# Loss streak: 6
# Remaining runs: 563
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# 1493.0000000000177
# Num buys: 23
# Num sells: 17
# Num trades: 40
# Num wins: 17
# Num losses: 23
# Win streak: 4
# Loss streak: 5
# Remaining runs: 562
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# 311.5000000000158
# Num buys: 20
# Num sells: 13
# Num trades: 33
# Num wins: 13
# Num losses: 20
# Win streak: 4
# Loss streak: 8
# Remaining runs: 561
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# 311.00000000001376
# Num buys: 13
# Num sells: 10
# Num trades: 23
# Num wins: 9
# Num losses: 14
# Win streak: 3
# Loss streak: 7
# Remaining runs: 560
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# -1190.9999999999975
# Num buys: 61
# Num sells: 50
# Num trades: 111
# Num wins: 38
# Num losses: 70
# Win streak: 6
# Loss streak: 9
# Remaining runs: 559
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# -1317.499999999956
# Num buys: 60
# Num sells: 48
# Num trades: 108
# Num wins: 35
# Num losses: 72
# Win streak: 4
# Loss streak: 8
# Remaining runs: 558
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# 629.0000000000779
# Num buys: 48
# Num sells: 39
# Num trades: 87
# Num wins: 33
# Num losses: 53
# Win streak: 5
# Loss streak: 8
# Remaining runs: 557
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# 1146.0000000000282
# Num buys: 30
# Num sells: 38
# Num trades: 68
# Num wins: 29
# Num losses: 38
# Win streak: 4
# Loss streak: 6
# Remaining runs: 556
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# -1882.9999999999568
# Num buys: 83
# Num sells: 67
# Num trades: 150
# Num wins: 54
# Num losses: 95
# Win streak: 3
# Loss streak: 7
# Remaining runs: 555
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# 2181.999999999992
# Num buys: 86
# Num sells: 64
# Num trades: 150
# Num wins: 60
# Num losses: 89
# Win streak: 4
# Loss streak: 6
# Remaining runs: 554
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# 1203.5000000000848
# Num buys: 79
# Num sells: 63
# Num trades: 142
# Num wins: 57
# Num losses: 84
# Win streak: 4
# Loss streak: 7
# Remaining runs: 553
# Best reward so far: 4310.000000000186
#
# 1.5
# 35
# -89.999999999934
# Num buys: 61
# Num sells: 65
# Num trades: 126
# Num wins: 51
# Num losses: 74
# Win streak: 4
# Loss streak: 7
# Remaining runs: 552
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# 358.4999999999816
# Num buys: 22
# Num sells: 21
# Num trades: 43
# Num wins: 14
# Num losses: 29
# Win streak: 2
# Loss streak: 6
# Remaining runs: 551
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# 601.4999999999927
# Num buys: 23
# Num sells: 14
# Num trades: 37
# Num wins: 15
# Num losses: 22
# Win streak: 3
# Loss streak: 6
# Remaining runs: 550
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# -880.000000000002
# Num buys: 20
# Num sells: 13
# Num trades: 33
# Num wins: 10
# Num losses: 23
# Win streak: 2
# Loss streak: 8
# Remaining runs: 549
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# -85.99999999997448
# Num buys: 12
# Num sells: 11
# Num trades: 23
# Num wins: 10
# Num losses: 13
# Win streak: 3
# Loss streak: 3
# Remaining runs: 548
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# -335.50000000002416
# Num buys: 55
# Num sells: 47
# Num trades: 102
# Num wins: 39
# Num losses: 63
# Win streak: 2
# Loss streak: 7
# Remaining runs: 547
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# -3983.9999999999613
# Num buys: 58
# Num sells: 44
# Num trades: 102
# Num wins: 33
# Num losses: 68
# Win streak: 4
# Loss streak: 8
# Remaining runs: 546
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# -86.99999999995975
# Num buys: 44
# Num sells: 39
# Num trades: 83
# Num wins: 33
# Num losses: 49
# Win streak: 5
# Loss streak: 7
# Remaining runs: 545
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# -212.99999999997914
# Num buys: 31
# Num sells: 37
# Num trades: 68
# Num wins: 28
# Num losses: 39
# Win streak: 4
# Loss streak: 6
# Remaining runs: 544
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# -2435.5000000000055
# Num buys: 71
# Num sells: 65
# Num trades: 136
# Num wins: 47
# Num losses: 88
# Win streak: 3
# Loss streak: 8
# Remaining runs: 543
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# 703.4999999999986
# Num buys: 71
# Num sells: 62
# Num trades: 133
# Num wins: 53
# Num losses: 79
# Win streak: 4
# Loss streak: 7
# Remaining runs: 542
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# 328.5000000000458
# Num buys: 69
# Num sells: 59
# Num trades: 128
# Num wins: 49
# Num losses: 78
# Win streak: 4
# Loss streak: 7
# Remaining runs: 541
# Best reward so far: 4310.000000000186
#
# 1.5
# 40
# -124.49999999993133
# Num buys: 55
# Num sells: 58
# Num trades: 113
# Num wins: 43
# Num losses: 69
# Win streak: 3
# Loss streak: 5
# Remaining runs: 540
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -309.49999999993804
# Num buys: 48
# Num sells: 49
# Num trades: 97
# Num wins: 32
# Num losses: 65
# Win streak: 3
# Loss streak: 6
# Remaining runs: 539
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -443.4999999999218
# Num buys: 42
# Num sells: 36
# Num trades: 78
# Num wins: 22
# Num losses: 56
# Win streak: 3
# Loss streak: 8
# Remaining runs: 538
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -688.4999999999129
# Num buys: 35
# Num sells: 29
# Num trades: 64
# Num wins: 20
# Num losses: 44
# Win streak: 3
# Loss streak: 6
# Remaining runs: 537
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# 643.0000000000298
# Num buys: 21
# Num sells: 22
# Num trades: 43
# Num wins: 16
# Num losses: 27
# Win streak: 4
# Loss streak: 6
# Remaining runs: 536
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -4164.99999999998
# Num buys: 134
# Num sells: 131
# Num trades: 265
# Num wins: 80
# Num losses: 184
# Win streak: 3
# Loss streak: 16
# Remaining runs: 535
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -2660.4999999999777
# Num buys: 115
# Num sells: 108
# Num trades: 223
# Num wins: 69
# Num losses: 153
# Win streak: 3
# Loss streak: 15
# Remaining runs: 534
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -1745.4999999999113
# Num buys: 86
# Num sells: 90
# Num trades: 176
# Num wins: 55
# Num losses: 120
# Win streak: 4
# Loss streak: 10
# Remaining runs: 533
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -489.00000000002757
# Num buys: 62
# Num sells: 76
# Num trades: 138
# Num wins: 48
# Num losses: 89
# Win streak: 5
# Loss streak: 7
# Remaining runs: 532
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -4900.9999999998145
# Num buys: 227
# Num sells: 225
# Num trades: 452
# Num wins: 143
# Num losses: 308
# Win streak: 4
# Loss streak: 14
# Remaining runs: 531
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -5877.999999999688
# Num buys: 208
# Num sells: 214
# Num trades: 422
# Num wins: 136
# Num losses: 285
# Win streak: 4
# Loss streak: 12
# Remaining runs: 530
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -3277.4999999997535
# Num buys: 187
# Num sells: 175
# Num trades: 362
# Num wins: 120
# Num losses: 241
# Win streak: 4
# Loss streak: 13
# Remaining runs: 529
# Best reward so far: 4310.000000000186
#
# 1.6
# 0
# -1939.4999999998945
# Num buys: 143
# Num sells: 152
# Num trades: 295
# Num wins: 100
# Num losses: 194
# Win streak: 5
# Loss streak: 12
# Remaining runs: 528
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# 120.00000000003064
# Num buys: 40
# Num sells: 42
# Num trades: 82
# Num wins: 27
# Num losses: 55
# Win streak: 3
# Loss streak: 12
# Remaining runs: 527
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# -154.9999999999418
# Num buys: 38
# Num sells: 31
# Num trades: 69
# Num wins: 21
# Num losses: 48
# Win streak: 3
# Loss streak: 8
# Remaining runs: 526
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# -14.499999999949637
# Num buys: 33
# Num sells: 29
# Num trades: 62
# Num wins: 20
# Num losses: 42
# Win streak: 3
# Loss streak: 7
# Remaining runs: 525
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# 480.0000000000497
# Num buys: 17
# Num sells: 20
# Num trades: 37
# Num wins: 12
# Num losses: 25
# Win streak: 2
# Loss streak: 6
# Remaining runs: 524
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# -419.9999999999391
# Num buys: 109
# Num sells: 96
# Num trades: 205
# Num wins: 68
# Num losses: 135
# Win streak: 3
# Loss streak: 13
# Remaining runs: 523
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# -1570.9999999999498
# Num buys: 94
# Num sells: 79
# Num trades: 173
# Num wins: 55
# Num losses: 117
# Win streak: 4
# Loss streak: 10
# Remaining runs: 522
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# -336.99999999991707
# Num buys: 75
# Num sells: 76
# Num trades: 151
# Num wins: 52
# Num losses: 98
# Win streak: 3
# Loss streak: 12
# Remaining runs: 521
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# 199.50000000009334
# Num buys: 52
# Num sells: 65
# Num trades: 117
# Num wins: 40
# Num losses: 76
# Win streak: 4
# Loss streak: 9
# Remaining runs: 520
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# -2520.9999999997863
# Num buys: 178
# Num sells: 166
# Num trades: 344
# Num wins: 112
# Num losses: 230
# Win streak: 4
# Loss streak: 13
# Remaining runs: 519
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# -4991.999999999661
# Num buys: 172
# Num sells: 159
# Num trades: 331
# Num wins: 108
# Num losses: 222
# Win streak: 7
# Loss streak: 13
# Remaining runs: 518
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# -3404.4999999997544
# Num buys: 161
# Num sells: 138
# Num trades: 299
# Num wins: 102
# Num losses: 196
# Win streak: 6
# Loss streak: 12
# Remaining runs: 517
# Best reward so far: 4310.000000000186
#
# 1.6
# 5
# -3213.4999999998063
# Num buys: 127
# Num sells: 127
# Num trades: 254
# Num wins: 83
# Num losses: 170
# Win streak: 6
# Loss streak: 11
# Remaining runs: 516
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# -1146.4999999999852
# Num buys: 37
# Num sells: 38
# Num trades: 75
# Num wins: 22
# Num losses: 53
# Win streak: 2
# Loss streak: 12
# Remaining runs: 515
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# -1004.49999999999
# Num buys: 35
# Num sells: 26
# Num trades: 61
# Num wins: 19
# Num losses: 42
# Win streak: 2
# Loss streak: 7
# Remaining runs: 514
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# -679.9999999999935
# Num buys: 30
# Num sells: 22
# Num trades: 52
# Num wins: 18
# Num losses: 34
# Win streak: 2
# Loss streak: 6
# Remaining runs: 513
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# 41.500000000018815
# Num buys: 16
# Num sells: 16
# Num trades: 32
# Num wins: 11
# Num losses: 21
# Win streak: 2
# Loss streak: 6
# Remaining runs: 512
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# -1082.4999999999125
# Num buys: 91
# Num sells: 77
# Num trades: 168
# Num wins: 60
# Num losses: 108
# Win streak: 3
# Loss streak: 9
# Remaining runs: 511
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# -1847.999999999845
# Num buys: 89
# Num sells: 67
# Num trades: 156
# Num wins: 51
# Num losses: 105
# Win streak: 3
# Loss streak: 9
# Remaining runs: 510
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# 425.00000000006276
# Num buys: 67
# Num sells: 56
# Num trades: 123
# Num wins: 48
# Num losses: 75
# Win streak: 3
# Loss streak: 8
# Remaining runs: 509
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# 865.5000000001521
# Num buys: 47
# Num sells: 54
# Num trades: 101
# Num wins: 39
# Num losses: 62
# Win streak: 4
# Loss streak: 5
# Remaining runs: 508
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# -3895.9999999998854
# Num buys: 141
# Num sells: 132
# Num trades: 273
# Num wins: 94
# Num losses: 178
# Win streak: 4
# Loss streak: 13
# Remaining runs: 507
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# -1654.9999999998633
# Num buys: 136
# Num sells: 124
# Num trades: 260
# Num wins: 100
# Num losses: 159
# Win streak: 6
# Loss streak: 11
# Remaining runs: 506
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# -2992.4999999998586
# Num buys: 132
# Num sells: 110
# Num trades: 242
# Num wins: 83
# Num losses: 158
# Win streak: 4
# Loss streak: 12
# Remaining runs: 505
# Best reward so far: 4310.000000000186
#
# 1.6
# 10
# -266.4999999998968
# Num buys: 108
# Num sells: 102
# Num trades: 210
# Num wins: 77
# Num losses: 132
# Win streak: 6
# Loss streak: 9
# Remaining runs: 504
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# -234.99999999995816
# Num buys: 33
# Num sells: 32
# Num trades: 65
# Num wins: 21
# Num losses: 44
# Win streak: 2
# Loss streak: 6
# Remaining runs: 503
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# -65.49999999995723
# Num buys: 31
# Num sells: 21
# Num trades: 52
# Num wins: 19
# Num losses: 33
# Win streak: 4
# Loss streak: 6
# Remaining runs: 502
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# -426.99999999997306
# Num buys: 28
# Num sells: 19
# Num trades: 47
# Num wins: 17
# Num losses: 30
# Win streak: 3
# Loss streak: 5
# Remaining runs: 501
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# -674.5000000000066
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 9
# Num losses: 22
# Win streak: 2
# Loss streak: 6
# Remaining runs: 500
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# 315.9999999999043
# Num buys: 80
# Num sells: 75
# Num trades: 155
# Num wins: 59
# Num losses: 96
# Win streak: 5
# Loss streak: 5
# Remaining runs: 499
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# 3039.500000000074
# Num buys: 73
# Num sells: 61
# Num trades: 134
# Num wins: 56
# Num losses: 78
# Win streak: 5
# Loss streak: 10
# Remaining runs: 498
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# 3672.0000000000323
# Num buys: 57
# Num sells: 56
# Num trades: 113
# Num wins: 48
# Num losses: 65
# Win streak: 4
# Loss streak: 6
# Remaining runs: 497
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# 2998.0000000000427
# Num buys: 44
# Num sells: 49
# Num trades: 93
# Num wins: 39
# Num losses: 54
# Win streak: 5
# Loss streak: 7
# Remaining runs: 496
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# -735.4999999999409
# Num buys: 113
# Num sells: 112
# Num trades: 225
# Num wins: 82
# Num losses: 142
# Win streak: 5
# Loss streak: 14
# Remaining runs: 495
# Best reward so far: 4310.000000000186
#
# 1.6
# 15
# 4314.5000000001155
# Num buys: 106
# Num sells: 102
# Num trades: 208
# Num wins: 88
# Num losses: 119
# Win streak: 5
# Loss streak: 9
# Remaining runs: 494
# Best reward so far: 4314.5000000001155
#
# 1.6
# 15
# 4904.50000000016
# Num buys: 100
# Num sells: 92
# Num trades: 192
# Num wins: 83
# Num losses: 108
# Win streak: 5
# Loss streak: 9
# Remaining runs: 493
# Best reward so far: 4904.50000000016
#
# 1.6
# 15
# 1496.5000000001
# Num buys: 96
# Num sells: 85
# Num trades: 181
# Num wins: 72
# Num losses: 108
# Win streak: 5
# Loss streak: 9
# Remaining runs: 492
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# -1032.9999999999764
# Num buys: 33
# Num sells: 29
# Num trades: 62
# Num wins: 23
# Num losses: 39
# Win streak: 2
# Loss streak: 6
# Remaining runs: 491
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# -1382.0000000000018
# Num buys: 28
# Num sells: 19
# Num trades: 47
# Num wins: 16
# Num losses: 31
# Win streak: 3
# Loss streak: 6
# Remaining runs: 490
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# -1368.999999999984
# Num buys: 23
# Num sells: 17
# Num trades: 40
# Num wins: 13
# Num losses: 27
# Win streak: 3
# Loss streak: 8
# Remaining runs: 489
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# -558.999999999992
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 10
# Num losses: 21
# Win streak: 2
# Loss streak: 6
# Remaining runs: 488
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# 768.0000000000359
# Num buys: 73
# Num sells: 63
# Num trades: 136
# Num wins: 51
# Num losses: 85
# Win streak: 3
# Loss streak: 7
# Remaining runs: 487
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# 599.5000000000651
# Num buys: 72
# Num sells: 54
# Num trades: 126
# Num wins: 49
# Num losses: 77
# Win streak: 3
# Loss streak: 6
# Remaining runs: 486
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# 3485.9999999999745
# Num buys: 55
# Num sells: 49
# Num trades: 104
# Num wins: 46
# Num losses: 58
# Win streak: 4
# Loss streak: 6
# Remaining runs: 485
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# 3367.4999999999895
# Num buys: 42
# Num sells: 43
# Num trades: 85
# Num wins: 38
# Num losses: 47
# Win streak: 4
# Loss streak: 8
# Remaining runs: 484
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# 2205.0000000001196
# Num buys: 99
# Num sells: 93
# Num trades: 192
# Num wins: 72
# Num losses: 119
# Win streak: 4
# Loss streak: 9
# Remaining runs: 483
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# 3856.000000000163
# Num buys: 100
# Num sells: 88
# Num trades: 188
# Num wins: 77
# Num losses: 110
# Win streak: 4
# Loss streak: 9
# Remaining runs: 482
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# 2383.000000000085
# Num buys: 96
# Num sells: 85
# Num trades: 181
# Num wins: 74
# Num losses: 106
# Win streak: 4
# Loss streak: 7
# Remaining runs: 481
# Best reward so far: 4904.50000000016
#
# 1.6
# 20
# 4057.0000000001
# Num buys: 82
# Num sells: 78
# Num trades: 160
# Num wins: 70
# Num losses: 89
# Win streak: 6
# Loss streak: 6
# Remaining runs: 480
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# -1594.9999999999295
# Num buys: 31
# Num sells: 28
# Num trades: 59
# Num wins: 20
# Num losses: 39
# Win streak: 2
# Loss streak: 11
# Remaining runs: 479
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# -992.4999999999899
# Num buys: 26
# Num sells: 18
# Num trades: 44
# Num wins: 16
# Num losses: 28
# Win streak: 4
# Loss streak: 8
# Remaining runs: 478
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# -947.9999999999553
# Num buys: 21
# Num sells: 16
# Num trades: 37
# Num wins: 14
# Num losses: 23
# Win streak: 3
# Loss streak: 7
# Remaining runs: 477
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# -355.4999999999477
# Num buys: 14
# Num sells: 14
# Num trades: 28
# Num wins: 11
# Num losses: 17
# Win streak: 3
# Loss streak: 6
# Remaining runs: 476
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# 660.0000000000086
# Num buys: 67
# Num sells: 59
# Num trades: 126
# Num wins: 47
# Num losses: 79
# Win streak: 4
# Loss streak: 8
# Remaining runs: 475
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# -1731.499999999977
# Num buys: 65
# Num sells: 52
# Num trades: 117
# Num wins: 37
# Num losses: 80
# Win streak: 3
# Loss streak: 10
# Remaining runs: 474
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# 1787.4999999999409
# Num buys: 51
# Num sells: 44
# Num trades: 95
# Num wins: 39
# Num losses: 56
# Win streak: 4
# Loss streak: 6
# Remaining runs: 473
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# 2378.4999999999955
# Num buys: 38
# Num sells: 40
# Num trades: 78
# Num wins: 34
# Num losses: 44
# Win streak: 4
# Loss streak: 8
# Remaining runs: 472
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# 1621.5000000000991
# Num buys: 90
# Num sells: 85
# Num trades: 175
# Num wins: 69
# Num losses: 105
# Win streak: 4
# Loss streak: 8
# Remaining runs: 471
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# 3087.000000000082
# Num buys: 88
# Num sells: 81
# Num trades: 169
# Num wins: 64
# Num losses: 104
# Win streak: 4
# Loss streak: 8
# Remaining runs: 470
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# 1997.5000000000864
# Num buys: 77
# Num sells: 79
# Num trades: 156
# Num wins: 64
# Num losses: 91
# Win streak: 4
# Loss streak: 9
# Remaining runs: 469
# Best reward so far: 4904.50000000016
#
# 1.6
# 25
# 3193.5000000001055
# Num buys: 71
# Num sells: 75
# Num trades: 146
# Num wins: 65
# Num losses: 80
# Win streak: 5
# Loss streak: 8
# Remaining runs: 468
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# -63.999999999955264
# Num buys: 29
# Num sells: 25
# Num trades: 54
# Num wins: 20
# Num losses: 34
# Win streak: 4
# Loss streak: 7
# Remaining runs: 467
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# -5.99999999994418
# Num buys: 25
# Num sells: 16
# Num trades: 41
# Num wins: 15
# Num losses: 26
# Win streak: 4
# Loss streak: 9
# Remaining runs: 466
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# 98.00000000004161
# Num buys: 20
# Num sells: 14
# Num trades: 34
# Num wins: 12
# Num losses: 22
# Win streak: 3
# Loss streak: 7
# Remaining runs: 465
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# 94.00000000003303
# Num buys: 13
# Num sells: 11
# Num trades: 24
# Num wins: 9
# Num losses: 15
# Win streak: 3
# Loss streak: 5
# Remaining runs: 464
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# -3382.9999999999027
# Num buys: 65
# Num sells: 58
# Num trades: 123
# Num wins: 43
# Num losses: 79
# Win streak: 6
# Loss streak: 8
# Remaining runs: 463
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# -2217.9999999998877
# Num buys: 62
# Num sells: 49
# Num trades: 111
# Num wins: 37
# Num losses: 73
# Win streak: 3
# Loss streak: 8
# Remaining runs: 462
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# 1049.0000000000853
# Num buys: 52
# Num sells: 42
# Num trades: 94
# Num wins: 36
# Num losses: 57
# Win streak: 4
# Loss streak: 9
# Remaining runs: 461
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# 577.0000000000438
# Num buys: 36
# Num sells: 37
# Num trades: 73
# Num wins: 29
# Num losses: 43
# Win streak: 4
# Loss streak: 11
# Remaining runs: 460
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# -6083.999999999965
# Num buys: 88
# Num sells: 80
# Num trades: 168
# Num wins: 52
# Num losses: 115
# Win streak: 3
# Loss streak: 11
# Remaining runs: 459
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# -4722.499999999898
# Num buys: 92
# Num sells: 76
# Num trades: 168
# Num wins: 55
# Num losses: 112
# Win streak: 4
# Loss streak: 16
# Remaining runs: 458
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# -3146.999999999943
# Num buys: 79
# Num sells: 76
# Num trades: 155
# Num wins: 54
# Num losses: 100
# Win streak: 4
# Loss streak: 10
# Remaining runs: 457
# Best reward so far: 4904.50000000016
#
# 1.6
# 30
# -1449.4999999998927
# Num buys: 67
# Num sells: 70
# Num trades: 137
# Num wins: 53
# Num losses: 83
# Win streak: 5
# Loss streak: 13
# Remaining runs: 456
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# 453.50000000002535
# Num buys: 26
# Num sells: 24
# Num trades: 50
# Num wins: 17
# Num losses: 31
# Win streak: 4
# Loss streak: 6
# Remaining runs: 455
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# 1688.5
# Num buys: 22
# Num sells: 17
# Num trades: 39
# Num wins: 17
# Num losses: 22
# Win streak: 4
# Loss streak: 5
# Remaining runs: 454
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# 476.99999999999534
# Num buys: 20
# Num sells: 13
# Num trades: 33
# Num wins: 13
# Num losses: 20
# Win streak: 4
# Loss streak: 8
# Remaining runs: 453
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# 528.0000000000178
# Num buys: 13
# Num sells: 10
# Num trades: 23
# Num wins: 9
# Num losses: 14
# Win streak: 3
# Loss streak: 7
# Remaining runs: 452
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# -2038.9999999999864
# Num buys: 61
# Num sells: 49
# Num trades: 110
# Num wins: 38
# Num losses: 70
# Win streak: 6
# Loss streak: 9
# Remaining runs: 451
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# -992.9999999999577
# Num buys: 57
# Num sells: 46
# Num trades: 103
# Num wins: 36
# Num losses: 66
# Win streak: 4
# Loss streak: 7
# Remaining runs: 450
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# 2.5000000000836167
# Num buys: 47
# Num sells: 38
# Num trades: 85
# Num wins: 33
# Num losses: 51
# Win streak: 5
# Loss streak: 8
# Remaining runs: 449
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# 857.0000000000666
# Num buys: 30
# Num sells: 38
# Num trades: 68
# Num wins: 29
# Num losses: 38
# Win streak: 4
# Loss streak: 6
# Remaining runs: 448
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# -291.9999999999831
# Num buys: 82
# Num sells: 66
# Num trades: 148
# Num wins: 55
# Num losses: 92
# Win streak: 7
# Loss streak: 7
# Remaining runs: 447
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# 2781.4999999999586
# Num buys: 82
# Num sells: 63
# Num trades: 145
# Num wins: 60
# Num losses: 84
# Win streak: 7
# Loss streak: 6
# Remaining runs: 446
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# 397.00000000007435
# Num buys: 77
# Num sells: 62
# Num trades: 139
# Num wins: 55
# Num losses: 83
# Win streak: 5
# Loss streak: 9
# Remaining runs: 445
# Best reward so far: 4904.50000000016
#
# 1.6
# 35
# -217.49999999992218
# Num buys: 60
# Num sells: 65
# Num trades: 125
# Num wins: 50
# Num losses: 74
# Win streak: 4
# Loss streak: 7
# Remaining runs: 444
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# 884.4999999999895
# Num buys: 22
# Num sells: 20
# Num trades: 42
# Num wins: 14
# Num losses: 28
# Win streak: 2
# Loss streak: 6
# Remaining runs: 443
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# 302.99999999999795
# Num buys: 23
# Num sells: 15
# Num trades: 38
# Num wins: 15
# Num losses: 23
# Win streak: 3
# Loss streak: 6
# Remaining runs: 442
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# -617.0000000000083
# Num buys: 20
# Num sells: 13
# Num trades: 33
# Num wins: 10
# Num losses: 23
# Win streak: 2
# Loss streak: 8
# Remaining runs: 441
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# -74.99999999999085
# Num buys: 12
# Num sells: 11
# Num trades: 23
# Num wins: 9
# Num losses: 14
# Win streak: 3
# Loss streak: 3
# Remaining runs: 440
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# -395.5000000000038
# Num buys: 57
# Num sells: 47
# Num trades: 104
# Num wins: 39
# Num losses: 65
# Win streak: 3
# Loss streak: 6
# Remaining runs: 439
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# -3327.499999999964
# Num buys: 57
# Num sells: 44
# Num trades: 101
# Num wins: 33
# Num losses: 67
# Win streak: 4
# Loss streak: 8
# Remaining runs: 438
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# 566.0000000000309
# Num buys: 43
# Num sells: 39
# Num trades: 82
# Num wins: 33
# Num losses: 48
# Win streak: 5
# Loss streak: 7
# Remaining runs: 437
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# -219.99999999999255
# Num buys: 31
# Num sells: 37
# Num trades: 68
# Num wins: 27
# Num losses: 40
# Win streak: 4
# Loss streak: 6
# Remaining runs: 436
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# -1575.4999999999586
# Num buys: 74
# Num sells: 64
# Num trades: 138
# Num wins: 50
# Num losses: 87
# Win streak: 3
# Loss streak: 8
# Remaining runs: 435
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# 1373.500000000046
# Num buys: 69
# Num sells: 61
# Num trades: 130
# Num wins: 53
# Num losses: 76
# Win streak: 4
# Loss streak: 7
# Remaining runs: 434
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# -204.49999999994924
# Num buys: 62
# Num sells: 59
# Num trades: 121
# Num wins: 48
# Num losses: 72
# Win streak: 5
# Loss streak: 7
# Remaining runs: 433
# Best reward so far: 4904.50000000016
#
# 1.6
# 40
# -2655.499999999909
# Num buys: 54
# Num sells: 56
# Num trades: 110
# Num wins: 41
# Num losses: 68
# Win streak: 4
# Loss streak: 5
# Remaining runs: 432
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -268.9999999998852
# Num buys: 46
# Num sells: 47
# Num trades: 93
# Num wins: 31
# Num losses: 62
# Win streak: 3
# Loss streak: 6
# Remaining runs: 431
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -313.999999999891
# Num buys: 42
# Num sells: 36
# Num trades: 78
# Num wins: 22
# Num losses: 56
# Win streak: 3
# Loss streak: 8
# Remaining runs: 430
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -465.9999999999118
# Num buys: 35
# Num sells: 29
# Num trades: 64
# Num wins: 20
# Num losses: 44
# Win streak: 3
# Loss streak: 6
# Remaining runs: 429
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# 709.5000000000418
# Num buys: 21
# Num sells: 22
# Num trades: 43
# Num wins: 16
# Num losses: 27
# Win streak: 4
# Loss streak: 6
# Remaining runs: 428
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -4455.499999999998
# Num buys: 128
# Num sells: 129
# Num trades: 257
# Num wins: 77
# Num losses: 179
# Win streak: 3
# Loss streak: 16
# Remaining runs: 427
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -2480.4999999999823
# Num buys: 110
# Num sells: 104
# Num trades: 214
# Num wins: 67
# Num losses: 146
# Win streak: 3
# Loss streak: 15
# Remaining runs: 426
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -2325.4999999999413
# Num buys: 86
# Num sells: 87
# Num trades: 173
# Num wins: 52
# Num losses: 120
# Win streak: 4
# Loss streak: 10
# Remaining runs: 425
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -213.00000000002728
# Num buys: 61
# Num sells: 72
# Num trades: 133
# Num wins: 47
# Num losses: 85
# Win streak: 5
# Loss streak: 7
# Remaining runs: 424
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -4512.999999999696
# Num buys: 221
# Num sells: 213
# Num trades: 434
# Num wins: 135
# Num losses: 298
# Win streak: 4
# Loss streak: 13
# Remaining runs: 423
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -5231.999999999643
# Num buys: 203
# Num sells: 205
# Num trades: 408
# Num wins: 134
# Num losses: 273
# Win streak: 4
# Loss streak: 12
# Remaining runs: 422
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -4388.499999999745
# Num buys: 187
# Num sells: 171
# Num trades: 358
# Num wins: 118
# Num losses: 239
# Win streak: 4
# Loss streak: 13
# Remaining runs: 421
# Best reward so far: 4904.50000000016
#
# 1.7
# 0
# -1629.4999999998804
# Num buys: 141
# Num sells: 146
# Num trades: 287
# Num wins: 99
# Num losses: 187
# Win streak: 5
# Loss streak: 12
# Remaining runs: 420
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# 171.50000000002615
# Num buys: 41
# Num sells: 42
# Num trades: 83
# Num wins: 27
# Num losses: 56
# Win streak: 3
# Loss streak: 12
# Remaining runs: 419
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# 140.00000000003837
# Num buys: 38
# Num sells: 30
# Num trades: 68
# Num wins: 21
# Num losses: 47
# Win streak: 3
# Loss streak: 8
# Remaining runs: 418
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# 257.0000000000397
# Num buys: 32
# Num sells: 29
# Num trades: 61
# Num wins: 20
# Num losses: 41
# Win streak: 3
# Loss streak: 7
# Remaining runs: 417
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# 465.5000000000433
# Num buys: 17
# Num sells: 20
# Num trades: 37
# Num wins: 12
# Num losses: 25
# Win streak: 2
# Loss streak: 6
# Remaining runs: 416
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# -1105.999999999986
# Num buys: 108
# Num sells: 93
# Num trades: 201
# Num wins: 66
# Num losses: 134
# Win streak: 3
# Loss streak: 13
# Remaining runs: 415
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# -2255.499999999968
# Num buys: 94
# Num sells: 75
# Num trades: 169
# Num wins: 53
# Num losses: 116
# Win streak: 4
# Loss streak: 10
# Remaining runs: 414
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# -279.9999999999857
# Num buys: 75
# Num sells: 71
# Num trades: 146
# Num wins: 52
# Num losses: 94
# Win streak: 4
# Loss streak: 12
# Remaining runs: 413
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# 678.0000000000842
# Num buys: 52
# Num sells: 64
# Num trades: 116
# Num wins: 40
# Num losses: 76
# Win streak: 4
# Loss streak: 9
# Remaining runs: 412
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# -3539.4999999997463
# Num buys: 175
# Num sells: 166
# Num trades: 341
# Num wins: 111
# Num losses: 229
# Win streak: 5
# Loss streak: 13
# Remaining runs: 411
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# -5768.999999999665
# Num buys: 172
# Num sells: 160
# Num trades: 332
# Num wins: 108
# Num losses: 223
# Win streak: 7
# Loss streak: 13
# Remaining runs: 410
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# -2921.499999999824
# Num buys: 160
# Num sells: 136
# Num trades: 296
# Num wins: 102
# Num losses: 193
# Win streak: 6
# Loss streak: 12
# Remaining runs: 409
# Best reward so far: 4904.50000000016
#
# 1.7
# 5
# -2762.4999999998236
# Num buys: 125
# Num sells: 127
# Num trades: 252
# Num wins: 83
# Num losses: 168
# Win streak: 6
# Loss streak: 11
# Remaining runs: 408
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# -849.4999999999816
# Num buys: 35
# Num sells: 37
# Num trades: 72
# Num wins: 21
# Num losses: 51
# Win streak: 2
# Loss streak: 12
# Remaining runs: 407
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# -739.0000000000068
# Num buys: 35
# Num sells: 26
# Num trades: 61
# Num wins: 19
# Num losses: 42
# Win streak: 2
# Loss streak: 7
# Remaining runs: 406
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# -460.99999999999955
# Num buys: 30
# Num sells: 22
# Num trades: 52
# Num wins: 18
# Num losses: 34
# Win streak: 2
# Loss streak: 6
# Remaining runs: 405
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# 191.00000000001245
# Num buys: 16
# Num sells: 16
# Num trades: 32
# Num wins: 11
# Num losses: 21
# Win streak: 2
# Loss streak: 6
# Remaining runs: 404
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# -811.4999999999312
# Num buys: 87
# Num sells: 77
# Num trades: 164
# Num wins: 58
# Num losses: 106
# Win streak: 3
# Loss streak: 9
# Remaining runs: 403
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# -1770.4999999998527
# Num buys: 87
# Num sells: 68
# Num trades: 155
# Num wins: 51
# Num losses: 104
# Win streak: 3
# Loss streak: 9
# Remaining runs: 402
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# 639.000000000034
# Num buys: 66
# Num sells: 57
# Num trades: 123
# Num wins: 49
# Num losses: 74
# Win streak: 3
# Loss streak: 8
# Remaining runs: 401
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# 949.5000000001228
# Num buys: 47
# Num sells: 54
# Num trades: 101
# Num wins: 39
# Num losses: 62
# Win streak: 4
# Loss streak: 5
# Remaining runs: 400
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# -6208.999999999908
# Num buys: 146
# Num sells: 133
# Num trades: 279
# Num wins: 92
# Num losses: 186
# Win streak: 5
# Loss streak: 13
# Remaining runs: 399
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# -1139.4999999998518
# Num buys: 134
# Num sells: 121
# Num trades: 255
# Num wins: 99
# Num losses: 155
# Win streak: 6
# Loss streak: 11
# Remaining runs: 398
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# -1683.4999999998258
# Num buys: 130
# Num sells: 105
# Num trades: 235
# Num wins: 82
# Num losses: 152
# Win streak: 5
# Loss streak: 12
# Remaining runs: 397
# Best reward so far: 4904.50000000016
#
# 1.7
# 10
# -303.9999999998442
# Num buys: 108
# Num sells: 98
# Num trades: 206
# Num wins: 76
# Num losses: 129
# Win streak: 6
# Loss streak: 9
# Remaining runs: 396
# Best reward so far: 4904.50000000016
#
# 1.7
# 15
# -120.49999999994974
# Num buys: 33
# Num sells: 32
# Num trades: 65
# Num wins: 20
# Num losses: 45
# Win streak: 2
# Loss streak: 6
# Remaining runs: 395
# Best reward so far: 4904.50000000016
#
# 1.7
# 15
# -96.99999999994255
# Num buys: 31
# Num sells: 21
# Num trades: 52
# Num wins: 18
# Num losses: 34
# Win streak: 3
# Loss streak: 6
# Remaining runs: 394
# Best reward so far: 4904.50000000016
#
# 1.7
# 15
# -195.4999999999643
# Num buys: 28
# Num sells: 19
# Num trades: 47
# Num wins: 17
# Num losses: 30
# Win streak: 3
# Loss streak: 5
# Remaining runs: 393
# Best reward so far: 4904.50000000016
#
# 1.7
# 15
# -528.5000000000025
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 9
# Num losses: 22
# Win streak: 2
# Loss streak: 6
# Remaining runs: 392
# Best reward so far: 4904.50000000016
#
# 1.7
# 15
# 720.9999999999852
# Num buys: 77
# Num sells: 74
# Num trades: 151
# Num wins: 56
# Num losses: 95
# Win streak: 5
# Loss streak: 5
# Remaining runs: 391
# Best reward so far: 4904.50000000016
#
# 1.7
# 15
# 2493.50000000011
# Num buys: 76
# Num sells: 63
# Num trades: 139
# Num wins: 57
# Num losses: 82
# Win streak: 5
# Loss streak: 10
# Remaining runs: 390
# Best reward so far: 4904.50000000016
#
# 1.7
# 15
# 3956.5000000000473
# Num buys: 56
# Num sells: 56
# Num trades: 112
# Num wins: 48
# Num losses: 64
# Win streak: 4
# Loss streak: 6
# Remaining runs: 389
# Best reward so far: 4904.50000000016
#
# 1.7
# 15
# 3204.500000000049
# Num buys: 45
# Num sells: 49
# ...
# Num wins: 106
# Num losses: 234
# Win streak: 5
# Loss streak: 12
# Remaining runs: 87
# Best reward so far: 4904.50000000016
#
# 2
# 5
# -5291.99999999971
# Num buys: 168
# Num sells: 155
# Num trades: 323
# Num wins: 108
# Num losses: 214
# Win streak: 8
# Loss streak: 12
# Remaining runs: 86
# Best reward so far: 4904.50000000016
#
# 2
# 5
# -3102.499999999813
# Num buys: 161
# Num sells: 131
# Num trades: 292
# Num wins: 98
# Num losses: 193
# Win streak: 5
# Loss streak: 12
# Remaining runs: 85
# Best reward so far: 4904.50000000016
#
# 2
# 5
# -2120.4999999998336
# Num buys: 127
# Num sells: 124
# Num trades: 251
# Num wins: 81
# Num losses: 169
# Win streak: 5
# Loss streak: 11
# Remaining runs: 84
# Best reward so far: 4904.50000000016
#
# 2
# 10
# -397.50000000000944
# Num buys: 35
# Num sells: 36
# Num trades: 71
# Num wins: 20
# Num losses: 51
# Win streak: 2
# Loss streak: 12
# Remaining runs: 83
# Best reward so far: 4904.50000000016
#
# 2
# 10
# 289.0000000000067
# Num buys: 33
# Num sells: 25
# Num trades: 58
# Num wins: 19
# Num losses: 39
# Win streak: 2
# Loss streak: 7
# Remaining runs: 82
# Best reward so far: 4904.50000000016
#
# 2
# 10
# 303.00000000001205
# Num buys: 29
# Num sells: 21
# Num trades: 50
# Num wins: 18
# Num losses: 32
# Win streak: 2
# Loss streak: 6
# Remaining runs: 81
# Best reward so far: 4904.50000000016
#
# 2
# 10
# 5.500000000023135
# Num buys: 16
# Num sells: 16
# Num trades: 32
# Num wins: 11
# Num losses: 21
# Win streak: 2
# Loss streak: 6
# Remaining runs: 80
# Best reward so far: 4904.50000000016
#
# 2
# 10
# -944.9999999998518
# Num buys: 90
# Num sells: 77
# Num trades: 167
# Num wins: 57
# Num losses: 110
# Win streak: 3
# Loss streak: 8
# Remaining runs: 79
# Best reward so far: 4904.50000000016
#
# 2
# 10
# -2226.4999999998263
# Num buys: 88
# Num sells: 66
# Num trades: 154
# Num wins: 51
# Num losses: 103
# Win streak: 3
# Loss streak: 8
# Remaining runs: 78
# Best reward so far: 4904.50000000016
#
# 2
# 10
# 469.0000000000732
# Num buys: 66
# Num sells: 57
# Num trades: 123
# Num wins: 47
# Num losses: 76
# Win streak: 3
# Loss streak: 9
# Remaining runs: 77
# Best reward so far: 4904.50000000016
#
# 2
# 10
# 2102.5000000001733
# Num buys: 46
# Num sells: 51
# Num trades: 97
# Num wins: 40
# Num losses: 57
# Win streak: 5
# Loss streak: 5
# Remaining runs: 76
# Best reward so far: 4904.50000000016
#
# 2
# 10
# -5139.99999999983
# Num buys: 141
# Num sells: 127
# Num trades: 268
# Num wins: 91
# Num losses: 176
# Win streak: 6
# Loss streak: 12
# Remaining runs: 75
# Best reward so far: 4904.50000000016
#
# 2
# 10
# -1270.4999999997706
# Num buys: 132
# Num sells: 119
# Num trades: 251
# Num wins: 97
# Num losses: 153
# Win streak: 6
# Loss streak: 10
# Remaining runs: 74
# Best reward so far: 4904.50000000016
#
# 2
# 10
# -1198.499999999834
# Num buys: 129
# Num sells: 105
# Num trades: 234
# Num wins: 81
# Num losses: 152
# Win streak: 5
# Loss streak: 12
# Remaining runs: 73
# Best reward so far: 4904.50000000016
#
# 2
# 10
# 1853.000000000201
# Num buys: 106
# Num sells: 94
# Num trades: 200
# Num wins: 77
# Num losses: 122
# Win streak: 5
# Loss streak: 9
# Remaining runs: 72
# Best reward so far: 4904.50000000016
#
# 2
# 15
# -28.499999999932612
# Num buys: 33
# Num sells: 31
# Num trades: 64
# Num wins: 20
# Num losses: 44
# Win streak: 2
# Loss streak: 6
# Remaining runs: 71
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 238.00000000003922
# Num buys: 30
# Num sells: 21
# Num trades: 51
# Num wins: 17
# Num losses: 34
# Win streak: 3
# Loss streak: 6
# Remaining runs: 70
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 103.0000000000162
# Num buys: 28
# Num sells: 19
# Num trades: 47
# Num wins: 16
# Num losses: 31
# Win streak: 2
# Loss streak: 5
# Remaining runs: 69
# Best reward so far: 4904.50000000016
#
# 2
# 15
# -537.5000000000019
# Num buys: 16
# Num sells: 14
# Num trades: 30
# Num wins: 9
# Num losses: 21
# Win streak: 2
# Loss streak: 5
# Remaining runs: 68
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 264.50000000003627
# Num buys: 75
# Num sells: 72
# Num trades: 147
# Num wins: 55
# Num losses: 91
# Win streak: 4
# Loss streak: 5
# Remaining runs: 67
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 2446.000000000089
# Num buys: 75
# Num sells: 58
# Num trades: 133
# Num wins: 54
# Num losses: 78
# Win streak: 4
# Loss streak: 10
# Remaining runs: 66
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 3429.0000000000405
# Num buys: 59
# Num sells: 53
# Num trades: 112
# Num wins: 46
# Num losses: 65
# Win streak: 3
# Loss streak: 6
# Remaining runs: 65
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 2207.5000000000846
# Num buys: 45
# Num sells: 47
# Num trades: 92
# Num wins: 38
# Num losses: 53
# Win streak: 5
# Loss streak: 7
# Remaining runs: 64
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 2468.5000000000655
# Num buys: 104
# Num sells: 102
# Num trades: 206
# Num wins: 80
# Num losses: 125
# Win streak: 5
# Loss streak: 15
# Remaining runs: 63
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 3156.00000000015
# Num buys: 104
# Num sells: 100
# Num trades: 204
# Num wins: 86
# Num losses: 117
# Win streak: 5
# Loss streak: 9
# Remaining runs: 62
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 3277.500000000135
# Num buys: 101
# Num sells: 92
# Num trades: 193
# Num wins: 83
# Num losses: 109
# Win streak: 5
# Loss streak: 8
# Remaining runs: 61
# Best reward so far: 4904.50000000016
#
# 2
# 15
# 2418.500000000104
# Num buys: 93
# Num sells: 81
# Num trades: 174
# Num wins: 73
# Num losses: 100
# Win streak: 5
# Loss streak: 8
# Remaining runs: 60
# Best reward so far: 4904.50000000016
#
# 2
# 20
# -781.4999999999402
# Num buys: 34
# Num sells: 28
# Num trades: 62
# Num wins: 24
# Num losses: 38
# Win streak: 2
# Loss streak: 5
# Remaining runs: 59
# Best reward so far: 4904.50000000016
#
# 2
# 20
# -1627.4999999999964
# Num buys: 28
# Num sells: 19
# Num trades: 47
# Num wins: 15
# Num losses: 32
# Win streak: 2
# Loss streak: 6
# Remaining runs: 58
# Best reward so far: 4904.50000000016
#
# 2
# 20
# -710.4999999999691
# Num buys: 23
# Num sells: 16
# Num trades: 39
# Num wins: 12
# Num losses: 27
# Win streak: 2
# Loss streak: 7
# Remaining runs: 57
# Best reward so far: 4904.50000000016
#
# 2
# 20
# -361.99999999999164
# Num buys: 16
# Num sells: 14
# Num trades: 30
# Num wins: 10
# Num losses: 20
# Win streak: 2
# Loss streak: 5
# Remaining runs: 56
# Best reward so far: 4904.50000000016
#
# 2
# 20
# 835.0000000000712
# Num buys: 70
# Num sells: 61
# Num trades: 131
# Num wins: 52
# Num losses: 78
# Win streak: 4
# Loss streak: 6
# Remaining runs: 55
# Best reward so far: 4904.50000000016
#
# 2
# 20
# 228.00000000003297
# Num buys: 67
# Num sells: 53
# Num trades: 120
# Num wins: 47
# Num losses: 72
# Win streak: 3
# Loss streak: 6
# Remaining runs: 54
# Best reward so far: 4904.50000000016
#
# 2
# 20
# 3416.0000000000236
# Num buys: 53
# Num sells: 46
# Num trades: 99
# Num wins: 44
# Num losses: 54
# Win streak: 4
# Loss streak: 6
# Remaining runs: 53
# Best reward so far: 4904.50000000016
#
# 2
# 20
# 2578.500000000002
# Num buys: 41
# Num sells: 40
# Num trades: 81
# Num wins: 37
# Num losses: 43
# Win streak: 5
# Loss streak: 8
# Remaining runs: 52
# Best reward so far: 4904.50000000016
#
# 2
# 20
# 2739.5000000001587
# Num buys: 94
# Num sells: 92
# Num trades: 186
# Num wins: 72
# Num losses: 113
# Win streak: 4
# Loss streak: 9
# Remaining runs: 51
# Best reward so far: 4904.50000000016
#
# 2
# 20
# 2872.0000000001733
# Num buys: 94
# Num sells: 83
# Num trades: 177
# Num wins: 71
# Num losses: 105
# Win streak: 5
# Loss streak: 9
# Remaining runs: 50
# Best reward so far: 4904.50000000016
#
# 2
# 20
# 2441.5000000001087
# Num buys: 86
# Num sells: 83
# Num trades: 169
# Num wins: 69
# Num losses: 99
# Win streak: 6
# Loss streak: 7
# Remaining runs: 49
# Best reward so far: 4904.50000000016
#
# 2
# 20
# 3107.0000000001232
# Num buys: 77
# Num sells: 74
# Num trades: 151
# Num wins: 67
# Num losses: 83
# Win streak: 5
# Loss streak: 6
# Remaining runs: 48
# Best reward so far: 4904.50000000016
#
# 2
# 25
# -1326.4999999999109
# Num buys: 28
# Num sells: 27
# Num trades: 55
# Num wins: 19
# Num losses: 36
# Win streak: 2
# Loss streak: 11
# Remaining runs: 47
# Best reward so far: 4904.50000000016
#
# 2
# 25
# -1177.0000000000164
# Num buys: 24
# Num sells: 18
# Num trades: 42
# Num wins: 14
# Num losses: 28
# Win streak: 2
# Loss streak: 8
# Remaining runs: 46
# Best reward so far: 4904.50000000016
#
# 2
# 25
# -863.9999999999849
# Num buys: 20
# Num sells: 16
# Num trades: 36
# Num wins: 13
# Num losses: 23
# Win streak: 3
# Loss streak: 7
# Remaining runs: 45
# Best reward so far: 4904.50000000016
#
# 2
# 25
# -100.99999999996655
# Num buys: 13
# Num sells: 12
# Num trades: 25
# Num wins: 9
# Num losses: 16
# Win streak: 1
# Loss streak: 4
# Remaining runs: 44
# Best reward so far: 4904.50000000016
#
# 2
# 25
# 365.50000000001637
# Num buys: 64
# Num sells: 57
# Num trades: 121
# Num wins: 48
# Num losses: 72
# Win streak: 4
# Loss streak: 8
# Remaining runs: 43
# Best reward so far: 4904.50000000016
#
# 2
# 25
# -724.999999999975
# Num buys: 56
# Num sells: 47
# Num trades: 103
# Num wins: 37
# Num losses: 65
# Win streak: 3
# Loss streak: 7
# Remaining runs: 42
# Best reward so far: 4904.50000000016
#
# 2
# 25
# 1056.4999999999718
# Num buys: 49
# Num sells: 40
# Num trades: 89
# Num wins: 37
# Num losses: 51
# Win streak: 5
# Loss streak: 6
# Remaining runs: 41
# Best reward so far: 4904.50000000016
#
# 2
# 25
# 1582.5
# Num buys: 36
# Num sells: 36
# Num trades: 72
# Num wins: 32
# Num losses: 39
# Win streak: 4
# Loss streak: 8
# Remaining runs: 40
# Best reward so far: 4904.50000000016
#
# 2
# 25
# 1806.5000000001169
# Num buys: 84
# Num sells: 81
# Num trades: 165
# Num wins: 66
# Num losses: 98
# Win streak: 4
# Loss streak: 8
# Remaining runs: 39
# Best reward so far: 4904.50000000016
#
# 2
# 25
# 232.00000000018758
# Num buys: 80
# Num sells: 73
# Num trades: 153
# Num wins: 58
# Num losses: 93
# Win streak: 4
# Loss streak: 8
# Remaining runs: 38
# Best reward so far: 4904.50000000016
#
# 2
# 25
# 2247.000000000133
# Num buys: 76
# Num sells: 72
# Num trades: 148
# Num wins: 64
# Num losses: 83
# Win streak: 5
# Loss streak: 9
# Remaining runs: 37
# Best reward so far: 4904.50000000016
#
# 2
# 25
# 2212.000000000133
# Num buys: 67
# Num sells: 69
# Num trades: 136
# Num wins: 61
# Num losses: 74
# Win streak: 5
# Loss streak: 8
# Remaining runs: 36
# Best reward so far: 4904.50000000016
#
# 2
# 30
# -1139.9999999999322
# Num buys: 26
# Num sells: 24
# Num trades: 50
# Num wins: 19
# Num losses: 31
# Win streak: 3
# Loss streak: 8
# Remaining runs: 35
# Best reward so far: 4904.50000000016
#
# 2
# 30
# 284.0000000000533
# Num buys: 22
# Num sells: 14
# Num trades: 36
# Num wins: 13
# Num losses: 23
# Win streak: 2
# Loss streak: 7
# Remaining runs: 34
# Best reward so far: 4904.50000000016
#
# 2
# 30
# 567.000000000067
# Num buys: 18
# Num sells: 13
# Num trades: 31
# Num wins: 11
# Num losses: 20
# Win streak: 3
# Loss streak: 6
# Remaining runs: 33
# Best reward so far: 4904.50000000016
#
# 2
# 30
# 127.50000000001734
# Num buys: 12
# Num sells: 10
# Num trades: 22
# Num wins: 7
# Num losses: 15
# Win streak: 1
# Loss streak: 4
# Remaining runs: 32
# Best reward so far: 4904.50000000016
#
# 2
# 30
# -2554.499999999883
# Num buys: 59
# Num sells: 52
# Num trades: 111
# Num wins: 39
# Num losses: 71
# Win streak: 5
# Loss streak: 8
# Remaining runs: 31
# Best reward so far: 4904.50000000016
#
# 2
# 30
# -2281.999999999929
# Num buys: 56
# Num sells: 45
# Num trades: 101
# Num wins: 36
# Num losses: 64
# Win streak: 3
# Loss streak: 7
# Remaining runs: 30
# Best reward so far: 4904.50000000016
#
# 2
# 30
# 403.5000000000912
# Num buys: 47
# Num sells: 38
# Num trades: 85
# Num wins: 35
# Num losses: 49
# Win streak: 5
# Loss streak: 7
# Remaining runs: 29
# Best reward so far: 4904.50000000016
#
# 2
# 30
# -233.99999999993264
# Num buys: 35
# Num sells: 34
# Num trades: 69
# Num wins: 28
# Num losses: 40
# Win streak: 4
# Loss streak: 9
# Remaining runs: 28
# Best reward so far: 4904.50000000016
#
# 2
# 30
# -2471.500000000019
# Num buys: 84
# Num sells: 69
# Num trades: 153
# Num wins: 54
# Num losses: 98
# Win streak: 4
# Loss streak: 11
# Remaining runs: 27
# Best reward so far: 4904.50000000016
#
# 2
# 30
# -2848.49999999982
# Num buys: 80
# Num sells: 69
# Num trades: 149
# Num wins: 53
# Num losses: 95
# Win streak: 4
# Loss streak: 15
# Remaining runs: 26
# Best reward so far: 4904.50000000016
#
# 2
# 30
# -4313.499999999898
# Num buys: 78
# Num sells: 71
# Num trades: 149
# Num wins: 52
# Num losses: 96
# Win streak: 4
# Loss streak: 10
# Remaining runs: 25
# Best reward so far: 4904.50000000016
#
# 2
# 30
# -1849.999999999927
# Num buys: 66
# Num sells: 65
# Num trades: 131
# Num wins: 51
# Num losses: 79
# Win streak: 5
# Loss streak: 13
# Remaining runs: 24
# Best reward so far: 4904.50000000016
#
# 2
# 35
# -593.4999999999794
# Num buys: 23
# Num sells: 23
# Num trades: 46
# Num wins: 16
# Num losses: 28
# Win streak: 4
# Loss streak: 7
# Remaining runs: 23
# Best reward so far: 4904.50000000016
#
# 2
# 35
# 1491.0000000000286
# Num buys: 20
# Num sells: 15
# Num trades: 35
# Num wins: 16
# Num losses: 19
# Win streak: 4
# Loss streak: 5
# Remaining runs: 22
# Best reward so far: 4904.50000000016
#
# 2
# 35
# 901.5000000000057
# Num buys: 17
# Num sells: 12
# Num trades: 29
# Num wins: 12
# Num losses: 17
# Win streak: 3
# Loss streak: 8
# Remaining runs: 21
# Best reward so far: 4904.50000000016
#
# 2
# 35
# 517.4999999999953
# Num buys: 12
# Num sells: 9
# Num trades: 21
# Num wins: 7
# Num losses: 14
# Win streak: 2
# Loss streak: 7
# Remaining runs: 20
# Best reward so far: 4904.50000000016
#
# 2
# 35
# -2538.9999999999577
# Num buys: 56
# Num sells: 46
# Num trades: 102
# Num wins: 36
# Num losses: 64
# Win streak: 5
# Loss streak: 9
# Remaining runs: 19
# Best reward so far: 4904.50000000016
#
# 2
# 35
# 229.5000000000682
# Num buys: 49
# Num sells: 41
# Num trades: 90
# Num wins: 35
# Num losses: 54
# Win streak: 5
# Loss streak: 7
# Remaining runs: 18
# Best reward so far: 4904.50000000016
#
# 2
# 35
# 1338.0000000000932
# Num buys: 44
# Num sells: 35
# Num trades: 79
# Num wins: 34
# Num losses: 44
# Win streak: 5
# Loss streak: 8
# Remaining runs: 17
# Best reward so far: 4904.50000000016
#
# 2
# 35
# 559.5000000000639
# Num buys: 30
# Num sells: 35
# Num trades: 65
# Num wins: 28
# Num losses: 36
# Win streak: 4
# Loss streak: 6
# Remaining runs: 16
# Best reward so far: 4904.50000000016
#
# 2
# 35
# 84.0000000000208
# Num buys: 76
# Num sells: 63
# Num trades: 139
# Num wins: 55
# Num losses: 83
# Win streak: 3
# Loss streak: 7
# Remaining runs: 15
# Best reward so far: 4904.50000000016
#
# 2
# 35
# -207.99999999993713
# Num buys: 73
# Num sells: 62
# Num trades: 135
# Num wins: 56
# Num losses: 78
# Win streak: 6
# Loss streak: 9
# Remaining runs: 14
# Best reward so far: 4904.50000000016
#
# 2
# 35
# -1814.999999999888
# Num buys: 71
# Num sells: 60
# Num trades: 131
# Num wins: 51
# Num losses: 79
# Win streak: 5
# Loss streak: 9
# Remaining runs: 13
# Best reward so far: 4904.50000000016
#
# 2
# 35
# -577.4999999999143
# Num buys: 58
# Num sells: 60
# Num trades: 118
# Num wins: 50
# Num losses: 67
# Win streak: 4
# Loss streak: 7
# Remaining runs: 12
# Best reward so far: 4904.50000000016
#
# 2
# 40
# 2004.0000000000236
# Num buys: 19
# Num sells: 17
# Num trades: 36
# Num wins: 14
# Num losses: 22
# Win streak: 2
# Loss streak: 4
# Remaining runs: 11
# Best reward so far: 4904.50000000016
#
# 2
# 40
# 520.4999999999884
# Num buys: 21
# Num sells: 13
# Num trades: 34
# Num wins: 13
# Num losses: 21
# Win streak: 2
# Loss streak: 6
# Remaining runs: 10
# Best reward so far: 4904.50000000016
#
# 2
# 40
# 796.0000000000332
# Num buys: 18
# Num sells: 11
# Num trades: 29
# Num wins: 10
# Num losses: 19
# Win streak: 3
# Loss streak: 8
# Remaining runs: 9
# Best reward so far: 4904.50000000016
#
# 2
# 40
# 256.5000000000082
# Num buys: 12
# Num sells: 11
# Num trades: 23
# Num wins: 9
# Num losses: 14
# Win streak: 3
# Loss streak: 3
# Remaining runs: 8
# Best reward so far: 4904.50000000016
#
# 2
# 40
# -627.0000000000091
# Num buys: 49
# Num sells: 42
# Num trades: 91
# Num wins: 35
# Num losses: 55
# Win streak: 3
# Loss streak: 6
# Remaining runs: 7
# Best reward so far: 4904.50000000016
#
# 2
# 40
# -2945.4999999998968
# Num buys: 47
# Num sells: 41
# Num trades: 88
# Num wins: 30
# Num losses: 57
# Win streak: 3
# Loss streak: 8
# Remaining runs: 6
# Best reward so far: 4904.50000000016
#
# 2
# 40
# -43.49999999995259
# Num buys: 41
# Num sells: 35
# Num trades: 76
# Num wins: 32
# Num losses: 43
# Win streak: 5
# Loss streak: 7
# Remaining runs: 5
# Best reward so far: 4904.50000000016
#
# 2
# 40
# -752.0000000000059
# Num buys: 30
# Num sells: 35
# Num trades: 65
# Num wins: 27
# Num losses: 37
# Win streak: 4
# Loss streak: 6
# Remaining runs: 4
# Best reward so far: 4904.50000000016
#
# 2
# 40
# -1121.4999999999457
# Num buys: 63
# Num sells: 59
# Num trades: 122
# Num wins: 45
# Num losses: 75
# Win streak: 4
# Loss streak: 7
# Remaining runs: 3
# Best reward so far: 4904.50000000016
#
# 2
# 40
# 534.5000000001287
# Num buys: 64
# Num sells: 56
# Num trades: 120
# Num wins: 50
# Num losses: 68
# Win streak: 4
# Loss streak: 7
# Remaining runs: 2
# Best reward so far: 4904.50000000016
#
# 2
# 40
# -1230.4999999999618
# Num buys: 62
# Num sells: 55
# Num trades: 117
# Num wins: 47
# Num losses: 69
# Win streak: 5
# Loss streak: 7
# Remaining runs: 1
# Best reward so far: 4904.50000000016
#
# 2
# 40
# -1973.499999999966
# Num buys: 52
# Num sells: 53
# Num trades: 105
# Num wins: 41
# Num losses: 63
# Win streak: 4
# Loss streak: 5
# Remaining runs: 0
# Best reward so far: 4904.50000000016
#
# ------------ FINAL RESULTS ------------
# Best reward: 4904.50000000016
# Best risk/reward ratio: 1.6
# Best pullback cushion: 15
# Best atr percentage: 0.35
# Best last x bars: 4
