# %%
import numpy as np
import pandas as pd
import random

# %%
file_path = '../../bar_movement/data/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
df = pd.read_csv(file_path + 'Oanda_Eur_Usd_M5_2021-2022.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2021-04-01 06:00:00   1.17170   1.17172  1.17141    1.17141   1.17184
# 1 2021-04-01 06:05:00   1.17140   1.17182  1.17119    1.17154   1.17153
# 2 2021-04-01 06:10:00   1.17153   1.17162  1.17140    1.17161   1.17166
# 3 2021-04-01 06:15:00   1.17160   1.17187  1.17153    1.17185   1.17173
# 4 2021-04-01 06:20:00   1.17184   1.17253  1.17171    1.17232   1.17196
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0   1.17187  1.17154    1.17154   1.17177   1.17180  1.17148    1.17148
# 1   1.17194  1.17133    1.17167   1.17146   1.17188  1.17126    1.17160
# 2   1.17175  1.17151    1.17174   1.17160   1.17168  1.17146    1.17168
# 3   1.17200  1.17165    1.17197   1.17166   1.17194  1.17160    1.17191
# 4   1.17266  1.17185    1.17244   1.17190   1.17259  1.17178    1.17238
#
#    Volume
# 0     348
# 1     451
# 2     324
# 3     275
# 4     646
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 74778 2022-04-01 05:35:00   1.10690   1.10694  1.10668    1.10676   1.10707
# 74779 2022-04-01 05:40:00   1.10675   1.10727  1.10672    1.10720   1.10691
# 74780 2022-04-01 05:45:00   1.10721   1.10722  1.10698    1.10704   1.10737
# 74781 2022-04-01 05:50:00   1.10703   1.10729  1.10700    1.10726   1.10721
# 74782 2022-04-01 05:55:00   1.10727   1.10737  1.10667    1.10673   1.10742
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 74778   1.10710  1.10683    1.10691   1.10698   1.10702  1.10676    1.10684
# 74779   1.10744  1.10689    1.10737   1.10683   1.10735  1.10680    1.10728
# 74780   1.10738  1.10715    1.10721   1.10729   1.10730  1.10707    1.10712
# 74781   1.10744  1.10717    1.10743   1.10712   1.10736  1.10708    1.10734
# 74782   1.10754  1.10683    1.10690   1.10734   1.10745  1.10675    1.10682
#
#        Volume
# 74778     291
# 74779     400
# 74780     183
# 74781     227
# 74782     439

# %%
def psar(barsdata, iaf=0.02, maxaf=0.2):
    length = len(barsdata)
    high = list(barsdata['Mid_High'])
    low = list(barsdata['Mid_Low'])
    close = list(barsdata['Mid_Close'])
    psar = close[0:len(close)]
    bull = True
    af = iaf
    hp = high[0]
    lp = low[0]
    for i in range(2, length):
        if bull:
            psar[i] = psar[i - 1] + af * (hp - psar[i - 1])
        else:
            psar[i] = psar[i - 1] + af * (lp - psar[i - 1])
        reverse = False
        if bull:
            if low[i] < psar[i]:
                bull = False
                reverse = True
                psar[i] = hp
                lp = low[i]
                af = iaf
        else:
            if high[i] > psar[i]:
                bull = True
                reverse = True
                psar[i] = lp
                hp = high[i]
                af = iaf
        if not reverse:
            if bull:
                if high[i] > hp:
                    hp = high[i]
                    af = min(af + iaf, maxaf)
                if low[i - 1] < psar[i]:
                    psar[i] = low[i - 1]
                if low[i - 2] < psar[i]:
                    psar[i] = low[i - 2]
            else:
                if low[i] < lp:
                    lp = low[i]
                    af = min(af + iaf, maxaf)
                if high[i - 1] > psar[i]:
                    psar[i] = high[i - 1]
                if high[i - 2] > psar[i]:
                    psar[i] = high[i - 2]
    return psar


def atr(barsdata, lookback=14):
    high_low = barsdata['Mid_High'] - barsdata['Mid_Low']
    high_close = np.abs(barsdata['Mid_High'] - barsdata['Mid_Close'].shift())
    low_close = np.abs(barsdata['Mid_Low'] - barsdata['Mid_Close'].shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = np.max(ranges, axis=1)

    return true_range.rolling(lookback).sum() / lookback


def rsi(barsdata, periods=14):
    close_delta = barsdata['Mid_Close'].diff()

    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)
    ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))

    return rsi

  
def adx(high, low, close, lookback=14):
    plus_dm = high.diff()
    minus_dm = low.diff()
    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0
    
    tr1 = pd.DataFrame(high - low)
    tr2 = pd.DataFrame(abs(high - close.shift(1)))
    tr3 = pd.DataFrame(abs(low - close.shift(1)))
    frames = [tr1, tr2, tr3]
    tr = pd.concat(frames, axis = 1, join = 'inner').max(axis = 1)
    atr = tr.rolling(lookback).mean()
    
    plus_di = 100 * (plus_dm.ewm(alpha = 1/lookback).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha = 1/lookback).mean() / atr))
    dx = (abs(plus_di - minus_di) / abs(plus_di + minus_di)) * 100
    adx = ((dx.shift(1) * (lookback - 1)) + dx) / lookback
    adx_smooth = adx.ewm(alpha = 1/lookback).mean()

    return adx_smooth


def stoch(high, low, close, lookback=14):
    high_lookback = high.rolling(lookback).max()
    low_lookback = low.rolling(lookback).min()
    slow_k = (close - low_lookback) * 100 / (high_lookback - low_lookback)
    slow_d = slow_k.rolling(3).mean()

    return slow_k, slow_d

def stoch_rsi(data, k_window=3, d_window=3, window=14):
    min_val = data.rolling(window=window, center=False).min()
    max_val = data.rolling(window=window, center=False).max()

    stoch = ((data - min_val) / (max_val - min_val)) * 100

    slow_k = stoch.rolling(window=k_window, center=False).mean()

    slow_d = slow_k.rolling(window=d_window, center=False).mean()

    return slow_k, slow_d

def n_macd(macd, macdsignal, lookback=50):
    n_macd = 2 * (((macd - macd.rolling(lookback).min()) / (macd.rolling(lookback).max() - macd.rolling(lookback).min()))) - 1
    n_macdsignal = 2 * (((macdsignal - macdsignal.rolling(lookback).min()) / (macdsignal.rolling(lookback).max() - macdsignal.rolling(lookback).min()))) - 1

    return n_macd, n_macdsignal

def chop(df, lookback=14):
    atr1 = atr(df, lookback=1)
    high, low = df['Mid_High'], df['Mid_Low']

    chop = np.log10(atr1.rolling(lookback).sum() / (high.rolling(lookback).max() - low.rolling(lookback).min())) / np.log10(lookback)

    return chop

def vo(volume, short_lookback=5, long_lookback=10):
    short_ema =  pd.Series.ewm(volume, span=short_lookback).mean()
    long_ema = pd.Series.ewm(volume, span=long_lookback).mean()

    volume_oscillator = (short_ema - long_ema) / long_ema

    return volume_oscillator

def bar_lengths(bar_lens, window=36):
    return bar_lens.rolling(window=window).mean(), bar_lens.rolling(window=window).std()

def sar_lengths(opens, sars, window=36):
    diffs = abs(opens - sars.shift(1))

    return diffs.rolling(window=window).mean(), diffs.rolling(window=window).std()

def range_high_lows(df, i, n_histograms=6):
    green, red = False, False
    curr_color, curr_streak = None, 0
    high, low = -np.inf, np.inf

    while i >= 0:
        hist = df.loc[df.index[i], 'macdhist']
        curr_high, curr_low = df.loc[df.index[i], ['Mid_High', 'Mid_Low']]
        new_color = 'green' if hist > 0 else 'red'

        if curr_color != new_color:
            curr_color = new_color
            curr_streak = 0

            if green and red:
                break

        curr_streak += 1

        if curr_streak >= n_histograms:
            high = max(high, curr_high)
            low = min(low, curr_low)

            if curr_color == 'red':
                red = True

            else:
                green = True

        i -= 1

    return high, low if (high > -np.inf and low < np.inf) else np.nan, np.nan

# def range_high_lows(df, i):
#     green, red = False, False
#     curr_color, curr_streak = None, 0
#     high, low = -np.inf, np.inf

#     while i >= 0:
#         hist = df.loc[df.index[i], 'macdhist']
#         curr_high, curr_low = df.loc[df.index[i], ['Mid_High', 'Mid_Low']]
#         new_color = 'green' if hist > 0 else 'red'

#         if curr_color != new_color:
#             curr_color = new_color
#             curr_streak = 0

#             if green and red:
#                 break

#         curr_streak += 1

#         if curr_streak >= 3:
#             if curr_color == 'red':
#                 low = min(low, curr_low)
#                 red = True

#             else:
#                 high = max(high, curr_high)
#                 green = True

#         i -= 1

#     return high, low if (high > -np.inf and low < np.inf) else np.nan, np.nan

# %%
# Add technical indicators (for additional features)
df['atr'] = atr(df)
df['adx'] = adx(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

print(df)
# Out:
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0     2021-04-01 07:10:00   1.17239   1.17334  1.17239    1.17316   1.17252
# 1     2021-04-01 07:15:00   1.17315   1.17321  1.17274    1.17297   1.17329
# 2     2021-04-01 07:20:00   1.17298   1.17362  1.17263    1.17362   1.17311
# 3     2021-04-01 07:25:00   1.17364   1.17420  1.17352    1.17414   1.17377
# 4     2021-04-01 07:30:00   1.17412   1.17425  1.17381    1.17394   1.17425
# ...                   ...       ...       ...      ...        ...       ...
# 74764 2022-04-01 05:35:00   1.10690   1.10694  1.10668    1.10676   1.10707
# 74765 2022-04-01 05:40:00   1.10675   1.10727  1.10672    1.10720   1.10691
# 74766 2022-04-01 05:45:00   1.10721   1.10722  1.10698    1.10704   1.10737
# 74767 2022-04-01 05:50:00   1.10703   1.10729  1.10700    1.10726   1.10721
# 74768 2022-04-01 05:55:00   1.10727   1.10737  1.10667    1.10673   1.10742
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0       1.17348  1.17252    1.17330   1.17246   1.17341  1.17246    1.17323
# 1       1.17334  1.17287    1.17310   1.17322   1.17328  1.17281    1.17304
# 2       1.17375  1.17276    1.17375   1.17304   1.17368  1.17270    1.17368
# 3       1.17433  1.17366    1.17427   1.17370   1.17426  1.17359    1.17420
# 4       1.17438  1.17391    1.17405   1.17418   1.17432  1.17386    1.17400
# ...         ...      ...        ...       ...       ...      ...        ...
# 74764   1.10710  1.10683    1.10691   1.10698   1.10702  1.10676    1.10684
# 74765   1.10744  1.10689    1.10737   1.10683   1.10735  1.10680    1.10728
# 74766   1.10738  1.10715    1.10721   1.10729   1.10730  1.10707    1.10712
# 74767   1.10744  1.10717    1.10743   1.10712   1.10736  1.10708    1.10734
# 74768   1.10754  1.10683    1.10690   1.10734   1.10745  1.10675    1.10682
#
#        Volume       atr        adx
# 0         662  0.000531  38.394956
# 1         490  0.000520  46.548073
# 2         548  0.000574  49.272128
# 3         698  0.000598  50.893711
# 4         398  0.000573  53.478762
# ...       ...       ...        ...
# 74764     291  0.000272   9.813219
# 74765     400  0.000299   9.807821
# 74766     183  0.000289  10.947864
# 74767     227  0.000294  12.020967
# 74768     439  0.000331  13.107870
#
# [74769 rows x 16 columns]

# %%
value_per_pip = 1.0
amounts_per_day = [-0.00008, -0.0001, -0.00012]
pair = 'EUR_USD'

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee

def get_n_units(open_price, stop_loss, mid_open, currency_pair):
    _, second = currency_pair.split('_')
  
    pips_to_risk = abs(open_price - stop_loss)
    pips_to_risk_calc = pips_to_risk * 10000 if second != 'JPY' else pips_to_risk * 100

    if second == 'USD':
        per_pip = 0.0001

    else:
        per_pip = 0.0001 / mid_open if second != 'JPY' else 0.01 / mid_open

    n_units = int(50 / (pips_to_risk_calc * per_pip))

    return n_units

def run_simulation(risk_reward_ratio, spread_cutoff, n_minutes, adx_cutoff):
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    lo = None
    trade = None
    placed_trade = False
    trade_lengths = []

    for i in range(12, len(df)):
        curr_date = df.loc[df.index[i], 'Date']
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, curr_mid_open, curr_mid_low = \
            df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_Low']]
        atr, adx, ask_low, bid_high = df.loc[df.index[i - 1], ['atr', 'adx', 'Ask_Low', 'Bid_High']]
        chop_signal = adx < adx_cutoff

        mid_highs = list(df.loc[df.index[i - 12:i], 'Mid_High'])
        mid_lows = list(df.loc[df.index[i - 12:i], 'Mid_Low'])

        if not chop_signal:
            placed_trade = False

        if lo is not None:
            minutes_elapsed = (curr_date - lo['start_date']).total_seconds() / 60
            stop_signal = adx >= adx_cutoff or minutes_elapsed >= n_minutes
            # stop_signal = minutes_elapsed >= n_minutes

            if stop_signal:
                lo = None

        if lo is None and trade is None and chop_signal and not placed_trade:
            range_high, range_low = max(mid_highs), min(mid_lows)
            rang = abs(float(range_high) - float(range_low))
            pips_gain = (rang / 2) * risk_reward_ratio
            pips_to_risk = pips_gain / risk_reward_ratio
            
            if range_high > range_low and spread <= pips_to_risk * spread_cutoff:
                buy_open_price = float(range_low)
                buy_stop_gain = buy_open_price + (rang / 2) * risk_reward_ratio
                buy_pips_gained = buy_stop_gain - buy_open_price
                buy_pips_to_risk = buy_pips_gained / risk_reward_ratio
                buy_pullback = buy_open_price - buy_pips_to_risk
                buy_stop_loss = round(buy_pullback, 5)
                buy_mo = buy_open_price - (spread / 2)
                buy_n_units = get_n_units(buy_open_price, buy_stop_loss, buy_mo, pair)

                sell_open_price = float(range_high)
                sell_stop_gain = sell_open_price - (rang / 2) * risk_reward_ratio
                sell_pips_gained = sell_open_price - sell_stop_gain
                sell_pips_to_risk = sell_pips_gained / risk_reward_ratio
                sell_pullback = sell_open_price + sell_pips_to_risk
                sell_stop_loss = round(sell_pullback, 5)
                sell_mo = sell_open_price + (spread / 2)
                sell_n_units = get_n_units(sell_open_price, sell_stop_loss, sell_mo, pair)

                lo = {'buy_open_price': buy_open_price, 'buy_stop_gain': buy_stop_gain, 'buy_stop_loss': buy_stop_loss, 'buy_n_units': buy_n_units, 
                               'sell_open_price': sell_open_price, 'sell_stop_gain': sell_stop_gain, 'sell_stop_loss': sell_stop_loss, 'sell_n_units': sell_n_units, 'start_date': curr_date}

        if trade is None and lo is not None:
            place_buy = curr_ask_low <= lo['buy_open_price']
            place_sell = curr_bid_high >= lo['sell_open_price']

            if place_buy:
                open_price = lo['buy_open_price']
                stop_gain = lo['buy_stop_gain']
                pips_gained = stop_gain - open_price
                curr_pips_to_risk = pips_gained / risk_reward_ratio
                stop_loss = lo['buy_stop_loss']

                if stop_loss < open_price and stop_gain > open_price:
                    n_units = lo['buy_n_units']

                    trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                    'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                    'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None, 'index': i}

                    n_buys += 1

                    pips_risked.append(curr_pips_to_risk)
                    
                    lo = None
                    placed_trade = True

            elif place_sell:
                open_price = lo['sell_open_price']
                stop_gain = lo['sell_stop_gain']
                pips_gained = open_price - stop_gain
                curr_pips_to_risk = pips_gained / risk_reward_ratio
                stop_loss = lo['sell_stop_loss']

                if stop_loss > open_price and stop_gain < open_price:
                    n_units = lo['sell_n_units']

                    trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                            'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                            'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None, 'index': i}

                    n_sells += 1

                    pips_risked.append(curr_pips_to_risk)

                    lo = None
                    placed_trade = True

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
            trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
            trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
            trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
            trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked, trade_lengths

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
risk_reward_ratio_vals = [0.25, 0.5, 1.0, 1.5, 2.0]
spread_cutoffs = [0.10, 0.20]
adx_cutoffs = [15, 20, 25]
n_bars_vals = [5, 10, 15, 20, 25, 30, 40, 50, 60]
all_combos = []


# use_half_sar, vo_cutoff, use_candles

for risk_reward_ratio in risk_reward_ratio_vals:
    for spread_val in spread_cutoffs:
        for n_bars in n_bars_vals:
            for adx_cutoff in adx_cutoffs:
                all_combos.append((risk_reward_ratio, spread_val, n_bars, adx_cutoff))

# percentage_to_try = 0.5
percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)
print('Num runs: '+ str(len(combos_to_try)) + '\n')

best_risk_reward = None
best_spread_cutoff = None
best_n_bars= None
best_adx_cutoff = None
top_n_results = 20
best_rewards = []
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, spread_val, n_bars, adx_cutoff in combos_to_try:
    reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked, trade_lengths = run_simulation(risk_reward_ratio, spread_val, n_bars, adx_cutoff)
    runs_finished += 1

    print(reward)
    print('Num buys: ' + str(n_buys))
    print('Num sells: ' + str(n_sells))
    print('Num trades: ' + str(n_buys + n_sells))
    print('Num wins: ' + str(n_wins))
    print('Num losses: ' + str(n_losses))
    print('Win streak: ' + str(win_streak))
    print('Loss streak: ' + str(loss_streak))
    avg_pips_risked = (sum(pips_risked) / len(pips_risked)) if len(pips_risked) > 0 else 'N/A'
    avg_trade_len = (sum(trade_lengths) / len(trade_lengths)) if len(trade_lengths) > 0 else 'N/A'
    print('Avg pips risked: ' + str(avg_pips_risked))
    print('Trade length: ' + str(avg_trade_len))
    print('Remaining runs: ' + str(n_runs - runs_finished))

    min_item = min(best_rewards, key=lambda entry: entry['reward']) if len(best_rewards) >= top_n_results else None

    if min_item is None or reward > min_item['reward']:
        if min_item is not None:
            best_rewards.remove(min_item)
            
        best_rewards.append({'reward': int(reward), 'ratio': risk_reward_ratio, 'spread_val': spread_val, 'n_bars': n_bars, 'adx_cutoff': adx_cutoff})


    if reward > best_reward:
        best_reward = reward
        best_risk_reward = risk_reward_ratio
        best_spread_cutoff = spread_val
        best_n_bars = n_bars
        best_adx_cutoff = adx_cutoff

    print('Best reward so far: ' + str(best_reward))
    print()
# Out:
# Num runs: 270
#
# -2377.0009374999504
# Num buys: 129
# Num sells: 124
# Num trades: 253
# Num wins: 83
# Num losses: 170
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008479051383399277
# Trade length: 16.932806324110672
# Remaining runs: 269
# Best reward so far: -2377.0009374999504
#
# -2170.314567499936
# Num buys: 126
# Num sells: 123
# Num trades: 249
# Num wins: 83
# Num losses: 166
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008463052208835414
# Trade length: 16.566265060240966
# Remaining runs: 268
# Best reward so far: -2170.314567499936
#
# -2393.2509949998525
# Num buys: 123
# Num sells: 123
# Num trades: 246
# Num wins: 80
# Num losses: 166
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008444308943089483
# Trade length: 16.65447154471545
# Remaining runs: 267
# Best reward so far: -2170.314567499936
#
# -5832.20821999971
# Num buys: 322
# Num sells: 328
# Num trades: 650
# Num wins: 215
# Num losses: 435
# Win streak: 8
# Loss streak: 20
# Avg pips risked: 0.0008679692307692363
# Trade length: 18.189230769230768
# Remaining runs: 266
# Best reward so far: -2170.314567499936
#
# -433.8802325000082
# Num buys: 48
# Num sells: 45
# Num trades: 93
# Num wins: 34
# Num losses: 59
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0015900000000000033
# Trade length: 35.43010752688172
# Remaining runs: 265
# Best reward so far: -433.8802325000082
#
# 436.03874000000144
# Num buys: 82
# Num sells: 78
# Num trades: 160
# Num wins: 135
# Num losses: 25
# Win streak: 21
# Loss streak: 3
# Avg pips risked: 0.001628406250000003
# Trade length: 5.625
# Remaining runs: 264
# Best reward so far: 436.03874000000144
#
# -488.11684249986877
# Num buys: 137
# Num sells: 124
# Num trades: 261
# Num wins: 201
# Num losses: 60
# Win streak: 16
# Loss streak: 4
# Avg pips risked: 0.0008306704980843181
# Trade length: 2.5095785440613025
# Remaining runs: 263
# Best reward so far: 436.03874000000144
#
# -406.3293549999501
# Num buys: 46
# Num sells: 46
# Num trades: 92
# Num wins: 56
# Num losses: 36
# Win streak: 7
# Loss streak: 4
# Avg pips risked: 0.0015886413043478336
# Trade length: 11.815217391304348
# Remaining runs: 262
# Best reward so far: 436.03874000000144
#
# -1031.1157349999714
# Num buys: 80
# Num sells: 78
# Num trades: 158
# Num wins: 69
# Num losses: 89
# Win streak: 9
# Loss streak: 10
# Avg pips risked: 0.0016325632911392439
# Trade length: 24.943037974683545
# Remaining runs: 261
# Best reward so far: 436.03874000000144
#
# -706.6848524999854
# Num buys: 76
# Num sells: 74
# Num trades: 150
# Num wins: 55
# Num losses: 95
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0016233000000000022
# Trade length: 46.913333333333334
# Remaining runs: 260
# Best reward so far: 436.03874000000144
#
# -660.3111299999546
# Num buys: 72
# Num sells: 71
# Num trades: 143
# Num wins: 44
# Num losses: 99
# Win streak: 4
# Loss streak: 12
# Avg pips risked: 0.001621083916083923
# Trade length: 67.76223776223776
# Remaining runs: 259
# Best reward so far: 436.03874000000144
#
# -858.4923199999417
# Num buys: 273
# Num sells: 289
# Num trades: 562
# Num wins: 436
# Num losses: 126
# Win streak: 20
# Loss streak: 3
# Avg pips risked: 0.0008519928825622756
# Trade length: 2.969750889679715
# Remaining runs: 258
# Best reward so far: 436.03874000000144
#
# -75.04930499999335
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 11
# Num losses: 7
# Win streak: 4
# Loss streak: 2
# Avg pips risked: 0.0018347222222222144
# Trade length: 5.0
# Remaining runs: 257
# Best reward so far: 436.03874000000144
#
# -276.2766787498647
# Num buys: 129
# Num sells: 124
# Num trades: 253
# Num wins: 198
# Num losses: 55
# Win streak: 16
# Loss streak: 4
# Avg pips risked: 0.0008234387351778977
# Trade length: 2.6047430830039526
# Remaining runs: 256
# Best reward so far: 436.03874000000144
#
# -5730.762992499643
# Num buys: 265
# Num sells: 281
# Num trades: 546
# Num wins: 174
# Num losses: 372
# Win streak: 7
# Loss streak: 18
# Avg pips risked: 0.000864010989010994
# Trade length: 17.197802197802197
# Remaining runs: 255
# Best reward so far: 436.03874000000144
#
# -974.0294387499221
# Num buys: 327
# Num sells: 336
# Num trades: 663
# Num wins: 515
# Num losses: 148
# Win streak: 28
# Loss streak: 4
# Avg pips risked: 0.0008584012066365045
# Trade length: 3.339366515837104
# Remaining runs: 254
# Best reward so far: 436.03874000000144
#
# 298.06288000000865
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 8
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.001818055555555562
# Trade length: 31.666666666666668
# Remaining runs: 253
# Best reward so far: 436.03874000000144
#
# -6239.413829999799
# Num buys: 281
# Num sells: 282
# Num trades: 563
# Num wins: 148
# Num losses: 415
# Win streak: 5
# Loss streak: 17
# Avg pips risked: 0.0008576731793960985
# Trade length: 24.119005328596803
# Remaining runs: 252
# Best reward so far: 436.03874000000144
#
# 297.68224625000204
# Num buys: 80
# Num sells: 79
# Num trades: 159
# Num wins: 132
# Num losses: 27
# Win streak: 21
# Loss streak: 3
# Avg pips risked: 0.001617421383647801
# Trade length: 5.6918238993710695
# Remaining runs: 251
# Best reward so far: 436.03874000000144
#
# -251.46517249999732
# Num buys: 45
# Num sells: 42
# Num trades: 87
# Num wins: 33
# Num losses: 54
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0016174137931034567
# Trade length: 35.172413793103445
# Remaining runs: 250
# Best reward so far: 436.03874000000144
#
# -2131.668089999952
# Num buys: 131
# Num sells: 123
# Num trades: 254
# Num wins: 106
# Num losses: 148
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0008303543307086646
# Trade length: 9.881889763779528
# Remaining runs: 249
# Best reward so far: 436.03874000000144
#
# 311.1464362500014
# Num buys: 80
# Num sells: 80
# Num trades: 160
# Num wins: 133
# Num losses: 27
# Win streak: 21
# Loss streak: 3
# Avg pips risked: 0.0016293125000000131
# Trade length: 5.88125
# Remaining runs: 248
# Best reward so far: 436.03874000000144
#
# -100.08892999999172
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 14
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0017499999999999762
# Trade length: 7.043478260869565
# Remaining runs: 247
# Best reward so far: 436.03874000000144
#
# -149.7848449999894
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 10
# Num losses: 13
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017499999999999569
# Trade length: 11.26086956521739
# Remaining runs: 246
# Best reward so far: 436.03874000000144
#
# -1425.503587499994
# Num buys: 132
# Num sells: 123
# Num trades: 255
# Num wins: 151
# Num losses: 104
# Win streak: 7
# Loss streak: 5
# Avg pips risked: 0.0008295098039215754
# Trade length: 5.329411764705882
# Remaining runs: 245
# Best reward so far: 436.03874000000144
#
# -12.607382499990642
# Num buys: 11
# Num sells: 8
# Num trades: 19
# Num wins: 15
# Num losses: 4
# Win streak: 9
# Loss streak: 2
# Avg pips risked: 0.001792105263157972
# Trade length: 2.9473684210526314
# Remaining runs: 244
# Best reward so far: 436.03874000000144
#
# -512.5527199998037
# Num buys: 121
# Num sells: 117
# Num trades: 238
# Num wins: 77
# Num losses: 161
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.000847710084033622
# Trade length: 24.764705882352942
# Remaining runs: 243
# Best reward so far: 436.03874000000144
#
# -99.38048499999323
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 9
# Num losses: 11
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.001775499999999952
# Trade length: 11.5
# Remaining runs: 242
# Best reward so far: 436.03874000000144
#
# -482.0126949999595
# Num buys: 49
# Num sells: 46
# Num trades: 95
# Num wins: 57
# Num losses: 38
# Win streak: 8
# Loss streak: 4
# Avg pips risked: 0.0015842631578947403
# Trade length: 11.578947368421053
# Remaining runs: 241
# Best reward so far: 436.03874000000144
#
# -1071.511353749945
# Num buys: 344
# Num sells: 346
# Num trades: 690
# Num wins: 535
# Num losses: 155
# Win streak: 29
# Loss streak: 4
# Avg pips risked: 0.0008677753623188473
# Trade length: 3.4260869565217393
# Remaining runs: 240
# Best reward so far: 436.03874000000144
#
# -920.6407437499767
# Num buys: 285
# Num sells: 307
# Num trades: 592
# Num wins: 459
# Num losses: 133
# Win streak: 18
# Loss streak: 3
# Avg pips risked: 0.000835557432432431
# Trade length: 2.9138513513513513
# Remaining runs: 239
# Best reward so far: 436.03874000000144
#
# -1450.3845875000095
# Num buys: 136
# Num sells: 124
# Num trades: 260
# Num wins: 154
# Num losses: 106
# Win streak: 8
# Loss streak: 5
# Avg pips risked: 0.0008308653846153919
# Trade length: 5.357692307692307
# Remaining runs: 238
# Best reward so far: 436.03874000000144
#
# 37.29006750001609
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 19
# Num losses: 4
# Win streak: 12
# Loss streak: 2
# Avg pips risked: 0.001750000000000092
# Trade length: 2.608695652173913
# Remaining runs: 237
# Best reward so far: 436.03874000000144
#
# -5991.974582499914
# Num buys: 326
# Num sells: 337
# Num trades: 663
# Num wins: 219
# Num losses: 444
# Win streak: 9
# Loss streak: 19
# Avg pips risked: 0.0008633710407239876
# Trade length: 18.066365007541478
# Remaining runs: 236
# Best reward so far: 436.03874000000144
#
# -256.3188224999431
# Num buys: 44
# Num sells: 42
# Num trades: 86
# Num wins: 54
# Num losses: 32
# Win streak: 7
# Loss streak: 3
# Avg pips risked: 0.001634534883720944
# Trade length: 10.790697674418604
# Remaining runs: 235
# Best reward so far: 436.03874000000144
#
# -834.2844299999622
# Num buys: 82
# Num sells: 78
# Num trades: 160
# Num wins: 72
# Num losses: 88
# Win streak: 9
# Loss streak: 9
# Avg pips risked: 0.0016281562500000055
# Trade length: 25.8625
# Remaining runs: 234
# Best reward so far: 436.03874000000144
#
# -1728.1961899998316
# Num buys: 124
# Num sells: 122
# Num trades: 246
# Num wins: 106
# Num losses: 140
# Win streak: 7
# Loss streak: 10
# Avg pips risked: 0.0008294512195122034
# Trade length: 9.390243902439025
# Remaining runs: 233
# Best reward so far: 436.03874000000144
#
# -2381.034549999991
# Num buys: 130
# Num sells: 123
# Num trades: 253
# Num wins: 83
# Num losses: 170
# Win streak: 6
# Loss streak: 13
# Avg pips risked: 0.0008472332015810341
# Trade length: 17.509881422924902
# Remaining runs: 232
# Best reward so far: 436.03874000000144
#
# 198.5291200000087
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 8
# Num losses: 12
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017665000000000042
# Trade length: 31.05
# Remaining runs: 231
# Best reward so far: 436.03874000000144
#
# 523.2931924999853
# Num buys: 83
# Num sells: 79
# Num trades: 162
# Num wins: 138
# Num losses: 24
# Win streak: 22
# Loss streak: 3
# Avg pips risked: 0.0016330246913580182
# Trade length: 5.549382716049383
# Remaining runs: 230
# Best reward so far: 523.2931924999853
#
# -7740.86689999994
# Num buys: 307
# Num sells: 328
# Num trades: 635
# Num wins: 162
# Num losses: 473
# Win streak: 6
# Loss streak: 22
# Avg pips risked: 0.0008678897637795329
# Trade length: 26.135433070866142
# Remaining runs: 229
# Best reward so far: 523.2931924999853
#
# -37.66289624997204
# Num buys: 46
# Num sells: 46
# Num trades: 92
# Num wins: 73
# Num losses: 19
# Win streak: 17
# Loss streak: 3
# Avg pips risked: 0.0016074456521739183
# Trade length: 4.076086956521739
# Remaining runs: 228
# Best reward so far: 523.2931924999853
#
# -1018.6188699999414
# Num buys: 127
# Num sells: 118
# Num trades: 245
# Num wins: 76
# Num losses: 169
# Win streak: 6
# Loss streak: 13
# Avg pips risked: 0.0008546530612244964
# Trade length: 24.538775510204083
# Remaining runs: 227
# Best reward so far: 523.2931924999853
#
# -383.54524999996625
# Num buys: 80
# Num sells: 79
# Num trades: 159
# Num wins: 101
# Num losses: 58
# Win streak: 11
# Loss streak: 4
# Avg pips risked: 0.001617421383647812
# Trade length: 12.547169811320755
# Remaining runs: 226
# Best reward so far: 523.2931924999853
#
# -758.1509199999663
# Num buys: 70
# Num sells: 72
# Num trades: 142
# Num wins: 43
# Num losses: 99
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0016342957746478942
# Trade length: 68.88028169014085
# Remaining runs: 225
# Best reward so far: 523.2931924999853
#
# -1832.0626049997948
# Num buys: 118
# Num sells: 116
# Num trades: 234
# Num wins: 99
# Num losses: 135
# Win streak: 7
# Loss streak: 10
# Avg pips risked: 0.0008384615384615467
# Trade length: 9.764957264957266
# Remaining runs: 224
# Best reward so far: 523.2931924999853
#
# -75.04930499999335
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 11
# Num losses: 7
# Win streak: 4
# Loss streak: 2
# Avg pips risked: 0.0018347222222222144
# Trade length: 5.0
# Remaining runs: 223
# Best reward so far: 523.2931924999853
#
# 298.52798000000865
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 8
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.001818055555555562
# Trade length: 31.666666666666668
# Remaining runs: 222
# Best reward so far: 523.2931924999853
#
# -460.69251999996357
# Num buys: 73
# Num sells: 75
# Num trades: 148
# Num wins: 47
# Num losses: 101
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0016214189189189244
# Trade length: 70.28378378378379
# Remaining runs: 221
# Best reward so far: 523.2931924999853
#
# -535.6485762499138
# Num buys: 335
# Num sells: 338
# Num trades: 673
# Num wins: 530
# Num losses: 143
# Win streak: 27
# Loss streak: 4
# Avg pips risked: 0.0008573922734026823
# Trade length: 3.2585438335809807
# Remaining runs: 220
# Best reward so far: 523.2931924999853
#
# -100.08892999999172
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 14
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0017499999999999762
# Trade length: 7.043478260869565
# Remaining runs: 219
# Best reward so far: 523.2931924999853
#
# -2178.0234474999074
# Num buys: 125
# Num sells: 124
# Num trades: 249
# Num wins: 83
# Num losses: 166
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008428714859437821
# Trade length: 17.03614457831325
# Remaining runs: 218
# Best reward so far: 523.2931924999853
#
# -99.78652499998648
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 9
# Num losses: 11
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017664999999999597
# Trade length: 10.85
# Remaining runs: 217
# Best reward so far: 523.2931924999853
#
# -3319.61127750003
# Num buys: 280
# Num sells: 299
# Num trades: 579
# Num wins: 342
# Num losses: 237
# Win streak: 12
# Loss streak: 7
# Avg pips risked: 0.0008383851468048425
# Trade length: 5.595854922279793
# Remaining runs: 216
# Best reward so far: 523.2931924999853
#
# -6171.481849999833
# Num buys: 266
# Num sells: 281
# Num trades: 547
# Num wins: 143
# Num losses: 404
# Win streak: 5
# Loss streak: 20
# Avg pips risked: 0.0008531078610603357
# Trade length: 23.70749542961609
# Remaining runs: 215
# Best reward so far: 523.2931924999853
#
# -5380.207734999749
# Num buys: 288
# Num sells: 296
# Num trades: 584
# Num wins: 239
# Num losses: 345
# Win streak: 6
# Loss streak: 13
# Avg pips risked: 0.000839006849315074
# Trade length: 11.36472602739726
# Remaining runs: 214
# Best reward so far: 523.2931924999853
#
# -5804.614239999986
# Num buys: 330
# Num sells: 350
# Num trades: 680
# Num wins: 283
# Num losses: 397
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0008661102941176495
# Trade length: 12.3
# Remaining runs: 213
# Best reward so far: 523.2931924999853
#
# -2139.8814550000093
# Num buys: 137
# Num sells: 123
# Num trades: 260
# Num wins: 109
# Num losses: 151
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0008299038461538489
# Trade length: 10.11923076923077
# Remaining runs: 212
# Best reward so far: 523.2931924999853
#
# -1021.2096974999266
# Num buys: 291
# Num sells: 308
# Num trades: 599
# Num wins: 463
# Num losses: 136
# Win streak: 17
# Loss streak: 3
# Avg pips risked: 0.0008332721202003384
# Trade length: 2.9232053422370616
# Remaining runs: 211
# Best reward so far: 523.2931924999853
#
# -931.6203037499026
# Num buys: 280
# Num sells: 301
# Num trades: 581
# Num wins: 450
# Num losses: 131
# Win streak: 18
# Loss streak: 3
# Avg pips risked: 0.0008383820998278828
# Trade length: 2.9053356282271947
# Remaining runs: 210
# Best reward so far: 523.2931924999853
#
# -238.55329749987058
# Num buys: 131
# Num sells: 125
# Num trades: 256
# Num wins: 201
# Num losses: 55
# Win streak: 18
# Loss streak: 4
# Avg pips risked: 0.0008247265625000305
# Trade length: 2.56640625
# Remaining runs: 209
# Best reward so far: 523.2931924999853
#
# -353.0371049999951
# Num buys: 45
# Num sells: 44
# Num trades: 89
# Num wins: 33
# Num losses: 56
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0016048876404494462
# Trade length: 34.640449438202246
# Remaining runs: 208
# Best reward so far: 523.2931924999853
#
# -832.2595075000017
# Num buys: 78
# Num sells: 77
# Num trades: 155
# Num wins: 56
# Num losses: 99
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0016321612903225826
# Trade length: 46.76129032258064
# Remaining runs: 207
# Best reward so far: 523.2931924999853
#
# -29.926957499994977
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 9
# Num losses: 14
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017500000000000146
# Trade length: 28.17391304347826
# Remaining runs: 206
# Best reward so far: 523.2931924999853
#
# -1127.7010349998668
# Num buys: 128
# Num sells: 124
# Num trades: 252
# Num wins: 153
# Num losses: 99
# Win streak: 11
# Loss streak: 5
# Avg pips risked: 0.0008236111111111318
# Trade length: 5.238095238095238
# Remaining runs: 205
# Best reward so far: 523.2931924999853
#
# -6174.755920000008
# Num buys: 333
# Num sells: 344
# Num trades: 677
# Num wins: 278
# Num losses: 399
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0008670162481536222
# Trade length: 12.18463810930576
# Remaining runs: 204
# Best reward so far: 523.2931924999853
#
# -2918.3615224999057
# Num buys: 288
# Num sells: 301
# Num trades: 589
# Num wins: 354
# Num losses: 235
# Win streak: 12
# Loss streak: 7
# Avg pips risked: 0.0008343039049236097
# Trade length: 5.67572156196944
# Remaining runs: 203
# Best reward so far: 523.2931924999853
#
# -1909.88726499987
# Num buys: 120
# Num sells: 119
# Num trades: 239
# Num wins: 81
# Num losses: 158
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008450836820083741
# Trade length: 16.301255230125523
# Remaining runs: 202
# Best reward so far: 523.2931924999853
#
# -87.56339999997202
# Num buys: 45
# Num sells: 43
# Num trades: 88
# Num wins: 69
# Num losses: 19
# Win streak: 14
# Loss streak: 3
# Avg pips risked: 0.0016100568181818264
# Trade length: 4.079545454545454
# Remaining runs: 201
# Best reward so far: 523.2931924999853
#
# -569.4315349999627
# Num buys: 49
# Num sells: 46
# Num trades: 95
# Num wins: 42
# Num losses: 53
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0015881052631579
# Trade length: 24.221052631578946
# Remaining runs: 200
# Best reward so far: 523.2931924999853
#
# 12.351781250012955
# Num buys: 45
# Num sells: 46
# Num trades: 91
# Num wins: 73
# Num losses: 18
# Win streak: 17
# Loss streak: 3
# Avg pips risked: 0.0015977472527472399
# Trade length: 4.153846153846154
# Remaining runs: 199
# Best reward so far: 523.2931924999853
#
# -5994.808147499706
# Num buys: 275
# Num sells: 298
# Num trades: 573
# Num wins: 183
# Num losses: 390
# Win streak: 6
# Loss streak: 20
# Avg pips risked: 0.0008475305410122237
# Trade length: 17.350785340314136
# Remaining runs: 198
# Best reward so far: 523.2931924999853
#
# -3267.284319999951
# Num buys: 272
# Num sells: 288
# Num trades: 560
# Num wins: 330
# Num losses: 230
# Win streak: 12
# Loss streak: 8
# Avg pips risked: 0.0008518571428571542
# Trade length: 5.682142857142857
# Remaining runs: 197
# Best reward so far: 523.2931924999853
#
# -403.91919750000864
# Num buys: 45
# Num sells: 45
# Num trades: 90
# Num wins: 33
# Num losses: 57
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0016047222222222272
# Trade length: 34.666666666666664
# Remaining runs: 196
# Best reward so far: 523.2931924999853
#
# 345.5828200000096
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 9
# Num losses: 11
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017755000000000021
# Trade length: 33.45
# Remaining runs: 195
# Best reward so far: 523.2931924999853
#
# -5179.315529999861
# Num buys: 289
# Num sells: 303
# Num trades: 592
# Num wins: 245
# Num losses: 347
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.0008442483108108149
# Trade length: 11.33445945945946
# Remaining runs: 194
# Best reward so far: 523.2931924999853
#
# -6314.18288249974
# Num buys: 292
# Num sells: 297
# Num trades: 589
# Num wins: 187
# Num losses: 402
# Win streak: 5
# Loss streak: 17
# Avg pips risked: 0.0008523259762309067
# Trade length: 17.949066213921903
# Remaining runs: 193
# Best reward so far: 523.2931924999853
#
# -2937.1393075001124
# Num buys: 326
# Num sells: 337
# Num trades: 663
# Num wins: 403
# Num losses: 260
# Win streak: 16
# Loss streak: 7
# Avg pips risked: 0.0008589064856711983
# Trade length: 6.138763197586727
# Remaining runs: 192
# Best reward so far: 523.2931924999853
#
# -174.88424999999188
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 11
# Num losses: 9
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.0017754999999999744
# Trade length: 7.95
# Remaining runs: 191
# Best reward so far: 523.2931924999853
#
# -44.45557999998139
# Num buys: 47
# Num sells: 43
# Num trades: 90
# Num wins: 30
# Num losses: 60
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.001592722222222229
# Trade length: 51.44444444444444
# Remaining runs: 190
# Best reward so far: 523.2931924999853
#
# 174.06495750000383
# Num buys: 11
# Num sells: 8
# Num trades: 19
# Num wins: 9
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.001792105263157909
# Trade length: 27.263157894736842
# Remaining runs: 189
# Best reward so far: 523.2931924999853
#
# -881.1919099998249
# Num buys: 121
# Num sells: 118
# Num trades: 239
# Num wins: 75
# Num losses: 164
# Win streak: 6
# Loss streak: 13
# Avg pips risked: 0.0008482217573221843
# Trade length: 24.96652719665272
# Remaining runs: 188
# Best reward so far: 523.2931924999853
#
# -580.7813549999634
# Num buys: 45
# Num sells: 46
# Num trades: 91
# Num wins: 53
# Num losses: 38
# Win streak: 7
# Loss streak: 4
# Avg pips risked: 0.0015977472527472546
# Trade length: 11.736263736263735
# Remaining runs: 187
# Best reward so far: 523.2931924999853
#
# -49.38132499999264
# Num buys: 11
# Num sells: 8
# Num trades: 19
# Num wins: 9
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.001792105263157855
# Trade length: 11.894736842105264
# Remaining runs: 186
# Best reward so far: 523.2931924999853
#
# -250.93508499988974
# Num buys: 131
# Num sells: 124
# Num trades: 255
# Num wins: 200
# Num losses: 55
# Win streak: 16
# Loss streak: 4
# Avg pips risked: 0.0008218235294117908
# Trade length: 2.5215686274509803
# Remaining runs: 185
# Best reward so far: 523.2931924999853
#
# -8381.182909999945
# Num buys: 310
# Num sells: 334
# Num trades: 644
# Num wins: 161
# Num losses: 483
# Win streak: 4
# Loss streak: 22
# Avg pips risked: 0.0008765295031055945
# Trade length: 28.479813664596275
# Remaining runs: 184
# Best reward so far: 523.2931924999853
#
# -5640.573847499895
# Num buys: 340
# Num sells: 333
# Num trades: 673
# Num wins: 226
# Num losses: 447
# Win streak: 7
# Loss streak: 18
# Avg pips risked: 0.0008789450222882675
# Trade length: 18.74888558692422
# Remaining runs: 183
# Best reward so far: 523.2931924999853
#
# -6340.842209999926
# Num buys: 317
# Num sells: 324
# Num trades: 641
# Num wins: 258
# Num losses: 383
# Win streak: 8
# Loss streak: 18
# Avg pips risked: 0.0008739469578783196
# Trade length: 11.731669266770671
# Remaining runs: 182
# Best reward so far: 523.2931924999853
#
# 147.788458750006
# Num buys: 76
# Num sells: 76
# Num trades: 152
# Num wins: 124
# Num losses: 28
# Win streak: 20
# Loss streak: 3
# Avg pips risked: 0.0016299342105263268
# Trade length: 5.953947368421052
# Remaining runs: 181
# Best reward so far: 523.2931924999853
#
# -534.2457049999633
# Num buys: 78
# Num sells: 75
# Num trades: 153
# Num wins: 95
# Num losses: 58
# Win streak: 11
# Loss streak: 7
# Avg pips risked: 0.0016156862745098175
# Trade length: 13.196078431372548
# Remaining runs: 180
# Best reward so far: 523.2931924999853
#
# -2861.6454750000958
# Num buys: 341
# Num sells: 346
# Num trades: 687
# Num wins: 420
# Num losses: 267
# Win streak: 13
# Loss streak: 6
# Avg pips risked: 0.0008591120815138307
# Trade length: 6.336244541484716
# Remaining runs: 179
# Best reward so far: 523.2931924999853
#
# -708.1588999999857
# Num buys: 80
# Num sells: 78
# Num trades: 158
# Num wins: 96
# Num losses: 62
# Win streak: 9
# Loss streak: 7
# Avg pips risked: 0.001632278481012668
# Trade length: 13.139240506329115
# Remaining runs: 178
# Best reward so far: 523.2931924999853
#
# 44.636400000006695
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 8
# Num losses: 15
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0017500000000000052
# Trade length: 34.869565217391305
# Remaining runs: 177
# Best reward so far: 523.2931924999853
#
# -3340.2517300000322
# Num buys: 321
# Num sells: 326
# Num trades: 647
# Num wins: 387
# Num losses: 260
# Win streak: 16
# Loss streak: 11
# Avg pips risked: 0.0008714605873261324
# Trade length: 6.12982998454405
# Remaining runs: 176
# Best reward so far: 523.2931924999853
#
# -579.9806099999714
# Num buys: 78
# Num sells: 75
# Num trades: 153
# Num wins: 71
# Num losses: 82
# Win streak: 9
# Loss streak: 10
# Avg pips risked: 0.0016156862745098104
# Trade length: 25.751633986928105
# Remaining runs: 175
# Best reward so far: 523.2931924999853
#
# -5032.062089999919
# Num buys: 289
# Num sells: 302
# Num trades: 591
# Num wins: 246
# Num losses: 345
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0008378595600676848
# Trade length: 11.21150592216582
# Remaining runs: 174
# Best reward so far: 523.2931924999853
#
# -1023.7096199999871
# Num buys: 77
# Num sells: 73
# Num trades: 150
# Num wins: 44
# Num losses: 106
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.0016299333333333384
# Trade length: 70.48666666666666
# Remaining runs: 173
# Best reward so far: 523.2931924999853
#
# -206.42972499997495
# Num buys: 44
# Num sells: 42
# Num trades: 86
# Num wins: 33
# Num losses: 53
# Win streak: 6
# Loss streak: 6
# Avg pips risked: 0.0016387790697674532
# Trade length: 35.25581395348837
# Remaining runs: 172
# Best reward so far: 523.2931924999853
#
# -1350.9737175000282
# Num buys: 138
# Num sells: 123
# Num trades: 261
# Num wins: 156
# Num losses: 105
# Win streak: 8
# Loss streak: 6
# Avg pips risked: 0.0008290804597701221
# Trade length: 5.283524904214559
# Remaining runs: 171
# Best reward so far: 523.2931924999853
#
# -2614.406265000091
# Num buys: 335
# Num sells: 338
# Num trades: 673
# Num wins: 414
# Num losses: 259
# Win streak: 12
# Loss streak: 6
# Avg pips risked: 0.0008568499257057982
# Trade length: 6.197622585438336
# Remaining runs: 170
# Best reward so far: 523.2931924999853
#
# -1992.4155699998716
# Num buys: 125
# Num sells: 123
# Num trades: 248
# Num wins: 84
# Num losses: 164
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008426411290322641
# Trade length: 16.830645161290324
# Remaining runs: 169
# Best reward so far: 523.2931924999853
#
# 107.57644000002381
# Num buys: 44
# Num sells: 43
# Num trades: 87
# Num wins: 30
# Num losses: 57
# Win streak: 5
# Loss streak: 7
# Avg pips risked: 0.0016152873563218472
# Trade length: 52.758620689655174
# Remaining runs: 168
# Best reward so far: 523.2931924999853
#
# 12.481630000025675
# Num buys: 43
# Num sells: 40
# Num trades: 83
# Num wins: 28
# Num losses: 55
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.001618433734939769
# Trade length: 51.06024096385542
# Remaining runs: 167
# Best reward so far: 523.2931924999853
#
# 62.34397125000619
# Num buys: 49
# Num sells: 46
# Num trades: 95
# Num wins: 77
# Num losses: 18
# Win streak: 18
# Loss streak: 3
# Avg pips risked: 0.0015842631578947169
# Trade length: 4.031578947368421
# Remaining runs: 166
# Best reward so far: 523.2931924999853
#
# -3120.08241749994
# Num buys: 285
# Num sells: 305
# Num trades: 590
# Num wins: 352
# Num losses: 238
# Win streak: 12
# Loss streak: 7
# Avg pips risked: 0.0008350847457627212
# Trade length: 5.749152542372881
# Remaining runs: 165
# Best reward so far: 523.2931924999853
#
# -5432.4733299998325
# Num buys: 271
# Num sells: 284
# Num trades: 555
# Num wins: 224
# Num losses: 331
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.0008563693693693729
# Trade length: 11.36936936936937
# Remaining runs: 164
# Best reward so far: 523.2931924999853
#
# -408.51691749997985
# Num buys: 76
# Num sells: 76
# Num trades: 152
# Num wins: 96
# Num losses: 56
# Win streak: 11
# Loss streak: 4
# Avg pips risked: 0.0016299342105263299
# Trade length: 12.914473684210526
# Remaining runs: 163
# Best reward so far: 523.2931924999853
#
# -405.7790874999577
# Num buys: 46
# Num sells: 46
# Num trades: 92
# Num wins: 56
# Num losses: 36
# Win streak: 7
# Loss streak: 4
# Avg pips risked: 0.0016074456521739183
# Trade length: 11.08695652173913
# Remaining runs: 162
# Best reward so far: 523.2931924999853
#
# 123.60069750000324
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 9
# Num losses: 11
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017755000000000108
# Trade length: 26.1
# Remaining runs: 161
# Best reward so far: 523.2931924999853
#
# -7805.58807999981
# Num buys: 314
# Num sells: 325
# Num trades: 639
# Num wins: 163
# Num losses: 476
# Win streak: 5
# Loss streak: 22
# Avg pips risked: 0.0008669874804381905
# Trade length: 26.291079812206572
# Remaining runs: 160
# Best reward so far: 523.2931924999853
#
# 98.31733250000266
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 8
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.0018180555555555697
# Trade length: 27.166666666666668
# Remaining runs: 159
# Best reward so far: 523.2931924999853
#
# -5603.2345824998165
# Num buys: 281
# Num sells: 299
# Num trades: 580
# Num wins: 189
# Num losses: 391
# Win streak: 6
# Loss streak: 18
# Avg pips risked: 0.0008476120689655249
# Trade length: 17.420689655172414
# Remaining runs: 158
# Best reward so far: 523.2931924999853
#
# -671.0124087498423
# Num buys: 328
# Num sells: 349
# Num trades: 677
# Num wins: 531
# Num losses: 146
# Win streak: 27
# Loss streak: 4
# Avg pips risked: 0.0008567429837518627
# Trade length: 3.379615952732644
# Remaining runs: 157
# Best reward so far: 523.2931924999853
#
# -3164.5838924999703
# Num buys: 334
# Num sells: 341
# Num trades: 675
# Num wins: 408
# Num losses: 267
# Win streak: 16
# Loss streak: 7
# Avg pips risked: 0.0008531037037037125
# Trade length: 6.062222222222222
# Remaining runs: 156
# Best reward so far: 523.2931924999853
#
# -1011.7951399998625
# Num buys: 334
# Num sells: 341
# Num trades: 675
# Num wins: 524
# Num losses: 151
# Win streak: 24
# Loss streak: 4
# Avg pips risked: 0.000853674074074079
# Trade length: 3.362962962962963
# Remaining runs: 155
# Best reward so far: 523.2931924999853
#
# -0.20910249998649988
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 16
# Num losses: 4
# Win streak: 9
# Loss streak: 2
# Avg pips risked: 0.001766500000000093
# Trade length: 2.8
# Remaining runs: 154
# Best reward so far: 523.2931924999853
#
# -768.6154349999703
# Num buys: 45
# Num sells: 46
# Num trades: 91
# Num wins: 38
# Num losses: 53
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0016017582417582454
# Trade length: 24.208791208791208
# Remaining runs: 153
# Best reward so far: 523.2931924999853
#
# -832.5050849999734
# Num buys: 80
# Num sells: 80
# Num trades: 160
# Num wins: 72
# Num losses: 88
# Win streak: 9
# Loss streak: 10
# Avg pips risked: 0.001629593750000008
# Trade length: 26.3375
# Remaining runs: 152
# Best reward so far: 523.2931924999853
#
# -784.8837225000017
# Num buys: 74
# Num sells: 75
# Num trades: 149
# Num wins: 54
# Num losses: 95
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0016381879194630894
# Trade length: 48.11409395973154
# Remaining runs: 151
# Best reward so far: 523.2931924999853
#
# -6887.918752499707
# Num buys: 314
# Num sells: 320
# Num trades: 634
# Num wins: 200
# Num losses: 434
# Win streak: 7
# Loss streak: 18
# Avg pips risked: 0.000879329652996851
# Trade length: 18.126182965299684
# Remaining runs: 150
# Best reward so far: 523.2931924999853
#
# 446.59230000000593
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 9
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0018347222222222267
# Trade length: 43.888888888888886
# Remaining runs: 149
# Best reward so far: 523.2931924999853
#
# -2744.1922074999393
# Num buys: 295
# Num sells: 313
# Num trades: 608
# Num wins: 369
# Num losses: 239
# Win streak: 12
# Loss streak: 8
# Avg pips risked: 0.0008419407894736904
# Trade length: 5.873355263157895
# Remaining runs: 148
# Best reward so far: 523.2931924999853
#
# -5437.370559999753
# Num buys: 330
# Num sells: 329
# Num trades: 659
# Num wins: 222
# Num losses: 437
# Win streak: 9
# Loss streak: 21
# Avg pips risked: 0.0008647875569044081
# Trade length: 18.544764795144157
# Remaining runs: 147
# Best reward so far: 523.2931924999853
#
# 394.65178000001015
# Num buys: 11
# Num sells: 8
# Num trades: 19
# Num wins: 9
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.001792105263157902
# Trade length: 35.0
# Remaining runs: 146
# Best reward so far: 523.2931924999853
#
# -2690.8069599999494
# Num buys: 300
# Num sells: 307
# Num trades: 607
# Num wins: 369
# Num losses: 238
# Win streak: 12
# Loss streak: 8
# Avg pips risked: 0.0008386738056013255
# Trade length: 5.7973640856672155
# Remaining runs: 145
# Best reward so far: 523.2931924999853
#
# -455.684192500012
# Num buys: 46
# Num sells: 45
# Num trades: 91
# Num wins: 33
# Num losses: 58
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0015954395604395651
# Trade length: 34.879120879120876
# Remaining runs: 144
# Best reward so far: 523.2931924999853
#
# -140.68261999997634
# Num buys: 44
# Num sells: 42
# Num trades: 86
# Num wins: 28
# Num losses: 58
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.0016030232558139623
# Trade length: 50.25581395348837
# Remaining runs: 143
# Best reward so far: 523.2931924999853
#
# -838.5807974999987
# Num buys: 77
# Num sells: 78
# Num trades: 155
# Num wins: 56
# Num losses: 99
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.001640032258064519
# Trade length: 47.961290322580645
# Remaining runs: 142
# Best reward so far: 523.2931924999853
#
# -433.1770024999846
# Num buys: 80
# Num sells: 80
# Num trades: 160
# Num wins: 101
# Num losses: 59
# Win streak: 11
# Loss streak: 7
# Avg pips risked: 0.0016293125000000075
# Trade length: 13.29375
# Remaining runs: 141
# Best reward so far: 523.2931924999853
#
# -695.9808562499055
# Num buys: 291
# Num sells: 309
# Num trades: 600
# Num wins: 469
# Num losses: 131
# Win streak: 18
# Loss streak: 3
# Avg pips risked: 0.0008397416666666728
# Trade length: 2.9583333333333335
# Remaining runs: 140
# Best reward so far: 523.2931924999853
#
# -435.03198999994544
# Num buys: 83
# Num sells: 79
# Num trades: 162
# Num wins: 77
# Num losses: 85
# Win streak: 9
# Loss streak: 7
# Avg pips risked: 0.0016327777777777862
# Trade length: 25.567901234567902
# Remaining runs: 139
# Best reward so far: 523.2931924999853
#
# -709.2198387498426
# Num buys: 301
# Num sells: 308
# Num trades: 609
# Num wins: 476
# Num losses: 133
# Win streak: 18
# Loss streak: 3
# Avg pips risked: 0.0008389655172413897
# Trade length: 2.9277504105090313
# Remaining runs: 138
# Best reward so far: 523.2931924999853
#
# -355.85286499995397
# Num buys: 45
# Num sells: 43
# Num trades: 88
# Num wins: 54
# Num losses: 34
# Win streak: 7
# Loss streak: 4
# Avg pips risked: 0.0016100568181818264
# Trade length: 11.090909090909092
# Remaining runs: 137
# Best reward so far: 523.2931924999853
#
# -911.1090499999833
# Num buys: 75
# Num sells: 73
# Num trades: 148
# Num wins: 44
# Num losses: 104
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.001637871621621626
# Trade length: 69.52702702702703
# Remaining runs: 136
# Best reward so far: 523.2931924999853
#
# -149.9792649999917
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 10
# Num losses: 8
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0018180555555555372
# Trade length: 7.5
# Remaining runs: 135
# Best reward so far: 523.2931924999853
#
# -521.9727049999697
# Num buys: 45
# Num sells: 43
# Num trades: 88
# Num wins: 39
# Num losses: 49
# Win streak: 6
# Loss streak: 6
# Avg pips risked: 0.0016142045454545582
# Trade length: 25.681818181818183
# Remaining runs: 134
# Best reward so far: 523.2931924999853
#
# -151.26391499990717
# Num buys: 126
# Num sells: 122
# Num trades: 248
# Num wins: 196
# Num losses: 52
# Win streak: 16
# Loss streak: 3
# Avg pips risked: 0.0008285080645161543
# Trade length: 2.592741935483871
# Remaining runs: 133
# Best reward so far: 523.2931924999853
#
# -798.332741249876
# Num buys: 341
# Num sells: 346
# Num trades: 687
# Num wins: 537
# Num losses: 150
# Win streak: 30
# Loss streak: 4
# Avg pips risked: 0.0008598034934497967
# Trade length: 3.37117903930131
# Remaining runs: 132
# Best reward so far: 523.2931924999853
#
# -5719.589014999951
# Num buys: 323
# Num sells: 335
# Num trades: 658
# Num wins: 273
# Num losses: 385
# Win streak: 9
# Loss streak: 18
# Avg pips risked: 0.0008616641337386055
# Trade length: 11.844984802431611
# Remaining runs: 131
# Best reward so far: 523.2931924999853
#
# -896.7257649999118
# Num buys: 336
# Num sells: 348
# Num trades: 684
# Num wins: 533
# Num losses: 151
# Win streak: 30
# Loss streak: 4
# Avg pips risked: 0.0008641520467836385
# Trade length: 3.4195906432748537
# Remaining runs: 130
# Best reward so far: 523.2931924999853
#
# 220.76015250000046
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 9
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0018347222222222306
# Trade length: 38.72222222222222
# Remaining runs: 129
# Best reward so far: 523.2931924999853
#
# -140.5300599999892
# Num buys: 45
# Num sells: 44
# Num trades: 89
# Num wins: 29
# Num losses: 60
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0015945505617977593
# Trade length: 50.20224719101124
# Remaining runs: 128
# Best reward so far: 523.2931924999853
#
# -357.7657224999998
# Num buys: 49
# Num sells: 45
# Num trades: 94
# Num wins: 35
# Num losses: 59
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.001590797872340432
# Trade length: 35.361702127659576
# Remaining runs: 127
# Best reward so far: 523.2931924999853
#
# -613.609119999889
# Num buys: 123
# Num sells: 117
# Num trades: 240
# Num wins: 77
# Num losses: 163
# Win streak: 6
# Loss streak: 13
# Avg pips risked: 0.0008515833333333408
# Trade length: 24.3375
# Remaining runs: 126
# Best reward so far: 523.2931924999853
#
# -5214.421124999933
# Num buys: 332
# Num sells: 340
# Num trades: 672
# Num wins: 229
# Num losses: 443
# Win streak: 7
# Loss streak: 20
# Avg pips risked: 0.0008734077380952428
# Trade length: 18.83779761904762
# Remaining runs: 125
# Best reward so far: 523.2931924999853
#
# -2.7478749999994583
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 9
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0018347222222221775
# Trade length: 19.555555555555557
# Remaining runs: 124
# Best reward so far: 523.2931924999853
#
# -0.10759249999239984
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 16
# Num losses: 4
# Win streak: 10
# Loss streak: 2
# Avg pips risked: 0.001775500000000063
# Trade length: 2.85
# Remaining runs: 123
# Best reward so far: 523.2931924999853
#
# -5014.5924199999145
# Num buys: 291
# Num sells: 304
# Num trades: 595
# Num wins: 248
# Num losses: 347
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0008451428571428606
# Trade length: 11.08235294117647
# Remaining runs: 122
# Best reward so far: 523.2931924999853
#
# -535.9949299999778
# Num buys: 73
# Num sells: 71
# Num trades: 144
# Num wins: 67
# Num losses: 77
# Win streak: 9
# Loss streak: 9
# Avg pips risked: 0.0016596527777777827
# Trade length: 28.194444444444443
# Remaining runs: 121
# Best reward so far: 523.2931924999853
#
# -192.4688299999877
# Num buys: 46
# Num sells: 44
# Num trades: 90
# Num wins: 29
# Num losses: 61
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0015919444444444486
# Trade length: 50.27777777777778
# Remaining runs: 120
# Best reward so far: 523.2931924999853
#
# -1169.507659999913
# Num buys: 332
# Num sells: 355
# Num trades: 687
# Num wins: 531
# Num losses: 156
# Win streak: 28
# Loss streak: 4
# Avg pips risked: 0.0008633842794759939
# Trade length: 3.374090247452693
# Remaining runs: 119
# Best reward so far: 523.2931924999853
#
# -638.3637249999726
# Num buys: 80
# Num sells: 78
# Num trades: 158
# Num wins: 73
# Num losses: 85
# Win streak: 9
# Loss streak: 10
# Avg pips risked: 0.0016184493670886142
# Trade length: 27.71518987341772
# Remaining runs: 118
# Best reward so far: 523.2931924999853
#
# -6142.165812499758
# Num buys: 284
# Num sells: 299
# Num trades: 583
# Num wins: 186
# Num losses: 397
# Win streak: 5
# Loss streak: 17
# Avg pips risked: 0.00085411663807891
# Trade length: 17.754716981132077
# Remaining runs: 117
# Best reward so far: 523.2931924999853
#
# -7245.927579999807
# Num buys: 305
# Num sells: 323
# Num trades: 628
# Num wins: 163
# Num losses: 465
# Win streak: 4
# Loss streak: 22
# Avg pips risked: 0.000870509554140133
# Trade length: 26.480891719745223
# Remaining runs: 116
# Best reward so far: 523.2931924999853
#
# 373.53934375000944
# Num buys: 81
# Num sells: 79
# Num trades: 160
# Num wins: 134
# Num losses: 26
# Win streak: 15
# Loss streak: 3
# Avg pips risked: 0.0016218437500000072
# Trade length: 5.63125
# Remaining runs: 115
# Best reward so far: 523.2931924999853
#
# -6181.372989999849
# Num buys: 274
# Num sells: 282
# Num trades: 556
# Num wins: 146
# Num losses: 410
# Win streak: 5
# Loss streak: 17
# Avg pips risked: 0.0008595503597122365
# Trade length: 24.12230215827338
# Remaining runs: 114
# Best reward so far: 523.2931924999853
#
# -6138.946017499573
# Num buys: 272
# Num sells: 292
# Num trades: 564
# Num wins: 178
# Num losses: 386
# Win streak: 5
# Loss streak: 20
# Avg pips risked: 0.000850079787234049
# Trade length: 16.70921985815603
# Remaining runs: 113
# Best reward so far: 523.2931924999853
#
# -5848.966769999981
# Num buys: 337
# Num sells: 342
# Num trades: 679
# Num wins: 282
# Num losses: 397
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.0008614727540500766
# Trade length: 11.960235640648012
# Remaining runs: 112
# Best reward so far: 523.2931924999853
#
# 222.64864750001288
# Num buys: 78
# Num sells: 75
# Num trades: 153
# Num wins: 126
# Num losses: 27
# Win streak: 20
# Loss streak: 3
# Avg pips risked: 0.0016156862745098175
# Trade length: 5.888888888888889
# Remaining runs: 111
# Best reward so far: 523.2931924999853
#
# 112.97457000005235
# Num buys: 42
# Num sells: 39
# Num trades: 81
# Num wins: 28
# Num losses: 53
# Win streak: 5
# Loss streak: 7
# Avg pips risked: 0.001644444444444458
# Trade length: 51.876543209876544
# Remaining runs: 110
# Best reward so far: 523.2931924999853
#
# -5030.603554999891
# Num buys: 300
# Num sells: 303
# Num trades: 603
# Num wins: 252
# Num losses: 351
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0008429684908789439
# Trade length: 11.417910447761194
# Remaining runs: 109
# Best reward so far: 523.2931924999853
#
# -62.738528749966584
# Num buys: 45
# Num sells: 45
# Num trades: 90
# Num wins: 71
# Num losses: 19
# Win streak: 16
# Loss streak: 3
# Avg pips risked: 0.0015978333333333478
# Trade length: 4.211111111111111
# Remaining runs: 108
# Best reward so far: 523.2931924999853
#
# -3235.8768350000605
# Num buys: 332
# Num sells: 355
# Num trades: 687
# Num wins: 415
# Num losses: 272
# Win streak: 13
# Loss streak: 6
# Avg pips risked: 0.0008624090247452762
# Trade length: 6.2809315866084425
# Remaining runs: 107
# Best reward so far: 523.2931924999853
#
# -25.078682499991956
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 14
# Num losses: 4
# Win streak: 8
# Loss streak: 2
# Avg pips risked: 0.0018347222222222885
# Trade length: 3.111111111111111
# Remaining runs: 106
# Best reward so far: 523.2931924999853
#
# -1677.4217649998777
# Num buys: 129
# Num sells: 124
# Num trades: 253
# Num wins: 110
# Num losses: 143
# Win streak: 7
# Loss streak: 9
# Avg pips risked: 0.0008233201581027718
# Trade length: 9.648221343873518
# Remaining runs: 105
# Best reward so far: 523.2931924999853
#
# -100.96170999998611
# Num buys: 47
# Num sells: 44
# Num trades: 91
# Num wins: 30
# Num losses: 61
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0015890109890109934
# Trade length: 50.76923076923077
# Remaining runs: 104
# Best reward so far: 523.2931924999853
#
# 37.29006750001609
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 19
# Num losses: 4
# Win streak: 12
# Loss streak: 2
# Avg pips risked: 0.001750000000000092
# Trade length: 2.608695652173913
# Remaining runs: 103
# Best reward so far: 523.2931924999853
#
# -621.270659999971
# Num buys: 46
# Num sells: 46
# Num trades: 92
# Num wins: 40
# Num losses: 52
# Win streak: 6
# Loss streak: 6
# Avg pips risked: 0.001611413043478268
# Trade length: 25.72826086956522
# Remaining runs: 102
# Best reward so far: 523.2931924999853
#
# 112.3837537499961
# Num buys: 48
# Num sells: 46
# Num trades: 94
# Num wins: 77
# Num losses: 17
# Win streak: 18
# Loss streak: 3
# Avg pips risked: 0.0015834042553191192
# Trade length: 4.042553191489362
# Remaining runs: 101
# Best reward so far: 523.2931924999853
#
# -5475.795424999806
# Num buys: 279
# Num sells: 295
# Num trades: 574
# Num wins: 233
# Num losses: 341
# Win streak: 6
# Loss streak: 10
# Avg pips risked: 0.0008423083623693429
# Trade length: 10.898954703832752
# Remaining runs: 100
# Best reward so far: 523.2931924999853
#
# -3171.044914999904
# Num buys: 290
# Num sells: 307
# Num trades: 597
# Num wins: 356
# Num losses: 241
# Win streak: 12
# Loss streak: 8
# Avg pips risked: 0.0008331407035175998
# Trade length: 5.678391959798995
# Remaining runs: 99
# Best reward so far: 523.2931924999853
#
# -1926.6902699999248
# Num buys: 129
# Num sells: 125
# Num trades: 254
# Num wins: 108
# Num losses: 146
# Win streak: 7
# Loss streak: 7
# Avg pips risked: 0.0008262401574803166
# Trade length: 9.578740157480315
# Remaining runs: 98
# Best reward so far: 523.2931924999853
#
# -7771.260609999794
# Num buys: 300
# Num sells: 312
# Num trades: 612
# Num wins: 154
# Num losses: 458
# Win streak: 4
# Loss streak: 22
# Avg pips risked: 0.0008846160130719021
# Trade length: 27.008169934640524
# Remaining runs: 97
# Best reward so far: 523.2931924999853
#
# -425.9064849998564
# Num buys: 133
# Num sells: 123
# Num trades: 256
# Num wins: 198
# Num losses: 58
# Win streak: 15
# Loss streak: 4
# Avg pips risked: 0.0008293164062500302
# Trade length: 2.62890625
# Remaining runs: 96
# Best reward so far: 523.2931924999853
#
# -6313.3238699998055
# Num buys: 250
# Num sells: 267
# Num trades: 517
# Num wins: 132
# Num losses: 385
# Win streak: 5
# Loss streak: 19
# Avg pips risked: 0.0008702998065764084
# Trade length: 24.60348162475822
# Remaining runs: 95
# Best reward so far: 523.2931924999853
#
# -623.5716599999561
# Num buys: 44
# Num sells: 42
# Num trades: 86
# Num wins: 37
# Num losses: 49
# Win streak: 6
# Loss streak: 5
# Avg pips risked: 0.0016387790697674552
# Trade length: 25.976744186046513
# Remaining runs: 94
# Best reward so far: 523.2931924999853
#
# -473.0309599999704
# Num buys: 77
# Num sells: 74
# Num trades: 151
# Num wins: 48
# Num losses: 103
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.0016364238410596092
# Trade length: 72.03311258278146
# Remaining runs: 93
# Best reward so far: 523.2931924999853
#
# -4931.278249999904
# Num buys: 294
# Num sells: 309
# Num trades: 603
# Num wins: 253
# Num losses: 350
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.0008454643449419604
# Trade length: 11.538971807628524
# Remaining runs: 92
# Best reward so far: 523.2931924999853
#
# -1176.572844999852
# Num buys: 125
# Num sells: 119
# Num trades: 244
# Num wins: 147
# Num losses: 97
# Win streak: 9
# Loss streak: 5
# Avg pips risked: 0.000824405737704938
# Trade length: 5.090163934426229
# Remaining runs: 91
# Best reward so far: 523.2931924999853
#
# -283.01990249997294
# Num buys: 82
# Num sells: 78
# Num trades: 160
# Num wins: 103
# Num losses: 57
# Win streak: 9
# Loss streak: 4
# Avg pips risked: 0.0016284062500000168
# Trade length: 12.65
# Remaining runs: 90
# Best reward so far: 523.2931924999853
#
# -2846.6533724998826
# Num buys: 290
# Num sells: 308
# Num trades: 598
# Num wins: 361
# Num losses: 237
# Win streak: 12
# Loss streak: 8
# Avg pips risked: 0.0008400334448160628
# Trade length: 5.79933110367893
# Remaining runs: 89
# Best reward so far: 523.2931924999853
#
# -911.1095399997769
# Num buys: 119
# Num sells: 118
# Num trades: 237
# Num wins: 74
# Num losses: 163
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.00084837552742617
# Trade length: 24.248945147679326
# Remaining runs: 88
# Best reward so far: 523.2931924999853
#
# -1876.0038499998498
# Num buys: 124
# Num sells: 119
# Num trades: 243
# Num wins: 103
# Num losses: 140
# Win streak: 7
# Loss streak: 9
# Avg pips risked: 0.0008258024691358093
# Trade length: 9.358024691358025
# Remaining runs: 87
# Best reward so far: 523.2931924999853
#
# -593.3283699999912
# Num buys: 77
# Num sells: 78
# Num trades: 155
# Num wins: 58
# Num losses: 97
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0016240645161290333
# Trade length: 49.748387096774195
# Remaining runs: 86
# Best reward so far: 523.2931924999853
#
# -5824.861239999614
# Num buys: 277
# Num sells: 293
# Num trades: 570
# Num wins: 183
# Num losses: 387
# Win streak: 7
# Loss streak: 14
# Avg pips risked: 0.0008487456140350954
# Trade length: 17.41578947368421
# Remaining runs: 85
# Best reward so far: 523.2931924999853
#
# -1011.359609999986
# Num buys: 76
# Num sells: 74
# Num trades: 150
# Num wins: 44
# Num losses: 106
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.0016233666666666724
# Trade length: 70.0
# Remaining runs: 84
# Best reward so far: 523.2931924999853
#
# -2.146627499997282
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 8
# Num losses: 12
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017665000000000111
# Trade length: 27.0
# Remaining runs: 83
# Best reward so far: 523.2931924999853
#
# -1076.4663774998903
# Num buys: 130
# Num sells: 124
# Num trades: 254
# Num wins: 155
# Num losses: 99
# Win streak: 12
# Loss streak: 5
# Avg pips risked: 0.0008219881889763929
# Trade length: 5.224409448818897
# Remaining runs: 82
# Best reward so far: 523.2931924999853
#
# 220.76015250000046
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 9
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0018347222222222306
# Trade length: 38.72222222222222
# Remaining runs: 81
# Best reward so far: 523.2931924999853
#
# 285.544851249993
# Num buys: 80
# Num sells: 78
# Num trades: 158
# Num wins: 131
# Num losses: 27
# Win streak: 18
# Loss streak: 3
# Avg pips risked: 0.0016322784810126599
# Trade length: 5.8354430379746836
# Remaining runs: 80
# Best reward so far: 523.2931924999853
#
# 45.93508000000669
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 8
# Num losses: 15
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0017500000000000052
# Trade length: 34.869565217391305
# Remaining runs: 79
# Best reward so far: 523.2931924999853
#
# -803.9562999997743
# Num buys: 116
# Num sells: 116
# Num trades: 232
# Num wins: 73
# Num losses: 159
# Win streak: 6
# Loss streak: 13
# Avg pips risked: 0.0008534051724138036
# Trade length: 24.219827586206897
# Remaining runs: 78
# Best reward so far: 523.2931924999853
#
# ...
# Remaining runs: 64
# Best reward so far: 523.2931924999853
#
# -7252.631769999825
# Num buys: 316
# Num sells: 321
# Num trades: 637
# Num wins: 166
# Num losses: 471
# Win streak: 5
# Loss streak: 22
# Avg pips risked: 0.0008677080062794415
# Trade length: 26.03767660910518
# Remaining runs: 63
# Best reward so far: 523.2931924999853
#
# -2942.7780174999466
# Num buys: 292
# Num sells: 308
# Num trades: 600
# Num wins: 361
# Num losses: 239
# Win streak: 11
# Loss streak: 8
# Avg pips risked: 0.0008408750000000038
# Trade length: 5.723333333333334
# Remaining runs: 62
# Best reward so far: 523.2931924999853
#
# -719.8189649999649
# Num buys: 46
# Num sells: 46
# Num trades: 92
# Num wins: 39
# Num losses: 53
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0015926086956521833
# Trade length: 24.402173913043477
# Remaining runs: 61
# Best reward so far: 523.2931924999853
#
# -658.444449999773
# Num buys: 116
# Num sells: 113
# Num trades: 229
# Num wins: 73
# Num losses: 156
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008491703056768654
# Trade length: 24.921397379912662
# Remaining runs: 60
# Best reward so far: 523.2931924999853
#
# -207.17789499999236
# Num buys: 46
# Num sells: 45
# Num trades: 91
# Num wins: 35
# Num losses: 56
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0016144505494505561
# Trade length: 36.934065934065934
# Remaining runs: 59
# Best reward so far: 523.2931924999853
#
# -5912.878815000031
# Num buys: 341
# Num sells: 341
# Num trades: 682
# Num wins: 283
# Num losses: 399
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0008712683284457483
# Trade length: 12.065982404692082
# Remaining runs: 58
# Best reward so far: 523.2931924999853
#
# -5835.273789999806
# Num buys: 272
# Num sells: 280
# Num trades: 552
# Num wins: 147
# Num losses: 405
# Win streak: 5
# Loss streak: 17
# Avg pips risked: 0.0008600090579710219
# Trade length: 24.42753623188406
# Remaining runs: 57
# Best reward so far: 523.2931924999853
#
# -3463.677117500176
# Num buys: 345
# Num sells: 345
# Num trades: 690
# Num wins: 414
# Num losses: 276
# Win streak: 13
# Loss streak: 6
# Avg pips risked: 0.0008667463768115974
# Trade length: 6.282608695652174
# Remaining runs: 56
# Best reward so far: 523.2931924999853
#
# 445.48734000000593
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 9
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0018347222222222267
# Trade length: 43.888888888888886
# Remaining runs: 55
# Best reward so far: 523.2931924999853
#
# -510.05057750000947
# Num buys: 47
# Num sells: 45
# Num trades: 92
# Num wins: 33
# Num losses: 59
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.001592880434782612
# Trade length: 35.5
# Remaining runs: 54
# Best reward so far: 523.2931924999853
#
# -6326.982959999817
# Num buys: 276
# Num sells: 286
# Num trades: 562
# Num wins: 147
# Num losses: 415
# Win streak: 5
# Loss streak: 17
# Avg pips risked: 0.0008624110320284758
# Trade length: 24.505338078291814
# Remaining runs: 53
# Best reward so far: 523.2931924999853
#
# -632.7331712498552
# Num buys: 296
# Num sells: 314
# Num trades: 610
# Num wins: 478
# Num losses: 132
# Win streak: 19
# Loss streak: 5
# Avg pips risked: 0.0008424754098360744
# Trade length: 2.9901639344262296
# Remaining runs: 52
# Best reward so far: 523.2931924999853
#
# -112.96950374996231
# Num buys: 119
# Num sells: 117
# Num trades: 236
# Num wins: 187
# Num losses: 49
# Win streak: 19
# Loss streak: 3
# Avg pips risked: 0.000837542372881367
# Trade length: 2.6313559322033897
# Remaining runs: 51
# Best reward so far: 523.2931924999853
#
# -2179.9808049999674
# Num buys: 135
# Num sells: 124
# Num trades: 259
# Num wins: 108
# Num losses: 151
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0008316988416988456
# Trade length: 9.91891891891892
# Remaining runs: 50
# Best reward so far: 523.2931924999853
#
# -5833.535969999853
# Num buys: 272
# Num sells: 280
# Num trades: 552
# Num wins: 147
# Num losses: 405
# Win streak: 5
# Loss streak: 18
# Avg pips risked: 0.0008531521739130512
# Trade length: 23.9981884057971
# Remaining runs: 49
# Best reward so far: 523.2931924999853
#
# -5934.454747499757
# Num buys: 286
# Num sells: 303
# Num trades: 589
# Num wins: 190
# Num losses: 399
# Win streak: 5
# Loss streak: 17
# Avg pips risked: 0.0008550679117147775
# Trade length: 17.984719864176572
# Remaining runs: 48
# Best reward so far: 523.2931924999853
#
# -143.22583999994552
# Num buys: 66
# Num sells: 67
# Num trades: 133
# Num wins: 44
# Num losses: 89
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.0016668796992481277
# Trade length: 68.94736842105263
# Remaining runs: 47
# Best reward so far: 523.2931924999853
#
# -1251.8967574998285
# Num buys: 118
# Num sells: 117
# Num trades: 235
# Num wins: 140
# Num losses: 95
# Win streak: 9
# Loss streak: 5
# Avg pips risked: 0.0008377872340425747
# Trade length: 5.314893617021276
# Remaining runs: 46
# Best reward so far: 523.2931924999853
#
# -149.9792649999917
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 10
# Num losses: 8
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0018180555555555372
# Trade length: 7.5
# Remaining runs: 45
# Best reward so far: 523.2931924999853
#
# -175.0872699999885
# Num buys: 12
# Num sells: 8
# Num trades: 20
# Num wins: 11
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.001766499999999982
# Trade length: 7.0
# Remaining runs: 44
# Best reward so far: 523.2931924999853
#
# -3267.7955325000357
# Num buys: 328
# Num sells: 349
# Num trades: 677
# Num wins: 408
# Num losses: 269
# Win streak: 12
# Loss streak: 6
# Avg pips risked: 0.0008566838995568746
# Trade length: 6.335302806499262
# Remaining runs: 43
# Best reward so far: 523.2931924999853
#
# -868.3530099999796
# Num buys: 74
# Num sells: 76
# Num trades: 150
# Num wins: 45
# Num losses: 105
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.0016373666666666716
# Trade length: 70.56666666666666
# Remaining runs: 42
# Best reward so far: 523.2931924999853
#
# -7821.775569999987
# Num buys: 321
# Num sells: 327
# Num trades: 648
# Num wins: 166
# Num losses: 482
# Win streak: 4
# Loss streak: 22
# Avg pips risked: 0.00087993055555556
# Trade length: 27.89814814814815
# Remaining runs: 41
# Best reward so far: 523.2931924999853
#
# -1177.642539999889
# Num buys: 125
# Num sells: 122
# Num trades: 247
# Num wins: 149
# Num losses: 98
# Win streak: 9
# Loss streak: 5
# Avg pips risked: 0.0008287044534413145
# Trade length: 5.165991902834008
# Remaining runs: 40
# Best reward so far: 523.2931924999853
#
# -99.56967499999342
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 8
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.0018180555555555127
# Trade length: 11.222222222222221
# Remaining runs: 39
# Best reward so far: 523.2931924999853
#
# -5906.601697499766
# Num buys: 282
# Num sells: 299
# Num trades: 581
# Num wins: 187
# Num losses: 394
# Win streak: 5
# Loss streak: 17
# Avg pips risked: 0.0008535542168674778
# Trade length: 18.001721170395868
# Remaining runs: 38
# Best reward so far: 523.2931924999853
#
# -25.078682499991956
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 14
# Num losses: 4
# Win streak: 8
# Loss streak: 2
# Avg pips risked: 0.0018347222222222885
# Trade length: 3.111111111111111
# Remaining runs: 37
# Best reward so far: 523.2931924999853
#
# -1201.3939674999153
# Num buys: 130
# Num sells: 125
# Num trades: 255
# Num wins: 154
# Num losses: 101
# Win streak: 8
# Loss streak: 5
# Avg pips risked: 0.0008249019607843261
# Trade length: 5.243137254901961
# Remaining runs: 36
# Best reward so far: 523.2931924999853
#
# -5728.455097499925
# Num buys: 332
# Num sells: 338
# Num trades: 670
# Num wins: 224
# Num losses: 446
# Win streak: 6
# Loss streak: 22
# Avg pips risked: 0.0008733955223880672
# Trade length: 18.571641791044776
# Remaining runs: 35
# Best reward so far: 523.2931924999853
#
# -124.88508999999132
# Num buys: 11
# Num sells: 8
# Num trades: 19
# Num wins: 11
# Num losses: 8
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0017921052631578785
# Trade length: 8.157894736842104
# Remaining runs: 34
# Best reward so far: 523.2931924999853
#
# -99.56967499999342
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 8
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.0018180555555555127
# Trade length: 11.222222222222221
# Remaining runs: 33
# Best reward so far: 523.2931924999853
#
# -5227.198269999937
# Num buys: 283
# Num sells: 302
# Num trades: 585
# Num wins: 241
# Num losses: 344
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0008391538461538479
# Trade length: 11.249572649572649
# Remaining runs: 32
# Best reward so far: 523.2931924999853
#
# -29.277617499994975
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 9
# Num losses: 14
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017500000000000146
# Trade length: 28.17391304347826
# Remaining runs: 31
# Best reward so far: 523.2931924999853
#
# -658.8805050000046
# Num buys: 78
# Num sells: 76
# Num trades: 154
# Num wins: 57
# Num losses: 97
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.001641136363636366
# Trade length: 45.36363636363637
# Remaining runs: 30
# Best reward so far: 523.2931924999853
#
# -719.7363599999641
# Num buys: 45
# Num sells: 45
# Num trades: 90
# Num wins: 38
# Num losses: 52
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0016018888888888977
# Trade length: 24.22222222222222
# Remaining runs: 29
# Best reward so far: 523.2931924999853
#
# 98.78243250000267
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 8
# Num losses: 10
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.0018180555555555697
# Trade length: 27.166666666666668
# Remaining runs: 28
# Best reward so far: 523.2931924999853
#
# -7552.083699999908
# Num buys: 316
# Num sells: 327
# Num trades: 643
# Num wins: 166
# Num losses: 477
# Win streak: 5
# Loss streak: 22
# Avg pips risked: 0.0008707698289269099
# Trade length: 26.709175738724728
# Remaining runs: 27
# Best reward so far: 523.2931924999853
#
# -454.49312249995455
# Num buys: 45
# Num sells: 45
# Num trades: 90
# Num wins: 54
# Num losses: 36
# Win streak: 7
# Loss streak: 4
# Avg pips risked: 0.0015978333333333378
# Trade length: 11.733333333333333
# Remaining runs: 26
# Best reward so far: 523.2931924999853
#
# -25.15446999998663
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 14
# Num losses: 4
# Win streak: 8
# Loss streak: 2
# Avg pips risked: 0.0018180555555556606
# Trade length: 3.0
# Remaining runs: 25
# Best reward so far: 523.2931924999853
#
# 234.81062875000634
# Num buys: 73
# Num sells: 71
# Num trades: 144
# Num wins: 119
# Num losses: 25
# Win streak: 17
# Loss streak: 2
# Avg pips risked: 0.0016587847222222383
# Trade length: 5.6875
# Remaining runs: 24
# Best reward so far: 523.2931924999853
#
# -37.65495999997555
# Num buys: 46
# Num sells: 46
# Num trades: 92
# Num wins: 73
# Num losses: 19
# Win streak: 17
# Loss streak: 3
# Avg pips risked: 0.0015886413043478289
# Trade length: 4.141304347826087
# Remaining runs: 23
# Best reward so far: 523.2931924999853
#
# -6391.5122524998715
# Num buys: 328
# Num sells: 335
# Num trades: 663
# Num wins: 216
# Num losses: 447
# Win streak: 9
# Loss streak: 21
# Avg pips risked: 0.000861764705882358
# Trade length: 18.508295625942687
# Remaining runs: 22
# Best reward so far: 523.2931924999853
#
# -1975.432224999881
# Num buys: 127
# Num sells: 124
# Num trades: 251
# Num wins: 106
# Num losses: 145
# Win streak: 7
# Loss streak: 9
# Avg pips risked: 0.0008249601593625536
# Trade length: 9.681274900398407
# Remaining runs: 21
# Best reward so far: 523.2931924999853
#
# -379.678229999967
# Num buys: 47
# Num sells: 46
# Num trades: 93
# Num wins: 57
# Num losses: 36
# Win streak: 8
# Loss streak: 4
# Avg pips risked: 0.0015861827956989278
# Trade length: 11.129032258064516
# Remaining runs: 20
# Best reward so far: 523.2931924999853
#
# -930.8051999999542
# Num buys: 81
# Num sells: 79
# Num trades: 160
# Num wins: 71
# Num losses: 89
# Win streak: 9
# Loss streak: 10
# Avg pips risked: 0.0016220000000000067
# Trade length: 25.63125
# Remaining runs: 19
# Best reward so far: 523.2931924999853
#
# -922.6230412499368
# Num buys: 294
# Num sells: 308
# Num trades: 602
# Num wins: 467
# Num losses: 135
# Win streak: 17
# Loss streak: 3
# Avg pips risked: 0.0008412375415282409
# Trade length: 2.8870431893687707
# Remaining runs: 18
# Best reward so far: 523.2931924999853
#
# -1750.4713474998182
# Num buys: 114
# Num sells: 117
# Num trades: 231
# Num wins: 79
# Num losses: 152
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008584199134199182
# Trade length: 16.748917748917748
# Remaining runs: 17
# Best reward so far: 523.2931924999853
#
# -6528.417639999768
# Num buys: 264
# Num sells: 275
# Num trades: 539
# Num wins: 138
# Num losses: 401
# Win streak: 5
# Loss streak: 20
# Avg pips risked: 0.0008552133580705066
# Trade length: 23.8126159554731
# Remaining runs: 16
# Best reward so far: 523.2931924999853
#
# -361.99020249999194
# Num buys: 80
# Num sells: 78
# Num trades: 158
# Num wins: 61
# Num losses: 97
# Win streak: 5
# Loss streak: 7
# Avg pips risked: 0.0016435443037974714
# Trade length: 47.13291139240506
# Remaining runs: 15
# Best reward so far: 523.2931924999853
#
# -1107.5204762499925
# Num buys: 321
# Num sells: 326
# Num trades: 647
# Num wins: 500
# Num losses: 147
# Win streak: 22
# Loss streak: 8
# Avg pips risked: 0.0008714605873261234
# Trade length: 3.394126738794436
# Remaining runs: 14
# Best reward so far: 523.2931924999853
#
# -668.3569349999649
# Num buys: 47
# Num sells: 46
# Num trades: 93
# Num wins: 40
# Num losses: 53
# Win streak: 6
# Loss streak: 6
# Avg pips risked: 0.0015901075268817254
# Trade length: 24.043010752688172
# Remaining runs: 13
# Best reward so far: 523.2931924999853
#
# -745.8908099998495
# Num buys: 289
# Num sells: 302
# Num trades: 591
# Num wins: 461
# Num losses: 130
# Win streak: 18
# Loss streak: 3
# Avg pips risked: 0.0008344923857868103
# Trade length: 2.8781725888324874
# Remaining runs: 12
# Best reward so far: 523.2931924999853
#
# -355.79977499996653
# Num buys: 48
# Num sells: 46
# Num trades: 94
# Num wins: 58
# Num losses: 36
# Win streak: 8
# Loss streak: 4
# Avg pips risked: 0.0015834042553191522
# Trade length: 11.22340425531915
# Remaining runs: 11
# Best reward so far: 523.2931924999853
#
# -6149.893109999985
# Num buys: 326
# Num sells: 345
# Num trades: 671
# Num wins: 275
# Num losses: 396
# Win streak: 10
# Loss streak: 11
# Avg pips risked: 0.0008587555886736237
# Trade length: 11.758569299552907
# Remaining runs: 10
# Best reward so far: 523.2931924999853
#
# -538.2184599998608
# Num buys: 139
# Num sells: 123
# Num trades: 262
# Num wins: 201
# Num losses: 61
# Win streak: 16
# Loss streak: 5
# Avg pips risked: 0.0008288931297710207
# Trade length: 2.599236641221374
# Remaining runs: 9
# Best reward so far: 523.2931924999853
#
# 99.8366662500001
# Num buys: 47
# Num sells: 46
# Num trades: 93
# Num wins: 76
# Num losses: 17
# Win streak: 18
# Loss streak: 3
# Avg pips risked: 0.0015861827956988991
# Trade length: 4.064516129032258
# Remaining runs: 8
# Best reward so far: 523.2931924999853
#
# -1.6429149999994586
# Num buys: 10
# Num sells: 8
# Num trades: 18
# Num wins: 9
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0018347222222221775
# Trade length: 19.555555555555557
# Remaining runs: 7
# Best reward so far: 523.2931924999853
#
# -313.68573124987955
# Num buys: 126
# Num sells: 119
# Num trades: 245
# Num wins: 191
# Num losses: 54
# Win streak: 16
# Loss streak: 4
# Avg pips risked: 0.0008242244897959536
# Trade length: 2.4938775510204083
# Remaining runs: 6
# Best reward so far: 523.2931924999853
#
# -149.7848449999894
# Num buys: 15
# Num sells: 8
# Num trades: 23
# Num wins: 10
# Num losses: 13
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0017499999999999569
# Trade length: 11.26086956521739
# Remaining runs: 5
# Best reward so far: 523.2931924999853
#
# -190.42395999998882
# Num buys: 44
# Num sells: 43
# Num trades: 87
# Num wins: 28
# Num losses: 59
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.001605114942528741
# Trade length: 50.05747126436781
# Remaining runs: 4
# Best reward so far: 523.2931924999853
#
# -373.64993999998154
# Num buys: 71
# Num sells: 70
# Num trades: 141
# Num wins: 54
# Num losses: 87
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.001667446808510642
# Trade length: 47.808510638297875
# Remaining runs: 3
# Best reward so far: 523.2931924999853
#
# -432.2615899999721
# Num buys: 81
# Num sells: 79
# Num trades: 160
# Num wins: 101
# Num losses: 59
# Win streak: 9
# Loss streak: 7
# Avg pips risked: 0.0016218437500000154
# Trade length: 12.95
# Remaining runs: 2
# Best reward so far: 523.2931924999853
#
# -7500.974979999966
# Num buys: 313
# Num sells: 329
# Num trades: 642
# Num wins: 166
# Num losses: 476
# Win streak: 5
# Loss streak: 24
# Avg pips risked: 0.0008759968847352073
# Trade length: 26.71651090342679
# Remaining runs: 1
# Best reward so far: 523.2931924999853
#
# -2048.053684999847
# Num buys: 120
# Num sells: 122
# Num trades: 242
# Num wins: 81
# Num losses: 161
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0008485330578512466
# Trade length: 16.363636363636363
# Remaining runs: 0
# Best reward so far: 523.2931924999853

# %%
# EUR/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(n_bars))
print('Best adx cutoff: ' + str(best_adx_cutoff))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 881.4109839285644
# Best risk/reward ratio: 1.5
# Best spread: 0.1
# Best atr multiplier: 1.5
# Best n bars: 5
# Best adx cutoff: 25
# -----------------------
# Top results:
# {'reward': 145, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_bars': 2, 'adx_cutoff': 25}
# {'reward': 190, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_bars': 3, 'adx_cutoff': 20}
# {'reward': 787, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_bars': 2, 'adx_cutoff': 20}
# {'reward': 172, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 2, 'adx_cutoff': 20}
# {'reward': 273, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 2, 'adx_cutoff': 25}
# {'reward': 279, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 5, 'adx_cutoff': 15}
# {'reward': 99, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 2, 'adx_cutoff': 25}
# {'reward': 560, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_bars': 2, 'adx_cutoff': 25}
# {'reward': 416, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_bars': 4, 'adx_cutoff': 25}
# {'reward': 221, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_bars': 4, 'adx_cutoff': 15}
# {'reward': 98, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 2, 'adx_cutoff': 20}
# {'reward': 99, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 2, 'adx_cutoff': 20}
# {'reward': 147, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 0.5, 'n_bars': 2, 'adx_cutoff': 25}
# {'reward': 269, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_bars': 2, 'adx_cutoff': 20}
# {'reward': 243, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_bars': 5, 'adx_cutoff': 15}
# {'reward': 712, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_bars': 2, 'adx_cutoff': 25}
# {'reward': 881, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_bars': 2, 'adx_cutoff': 25}
# {'reward': 99, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.0, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 207, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_bars': 5, 'adx_cutoff': 20}
# {'reward': 423, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_bars': 2, 'adx_cutoff': 20}

# %%
# GBP/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 4223.3566550000905
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 4124, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 2249, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 2668, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 3674, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 2172, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 1450, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 4223, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 2473, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 2275, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}

# %%
# AUD/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1876.0760714286596
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 95, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 1798, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 1876, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 1650, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 1700, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 1497, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 50, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 850, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 1199, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}

# %%
# USD/CAD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 4048.6535253571433
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 1
# -----------------------
# Top results:
# {'reward': 2053, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 716, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 4048, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 636, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 523, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 2977, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 3480, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 2039, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 2445, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}

# %%
# USD/JPY
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 250758.18965857464
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 1
# -----------------------
# Top results:
# {'reward': 145619, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 192316, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 37162, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 176101, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 225827, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 250758, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 206984, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 135342, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 148785, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}

# %%
# USD/CHF
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1456.2561146429143
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 1456, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 1316, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 225, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 1034, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 207, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 690, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 296, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 302, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 1339, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}

# %%
# NZD/USD
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 1074.2768450000149
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.0
# Best n bars: 3
# -----------------------
# Top results:
# {'reward': 725, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 1074, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': -25, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
# {'reward': 624, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 750, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 449, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 549, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 774, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 1049, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}

# %%
# GBP/CHF
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n minutes: ' + str(best_n_minutes))
print('Best adx cutoff: ' + str(best_adx_cutoff))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 527.8893594643564
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n minutes: 5
# Best adx cutoff: 25
# -----------------------
# Top results:
# {'reward': 300, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 10, 'adx_cutoff': 15}
# {'reward': 527, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 25}
# {'reward': 367, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 15}
# {'reward': 339, 'ratio': 0.5, 'spread_val': 0.1, 'atr_multiplier': 2.5, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 371, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 25}
# {'reward': 488, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 5, 'adx_cutoff': 20}
# {'reward': 244, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 15, 'adx_cutoff': 15}
# {'reward': 433, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 2.5, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 302, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 20}
# {'reward': 485, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 15, 'adx_cutoff': 15}
# {'reward': 243, 'ratio': 1.0, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 10, 'adx_cutoff': 25}
# {'reward': 366, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 5, 'adx_cutoff': 20}
# {'reward': 317, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 10, 'adx_cutoff': 25}
# {'reward': 336, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 3.0, 'n_minutes': 10, 'adx_cutoff': 20}
# {'reward': 399, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 2.5, 'n_minutes': 15, 'adx_cutoff': 25}
# {'reward': 241, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 20}
# {'reward': 402, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 15}
# {'reward': 189, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 25}
# {'reward': 319, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'adx_cutoff': 20}
# {'reward': 395, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 10, 'adx_cutoff': 25}

# %%
# EUR/JPY
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n bars: ' + str(best_n_bars))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 403452.127566436
# Best risk/reward ratio: 0.5
# Best spread: 0.2
# Best atr multiplier: 1.5
# Best n bars: 2
# -----------------------
# Top results:
# {'reward': 222544, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 1}
# {'reward': 127405, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 2}
# {'reward': 285747, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 1}
# {'reward': 171298, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 2}
# {'reward': 199570, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 3}
# {'reward': 403452, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_bars': 2}
# {'reward': 178521, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 1}
# {'reward': 100253, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_bars': 3}
# {'reward': 30516, 'ratio': 0.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_bars': 3}
