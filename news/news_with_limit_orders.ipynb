# %%
import numpy as np
import pandas as pd
import random

# %%
file_path = '../bar_movement/data/'

# %%
currency_pair = 'Eur_Usd'

# %%
df = pd.read_csv(file_path + f'Oanda_{currency_pair}_M5_2021-2022.csv')
df.Date = pd.to_datetime(df.Date, utc=True)
df.reset_index(drop=True, inplace=True)

# %%
def atr(highs, lows, closes, lookback=14):
    high_low = highs - lows
    high_close = np.abs(highs - closes.shift())
    low_close = np.abs(lows - closes.shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = np.max(ranges, axis=1)

    return true_range.rolling(lookback).sum() / lookback

# %%
df['atr'] = atr(df['Mid_High'], df['Mid_Low'], df['Mid_Close'])

df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
currency1, currency2 = currency_pair.split('_')
currency1, currency2 = currency1.upper(), currency2.upper()
news = pd.read_csv(file_path + 'events.csv')
news.Date = pd.to_datetime(news.Date, utc=True)
news = news.loc[(news['Currency_Code'] == currency1) | (news['Currency_Code'] == currency2)]
news.drop(news[(news['Impact'] != 'low') & (news['Impact'] != 'med') & (news['Impact'] != 'high')].index, inplace=True)
news.loc[news['Impact'] == 'low', 'Impact'] = 1
news.loc[news['Impact'] == 'med', 'Impact'] = 2
news.loc[news['Impact'] == 'high', 'Impact'] = 3
news['Impact'] = pd.to_numeric(news['Impact'])
news.drop(['Currency_Code', 'Actual', 'Previous', 'Actual_Val', 'Forecast_Val', 'Previous_Val'], axis=1, inplace=True)
by_date = news.groupby('Date')
impact = by_date['Impact'].max().reset_index()
news = news.iloc[0:0]
news['Date'], news['Impact'] = impact['Date'], impact['Impact']
news.tail()
# Out:
# /var/folders/y1/r6lw81g960n148db75yhq7140000gn/T/ipykernel_8299/521418843.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news['Date'], news['Impact'] = impact['Date'], impact['Impact']
#                           Date  Impact
# 7828 2022-09-09 00:00:00+00:00       2
# 7829 2022-09-09 06:45:00+00:00       2
# 7830 2022-09-09 14:00:00+00:00       2
# 7831 2022-09-09 16:00:00+00:00       2
# 7832 2022-09-09 17:00:00+00:00       1

# %%
df = pd.merge(df, news, how='left', on='Date')
df.head()
# Out:
#                        Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2021-04-01 07:05:00+00:00   1.17246   1.17252  1.17206    1.17238   1.17258
# 1 2021-04-01 07:10:00+00:00   1.17239   1.17334  1.17239    1.17316   1.17252
# 2 2021-04-01 07:15:00+00:00   1.17315   1.17321  1.17274    1.17297   1.17329
# 3 2021-04-01 07:20:00+00:00   1.17298   1.17362  1.17263    1.17362   1.17311
# 4 2021-04-01 07:25:00+00:00   1.17364   1.17420  1.17352    1.17414   1.17377
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close  \
# 0   1.17265  1.17218    1.17251   1.17252   1.17258  1.17212    1.17244
# 1   1.17348  1.17252    1.17330   1.17246   1.17341  1.17246    1.17323
# 2   1.17334  1.17287    1.17310   1.17322   1.17328  1.17281    1.17304
# 3   1.17375  1.17276    1.17375   1.17304   1.17368  1.17270    1.17368
# 4   1.17433  1.17366    1.17427   1.17370   1.17426  1.17359    1.17420
#
#    Volume       atr  Impact
# 0     524  0.000484     NaN
# 1     662  0.000531     NaN
# 2     490  0.000520     NaN
# 3     548  0.000574     NaN
# 4     698  0.000598     NaN

# %%
value_per_pip = 1.0
amounts_per_day = [-0.00008, -0.0001, -0.00012]
rounding = 5 if 'Jpy' not in currency_pair else 3
divider = 10000 if 'Jpy' not in currency_pair else 100

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee

def get_n_units(open_price, stop_loss, mid_open, currency_pair):
    _, second = currency_pair.split('_')
  
    pips_to_risk = abs(open_price - stop_loss)
    pips_to_risk_calc = pips_to_risk * 10000 if second != 'Jpy' else pips_to_risk * 100

    if second == 'Usd':
        per_pip = 0.0001

    else:
        per_pip = 0.0001 / mid_open if second != 'Jpy' else 0.01 / mid_open

    n_units = int(50 / (pips_to_risk_calc * per_pip))

    return n_units

def run_simulation(risk_reward_ratio, spread_cutoff, atr_multiplier, n_minutes, impact_cutoff):
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    lo = None
    trade = None
    trade_lengths = []

    for i in range(1, len(df)):
        curr_date = df.loc[df.index[i], 'Date']
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close, curr_mid_open, curr_mid_low = \
            df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                                'Ask_Low', 'Ask_Close', 'Mid_Open', 'Mid_Low']]
        ask_low, bid_high, atr = df.loc[df.index[i - 1], ['Ask_Low', 'Bid_High', 'atr']]
        impact = df.loc[df.index[i], 'Impact']
        important_news = not np.isnan(impact) and impact >= impact_cutoff

        if lo is not None:
            minutes_elapsed = (curr_date - lo['start_date']).total_seconds() / 60
            stop_signal = minutes_elapsed >= n_minutes

            if stop_signal:
                lo = None

        if lo is None and trade is None and important_news:
            range_high, range_low = bid_high + (atr * atr_multiplier), ask_low - (atr * atr_multiplier)
            rang = abs(float(range_high) - float(range_low))
            pips_gain = (rang / 2) * risk_reward_ratio
            pips_to_risk = pips_gain / risk_reward_ratio
            
            if range_high > range_low and spread <= pips_to_risk * spread_cutoff:
                buy_open_price = float(range_low)
                buy_stop_gain = curr_ao
                buy_pips_gained = buy_stop_gain - buy_open_price
                buy_pips_to_risk = buy_pips_gained / risk_reward_ratio
                buy_pullback = buy_open_price - buy_pips_to_risk
                buy_stop_loss = round(buy_pullback, 5)
                buy_mo = buy_open_price - (spread / 2)
                buy_n_units = get_n_units(buy_open_price, buy_stop_loss, buy_mo, currency_pair)

                sell_open_price = float(range_high)
                sell_stop_gain = curr_bo
                sell_pips_gained = sell_open_price - sell_stop_gain
                sell_pips_to_risk = sell_pips_gained / risk_reward_ratio
                sell_pullback = sell_open_price + sell_pips_to_risk
                sell_stop_loss = round(sell_pullback, 5)
                sell_mo = sell_open_price + (spread / 2)
                sell_n_units = get_n_units(sell_open_price, sell_stop_loss, sell_mo, currency_pair)

                lo = {'buy_open_price': buy_open_price, 'buy_stop_gain': buy_stop_gain, 'buy_stop_loss': buy_stop_loss, 'buy_n_units': buy_n_units, 
                               'sell_open_price': sell_open_price, 'sell_stop_gain': sell_stop_gain, 'sell_stop_loss': sell_stop_loss, 'sell_n_units': sell_n_units, 'start_date': curr_date}

        if trade is None and lo is not None:
            place_buy = curr_ask_low <= lo['buy_open_price']
            place_sell = curr_bid_high >= lo['sell_open_price']

            if place_buy:
                open_price = lo['buy_open_price']
                stop_gain = lo['buy_stop_gain']
                pips_gained = stop_gain - open_price
                curr_pips_to_risk = pips_gained / risk_reward_ratio
                stop_loss = lo['buy_stop_loss']

                if stop_loss < open_price and stop_gain > open_price:
                    n_units = lo['buy_n_units']

                    trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                    'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                    'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None, 'index': i}

                    n_buys += 1

                    pips_risked.append(curr_pips_to_risk)
                    
                    lo = None

            elif place_sell:
                open_price = lo['sell_open_price']
                stop_gain = lo['sell_stop_gain']
                pips_gained = open_price - stop_gain
                curr_pips_to_risk = pips_gained / risk_reward_ratio
                stop_loss = lo['sell_stop_loss']

                if stop_loss > open_price and stop_gain < open_price:
                    n_units = lo['sell_n_units']

                    trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                            'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                            'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None, 'index': i}

                    n_sells += 1

                    pips_risked.append(curr_pips_to_risk)

                    lo = None

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
            trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
            trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
            trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
            trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
            reward += trade_amount
            day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

            n_wins += 1 if trade_amount > 0 else 0
            n_losses += 1 if trade_amount < 0 else 0
            curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
            curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1
            trade_lengths.append(i - trade['index'] + 1)

            if curr_win_streak > win_streak:
              win_streak = curr_win_streak

            if curr_loss_streak > loss_streak:
              loss_streak = curr_loss_streak

            trade = None

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked, trade_lengths

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
risk_reward_ratio_vals = [1.0, 1.5, 2.0]
spread_cutoffs = [0.10, 0.20]
atr_multipliers = [1.0, 1.5, 2.0, 2.5, 3.0]
n_minutes_vals = [5, 10, 15, 30]
impact_cutoffs = [2, 3]

all_combos = []


for risk_reward_ratio in risk_reward_ratio_vals:
    for spread_val in spread_cutoffs:
        for atr_multiplier in atr_multipliers:
            for n_minutes in n_minutes_vals:
                for impact_cutoff in impact_cutoffs:
                    all_combos.append((risk_reward_ratio, spread_val, atr_multiplier, n_minutes, impact_cutoff))

percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)
print('Num runs: '+ str(len(combos_to_try)) + '\n')

best_risk_reward = None
best_spread_cutoff = None
best_atr_multiplier = None
best_n_minutes= None
best_impact_cutoff = None
top_n_results = 20
best_rewards = []
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, spread_val, atr_multiplier, n_minutes, impact_cutoff in combos_to_try:
    reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked, trade_lengths = run_simulation(risk_reward_ratio, spread_val, atr_multiplier, n_minutes, impact_cutoff)
    runs_finished += 1

    print(reward)
    print('Num buys: ' + str(n_buys))
    print('Num sells: ' + str(n_sells))
    print('Num trades: ' + str(n_buys + n_sells))
    print('Num wins: ' + str(n_wins))
    print('Num losses: ' + str(n_losses))
    print('Win streak: ' + str(win_streak))
    print('Loss streak: ' + str(loss_streak))
    avg_pips_risked = (sum(pips_risked) / len(pips_risked)) if len(pips_risked) > 0 else 'N/A'
    avg_trade_len = (sum(trade_lengths) / len(trade_lengths)) if len(trade_lengths) > 0 else 0
    print('Avg pips risked: ' + str(avg_pips_risked))
    print('Avg trade length: ' + str(avg_trade_len))
    print('Remaining runs: ' + str(n_runs - runs_finished))

    min_item = min(best_rewards, key=lambda entry: entry['reward']) if len(best_rewards) >= top_n_results else None

    if min_item is None or reward > min_item['reward']:
        if min_item is not None:
            best_rewards.remove(min_item)
            
        best_rewards.append({'reward': int(reward), 'ratio': risk_reward_ratio, 'spread_val': spread_val, 'atr_multiplier': atr_multiplier, 'n_minutes': n_minutes, 'impact_cutoff': impact_cutoff})


    if reward > best_reward and avg_trade_len >= 1:
        best_reward = reward
        best_risk_reward = risk_reward_ratio
        best_spread_cutoff = spread_val
        best_atr_multiplier = atr_multiplier
        best_n_minutes = n_minutes
        best_impact_cutoff = impact_cutoff

    print('Best reward so far: ' + str(best_reward))
    print()
# Out:
# Num runs: 240
#
# -316.21693500002124
# Num buys: 18
# Num sells: 24
# Num trades: 42
# Num wins: 12
# Num losses: 30
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0008861309523809606
# Avg trade length: 22.38095238095238
# Remaining runs: 239
# Best reward so far: -316.21693500002124
#
# -398.15211928555885
# Num buys: 16
# Num sells: 10
# Num trades: 26
# Num wins: 6
# Num losses: 20
# Win streak: 1
# Loss streak: 6
# Avg pips risked: 0.0005305082417582694
# Avg trade length: 2.3846153846153846
# Remaining runs: 238
# Best reward so far: -316.21693500002124
#
# -130.46378999998214
# Num buys: 29
# Num sells: 23
# Num trades: 52
# Num wins: 25
# Num losses: 27
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0021293131868131976
# Avg trade length: 58.23076923076923
# Remaining runs: 237
# Best reward so far: -130.46378999998214
#
# -512.9992950000067
# Num buys: 24
# Num sells: 24
# Num trades: 48
# Num wins: 19
# Num losses: 29
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0018131994047618967
# Avg trade length: 40.791666666666664
# Remaining runs: 236
# Best reward so far: -130.46378999998214
#
# -832.6769628572139
# Num buys: 24
# Num sells: 25
# Num trades: 49
# Num wins: 13
# Num losses: 36
# Win streak: 2
# Loss streak: 7
# Avg pips risked: 0.0011994557823129194
# Avg trade length: 21.408163265306122
# Remaining runs: 235
# Best reward so far: -130.46378999998214
#
# -53.50445571429761
# Num buys: 4
# Num sells: 2
# Num trades: 6
# Num wins: 2
# Num losses: 4
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0013389682539682497
# Avg trade length: 17.333333333333332
# Remaining runs: 234
# Best reward so far: -53.50445571429761
#
# -4018.8209885710007
# Num buys: 122
# Num sells: 102
# Num trades: 224
# Num wins: 48
# Num losses: 176
# Win streak: 3
# Loss streak: 13
# Avg pips risked: 0.000610041454081643
# Avg trade length: 7.589285714285714
# Remaining runs: 233
# Best reward so far: -53.50445571429761
#
# -324.93347714281975
# Num buys: 6
# Num sells: 3
# Num trades: 9
# Num wins: 1
# Num losses: 8
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0005900000000000329
# Avg trade length: 2.4444444444444446
# Remaining runs: 232
# Best reward so far: -53.50445571429761
#
# -173.77415785704275
# Num buys: 22
# Num sells: 14
# Num trades: 36
# Num wins: 13
# Num losses: 23
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0005775925925925977
# Avg trade length: 2.611111111111111
# Remaining runs: 231
# Best reward so far: -53.50445571429761
#
# -404.86691892855004
# Num buys: 14
# Num sells: 16
# Num trades: 30
# Num wins: 11
# Num losses: 19
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0018676904761904941
# Avg trade length: 21.566666666666666
# Remaining runs: 230
# Best reward so far: -53.50445571429761
#
# -104.40211285712272
# Num buys: 5
# Num sells: 3
# Num trades: 8
# Num wins: 3
# Num losses: 5
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.0017310714285714845
# Avg trade length: 27.75
# Remaining runs: 229
# Best reward so far: -53.50445571429761
#
# -2349.281036428399
# Num buys: 70
# Num sells: 64
# Num trades: 134
# Num wins: 29
# Num losses: 105
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0005340178571428644
# Avg trade length: 2.9776119402985075
# Remaining runs: 228
# Best reward so far: -53.50445571429761
#
# -349.9961807142902
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 0
# Num losses: 7
# Win streak: 0
# Loss streak: 7
# Avg pips risked: 0.0009275000000000176
# Avg trade length: 2.0
# Remaining runs: 227
# Best reward so far: -53.50445571429761
#
# -99.99988142857809
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Avg pips risked: 0.0011691666666666656
# Avg trade length: 1.5
# Remaining runs: 226
# Best reward so far: -53.50445571429761
#
# -209.64973749996255
# Num buys: 40
# Num sells: 26
# Num trades: 66
# Num wins: 31
# Num losses: 35
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.001544577922077944
# Avg trade length: 20.984848484848484
# Remaining runs: 225
# Best reward so far: -53.50445571429761
#
# -499.71525785711606
# Num buys: 9
# Num sells: 6
# Num trades: 15
# Num wins: 2
# Num losses: 13
# Win streak: 1
# Loss streak: 9
# Avg pips risked: 0.0007135714285714614
# Avg trade length: 3.1333333333333333
# Remaining runs: 224
# Best reward so far: -53.50445571429761
#
# -1353.391246428471
# Num buys: 50
# Num sells: 43
# Num trades: 93
# Num wins: 22
# Num losses: 71
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.0005256547619047725
# Avg trade length: 3.086021505376344
# Remaining runs: 223
# Best reward so far: -53.50445571429761
#
# -935.14552714277
# Num buys: 72
# Num sells: 61
# Num trades: 133
# Num wins: 46
# Num losses: 87
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0010672753311851166
# Avg trade length: 20.74436090225564
# Remaining runs: 222
# Best reward so far: -53.50445571429761
#
# 50.42207428571655
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0008280357142857464
# Avg trade length: 1.5
# Remaining runs: 221
# Best reward so far: 50.42207428571655
#
# -0.0001250000107617666
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0016574999999998674
# Avg trade length: 7.5
# Remaining runs: 220
# Best reward so far: 50.42207428571655
#
# 99.9200357142916
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 2
# Num losses: 0
# Win streak: 2
# Loss streak: 0
# Avg pips risked: 0.0014642857142858068
# Avg trade length: 1.5
# Remaining runs: 219
# Best reward so far: 99.9200357142916
#
# 0.09775892857358315
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.001627321428571471
# Avg trade length: 4.5
# Remaining runs: 218
# Best reward so far: 99.9200357142916
#
# -125.25164571428033
# Num buys: 3
# Num sells: 2
# Num trades: 5
# Num wins: 1
# Num losses: 4
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.0011053333333333804
# Avg trade length: 3.6
# Remaining runs: 217
# Best reward so far: 99.9200357142916
#
# -149.91352285715266
# Num buys: 7
# Num sells: 0
# Num trades: 7
# Num wins: 2
# Num losses: 5
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0018883673469386939
# Avg trade length: 11.0
# Remaining runs: 216
# Best reward so far: 99.9200357142916
#
# -3198.1294896423133
# Num buys: 117
# Num sells: 119
# Num trades: 236
# Num wins: 69
# Num losses: 167
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0007284554075867829
# Avg trade length: 7.004237288135593
# Remaining runs: 215
# Best reward so far: 99.9200357142916
#
# -524.8426892857367
# Num buys: 6
# Num sells: 7
# Num trades: 13
# Num wins: 1
# Num losses: 12
# Win streak: 1
# Loss streak: 10
# Avg pips risked: 0.00097531135531135
# Avg trade length: 7.538461538461538
# Remaining runs: 214
# Best reward so far: 99.9200357142916
#
# -505.79912392852265
# Num buys: 15
# Num sells: 16
# Num trades: 31
# Num wins: 7
# Num losses: 24
# Win streak: 3
# Loss streak: 8
# Avg pips risked: 0.000928513824884802
# Avg trade length: 9.67741935483871
# Remaining runs: 213
# Best reward so far: 99.9200357142916
#
# -178.50551142851447
# Num buys: 21
# Num sells: 18
# Num trades: 39
# Num wins: 18
# Num losses: 21
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0019570329670330158
# Avg trade length: 48.1025641025641
# Remaining runs: 212
# Best reward so far: 99.9200357142916
#
# 0.1130957142844764
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0017537499999999984
# Avg trade length: 2.0
# Remaining runs: 211
# Best reward so far: 99.9200357142916
#
# -350.086727857144
# Num buys: 6
# Num sells: 7
# Num trades: 13
# Num wins: 3
# Num losses: 10
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0014629670329670253
# Avg trade length: 9.23076923076923
# Remaining runs: 210
# Best reward so far: 99.9200357142916
#
# 247.09020071431772
# Num buys: 6
# Num sells: 4
# Num trades: 10
# Num wins: 6
# Num losses: 4
# Win streak: 3
# Loss streak: 2
# Avg pips risked: 0.0009527380952381629
# Avg trade length: 12.5
# Remaining runs: 209
# Best reward so far: 247.09020071431772
#
# -62.39596499998837
# Num buys: 6
# Num sells: 9
# Num trades: 15
# Num wins: 7
# Num losses: 8
# Win streak: 2
# Loss streak: 2
# Avg pips risked: 0.002326095238095253
# Avg trade length: 112.46666666666667
# Remaining runs: 208
# Best reward so far: 247.09020071431772
#
# -2279.209524285345
# Num buys: 121
# Num sells: 99
# Num trades: 220
# Num wins: 70
# Num losses: 150
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.00081219047619049
# Avg trade length: 11.036363636363637
# Remaining runs: 207
# Best reward so far: 247.09020071431772
#
# 0.040790714287538776
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0016560714285714928
# Avg trade length: 2.0
# Remaining runs: 206
# Best reward so far: 247.09020071431772
#
# 149.39758535714512
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 2
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0008642857142857249
# Avg trade length: 2.0
# Remaining runs: 205
# Best reward so far: 247.09020071431772
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 204
# Best reward so far: 247.09020071431772
#
# -349.60004785705826
# Num buys: 11
# Num sells: 8
# Num trades: 19
# Num wins: 6
# Num losses: 13
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.0010602255639098452
# Avg trade length: 2.3684210526315788
# Remaining runs: 203
# Best reward so far: 247.09020071431772
#
# -424.5504139285608
# Num buys: 9
# Num sells: 7
# Num trades: 16
# Num wins: 3
# Num losses: 13
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0011494791666666706
# Avg trade length: 4.1875
# Remaining runs: 202
# Best reward so far: 247.09020071431772
#
# -304.58114571427814
# Num buys: 11
# Num sells: 7
# Num trades: 18
# Num wins: 6
# Num losses: 12
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0021507738095238255
# Avg trade length: 20.0
# Remaining runs: 201
# Best reward so far: 247.09020071431772
#
# 393.6834782143215
# Num buys: 6
# Num sells: 4
# Num trades: 10
# Num wins: 6
# Num losses: 4
# Win streak: 3
# Loss streak: 2
# Avg pips risked: 0.0007145535714286222
# Avg trade length: 12.4
# Remaining runs: 200
# Best reward so far: 393.6834782143215
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 199
# Best reward so far: 393.6834782143215
#
# -147.91976714278346
# Num buys: 22
# Num sells: 14
# Num trades: 36
# Num wins: 11
# Num losses: 25
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.00043319444444444823
# Avg trade length: 1.9444444444444444
# Remaining runs: 198
# Best reward so far: 393.6834782143215
#
# 192.53710464286448
# Num buys: 10
# Num sells: 7
# Num trades: 17
# Num wins: 7
# Num losses: 10
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0007799054621848907
# Avg trade length: 10.411764705882353
# Remaining runs: 197
# Best reward so far: 393.6834782143215
#
# 45.384137857164994
# Num buys: 8
# Num sells: 3
# Num trades: 11
# Num wins: 4
# Num losses: 7
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0010209253246753378
# Avg trade length: 14.181818181818182
# Remaining runs: 196
# Best reward so far: 393.6834782143215
#
# -199.73348785709558
# Num buys: 6
# Num sells: 2
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0008576785714286272
# Avg trade length: 2.625
# Remaining runs: 195
# Best reward so far: 393.6834782143215
#
# -499.7499407143644
# Num buys: 6
# Num sells: 7
# Num trades: 13
# Num wins: 1
# Num losses: 12
# Win streak: 1
# Loss streak: 10
# Avg pips risked: 0.0007314835164835126
# Avg trade length: 3.6153846153846154
# Remaining runs: 194
# Best reward so far: 393.6834782143215
#
# 92.34806892859754
# Num buys: 22
# Num sells: 18
# Num trades: 40
# Num wins: 21
# Num losses: 19
# Win streak: 5
# Loss streak: 5
# Avg pips risked: 0.0009966160714285966
# Avg trade length: 9.525
# Remaining runs: 193
# Best reward so far: 393.6834782143215
#
# -177.4673428571319
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 3
# Num losses: 8
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0014652813852814013
# Avg trade length: 21.0
# Remaining runs: 192
# Best reward so far: 393.6834782143215
#
# -1821.9067728569298
# Num buys: 100
# Num sells: 80
# Num trades: 180
# Num wins: 72
# Num losses: 108
# Win streak: 5
# Loss streak: 9
# Avg pips risked: 0.000976948412698432
# Avg trade length: 9.405555555555555
# Remaining runs: 191
# Best reward so far: 393.6834782143215
#
# 49.85468000003053
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0007567857142857792
# Avg trade length: 1.0
# Remaining runs: 190
# Best reward so far: 393.6834782143215
#
# -702.0095607142018
# Num buys: 71
# Num sells: 58
# Num trades: 129
# Num wins: 58
# Num losses: 71
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0016090531561461987
# Avg trade length: 34.44186046511628
# Remaining runs: 189
# Best reward so far: 393.6834782143215
#
# -893.5581007142209
# Num buys: 73
# Num sells: 61
# Num trades: 134
# Num wins: 39
# Num losses: 95
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.0007991417910447843
# Avg trade length: 15.985074626865671
# Remaining runs: 188
# Best reward so far: 393.6834782143215
#
# 42.94445571428593
# Num buys: 4
# Num sells: 3
# Num trades: 7
# Num wins: 4
# Num losses: 3
# Win streak: 2
# Loss streak: 2
# Avg pips risked: 0.0024139795918366935
# Avg trade length: 183.0
# Remaining runs: 187
# Best reward so far: 393.6834782143215
#
# -1606.7740299997881
# Num buys: 118
# Num sells: 97
# Num trades: 215
# Num wins: 92
# Num losses: 123
# Win streak: 6
# Loss streak: 8
# Avg pips risked: 0.001219568106312312
# Avg trade length: 20.074418604651164
# Remaining runs: 186
# Best reward so far: 393.6834782143215
#
# -752.9213882142336
# Num buys: 22
# Num sells: 17
# Num trades: 39
# Num wins: 12
# Num losses: 27
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0012274725274725672
# Avg trade length: 10.666666666666666
# Remaining runs: 185
# Best reward so far: 393.6834782143215
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 184
# Best reward so far: 393.6834782143215
#
# 99.68391607142935
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 2
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0011523809523809663
# Avg trade length: 2.0
# Remaining runs: 183
# Best reward so far: 393.6834782143215
#
# -476.5493864285756
# Num buys: 30
# Num sells: 24
# Num trades: 54
# Num wins: 15
# Num losses: 39
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.0010539153439153468
# Avg trade length: 25.666666666666668
# Remaining runs: 182
# Best reward so far: 393.6834782143215
#
# 200.45561857144037
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 2
# Num losses: 0
# Win streak: 2
# Loss streak: 0
# Avg pips risked: 0.0007321428571429034
# Avg trade length: 1.5
# Remaining runs: 181
# Best reward so far: 393.6834782143215
#
# -1199.794687499781
# Num buys: 34
# Num sells: 23
# Num trades: 57
# Num wins: 11
# Num losses: 46
# Win streak: 2
# Loss streak: 11
# Avg pips risked: 0.0006342763157894948
# Avg trade length: 3.526315789473684
# Remaining runs: 180
# Best reward so far: 393.6834782143215
#
# -209.54477214286928
# Num buys: 4
# Num sells: 3
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0012069897959183467
# Avg trade length: 83.14285714285714
# Remaining runs: 179
# Best reward so far: 393.6834782143215
#
# -208.98977000001227
# Num buys: 9
# Num sells: 13
# Num trades: 22
# Num wins: 9
# Num losses: 13
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0018302597402597128
# Avg trade length: 66.77272727272727
# Remaining runs: 178
# Best reward so far: 393.6834782143215
#
# -260.17732571428115
# Num buys: 6
# Num sells: 9
# Num trades: 15
# Num wins: 4
# Num losses: 11
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0015507301587301685
# Avg trade length: 61.333333333333336
# Remaining runs: 177
# Best reward so far: 393.6834782143215
#
# 147.1691464285775
# Num buys: 10
# Num sells: 7
# Num trades: 17
# Num wins: 8
# Num losses: 9
# Win streak: 3
# Loss streak: 2
# Avg pips risked: 0.0010398739495798542
# Avg trade length: 11.294117647058824
# Remaining runs: 176
# Best reward so far: 393.6834782143215
#
# 196.22965714291664
# Num buys: 16
# Num sells: 12
# Num trades: 28
# Num wins: 16
# Num losses: 12
# Win streak: 5
# Loss streak: 3
# Avg pips risked: 0.0011377551020408541
# Avg trade length: 10.678571428571429
# Remaining runs: 175
# Best reward so far: 393.6834782143215
#
# -249.8746989285488
# Num buys: 4
# Num sells: 4
# Num trades: 8
# Num wins: 1
# Num losses: 7
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0008518973214285963
# Avg trade length: 1.625
# Remaining runs: 174
# Best reward so far: 393.6834782143215
#
# -99.99890821429
# Num buys: 1
# Num sells: 1
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Avg pips risked: 0.0008768749999999992
# Avg trade length: 1.0
# Remaining runs: 173
# Best reward so far: 393.6834782143215
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 172
# Best reward so far: 393.6834782143215
#
# -1198.1866521426316
# Num buys: 44
# Num sells: 37
# Num trades: 81
# Num wins: 19
# Num losses: 62
# Win streak: 3
# Loss streak: 9
# Avg pips risked: 0.00047411816578484065
# Avg trade length: 2.3950617283950617
# Remaining runs: 171
# Best reward so far: 393.6834782143215
#
# -233.6661107142992
# Num buys: 4
# Num sells: 3
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0016093197278911288
# Avg trade length: 85.71428571428571
# Remaining runs: 170
# Best reward so far: 393.6834782143215
#
# -200.17356285714925
# Num buys: 2
# Num sells: 6
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0013324999999999865
# Avg trade length: 10.625
# Remaining runs: 169
# Best reward so far: 393.6834782143215
#
# -1866.9823107142277
# Num buys: 68
# Num sells: 63
# Num trades: 131
# Num wins: 47
# Num losses: 84
# Win streak: 5
# Loss streak: 9
# Avg pips risked: 0.001070177208287909
# Avg trade length: 9.274809160305344
# Remaining runs: 168
# Best reward so far: 393.6834782143215
#
# -317.11054857141323
# Num buys: 6
# Num sells: 9
# Num trades: 15
# Num wins: 3
# Num losses: 12
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0011630476190476265
# Avg trade length: 49.53333333333333
# Remaining runs: 167
# Best reward so far: 393.6834782143215
#
# -499.2479410714076
# Num buys: 9
# Num sells: 7
# Num trades: 16
# Num wins: 2
# Num losses: 14
# Win streak: 1
# Loss streak: 6
# Avg pips risked: 0.0008621093750000031
# Avg trade length: 2.5
# Remaining runs: 166
# Best reward so far: 393.6834782143215
#
# -575.2764207143445
# Num buys: 13
# Num sells: 11
# Num trades: 24
# Num wins: 5
# Num losses: 19
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0009971230158730016
# Avg trade length: 9.208333333333334
# Remaining runs: 165
# Best reward so far: 393.6834782143215
#
# -149.8839521428527
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 2
# Num losses: 5
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.0018550000000000352
# Avg trade length: 8.285714285714286
# Remaining runs: 164
# Best reward so far: 393.6834782143215
#
# -150.4072592857135
# Num buys: 5
# Num sells: 3
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.0011540476190476563
# Avg trade length: 4.375
# Remaining runs: 163
# Best reward so far: 393.6834782143215
#
# -399.99668071430773
# Num buys: 2
# Num sells: 6
# Num trades: 8
# Num wins: 0
# Num losses: 8
# Win streak: 0
# Loss streak: 8
# Avg pips risked: 0.0008883333333333243
# Avg trade length: 9.0
# Remaining runs: 162
# Best reward so far: 393.6834782143215
#
# -211.2535164285476
# Num buys: 18
# Num sells: 24
# Num trades: 42
# Num wins: 19
# Num losses: 23
# Win streak: 3
# Loss streak: 4
# Avg pips risked: 0.0017722619047619212
# Avg trade length: 47.476190476190474
# Remaining runs: 161
# Best reward so far: 393.6834782143215
#
# 0.2460299999995499
# Num buys: 3
# Num sells: 0
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.000927500000000007
# Avg trade length: 5.666666666666667
# Remaining runs: 160
# Best reward so far: 393.6834782143215
#
# -122.18224999988729
# Num buys: 31
# Num sells: 19
# Num trades: 50
# Num wins: 16
# Num losses: 34
# Win streak: 2
# Loss streak: 9
# Avg pips risked: 0.0010301107142857257
# Avg trade length: 18.8
# Remaining runs: 159
# Best reward so far: 393.6834782143215
#
# 119.88385892863765
# Num buys: 22
# Num sells: 18
# Num trades: 40
# Num wins: 17
# Num losses: 23
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0006644107142857311
# Avg trade length: 5.125
# Remaining runs: 158
# Best reward so far: 393.6834782143215
#
# 70.1564685714442
# Num buys: 4
# Num sells: 7
# Num trades: 11
# Num wins: 5
# Num losses: 6
# Win streak: 2
# Loss streak: 2
# Avg pips risked: 0.0012715151515151782
# Avg trade length: 16.363636363636363
# Remaining runs: 157
# Best reward so far: 393.6834782143215
#
# 198.12404178573973
# Num buys: 6
# Num sells: 4
# Num trades: 10
# Num wins: 7
# Num losses: 3
# Win streak: 6
# Loss streak: 2
# Avg pips risked: 0.0014291071428572445
# Avg trade length: 14.3
# Remaining runs: 156
# Best reward so far: 393.6834782143215
#
# 419.2204028571864
# Num buys: 16
# Num sells: 13
# Num trades: 29
# Num wins: 15
# Num losses: 14
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0007694909688013376
# Avg trade length: 7.931034482758621
# Remaining runs: 155
# Best reward so far: 419.2204028571864
#
# 150.11160000000882
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 2
# Num losses: 0
# Win streak: 2
# Loss streak: 0
# Avg pips risked: 0.0009761904761905378
# Avg trade length: 1.5
# Remaining runs: 154
# Best reward so far: 419.2204028571864
#
# -7.7630928571217925
# Num buys: 18
# Num sells: 16
# Num trades: 34
# Num wins: 17
# Num losses: 17
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0014612184873949669
# Avg trade length: 18.823529411764707
# Remaining runs: 153
# Best reward so far: 419.2204028571864
#
# -99.57651499998448
# Num buys: 3
# Num sells: 2
# Num trades: 5
# Num wins: 1
# Num losses: 4
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.0008290000000000352
# Avg trade length: 3.6
# Remaining runs: 152
# Best reward so far: 419.2204028571864
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 151
# Best reward so far: 419.2204028571864
#
# -103.31069142855584
# Num buys: 4
# Num sells: 7
# Num trades: 11
# Num wins: 3
# Num losses: 8
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0009536363636363838
# Avg trade length: 12.090909090909092
# Remaining runs: 150
# Best reward so far: 419.2204028571864
#
# -400.13378214284813
# Num buys: 9
# Num sells: 7
# Num trades: 16
# Num wins: 4
# Num losses: 12
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.0017242187500000061
# Avg trade length: 6.0625
# Remaining runs: 149
# Best reward so far: 419.2204028571864
#
# 143.5764657143203
# Num buys: 6
# Num sells: 6
# Num trades: 12
# Num wins: 5
# Num losses: 7
# Win streak: 3
# Loss streak: 4
# Avg pips risked: 0.0006260119047619231
# Avg trade length: 10.416666666666666
# Remaining runs: 148
# Best reward so far: 419.2204028571864
#
# -1030.6876678567517
# Num buys: 98
# Num sells: 66
# Num trades: 164
# Num wins: 48
# Num losses: 116
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.000740697952961686
# Avg trade length: 12.841463414634147
# Remaining runs: 147
# Best reward so far: 419.2204028571864
#
# -99.98531535713406
# Num buys: 4
# Num sells: 4
# Num trades: 8
# Num wins: 3
# Num losses: 5
# Win streak: 2
# Loss streak: 2
# Avg pips risked: 0.0017037946428571926
# Avg trade length: 2.625
# Remaining runs: 146
# Best reward so far: 419.2204028571864
#
# -140.58762071424377
# Num buys: 31
# Num sells: 19
# Num trades: 50
# Num wins: 19
# Num losses: 31
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.0013734809523809678
# Avg trade length: 23.68
# Remaining runs: 145
# Best reward so far: 419.2204028571864
#
# -1219.219122857095
# Num buys: 50
# Num sells: 42
# Num trades: 92
# Num wins: 34
# Num losses: 58
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.0010534821428571626
# Avg trade length: 10.01086956521739
# Remaining runs: 144
# Best reward so far: 419.2204028571864
#
# -149.8842175000052
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 1
# Num losses: 4
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.0018013571428570963
# Avg trade length: 7.4
# Remaining runs: 143
# Best reward so far: 419.2204028571864
#
# -104.01600999997513
# Num buys: 8
# Num sells: 9
# Num trades: 17
# Num wins: 6
# Num losses: 11
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.0013792156862745242
# Avg trade length: 13.058823529411764
# Remaining runs: 142
# Best reward so far: 419.2204028571864
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 141
# Best reward so far: 419.2204028571864
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 140
# Best reward so far: 419.2204028571864
#
# -1.9776271428462446
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 2
# Num losses: 2
# Win streak: 2
# Loss streak: 1
# Avg pips risked: 0.0019075000000000064
# Avg trade length: 25.75
# Remaining runs: 139
# Best reward so far: 419.2204028571864
#
# -105.7045471428329
# Num buys: 12
# Num sells: 11
# Num trades: 23
# Num wins: 7
# Num losses: 16
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0007014596273292016
# Avg trade length: 7.304347826086956
# Remaining runs: 138
# Best reward so far: 419.2204028571864
#
# 24.747643571430594
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.001104047619047662
# Avg trade length: 1.5
# Remaining runs: 137
# Best reward so far: 419.2204028571864
#
# -811.4176950000943
# Num buys: 24
# Num sells: 25
# Num trades: 49
# Num wins: 11
# Num losses: 38
# Win streak: 2
# Loss streak: 7
# Avg pips risked: 0.0008995918367346895
# Avg trade length: 18.693877551020407
# Remaining runs: 136
# Best reward so far: 419.2204028571864
#
# 99.7722996428652
# Num buys: 4
# Num sells: 0
# Num trades: 4
# Num wins: 2
# Num losses: 2
# Win streak: 2
# Loss streak: 2
# Avg pips risked: 0.0009812500000000168
# Avg trade length: 2.0
# Remaining runs: 135
# Best reward so far: 419.2204028571864
#
# -249.9983042857225
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 0
# Num losses: 5
# Win streak: 0
# Loss streak: 5
# Avg pips risked: 0.0012009047619047307
# Avg trade length: 2.0
# Remaining runs: 134
# Best reward so far: 419.2204028571864
#
# -2339.4370464283925
# Num buys: 70
# Num sells: 64
# Num trades: 134
# Num wins: 35
# Num losses: 99
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0007120238095238194
# Avg trade length: 4.492537313432836
# Remaining runs: 133
# Best reward so far: 419.2204028571864
#
# -936.3357157141361
# Num buys: 63
# Num sells: 43
# Num trades: 106
# Num wins: 35
# Num losses: 71
# Win streak: 3
# Loss streak: 8
# Avg pips risked: 0.0008459748427673065
# Avg trade length: 8.830188679245284
# Remaining runs: 132
# Best reward so far: 419.2204028571864
#
# -1321.6345192855301
# Num buys: 65
# Num sells: 47
# Num trades: 112
# Num wins: 43
# Num losses: 69
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0009611096938775722
# Avg trade length: 9.892857142857142
# Remaining runs: 131
# Best reward so far: 419.2204028571864
#
# 239.88133428570123
# Num buys: 7
# Num sells: 9
# Num trades: 16
# Num wins: 7
# Num losses: 9
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.001149598214285709
# Avg trade length: 26.375
# Remaining runs: 130
# Best reward so far: 419.2204028571864
#
# -1349.6568896427025
# Num buys: 34
# Num sells: 23
# Num trades: 57
# Num wins: 12
# Num losses: 45
# Win streak: 2
# Loss streak: 8
# Avg pips risked: 0.000845701754385993
# Avg trade length: 5.298245614035087
# Remaining runs: 129
# Best reward so far: 419.2204028571864
#
# 88.94338428572222
# Num buys: 25
# Num sells: 27
# Num trades: 52
# Num wins: 27
# Num losses: 25
# Win streak: 7
# Loss streak: 5
# Avg pips risked: 0.001487362637362642
# Avg trade length: 18.615384615384617
# Remaining runs: 128
# Best reward so far: 419.2204028571864
#
# -769.8321085713526
# Num buys: 63
# Num sells: 42
# Num trades: 105
# Num wins: 45
# Num losses: 60
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012656598639455945
# Avg trade length: 16.133333333333333
# Remaining runs: 127
# Best reward so far: 419.2204028571864
#
# -341.9939042856487
# Num buys: 21
# Num sells: 18
# Num trades: 39
# Num wins: 13
# Num losses: 26
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.0013046886446886773
# Avg trade length: 22.564102564102566
# Remaining runs: 126
# Best reward so far: 419.2204028571864
#
# -424.43552571421134
# Num buys: 16
# Num sells: 10
# Num trades: 26
# Num wins: 7
# Num losses: 19
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0007073443223443594
# Avg trade length: 2.769230769230769
# Remaining runs: 125
# Best reward so far: 419.2204028571864
#
# -600.5721621429467
# Num buys: 13
# Num sells: 11
# Num trades: 24
# Num wins: 4
# Num losses: 20
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0007478422619047511
# Avg trade length: 4.541666666666667
# Remaining runs: 124
# Best reward so far: 419.2204028571864
#
# 99.82633964286583
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 2
# Num losses: 0
# Win streak: 2
# Loss streak: 0
# Avg pips risked: 0.0015135714285715585
# Avg trade length: 1.0
# Remaining runs: 123
# Best reward so far: 419.2204028571864
#
# 632.8377100001028
# Num buys: 26
# Num sells: 24
# Num trades: 50
# Num wins: 21
# Num losses: 29
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.000855403571428588
# Avg trade length: 14.66
# Remaining runs: 122
# Best reward so far: 632.8377100001028
#
# -58.2765428571293
# Num buys: 18
# Num sells: 16
# Num trades: 34
# Num wins: 11
# Num losses: 23
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0007306092436974834
# Avg trade length: 7.970588235294118
# Remaining runs: 121
# Best reward so far: 632.8377100001028
#
# 50.42207428571655
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0008280357142857464
# Avg trade length: 1.5
# Remaining runs: 120
# Best reward so far: 632.8377100001028
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 119
# Best reward so far: 632.8377100001028
#
# -249.99742714287763
# Num buys: 2
# Num sells: 3
# Num trades: 5
# Num wins: 0
# Num losses: 5
# Win streak: 0
# Loss streak: 5
# Avg pips risked: 0.0009006785714285482
# Avg trade length: 1.6
# Remaining runs: 118
# Best reward so far: 632.8377100001028
#
# -199.751275000026
# Num buys: 7
# Num sells: 0
# Num trades: 7
# Num wins: 1
# Num losses: 6
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0009441836734693469
# Avg trade length: 3.0
# Remaining runs: 117
# Best reward so far: 632.8377100001028
#
# -308.62400357144617
# Num buys: 14
# Num sells: 6
# Num trades: 20
# Num wins: 7
# Num losses: 13
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.002323607142857109
# Avg trade length: 73.05
# Remaining runs: 116
# Best reward so far: 632.8377100001028
#
# -30.153654285703098
# Num buys: 12
# Num sells: 11
# Num trades: 23
# Num wins: 9
# Num losses: 14
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0009352795031056019
# Avg trade length: 9.565217391304348
# Remaining runs: 115
# Best reward so far: 632.8377100001028
#
# -350.21099071436936
# Num buys: 4
# Num sells: 9
# Num trades: 13
# Num wins: 2
# Num losses: 11
# Win streak: 1
# Loss streak: 7
# Avg pips risked: 0.0006917032967032824
# Avg trade length: 2.6923076923076925
# Remaining runs: 114
# Best reward so far: 632.8377100001028
#
# -398.96028571415985
# Num buys: 11
# Num sells: 9
# Num trades: 20
# Num wins: 4
# Num losses: 16
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0005311964285714621
# Avg trade length: 1.75
# Remaining runs: 113
# Best reward so far: 632.8377100001028
#
# -281.1724292857155
# Num buys: 11
# Num sells: 7
# Num trades: 18
# Num wins: 5
# Num losses: 13
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0014338492063492169
# Avg trade length: 18.0
# Remaining runs: 112
# Best reward so far: 632.8377100001028
#
# -100.03376642859803
# Num buys: 7
# Num sells: 0
# Num trades: 7
# Num wins: 2
# Num losses: 5
# Win streak: 2
# Loss streak: 5
# Avg pips risked: 0.001258911564625796
# Avg trade length: 5.714285714285714
# Remaining runs: 111
# Best reward so far: 632.8377100001028
#
# -349.99792714284575
# Num buys: 2
# Num sells: 5
# Num trades: 7
# Num wins: 0
# Num losses: 7
# Win streak: 0
# Loss streak: 7
# Avg pips risked: 0.0012366666666666901
# Avg trade length: 2.4285714285714284
# Remaining runs: 110
# Best reward so far: 632.8377100001028
#
# -100.90340071427771
# Num buys: 7
# Num sells: 5
# Num trades: 12
# Num wins: 4
# Num losses: 8
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.0011760317460317827
# Avg trade length: 4.083333333333333
# Remaining runs: 109
# Best reward so far: 632.8377100001028
#
# -499.63478285706094
# Num buys: 22
# Num sells: 14
# Num trades: 36
# Num wins: 13
# Num losses: 23
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0010794444444444846
# Avg trade length: 3.5
# Remaining runs: 108
# Best reward so far: 632.8377100001028
#
# -1124.4454964284355
# Num buys: 43
# Num sells: 37
# Num trades: 80
# Num wins: 23
# Num losses: 57
# Win streak: 3
# Loss streak: 8
# Avg pips risked: 0.0006343690476190582
# Avg trade length: 3.55
# Remaining runs: 107
# Best reward so far: 632.8377100001028
#
# 106.70521642859781
# Num buys: 22
# Num sells: 18
# Num trades: 40
# Num wins: 14
# Num losses: 26
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0004983080357142983
# Avg trade length: 2.975
# Remaining runs: 106
# Best reward so far: 632.8377100001028
#
# -275.47919642860836
# Num buys: 4
# Num sells: 9
# Num trades: 13
# Num wins: 3
# Num losses: 10
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.000922271062271043
# Avg trade length: 7.230769230769231
# Remaining runs: 105
# Best reward so far: 632.8377100001028
#
# 44.38801857145002
# Num buys: 4
# Num sells: 7
# Num trades: 11
# Num wins: 6
# Num losses: 5
# Win streak: 4
# Loss streak: 2
# Avg pips risked: 0.0019072727272727676
# Avg trade length: 24.454545454545453
# Remaining runs: 104
# Best reward so far: 632.8377100001028
#
# 359.7872217858139
# Num buys: 26
# Num sells: 24
# Num trades: 50
# Num wins: 23
# Num losses: 27
# Win streak: 5
# Loss streak: 3
# Avg pips risked: 0.001140538095238117
# Avg trade length: 16.58
# Remaining runs: 103
# Best reward so far: 632.8377100001028
#
# -714.2489599999474
# Num buys: 40
# Num sells: 26
# Num trades: 66
# Num wins: 26
# Num losses: 40
# Win streak: 4
# Loss streak: 5
# Avg pips risked: 0.0012601948051948256
# Avg trade length: 15.348484848484848
# Remaining runs: 102
# Best reward so far: 632.8377100001028
#
# -399.9966371429223
# Num buys: 2
# Num sells: 6
# Num trades: 8
# Num wins: 0
# Num losses: 8
# Win streak: 0
# Loss streak: 8
# Avg pips risked: 0.0006662499999999932
# Avg trade length: 3.375
# Remaining runs: 101
# Best reward so far: 632.8377100001028
#
# -0.059114285676031386
# Num buys: 7
# Num sells: 5
# Num trades: 12
# Num wins: 4
# Num losses: 8
# Win streak: 2
# Loss streak: 4
# Avg pips risked: 0.0008820238095238372
# Avg trade length: 3.9166666666666665
# Remaining runs: 100
# Best reward so far: 632.8377100001028
#
# -653.3557978570911
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 9
# Num losses: 22
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0011320967741935946
# Avg trade length: 10.67741935483871
# Remaining runs: 99
# Best reward so far: 632.8377100001028
#
# -861.8710364284743
# Num buys: 43
# Num sells: 36
# Num trades: 79
# Num wins: 31
# Num losses: 48
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0009496292947558931
# Avg trade length: 6.544303797468355
# Remaining runs: 98
# Best reward so far: 632.8377100001028
#
# -400.210072142868
# Num buys: 13
# Num sells: 11
# Num trades: 24
# Num wins: 8
# Num losses: 16
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0014956845238095022
# Avg trade length: 11.625
# Remaining runs: 97
# Best reward so far: 632.8377100001028
#
# -5.7851532142921975
# Num buys: 13
# Num sells: 12
# Num trades: 25
# Num wins: 10
# Num losses: 15
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0010979238095238193
# Avg trade length: 13.24
# Remaining runs: 96
# Best reward so far: 632.8377100001028
#
# -131.8752289286111
# Num buys: 26
# Num sells: 14
# Num trades: 40
# Num wins: 15
# Num losses: 25
# Win streak: 5
# Loss streak: 4
# Avg pips risked: 0.001014821428571433
# Avg trade length: 12.6
# Remaining runs: 95
# Best reward so far: 632.8377100001028
#
# -0.0007778571348993069
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0011457142857143054
# Avg trade length: 1.0
# Remaining runs: 94
# Best reward so far: 632.8377100001028
#
# 50.153061428573025
# Num buys: 2
# Num sells: 1
# Num trades: 3
# Num wins: 2
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0017285714285714497
# Avg trade length: 3.3333333333333335
# Remaining runs: 93
# Best reward so far: 632.8377100001028
#
# -50.239551428589735
# Num buys: 4
# Num sells: 9
# Num trades: 13
# Num wins: 6
# Num losses: 7
# Win streak: 3
# Loss streak: 5
# Avg pips risked: 0.0013834065934065648
# Avg trade length: 8.461538461538462
# Remaining runs: 92
# Best reward so far: 632.8377100001028
#
# -53.95949821427673
# Num buys: 8
# Num sells: 3
# Num trades: 11
# Num wins: 4
# Num losses: 7
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0013612337662337838
# Avg trade length: 14.363636363636363
# Remaining runs: 91
# Best reward so far: 632.8377100001028
#
# -361.4303042856893
# Num buys: 18
# Num sells: 24
# Num trades: 42
# Num wins: 14
# Num losses: 28
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0011815079365079474
# Avg trade length: 28.357142857142858
# Remaining runs: 90
# Best reward so far: 632.8377100001028
#
# -99.89153714283628
# Num buys: 5
# Num sells: 3
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.0008655357142857423
# Avg trade length: 4.125
# Remaining runs: 89
# Best reward so far: 632.8377100001028
#
# 24.810224999996215
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0011049999999999116
# Avg trade length: 7.5
# Remaining runs: 88
# Best reward so far: 632.8377100001028
#
# -157.19327999998995
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 4
# Num losses: 7
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0021979220779221017
# Avg trade length: 40.36363636363637
# Remaining runs: 87
# Best reward so far: 632.8377100001028
#
# -61.409525000021866
# Num buys: 26
# Num sells: 14
# Num trades: 40
# Num wins: 13
# Num losses: 27
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.0007611160714285747
# Avg trade length: 12.025
# Remaining runs: 86
# Best reward so far: 632.8377100001028
#
# 44.432852857147175
# Num buys: 18
# Num sells: 16
# Num trades: 34
# Num wins: 14
# Num losses: 20
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0009741456582633109
# Avg trade length: 10.088235294117647
# Remaining runs: 85
# Best reward so far: 632.8377100001028
#
# -174.93086571428876
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 1
# Num losses: 5
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.001383809523809503
# Avg trade length: 8.666666666666666
# Remaining runs: 84
# Best reward so far: 632.8377100001028
#
# -949.7002357141872
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 4
# Num losses: 27
# Win streak: 1
# Loss streak: 9
# Avg pips risked: 0.0005660483870967973
# Avg trade length: 2.935483870967742
# Remaining runs: 83
# Best reward so far: 632.8377100001028
#
# 346.5171764286039
# Num buys: 11
# Num sells: 7
# Num trades: 18
# Num wins: 10
# Num losses: 8
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.0009392460317460692
# Avg trade length: 9.944444444444445
# Remaining runs: 82
# Best reward so far: 632.8377100001028
#
# -608.2736714286175
# Num buys: 9
# Num sells: 13
# Num trades: 22
# Num wins: 4
# Num losses: 18
# Win streak: 1
# Loss streak: 7
# Avg pips risked: 0.001220173160173142
# Avg trade length: 34.77272727272727
# Remaining runs: 81
# Best reward so far: 632.8377100001028
#
# -436.8622553571191
# Num buys: 40
# Num sells: 26
# Num trades: 66
# Num wins: 23
# Num losses: 43
# Win streak: 4
# Loss streak: 6
# Avg pips risked: 0.0010297186147186295
# Avg trade length: 12.075757575757576
# Remaining runs: 80
# Best reward so far: 632.8377100001028
#
# -554.1900724999646
# Num buys: 15
# Num sells: 16
# Num trades: 31
# Num wins: 8
# Num losses: 23
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0012380184331797362
# Avg trade length: 12.709677419354838
# Remaining runs: 79
# Best reward so far: 632.8377100001028
#
# -1712.4480971427984
# Num buys: 63
# Num sells: 43
# Num trades: 106
# Num wins: 24
# Num losses: 82
# Win streak: 2
# Loss streak: 8
# Avg pips risked: 0.0006344811320754797
# Avg trade length: 6.547169811320755
# Remaining runs: 78
# Best reward so far: 632.8377100001028
#
# -1876.9829739283005
# Num buys: 111
# Num sells: 114
# Num trades: 225
# Num wins: 94
# Num losses: 131
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0010977857142857417
# Avg trade length: 13.066666666666666
# Remaining runs: 77
# Best reward so far: 632.8377100001028
#
# 444.0841892857755
# Num buys: 11
# Num sells: 7
# Num trades: 18
# Num wins: 9
# Num losses: 9
# Win streak: 4
# Loss streak: 3
# Avg pips risked: 0.000704434523809552
# Avg trade length: 9.777777777777779
# Remaining runs: 76
# Best reward so far: 632.8377100001028
#
# 24.775724285715896
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0010848809523809806
# Avg trade length: 2.5
# Remaining runs: 75
# Best reward so far: 632.8377100001028
#
# -108.09171750000932
# Num buys: 7
# Num sells: 9
# Num trades: 16
# Num wins: 7
# Num losses: 9
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.002299196428571418
# Avg trade length: 39.75
# Remaining runs: 74
# Best reward so far: 632.8377100001028
#
# 287.1659178571975
# Num buys: 26
# Num sells: 24
# Num trades: 50
# Num wins: 28
# Num losses: 22
# Win streak: 5
# Loss streak: 3
# Avg pips risked: 0.001710807142857176
# Avg trade length: 29.52
# Remaining runs: 73
# Best reward so far: 632.8377100001028
#
# -814.9444157141794
# Num buys: 21
# Num sells: 19
# Num trades: 40
# Num wins: 8
# Num losses: 32
# Win streak: 1
# Loss streak: 6
# Avg pips risked: 0.0009823392857143092
# Avg trade length: 17.95
# Remaining runs: 72
# Best reward so far: 632.8377100001028
#
# -74.93177857142439
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 1
# Num losses: 3
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.001271666666666671
# Avg trade length: 3.75
# Remaining runs: 71
# Best reward so far: 632.8377100001028
#
# -3452.9865292850786
# Num buys: 120
# Num sells: 120
# Num trades: 240
# Num wins: 57
# Num losses: 183
# Win streak: 3
# Loss streak: 18
# Avg pips risked: 0.0005455930059523953
# Avg trade length: 4.691666666666666
# Remaining runs: 70
# Best reward so far: 632.8377100001028
#
# -348.73299499994215
# Num buys: 22
# Num sells: 15
# Num trades: 37
# Num wins: 12
# Num losses: 25
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0007200643500643762
# Avg trade length: 3.081081081081081
# Remaining runs: 69
# Best reward so far: 632.8377100001028
#
# -375.0937464284873
# Num buys: 11
# Num sells: 9
# Num trades: 20
# Num wins: 5
# Num losses: 15
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0007082619047619496
# Avg trade length: 2.15
# Remaining runs: 68
# Best reward so far: 632.8377100001028
#
# -506.23978071431463
# Num buys: 14
# Num sells: 6
# Num trades: 20
# Num wins: 4
# Num losses: 16
# Win streak: 1
# Loss streak: 11
# Avg pips risked: 0.001549071428571406
# Avg trade length: 35.75
# Remaining runs: 67
# Best reward so far: 632.8377100001028
#
# 49.74850642857481
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0008136607142857355
# Avg trade length: 2.5
# Remaining runs: 66
# Best reward so far: 632.8377100001028
#
# -3552.0795357139054
# Num buys: 106
# Num sells: 85
# Num trades: 191
# Num wins: 40
# Num losses: 151
# Win streak: 3
# Loss streak: 16
# Avg pips risked: 0.0004904973821989617
# Avg trade length: 3.3089005235602094
# Remaining runs: 65
# Best reward so far: 632.8377100001028
#
# 24.747643571430594
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.001104047619047662
# Avg trade length: 1.5
# Remaining runs: 64
# Best reward so far: 632.8377100001028
#
# -112.64376999998393
# Num buys: 26
# Num sells: 27
# Num trades: 53
# Num wins: 17
# Num losses: 36
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.0007409838274932658
# Avg trade length: 9.867924528301886
# Remaining runs: 63
# Best reward so far: 632.8377100001028
#
# -924.8006407142004
# Num buys: 16
# Num sells: 15
# Num trades: 31
# Num wins: 5
# Num losses: 26
# Win streak: 1
# Loss streak: 7
# Avg pips risked: 0.0007547311827957299
# Avg trade length: 4.0
# Remaining runs: 62
# Best reward so far: 632.8377100001028
#
# -299.65528857137883
# Num buys: 6
# Num sells: 3
# Num trades: 9
# Num wins: 1
# Num losses: 8
# Win streak: 1
# Loss streak: 5
# Avg pips risked: 0.0004425000000000247
# Avg trade length: 2.3333333333333335
# Remaining runs: 61
# Best reward so far: 632.8377100001028
#
# 65.17020107141256
# Num buys: 7
# Num sells: 9
# Num trades: 16
# Num wins: 7
# Num losses: 9
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.001532797619047612
# Avg trade length: 29.9375
# Remaining runs: 60
# Best reward so far: 632.8377100001028
#
# -24.846254285720192
# Num buys: 3
# Num sells: 0
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.001236666666666676
# Avg trade length: 7.666666666666667
# Remaining runs: 59
# Best reward so far: 632.8377100001028
#
# -99.99935500000484
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Avg pips risked: 0.0008287499999999337
# Avg trade length: 1.0
# Remaining runs: 58
# Best reward so far: 632.8377100001028
#
# -119.55910821424311
# Num buys: 31
# Num sells: 19
# Num trades: 50
# Num wins: 24
# Num losses: 26
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0020602214285714514
# Avg trade length: 41.72
# Remaining runs: 57
# Best reward so far: 632.8377100001028
#
# -449.67695285704417
# Num buys: 16
# Num sells: 9
# Num trades: 25
# Num wins: 8
# Num losses: 17
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0010593142857143435
# Avg trade length: 3.08
# Remaining runs: 56
# Best reward so far: 632.8377100001028
#
# -158.10712107141134
# Num buys: 11
# Num sells: 7
# Num trades: 18
# Num wins: 5
# Num losses: 13
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0010753869047619127
# Avg trade length: 13.666666666666666
# Remaining runs: 55
# Best reward so far: 632.8377100001028
#
# 0.040790714287538776
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0016560714285714928
# Avg trade length: 2.0
# Remaining runs: 54
# Best reward so far: 632.8377100001028
#
# -1199.7234364284689
# Num buys: 22
# Num sells: 17
# Num trades: 39
# Num wins: 6
# Num losses: 33
# Win streak: 1
# Loss streak: 8
# Avg pips risked: 0.0008183150183150448
# Avg trade length: 4.3076923076923075
# Remaining runs: 53
# Best reward so far: 632.8377100001028
#
# 89.13004892854532
# Num buys: 13
# Num sells: 12
# Num trades: 25
# Num wins: 9
# Num losses: 16
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0008234428571428642
# Avg trade length: 12.24
# Remaining runs: 52
# Best reward so far: 632.8377100001028
#
# -404.3413642857073
# Num buys: 8
# Num sells: 9
# Num trades: 17
# Num wins: 3
# Num losses: 14
# Win streak: 1
# Loss streak: 8
# Avg pips risked: 0.001034411764705893
# Avg trade length: 9.235294117647058
# Remaining runs: 51
# Best reward so far: 632.8377100001028
#
# 149.64023964287014
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 2
# Num losses: 0
# Win streak: 2
# Loss streak: 0
# Avg pips risked: 0.0010090476190477056
# Avg trade length: 1.0
# Remaining runs: 50
# Best reward so far: 632.8377100001028
#
# -204.9791621428728
# Num buys: 26
# Num sells: 14
# Num trades: 40
# Num wins: 18
# Num losses: 22
# Win streak: 5
# Loss streak: 4
# Avg pips risked: 0.0015222321428571494
# Avg trade length: 17.15
# Remaining runs: 49
# Best reward so far: 632.8377100001028
#
# 24.747643571430594
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.001104047619047662
# Avg trade length: 1.5
# Remaining runs: 48
# Best reward so far: 632.8377100001028
#
# 50.42207428571655
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0008280357142857464
# Avg trade length: 1.5
# Remaining runs: 47
# Best reward so far: 632.8377100001028
#
# -1199.8939489284717
# Num buys: 22
# Num sells: 17
# Num trades: 39
# Num wins: 5
# Num losses: 34
# Win streak: 1
# Loss streak: 11
# Avg pips risked: 0.0006137362637362836
# Avg trade length: 3.3846153846153846
# Remaining runs: 46
# Best reward so far: 632.8377100001028
#
# -149.95741357141384
# Num buys: 3
# Num sells: 2
# Num trades: 5
# Num wins: 1
# Num losses: 4
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.0016580000000000704
# Avg trade length: 4.0
# Remaining runs: 45
# Best reward so far: 632.8377100001028
#
# -510.7809764286756
# Num buys: 9
# Num sells: 13
# Num trades: 22
# Num wins: 4
# Num losses: 18
# Win streak: 1
# Loss streak: 7
# Avg pips risked: 0.0009151298701298564
# Avg trade length: 31.818181818181817
# Remaining runs: 44
# Best reward so far: 632.8377100001028
#
# -49.91562499999487
# Num buys: 3
# Num sells: 0
# Num trades: 3
# Num wins: 1
# Num losses: 2
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.001855000000000014
# Avg trade length: 10.333333333333334
# Remaining runs: 43
# Best reward so far: 632.8377100001028
#
# -1950.725459999648
# Num buys: 68
# Num sells: 49
# Num trades: 117
# Num wins: 26
# Num losses: 91
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.0004865995115995222
# Avg trade length: 3.264957264957265
# Remaining runs: 42
# Best reward so far: 632.8377100001028
#
# -102.9674442856824
# Num buys: 7
# Num sells: 5
# Num trades: 12
# Num wins: 5
# Num losses: 7
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0017640476190476744
# Avg trade length: 20.25
# Remaining runs: 41
# Best reward so far: 632.8377100001028
#
# 91.06047857141814
# Num buys: 26
# Num sells: 27
# Num trades: 53
# Num wins: 22
# Num losses: 31
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.000987978436657688
# Avg trade length: 11.641509433962264
# Remaining runs: 40
# Best reward so far: 632.8377100001028
#
# -253.63933928569944
# Num buys: 9
# Num sells: 6
# Num trades: 15
# Num wins: 5
# Num losses: 10
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0010703571428571923
# Avg trade length: 12.2
# Remaining runs: 39
# Best reward so far: 632.8377100001028
#
# 25.142208571430906
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.000763809523809537
# Avg trade length: 1.0
# Remaining runs: 38
# Best reward so far: 632.8377100001028
#
# -449.74760892854545
# Num buys: 9
# Num sells: 6
# Num trades: 15
# Num wins: 2
# Num losses: 13
# Win streak: 1
# Loss streak: 9
# Avg pips risked: 0.0005351785714285962
# Avg trade length: 2.8
# Remaining runs: 37
# Best reward so far: 632.8377100001028
#
# -4.38999928572548
# Num buys: 4
# Num sells: 2
# Num trades: 6
# Num wins: 2
# Num losses: 4
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0010042261904761873
# Avg trade length: 15.833333333333334
# Remaining runs: 36
# Best reward so far: 632.8377100001028
#
# -1063.2298185711572
# Num buys: 98
# Num sells: 65
# Num trades: 163
# Num wins: 57
# Num losses: 106
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.000987182296231395
# Avg trade length: 15.877300613496933
# Remaining runs: 35
# Best reward so far: 632.8377100001028
#
# -346.5665857141502
# Num buys: 22
# Num sells: 15
# Num trades: 37
# Num wins: 10
# Num losses: 27
# Win streak: 1
# Loss streak: 6
# Avg pips risked: 0.0005400482625482821
# Avg trade length: 2.675675675675676
# Remaining runs: 34
# Best reward so far: 632.8377100001028
#
# -149.94422999999045
# Num buys: 4
# Num sells: 4
# Num trades: 8
# Num wins: 2
# Num losses: 6
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.0011358630952381286
# Avg trade length: 2.5
# Remaining runs: 33
# Best reward so far: 632.8377100001028
#
# -466.52421428565714
# Num buys: 40
# Num sells: 26
# Num trades: 66
# Num wins: 19
# Num losses: 47
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.000772288961038972
# Avg trade length: 10.318181818181818
# Remaining runs: 32
# Best reward so far: 632.8377100001028
#
# -55.48941714283073
# Num buys: 12
# Num sells: 11
# Num trades: 23
# Num wins: 11
# Num losses: 12
# Win streak: 3
# Loss streak: 3
# Avg pips risked: 0.0014029192546584032
# Avg trade length: 14.347826086956522
# Remaining runs: 31
# Best reward so far: 632.8377100001028
#
# -103.93242571427515
# Num buys: 3
# Num sells: 8
# Num trades: 11
# Num wins: 3
# Num losses: 8
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0010989610389610508
# Avg trade length: 19.09090909090909
# Remaining runs: 30
# Best reward so far: 632.8377100001028
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 29
# Best reward so far: 632.8377100001028
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 28
# Best reward so far: 632.8377100001028
#
# -847.9729407140977
# Num buys: 97
# Num sells: 65
# Num trades: 162
# Num wins: 73
# Num losses: 89
# Win streak: 5
# Loss streak: 6
# Avg pips risked: 0.0014818761022927975
# Avg trade length: 29.432098765432098
# Remaining runs: 27
# Best reward so far: 632.8377100001028
#
# -49.64022428571314
# Num buys: 2
# Num sells: 2
# Num trades: 4
# Num wins: 1
# Num losses: 3
# Win streak: 1
# Loss streak: 2
# Avg pips risked: 0.0009537500000000032
# Avg trade length: 3.25
# Remaining runs: 26
# Best reward so far: 632.8377100001028
#
# 297.95335214287996
# Num buys: 11
# Num sells: 7
# Num trades: 18
# Num wins: 12
# Num losses: 6
# Win streak: 6
# Loss streak: 2
# Avg pips risked: 0.001408869047619104
# Avg trade length: 12.777777777777779
# Remaining runs: 25
# Best reward so far: 632.8377100001028
#
# 148.00805107143623
# Num buys: 10
# Num sells: 7
# Num trades: 17
# Num wins: 10
# Num losses: 7
# Win streak: 5
# Loss streak: 2
# Avg pips risked: 0.0015598109243697815
# Avg trade length: 16.235294117647058
# Remaining runs: 24
# Best reward so far: 632.8377100001028
#
# -1261.6112442856816
# Num buys: 40
# Num sells: 27
# Num trades: 67
# Num wins: 14
# Num losses: 53
# Win streak: 2
# Loss streak: 11
# Avg pips risked: 0.0006327505330490505
# Avg trade length: 7.08955223880597
# Remaining runs: 23
# Best reward so far: 632.8377100001028
#
# -1623.9886128569535
# Num buys: 66
# Num sells: 49
# Num trades: 115
# Num wins: 33
# Num losses: 82
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.0006524886128364525
# Avg trade length: 4.565217391304348
# Remaining runs: 22
# Best reward so far: 632.8377100001028
#
# -1290.5290889284383
# Num buys: 50
# Num sells: 43
# Num trades: 93
# Num wins: 27
# Num losses: 66
# Win streak: 2
# Loss streak: 10
# Avg pips risked: 0.0007008730158730299
# Avg trade length: 4.698924731182796
# Remaining runs: 21
# Best reward so far: 632.8377100001028
#
# -104.39219571428212
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 2
# Num losses: 4
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.002075714285714255
# Avg trade length: 43.0
# Remaining runs: 20
# Best reward so far: 632.8377100001028
#
# 0.04693928571451522
# Num buys: 4
# Num sells: 0
# Num trades: 4
# Num wins: 2
# Num losses: 2
# Win streak: 2
# Loss streak: 2
# Avg pips risked: 0.0019625000000000337
# Avg trade length: 3.0
# Remaining runs: 19
# Best reward so far: 632.8377100001028
#
# -102.45120035714676
# Num buys: 4
# Num sells: 2
# Num trades: 6
# Num wins: 2
# Num losses: 4
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0020084523809523747
# Avg trade length: 19.833333333333332
# Remaining runs: 18
# Best reward so far: 632.8377100001028
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 17
# Best reward so far: 632.8377100001028
#
# 49.61738964285694
# Num buys: 4
# Num sells: 0
# Num trades: 4
# Num wins: 2
# Num losses: 2
# Win streak: 2
# Loss streak: 2
# Avg pips risked: 0.0013083333333333558
# Avg trade length: 2.0
# Remaining runs: 16
# Best reward so far: 632.8377100001028
#
# -149.6400942857259
# Num buys: 3
# Num sells: 3
# Num trades: 6
# Num wins: 1
# Num losses: 5
# Win streak: 1
# Loss streak: 3
# Avg pips risked: 0.0010378571428571275
# Avg trade length: 6.333333333333333
# Remaining runs: 15
# Best reward so far: 632.8377100001028
#
# -99.99925999999853
# Num buys: 0
# Num sells: 2
# Num trades: 2
# Num wins: 0
# Num losses: 2
# Win streak: 0
# Loss streak: 2
# Avg pips risked: 0.0005728571428571527
# Avg trade length: 1.0
# Remaining runs: 14
# Best reward so far: 632.8377100001028
#
# 197.5570857143038
# Num buys: 6
# Num sells: 6
# Num trades: 12
# Num wins: 8
# Num losses: 4
# Win streak: 3
# Loss streak: 2
# Avg pips risked: 0.0012520238095238463
# Avg trade length: 12.166666666666666
# Remaining runs: 13
# Best reward so far: 632.8377100001028
#
# -709.8751814286127
# Num buys: 14
# Num sells: 6
# Num trades: 20
# Num wins: 2
# Num losses: 18
# Win streak: 1
# Loss streak: 11
# Avg pips risked: 0.0011618035714285545
# Avg trade length: 34.0
# Remaining runs: 12
# Best reward so far: 632.8377100001028
#
# -157.1008742856991
# Num buys: 8
# Num sells: 9
# Num trades: 17
# Num wins: 7
# Num losses: 10
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.002068823529411786
# Avg trade length: 29.176470588235293
# Remaining runs: 11
# Best reward so far: 632.8377100001028
#
# 141.86238285714555
# Num buys: 13
# Num sells: 12
# Num trades: 25
# Num wins: 14
# Num losses: 11
# Win streak: 6
# Loss streak: 3
# Avg pips risked: 0.0016468857142857285
# Avg trade length: 30.88
# Remaining runs: 10
# Best reward so far: 632.8377100001028
#
# -606.1131207142093
# Num buys: 34
# Num sells: 22
# Num trades: 56
# Num wins: 22
# Num losses: 34
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0012746364795918738
# Avg trade length: 11.732142857142858
# Remaining runs: 9
# Best reward so far: 632.8377100001028
#
# -2423.501775714008
# Num buys: 104
# Num sells: 82
# Num trades: 186
# Num wins: 55
# Num losses: 131
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0006593625192012403
# Avg trade length: 4.650537634408602
# Remaining runs: 8
# Best reward so far: 632.8377100001028
#
# 43.47719857150204
# Num buys: 16
# Num sells: 13
# Num trades: 29
# Num wins: 10
# Num losses: 19
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0005771182266010033
# Avg trade length: 6.793103448275862
# Remaining runs: 7
# Best reward so far: 632.8377100001028
#
# -49.74902428567189
# Num buys: 22
# Num sells: 13
# Num trades: 35
# Num wins: 17
# Num losses: 18
# Win streak: 6
# Loss streak: 5
# Avg pips risked: 0.0008596122448979671
# Avg trade length: 3.2857142857142856
# Remaining runs: 6
# Best reward so far: 632.8377100001028
#
# -349.34004785713404
# Num buys: 30
# Num sells: 24
# Num trades: 54
# Num wins: 19
# Num losses: 35
# Win streak: 4
# Loss streak: 4
# Avg pips risked: 0.0014052204585537954
# Avg trade length: 33.111111111111114
# Remaining runs: 5
# Best reward so far: 632.8377100001028
#
# -151.66941535713462
# Num buys: 8
# Num sells: 3
# Num trades: 11
# Num wins: 4
# Num losses: 7
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0020418506493506757
# Avg trade length: 17.181818181818183
# Remaining runs: 4
# Best reward so far: 632.8377100001028
#
# 0
# Num buys: 0
# Num sells: 0
# Num trades: 0
# Num wins: 0
# Num losses: 0
# Win streak: 0
# Loss streak: 0
# Avg pips risked: N/A
# Avg trade length: 0
# Remaining runs: 3
# Best reward so far: 632.8377100001028
#
# -485.96083285705623
# Num buys: 40
# Num sells: 27
# Num trades: 67
# Num wins: 23
# Num losses: 44
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0008436673773987338
# Avg trade length: 10.194029850746269
# Remaining runs: 2
# Best reward so far: 632.8377100001028
#
# 270.58468571429006
# Num buys: 6
# Num sells: 6
# Num trades: 12
# Num wins: 7
# Num losses: 5
# Win streak: 3
# Loss streak: 4
# Avg pips risked: 0.0008346825396825644
# Avg trade length: 11.0
# Remaining runs: 1
# Best reward so far: 632.8377100001028
#
# 0.040790714287538776
# Num buys: 2
# Num sells: 0
# Num trades: 2
# Num wins: 1
# Num losses: 1
# Win streak: 1
# Loss streak: 1
# Avg pips risked: 0.0016560714285714928
# Avg trade length: 2.0
# Remaining runs: 0
# Best reward so far: 632.8377100001028

# %%
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n minutes: ' + str(best_n_minutes))
print('Best impact cutoff: ' + str(best_impact_cutoff))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 590.5448557143058
# Best risk/reward ratio: 1.5
# Best spread: 0.2
# Best atr multiplier: 2.0
# Best n minutes: 10
# Best adx cutoff: 2
# -----------------------
# Top results:
# {'reward': 314, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 345, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 195, 'ratio': 2.0, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 15, 'impact_cutoff': 3}
# {'reward': 319, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 10, 'impact_cutoff': 3}
# {'reward': 313, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 10, 'impact_cutoff': 3}
# {'reward': 251, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 15, 'impact_cutoff': 3}
# {'reward': 216, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 3}
# {'reward': 436, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 10, 'impact_cutoff': 2}
# {'reward': 249, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 3}
# {'reward': 432, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 10, 'impact_cutoff': 3}
# {'reward': 560, 'ratio': 2.0, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 10, 'impact_cutoff': 2}
# {'reward': 374, 'ratio': 2.0, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 436, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 10, 'impact_cutoff': 3}
# {'reward': 289, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 15, 'impact_cutoff': 3}
# {'reward': 319, 'ratio': 2.0, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 10, 'impact_cutoff': 3}
# {'reward': 406, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 239, 'ratio': 2.0, 'spread_val': 0.2, 'atr_multiplier': 1.0, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 590, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 10, 'impact_cutoff': 2}
# {'reward': 308, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 1.5, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 240, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 30, 'impact_cutoff': 3}

# %%
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best atr multiplier: ' + str(best_atr_multiplier))
print('Best n minutes: ' + str(best_n_minutes))
print('Best impact cutoff: ' + str(best_impact_cutoff))
print('-----------------------')
print('Top results:')

for entry in best_rewards:
    print(entry)
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: 632.8377100001028
# Best risk/reward ratio: 2.0
# Best spread: 0.2
# Best atr multiplier: 2.5
# Best n minutes: 30
# Best impact cutoff: 3
# -----------------------
# Top results:
# {'reward': 247, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 5, 'impact_cutoff': 3}
# {'reward': 149, 'ratio': 2.0, 'spread_val': 0.1, 'atr_multiplier': 2.5, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 393, 'ratio': 2.0, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 5, 'impact_cutoff': 3}
# {'reward': 192, 'ratio': 2.0, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 10, 'impact_cutoff': 3}
# {'reward': 200, 'ratio': 2.0, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 196, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 198, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 5, 'impact_cutoff': 3}
# {'reward': 419, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 150, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 239, 'ratio': 2.0, 'spread_val': 0.1, 'atr_multiplier': 2.5, 'n_minutes': 30, 'impact_cutoff': 3}
# {'reward': 632, 'ratio': 2.0, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 30, 'impact_cutoff': 3}
# {'reward': 359, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 30, 'impact_cutoff': 3}
# {'reward': 346, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 444, 'ratio': 2.0, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 287, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 30, 'impact_cutoff': 3}
# {'reward': 149, 'ratio': 1.5, 'spread_val': 0.1, 'atr_multiplier': 1.5, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 297, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 5, 'impact_cutoff': 2}
# {'reward': 148, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.5, 'n_minutes': 10, 'impact_cutoff': 3}
# {'reward': 197, 'ratio': 1.0, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 3}
# {'reward': 270, 'ratio': 1.5, 'spread_val': 0.2, 'atr_multiplier': 2.0, 'n_minutes': 5, 'impact_cutoff': 3}
