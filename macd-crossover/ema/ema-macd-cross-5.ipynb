# %%
import talib
import numpy as np
import pandas as pd
import random
from collections import deque

# %%
file_path = '/Users/mymac/Google_Drive/Forex_Robot/'

# %%
# ----------------------------------------------------------------------------------------------------
# Get the data
# ----------------------------------------------------------------------------------------------------
df = pd.read_csv(file_path + 'Oanda_Gbp_Usd_M5_2020-2021.csv')
df.Date = pd.to_datetime(df.Date)
df.reset_index(drop=True, inplace=True)

# %%
print(df.head())
print('-' * 75)
print(df.tail())
# Out:
#                  Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 0 2020-07-30 07:00:00   1.29543   1.29607  1.29540    1.29572   1.29562
# 1 2020-07-30 07:05:00   1.29569   1.29591  1.29505    1.29542   1.29588
# 2 2020-07-30 07:10:00   1.29541   1.29590  1.29514    1.29559   1.29557
# 3 2020-07-30 07:15:00   1.29561   1.29567  1.29510    1.29515   1.29577
# 4 2020-07-30 07:20:00   1.29514   1.29643  1.29501    1.29642   1.29529
#
#    Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 0   1.29623  1.29560    1.29589   1.29552   1.29615  1.29550    1.29580
# 1   1.29608  1.29522    1.29560   1.29578   1.29600  1.29514    1.29551
# 2   1.29606  1.29535    1.29575   1.29549   1.29598  1.29524    1.29567
# 3   1.29584  1.29530    1.29533   1.29569   1.29576  1.29520    1.29524
# 4   1.29660  1.29518    1.29660   1.29522   1.29652  1.29510    1.29651
# ---------------------------------------------------------------------------
#                      Date  Bid_Open  Bid_High  Bid_Low  Bid_Close  Ask_Open  \
# 74259 2021-07-30 06:35:00   1.39401   1.39451  1.39401    1.39430   1.39417
# 74260 2021-07-30 06:40:00   1.39433   1.39452  1.39415    1.39422   1.39449
# 74261 2021-07-30 06:45:00   1.39420   1.39455  1.39400    1.39451   1.39436
# 74262 2021-07-30 06:50:00   1.39454   1.39481  1.39447    1.39470   1.39469
# 74263 2021-07-30 06:55:00   1.39469   1.39503  1.39462    1.39503   1.39486
#
#        Ask_High  Ask_Low  Ask_Close  Mid_Open  Mid_High  Mid_Low  Mid_Close
# 74259   1.39467  1.39417    1.39447   1.39409   1.39459  1.39409    1.39438
# 74260   1.39466  1.39433    1.39440   1.39441   1.39459  1.39424    1.39431
# 74261   1.39472  1.39418    1.39466   1.39428   1.39464  1.39409    1.39458
# 74262   1.39499  1.39462    1.39490   1.39462   1.39490  1.39454    1.39480
# 74263   1.39518  1.39477    1.39518   1.39478   1.39510  1.39470    1.39510

# %%
df['macd'], df['macdsignal'], df['macdhist'] = talib.MACD(df['Mid_Close'])
df['ema200'] = talib.EMA(df['Mid_Close'], timeperiod=200)
df['ema175'] = talib.EMA(df['Mid_Close'], timeperiod=175)
df['ema150'] = talib.EMA(df['Mid_Close'], timeperiod=150)
df['ema125'] = talib.EMA(df['Mid_Close'], timeperiod=125)
df['ema100'] = talib.EMA(df['Mid_Close'], timeperiod=100)
df['ema75'] = talib.EMA(df['Mid_Close'], timeperiod=75)
df['ema20'] = talib.EMA(df['Mid_Close'], timeperiod=20)
df['ema10'] = talib.EMA(df['Mid_Close'], timeperiod=10)
df['ema5'] = talib.EMA(df['Mid_Close'], timeperiod=5)
df['adx'] = talib.ADX(df['Mid_High'], df['Mid_Low'], df['Mid_Close'], timeperiod=14)
df['rsi'] = talib.RSI(df['Mid_Close'], timeperiod=20)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
value_per_pip = 1.0
# max_pips_to_risk = 0.0020
amounts_per_day = [-0.00008, -0.0001, -0.00012]

# %%
# ----------------------------------------------------------------------------------------------------
# Simulation code
# ----------------------------------------------------------------------------------------------------
def calculate_day_fees(start_date, end_date, n_units):
    curr_fee = np.random.choice(amounts_per_day, p=[0.25, 0.50, 0.25]) * n_units
    num_days = np.busday_count(start_date.date(), end_date.date())

    return num_days * curr_fee


def run_simulation(risk_reward_ratio, spread_cutoff, use_tl, min_pips_to_risk, max_pips_to_risk, adx_cutoff, lookback):
    max_pips_to_risk /= 10000
    min_pips_to_risk /= 10000
    reward = 0
    n_wins = 0
    n_losses = 0
    win_streak = 0
    loss_streak = 0
    curr_win_streak = 0
    curr_loss_streak = 0
    n_buys = 0
    n_sells = 0
    pips_risked = []
    day_fees = 0
    n_units = 50000
    trade = None

    i = 12

    while i < len(df):
        curr_date = df.loc[df.index[i], 'Date']
        ema200 = df.loc[df.index[i - 1], 'ema200']
        ema175 = df.loc[df.index[i - 1], 'ema175']
        ema150 = df.loc[df.index[i - 1], 'ema150']
        ema125 = df.loc[df.index[i - 1], 'ema125']
        ema100 = df.loc[df.index[i - 1], 'ema100']
        ema75 = df.loc[df.index[i - 1], 'ema75']
        ema20_1, ema10_1 = df.loc[df.index[i - 1], ['ema20', 'ema10']]
        ema20_2, ema10_2 = df.loc[df.index[i - 2], ['ema20', 'ema10']]
        adx = max(df.loc[df.index[i - 6:i], 'adx'])
        rsi = df.loc[df.index[i - 1], 'rsi']
        curr_ao = df.loc[df.index[i], 'Ask_Open']
        curr_bo = df.loc[df.index[i], 'Bid_Open']
        spread = abs(curr_ao - curr_bo)
        enough_volatility = spread <= spread_cutoff
        curr_ml2 = df.loc[df.index[i - 2], 'Mid_Low']
        curr_ml1 = df.loc[df.index[i - 1], 'Mid_Low']
        curr_mh2 = df.loc[df.index[i - 2], 'Mid_High']
        curr_mh1 = df.loc[df.index[i - 1], 'Mid_High']
        curr_bar_length = abs(curr_mh1 - curr_ml1)
        trending = adx >= adx_cutoff
        curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
          df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
                              'Ask_Low', 'Ask_Close']]

        if trade is None:
          if ema10_2 < ema20_2 and ema10_1 > ema20_1  and enough_volatility and trending:
              recent_crossover = False

              for z in range(i - lookback, i - 1):
                macd1, macdsignal1 = df.loc[df.index[z + 1], ['macd', 'macdsignal']]
                macd2, macdsignal2 = df.loc[df.index[z], ['macd', 'macdsignal']]
                macd_vals = [0, macd2, macdsignal1]

                if macd2 < macdsignal2 and macd1 > macdsignal1 and max(macd_vals) == 0:
                    recent_crossover = True
                    break

              all_buys = True

              if recent_crossover and all_buys:
                open_price = float(curr_ask_open)
                pullback = None
                pullback = min(df.loc[df.index[i - 12:i], 'Mid_Low'])

                if open_price - pullback < min_pips_to_risk:
                  pullback = open_price - min_pips_to_risk

                elif open_price - pullback > max_pips_to_risk:
                  pullback = open_price - max_pips_to_risk

                if pullback is not None:
                    stop_loss = round(pullback, 5)
                    # stop_loss = round(pullback - pullback_cushion, 3)

                    if stop_loss < open_price:
                        curr_pips_to_risk = open_price - stop_loss

                        if curr_pips_to_risk <= max_pips_to_risk:
                            stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 5)
                            # stop_gain = round(open_price + (curr_pips_to_risk * risk_reward_ratio), 3)

                            trade = {'open_price': open_price, 'trade_type': 'buy', 'stop_loss': stop_loss,
                                                              'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                                              'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

                            n_buys += 1

                            pips_risked.append(curr_pips_to_risk)

          elif ema10_2 > ema20_2 and ema10_1 < ema20_1  and enough_volatility and trending:
              recent_crossover = False

              for z in range(i - lookback, i - 1):
                macd1, macdsignal1 = df.loc[df.index[z + 1], ['macd', 'macdsignal']]
                macd2, macdsignal2 = df.loc[df.index[z], ['macd', 'macdsignal']]
                macd_vals = [0, macd2, macdsignal1]

                if macd2 > macdsignal2 and macd1 < macdsignal1 and min(macd_vals) == 0:
                    recent_crossover = True
                    break

              all_sells = True

              if recent_crossover and all_sells:
                open_price = float(curr_bid_open)
                pullback = None
                pullback = max(df.loc[df.index[i - 12:i], 'Mid_High'])

                if pullback - open_price < min_pips_to_risk:
                  pullback = open_price + min_pips_to_risk

                elif pullback - open_price > max_pips_to_risk:
                  pullback = open_price + max_pips_to_risk

                if pullback is not None:
                    stop_loss = round(pullback, 5)
                    # stop_loss = round(pullback + pullback_cushion, 3)

                    if stop_loss > open_price:
                        curr_pips_to_risk = stop_loss - open_price

                        if curr_pips_to_risk <= max_pips_to_risk:
                            stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 5)
                            # stop_gain = round(open_price - (curr_pips_to_risk * risk_reward_ratio), 3)

                            trade = {'open_price': open_price, 'trade_type': 'sell', 'stop_loss': stop_loss,
                                    'stop_gain': stop_gain, 'pips_risked': round(curr_pips_to_risk, 5),
                                    'n_units': n_units, 'original_units': n_units, 'start_date': curr_date, 'end_date': None}

                            n_sells += 1

                            pips_risked.append(curr_pips_to_risk)

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_low <= trade['stop_loss']:
          trade_amount = (trade['stop_loss'] - trade['open_price']) * trade['n_units'] * value_per_pip
          reward += trade_amount
          day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

          n_wins += 1 if trade_amount > 0 else 0
          n_losses += 1 if trade_amount < 0 else 0
          curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
          curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

          if curr_win_streak > win_streak:
            win_streak = curr_win_streak

          if curr_loss_streak > loss_streak:
            loss_streak = curr_loss_streak

          trade = None

        if use_tl:
          if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high - trade['pips_risked'] > trade['stop_loss']:
              trade['stop_loss'] = curr_bid_high - trade['pips_risked']
          # if trade is not None and trade['original_units'] == trade['n_units'] and trade['trade_type'] == 'buy' and curr_bid_high - trade['open_price'] >= trade['pips_risked']:
          #     trade['stop_loss'] = trade['open_price']
          #     reward += trade['pips_risked'] * (trade['n_units'] / 2) * value_per_pip
          #     day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'] / 2)
          #     trade['n_units'] = trade['n_units'] / 2
              

        if trade is not None and trade['trade_type'] == 'buy' and curr_bid_high >= trade['stop_gain']:
          trade_amount = (trade['stop_gain'] - trade['open_price']) * trade['n_units'] * value_per_pip
          reward += trade_amount
          day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

          n_wins += 1 if trade_amount > 0 else 0
          n_losses += 1 if trade_amount < 0 else 0
          curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
          curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

          if curr_win_streak > win_streak:
            win_streak = curr_win_streak

          if curr_loss_streak > loss_streak:
            loss_streak = curr_loss_streak

          trade = None

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_high >= trade['stop_loss']:
          trade_amount = (trade['open_price'] - trade['stop_loss']) * trade['n_units'] * value_per_pip
          reward += trade_amount
          day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

          n_wins += 1 if trade_amount > 0 else 0
          n_losses += 1 if trade_amount < 0 else 0
          curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
          curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

          if curr_win_streak > win_streak:
            win_streak = curr_win_streak

          if curr_loss_streak > loss_streak:
            loss_streak = curr_loss_streak

          trade = None

        if use_tl:
          if trade is not None and trade['trade_type'] == 'sell' and trade['pips_risked'] + curr_ask_low < trade['stop_loss']:
            trade['stop_loss'] = trade['pips_risked'] + curr_ask_low
          # if trade is not None and trade['original_units'] == trade['n_units'] and trade['trade_type'] == 'sell' and trade['open_price'] - curr_ask_low >= trade['pips_risked']:
          #     trade['stop_loss'] = trade['open_price']
          #     reward += trade['pips_risked'] * (trade['n_units'] / 2) * value_per_pip
          #     day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'] / 2)
          #     trade['n_units'] = trade['n_units'] / 2

        if trade is not None and trade['trade_type'] == 'sell' and curr_ask_low <= trade['stop_gain']:
          trade_amount = (trade['open_price'] - trade['stop_gain']) * trade['n_units'] * value_per_pip
          reward += trade_amount
          day_fees += calculate_day_fees(trade['start_date'], curr_date, trade['n_units'])

          n_wins += 1 if trade_amount > 0 else 0
          n_losses += 1 if trade_amount < 0 else 0
          curr_win_streak = 0 if trade_amount < 0 else curr_win_streak + 1
          curr_loss_streak = 0 if trade_amount > 0 else curr_loss_streak + 1

          if curr_win_streak > win_streak:
            win_streak = curr_win_streak

          if curr_loss_streak > loss_streak:
            loss_streak = curr_loss_streak

          trade = None

        i += 1

    return reward + day_fees, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked

# %%
# ----------------------------------------------------------------------------------------------------
# Run simulation
# ----------------------------------------------------------------------------------------------------
risk_reward_ratio_vals = [1, 1.5, 2]
# risk_reward_ratio_vals = [2]
spread_cutoffs = [1.5, 2, 2.5]
# spread_cutoffs = [2]
use_tl_vals = [True, False]
min_pips_to_risk_vals = [5, 10]
max_pips_to_risk_vals = [10, 15]
adx_cutoff_vals = [5, 10, 15, 20, 25]
lookback_vals = [3, 4, 5, 6]
n_possibilities = len(risk_reward_ratio_vals) * len(spread_cutoffs) * len(use_tl_vals) * len(min_pips_to_risk_vals) * len(max_pips_to_risk_vals) * len(adx_cutoff_vals) * len(lookback_vals)
all_combos = []

for risk_reward_ratio in risk_reward_ratio_vals:
  for spread_val in spread_cutoffs:
    for use_tl in use_tl_vals:
      for min_pips in min_pips_to_risk_vals:
        for max_pips in max_pips_to_risk_vals:
          for adx_cutoff in adx_cutoff_vals:
            for lookback in lookback_vals:
              all_combos.append((risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff, lookback))

# percentage_to_try = 0.5
percentage_to_try = 1
n_runs = int(percentage_to_try * len(all_combos))
combos_to_try = random.sample(all_combos, n_runs)
print('Num runs: '+ str(len(combos_to_try)) + '\n')

best_risk_reward = None
best_spread_cutoff = None
best_use_tl_val = None
best_min_pips_val = None
best_max_pips_val = None
best_adx_val = None
best_lookback_val = None
top_n_results = 20
best_rewards = []
best_reward = -np.inf
runs_finished = 0

for risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff, lookback in combos_to_try:
  reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked = run_simulation(risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff, lookback)
  runs_finished += 1

  print(reward)
  print('Num buys: ' + str(n_sells))
  print('Num sells: ' + str(n_buys))
  print('Num trades: ' + str(n_buys + n_sells))
  print('Num wins: ' + str(n_wins))
  print('Num losses: ' + str(n_losses))
  print('Win streak: ' + str(win_streak))
  print('Loss streak: ' + str(loss_streak))
  print('Avg pips risked: ' + str(sum(pips_risked) / len(pips_risked)))
  print('Remaining runs: ' + str(n_runs - runs_finished))

  min_item = min(best_rewards, key=lambda entry: entry['reward']) if len(best_rewards) >= top_n_results else None
  if min_item is None or reward > min_item['reward']:
    if min_item is not None:
      best_rewards.remove(min_item)
    best_rewards.append({'reward': int(reward), 'ratio': risk_reward_ratio, 'spread': spread_val, 'use_tl': use_tl, 'min_pips': min_pips, 'max_pips': max_pips, 'adx_cutoff': adx_cutoff, 'lookback': lookback})


  if reward > best_reward:
    best_reward = reward
    best_risk_reward = risk_reward_ratio
    best_spread_cutoff = spread_val
    best_use_tl_val = use_tl
    best_min_pips_val = min_pips
    best_max_pips_val = max_pips
    best_adx_val = adx_cutoff
    best_lookback_val = lookback

  print('Best reward so far: ' + str(best_reward))
  print()
# Out:
# Num runs: 1440
#
# -1072.999999999818
# Num buys: 41
# Num sells: 44
# Num trades: 85
# Num wins: 24
# Num losses: 61
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0013068235294116976
# Remaining runs: 1439
# Best reward so far: -1072.999999999818
#
# -1012.4999999996605
# Num buys: 74
# Num sells: 67
# Num trades: 141
# Num wins: 63
# Num losses: 78
# Win streak: 5
# Loss streak: 12
# Avg pips risked: 0.0012926950354609247
# Remaining runs: 1438
# Best reward so far: -1012.4999999996605
#
# -9035.499999998716
# Num buys: 281
# Num sells: 255
# Num trades: 536
# Num wins: 129
# Num losses: 407
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0011999813432835302
# Remaining runs: 1437
# Best reward so far: -1012.4999999996605
#
# -9395.4999999983
# Num buys: 280
# Num sells: 251
# Num trades: 531
# Num wins: 113
# Num losses: 418
# Win streak: 3
# Loss streak: 30
# Avg pips risked: 0.0009563088512240223
# Remaining runs: 1436
# Best reward so far: -1012.4999999996605
#
# -2075.999999999334
# Num buys: 62
# Num sells: 79
# Num trades: 141
# Num wins: 40
# Num losses: 101
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1435
# Best reward so far: -1012.4999999996605
#
# -9036.499999998929
# Num buys: 326
# Num sells: 281
# Num trades: 607
# Num wins: 171
# Num losses: 436
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.0012583690280065427
# Remaining runs: 1434
# Best reward so far: -1012.4999999996605
#
# -10897.499999998048
# Num buys: 356
# Num sells: 301
# Num trades: 657
# Num wins: 144
# Num losses: 513
# Win streak: 3
# Loss streak: 29
# Avg pips risked: 0.0009449467275493902
# Remaining runs: 1433
# Best reward so far: -1012.4999999996605
#
# -1565.9999999990946
# Num buys: 62
# Num sells: 79
# Num trades: 141
# Num wins: 40
# Num losses: 101
# Win streak: 3
# Loss streak: 12
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1432
# Best reward so far: -1012.4999999996605
#
# -7760.499999997008
# Num buys: 300
# Num sells: 260
# Num trades: 560
# Num wins: 149
# Num losses: 411
# Win streak: 4
# Loss streak: 21
# Avg pips risked: 0.0009510178571427762
# Remaining runs: 1431
# Best reward so far: -1012.4999999996605
#
# -1565.9999999990946
# Num buys: 62
# Num sells: 79
# Num trades: 141
# Num wins: 40
# Num losses: 101
# Win streak: 3
# Loss streak: 12
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1430
# Best reward so far: -1012.4999999996605
#
# -4073.499999998823
# Num buys: 171
# Num sells: 158
# Num trades: 329
# Num wins: 98
# Num losses: 231
# Win streak: 3
# Loss streak: 13
# Avg pips risked: 0.0009551367781154174
# Remaining runs: 1429
# Best reward so far: -1012.4999999996605
#
# -3736.499999999288
# Num buys: 121
# Num sells: 109
# Num trades: 230
# Num wins: 56
# Num losses: 174
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0012525217391303658
# Remaining runs: 1428
# Best reward so far: -1012.4999999996605
#
# -1728.9999999990475
# Num buys: 62
# Num sells: 79
# Num trades: 141
# Num wins: 40
# Num losses: 101
# Win streak: 3
# Loss streak: 12
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1427
# Best reward so far: -1012.4999999996605
#
# -699.9999999999224
# Num buys: 23
# Num sells: 32
# Num trades: 55
# Num wins: 17
# Num losses: 38
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.00130218181818175
# Remaining runs: 1426
# Best reward so far: -699.9999999999224
#
# -925.4999999997817
# Num buys: 30
# Num sells: 40
# Num trades: 70
# Num wins: 17
# Num losses: 53
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0009692857142856281
# Remaining runs: 1425
# Best reward so far: -699.9999999999224
#
# -3992.999999999361
# Num buys: 122
# Num sells: 109
# Num trades: 231
# Num wins: 66
# Num losses: 165
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.001251904761904694
# Remaining runs: 1424
# Best reward so far: -699.9999999999224
#
# -5145.999999998611
# Num buys: 233
# Num sells: 207
# Num trades: 440
# Num wins: 133
# Num losses: 307
# Win streak: 4
# Loss streak: 15
# Avg pips risked: 0.0009346363636362896
# Remaining runs: 1423
# Best reward so far: -699.9999999999224
#
# -670.4999999999505
# Num buys: 23
# Num sells: 32
# Num trades: 55
# Num wins: 17
# Num losses: 38
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.001267636363636295
# Remaining runs: 1422
# Best reward so far: -670.4999999999505
#
# -124.99999999995399
# Num buys: 10
# Num sells: 11
# Num trades: 21
# Num wins: 6
# Num losses: 15
# Win streak: 2
# Loss streak: 6
# Avg pips risked: 0.0013204761904760968
# Remaining runs: 1421
# Best reward so far: -124.99999999995399
#
# -9669.499999999309
# Num buys: 339
# Num sells: 293
# Num trades: 632
# Num wins: 169
# Num losses: 463
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.001192341772151853
# Remaining runs: 1420
# Best reward so far: -124.99999999995399
#
# -2449.4999999995894
# Num buys: 136
# Num sells: 119
# Num trades: 255
# Num wins: 74
# Num losses: 181
# Win streak: 4
# Loss streak: 12
# Avg pips risked: 0.0012202745098038865
# Remaining runs: 1419
# Best reward so far: -124.99999999995399
#
# -7572.499999998998
# Num buys: 225
# Num sells: 197
# Num trades: 422
# Num wins: 122
# Num losses: 300
# Win streak: 4
# Loss streak: 15
# Avg pips risked: 0.0012774881516587101
# Remaining runs: 1418
# Best reward so far: -124.99999999995399
#
# -3514.999999998634
# Num buys: 152
# Num sells: 143
# Num trades: 295
# Num wins: 91
# Num losses: 204
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1417
# Best reward so far: -124.99999999995399
#
# -7817.999999995921
# Num buys: 317
# Num sells: 273
# Num trades: 590
# Num wins: 165
# Num losses: 425
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1416
# Best reward so far: -124.99999999995399
#
# -3091.999999999253
# Num buys: 149
# Num sells: 133
# Num trades: 282
# Num wins: 86
# Num losses: 196
# Win streak: 4
# Loss streak: 19
# Avg pips risked: 0.0012149290780141477
# Remaining runs: 1415
# Best reward so far: -124.99999999995399
#
# -2876.9999999994984
# Num buys: 110
# Num sells: 94
# Num trades: 204
# Num wins: 60
# Num losses: 144
# Win streak: 7
# Loss streak: 11
# Avg pips risked: 0.0012857352941175835
# Remaining runs: 1414
# Best reward so far: -124.99999999995399
#
# -4857.999999999249
# Num buys: 194
# Num sells: 184
# Num trades: 378
# Num wins: 98
# Num losses: 280
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0011693915343914919
# Remaining runs: 1413
# Best reward so far: -124.99999999995399
#
# -3652.9999999995503
# Num buys: 98
# Num sells: 86
# Num trades: 184
# Num wins: 42
# Num losses: 142
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.001184891304347776
# Remaining runs: 1412
# Best reward so far: -124.99999999995399
#
# -1412.4999999998097
# Num buys: 38
# Num sells: 43
# Num trades: 81
# Num wins: 24
# Num losses: 57
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0012981481481480833
# Remaining runs: 1411
# Best reward so far: -124.99999999995399
#
# -1242.499999999107
# Num buys: 87
# Num sells: 87
# Num trades: 174
# Num wins: 57
# Num losses: 117
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.0009659195402297979
# Remaining runs: 1410
# Best reward so far: -124.99999999995399
#
# -424.9999999998754
# Num buys: 12
# Num sells: 14
# Num trades: 26
# Num wins: 7
# Num losses: 19
# Win streak: 1
# Loss streak: 4
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1409
# Best reward so far: -124.99999999995399
#
# -9027.499999998716
# Num buys: 281
# Num sells: 255
# Num trades: 536
# Num wins: 129
# Num losses: 407
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0011999813432835302
# Remaining runs: 1408
# Best reward so far: -124.99999999995399
#
# -1504.9999999996533
# Num buys: 75
# Num sells: 71
# Num trades: 146
# Num wins: 47
# Num losses: 99
# Win streak: 5
# Loss streak: 21
# Avg pips risked: 0.0012958219178081506
# Remaining runs: 1407
# Best reward so far: -124.99999999995399
#
# -2865.999999999525
# Num buys: 111
# Num sells: 94
# Num trades: 205
# Num wins: 60
# Num losses: 145
# Win streak: 7
# Loss streak: 11
# Avg pips risked: 0.0012843414634145715
# Remaining runs: 1406
# Best reward so far: -124.99999999995399
#
# -2290.99999999892
# Num buys: 108
# Num sells: 99
# Num trades: 207
# Num wins: 58
# Num losses: 149
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0009402415458936376
# Remaining runs: 1405
# Best reward so far: -124.99999999995399
#
# -3227.499999999539
# Num buys: 149
# Num sells: 128
# Num trades: 277
# Num wins: 89
# Num losses: 188
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.001134332129963861
# Remaining runs: 1404
# Best reward so far: -124.99999999995399
#
# -1513.9999999990423
# Num buys: 87
# Num sells: 87
# Num trades: 174
# Num wins: 57
# Num losses: 117
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.0009659195402297979
# Remaining runs: 1403
# Best reward so far: -124.99999999995399
#
# -1029.4999999994452
# Num buys: 51
# Num sells: 61
# Num trades: 112
# Num wins: 32
# Num losses: 80
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.0009659821428570577
# Remaining runs: 1402
# Best reward so far: -124.99999999995399
#
# -5085.499999997759
# Num buys: 246
# Num sells: 217
# Num trades: 463
# Num wins: 127
# Num losses: 336
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0009309935205182864
# Remaining runs: 1401
# Best reward so far: -124.99999999995399
#
# -1230.9999999999013
# Num buys: 41
# Num sells: 44
# Num trades: 85
# Num wins: 24
# Num losses: 61
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0012699999999999346
# Remaining runs: 1400
# Best reward so far: -124.99999999995399
#
# -7763.499999997008
# Num buys: 300
# Num sells: 260
# Num trades: 560
# Num wins: 149
# Num losses: 411
# Win streak: 4
# Loss streak: 21
# Avg pips risked: 0.0009510178571427762
# Remaining runs: 1399
# Best reward so far: -124.99999999995399
#
# -6311.999999996631
# Num buys: 252
# Num sells: 237
# Num trades: 489
# Num wins: 140
# Num losses: 349
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1398
# Best reward so far: -124.99999999995399
#
# -671.4999999999505
# Num buys: 23
# Num sells: 32
# Num trades: 55
# Num wins: 17
# Num losses: 38
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.001267636363636295
# Remaining runs: 1397
# Best reward so far: -124.99999999995399
#
# -695.9999999999224
# Num buys: 23
# Num sells: 32
# Num trades: 55
# Num wins: 17
# Num losses: 38
# Win streak: 3
# Loss streak: 10
# Avg pips risked: 0.00130218181818175
# Remaining runs: 1396
# Best reward so far: -124.99999999995399
#
# -3840.4999999981615
# Num buys: 177
# Num sells: 161
# Num trades: 338
# Num wins: 94
# Num losses: 244
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0009506213017750658
# Remaining runs: 1395
# Best reward so far: -124.99999999995399
#
# -5434.999999997776
# Num buys: 246
# Num sells: 217
# Num trades: 463
# Num wins: 127
# Num losses: 336
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0009309935205182864
# Remaining runs: 1394
# Best reward so far: -124.99999999995399
#
# -6183.999999996582
# Num buys: 261
# Num sells: 229
# Num trades: 490
# Num wins: 138
# Num losses: 352
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1393
# Best reward so far: -124.99999999995399
#
# -10892.499999998048
# Num buys: 356
# Num sells: 301
# Num trades: 657
# Num wins: 144
# Num losses: 513
# Win streak: 3
# Loss streak: 29
# Avg pips risked: 0.0009449467275493902
# Remaining runs: 1392
# Best reward so far: -124.99999999995399
#
# -4550.499999999326
# Num buys: 146
# Num sells: 142
# Num trades: 288
# Num wins: 86
# Num losses: 202
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0012187499999999475
# Remaining runs: 1391
# Best reward so far: -124.99999999995399
#
# -163.49999999992215
# Num buys: 10
# Num sells: 11
# Num trades: 21
# Num wins: 7
# Num losses: 14
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0013295238095237117
# Remaining runs: 1390
# Best reward so far: -124.99999999995399
#
# -2739.999999998735
# Num buys: 120
# Num sells: 111
# Num trades: 231
# Num wins: 89
# Num losses: 142
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1389
# Best reward so far: -124.99999999995399
#
# -1981.499999999784
# Num buys: 38
# Num sells: 43
# Num trades: 81
# Num wins: 16
# Num losses: 65
# Win streak: 2
# Loss streak: 11
# Avg pips risked: 0.0012595061728394431
# Remaining runs: 1388
# Best reward so far: -124.99999999995399
#
# -3679.499999998658
# Num buys: 157
# Num sells: 136
# Num trades: 293
# Num wins: 77
# Num losses: 216
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009187030716722859
# Remaining runs: 1387
# Best reward so far: -124.99999999995399
#
# -7694.999999999201
# Num buys: 243
# Num sells: 213
# Num trades: 456
# Num wins: 169
# Num losses: 287
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0012498245614034616
# Remaining runs: 1386
# Best reward so far: -124.99999999995399
#
# -2882.4999999983165
# Num buys: 125
# Num sells: 116
# Num trades: 241
# Num wins: 70
# Num losses: 171
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1385
# Best reward so far: -124.99999999995399
#
# -1569.9999999994536
# Num buys: 43
# Num sells: 56
# Num trades: 99
# Num wins: 34
# Num losses: 65
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1384
# Best reward so far: -124.99999999995399
#
# -3752.9999999989927
# Num buys: 154
# Num sells: 132
# Num trades: 286
# Num wins: 103
# Num losses: 183
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0009211888111887399
# Remaining runs: 1383
# Best reward so far: -124.99999999995399
#
# -2867.999999999496
# Num buys: 110
# Num sells: 94
# Num trades: 204
# Num wins: 60
# Num losses: 144
# Win streak: 7
# Loss streak: 11
# Avg pips risked: 0.0012857352941175835
# Remaining runs: 1382
# Best reward so far: -124.99999999995399
#
# -8190.9999999990505
# Num buys: 275
# Num sells: 248
# Num trades: 523
# Num wins: 143
# Num losses: 380
# Win streak: 7
# Loss streak: 17
# Avg pips risked: 0.0012469216061185022
# Remaining runs: 1381
# Best reward so far: -124.99999999995399
#
# -3552.9999999996176
# Num buys: 141
# Num sells: 124
# Num trades: 265
# Num wins: 107
# Num losses: 158
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0012156226415093957
# Remaining runs: 1380
# Best reward so far: -124.99999999995399
#
# -8238.499999999392
# Num buys: 257
# Num sells: 229
# Num trades: 486
# Num wins: 125
# Num losses: 360
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.001223106995884722
# Remaining runs: 1379
# Best reward so far: -124.99999999995399
#
# -646.4999999993876
# Num buys: 48
# Num sells: 46
# Num trades: 94
# Num wins: 34
# Num losses: 60
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1378
# Best reward so far: -124.99999999995399
#
# -5032.9999999983565
# Num buys: 232
# Num sells: 204
# Num trades: 436
# Num wins: 164
# Num losses: 272
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0009373394495412098
# Remaining runs: 1377
# Best reward so far: -124.99999999995399
#
# -8074.999999998
# Num buys: 247
# Num sells: 223
# Num trades: 470
# Num wins: 104
# Num losses: 366
# Win streak: 3
# Loss streak: 22
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1376
# Best reward so far: -124.99999999995399
#
# -7814.999999995921
# Num buys: 317
# Num sells: 273
# Num trades: 590
# Num wins: 165
# Num losses: 425
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1375
# Best reward so far: -124.99999999995399
#
# -1012.999999999388
# Num buys: 78
# Num sells: 79
# Num trades: 157
# Num wins: 46
# Num losses: 111
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1374
# Best reward so far: -124.99999999995399
#
# -4887.499999999254
# Num buys: 198
# Num sells: 189
# Num trades: 387
# Num wins: 122
# Num losses: 265
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0011698449612402666
# Remaining runs: 1373
# Best reward so far: -124.99999999995399
#
# -525.4999999999005
# Num buys: 22
# Num sells: 31
# Num trades: 53
# Num wins: 22
# Num losses: 31
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012594339622640856
# Remaining runs: 1372
# Best reward so far: -124.99999999995399
#
# -7768.49999999787
# Num buys: 304
# Num sells: 258
# Num trades: 562
# Num wins: 198
# Num losses: 364
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0009397686832739457
# Remaining runs: 1371
# Best reward so far: -124.99999999995399
#
# -4578.999999998968
# Num buys: 170
# Num sells: 157
# Num trades: 327
# Num wins: 78
# Num losses: 249
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0009564220183485392
# Remaining runs: 1370
# Best reward so far: -124.99999999995399
#
# -1596.9999999997387
# Num buys: 76
# Num sells: 72
# Num trades: 148
# Num wins: 47
# Num losses: 101
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001257229729729662
# Remaining runs: 1369
# Best reward so far: -124.99999999995399
#
# -2881.9999999994984
# Num buys: 110
# Num sells: 94
# Num trades: 204
# Num wins: 60
# Num losses: 144
# Win streak: 7
# Loss streak: 11
# Avg pips risked: 0.0012857352941175835
# Remaining runs: 1368
# Best reward so far: -124.99999999995399
#
# -9819.999999998994
# Num buys: 308
# Num sells: 266
# Num trades: 574
# Num wins: 203
# Num losses: 371
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0011970383275260845
# Remaining runs: 1367
# Best reward so far: -124.99999999995399
#
# -1051.499999999904
# Num buys: 41
# Num sells: 44
# Num trades: 85
# Num wins: 24
# Num losses: 61
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0012699999999999346
# Remaining runs: 1366
# Best reward so far: -124.99999999995399
#
# -8046.4999999994
# Num buys: 256
# Num sells: 229
# Num trades: 485
# Num wins: 124
# Num losses: 360
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.00122323711340201
# Remaining runs: 1365
# Best reward so far: -124.99999999995399
#
# -2975.9999999995584
# Num buys: 142
# Num sells: 126
# Num trades: 268
# Num wins: 90
# Num losses: 178
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0012148507462686202
# Remaining runs: 1364
# Best reward so far: -124.99999999995399
#
# -6239.999999996655
# Num buys: 252
# Num sells: 237
# Num trades: 489
# Num wins: 140
# Num losses: 349
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1363
# Best reward so far: -124.99999999995399
#
# -2744.999999998735
# Num buys: 120
# Num sells: 111
# Num trades: 231
# Num wins: 89
# Num losses: 142
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1362
# Best reward so far: -124.99999999995399
#
# -1607.4999999997372
# Num buys: 76
# Num sells: 72
# Num trades: 148
# Num wins: 47
# Num losses: 101
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001257229729729662
# Remaining runs: 1361
# Best reward so far: -124.99999999995399
#
# -4360.499999998827
# Num buys: 160
# Num sells: 152
# Num trades: 312
# Num wins: 89
# Num losses: 223
# Win streak: 4
# Loss streak: 20
# Avg pips risked: 0.000963878205128116
# Remaining runs: 1360
# Best reward so far: -124.99999999995399
#
# -3488.9999999996253
# Num buys: 133
# Num sells: 120
# Num trades: 253
# Num wins: 72
# Num losses: 181
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.001249920948616535
# Remaining runs: 1359
# Best reward so far: -124.99999999995399
#
# -3916.999999998228
# Num buys: 163
# Num sells: 156
# Num trades: 319
# Num wins: 93
# Num losses: 226
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0009628213166143315
# Remaining runs: 1358
# Best reward so far: -124.99999999995399
#
# -8696.99999999728
# Num buys: 306
# Num sells: 268
# Num trades: 574
# Num wins: 162
# Num losses: 412
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1357
# Best reward so far: -124.99999999995399
#
# -5001.49999999721
# Num buys: 202
# Num sells: 191
# Num trades: 393
# Num wins: 113
# Num losses: 280
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1356
# Best reward so far: -124.99999999995399
#
# -4240.999999998813
# Num buys: 143
# Num sells: 141
# Num trades: 284
# Num wins: 67
# Num losses: 217
# Win streak: 4
# Loss streak: 22
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1355
# Best reward so far: -124.99999999995399
#
# -752.9999999994292
# Num buys: 52
# Num sells: 50
# Num trades: 102
# Num wins: 36
# Num losses: 66
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0009589215686273591
# Remaining runs: 1354
# Best reward so far: -124.99999999995399
#
# -4594.499999999263
# Num buys: 183
# Num sells: 176
# Num trades: 359
# Num wins: 97
# Num losses: 262
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.001248272980501348
# Remaining runs: 1353
# Best reward so far: -124.99999999995399
#
# -554.499999999759
# Num buys: 45
# Num sells: 40
# Num trades: 85
# Num wins: 31
# Num losses: 54
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.0012809411764705082
# Remaining runs: 1352
# Best reward so far: -124.99999999995399
#
# -372.49999999978377
# Num buys: 46
# Num sells: 40
# Num trades: 86
# Num wins: 31
# Num losses: 55
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.001238139534883645
# Remaining runs: 1351
# Best reward so far: -124.99999999995399
#
# -7973.499999998206
# Num buys: 296
# Num sells: 254
# Num trades: 550
# Num wins: 153
# Num losses: 397
# Win streak: 5
# Loss streak: 19
# Avg pips risked: 0.0009389090909090145
# Remaining runs: 1350
# Best reward so far: -124.99999999995399
#
# -7367.99999999777
# Num buys: 250
# Num sells: 224
# Num trades: 474
# Num wins: 132
# Num losses: 342
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1349
# Best reward so far: -124.99999999995399
#
# -2810.4999999984134
# Num buys: 122
# Num sells: 113
# Num trades: 235
# Num wins: 69
# Num losses: 166
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1348
# Best reward so far: -124.99999999995399
#
# -6940.999999999457
# Num buys: 210
# Num sells: 189
# Num trades: 399
# Num wins: 100
# Num losses: 298
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001213734335839548
# Remaining runs: 1347
# Best reward so far: -124.99999999995399
#
# -2599.9999999984357
# Num buys: 122
# Num sells: 113
# Num trades: 235
# Num wins: 69
# Num losses: 166
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1346
# Best reward so far: -124.99999999995399
#
# -7631.999999999087
# Num buys: 236
# Num sells: 213
# Num trades: 449
# Num wins: 133
# Num losses: 316
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0012516035634743388
# Remaining runs: 1345
# Best reward so far: -124.99999999995399
#
# -3757.999999998667
# Num buys: 144
# Num sells: 142
# Num trades: 286
# Num wins: 85
# Num losses: 201
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1344
# Best reward so far: -124.99999999995399
#
# -4498.999999999379
# Num buys: 153
# Num sells: 148
# Num trades: 301
# Num wins: 82
# Num losses: 219
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0012647508305647316
# Remaining runs: 1343
# Best reward so far: -124.99999999995399
#
# -399.49999999993366
# Num buys: 10
# Num sells: 11
# Num trades: 21
# Num wins: 7
# Num losses: 14
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0013204761904760968
# Remaining runs: 1342
# Best reward so far: -124.99999999995399
#
# -1487.9999999996705
# Num buys: 75
# Num sells: 69
# Num trades: 144
# Num wins: 59
# Num losses: 85
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0012544444444443775
# Remaining runs: 1341
# Best reward so far: -124.99999999995399
#
# -4850.999999999249
# Num buys: 194
# Num sells: 184
# Num trades: 378
# Num wins: 98
# Num losses: 280
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0011693915343914919
# Remaining runs: 1340
# Best reward so far: -124.99999999995399
#
# -3096.499999999675
# Num buys: 104
# Num sells: 91
# Num trades: 195
# Num wins: 52
# Num losses: 143
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0011799999999999508
# Remaining runs: 1339
# Best reward so far: -124.99999999995399
#
# -1377.9999999993802
# Num buys: 86
# Num sells: 87
# Num trades: 173
# Num wins: 58
# Num losses: 115
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.000966011560693554
# Remaining runs: 1338
# Best reward so far: -124.99999999995399
#
# -151.99999999992653
# Num buys: 10
# Num sells: 11
# Num trades: 21
# Num wins: 7
# Num losses: 14
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0013204761904760968
# Remaining runs: 1337
# Best reward so far: -124.99999999995399
#
# -3319.9999999995557
# Num buys: 95
# Num sells: 85
# Num trades: 180
# Num wins: 52
# Num losses: 128
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.001245777777777721
# Remaining runs: 1336
# Best reward so far: -124.99999999995399
#
# -8333.999999999061
# Num buys: 288
# Num sells: 247
# Num trades: 535
# Num wins: 203
# Num losses: 332
# Win streak: 6
# Loss streak: 8
# Avg pips risked: 0.0012633644859812586
# Remaining runs: 1335
# Best reward so far: -124.99999999995399
#
# -6093.999999997449
# Num buys: 243
# Num sells: 227
# Num trades: 470
# Num wins: 176
# Num losses: 294
# Win streak: 5
# Loss streak: 9
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1334
# Best reward so far: -124.99999999995399
#
# -2813.4999999984134
# Num buys: 122
# Num sells: 113
# Num trades: 235
# Num wins: 69
# Num losses: 166
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1333
# Best reward so far: -124.99999999995399
#
# -7970.99999999591
# Num buys: 321
# Num sells: 278
# Num trades: 599
# Num wins: 167
# Num losses: 432
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1332
# Best reward so far: -124.99999999995399
#
# -741.9999999997751
# Num buys: 46
# Num sells: 40
# Num trades: 86
# Num wins: 37
# Num losses: 49
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.001238139534883645
# Remaining runs: 1331
# Best reward so far: -124.99999999995399
#
# -5666.999999998415
# Num buys: 193
# Num sells: 187
# Num trades: 380
# Num wins: 90
# Num losses: 290
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1330
# Best reward so far: -124.99999999995399
#
# -11070.49999999806
# Num buys: 362
# Num sells: 307
# Num trades: 669
# Num wins: 147
# Num losses: 522
# Win streak: 3
# Loss streak: 29
# Avg pips risked: 0.0009424065769804918
# Remaining runs: 1329
# Best reward so far: -124.99999999995399
#
# -2973.9999999995584
# Num buys: 142
# Num sells: 126
# Num trades: 268
# Num wins: 90
# Num losses: 178
# Win streak: 4
# Loss streak: 10
# Avg pips risked: 0.0012148507462686202
# Remaining runs: 1328
# Best reward so far: -124.99999999995399
#
# -5379.999999999303
# Num buys: 206
# Num sells: 204
# Num trades: 410
# Num wins: 121
# Num losses: 289
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.001241975609756054
# Remaining runs: 1327
# Best reward so far: -124.99999999995399
#
# -627.99999999948
# Num buys: 48
# Num sells: 46
# Num trades: 94
# Num wins: 41
# Num losses: 53
# Win streak: 6
# Loss streak: 6
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1326
# Best reward so far: -124.99999999995399
#
# -167.49999999969535
# Num buys: 45
# Num sells: 40
# Num trades: 85
# Num wins: 28
# Num losses: 57
# Win streak: 3
# Loss streak: 9
# Avg pips risked: 0.0012809411764705082
# Remaining runs: 1325
# Best reward so far: -124.99999999995399
#
# -6015.499999996727
# Num buys: 248
# Num sells: 232
# Num trades: 480
# Num wins: 138
# Num losses: 342
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1324
# Best reward so far: -124.99999999995399
#
# -257.49999999976535
# Num buys: 46
# Num sells: 40
# Num trades: 86
# Num wins: 31
# Num losses: 55
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.001238139534883645
# Remaining runs: 1323
# Best reward so far: -124.99999999995399
#
# -822.4999999993838
# Num buys: 43
# Num sells: 56
# Num trades: 99
# Num wins: 30
# Num losses: 69
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1322
# Best reward so far: -124.99999999995399
#
# -4504.999999998599
# Num buys: 162
# Num sells: 155
# Num trades: 317
# Num wins: 112
# Num losses: 205
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.0009642902208201002
# Remaining runs: 1321
# Best reward so far: -124.99999999995399
#
# -3040.999999998703
# Num buys: 123
# Num sells: 114
# Num trades: 237
# Num wins: 89
# Num losses: 148
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1320
# Best reward so far: -124.99999999995399
#
# -1597.9999999997387
# Num buys: 76
# Num sells: 72
# Num trades: 148
# Num wins: 47
# Num losses: 101
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001257229729729662
# Remaining runs: 1319
# Best reward so far: -124.99999999995399
#
# -7432.499999998794
# Num buys: 261
# Num sells: 227
# Num trades: 488
# Num wins: 125
# Num losses: 363
# Win streak: 5
# Loss streak: 18
# Avg pips risked: 0.0012726844262294537
# Remaining runs: 1318
# Best reward so far: -124.99999999995399
#
# -1771.4999999998772
# Num buys: 54
# Num sells: 61
# Num trades: 115
# Num wins: 30
# Num losses: 85
# Win streak: 3
# Loss streak: 12
# Avg pips risked: 0.0012792173913042828
# Remaining runs: 1317
# Best reward so far: -124.99999999995399
#
# -8761.999999999116
# Num buys: 264
# Num sells: 226
# Num trades: 490
# Num wins: 169
# Num losses: 321
# Win streak: 7
# Loss streak: 13
# Avg pips risked: 0.0011764897959183219
# Remaining runs: 1316
# Best reward so far: -124.99999999995399
#
# -174.49999999969535
# Num buys: 45
# Num sells: 40
# Num trades: 85
# Num wins: 28
# Num losses: 57
# Win streak: 3
# Loss streak: 9
# Avg pips risked: 0.0012809411764705082
# Remaining runs: 1315
# Best reward so far: -124.99999999995399
#
# -6418.9999999978345
# Num buys: 239
# Num sells: 225
# Num trades: 464
# Num wins: 136
# Num losses: 328
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1314
# Best reward so far: -124.99999999995399
#
# -3822.9999999993956
# Num buys: 133
# Num sells: 119
# Num trades: 252
# Num wins: 71
# Num losses: 181
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.001291904761904697
# Remaining runs: 1313
# Best reward so far: -124.99999999995399
#
# -5670.499999998799
# Num buys: 232
# Num sells: 205
# Num trades: 437
# Num wins: 107
# Num losses: 330
# Win streak: 4
# Loss streak: 15
# Avg pips risked: 0.0009353546910754406
# Remaining runs: 1312
# Best reward so far: -124.99999999995399
#
# -612.9999999998597
# Num buys: 22
# Num sells: 31
# Num trades: 53
# Num wins: 14
# Num losses: 39
# Win streak: 2
# Loss streak: 9
# Avg pips risked: 0.0012594339622640856
# Remaining runs: 1311
# Best reward so far: -124.99999999995399
#
# -1917.4999999997362
# Num buys: 52
# Num sells: 58
# Num trades: 110
# Num wins: 40
# Num losses: 70
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0013129999999999318
# Remaining runs: 1310
# Best reward so far: -124.99999999995399
#
# -3144.9999999994448
# Num buys: 100
# Num sells: 89
# Num trades: 189
# Num wins: 46
# Num losses: 143
# Win streak: 4
# Loss streak: 12
# Avg pips risked: 0.001238359788359722
# Remaining runs: 1309
# Best reward so far: -124.99999999995399
#
# -1028.4999999994452
# Num buys: 51
# Num sells: 61
# Num trades: 112
# Num wins: 32
# Num losses: 80
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.0009659821428570577
# Remaining runs: 1308
# Best reward so far: -124.99999999995399
#
# -9178.999999998745
# Num buys: 325
# Num sells: 281
# Num trades: 606
# Num wins: 170
# Num losses: 435
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.0012587953795379064
# Remaining runs: 1307
# Best reward so far: -124.99999999995399
#
# -1006.4999999995432
# Num buys: 52
# Num sells: 50
# Num trades: 102
# Num wins: 41
# Num losses: 61
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.0009589215686273591
# Remaining runs: 1306
# Best reward so far: -124.99999999995399
#
# -3578.4999999995184
# Num buys: 160
# Num sells: 143
# Num trades: 303
# Num wins: 82
# Num losses: 221
# Win streak: 4
# Loss streak: 21
# Avg pips risked: 0.001127590759075871
# Remaining runs: 1305
# Best reward so far: -124.99999999995399
#
# -7170.499999999076
# Num buys: 186
# Num sells: 172
# Num trades: 358
# Num wins: 80
# Num losses: 278
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0012151117318435205
# Remaining runs: 1304
# Best reward so far: -124.99999999995399
#
# -822.4999999993838
# Num buys: 43
# Num sells: 56
# Num trades: 99
# Num wins: 30
# Num losses: 69
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1303
# Best reward so far: -124.99999999995399
#
# -4780.9999999993815
# Num buys: 193
# Num sells: 187
# Num trades: 380
# Num wins: 155
# Num losses: 225
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.001243894736842059
# Remaining runs: 1302
# Best reward so far: -124.99999999995399
#
# -1890.9999999991603
# Num buys: 71
# Num sells: 85
# Num trades: 156
# Num wins: 42
# Num losses: 114
# Win streak: 3
# Loss streak: 13
# Avg pips risked: 0.0009690384615383735
# Remaining runs: 1301
# Best reward so far: -124.99999999995399
#
# -3484.499999999525
# Num buys: 94
# Num sells: 84
# Num trades: 178
# Num wins: 42
# Num losses: 136
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0012471348314606176
# Remaining runs: 1300
# Best reward so far: -124.99999999995399
#
# -2937.4999999994525
# Num buys: 100
# Num sells: 85
# Num trades: 185
# Num wins: 47
# Num losses: 138
# Win streak: 4
# Loss streak: 12
# Avg pips risked: 0.00128313513513507
# Remaining runs: 1299
# Best reward so far: -124.99999999995399
#
# -10006.99999999898
# Num buys: 312
# Num sells: 273
# Num trades: 585
# Num wins: 207
# Num losses: 378
# Win streak: 6
# Loss streak: 13
# Avg pips risked: 0.001193846153846106
# Remaining runs: 1298
# Best reward so far: -124.99999999995399
#
# -3501.9999999986167
# Num buys: 162
# Num sells: 140
# Num trades: 302
# Num wins: 80
# Num losses: 222
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009157284768211239
# Remaining runs: 1297
# Best reward so far: -124.99999999995399
#
# -1418.4999999998795
# Num buys: 53
# Num sells: 61
# Num trades: 114
# Num wins: 30
# Num losses: 84
# Win streak: 3
# Loss streak: 12
# Avg pips risked: 0.001282017543859583
# Remaining runs: 1296
# Best reward so far: -124.99999999995399
#
# -2470.9999999995284
# Num buys: 101
# Num sells: 89
# Num trades: 190
# Num wins: 53
# Num losses: 137
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0012416842105262603
# Remaining runs: 1295
# Best reward so far: -124.99999999995399
#
# -6426.499999996624
# Num buys: 261
# Num sells: 229
# Num trades: 490
# Num wins: 138
# Num losses: 352
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1294
# Best reward so far: -124.99999999995399
#
# -8079.999999998
# Num buys: 247
# Num sells: 223
# Num trades: 470
# Num wins: 104
# Num losses: 366
# Win streak: 3
# Loss streak: 22
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1293
# Best reward so far: -124.99999999995399
#
# -4442.999999999331
# Num buys: 139
# Num sells: 137
# Num trades: 276
# Num wins: 84
# Num losses: 192
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.001269818840579654
# Remaining runs: 1292
# Best reward so far: -124.99999999995399
#
# -6705.999999997794
# Num buys: 243
# Num sells: 229
# Num trades: 472
# Num wins: 137
# Num losses: 335
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1291
# Best reward so far: -124.99999999995399
#
# -2840.4999999983825
# Num buys: 125
# Num sells: 116
# Num trades: 241
# Num wins: 70
# Num losses: 171
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1290
# Best reward so far: -124.99999999995399
#
# -7325.499999997061
# Num buys: 300
# Num sells: 260
# Num trades: 560
# Num wins: 149
# Num losses: 411
# Win streak: 4
# Loss streak: 21
# Avg pips risked: 0.0009510178571427762
# Remaining runs: 1289
# Best reward so far: -124.99999999995399
#
# -6954.499999999458
# Num buys: 211
# Num sells: 189
# Num trades: 400
# Num wins: 101
# Num losses: 298
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.0012135999999999493
# Remaining runs: 1288
# Best reward so far: -124.99999999995399
#
# -8287.499999999352
# Num buys: 282
# Num sells: 251
# Num trades: 533
# Num wins: 138
# Num losses: 394
# Win streak: 5
# Loss streak: 18
# Avg pips risked: 0.0011789868667917008
# Remaining runs: 1287
# Best reward so far: -124.99999999995399
#
# -2528.999999999396
# Num buys: 62
# Num sells: 78
# Num trades: 140
# Num wins: 30
# Num losses: 110
# Win streak: 3
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1286
# Best reward so far: -124.99999999995399
#
# -3765.4999999991196
# Num buys: 152
# Num sells: 131
# Num trades: 283
# Num wins: 82
# Num losses: 201
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.0009208833922260771
# Remaining runs: 1285
# Best reward so far: -124.99999999995399
#
# -4509.999999998599
# Num buys: 162
# Num sells: 155
# Num trades: 317
# Num wins: 112
# Num losses: 205
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.0009642902208201002
# Remaining runs: 1284
# Best reward so far: -124.99999999995399
#
# -4050.999999998786
# Num buys: 152
# Num sells: 142
# Num trades: 294
# Num wins: 72
# Num losses: 222
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1283
# Best reward so far: -124.99999999995399
#
# -1053.499999999904
# Num buys: 41
# Num sells: 44
# Num trades: 85
# Num wins: 24
# Num losses: 61
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0012699999999999346
# Remaining runs: 1282
# Best reward so far: -124.99999999995399
#
# -8430.999999998894
# Num buys: 274
# Num sells: 248
# Num trades: 522
# Num wins: 142
# Num losses: 379
# Win streak: 7
# Loss streak: 17
# Avg pips risked: 0.0012473946360152808
# Remaining runs: 1281
# Best reward so far: -124.99999999995399
#
# -2079.9999999989923
# Num buys: 95
# Num sells: 87
# Num trades: 182
# Num wins: 71
# Num losses: 111
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1280
# Best reward so far: -124.99999999995399
#
# -1599.4999999994682
# Num buys: 86
# Num sells: 87
# Num trades: 173
# Num wins: 47
# Num losses: 126
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.000966011560693554
# Remaining runs: 1279
# Best reward so far: -124.99999999995399
#
# -3314.999999998656
# Num buys: 157
# Num sells: 136
# Num trades: 293
# Num wins: 77
# Num losses: 216
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009187030716722859
# Remaining runs: 1278
# Best reward so far: -124.99999999995399
#
# -401.49999999993366
# Num buys: 10
# Num sells: 11
# Num trades: 21
# Num wins: 7
# Num losses: 14
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0013204761904760968
# Remaining runs: 1277
# Best reward so far: -124.99999999995399
#
# -373.49999999978377
# Num buys: 46
# Num sells: 40
# Num trades: 86
# Num wins: 31
# Num losses: 55
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.001238139534883645
# Remaining runs: 1276
# Best reward so far: -124.99999999995399
#
# -2558.4999999995725
# Num buys: 140
# Num sells: 121
# Num trades: 261
# Num wins: 90
# Num losses: 171
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.00121666666666663
# Remaining runs: 1275
# Best reward so far: -124.99999999995399
#
# -8015.499999999458
# Num buys: 258
# Num sells: 229
# Num trades: 487
# Num wins: 126
# Num losses: 361
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.001222566735112885
# Remaining runs: 1274
# Best reward so far: -124.99999999995399
#
# -7268.999999999161
# Num buys: 185
# Num sells: 166
# Num trades: 351
# Num wins: 96
# Num losses: 255
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0012694301994301432
# Remaining runs: 1273
# Best reward so far: -124.99999999995399
#
# -8792.499999998721
# Num buys: 277
# Num sells: 248
# Num trades: 525
# Num wins: 126
# Num losses: 399
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0012035999999999482
# Remaining runs: 1272
# Best reward so far: -124.99999999995399
#
# -1794.4999999997156
# Num buys: 50
# Num sells: 57
# Num trades: 107
# Num wins: 32
# Num losses: 75
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0013174766355139485
# Remaining runs: 1271
# Best reward so far: -124.99999999995399
#
# -6093.999999997449
# Num buys: 243
# Num sells: 227
# Num trades: 470
# Num wins: 176
# Num losses: 294
# Win streak: 5
# Loss streak: 9
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1270
# Best reward so far: -124.99999999995399
#
# -3657.4999999993943
# Num buys: 133
# Num sells: 119
# Num trades: 252
# Num wins: 71
# Num losses: 181
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.001291904761904697
# Remaining runs: 1269
# Best reward so far: -124.99999999995399
#
# -524.4999999996867
# Num buys: 52
# Num sells: 50
# Num trades: 102
# Num wins: 31
# Num losses: 71
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0009589215686273591
# Remaining runs: 1268
# Best reward so far: -124.99999999995399
#
# -1057.4999999993472
# Num buys: 43
# Num sells: 56
# Num trades: 99
# Num wins: 30
# Num losses: 69
# Win streak: 3
# Loss streak: 6
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1267
# Best reward so far: -124.99999999995399
#
# -9834.99999999932
# Num buys: 344
# Num sells: 302
# Num trades: 646
# Num wins: 174
# Num losses: 472
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.001189318885448871
# Remaining runs: 1266
# Best reward so far: -124.99999999995399
#
# -6105.999999996697
# Num buys: 248
# Num sells: 232
# Num trades: 480
# Num wins: 138
# Num losses: 342
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1265
# Best reward so far: -124.99999999995399
#
# -9041.499999998929
# Num buys: 326
# Num sells: 281
# Num trades: 607
# Num wins: 171
# Num losses: 436
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.0012583690280065427
# Remaining runs: 1264
# Best reward so far: -124.99999999995399
#
# -684.9999999995628
# Num buys: 71
# Num sells: 67
# Num trades: 138
# Num wins: 43
# Num losses: 95
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.001293478260869495
# Remaining runs: 1263
# Best reward so far: -124.99999999995399
#
# -1918.4999999997362
# Num buys: 52
# Num sells: 58
# Num trades: 110
# Num wins: 40
# Num losses: 70
# Win streak: 6
# Loss streak: 11
# Avg pips risked: 0.0013129999999999318
# Remaining runs: 1262
# Best reward so far: -124.99999999995399
#
# -3756.4999999996085
# Num buys: 143
# Num sells: 129
# Num trades: 272
# Num wins: 109
# Num losses: 163
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.001213860294117609
# Remaining runs: 1261
# Best reward so far: -124.99999999995399
#
# -3100.499999999675
# Num buys: 104
# Num sells: 91
# Num trades: 195
# Num wins: 52
# Num losses: 143
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0011799999999999508
# Remaining runs: 1260
# Best reward so far: -124.99999999995399
#
# -8230.499999999392
# Num buys: 257
# Num sells: 229
# Num trades: 486
# Num wins: 125
# Num losses: 360
# Win streak: 6
# Loss streak: 16
# Avg pips risked: 0.001223106995884722
# Remaining runs: 1259
# Best reward so far: -124.99999999995399
#
# -5144.999999998611
# Num buys: 233
# Num sells: 207
# Num trades: 440
# Num wins: 133
# Num losses: 307
# Win streak: 4
# Loss streak: 15
# Avg pips risked: 0.0009346363636362896
# Remaining runs: 1258
# Best reward so far: -124.99999999995399
#
# -9234.49999999865
# Num buys: 324
# Num sells: 280
# Num trades: 604
# Num wins: 168
# Num losses: 435
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.0012592715231787605
# Remaining runs: 1257
# Best reward so far: -124.99999999995399
#
# -3828.499999997439
# Num buys: 192
# Num sells: 180
# Num trades: 372
# Num wins: 115
# Num losses: 257
# Win streak: 5
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1256
# Best reward so far: -124.99999999995399
#
# -1776.4999999998772
# Num buys: 54
# Num sells: 61
# Num trades: 115
# Num wins: 30
# Num losses: 85
# Win streak: 3
# Loss streak: 12
# Avg pips risked: 0.0012792173913042828
# Remaining runs: 1255
# Best reward so far: -124.99999999995399
#
# -1900.9999999997578
# Num buys: 52
# Num sells: 58
# Num trades: 110
# Num wins: 39
# Num losses: 71
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0012749090909090256
# Remaining runs: 1254
# Best reward so far: -124.99999999995399
#
# -1373.9999999993802
# Num buys: 86
# Num sells: 87
# Num trades: 173
# Num wins: 58
# Num losses: 115
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.000966011560693554
# Remaining runs: 1253
# Best reward so far: -124.99999999995399
#
# -2902.4999999991123
# Num buys: 124
# Num sells: 121
# Num trades: 245
# Num wins: 74
# Num losses: 171
# Win streak: 4
# Loss streak: 12
# Avg pips risked: 0.0009602448979590958
# Remaining runs: 1252
# Best reward so far: -124.99999999995399
#
# -2532.999999999396
# Num buys: 62
# Num sells: 78
# Num trades: 140
# Num wins: 30
# Num losses: 110
# Win streak: 3
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1251
# Best reward so far: -124.99999999995399
#
# -1198.4999999999077
# Num buys: 42
# Num sells: 44
# Num trades: 86
# Num wins: 24
# Num losses: 62
# Win streak: 3
# Loss streak: 11
# Avg pips risked: 0.0012663953488371454
# Remaining runs: 1250
# Best reward so far: -124.99999999995399
#
# -1709.499999999866
# Num buys: 53
# Num sells: 61
# Num trades: 114
# Num wins: 30
# Num losses: 84
# Win streak: 3
# Loss streak: 12
# Avg pips risked: 0.001282017543859583
# Remaining runs: 1249
# Best reward so far: -124.99999999995399
#
# -283.99999999944555
# Num buys: 48
# Num sells: 46
# Num trades: 94
# Num wins: 34
# Num losses: 60
# Win streak: 6
# Loss streak: 7
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1248
# Best reward so far: -124.99999999995399
#
# -7225.499999998881
# Num buys: 216
# Num sells: 194
# Num trades: 410
# Num wins: 100
# Num losses: 310
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0012811219512194522
# Remaining runs: 1247
# Best reward so far: -124.99999999995399
#
# -8375.499999999396
# Num buys: 283
# Num sells: 251
# Num trades: 534
# Num wins: 139
# Num losses: 395
# Win streak: 5
# Loss streak: 18
# Avg pips risked: 0.0011785767790261734
# Remaining runs: 1246
# Best reward so far: -124.99999999995399
#
# -6398.999999997405
# Num buys: 247
# Num sells: 231
# Num trades: 478
# Num wins: 177
# Num losses: 301
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1245
# Best reward so far: -124.99999999995399
#
# -152.99999999992653
# Num buys: 10
# Num sells: 11
# Num trades: 21
# Num wins: 7
# Num losses: 14
# Win streak: 2
# Loss streak: 3
# Avg pips risked: 0.0013204761904760968
# Remaining runs: 1244
# Best reward so far: -124.99999999995399
#
# -5328.999999999233
# Num buys: 198
# Num sells: 190
# Num trades: 388
# Num wins: 99
# Num losses: 289
# Win streak: 4
# Loss streak: 18
# Avg pips risked: 0.0011663144329896482
# Remaining runs: 1243
# Best reward so far: -124.99999999995399
#
# -4886.499999999254
# Num buys: 198
# Num sells: 189
# Num trades: 387
# Num wins: 122
# Num losses: 265
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0011698449612402666
# Remaining runs: 1242
# Best reward so far: -124.99999999995399
#
# -9871.499999996538
# Num buys: 398
# Num sells: 333
# Num trades: 731
# Num wins: 192
# Num losses: 539
# Win streak: 4
# Loss streak: 24
# Avg pips risked: 0.0009363337893296119
# Remaining runs: 1241
# Best reward so far: -124.99999999995399
#
# -3735.499999999288
# Num buys: 121
# Num sells: 109
# Num trades: 230
# Num wins: 56
# Num losses: 174
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0012525217391303658
# Remaining runs: 1240
# Best reward so far: -124.99999999995399
#
# -8413.99999999734
# Num buys: 302
# Num sells: 264
# Num trades: 566
# Num wins: 161
# Num losses: 405
# Win streak: 3
# Loss streak: 16
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1239
# Best reward so far: -124.99999999995399
#
# -3917.999999998165
# Num buys: 177
# Num sells: 161
# Num trades: 338
# Num wins: 94
# Num losses: 244
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0009506213017750658
# Remaining runs: 1238
# Best reward so far: -124.99999999995399
#
# -3225.499999999539
# Num buys: 149
# Num sells: 128
# Num trades: 277
# Num wins: 89
# Num losses: 188
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.001134332129963861
# Remaining runs: 1237
# Best reward so far: -124.99999999995399
#
# -4657.499999999597
# Num buys: 152
# Num sells: 130
# Num trades: 282
# Num wins: 101
# Num losses: 181
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0011301773049645014
# Remaining runs: 1236
# Best reward so far: -124.99999999995399
#
# -7812.999999999041
# Num buys: 252
# Num sells: 223
# Num trades: 475
# Num wins: 126
# Num losses: 348
# Win streak: 6
# Loss streak: 17
# Avg pips risked: 0.0012740210526315254
# Remaining runs: 1235
# Best reward so far: -124.99999999995399
#
# -10359.49999999775
# Num buys: 368
# Num sells: 311
# Num trades: 679
# Num wins: 186
# Num losses: 493
# Win streak: 4
# Loss streak: 19
# Avg pips risked: 0.0009417673048600127
# Remaining runs: 1234
# Best reward so far: -124.99999999995399
#
# -3449.999999998338
# Num buys: 187
# Num sells: 176
# Num trades: 363
# Num wins: 119
# Num losses: 244
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1233
# Best reward so far: -124.99999999995399
#
# -3924.999999998165
# Num buys: 177
# Num sells: 161
# Num trades: 338
# Num wins: 94
# Num losses: 244
# Win streak: 4
# Loss streak: 14
# Avg pips risked: 0.0009506213017750658
# Remaining runs: 1232
# Best reward so far: -124.99999999995399
#
# -2639.99999999837
# Num buys: 122
# Num sells: 113
# Num trades: 235
# Num wins: 69
# Num losses: 166
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1231
# Best reward so far: -124.99999999995399
#
# -4361.499999998827
# Num buys: 160
# Num sells: 152
# Num trades: 312
# Num wins: 89
# Num losses: 223
# Win streak: 4
# Loss streak: 20
# Avg pips risked: 0.000963878205128116
# Remaining runs: 1230
# Best reward so far: -124.99999999995399
#
# -3754.499999998639
# Num buys: 162
# Num sells: 140
# Num trades: 302
# Num wins: 80
# Num losses: 222
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009157284768211239
# Remaining runs: 1229
# Best reward so far: -124.99999999995399
#
# -3543.499999999611
# Num buys: 134
# Num sells: 120
# Num trades: 254
# Num wins: 72
# Num losses: 182
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.00124877952755899
# Remaining runs: 1228
# Best reward so far: -124.99999999995399
#
# -1262.4999999995741
# Num buys: 72
# Num sells: 69
# Num trades: 141
# Num wins: 40
# Num losses: 101
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0012547517730495774
# Remaining runs: 1227
# Best reward so far: -124.99999999995399
#
# -9034.499999998929
# Num buys: 326
# Num sells: 281
# Num trades: 607
# Num wins: 171
# Num losses: 436
# Win streak: 6
# Loss streak: 14
# Avg pips risked: 0.0012583690280065427
# Remaining runs: 1226
# Best reward so far: -124.99999999995399
#
# -4711.499999999545
# Num buys: 158
# Num sells: 151
# Num trades: 309
# Num wins: 81
# Num losses: 228
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0012163106796116007
# Remaining runs: 1225
# Best reward so far: -124.99999999995399
#
# -1005.4999999995432
# Num buys: 52
# ...
#
# -2807.9999999986226
# Num buys: 126
# Num sells: 123
# Num trades: 249
# Num wins: 75
# Num losses: 174
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.000960682730923607
# Remaining runs: 1043
# Best reward so far: -124.99999999995399
#
# -10221.999999997399
# Num buys: 376
# Num sells: 317
# Num trades: 693
# Num wins: 239
# Num losses: 454
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0009424819624818873
# Remaining runs: 1042
# Best reward so far: -124.99999999995399
#
# -7633.999999997199
# Num buys: 314
# Num sells: 269
# Num trades: 583
# Num wins: 153
# Num losses: 430
# Win streak: 5
# Loss streak: 20
# Avg pips risked: 0.0009346140651800291
# Remaining runs: 1041
# Best reward so far: -124.99999999995399
#
# -5747.499999999431
# Num buys: 218
# Num sells: 210
# Num trades: 428
# Num wins: 115
# Num losses: 313
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0011725700934579028
# Remaining runs: 1040
# Best reward so far: -124.99999999995399
#
# -2359.999999998466
# Num buys: 110
# Num sells: 113
# Num trades: 223
# Num wins: 70
# Num losses: 153
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1039
# Best reward so far: -124.99999999995399
#
# -3443.9999999986185
# Num buys: 162
# Num sells: 140
# Num trades: 302
# Num wins: 80
# Num losses: 222
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009157284768211239
# Remaining runs: 1038
# Best reward so far: -124.99999999995399
#
# -9866.499999996538
# Num buys: 398
# Num sells: 333
# Num trades: 731
# Num wins: 192
# Num losses: 539
# Win streak: 4
# Loss streak: 24
# Avg pips risked: 0.0009363337893296119
# Remaining runs: 1037
# Best reward so far: -124.99999999995399
#
# -1848.9999999997715
# Num buys: 53
# Num sells: 61
# Num trades: 114
# Num wins: 30
# Num losses: 84
# Win streak: 3
# Loss streak: 12
# Avg pips risked: 0.0013184210526315098
# Remaining runs: 1036
# Best reward so far: -124.99999999995399
#
# -285.9999999998829
# Num buys: 22
# Num sells: 31
# Num trades: 53
# Num wins: 20
# Num losses: 33
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012952830188678595
# Remaining runs: 1035
# Best reward so far: -124.99999999995399
#
# -1511.9999999996533
# Num buys: 75
# Num sells: 71
# Num trades: 146
# Num wins: 47
# Num losses: 99
# Win streak: 5
# Loss streak: 21
# Avg pips risked: 0.0012958219178081506
# Remaining runs: 1034
# Best reward so far: -124.99999999995399
#
# -6019.499999996727
# Num buys: 248
# Num sells: 232
# Num trades: 480
# Num wins: 138
# Num losses: 342
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1033
# Best reward so far: -124.99999999995399
#
# -6403.999999997389
# Num buys: 253
# Num sells: 226
# Num trades: 479
# Num wins: 177
# Num losses: 302
# Win streak: 5
# Loss streak: 11
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1032
# Best reward so far: -124.99999999995399
#
# -2810.4999999984134
# Num buys: 122
# Num sells: 113
# Num trades: 235
# Num wins: 69
# Num losses: 166
# Win streak: 4
# Loss streak: 13
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1031
# Best reward so far: -124.99999999995399
#
# -1240.499999999107
# Num buys: 87
# Num sells: 87
# Num trades: 174
# Num wins: 57
# Num losses: 117
# Win streak: 4
# Loss streak: 9
# Avg pips risked: 0.0009659195402297979
# Remaining runs: 1030
# Best reward so far: -124.99999999995399
#
# -9780.499999996566
# Num buys: 391
# Num sells: 324
# Num trades: 715
# Num wins: 186
# Num losses: 529
# Win streak: 4
# Loss streak: 24
# Avg pips risked: 0.0009383636363635625
# Remaining runs: 1029
# Best reward so far: -124.99999999995399
#
# -4506.999999999379
# Num buys: 153
# Num sells: 148
# Num trades: 301
# Num wins: 82
# Num losses: 219
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0012647508305647316
# Remaining runs: 1028
# Best reward so far: -124.99999999995399
#
# -4653.499999999597
# Num buys: 152
# Num sells: 130
# Num trades: 282
# Num wins: 101
# Num losses: 181
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0011301773049645014
# Remaining runs: 1027
# Best reward so far: -124.99999999995399
#
# -6241.999999996655
# Num buys: 252
# Num sells: 237
# Num trades: 489
# Num wins: 140
# Num losses: 349
# Win streak: 5
# Loss streak: 14
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1026
# Best reward so far: -124.99999999995399
#
# -7402.999999999144
# Num buys: 193
# Num sells: 174
# Num trades: 367
# Num wins: 98
# Num losses: 269
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0012139509536784213
# Remaining runs: 1025
# Best reward so far: -124.99999999995399
#
# -7690.999999999201
# Num buys: 243
# Num sells: 213
# Num trades: 456
# Num wins: 169
# Num losses: 287
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0012498245614034616
# Remaining runs: 1024
# Best reward so far: -124.99999999995399
#
# -7942.999999999185
# Num buys: 246
# Num sells: 220
# Num trades: 466
# Num wins: 172
# Num losses: 294
# Win streak: 7
# Loss streak: 8
# Avg pips risked: 0.0012492703862660472
# Remaining runs: 1023
# Best reward so far: -124.99999999995399
#
# -2603.4999999994866
# Num buys: 101
# Num sells: 89
# Num trades: 190
# Num wins: 53
# Num losses: 137
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0012416842105262603
# Remaining runs: 1022
# Best reward so far: -124.99999999995399
#
# -784.4999999990188
# Num buys: 78
# Num sells: 79
# Num trades: 157
# Num wins: 55
# Num losses: 102
# Win streak: 5
# Loss streak: 9
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1021
# Best reward so far: -124.99999999995399
#
# -2077.9999999989923
# Num buys: 95
# Num sells: 87
# Num trades: 182
# Num wins: 71
# Num losses: 111
# Win streak: 5
# Loss streak: 8
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1020
# Best reward so far: -124.99999999995399
#
# -4832.999999997896
# Num buys: 197
# Num sells: 189
# Num trades: 386
# Num wins: 146
# Num losses: 240
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1019
# Best reward so far: -124.99999999995399
#
# -7995.499999995829
# Num buys: 317
# Num sells: 273
# Num trades: 590
# Num wins: 165
# Num losses: 425
# Win streak: 4
# Loss streak: 17
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1018
# Best reward so far: -124.99999999995399
#
# -1940.9999999997704
# Num buys: 38
# Num sells: 43
# Num trades: 81
# Num wins: 17
# Num losses: 64
# Win streak: 2
# Loss streak: 11
# Avg pips risked: 0.0012981481481480833
# Remaining runs: 1017
# Best reward so far: -124.99999999995399
#
# -3455.999999998
# Num buys: 189
# Num sells: 177
# Num trades: 366
# Num wins: 150
# Num losses: 216
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1016
# Best reward so far: -124.99999999995399
#
# -9690.49999999653
# Num buys: 398
# Num sells: 333
# Num trades: 731
# Num wins: 192
# Num losses: 539
# Win streak: 4
# Loss streak: 24
# Avg pips risked: 0.0009363337893296119
# Remaining runs: 1015
# Best reward so far: -124.99999999995399
#
# -2957.499999999562
# Num buys: 101
# Num sells: 89
# Num trades: 190
# Num wins: 53
# Num losses: 137
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0012416842105262603
# Remaining runs: 1014
# Best reward so far: -124.99999999995399
#
# -6834.999999999068
# Num buys: 179
# Num sells: 164
# Num trades: 343
# Num wins: 80
# Num losses: 263
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0012718658892127699
# Remaining runs: 1013
# Best reward so far: -124.99999999995399
#
# -2180.9999999985253
# Num buys: 110
# Num sells: 113
# Num trades: 223
# Num wins: 70
# Num losses: 153
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 1012
# Best reward so far: -124.99999999995399
#
# -8332.499999998414
# Num buys: 298
# Num sells: 257
# Num trades: 555
# Num wins: 127
# Num losses: 428
# Win streak: 5
# Loss streak: 33
# Avg pips risked: 0.0009365405405404644
# Remaining runs: 1011
# Best reward so far: -124.99999999995399
#
# -10212.999999997399
# Num buys: 376
# Num sells: 317
# Num trades: 693
# Num wins: 239
# Num losses: 454
# Win streak: 6
# Loss streak: 12
# Avg pips risked: 0.0009424819624818873
# Remaining runs: 1010
# Best reward so far: -124.99999999995399
#
# -8173.499999998194
# Num buys: 302
# Num sells: 258
# Num trades: 560
# Num wins: 155
# Num losses: 405
# Win streak: 5
# Loss streak: 19
# Avg pips risked: 0.0009362678571427815
# Remaining runs: 1009
# Best reward so far: -124.99999999995399
#
# -3548.9999999996176
# Num buys: 141
# Num sells: 124
# Num trades: 265
# Num wins: 107
# Num losses: 158
# Win streak: 4
# Loss streak: 8
# Avg pips risked: 0.0012156226415093957
# Remaining runs: 1008
# Best reward so far: -124.99999999995399
#
# -2868.999999999525
# Num buys: 111
# Num sells: 94
# Num trades: 205
# Num wins: 60
# Num losses: 145
# Win streak: 7
# Loss streak: 11
# Avg pips risked: 0.0012843414634145715
# Remaining runs: 1007
# Best reward so far: -124.99999999995399
#
# -3486.499999999525
# Num buys: 94
# Num sells: 84
# Num trades: 178
# Num wins: 42
# Num losses: 136
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0012471348314606176
# Remaining runs: 1006
# Best reward so far: -124.99999999995399
#
# -6777.999999999491
# Num buys: 212
# Num sells: 189
# Num trades: 401
# Num wins: 102
# Num losses: 299
# Win streak: 5
# Loss streak: 16
# Avg pips risked: 0.001212967581047331
# Remaining runs: 1005
# Best reward so far: -124.99999999995399
#
# -7968.499999998206
# Num buys: 296
# Num sells: 254
# Num trades: 550
# Num wins: 153
# Num losses: 397
# Win streak: 5
# Loss streak: 19
# Avg pips risked: 0.0009389090909090145
# Remaining runs: 1004
# Best reward so far: -124.99999999995399
#
# -525.4999999999005
# Num buys: 22
# Num sells: 31
# Num trades: 53
# Num wins: 22
# Num losses: 31
# Win streak: 4
# Loss streak: 7
# Avg pips risked: 0.0012594339622640856
# Remaining runs: 1003
# Best reward so far: -124.99999999995399
#
# -477.4999999996654
# Num buys: 30
# Num sells: 40
# Num trades: 70
# Num wins: 22
# Num losses: 48
# Win streak: 3
# Loss streak: 8
# Avg pips risked: 0.0009692857142856281
# Remaining runs: 1002
# Best reward so far: -124.99999999995399
#
# -4763.499999999475
# Num buys: 154
# Num sells: 148
# Num trades: 302
# Num wins: 83
# Num losses: 219
# Win streak: 3
# Loss streak: 14
# Avg pips risked: 0.0012644039735098817
# Remaining runs: 1001
# Best reward so far: -124.99999999995399
#
# -739.9999999997751
# Num buys: 46
# Num sells: 40
# Num trades: 86
# Num wins: 37
# Num losses: 49
# Win streak: 3
# Loss streak: 7
# Avg pips risked: 0.001238139534883645
# Remaining runs: 1000
# Best reward so far: -124.99999999995399
#
# -4867.499999997813
# Num buys: 240
# Num sells: 212
# Num trades: 452
# Num wins: 124
# Num losses: 328
# Win streak: 4
# Loss streak: 16
# Avg pips risked: 0.0009329203539822284
# Remaining runs: 999
# Best reward so far: -124.99999999995399
#
# -3455.999999998
# Num buys: 189
# Num sells: 177
# Num trades: 366
# Num wins: 150
# Num losses: 216
# Win streak: 5
# Loss streak: 10
# Avg pips risked: 0.0009999999999998899
# Remaining runs: 998
# Best reward so far: -124.99999999995399
#
# -2958.499999999562
# Num buys: 101
# Num sells: 89
# Num trades: 190
# Num wins: 53
# Num losses: 137
# Win streak: 3
# Loss streak: 15
# Avg pips risked: 0.0012416842105262603
# Remaining runs: 997
# Best reward so far: -124.99999999995399
#
# -4888.499999999254
# Num buys: 198
# Num sells: 189
# Num trades: 387
# Num wins: 122
# Num losses: 265
# Win streak: 4
# Loss streak: 11
# Avg pips risked: 0.0011698449612402666
# Remaining runs: 996
# Best reward so far: -124.99999999995399
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/y1/r6lw81g960n148db75yhq7140000gn/T/ipykernel_96579/2602500799.py in <module>
#      42
#      43 for risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff, lookback in combos_to_try:
# ---> 44   reward, n_buys, n_sells, n_wins, n_losses, win_streak, loss_streak, pips_risked = run_simulation(risk_reward_ratio, spread_val, use_tl, min_pips, max_pips, adx_cutoff, lookback)
#      45   runs_finished += 1
#      46
#
# /var/folders/y1/r6lw81g960n148db75yhq7140000gn/T/ipykernel_96579/1325192873.py in run_simulation(risk_reward_ratio, spread_cutoff, use_tl, min_pips_to_risk, max_pips_to_risk, adx_cutoff, lookback)
#      52         curr_bid_open, curr_bid_high, curr_bid_low, curr_bid_close, curr_ask_open, curr_ask_high, curr_ask_low, curr_ask_close = \
#      53           df.loc[df.index[i], ['Bid_Open', 'Bid_High', 'Bid_Low', 'Bid_Close', 'Ask_Open', 'Ask_High',
# ---> 54                               'Ask_Low', 'Ask_Close']]
#      55
#      56         if trade is None:
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     829                     return section
#     830                 # This is an elided recursive call to iloc/loc
# --> 831                 return getattr(section, self.name)[new_key]
#     832
#     833         raise IndexingError("not applicable")
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
# -> 1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1056         )
#    1057
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4881                 fill_value=fill_value,
#    4882                 allow_dups=allow_dups,
# -> 4883                 copy=copy,
#    4884             )
#    4885             # If we've made a copy once, no need to make another one
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#    1306         if axis == 0:
#    1307             new_blocks = self._slice_take_blocks_ax0(
# -> 1308                 indexer, fill_value=fill_value, only_slice=only_slice
#    1309             )
#    1310         else:
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice)
#    1348
#    1349         sl_type, slobj, sllen = _preprocess_slice_or_indexer(
# -> 1350             slice_or_indexer, self.shape[0], allow_fill=allow_fill
#    1351         )
#    1352
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in shape(self)
#     206     @property
#     207     def shape(self) -> Shape:
# --> 208         return tuple(len(ax) for ax in self.axes)
#     209
#     210     @property
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in <genexpr>(.0)
#     206     @property
#     207     def shape(self) -> Shape:
# --> 208         return tuple(len(ax) for ax in self.axes)
#     209
#     210     @property
#
# ~/Forex_Robot/simulations/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in __len__(self)
#     602         Return the length of the Index.
#     603         """
# --> 604         return len(self._data)
#     605
#     606     def __array__(self, dtype=None) -> np.ndarray:
#
# KeyboardInterrupt:

# %%
print('------------ FINAL RESULTS ------------')
print('Best reward: ' + str(best_reward))
print('Best risk/reward ratio: ' + str(best_risk_reward))
print('Best spread: ' + str(best_spread_cutoff))
print('Best TL val: ' + str(best_use_tl_val))
print('Best min pips to risk: ' + str(best_min_pips_val))
print('Best max pips to risk: ' + str(best_max_pips_val))
print('Best adx val: ' + str(best_adx_val))
print('Best lookback val: ' + str(best_lookback_val))
print('-----------------------')
print('Top results:')
for entry in best_rewards:
    print(entry)

# 2018-2019:
# {'reward': 1539, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 1554, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 575, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': -94, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 553, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 526, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 153, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1345, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 585, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': -99, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 25, 'spread': 2}
# {'reward': 150, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': -94, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 3}
# {'reward': 1355, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': -96, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 25, 'spread': 3}
# {'reward': 115, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 3}
# {'reward': 102, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 2}
# {'reward': -100, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': -125, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 2}
# {'reward': -92, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 2}
# {'reward': -139, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 3}

# 2019-2020:
# {'reward': 494, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 2}
# {'reward': 1306, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1316, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1088, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1345, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 892, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 801, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 562, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 495, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 3}
# {'reward': 895, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': -34, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1077, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1323, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': -17, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 741, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 3}
# {'reward': 549, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 742, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 2}
# {'reward': 797, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 350, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 348, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}

# {'reward': 1788, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1795, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 803, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 1211, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1335, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 889, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 1329, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 889, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 728, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 787, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 1042, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 1431, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 728, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1320, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 1425, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 1057, 'ratio': 2, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 1089, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1341, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1222, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 1093, 'ratio': 1.5, 'pullback': 0, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}


# 2020-2021:
# {'reward': 2381, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 15, 'spread': 3}
# {'reward': 2239, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 2513, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 2666, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 10}
# {'reward': 2254, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 10}
# {'reward': 2516, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 10}
# {'reward': 2256, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 2277, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 2254, 'ratio': 2, 'pullback': 0, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 2366, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 15, 'spread': 2}
# {'reward': 2531, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 2552, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 2285, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 2667, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 2}
# {'reward': 2238, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 10}
# {'reward': 2280, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 10, 'adx': 20, 'spread': 10}
# {'reward': 2552, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 10}
# {'reward': 2369, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 15, 'spread': 10}
# {'reward': 2673, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 25, 'spread': 3}
# {'reward': 2523, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}

# {'reward': 549, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 1254, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 717, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 2}
# {'reward': 734, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 25, 'spread': 2}
# {'reward': 560, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 517, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 528, 'ratio': 2, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 503, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 3}
# {'reward': 729, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 3}
# {'reward': 732, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 25, 'spread': 3}
# {'reward': 642, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 710, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 25, 'spread': 3}
# {'reward': 495, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 655, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 779, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 1259, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 50, 'adx': 20, 'spread': 2}
# {'reward': 725, 'ratio': 2, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 10, 'adx': 20, 'spread': 2}
# {'reward': 772, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 15, 'bar_length': 5, 'adx': 20, 'spread': 2}
# {'reward': 674, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 3}
# {'reward': 664, 'ratio': 1.5, 'pullback': 5, 'fractal_dist': 20, 'bar_length': 5, 'adx': 20, 'spread': 2}
# Out:
# ------------ FINAL RESULTS ------------
# Best reward: -4025.4999999998936
# Best risk/reward ratio: 2
# Best bar length: 10
# Best spread: 3
# Best TL val: False
# Best pips to risk: 20
# Best strict pips val: True
# -----------------------
# Top results:
# {'reward': -4554, 'ratio': 1.5, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': False}
# {'reward': -4463, 'ratio': 1.5, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4320, 'ratio': 1.5, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4322, 'ratio': 1.5, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4184, 'ratio': 2, 'bar_length': 10, 'spread': 2, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4214, 'ratio': 2, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4193, 'ratio': 2, 'bar_length': 10, 'spread': 3, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4025, 'ratio': 2, 'bar_length': 10, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4540, 'ratio': 2, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': False}
# {'reward': -4729, 'ratio': 1.5, 'bar_length': 10, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -5095, 'ratio': 2, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': False}
# {'reward': -4102, 'ratio': 2, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4025, 'ratio': 2, 'bar_length': 10, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4534, 'ratio': 1.5, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': False}
# {'reward': -4536, 'ratio': 2, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': False}
# {'reward': -4102, 'ratio': 2, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -5075, 'ratio': 2, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': False}
# {'reward': -4222, 'ratio': 2, 'bar_length': 5, 'spread': 2, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}
# {'reward': -4448, 'ratio': 1.5, 'bar_length': 5, 'spread': 3, 'use_tl': False, 'pips_to_risk': 15, 'strict_pips': True}
# {'reward': -4726, 'ratio': 1.5, 'bar_length': 10, 'spread': 3, 'use_tl': False, 'pips_to_risk': 20, 'strict_pips': True}

# %%
print(df['macd'].min())
print(df['macd'].max())
print(df['macd'].mean())
# Out:
# -0.003969309682979816
# 0.0035649639441031056
# 8.15201580071511e-06

# %%
print(df['macdsignal'].min())
print(df['macdsignal'].max())
print(df['macdsignal'].mean())
# Out:
# -0.0036593454070104913
# 0.003094390540288942
# 8.13115151206653e-06
